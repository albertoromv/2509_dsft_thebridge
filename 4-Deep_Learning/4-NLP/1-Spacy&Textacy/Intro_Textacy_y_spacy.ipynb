# %% [markdown]
# # Textacy & Spacy
# Librerias de procesado de NLP

# %%
'''
Versiones compatibles
Despues hay que reiniciar el entorno de ejecución
'''
# !pip install spacy
# !pip install textacy

# # Para siguientes ejecuciones, solo ejecutar esto y reiniciar despues el entorno
# !python -m spacy download en_core_web_lg
# !python -m spacy download es_core_news_lg
# Out:
# '\nVersiones compatibles\nDespues hay que reiniciar el entorno de ejecución\n'

# %%
# %pip install spacy
# %pip install textacy
# Out:
# Requirement already satisfied: spacy in c:\users\alberto romero\appdata\local\programs\python\python313\lib\site-packages (3.8.7)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in c:\users\alberto romero\appdata\local\programs\python\python313\lib\site-packages (from spacy) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\alberto romero\appdata\local\programs\python\python313\lib\site-packages (from spacy) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\alberto romero\appdata\local\programs\python\python313\lib\site-packages (from spacy) (1.0.13)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\alberto romero\appdata\local\programs\python\python313\lib\site-packages (from spacy) (2.0.11)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\alberto romero\appdata\local\programs\python\python313\lib\site-packages (from spacy) (3.0.10)
# Requirement already satisfied: thinc<8.4.0,>=8.3.4 in c:\users\alberto romero\appdata\local\programs\python\python313\lib\site-packages (from spacy) (8.3.6)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in c:\users\alberto romero\appdata\local\programs\python\python313\lib\site-packages (from spacy) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\users\alberto romero\appdata\local\programs\python\python313\lib\site-packages (from spacy) (2.5.1)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\alberto romero\appdata\local\programs\python\python313\lib\site-packages (from spacy) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in c:\users\alberto romero\appdata\local\programs\python\python313\lib\site-packages (from spacy) (0.4.1)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in c:\users\alberto romero\appdata\local\programs\python\python313\lib\site-packages (from spacy) (0.20.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\alberto romero\appdata\local\programs\python\python313\lib\site-packages (from spacy) (4.67.1)
# Requirement already satisfied: numpy>=1.19.0 in c:\users\alberto romero\appdata\roaming\python\python313\site-packages (from spacy) (2.3.5)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\alberto romero\appdata\local\programs\python\python313\lib\site-packages (from spacy) (2.32.4)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in c:\users\alberto romero\appdata\local\programs\python\python313\lib\site-packages (from spacy) (2.10.6)
# Requirement already satisfied: jinja2 in c:\users\alberto romero\appdata\local\programs\python\python313\lib\site-packages (from spacy) (3.1.5)
# Requirement already satisfied: setuptools in c:\users\alberto romero\appdata\local\programs\python\python313\lib\site-packages (from spacy) (75.8.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\alberto romero\appdata\roaming\python\python313\site-packages (from spacy) (25.0)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\users\alberto romero\appdata\local\programs\python\python313\lib\site-packages (from spacy) (3.5.0)
# Requirement already satisfied: language-data>=1.2 in c:\users\alberto romero\appdata\local\programs\python\python313\lib\site-packages (from langcodes<4.0.0,>=3.2.0->spacy) (1.3.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\alberto romero\appdata\local\programs\python\python313\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in c:\users\alberto romero\appdata\local\programs\python\python313\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (2.27.2)
# Requirement already satisfied: typing-extensions>=4.12.2 in c:\users\alberto romero\appdata\local\programs\python\python313\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (4.12.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\alberto romero\appdata\local\programs\python\python313\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\alberto romero\appdata\local\programs\python\python313\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\alberto romero\appdata\local\programs\python\python313\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\alberto romero\appdata\local\programs\python\python313\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2024.12.14)
# Requirement already satisfied: blis<1.4.0,>=1.3.0 in c:\users\alberto romero\appdata\local\programs\python\python313\lib\site-packages (from thinc<8.4.0,>=8.3.4->spacy) (1.3.0)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in c:\users\alberto romero\appdata\local\programs\python\python313\lib\site-packages (from thinc<8.4.0,>=8.3.4->spacy) (0.1.5)
# Requirement already satisfied: colorama in c:\users\alberto romero\appdata\roaming\python\python313\site-packages (from tqdm<5.0.0,>=4.38.0->spacy) (0.4.6)
# Requirement already satisfied: click>=8.0.0 in c:\users\alberto romero\appdata\local\programs\python\python313\lib\site-packages (from typer<1.0.0,>=0.3.0->spacy) (8.1.8)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\alberto romero\appdata\local\programs\python\python313\lib\site-packages (from typer<1.0.0,>=0.3.0->spacy) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in c:\users\alberto romero\appdata\local\programs\python\python313\lib\site-packages (from typer<1.0.0,>=0.3.0->spacy) (14.0.0)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in c:\users\alberto romero\appdata\local\programs\python\python313\lib\site-packages (from weasel<0.5.0,>=0.1.0->spacy) (0.23.0)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in c:\users\alberto romero\appdata\local\programs\python\python313\lib\site-packages (from weasel<0.5.0,>=0.1.0->spacy) (7.4.0)
# Requirement already satisfied: wrapt in c:\users\alberto romero\appdata\local\programs\python\python313\lib\site-packages (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.1.0->spacy) (2.0.0)
# Requirement already satisfied: marisa-trie>=1.1.0 in c:\users\alberto romero\appdata\local\programs\python\python313\lib\site-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy) (1.3.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\alberto romero\appdata\local\programs\python\python313\lib\site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\alberto romero\appdata\roaming\python\python313\site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\alberto romero\appdata\local\programs\python\python313\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (0.1.2)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\alberto romero\appdata\local\programs\python\python313\lib\site-packages (from jinja2->spacy) (3.0.2)
# Note: you may need to restart the kernel to use updated packages.
# Collecting textacy
#   Using cached textacy-0.13.0-py3-none-any.whl.metadata (5.3 kB)
# Requirement already satisfied: cachetools>=4.0.0 in c:\users\alberto romero\appdata\local\programs\python\python313\lib\site-packages (from textacy) (5.5.2)
# Requirement already satisfied: catalogue~=2.0 in c:\users\alberto romero\appdata\local\programs\python\python313\lib\site-packages (from textacy) (2.0.10)
# Collecting cytoolz>=0.10.1 (from textacy)
#   Downloading cytoolz-1.1.0-cp313-cp313-win_amd64.whl.metadata (5.3 kB)
# Collecting floret~=0.10.0 (from textacy)
#   Using cached floret-0.10.5.tar.gz (70 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Collecting jellyfish>=0.8.0 (from textacy)
#   Downloading jellyfish-1.2.1-cp313-cp313-win_amd64.whl.metadata (642 bytes)
# Requirement already satisfied: joblib>=0.13.0 in c:\users\alberto romero\appdata\local\programs\python\python313\lib\site-packages (from textacy) (1.4.2)
# Requirement already satisfied: networkx>=2.7 in c:\users\alberto romero\appdata\local\programs\python\python313\lib\site-packages (from textacy) (3.4.2)
# Requirement already satisfied: numpy>=1.17.0 in c:\users\alberto romero\appdata\roaming\python\python313\site-packages (from textacy) (2.3.5)
# Collecting pyphen>=0.10.0 (from textacy)
#   Using cached pyphen-0.17.2-py3-none-any.whl.metadata (3.2 kB)
# Requirement already satisfied: requests>=2.10.0 in c:\users\alberto romero\appdata\local\programs\python\python313\lib\site-packages (from textacy) (2.32.4)
# Requirement already satisfied: scipy>=1.8.0 in c:\users\alberto romero\appdata\local\programs\python\python313\lib\site-packages (from textacy) (1.15.1)
# Requirement already satisfied: scikit-learn>=1.0 in c:\users\alberto romero\appdata\local\programs\python\python313\lib\site-packages (from textacy) (1.6.1)
# Requirement already satisfied: spacy~=3.0 in c:\users\alberto romero\appdata\local\programs\python\python313\lib\site-packages (from textacy) (3.8.7)
# Requirement already satisfied: tqdm>=4.19.6 in c:\users\alberto romero\appdata\local\programs\python\python313\lib\site-packages (from textacy) (4.67.1)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in c:\users\alberto romero\appdata\local\programs\python\python313\lib\site-packages (from spacy~=3.0->textacy) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\alberto romero\appdata\local\programs\python\python313\lib\site-packages (from spacy~=3.0->textacy) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\alberto romero\appdata\local\programs\python\python313\lib\site-packages (from spacy~=3.0->textacy) (1.0.13)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\alberto romero\appdata\local\programs\python\python313\lib\site-packages (from spacy~=3.0->textacy) (2.0.11)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\alberto romero\appdata\local\programs\python\python313\lib\site-packages (from spacy~=3.0->textacy) (3.0.10)
# Requirement already satisfied: thinc<8.4.0,>=8.3.4 in c:\users\alberto romero\appdata\local\programs\python\python313\lib\site-packages (from spacy~=3.0->textacy) (8.3.6)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in c:\users\alberto romero\appdata\local\programs\python\python313\lib\site-packages (from spacy~=3.0->textacy) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\users\alberto romero\appdata\local\programs\python\python313\lib\site-packages (from spacy~=3.0->textacy) (2.5.1)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in c:\users\alberto romero\appdata\local\programs\python\python313\lib\site-packages (from spacy~=3.0->textacy) (0.4.1)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in c:\users\alberto romero\appdata\local\programs\python\python313\lib\site-packages (from spacy~=3.0->textacy) (0.20.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in c:\users\alberto romero\appdata\local\programs\python\python313\lib\site-packages (from spacy~=3.0->textacy) (2.10.6)
# Requirement already satisfied: jinja2 in c:\users\alberto romero\appdata\local\programs\python\python313\lib\site-packages (from spacy~=3.0->textacy) (3.1.5)
# Requirement already satisfied: setuptools in c:\users\alberto romero\appdata\local\programs\python\python313\lib\site-packages (from spacy~=3.0->textacy) (75.8.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\alberto romero\appdata\roaming\python\python313\site-packages (from spacy~=3.0->textacy) (25.0)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\users\alberto romero\appdata\local\programs\python\python313\lib\site-packages (from spacy~=3.0->textacy) (3.5.0)
# Requirement already satisfied: language-data>=1.2 in c:\users\alberto romero\appdata\local\programs\python\python313\lib\site-packages (from langcodes<4.0.0,>=3.2.0->spacy~=3.0->textacy) (1.3.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\alberto romero\appdata\local\programs\python\python313\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy~=3.0->textacy) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in c:\users\alberto romero\appdata\local\programs\python\python313\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy~=3.0->textacy) (2.27.2)
# Requirement already satisfied: typing-extensions>=4.12.2 in c:\users\alberto romero\appdata\local\programs\python\python313\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy~=3.0->textacy) (4.12.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\alberto romero\appdata\local\programs\python\python313\lib\site-packages (from requests>=2.10.0->textacy) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\alberto romero\appdata\local\programs\python\python313\lib\site-packages (from requests>=2.10.0->textacy) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\alberto romero\appdata\local\programs\python\python313\lib\site-packages (from requests>=2.10.0->textacy) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\alberto romero\appdata\local\programs\python\python313\lib\site-packages (from requests>=2.10.0->textacy) (2024.12.14)
# Requirement already satisfied: blis<1.4.0,>=1.3.0 in c:\users\alberto romero\appdata\local\programs\python\python313\lib\site-packages (from thinc<8.4.0,>=8.3.4->spacy~=3.0->textacy) (1.3.0)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in c:\users\alberto romero\appdata\local\programs\python\python313\lib\site-packages (from thinc<8.4.0,>=8.3.4->spacy~=3.0->textacy) (0.1.5)
# Requirement already satisfied: colorama in c:\users\alberto romero\appdata\roaming\python\python313\site-packages (from tqdm>=4.19.6->textacy) (0.4.6)
# Requirement already satisfied: click>=8.0.0 in c:\users\alberto romero\appdata\local\programs\python\python313\lib\site-packages (from typer<1.0.0,>=0.3.0->spacy~=3.0->textacy) (8.1.8)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\alberto romero\appdata\local\programs\python\python313\lib\site-packages (from typer<1.0.0,>=0.3.0->spacy~=3.0->textacy) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in c:\users\alberto romero\appdata\local\programs\python\python313\lib\site-packages (from typer<1.0.0,>=0.3.0->spacy~=3.0->textacy) (14.0.0)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in c:\users\alberto romero\appdata\local\programs\python\python313\lib\site-packages (from weasel<0.5.0,>=0.1.0->spacy~=3.0->textacy) (0.23.0)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in c:\users\alberto romero\appdata\local\programs\python\python313\lib\site-packages (from weasel<0.5.0,>=0.1.0->spacy~=3.0->textacy) (7.4.0)
# Requirement already satisfied: wrapt in c:\users\alberto romero\appdata\local\programs\python\python313\lib\site-packages (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.1.0->spacy~=3.0->textacy) (2.0.0)
# Collecting toolz>=0.8.0 (from cytoolz>=0.10.1->textacy)
#   Using cached toolz-1.1.0-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: marisa-trie>=1.1.0 in c:\users\alberto romero\appdata\local\programs\python\python313\lib\site-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy~=3.0->textacy) (1.3.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\alberto romero\appdata\local\programs\python\python313\lib\site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy~=3.0->textacy) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\alberto romero\appdata\roaming\python\python313\site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy~=3.0->textacy) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\alberto romero\appdata\local\programs\python\python313\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy~=3.0->textacy) (0.1.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\alberto romero\appdata\local\programs\python\python313\lib\site-packages (from scikit-learn>=1.0->textacy) (3.5.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\alberto romero\appdata\local\programs\python\python313\lib\site-packages (from jinja2->spacy~=3.0->textacy) (3.0.2)
# Using cached textacy-0.13.0-py3-none-any.whl (210 kB)
# Downloading cytoolz-1.1.0-cp313-cp313-win_amd64.whl (946 kB)
#    ---------------------------------------- 0.0/946.5 kB ? eta -:--:--
#    ---------------------------------------- 946.5/946.5 kB 32.1 MB/s  0:00:00
# Downloading jellyfish-1.2.1-cp313-cp313-win_amd64.whl (213 kB)
# Using cached pyphen-0.17.2-py3-none-any.whl (2.1 MB)
# Using cached toolz-1.1.0-py3-none-any.whl (58 kB)
# Building wheels for collected packages: floret
#   Building wheel for floret (pyproject.toml): started
#   Building wheel for floret (pyproject.toml): finished with status 'done'
#   Created wheel for floret: filename=floret-0.10.5-cp313-cp313-win_amd64.whl size=255955 sha256=73976a9faf9b393163ebe81823ce2689e3576ecc7dad6d374175a0e1d5ee8ab3
#   Stored in directory: c:\users\alberto romero\appdata\local\pip\cache\wheels\20\4f\28\fcfb0b1b03c6de8d45ead19cc004f927e9e9f6c28f2c50b1a9
# Successfully built floret
# Installing collected packages: toolz, pyphen, jellyfish, floret, cytoolz, textacy
#
#    ---------------------------------------- 0/6 [toolz]
#    ---------------------------------------- 0/6 [toolz]
#    ---------------------------------------- 0/6 [toolz]
#    ------ --------------------------------- 1/6 [pyphen]
#    -------------------- ------------------- 3/6 [floret]
#    -------------------------- ------------- 4/6 [cytoolz]
#    -------------------------- ------------- 4/6 [cytoolz]
#    -------------------------- ------------- 4/6 [cytoolz]
#    --------------------------------- ------ 5/6 [textacy]
#    --------------------------------- ------ 5/6 [textacy]
#    --------------------------------- ------ 5/6 [textacy]
#    --------------------------------- ------ 5/6 [textacy]
#    --------------------------------- ------ 5/6 [textacy]
#    --------------------------------- ------ 5/6 [textacy]
#    --------------------------------- ------ 5/6 [textacy]
#    --------------------------------- ------ 5/6 [textacy]
#    --------------------------------- ------ 5/6 [textacy]
#    --------------------------------- ------ 5/6 [textacy]
#    --------------------------------- ------ 5/6 [textacy]
#    ---------------------------------------- 6/6 [textacy]
#
# Successfully installed cytoolz-1.1.0 floret-0.10.5 jellyfish-1.2.1 pyphen-0.17.2 textacy-0.13.0 toolz-1.1.0
# Note: you may need to restart the kernel to use updated packages.

# %%
# !python -m spacy download en_core_web_lg
# !python -m spacy download es_core_news_lg
# Out:
# Collecting en-core-web-lg==3.8.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_lg-3.8.0/en_core_web_lg-3.8.0-py3-none-any.whl (400.7 MB)
#      ---------------------------------------- 0.0/400.7 MB ? eta -:--:--
#      --------------------------------------- 2.4/400.7 MB 32.6 MB/s eta 0:00:13
#      - ------------------------------------ 12.1/400.7 MB 41.4 MB/s eta 0:00:10
#      -- ----------------------------------- 23.9/400.7 MB 48.3 MB/s eta 0:00:08
#      --- ---------------------------------- 37.0/400.7 MB 52.5 MB/s eta 0:00:07
#      --- ---------------------------------- 41.9/400.7 MB 54.6 MB/s eta 0:00:07
#      ---- --------------------------------- 50.6/400.7 MB 45.1 MB/s eta 0:00:08
#      ------ ------------------------------- 64.2/400.7 MB 48.0 MB/s eta 0:00:08
#      ------- ------------------------------ 79.2/400.7 MB 50.9 MB/s eta 0:00:07
#      -------- ----------------------------- 88.1/400.7 MB 49.8 MB/s eta 0:00:07
#      --------- --------------------------- 102.5/400.7 MB 51.6 MB/s eta 0:00:06
#      ---------- -------------------------- 114.3/400.7 MB 51.8 MB/s eta 0:00:06
#      ---------- -------------------------- 118.2/400.7 MB 48.9 MB/s eta 0:00:06
#      ------------ ------------------------ 132.6/400.7 MB 50.4 MB/s eta 0:00:06
#      ------------- ----------------------- 145.2/400.7 MB 50.8 MB/s eta 0:00:06
#      -------------- ---------------------- 158.3/400.7 MB 51.7 MB/s eta 0:00:05
#      --------------- --------------------- 170.1/400.7 MB 52.1 MB/s eta 0:00:05
#      ---------------- -------------------- 184.0/400.7 MB 52.8 MB/s eta 0:00:05
#      ------------------ ------------------ 197.4/400.7 MB 53.3 MB/s eta 0:00:04
#      ------------------- ----------------- 208.7/400.7 MB 53.3 MB/s eta 0:00:04
#      -------------------- ---------------- 221.2/400.7 MB 53.5 MB/s eta 0:00:04
#      --------------------- --------------- 233.8/400.7 MB 53.8 MB/s eta 0:00:04
#      ---------------------- -------------- 244.8/400.7 MB 53.7 MB/s eta 0:00:03
#      ----------------------- ------------- 258.5/400.7 MB 54.2 MB/s eta 0:00:03
#      ------------------------ ------------ 269.7/400.7 MB 55.0 MB/s eta 0:00:03
#      ------------------------- ----------- 280.0/400.7 MB 54.8 MB/s eta 0:00:03
#      --------------------------- --------- 293.3/400.7 MB 54.7 MB/s eta 0:00:02
#      ---------------------------- -------- 305.7/400.7 MB 56.7 MB/s eta 0:00:02
#      ----------------------------- ------- 314.6/400.7 MB 56.6 MB/s eta 0:00:02
#      ------------------------------ ------ 326.4/400.7 MB 55.8 MB/s eta 0:00:02
#      ------------------------------- ----- 339.2/400.7 MB 55.4 MB/s eta 0:00:02
#      -------------------------------- ---- 352.3/400.7 MB 56.2 MB/s eta 0:00:01
#      --------------------------------- --- 364.1/400.7 MB 55.9 MB/s eta 0:00:01
#      ---------------------------------- -- 375.7/400.7 MB 55.8 MB/s eta 0:00:01
#      ----------------------------------- - 388.5/400.7 MB 57.4 MB/s eta 0:00:01
#      ------------------------------------  400.6/400.7 MB 58.0 MB/s eta 0:00:01
#      ------------------------------------  400.6/400.7 MB 58.0 MB/s eta 0:00:01
#      ------------------------------------  400.6/400.7 MB 58.0 MB/s eta 0:00:01
#      ---------------------------------------- 400.7/400.7 MB 50.5 MB/s  0:00:08
# Installing collected packages: en-core-web-lg
# Successfully installed en-core-web-lg-3.8.0
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_lg')
# Collecting es-core-news-lg==3.8.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/es_core_news_lg-3.8.0/es_core_news_lg-3.8.0-py3-none-any.whl (568.0 MB)
#      ---------------------------------------- 0.0/568.0 MB ? eta -:--:--
#      --------------------------------------- 4.2/568.0 MB 47.4 MB/s eta 0:00:12
#      - ------------------------------------ 16.3/568.0 MB 52.9 MB/s eta 0:00:11
#      - ------------------------------------ 29.4/568.0 MB 56.1 MB/s eta 0:00:10
#      -- ----------------------------------- 41.4/568.0 MB 55.9 MB/s eta 0:00:10
#      --- ---------------------------------- 49.3/568.0 MB 51.4 MB/s eta 0:00:11
#      --- ---------------------------------- 58.7/568.0 MB 50.0 MB/s eta 0:00:11
#      ---- --------------------------------- 72.6/568.0 MB 52.2 MB/s eta 0:00:10
#      ----- -------------------------------- 83.9/568.0 MB 52.9 MB/s eta 0:00:10
#      ------ ------------------------------- 94.9/568.0 MB 52.1 MB/s eta 0:00:10
#      ------- ----------------------------- 109.3/568.0 MB 53.6 MB/s eta 0:00:09
#      ------- ----------------------------- 122.4/568.0 MB 54.4 MB/s eta 0:00:09
#      -------- ---------------------------- 130.3/568.0 MB 52.7 MB/s eta 0:00:09
#      --------- --------------------------- 144.2/568.0 MB 53.7 MB/s eta 0:00:08
#      ---------- -------------------------- 157.3/568.0 MB 54.2 MB/s eta 0:00:08
#      ---------- -------------------------- 164.9/568.0 MB 52.8 MB/s eta 0:00:08
#      ----------- ------------------------- 172.5/568.0 MB 51.7 MB/s eta 0:00:08
#      ----------- ------------------------- 184.0/568.0 MB 51.8 MB/s eta 0:00:08
#      ------------ ------------------------ 199.2/568.0 MB 52.8 MB/s eta 0:00:07
#      ------------- ----------------------- 209.7/568.0 MB 52.7 MB/s eta 0:00:07
#      -------------- ---------------------- 219.7/568.0 MB 52.3 MB/s eta 0:00:07
#      -------------- ---------------------- 224.4/568.0 MB 52.4 MB/s eta 0:00:07
#      -------------- ---------------------- 224.7/568.0 MB 48.6 MB/s eta 0:00:08
#      --------------- --------------------- 230.9/568.0 MB 47.7 MB/s eta 0:00:08
#      --------------- --------------------- 243.5/568.0 MB 48.2 MB/s eta 0:00:07
#      ---------------- -------------------- 251.7/568.0 MB 48.4 MB/s eta 0:00:07
#      ----------------- ------------------- 262.7/568.0 MB 48.0 MB/s eta 0:00:07
#      ----------------- ------------------- 275.8/568.0 MB 48.3 MB/s eta 0:00:07
#      ------------------ ------------------ 283.1/568.0 MB 47.9 MB/s eta 0:00:06
#      ------------------- ----------------- 293.6/568.0 MB 47.3 MB/s eta 0:00:06
#      ------------------- ----------------- 301.5/568.0 MB 46.5 MB/s eta 0:00:06
#      -------------------- ---------------- 307.8/568.0 MB 46.4 MB/s eta 0:00:06
#      -------------------- ---------------- 314.6/568.0 MB 46.5 MB/s eta 0:00:06
#      --------------------- --------------- 326.1/568.0 MB 45.8 MB/s eta 0:00:06
#      ---------------------- -------------- 339.0/568.0 MB 45.7 MB/s eta 0:00:06
#      ---------------------- -------------- 352.1/568.0 MB 46.4 MB/s eta 0:00:05
#      ----------------------- ------------- 366.7/568.0 MB 46.4 MB/s eta 0:00:05
#      ------------------------ ------------ 381.2/568.0 MB 46.4 MB/s eta 0:00:05
#      ------------------------- ----------- 394.3/568.0 MB 47.3 MB/s eta 0:00:04
#      -------------------------- ---------- 406.6/568.0 MB 47.1 MB/s eta 0:00:04
#      --------------------------- --------- 418.4/568.0 MB 47.0 MB/s eta 0:00:04
#      --------------------------- --------- 427.8/568.0 MB 47.6 MB/s eta 0:00:03
#      ---------------------------- -------- 442.2/568.0 MB 48.5 MB/s eta 0:00:03
#      ----------------------------- ------- 456.9/568.0 MB 48.6 MB/s eta 0:00:03
#      ------------------------------ ------ 469.8/568.0 MB 48.6 MB/s eta 0:00:03
#      ------------------------------- ----- 481.6/568.0 MB 49.1 MB/s eta 0:00:02
#      ------------------------------- ----- 488.9/568.0 MB 51.5 MB/s eta 0:00:02
#      -------------------------------- ---- 492.8/568.0 MB 52.5 MB/s eta 0:00:02
#      -------------------------------- ---- 493.1/568.0 MB 49.5 MB/s eta 0:00:02
#      -------------------------------- ---- 495.2/568.0 MB 48.0 MB/s eta 0:00:02
#      -------------------------------- ---- 503.3/568.0 MB 47.2 MB/s eta 0:00:02
#      --------------------------------- --- 511.4/568.0 MB 46.5 MB/s eta 0:00:02
#      --------------------------------- --- 517.2/568.0 MB 46.1 MB/s eta 0:00:02
#      ---------------------------------- -- 529.5/568.0 MB 46.3 MB/s eta 0:00:01
#      ---------------------------------- -- 534.8/568.0 MB 46.0 MB/s eta 0:00:01
#      ----------------------------------- - 549.5/568.0 MB 46.3 MB/s eta 0:00:01
#      ------------------------------------  563.3/568.0 MB 47.3 MB/s eta 0:00:01
#      ------------------------------------  567.8/568.0 MB 48.3 MB/s eta 0:00:01
#      ------------------------------------  567.8/568.0 MB 48.3 MB/s eta 0:00:01
#      ------------------------------------  567.8/568.0 MB 48.3 MB/s eta 0:00:01
#      ------------------------------------  567.8/568.0 MB 48.3 MB/s eta 0:00:01
#      ------------------------------------  567.8/568.0 MB 48.3 MB/s eta 0:00:01
#      ------------------------------------  567.8/568.0 MB 48.3 MB/s eta 0:00:01
#      ------------------------------------  567.8/568.0 MB 48.3 MB/s eta 0:00:01
#      ------------------------------------  567.8/568.0 MB 48.3 MB/s eta 0:00:01
#      ------------------------------------  567.8/568.0 MB 48.3 MB/s eta 0:00:01
#      ------------------------------------  567.8/568.0 MB 48.3 MB/s eta 0:00:01
#      ---------------------------------------- 568.0/568.0 MB 34.5 MB/s  0:00:14
# Installing collected packages: es-core-news-lg
# Successfully installed es-core-news-lg-3.8.0
# ✔ Download and installation successful
# You can now load the package via spacy.load('es_core_news_lg')

# %% [markdown]
# # Spacy
# https://spacy.io/
#
# NOTA: Recuerda reiniciar el entorno de ejecucion despues de la instalacion

# %%
import spacy

nlp = spacy.load('en_core_web_lg')

# %% [markdown]
# ## Text basics
# Veamos como trabajar cn estos primeros ejemplos con la libreria ´spacy´. Cosas que podemos hacer:
# 1. Tokenizar en frases
# 2. Tokenizar en palabras
# 3. Acceder a los atributos de cada token
# 4. Acceder a las entidades del texto
# 5. Visualizar las entidades del texto

# %%
# The text we want to examine
text = """
London is the capital and most populous city of England and 
the United Kingdom.  Standing on the River Thames in the south east 
of the island of Great Britain, London has been a major settlement 
for two millennia. It was founded by the Romans, who named it Londinium.
"""

doc = nlp(text)

print(doc)

for num, sentence in enumerate(doc.sents):
  print(num, sentence)
# Out:
# London is the capital and most populous city of England and
# the United Kingdom.  Standing on the River Thames in the south east
# of the island of Great Britain, London has been a major settlement
# for two millennia. It was founded by the Romans, who named it Londinium.
#
# 0
#
# 1 London is the capital and most populous city of England and
# the United Kingdom.
# 2 Standing on the River Thames in the south east
# of the island of Great Britain, London has been a major settlement
# for two millennia.
# 3 It was founded by the Romans, who named it Londinium.

# %%
len(list(doc.sents))
# Out:
# 4

# %%
for word in doc[:20]:
  print(word.text, word.lemma_, word.pos_, word.is_stop)
# Out:
#
#  SPACE False
# London London PROPN False
# is be AUX True
# the the DET True
# capital capital NOUN False
# and and CCONJ True
# most most ADV True
# populous populous ADJ False
# city city NOUN False
# of of ADP True
# England England PROPN False
# and and CCONJ True
#
#
#  SPACE False
# the the DET True
# United United PROPN False
# Kingdom Kingdom PROPN False
# . . PUNCT False
#     SPACE False
# Standing stand VERB False
# on on ADP True

# %%
type(doc)
# Out:
# spacy.tokens.doc.Doc

# %% [markdown]
# ## Syntactic analysis
# Doing the school homework

# %%
# displaycy.render seems to be broken
# My Workaround Downgrade ipython to 7.23.1:
# pip install ipython==7.23.1

# %%
# %pip install ipython==7.23.1
# Out:
# Collecting ipython==7.23.1
#   Downloading ipython-7.23.1-py3-none-any.whl.metadata (4.2 kB)
# Requirement already satisfied: setuptools>=18.5 in c:\users\alberto romero\appdata\local\programs\python\python313\lib\site-packages (from ipython==7.23.1) (75.8.2)
# Requirement already satisfied: jedi>=0.16 in c:\users\alberto romero\appdata\roaming\python\python313\site-packages (from ipython==7.23.1) (0.19.2)
# Requirement already satisfied: decorator in c:\users\alberto romero\appdata\roaming\python\python313\site-packages (from ipython==7.23.1) (5.2.1)
# Collecting pickleshare (from ipython==7.23.1)
#   Downloading pickleshare-0.7.5-py2.py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: traitlets>=4.2 in c:\users\alberto romero\appdata\roaming\python\python313\site-packages (from ipython==7.23.1) (5.14.3)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\alberto romero\appdata\roaming\python\python313\site-packages (from ipython==7.23.1) (3.0.51)
# Requirement already satisfied: pygments in c:\users\alberto romero\appdata\roaming\python\python313\site-packages (from ipython==7.23.1) (2.19.1)
# Collecting backcall (from ipython==7.23.1)
#   Downloading backcall-0.2.0-py2.py3-none-any.whl.metadata (2.0 kB)
# Requirement already satisfied: matplotlib-inline in c:\users\alberto romero\appdata\roaming\python\python313\site-packages (from ipython==7.23.1) (0.1.7)
# Requirement already satisfied: colorama in c:\users\alberto romero\appdata\roaming\python\python313\site-packages (from ipython==7.23.1) (0.4.6)
# Requirement already satisfied: wcwidth in c:\users\alberto romero\appdata\roaming\python\python313\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython==7.23.1) (0.2.13)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in c:\users\alberto romero\appdata\roaming\python\python313\site-packages (from jedi>=0.16->ipython==7.23.1) (0.8.4)
# Downloading ipython-7.23.1-py3-none-any.whl (785 kB)
#    ---------------------------------------- 0.0/785.0 kB ? eta -:--:--
#    ---------------------------------------- 785.0/785.0 kB 29.4 MB/s  0:00:00
# Downloading backcall-0.2.0-py2.py3-none-any.whl (11 kB)
# Downloading pickleshare-0.7.5-py2.py3-none-any.whl (6.9 kB)
# Installing collected packages: pickleshare, backcall, ipython
#
#   Attempting uninstall: ipython
#
#     Found existing installation: ipython 9.3.0
#
#    -------------------------- ------------- 2/3 [ipython]
#     Uninstalling ipython-9.3.0:
#    -------------------------- ------------- 2/3 [ipython]
#       Successfully uninstalled ipython-9.3.0
#    -------------------------- ------------- 2/3 [ipython]
#    -------------------------- ------------- 2/3 [ipython]
#    -------------------------- ------------- 2/3 [ipython]
#    -------------------------- ------------- 2/3 [ipython]
#    -------------------------- ------------- 2/3 [ipython]
#    -------------------------- ------------- 2/3 [ipython]
#    -------------------------- ------------- 2/3 [ipython]
#    -------------------------- ------------- 2/3 [ipython]
#    -------------------------- ------------- 2/3 [ipython]
#    -------------------------- ------------- 2/3 [ipython]
#    -------------------------- ------------- 2/3 [ipython]
#    -------------------------- ------------- 2/3 [ipython]
#    -------------------------- ------------- 2/3 [ipython]
#    -------------------------- ------------- 2/3 [ipython]
#    -------------------------- ------------- 2/3 [ipython]
#    -------------------------- ------------- 2/3 [ipython]
#    -------------------------- ------------- 2/3 [ipython]
#    -------------------------- ------------- 2/3 [ipython]
#    -------------------------- ------------- 2/3 [ipython]
#    -------------------------- ------------- 2/3 [ipython]
#    -------------------------- ------------- 2/3 [ipython]
#    -------------------------- ------------- 2/3 [ipython]
#    -------------------------- ------------- 2/3 [ipython]
#    -------------------------- ------------- 2/3 [ipython]
#    -------------------------- ------------- 2/3 [ipython]
#    -------------------------- ------------- 2/3 [ipython]
#    -------------------------- ------------- 2/3 [ipython]
#    -------------------------- ------------- 2/3 [ipython]
#    -------------------------- ------------- 2/3 [ipython]
#    -------------------------- ------------- 2/3 [ipython]
#    -------------------------- ------------- 2/3 [ipython]
#    -------------------------- ------------- 2/3 [ipython]
#    -------------------------- ------------- 2/3 [ipython]
#    -------------------------- ------------- 2/3 [ipython]
#    -------------------------- ------------- 2/3 [ipython]
#    -------------------------- ------------- 2/3 [ipython]
#    -------------------------- ------------- 2/3 [ipython]
#    ---------------------------------------- 3/3 [ipython]
#
# Successfully installed backcall-0.2.0 ipython-7.23.1 pickleshare-0.7.5
# Note: you may need to restart the kernel to use updated packages.

# %%
from spacy import displacy

doc2 = nlp("London is the capital and most populous city of England and the United Kingdom")
displacy.render(doc2, jupyter=True, style="dep")

#nlp = spacy.load("en_core_web_sm")
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="fbbaa50091cd4415a9358f9cf965e700-0" class="displacy" width="2500" height="399.5" direction="ltr" style="max-width: none; height: 399.5px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="50">London</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="225">is</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="400">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="575">capital</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="750">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="925">most</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="1100">populous</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="1275">city</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="1450">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="1625">England</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1625">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="1800">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1800">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="1975">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1975">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="2150">United</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="2325">Kingdom</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2325">PROPN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-fbbaa50091cd4415a9358f9cf965e700-0-0" stroke-width="2px" d="M70,264.5 C70,177.0 215.0,177.0 215.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-fbbaa50091cd4415a9358f9cf965e700-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,266.5 L62,254.5 78,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-fbbaa50091cd4415a9358f9cf965e700-0-1" stroke-width="2px" d="M420,264.5 C420,177.0 565.0,177.0 565.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-fbbaa50091cd4415a9358f9cf965e700-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M420,266.5 L412,254.5 428,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-fbbaa50091cd4415a9358f9cf965e700-0-2" stroke-width="2px" d="M245,264.5 C245,89.5 570.0,89.5 570.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-fbbaa50091cd4415a9358f9cf965e700-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">attr</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M570.0,266.5 L578.0,254.5 562.0,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-fbbaa50091cd4415a9358f9cf965e700-0-3" stroke-width="2px" d="M595,264.5 C595,177.0 740.0,177.0 740.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-fbbaa50091cd4415a9358f9cf965e700-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">cc</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M740.0,266.5 L748.0,254.5 732.0,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-fbbaa50091cd4415a9358f9cf965e700-0-4" stroke-width="2px" d="M945,264.5 C945,177.0 1090.0,177.0 1090.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-fbbaa50091cd4415a9358f9cf965e700-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">advmod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M945,266.5 L937,254.5 953,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-fbbaa50091cd4415a9358f9cf965e700-0-5" stroke-width="2px" d="M1120,264.5 C1120,177.0 1265.0,177.0 1265.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-fbbaa50091cd4415a9358f9cf965e700-0-5" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">amod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M1120,266.5 L1112,254.5 1128,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-fbbaa50091cd4415a9358f9cf965e700-0-6" stroke-width="2px" d="M595,264.5 C595,89.5 1270.0,89.5 1270.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-fbbaa50091cd4415a9358f9cf965e700-0-6" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">conj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M1270.0,266.5 L1278.0,254.5 1262.0,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-fbbaa50091cd4415a9358f9cf965e700-0-7" stroke-width="2p

# %% [markdown]
# ## Entities in text

# %%
for entity in doc.ents:
  print(entity.text, entity.label_, spacy.explain(entity.label_))
# Out:
# London GPE Countries, cities, states
# England GPE Countries, cities, states
# the United Kingdom GPE Countries, cities, states
# south east LOC Non-GPE locations, mountain ranges, bodies of water
# Great Britain GPE Countries, cities, states
# London GPE Countries, cities, states
# two millennia DATE Absolute or relative dates or periods
# Romans NORP Nationalities or religious or political groups
# Londinium PERSON People, including fictional

# %%
# Doubts with labels
spacy.explain('ORG')
# Out:
# 'Companies, agencies, institutions, etc.'

# %%
displacy.render(doc, style='ent', jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr"><br>
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     London
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  is the capital and most populous city of
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     England
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  and <br>
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the United Kingdom
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# .  Standing on the River Thames in the
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     south east
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  <br>of the island of
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Great Britain
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# ,
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     London
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  has been a major settlement <br>for
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     two millennia
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# . It was founded by the
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Romans
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
# , who named it
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Londinium
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# .<br></div></span>

# %% [markdown]
# ## Replacing names
# Hide names for GDPR

# %%
# Replace a token with "REDACTED" if it is a name
def replace_name_with_placeholder(token):
    if token.ent_iob != 0 and token.ent_type_ == "PERSON":
        return "GDPR"
    else:
        return token.text

# Loop through all the entities in a document and check if they are names
def scrub(text):
    doc = nlp(text)
    with doc.retokenize() as retokenizer:
        for ent in doc.ents:
            retokenizer.merge(ent)
    tokens = map(replace_name_with_placeholder, doc)
    return " ".join(tokens)

s = """
In 1950, Alan Turing published his famous article "Computing Machinery and Intelligence". In 1957, Noam Chomsky’s 
Syntactic Structures revolutionized Linguistics with 'universal grammar', a rule based system of syntactic structures.
"""

print(scrub(s))
# Out:
#  In 1950 , GDPR published his famous article "Computing Machinery and Intelligence " . In 1957 , GDPR
#  Syntactic Structures revolutionized Linguistics with ' universal grammar ' , a rule based system of syntactic structures .

# %% [markdown]
# ## Lematize

# %%
for w in doc:
  print(w.text, w.lemma_, w.pos_)
# Out:
#
#  SPACE
# London London PROPN
# is be AUX
# the the DET
# capital capital NOUN
# and and CCONJ
# most most ADV
# populous populous ADJ
# city city NOUN
# of of ADP
# England England PROPN
# and and CCONJ
#
#
#  SPACE
# the the DET
# United United PROPN
# Kingdom Kingdom PROPN
# . . PUNCT
#     SPACE
# Standing stand VERB
# on on ADP
# the the DET
# River River PROPN
# Thames Thames PROPN
# in in ADP
# the the DET
# south south PROPN
# east east PROPN
#
#
#  SPACE
# of of ADP
# the the DET
# island island NOUN
# of of ADP
# Great Great PROPN
# Britain Britain PROPN
# , , PUNCT
# London London PROPN
# has have AUX
# been be AUX
# a a DET
# major major ADJ
# settlement settlement NOUN
#
#
#  SPACE
# for for ADP
# two two NUM
# millennia millennium NOUN
# . . PUNCT
# It it PRON
# was be AUX
# founded found VERB
# by by ADP
# the the DET
# Romans Romans PROPN
# , , PUNCT
# who who PRON
# named name VERB
# it it PRON
# Londinium Londinium PROPN
# . . PUNCT
#
#
#  SPACE

# %% [markdown]
# ## Stopwords

# %%
from spacy.lang.en.stop_words import STOP_WORDS

print(list(STOP_WORDS)[:20])
# Out:
# ['five', 'much', 'seemed', 'becoming', 'nowhere', 'see', 'by', 'using', 'mine', 'seeming', 'he', 'just', 'now', 'hereafter', 'fifteen', 'onto', "'s", 'through', 'via', 'doing']

# %%
lista_clean = [palabra for palabra in doc if not palabra.is_stop and not palabra.is_punct]
print(lista_clean)
# Out:
# [
# , London, capital, populous, city, England,
# , United, Kingdom,  , Standing, River, Thames, south, east,
# , island, Great, Britain, London, major, settlement,
# , millennia, founded, Romans, named, Londinium,
# ]

# %% [markdown]
# # Spanish
# ## Spacy  and entities

# %%
nlp_es = spacy.load('es_core_news_lg')

text = '''Londres (en inglés, London, pronunciado /ˈlʌndən/ ( escuchar)) es la capital y mayor ciudad de Inglaterra y del Reino Unido.2​3​ Situada a orillas del río Támesis, Londres es un importante asentamiento humano desde que fue fundada por los romanos con el nombre de Londinium hace casi dos milenios.4​ El núcleo antiguo de la urbe, la City de Londres, conserva básicamente su perímetro medieval de una milla cuadrada. Desde el siglo XIX el nombre «Londres» también hace referencia a toda la metrópolis desarrollada alrededor de este núcleo.5​ El grueso de esta conurbación forma la región de Londres y el área administrativa del Gran Londres,6​ gobernado por el alcalde y la asamblea de Londres.7​
Londres es una ciudad global, uno de los centros neurálgicos en el ámbito de las artes, el comercio, la educación, el entretenimiento, la moda, las finanzas, los medios de comunicación, la investigación, el turismo o el transporte.8​ Es el principal centro financiero del mundo9​10​11​ y una de las áreas metropolitanas con mayor PIB.12​13​ Londres es también una capital cultural mundial,14​15​16​17​ la ciudad más visitada considerando el número de visitas internacionales18​ y tiene el mayor sistema aeroportuario del mundo según el tráfico de pasajeros.19​ Asimismo, las 43 universidades de la ciudad conforman la mayor concentración de centros de estudios superiores de toda Europa.20​ En el año 2012 Londres se convirtió en la única ciudad en albergar la celebración de tres Juegos Olímpicos de Verano.21​
En esta ciudad multirracial convive gente de un gran número de culturas que hablan más de trescientos idiomas distintos.22​ La Autoridad del Gran Londres estima que en 2015 la ciudad tiene 8,63 millones de habitantes,23​ que supone el 12,5 % del total de habitantes del Reino Unido.24​ El área urbana del Gran Londres, con 10 470 00025​ habitantes, es la segunda más grande de Europa, pero su área metropolitana, con una población estimada de entre 12 y 14 millones,26​27​ es la mayor del continente. Desde 1831 a 1925 Londres, como capital del Imperio británico, fue la ciudad más poblada del mundo.'''
doc = nlp_es(text)

# Para ver las entidades que ha detectado
for entity in doc.ents:
    print(f"{entity.text} ({entity.label_})")
# Out:
# Londres (LOC)
# London (LOC)
# Inglaterra (LOC)
# Reino Unido.2​3​ Situada (LOC)
# Támesis (LOC)
# Londres (LOC)
# Londinium (LOC)
# El núcleo antiguo de la urbe (MISC)
# City de Londres (LOC)
# Londres (LOC)
# Londres (LOC)
# Gran Londres,6​ (LOC)
# Londres.7​
# Londres (LOC)
# Londres (LOC)
# Londres (LOC)
# Juegos Olímpicos de Verano.21​
# En esta ciudad multirracial convive gente de un gran número de culturas (MISC)
# La Autoridad del Gran Londres (MISC)
# Reino Unido.24​ El área urbana del (LOC)
# Gran Londres (LOC)
# Europa (LOC)
# Londres (LOC)
# Imperio británico (LOC)

# %%
# Doubts with labels
spacy.explain('MISC')
# Out:
# 'Miscellaneous entities, e.g. events, nationalities, products or works of art'

# %% [markdown]
# ## Most frequent words
# In a Wikipedia page

# %%
# !pip install wikipedia

# %%
from spacy.lang.es.stop_words import STOP_WORDS

# %%
list(STOP_WORDS)[:20]
# Out:
# ['usted',
#  'llevar',
#  'próximos',
#  'estan',
#  'ni',
#  'primeros',
#  'tenía',
#  'diferentes',
#  'ambos',
#  'también',
#  'ellos',
#  'ustedes',
#  'suyo',
#  'alli',
#  'mediante',
#  'creo',
#  'parece',
#  'usais',
#  'donde',
#  'tambien']

# %%
import wikipedia
wikipedia.set_lang("en")
wiki = wikipedia.page(title="Cristiano Ronaldo")
text = wiki.content
text[0:1000]
# Out:
# "Cristiano Ronaldo dos Santos Aveiro (Portuguese pronunciation: [kɾiʃˈtjɐnu ʁɔˈnaldu duʃ ˈsɐ̃tuʃ aˈvej.ɾu] ; born 5 February 1985) is a Portuguese professional footballer who plays as a forward for, and captains, both Saudi Pro League club Al-Nassr and the Portugal national team. Nicknamed CR7, he is widely regarded as one of the greatest players in history, and has won numerous individual accolades throughout his career, including five Ballon d'Ors, a record three UEFA Men's Player of the Year Awards, four European Golden Shoes, and was named five times the world's best player by FIFA. He has won 34 trophies in his career, including five UEFA Champions Leagues and the UEFA European Championship. He holds the records for most goals (140) and assists (42) in the Champions League, goals (14) and assists (8) in the European Championship, and most international appearances (226) and international goals (143). He is the only player to have scored 100 goals with four different clubs. He has m"

# %%
nombres = [w.text.lower() for w in nlp(text) if ((not w.is_stop) and (not w.is_punct) and (w.pos_ == 'ADJ'))]
nombres[:10]
# Out:
# ['portuguese',
#  'portuguese',
#  'professional',
#  'national',
#  'greatest',
#  'numerous',
#  'individual',
#  'best',
#  'international',
#  'international']

# %%
from collections import Counter
word_freq = Counter(nombres)

word_freq.most_common(10)[1:]
# Out:
# [('second', 20),
#  ('final', 15),
#  ('portuguese', 13),
#  ('consecutive', 13),
#  ('best', 11),
#  ('free', 9),
#  ('highest', 9),
#  ('official', 8),
#  ('personal', 8)]

# %%
wikipedia.set_lang("es")
wiki = wikipedia.page(title="Regresión Lineal")
text = wiki.content
text[0:1000]
# Out:
# 'En estadística, la regresión lineal o ajuste lineal es un modelo matemático usado para aproximar la relación de dependencia entre una variable dependiente \n  \n    \n      \n        Y\n      \n    \n    {\\displaystyle Y}\n  \n, \n  \n    \n      \n        m\n      \n    \n    {\\displaystyle m}\n  \n variables independientes \n  \n    \n      \n        \n          X\n          \n            i\n          \n        \n      \n    \n    {\\displaystyle X_{i}}\n  \n con \n  \n    \n      \n        m\n        ∈\n        \n          \n            Z\n          \n          \n            +\n          \n        \n      \n    \n    {\\displaystyle m\\in \\mathbb {Z} ^{+}}\n  \n y un término aleatorio \n  \n    \n      \n        ε\n      \n    \n    {\\displaystyle \\varepsilon }\n  \n. Este método es aplicable en muchas situaciones en las que se estudia la relación entre dos o más variables o predecir un comportamiento, algunas incluso sin relación con la tecnología. En caso de que no se pueda aplicar un modelo de regresión a un estudio, se dice que no hay corr'

# %%
nombres = [w.lemma_ for w in nlp_es(text) if ((not w.is_stop) and (not w.is_punct) and (w.pos_ == 'ADJ'))]
nombres[:10]
# Out:
# ['lineal',
#  'lineal',
#  'matemático',
#  'usado',
#  'dependiente',
#  'independiente',
#  '\\displaystyle',
#  '\\displaystyle',
#  'aleatorio',
#  'aplicable']

# %%
from collections import Counter
word_freq = Counter(nombres)

word_freq.most_common(10)[1:]
# Out:
# [('obtenido', 11),
#  ('\\displaystyle', 8),
#  ('múltiple', 8),
#  ('independiente', 7),
#  ('cuadrado', 7),
#  ('simple', 7),
#  ('dependiente', 6),
#  ('aleatorio', 6),
#  ('llamado', 6)]

# %% [markdown]
# ## Textacy London text
# No we want to know things about London, from our previous text

# %%
# import spacy
import textacy.extract

#### CODE ####

# The text we want to examine
text = """London is the capital and most populous city of England and the United Kingdom. Standing on the River Thames in the south east of the island of Great Britain, London has been a major settlement for two millennia. London was founded by the Romans, 
who named it Londinium. London is a huge city. London has a lot of cute restaurants. Jaimito is my best friend.
"""

doc = nlp(text)
statements = textacy.extract.semistructured_statements(doc, entity="London", cue='be')

# Print the results
print("Here are the things I know about London:")

for statement in statements:
    subject, verb, fact = statement
    print(f" - {fact}")
# Out:
# Here are the things I know about London:
#  - [the, capital, and, most, populous, city, of, England, and, the, United, Kingdom]
#  - [a, major, settlement, for, two, millennia]
#  - [a, huge, city]

# %%
# nlp_es = spacy.load('es_core_news_lg')

# doc = nlp(wiki.content)

# statements = textacy.extract.semistructured_statements(doc, entity="Benzema", cue='be')

# # Print the results
# print("Here are the things I know about Karim:")

# for statement in statements:
#     subject, verb, fact = statement
#     print(f" - {fact}")

# %% [markdown]
# ## Textacy with Wikipedia API
# We don't want the most frequent words, we want sentences about London

# %%
wikipedia.set_lang("en")
london = wikipedia.page("London")
text = london.content

# %%
doc = nlp(text)

# Extract semi-structured statements
statements = textacy.extract.semistructured_statements(doc, entity="London Underground", cue='be')

# Print the results
print("Here are the things I know about London:")

for statement in statements:
    subject, verb, fact = statement
    print(f" - {fact}")
# Out:
# Here are the things I know about London:
#  - [the, world, 's, oldest, rapid, transit, system]
