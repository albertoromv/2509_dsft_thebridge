# %%
import requests

root_path = "http://127.0.0.1:5000"

path = "/api/v2/resources/book"

content = {'id': 2}

response = requests.get(url = root_path + path, json = content)
print(response)
print(response.text)
# Out:
# <Response [200]>
# {
#   "author": "Samuel R. Delany",
#   "first_sentence": "to wound the autumnal city.",
#   "id": 2,
#   "published": "1975",
#   "title": "Dhalgren"
# }

# %%
path = '/api/v1/resources/book'

new_book = {
    "author": "Author",
    "first_sentence": "Once upon a time...",
    "id":4,
    "title": "Red Little Riding Hood",
    "year_published": "1810"
}

response = requests.post(url= root_path + path, json = new_book)
print(response)
print(response.text)
# Out:
# <Response [200]>
# {
#   "author": "Author",
#   "first_sentence": "Once upon a time...",
#   "id": 4,
#   "title": "Red Little Riding Hood",
#   "year_published": "1810"
# }

# %%
response = requests.get(url="http://localhost:5000/api/v1/resources/books/all2")
print(response.text)
# Out:
# {
#   "books": [
#     [
#       null,
#       2014,
#       "Ann Leckie ",
#       "Ancillary Justice",
#       "The body lay naked and facedown, a deathly gray, spatters of blood staining the snow around it."
#     ],
#     [
#       null,
#       2013,
#       "John Scalzi",
#       "Redshirts",
#       "From the top of the large boulder he sat on, Ensign Tom Davis looked across the expanse of the cave, toward Captain Lucius Abernathy, Science Officer Q\u2019eeng and Chief Engineer Paul West perched on a second, larger boulder, and thought, Well, this sucks."
#     ],
#     [
#       null,
#       2012,
#       "Jo Walton",
#       "Among Others",
#       "The Phurnacite factory in Abercwmboi killed all the trees for two miles around."
#     ],
#     [
#       null,
#       2011,
#       "Connie Willis",
#       "Blackout, All Clear (Vol. 2 - Blackout)",
#       "By noon Michael and Merope still hadn\u2019t returned from Stepney, and Polly was beginning to get really worried."
# ...

# %%
response = requests.get("http://localhost:5000/api/v4/resources/book/Jo%20Walton")
print(response.text)
# Out:
# {
#   "books": [
#     [
#       null,
#       2012,
#       "Jo Walton",
#       "Among Others",
#       "The Phurnacite factory in Abercwmboi killed all the trees for two miles around."
#     ]
#   ]
# }

# %%
mi_json = {
    'published' : 2012,
    'author': 'Jo Walton'
}

response = requests.get(url = "http://localhost:5000/api/v4/resources/book/filter", json = mi_json)
print(response.text)
# Out:
# {
#   "books": [
#     [
#       null,
#       2012,
#       "Jo Walton",
#       "Among Others",
#       "The Phurnacite factory in Abercwmboi killed all the trees for two miles around."
#     ]
#   ]
# }
