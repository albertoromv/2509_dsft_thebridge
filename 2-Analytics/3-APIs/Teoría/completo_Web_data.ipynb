# %% [markdown]
# # Descargas de diferentes fuentes de la web

# %%
#!python.exe -m pip install --upgrade pip
# Out:
# Requirement already satisfied: pip in c:\users\alberto romero\appdata\local\programs\python\python313\lib\site-packages (25.1.1)

# %%
#%pip install numpy
# Out:
# Requirement already satisfied: numpy in c:\users\alberto romero\appdata\local\programs\python\python313\lib\site-packages (2.3.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
#%pip install pandas
# Out:
# Requirement already satisfied: pandas in c:\users\alberto romero\appdata\local\programs\python\python313\lib\site-packages (2.2.3)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\alberto romero\appdata\local\programs\python\python313\lib\site-packages (from pandas) (2.3.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\alberto romero\appdata\roaming\python\python313\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\alberto romero\appdata\local\programs\python\python313\lib\site-packages (from pandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\alberto romero\appdata\local\programs\python\python313\lib\site-packages (from pandas) (2024.2)
# Requirement already satisfied: six>=1.5 in c:\users\alberto romero\appdata\roaming\python\python313\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
#%pip install requests
# Out:
# Requirement already satisfied: requests in c:\users\alberto romero\appdata\local\programs\python\python313\lib\site-packages (2.20.0)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\users\alberto romero\appdata\local\programs\python\python313\lib\site-packages (from requests) (3.0.4)
# Requirement already satisfied: idna<2.8,>=2.5 in c:\users\alberto romero\appdata\local\programs\python\python313\lib\site-packages (from requests) (2.7)
# Collecting urllib3<1.25,>=1.21.1 (from requests)
#   Using cached urllib3-1.24.3-py2.py3-none-any.whl.metadata (36 kB)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\alberto romero\appdata\local\programs\python\python313\lib\site-packages (from requests) (2024.12.14)
# Using cached urllib3-1.24.3-py2.py3-none-any.whl (118 kB)
# Installing collected packages: urllib3
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 2.4.0
#     Uninstalling urllib3-2.4.0:
#       Successfully uninstalled urllib3-2.4.0
# Successfully installed urllib3-1.24.3
# Note: you may need to restart the kernel to use updated packages.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# selenium 4.31.0 requires urllib3[socks]<3,>=1.26, but you have urllib3 1.24.3 which is incompatible.

# %%
# Importamos librerias
import requests
import zipfile
import pandas as pd
import numpy as np
import json

# %% [markdown]
# ## Primera petición

# %%
url = "https://m.media-amazon.com/images/M/MV5BZGUzYTI3M2EtZmM0Yy00NGUyLWI4ODEtN2Q3ZGJlYzhhZjU3XkEyXkFqcGdeQXVyNTM0OTY1OQ@@._V1_.jpg"
image = requests.get(url)

# %%
image
# Out:
# <Response [200]>

# %%
with open("./data/thelast.png", "wb") as f:
    f.write(image.content)

# %% [markdown]
# ## Bajar datos de inflación mediante url

# %%
df_inflaction = pd.read_csv("https://datahub.io/core/inflation/r/inflation-gdp.csv")
df_inflaction.head()
# Out:
#   Country Country Code  Year  Inflation
# 0   Aruba          ABW  1985   4.032258
# 1   Aruba          ABW  1986   1.073966
# 2   Aruba          ABW  1987   3.643045
# 3   Aruba          ABW  1988   3.121868
# 4   Aruba          ABW  1989   3.991628

# %%
df_inflaction["Country"] == "Spain"
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 11177    False
# 11178    False
# 11179    False
# 11180    False
# 11181    False
# Name: Country, Length: 11182, dtype: bool

# %%
df_inflaction[df_inflaction["Country"] == "Spain"]
# Out:
#      Country Country Code  Year  Inflation
# 2904   Spain          ESP  1960   1.177771
# 2905   Spain          ESP  1961   0.809253
# 2906   Spain          ESP  1962   5.706477
# 2907   Spain          ESP  1963   8.743698
# 2908   Spain          ESP  1964   6.979247
# ...      ...          ...   ...        ...
# 2964   Spain          ESP  2020  -0.322753
# 2965   Spain          ESP  2021   3.093135
# 2966   Spain          ESP  2022   8.390576
# 2967   Spain          ESP  2023   3.532361
# 2968   Spain          ESP  2024   2.774178
#
# [65 rows x 4 columns]

# %%
df_inflaction.to_csv("./data/inflaction.csv") # Crear carpeta "data" en la ubicación del notebook

# %% [markdown]
# ## Bajar datos de Bicimad

# %%
url = "https://opendata.emtmadrid.es/getattachment/c3383795-121b-4ebf-98b4-c7b05e902eaf/202106_movements.aspx"
r = requests.get(url)

# %%
r
# Out:
# <Response [200]>

# %%
# Guardamos el zip
filename = "./data/bicis.zip"
with open(filename, "wb") as f:
    f.write(r.content)

# %%
# Extraemos lo que hay dentro
with zipfile.ZipFile(filename, "r") as zip_ref:
    zip_ref.extractall("data/")

# %%
# Leemos los datos
datos_bicis = pd.read_json("data/202106_movements.json", lines=True, encoding="latin-1", nrows=10000)

# %%
# Vemos qué pinta tienen
datos_bicis.head()
# Out:
#                                     _id  \
# 0  {'$oid': '60bbf3f21b91311d90d568ad'}
# 1  {'$oid': '60bbf3f21b91311d90d568b2'}
# 2  {'$oid': '60bbf3f21b91311d90d568b3'}
# 3  {'$oid': '60bbf3f21b91311d90d568b4'}
# 4  {'$oid': '60bbf3f21b91311d90d568b5'}
#
#                                        user_day_code  idplug_base  user_type  \
# 0  b67ea824acf706087d5818ebc6f90821a5abaab17a0868...           15          1
# 1  364b1b99f1f9a1748f7abf1134c8d6a46197b583649308...            7          1
# 2  5cc17031cba02835dda4b6c153b56572beaade54d8ab91...           14          1
# 3  6e855acaaa17d6d14236598c0f1172c783e16950e39c01...            8          1
# 4  e93417502d55208995a61f4177956ab9289aba39044ce3...            1          1
#
#    idunplug_base  travel_time  idunplug_station  ageRange  idplug_station  \
# 0             13          319                38         0              54
# 1              1          386               185         0             126
# 2             10          465                15         0              91
# 3             22          613                84         0             236
# 4              4          751               131         5              94
#
#         unplug_hourTime zip_code
# 0  2021-06-01T00:00:00Z
# 1  2021-06-01T00:00:00Z
# 2  2021-06-01T00:00:00Z
# 3  2021-06-01T00:00:00Z
# 4  2021-06-01T00:00:00Z    28006

# %%
# Informacion dataframe
datos_bicis.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   _id               10000 non-null  object
#  1   user_day_code     10000 non-null  object
#  2   idplug_base       10000 non-null  int64
#  3   user_type         10000 non-null  int64
#  4   idunplug_base     10000 non-null  int64
#  5   travel_time       10000 non-null  int64
#  6   idunplug_station  10000 non-null  int64
#  7   ageRange          10000 non-null  int64
#  8   idplug_station    10000 non-null  int64
#  9   unplug_hourTime   10000 non-null  object
#  10  zip_code          10000 non-null  object
# dtypes: int64(7), object(4)
# memory usage: 859.5+ KB

# %%
# Valores unicos de la columna zip_code
datos_bicis["zip_code"].unique()
# Out:
# array(['', '28006', '28004', '28045', '28028', '28009', '28007', '28005',
#        '28010', '28034', '28012', '28001', '28008', '28015', '28002',
#        '28105', 'CODIGO_POSTAL_NOT_DEF', '28013', '39724', '28100',
#        '28800', '28027', '28020', '28011', '28014', '28850', '15002',
#        '28003', '45007', '28046', '28039', '28043', '28038', '28934',
#        '28016', '28945', '28221', '28033', '28030', '28029', '28048',
#        '28054', '28035', '35572', '28049', '28004 ', '28019', '28040',
#        '28941', '28523', '28380', '28933', '28026', '45600', '28938',
#        '28220', '28935', '28760', '28863', '28018', '28250', '28053',
#        '28017', '28024', '28823', '28021', '28922', '28210', '28022',
#        '28036', '28047', '28430', '28041', '46009', '28770', '28031',
#        '28200', '46026', '20540', '28232', '28042', '28071', '18006',
#        '28400', '62973', '2', '28521', '28822', '28411', '28229', '48520',
#        '29039', '28260', '28055', '28942', '28815', '28037', '28702',
#        '28707', '28701', '28290', '28691', '28460', '28936', '28915',
#        '28025', '28750', '28905', '28223', '75014', '28891', '28903',
#        '23009', '28023', '28660', '28006 ', '28924', '28911', '28032',
#        '28801', '10318', '28803', '29740', '28051', '28342', '28912',
#        '28064', '28299', '33206', '28791', '28028 ', '09006', '28917',
#        '19160', '28923', '28350', '29045', '23012', '28670', '28044',
#        '28909', '28450', '28906', '28231'], dtype=object)

# %% [markdown]
# # Acceso a archivos de la pagina de datos.gob.es
# Uno de los mayores catálogos de información pública descargable en España

# %% [markdown]
# <table align="left">
#  <tr><td width="80"><img src="./img/ejercicio.png" style="width:auto;height:auto"></td>
#      <td style="text-align:left">
#          <h3>Ejercicio datos.gob.es</h3>
#
# Descarga con pandas un dataset de la página https://datos.gob.es/es/catalogo acerca del empleo y guárdalo en un csv en la carpeta data.
#
#  </td></tr>
# </table>

# %%
# ubicar en la pagina web la direccion del enlace del archivo a descargar, para ello ubicarse sobre el posible enlace (boton) y dar clic derecho
url = "https://dadesobertes.gva.es/dataset/f706e6d9-fd44-4d45-988f-9b79010bc219/resource/9ae4e50e-09b0-401d-91e9-640905275749/download/datos-erte-solicitados-por-covid-19-2020-11-30.csv"
datos_empleo = pd.read_csv(url, sep=";")
datos_empleo.head()
# Out:
#   AUTORIDAD_LABORAL       SECTOR  NUM_EXPEDIENTES  NUM_TRABAJADORES_AFECTADOS  \
# 0              D.G.  AGRICULTURA                3                          64
# 1              D.G.  CONSTRUCIÓN               32                        1431
# 2              D.G.    INDUSTRIA              223                       56791
# 3              D.G.    SERVICIOS              664                       38105
# 4       DT VALENCIA  AGRICULTURA               68                         264
#
#    HOMBRES  MUJERES  PERS_GENERO_SIN_DETERMINAR
# 0       50       14                           0
# 1     1189      242                           0
# 2    42703    10146                        3942
# 3    18003    18170                        1932
# 4      200       64                           0

# %%
url = "https://datos.madrid.es/egob/catalogo/212086-0-oficinas-empleo.csv"
datos_empleo = pd.read_csv(url, sep=";", encoding='latin-1')
datos_empleo.head()
# Out:
#         PK                                NOMBRE  \
# 0  5949409   Agencia de Proximidad de Arganzuela
# 1  5666151      Agencia de Proximidad de Barajas
# 2  4514901  Agencia de Proximidad de Carabanchel
# 3  5520471       Agencia de Proximidad de Latina
# 4  5520488  Agencia de Proximidad de MercaMadrid
#
#                            DESCRIPCION-ENTIDAD  \
# 0  Agencia de Colocación Autorizada 1300000002
# 1  Agencia de Colocación Autorizada 1300000002
# 2  Agencia de Colocación Autorizada 1300000002
# 3  Agencia de Colocación Autorizada 1300000002
# 4  Agencia de Colocación Autorizada 1300000002
#
#                                              HORARIO  \
# 0             De lunes a viernes de 8:30 a 14 horas.
# 1             De lunes a viernes de 8:30 a 14 horas.
# 2             De lunes a viernes de 8:30 a 14 horas.
# 3             De lunes a viernes de 8:30 a 14 horas.
# 4  De atención a Empresas: de lunes a viernes de ...
#
#                                         EQUIPAMIENTO  \
# 0  Para las personas desempleadas:   Orientación ...
# 1  Para las personas desempleadas:   Orientación ...
# 2  Para las personas desempleadas:   Orientación ...
# 3  Para las personas desempleadas:   Orientación ...
# 4  Para las personas desempleadas:  Bolsa de Empl...
#
#                                           TRANSPORTE  DESCRIPCION  \
# 0  Metro: Puerta de Toledo  Cercanias: Pirámides ...          NaN
# 1         Metro: Alameda de Osuna Bus: 114, 115, 151          NaN
# 2       Metro: Carabanchel Alto Bus: 34, 35, 47, 139          NaN
# 3            METRO/RENFE: Laguna BUS: 25,31,55 y 119          NaN
# 4  Autobuses: T-32 desde la Paza de Legazpi (24 h...          NaN
#
#   ACCESIBILIDAD                                        CONTENT-URL  \
# 0           1,6  http://www.madrid.es/sites/v/index.jsp?vgnextc...
# 1           1,6  http://www.madrid.es/sites/v/index.jsp?vgnextc...
# 2           1,6  http://www.madrid.es/sites/v/index.jsp?vgnextc...
# 3           1,6  http://www.madrid.es/sites/v/index.jsp?vgnextc...
# 4             1  http://www.madrid.es/sites/v/index.jsp?vgnextc...
#
#                                           NOMBRE-VIA  ... COD-DISTRITO  \
# 0                                           PONTONES  ...          2.0
# 1                                          CANTABRIA  ...         21.0
# 2                                   CARABANCHEL ALTO  ...         11.0
# 3                                           ALHAMBRA  ...         10.0
# 4  Zona Comercial Local 1E/1F Mercamadrid. Salida...  ...          NaN
#
#             DISTRITO  COORDENADA-X  COORDENADA-Y    LATITUD  LONGITUD  \
# 0         ARGANZUELA        439268       4472945  40.404908 -3.715722
# 1            BARAJAS        450175       4478385  40.454636 -3.587632
# 2        CARABANCHEL        436104       4469258  40.371456 -3.752637
# 3             LATINA        436899       4472004  40.396255 -3.743547
# 4  VILLA DE VALLECAS        443827       4467859  40.359398 -3.661553
#
#       TELEFONO FAX                      EMAIL  \
# 0  913 643 460 NaN   aparganzuelaae@madrid.es
# 1  917 412 190 NaN      apbarajasae@madrid.es
# 2  915 133 085 NaN  apcarabanchelae@madrid.es
# 3  915 088 758 NaN       aplatinaae@madrid.es
# 4  915 880 332 NaN    aemercamadrid@madrid.es
#
#                                              TIPO
# 0  /contenido/entidadesYorganismos/OficinasEmpleo
# 1  /contenido/entidadesYorganismos/OficinasEmpleo
# 2  /contenido/entidadesYorganismos/OficinasEmpleo
# 3  /contenido/entidadesYorganismos/OficinasEmpleo
# 4  /contenido/entidadesYorganismos/OficinasEmpleo
#
# [5 rows x 32 columns]

# %%
url = "https://dadesobertes.gva.es/dataset/e9b02404-1755-4965-8f5b-917b43dc0368/resource/8a61dfcf-fb24-46e7-9b62-30ad193ec77c/download/contratos_por_municipio-sector-grupo_ocupacion-genero-edad-2018.csv"
datos_empleo = pd.read_csv(url, sep=";")

# %%
datos_empleo.to_csv("data/datos_empleo.csv")

# %% [markdown]
# # OpenStreetMap

# %%
# Amenities
# https://wiki.openstreetmap.org/wiki/Key:amenity
overpass_url = "http://overpass-api.de/api/interpreter"

overpass_query = """
[out:json];
node["amenity"="cafe"]
  (40.421909, -3.799060 ,40.471980, -3.595498); 
out;
"""

response = requests.get(overpass_url, 
                        params={'data': overpass_query})
print(response)
data = response.json()
# Out:
# <Response [200]>

# %%
data
# Out:
# {'version': 0.6,
#  'generator': 'Overpass API 0.7.62.8 e802775f',
#  'osm3s': {'timestamp_osm_base': '2025-10-13T14:22:30Z',
#   'copyright': 'The data included in this document is from www.openstreetmap.org. The data is made available under ODbL.'},
#  'elements': [{'type': 'node',
#    'id': 150760847,
#    'lat': 40.4463777,
#    'lon': -3.7149013,
#    'tags': {'amenity': 'cafe',
#     'created_by': 'Potlatch 0.5d',
#     'name': 'Condemar'}},
#   {'type': 'node',
#    'id': 311973234,
#    'lat': 40.442532,
#    'lon': -3.6517071,
#    'tags': {'amenity': 'cafe', 'name': 'Torres', 'name:es': 'Torres'}},
#   {'type': 'node',
#    'id': 318919783,
#    'lat': 40.4292399,
#    'lon': -3.7224188,
#    'tags': {'addr:city': 'Madrid',
#     'addr:postcode': '28008',
#     'addr:street': 'Paseo del Pintor Rosales',
#     'amenity': 'cafe',
#     'name': 'Magadán'}},
#   {'type': 'node',
#    'id': 327565888,
#    'lat': 40.4377269,
#    'lon': -3.6635351,
#    'tags': {'amenity': 'cafe', 'name': 'Cafetería Bruselas'}},
#   {'type': 'node',
#    'id': 410620052,
#    'lat': 40.4482368,
#    'lon': -3.7238292,
#    'tags': {'amenity': 'cafe',
#     'cuisine': 'yes',
#     'name': 'Facultad de Forestales'}},
#   {'type': 'node',
#    'id': 622204562,
#    'lat': 40.4244873,
#    'lon': -3.7103465,
#    'tags': {'addr:city': 'Madrid',
#     'addr:housenumber': '7',
#     'addr:street': 'Calle de los Dos Amigos',
#     'amenity': 'cafe',
#     'contact:phone': '+34 91 542 90 19',
#     'contact:website': 'http://www.cafedosamigos.com/',
#     'name': 'Los Dos Amigos',
#     'wheelchair': 'no',
#     'wheelchair:description': 'escalón y escaleras interiores'}},
#   {'type': 'node',
#    'id': 622204563,
#    'lat': 40.4231601,
#    'lon': -3.7108488,
#    'tags': {'addr:city': 'Madrid',
#     'addr:housenumber': '73',
#     'addr:postcode': '28013',
#     'addr:street': 'Gran Vía',
#     'air_conditioning': 'yes',
#     'amenity': 'cafe',
#     'brand': 'Starbucks',
#     'brand:wikidata': 'Q37158',
#     'brand:wikipedia': 'en:Starbucks',
#     'check_date': '2024-12-10',
#     'check_date:diet:vegan': '2024-12-10',
#     'check_date:diet:vegetarian': '2024-12-10',
#     'check_date:smoking': '2024-11-24',
#     'check_date:toilets:wheelchair': '2024-12-10',
#     'cuisine': 'coffee_shop',
#     'diet:vegan': 'no',
#     'diet:vegetarian': 'yes',
#     'indoor_seating': 'yes',
#     'layer': '1',
#     'name': 'Starbucks',
#     'official_name': 'Starbucks Coffee',
#     'opening_hours': 'Mo-Su 07:30-23:00',
#     'outdoor_seating': 'yes',
#     'smoking': 'outside',
#     'takeaway': 'yes',
#     'toilets': 'yes',
#     'toilets:wheelchair': 'no',
#     'website': 'https://www.starbucks.es/',
#     'wheelchair': 'limited'}},
#   {'type': 'node',
#    'id': 623071231,
#    'lat': 40.4252249,
#    'lon': -3.7153795,
#    'tags': {'addr:city': 'Madrid',
#     'addr:housenumber': '23',
#     'addr:postcode': '28008',
#     'addr:street': 'Calle Luisa Fernanda',
#     'amenity': 'cafe',
#     'contact:phone': '+34 915594645',
#     'contact:website': 'http://www.vienacapellanes.com/',
#     'name': 'Café Viena'}},
#   {'type': 'node',
#    'id': 674492241,
#    'lat': 40.4254,
#    'lon': -3.7072729,
#    'tags': {'addr:city': 'Madrid',
#     'addr:housenumber': '58',
#     'addr:postcode': '28015',
#     'addr:street': 'Calle de San Bernardo',
#     'amenity': 'cafe',
#     'brand': 'Santagloria',
#     'brand:wikidata': 'Q54606497',
#     'check_date': '2023-09-24',
#     'check_date:opening_hours': '2022-09-05',
#     'diet:vegetarian': 'yes',
#     'name': 'Santagloria',
#     'old_name_1': 'Rodilla',
#     'old_name_2': 'Bake Bar',
#     'opening_hours:signed': 'no',
#     'outdoor_seating': 'yes',
#     'shop': 'bakery',
#     'wheelchair': 'no'}},
#   {'type': 'node',
#    'id': 750504785,
#    'lat': 40.4510028,
#    'lon': -3.6773993,
#    'tags': {'addr:city': 'Madrid',
#     'addr:housenumber': '210 (posterior)',
#     'addr:postcode': '28002',
#     'addr:street': 'Calle del Príncipe de Vergara',
#     'amenity': 'cafe',
#     'name': 'Café Universal'}},
#   {'type': 'node',
#    'id': 810259248,
#    'lat': 40.4445182,
#    'lon': -3.6668344,
#    'tags': {'amenity': 'cafe', 'name': 'Entre Jamones', 'wheelchair': 'no'}},
#   {'type': 'node',
#    'id': 989278217,
#    'lat': 40.4500696,
#    'lon': -3.6880992,
#    'tags': {'amenity': 'cafe', 'name': 'La Tertulia'}},
#   {'type': 'node',
#    'id': 993468828,
#    'lat': 40.4292978,
#    'lon': -3.7149613,
#    'tags': {'air_conditioning': 'yes',
#     'amenity': 'cafe',
#     'brand': 'Starbucks',
#     'brand:wikidata': 'Q37158',
#     'brand:wikipedia': 'en:Starbucks',
#     'cuisine': 'coffee_shop',
#     'name': 'Starbucks',
#     'official_name': 'Starbucks Coffee',
#     'opening_hours': 'Mo-Fr 07:30-22:00,08:00-22:00',
#     'smoking': 'outside',
#     'takeaway': 'yes',
#     'website': 'https://www.starbucks.co.uk/store-locator/32345-115929/princesa-40',
#     'wheelchair': 'yes'}},
#   {'type': 'node',
#    'id': 1056099074,
#    'lat': 40.4530713,
#    'lon': -3.7189142,
#    'tags': {'amenity': 'cafe', 'name': 'Cafetería Universidad Nebrija'}},
#   {'type': 'node',
#    'id': 1239289876,
#    'lat': 40.4703555,
#    'lon': -3.6325084,
#    'tags': {'amenity': 'cafe', 'cuisine': 'spanish', 'name': 'Europa 2'}},
#   {'type': 'node',
#    'id': 1288311612,
#    'lat': 40.4306465,
#    'lon': -3.7236666,
#    'tags': {'amenity': 'cafe', 'name': 'La Perla', 'source': 'survey'}},
#   {'type': 'node',
#    'id': 1316492166,
#    'lat': 40.4259892,
#    'lon': -3.6937987,
#    'tags': {'amenity': 'cafe', 'smoking': 'no', 'wheelchair': 'limited'}},
#   {'type': 'node',
#    'id': 1316546637,
#    'lat': 40.4272302,
#    'lon': -3.6952847,
#    'tags': {'addr:city': 'Madrid',
#     'addr:housenumber': '4',
#     'addr:postcode': '28004',
#     'addr:street': 'Calle de Génova',
#     'amenity': 'cafe',
#     'name': 'Viena Capellanes',
#     'phone': '+34 913192792',
#     'website': 'http://www.vienacapellanes.com/stores/lookstore.php?idioma=esp&terminal=linux&store=9'}},
#   {'type': 'node',
#    'id': 1316546690,
#    'lat': 40.4260117,
#    'lon': -3.6921003,
#    'tags': {'addr:city': 'Madrid',
#     'addr:housenumber': '27',
#     'addr:postcode': '28004',
#     'addr:street': 'Calle de Génova',
#     'amenity': 'cafe',
#     'brand': 'Starbucks',
#     'brand:wikidata': 'Q37158',
#     'brand:wikipedia': 'en:Starbucks',
#     'check_date': '2025-04-29',
#     'cuisine': 'coffee_shop',
#     'internet_access': 'wlan',
#     'internet_access:fee': 'no',
#     'name': 'Starbucks',
#     'official_name': 'Starbucks Coffee',
#     'opening_hours': '08:30-21:30',
#     'operator': 'Grupo Vips',
#     'outdoor_seating': 'yes',
#     'smoking': 'no',
#     'survey:date': '2022-04-04',
#     'takeaway': 'yes',
#     'website': 'https://www.starbucks.es/',
#     'wheelchair': 'limited'}},
#   {'type': 'node',
#    'id': 1319826836,
#    'lat': 40.4261051,
#    'lon': -3.6940576,
#    'tags': {'addr:city': 'Madrid',
#     'addr:housenumber': '19',
#     'addr:postcode': '28004',
#     'addr:street': 'Calle de Orellana',
#     'amenity': 'cafe',
#     'cuisine': 'israeli;middle_eastern;healthy',
#     'internet_access': 'yes',
#     'internet_access:fee': 'no',
#     'name': 'Golda Cafe',
#     'opening_hours': 'Mo-Su 08:00-20:30',
#     'website': 'https://goldacafe.com/'}},
#   {'type': 'node',
#    'id': 1319826861,
#    'lat': 40.4239163,
#    'lon': -3.6925858,
#    'tags': {'amenity': 'cafe', 'name': 'El Supremo', 'smoking': 'no'}},
#   {'type': 'node',
#    'id': 1319826869,
#    'lat': 40.4268533,
#    'lon': -3.6960421,
#    'tags': {'amenity': 'cafe',
#     'name': 'Santa Bárbara',
#     'wheelchair': 'limited'}},
#   {'type': 'node',
#    'id': 1359795118,
#    'lat': 40.4326811,
#    'lon': -3.6832448,
#    'tags': {'amenity': 'cafe',
#     'brand': 'Starbucks',
#     'brand:wikidata': 'Q37158',
#     'brand:wikipedia': 'en:Starbucks',
#     'cuisine': 'coffee_shop',
#     'name': 'Starbucks',
#     'official_name': 'Starbucks Coffee',
#     'takeaway': 'yes'}},
#   {'type': 'node',
#    'id': 1366539657,
#    'lat': 40.437727,
#    'lon': -3.6892063,
#    'tags': {'addr:street': 'Maria de Molina',
#     'amenity': 'cafe',
#     'name': 'Café Saigón'}},
#   {'type': 'node',
#    'id': 1413315512,
#    'lat': 40.4417047,
#    'lon': -3.6378328,
#    'tags': {'amenity': 'cafe', 'name': 'Bar Antonio'}},
#   {'type': 'node',
#    'id': 1434581409,
#    'lat': 40.4296017,
#    'lon': -3.7049083,
#    'tags': {'addr:city': 'Madrid',
#     'addr:housenumber': '20',
#     'addr:postcode': '28004',
#     'addr:street': 'Calle de Carranza',
#     'amenity': 'cafe',
#     'check_date': '2024-11-26',
#     'name': 'Dolce e Salato',
#     'old_name': 'Imaginarium',
#     'old_name_1': 'Valentinas & Coffee',
#     'wheelchair': 'no'}},
#   {'type': 'node',
#    'id': 1517405720,
#    'lat': 40.4238583,
#    'lon': -3.701488,
#    'tags': {'addr:city': 'Madrid',
#     'addr:housenumber': '14',
#     'addr:postcode': '28004',
#     'addr:street': 'Calle de Colón',
#     'amenity': 'cafe',
#     'contact:facebook': 'https://www.facebook.com/pages/Cr%C3%AAperie-La-Rue/118120001543910?sk=info&tab=overview',
#     'contact:phone': '+34 911 89 70 87',
#     'cuisine': 'crepe',
#     'name': 'La Rue',
#     'old_name': 'Al Laboratorio',
#     'opening_hours': 'Su-Th 10:00-00:00; Fr-Sa 10:00-01:00; PH off',
#     'website': 'https://creperielarue.com',
#     'website:menu': 'https://creperielarue.com/carta-7/',
#     'wheelchair': 'no'}},
#   {'type': 'node',
#    'id': 1613048501,
#    'lat': 40.4427781,
#    'lon': -3.6961674,
#    'tags': {'amenity': 'cafe', 'name': 'Camelia'}},
#   {'type': 'node',
#    'id': 1621005272,
#    'lat': 40.425099,
#    'lon': -3.7124847,
#    'tags': {'addr:city': 'Madrid',
#     'addr:housenumber': '3',
#     'addr:postcode': '28008',
#     'addr:street': 'Calle de la Princesa',
#     'amenity': 'cafe',
#     'diet:vegetarian': 'yes',
#     'indoor_seating': 'yes',
#     'name': 'Café & Té',
#     'outdoor_seating': 'yes',
#     'smoking': 'no',
#     'wheelchair': 'yes'}},
#   {'type': 'node',
#    'id': 1642177961,
#    'lat': 40.4246631,
#    'lon': -3.709637,
#    'tags': {'addr:city': 'Madrid',
#     'addr:housenumber': '2',
#     'addr:postcode': '28015',
#     'addr:street': 'Plaza del Conde de Toreno',
#     'amenity': 'cafe',
#     'name': 'db',
#     'old_name': 'Habibi',
#     'wheelchair': 'no'}},
#   {'type': 'node',
#    'id': 1642178045,
#    'lat': 40.4238691,
#    'lon': -3.7089925,
#    'tags': {'addr:city': 'Madrid',
#     'addr:housenumber': '8',
#     'addr:postcode': '28015',
#     'addr:street': 'Calle del Álamo',
#     'amenity': 'cafe',
#     'indoor_seating': 'no',
#     'name': 'Sieté Seven Tea',
#     'outdoor_seating': 'no',
#     'phone': '+34 657 917 362',
#     'takeaway': 'only'}},
#   {'type': 'node',
#    'id': 1686702375,
#    'lat': 40.4487805,
#    'lon': -3.7254083,
#    'tags': {'air_conditioning': 'yes',
#     'amenity': 'cafe',
#     'indoor_seating': 'yes',
#     'name': 'Cafetería Facultad de Ciencias Geológicas',
#     'outdoor_seating': 'yes',
#     'smoking': 'no'}},
#   {'type': 'node',
#    'id': 1739898679,
#    'lat': 40.4395371,
#    'lon': -3.6196894,
#    'tags': {'amenity': 'cafe'}},
#   {'type': 'node',
#    'id': 1740058741,
#    'lat': 40.4223451,
#    'lon': -3.6816075,
#    'tags': {'amenity': 'cafe', 'name': 'Café & Té', 'wheelchair': 'no'}},
#   {'type': 'node',
#    'id': 1927659397,
#    'lat': 40.4682877,
#    'lon': -3.7224352,
#    'tags': {'alt_name': 'Cervecería La Orensana',
#     'amenity': 'cafe',
#     'name': 'La Orensana'}},
#   {'type': 'node',
#    'id': 1944473872,
#    'lat': 40.4463066,
#    'lon': -3.7135061,
#    'tags': {'amenity': 'cafe', 'name': 'La Vuelta'}},
#   {'type': 'node',
#    'id': 1988186838,
#    'lat': 40.4340803,
#    'lon': -3.6328064,
#    'tags': {'amenity': 'cafe', 'name': 'Juka'}},
#   {'type': 'node',
#    'id': 2056509590,
#    'lat': 40.4261644,
#    'lon': -3.7147519,
#    'tags': {'alt_name': '3"', 'amenity': 'cafe', 'name': 'Café 3 segundos'}},
#   {'type': 'node',
#    'id': 2057557358,
#    'lat': 40.4566516,
#    'lon': -3.7051554,
#    'tags': {'amenity': 'cafe',
#     'check_date': '2023-10-31',
#     'name': 'La Pampa',
#     'wheelchair': 'limited'}},
#   {'type': 'node',
#    'id': 2057557418,
#    'lat': 40.4569966,
#    'lon': -3.7055108,
#    'tags': {'amenity': 'cafe',
#     'check_date': '2023-10-31',
#     'name': 'La Unión',
#     'toilets:wheelchair': 'no',
#     'wheelchair': 'limited'}},
#   {'type': 'node',
#    'id': 2057557445,
#    'lat': 40.4567065,
#    'lon': -3.7039235,
#    'tags': {'addr:city': 'Madrid',
#     'addr:postcode': '28039',
#     'addr:street': 'Calle de Berruguete',
#     'alt_name': 'Las delicias de Judith',
#     'amenity': 'cafe',
#     'diet:halal': 'no',
#     'name': 'Las Delicias de Judy',
#     'old_name': 'Bar Torre',
#     'old_name1': 'La Castiza',
#     'old_name2': 'Bulevar',
#     'opening_hours': 'PH,Tu-Su 09:00-24:00',
#     'operator': 'Magizan Bulevar, SL',
#     'payment:credit_cards': 'yes',
#     'payment:debit_cards': 'yes',
#     'wheelchair': 'limited'}},
#   {'type': 'node',
#    'id': 2135526338,
#    'lat': 40.4291823,
#    'lon': -3.7216853,
#    'tags': {'addr:city': 'Madrid',
#     'addr:housenumber': '48',
#     'addr:postcode': '28008',
#     'addr:street': 'Paseo del Pintor Rosales',
#     'amenity': 'cafe',
#     'name': 'La Habana Vieja',
#     'phone': '+34 915 59 81 04'}},
#   {'type': 'node',
#    'id': 2270766143,
#    'lat': 40.4443345,
#    'lon': -3.6749375,
#    'tags': {'amenity': 'cafe',
#     'name': 'Cafetería Prospe',
#     'wheelchair': 'limited'}},
#   {'type': 'node',
#    'id': 2298820823,
#    'lat': 40.4452235,
#    'lon': -3.6764378,
#    'tags': {'amenity': 'cafe',
#     'name': 'La tabernita azul',
#     'name:en': 'The Blue Little Tavern',
#     'name:fr': 'La petite taverne bleu',
#     'smoking': 'no'}},
#   {'type': 'node',
#    'id': 2302262357,
#    'lat': 40.4427506,
#    'lon': -3.6690847,
#    'tags': {'amenity': 'cafe',
#     'cuisine': 'spanish',
#     'name': 'La Taberna del Cardenal',
#     'wifi': 'no'}},
#   {'type': 'node',
#    'id': 2477700587,
#    'lat': 40.4225774,
#    'lon': -3.7063743,
#    'tags': {'addr:city': 'Madrid',
#     'addr:housenumber': '24',
#     'addr:postcode': '28015',
#     'addr:street': 'Calle de la Luna',
#     'amenity': 'cafe',
#     'check_date': '2023-09-26',
#     'name': 'Day Madrid',
#     'old_name': 'De Calle',
#     'old_name_1': 'Amor de calle',
#     'old_name_2': 'Crack',
#     'old_name_3': 'Maraca',
#     'wheelchair': 'no'}},
#   {'type': 'node',
#    'id': 2495089202,
#    'lat': 40.4569021,
#    'lon': -3.703247,
#    'tags': {'amenity': 'cafe',
#     'name': 'Brasiliana',
#     'opening_hours': 'PH,Mo-Su 07:30-13:30',
#     'wheelchair': 'no'}},
#   {'type': 'node',
#    'id': 2510220975,
#    'lat': 40.4348709,
#    'lon': -3.6306805,
#    'tags': {'amenity': 'cafe'}},
#   {'type': 'node',
#    'id': 2585165172,
#    'lat': 40.4256513,
#    'lon': -3.7067242,
#    'tags': {'addr:city': 'Madrid',
#     'addr:housenumber': '47',
#     'addr:postcode': '28004',
#     'addr:street': 'Calle del Espíritu Santo',
#     'amenity': 'cafe',
#     'contact:phone': '+34 91 521 85 76.',
#     'contact:website': 'http://www.jandjbooksandcoffee.com/index.php',
#     'description': 'Bar y café y tienda de libros de segunda mano en inglés.',
#     'name': 'J & J Books and Coffee',
#     'shop': 'books',
#     'wheelchair': 'no'}},
#   {'type': 'node',
#    'id': 2623305612,
#    'lat': 40.4365104,
#    'lon': -3.6106963,
#    'tags': {'addr:city': 'Madrid',
#     'addr:housename': 'Café Pub Dribling',
#     'addr:housenumber': '93',
#     'addr:postcode': '28022',
#     'addr:street': 'Calle de Nicolasa Gómez',
#     'amenity': 'cafe',
#     'cuisine': 'coffee_shop',
#     'internet_access': 'yes',
#     'name': 'Café Pub Dribling',
#     'opening_hours': '11:00-02:00',
#     'phone': '+34 91 320 49 16'}},
#   {'type': 'node',
#    'id': 2626943556,
#    'lat': 40.4237468,
#    'lon': -3.7022593,
#    'tags': {'addr:city': 'Madrid',
#     'addr:housenumber': '9',
#     'addr:postcode': '28004',
#     'addr:street': 'Plaza de San Ildefonso',
#     'amenity': 'cafe',
#     'diet:vegetarian': 'yes',
#     'email': 'labicicletacafe@gmail.com',
#     'internet_access': 'wlan',
#     'name': 'La Bicicleta',
#     'opening_hours': 'Su-Th 00:00-02:00,10:00-24:00; Fr-Sa 00:00-02:00, 10:00-24:00',
#     'payment:cash': 'yes',
#     'payment:mastercard': 'yes',
#     'payment:visa': 'yes',
#     'phone': '+34 915 32 97 42',
#     'website': 'https://www.labicicletacafe.com/',
#     'wheelchair': 'yes'}},
#   {'type': 'node',
#    'id': 2632228956,
#    'lat': 40.4242479,
#    'lon': -3.7072805,
#    'tags': {'addr:city': 'Madrid',
#     'addr:housenumber': '42',
#     'addr:postcode': '28015',
#     'addr:street': 'Calle de San Bernardo',
#     'amenity': 'cafe',
#     'diet:halal': 'no',
#     'diet:kosher': 'no',
#     'name': 'Dos Passos',
#     'opening_hours': 'Mo-Su 07:30-01:30',
#     'wheelchair': 'no',
#     'wheelchair:description': 'Escalón de acceso aprox. 5 cm'}},
#   {'type': 'node',
#    'id': 2636531053,
#    'lat': 40.4546924,
#    'lon': -3.7025906,
#    'tags': {'amenity': 'cafe', 'name': 'La Antigua de Estrecho'}},
#   {'type': 'node',
#    'id': 2639635434,
#    'lat': 40.425725,
#    'lon': -3.7088156,
#    'tags': {'addr:city': 'Madrid',
#     'addr:housenumber': '16',
#     'addr:postcode': '28015',
#     'addr:street': 'Calle de Noviciado',
#     'amenity': 'cafe',
#     'name': 'Sweet Studio',
#     'old_name': 'The Place'}},
#   {'type': 'node',
#    'id': 2640019766,
#    'lat': 40.426991,
#    'lon': -3.6165839,
#    'tags': {'amenity': 'cafe', 'name': 'Los Niños de la Victoria'}},
#   {'type': 'node',
#    'id': 2640019767,
#    'lat': 40.4271711,
#    'lon': -3.6167821,
#    'tags': {'amenity': 'cafe', 'name': 'Sila'}},
#   {'type': 'node',
#    'id': 2640019773,
#    'lat': 40.4269262,
#    'lon': -3.6173124,
#    'tags': {'amenity': 'cafe', 'name': "Julio's"}},
#   {'type': 'node',
#    'id': 2640019775,
#    'lat': 40.4269436,
#    'lon': -3.6168766,
#    'tags': {'amenity': 'cafe', 'old_name': 'Bar San Blas'}},
#   {'type': 'node',
#    'id': 2642274454,
#    'lat': 40.4261072,
#    'lon': -3.6815626,
#    'tags': {'addr:city': 'Madrid',
#     'addr:housenumber': '39',
#     'addr:postcode': '28001',
#     'addr:street': 'Calle de Castelló',
#     'amenity': 'cafe',
#     'brand': 'Granier',
#     'brand:wikidata': 'Q102311169',
#     'contact:facebook': 'https://es-es.facebook.com/Granierhermosilla/info',
#     'email': 'granierhermosilla@gmail.com',
#     'name': 'Granier',
#     'opening_hours': 'Mo-Su 07:00-21:30',
#     'phone': '+34 914 35 24 76',
#     'shop': 'bakery',
#     'wheelchair': 'yes'}},
#   {'type': 'node',
#    'id': 2642274457,
#    'lat': 40.4260456,
#    'lon': -3.6807566,
#    'tags': {'addr:city': 'Madrid',
#     'addr:housenumber': '58',
#     'addr:postcode': '28001',
#     'addr:street': 'Calle de Hermosilla',
#     'amenity': 'cafe',
#     'contact:facebook': 'https://es-es.facebook.com/juliettascaffe/',
#     'contact:phone': '+34 910530297',
#     'old_name': 'Nata Lovers',
#     'wheelchair': 'limited'}},
#   {'type': 'node',
#    'id': 2642274458,
#    'lat': 40.4261465,
#    'lon': -3.682848,
#    'tags': {'addr:city': 'Madrid',
#     'addr:housenumber': '40',
#     'addr:postcode': '28001',
#     'addr:street': 'Calle de Hermosilla',
#     'amenity': 'cafe',
#     'name': 'El Café de Hermosilla',
#     'wheelchair': 'yes'}},
#   {'type': 'node',
#    'id': 2646161158,
#    'lat': 40.4384818,
#    'lon': -3.651788,
#    'tags': {'amenity': 'cafe'}},
#   {'type': 'node',
#    'id': 2646161161,
#    'lat': 40.4385758,
#    'lon': -3.6518471,
#    'tags': {'amenity': 'cafe', 'name': 'Román'}},
#   {'type': 'node',
#    'id': 2646161163,
#    'lat': 40.4387166,
#    'lon': -3.6519678,
#    'tags': {'amenity': 'cafe', 'name': 'Laso', 'name:es': 'Laso'}},
#   {'type': 'node',
#    'id': 2646180931,
#    'lat': 40.4348551,
#    'lon': -3.6563344,
#    'tags': {'amenity': 'cafe', 'name': 'Río', 'name:es': 'Río'}},
#   {'type': 'node',
#    'id': 2652999510,
#    'lat': 40.4234287,
#    'lon': -3.6148448,
#    'tags': {'amenity': 'cafe'}},
#   {'type': 'node',
#    'id': 2653822213,
#    'lat': 40.4260105,
#    'lon': -3.7071668,
#    'tags': {'addr:city': 'Madrid',
#     'addr:housenumber': '57',
#     'addr:postcode': '28015',
#     'addr:street': 'Calle de San Bernardo',
#     'amenity': 'cafe',
#     'name': 'La Doña',
#     'old_name': 'Movistar',
#     'opening_hours': '24/7',
#     'toilets:wheelchair': 'yes',
#     'wheelchair': 'yes'}},
#   {'type': 'node',
#    'id': 2664897893,
#    'lat': 40.4379771,
#    'lon': -3.6773101,
#    'tags': {'addr:city': 'Madrid',
#     'addr:housenumber': '1',
#     'addr:postcode': '28002',
#     'addr:street': 'Avenida de América',
#     'amenity': 'cafe',
#     'contact:facebook': 'https://es-es.facebook.com/pages/Cafeteria-Honey-Madrid/214076878627039',
#     'email': 'cafeteriahoney@ono.com',
#     'name': 'Honey',
#     'phone': '+34 915 63 58 18'}},
#   {'type': 'node',
#    'id': 2668366790,
#    'lat': 40.4299435,
#    'lon': -3.7077873,
#    'tags': {'addr:city': 'Madrid',
#     'addr:housenumber': '12',
#     'addr:postcode': '28015',
#     'addr:street': 'Calle de Alberto Aguilera',
#     'amenity': 'cafe',
#     'name': 'Cauca'}},
#   {'type': 'node',
#    'id': 2668366797,
#    'lat': 40.4298654,
#    'lon': -3.7069624,
#    'tags': {'addr:city': 'Madrid',
#     'addr:housenumber': '8',
#     'addr:postcode': '28015',
#     'addr:street': 'Calle de Alberto Aguilera',
#     'amenity': 'cafe',
#     'check_date': '2023-09-28',
#     'name': 'Panaria',
#     'opening_hours': 'Mo-Sa 08:00-20:30; PH,Su 09:00-14:30',
#     'outdoor_seating': 'yes',
#     'shop': 'bakery',
#     'website': 'https://www.panariapanaderias.es/',
#     'wheelchair': 'no'}},
#   {'type': 'node',
#    'id': 2668463117,
#    'lat': 40.4241701,
#    'lon': -3.7063175,
#    'tags': {'addr:city': 'Madrid',
#     'addr:housenumber': '36',
#     'addr:postcode': '28004',
#     'addr:street': 'Calle del Pez',
#     'amenity': 'cafe',
#     'check_date': '2023-09-24',
#     'name': 'Ambu Coffee',
#     'old_name': 'Trakabarraka',
#     'old_name_1': 'Popota',
#     'website': 'https://ambu.coffee/',
#     'wheelchair': 'limited'}},
#   {'type': 'node',
#    'id': 2669198762,
#    'lat': 40.428062,
#    'lon': -3.7094676,
#    'tags': {'addr:city': 'Madrid',
#     'addr:housenumber': '36',
#     'addr:postcode': '28015',
#     'addr:street': 'Calle de Amaniel',
#     'amenity': 'cafe',
#     'contact:website': 'https://www.unfltrdcoffee.com/',
#     'name': 'Unfiltrd',
#     'old_name': 'Rías Baixas'}},
#   {'type': 'node',
#    'id': 2669198767,
#    'lat': 40.4270528,
#    'lon': -3.7092373,
#    'tags': {'addr:city': 'Madrid',
#     'addr:housenumber': '9',
#     'addr:postcode': '28015',
#     'addr:street': 'Plaza de las Comendadoras',
#     'amenity': 'cafe',
#     'check_date': '2023-09-30',
#     'diet:vegan': 'yes',
#     'diet:vegetarian': 'yes',
#     'email': 'madrid@federalcafe.es',
#     'internet_access': 'wlan',
#     'internet_access:password': 'cafeconleche',
#     'name': 'Federal Café',
#     'opening_hours': 'Mo-Sa 09:00-24:00; Sa,Su 00:00-01:00; Su 09:00-17:00',
#     'outdoor_seating': 'yes',
#     'phone': '+34 915 328 424',
#     'toilets:wheelchair': 'yes',
#     'website': 'https://federalcafe.es/madrid/',
#     'wheelchair': 'yes'}},
#   {'type': 'node',
#    'id': 2669909215,
#    'lat': 40.4296557,
#    'lon': -3.7051951,
#    'tags': {'addr:city': 'Madrid',
#     'addr:housenumber': '5',
#     'addr:postcode': '28015',
#     'addr:street': 'Glorieta de Ruiz Jiménez',
#     'amenity': 'cafe',
#     'check_date': '2024-05-20',
#     'name': 'Café Minber'}},
#   {'type': 'node',
#    'id': 2669909220,
#    'lat': 40.4314648,
#    'lon': -3.708136,
#    'tags': {'addr:city': 'Madrid',
#     'addr:housenumber': '7',
#     'addr:postcode': '28015',
#     'addr:street': 'Calle de Rodríguez San Pedro',
#     'amenity': 'cafe',
#     'name': "Friend's Coffee"}},
#   {'type': 'node',
#    'id': 2669997847,
#    'lat': 40.4352928,
#    'lon': -3.7141753,
#    'tags': {'addr:city': 'Madrid',
#     'addr:housenumber': '71',
#     'addr:postcode': '28015',
#     'addr:street': 'Calle de Fernández de los Ríos',
#     'amenity': 'cafe',
#     'name': 'C@ffe.it'}},
#   {'type': 'node',
#    'id': 2671175816,
#    'lat': 40.4332265,
#    'lon': -3.7088754,
#    'tags': {'addr:city': 'Madrid',
#     'addr:housenumber': '37',
#     'addr:postcode': '28015',
#     'addr:street': 'Calle de Vallehermoso',
#     'amenity': 'cafe',
#     'name': 'Tormes'}},
#   {'type': 'node',
#    'id': 2671207707,
#    'lat': 40.4351872,
#    'lon': -3.7118607,
#    'tags': {'addr:city': 'Madrid',
#     'addr:housenumber': '55',
#     'addr:postcode': '28015',
#     'addr:street': 'Calle de Fernández de los Ríos',
#     'amenity': 'cafe',
#     'name': 'Rotterdam'}},
#   {'type': 'node',
#    'id': 2671241942,
#    'lat': 40.4261035,
#    'lon': -3.7075585,
#    'tags': {'addr:city': 'Madrid',
#     'addr:housenumber': '53',
#     'addr:postcode': '28015',
#     'addr:street': 'Calle de San Vicente Ferrer',
#     'amenity': 'cafe',
#     'name': 'El Naranja',
#     'website': 'http://www.elnaranja.info/1.html'}},
#   {'type': 'node',
#    'id': 2672814926,
#    'lat': 40.4227936,
#    'lon': -3.7039429,
#    'tags': {'addr:city': 'Madrid',
#     'addr:housenumber': '4',
#     'addr:postcode': '28004',
#     'addr:street': 'Calle del Pez',
#     'amenity': 'cafe',
#     'check_date': '2023-10-04',
#     'name': 'Constanza Cafe',
#     'old_name': 'Antorcha Café',
#     'wheelchair': 'no'}},
#   {'type': 'node',
#    'id': 2672817741,
#    'lat': 40.4224594,
#    'lon': -3.7039475,
#    'tags': {'addr:city': 'Madrid',
#     'addr:housenumber': '25',
#     'addr:postcode': '28004',
#     'addr:street': 'Corredera Baja de San Pablo',
#     'amenity': 'cafe',
#     'name': 'SWT Gallery'}},
#   {'type': 'node',
#    'id': 2672831651,
#    'lat': 40.4221388,
#    'lon': -3.7025164,
#    'tags': {'addr:city': 'Madrid',
#     'addr:housenumber': '8',
#     'addr:postcode': '28004',
#     'addr:street': 'Calle de la Puebla',
#     'amenity': 'cafe',
#     'contact:facebook': 'pages/Caf%C3%A9-de-la-Luz/168195233378',
#     'name': 'Café de la Luz',
#     'opening_hours': 'Mo-Su 10:00-02:00',
#     'phone': '+34 915 23 11 99'}},
#   {'type': 'node',
#    'id': 2676854997,
#    'lat': 40.4219393,
#    'lon': -3.7045881,
#    'tags': {'addr:city': 'Madrid',
#     'addr:housenumber': '11',
#     'addr:postcode': '28004',
#     'addr:street': 'Corredera Baja de San Pablo',
#     'amenity': 'cafe',
#     'contact:facebook': 'https://es-es.facebook.com/BarCafeLara',
#     'name': 'Cafetería Lara',
#     'phone': '+34 609 90 68 12',
#     'wheelchair': 'no'}},
#   {'type': 'node',
#    'id': 2681923270,
#    'lat': 40.423242,
#    'lon': -3.7073722,
#    'tags': {'addr:city': 'Madrid',
#     'addr:housenumber': '24',
#     'addr:postcode': '28015',
#     'addr:street': 'Calle de San Bernardo',
#     'amenity': 'cafe',
#     'contact:phone': '+34 910 55 86',
#     'contact:website': 'https://cafeangelica.es/',
#     'name': 'Café Angélica',
#     'old_name': 'Angélica',
#     'shop': 'coffee',
#     'wheelchair': 'no',
#     'wheelchair:description': 'Escalón de acceso mayor de 7 cm y puerta de 80 cm'}},
#   {'type': 'node',
#    'id': 2692606027,
#    'lat': 40.422785,
#    'lon': -3.6993686,
#    'tags': {'addr:city': 'Madrid',
#     'addr:housenumber': '17',
#     'addr:postcode': '28004',
#     'addr:street': 'Calle de Augusto Figueroa',
#     'amenity': 'cafe',
#     'contact:website': 'https://www.lakamabaranoa.com/inicio',
#     'name': 'LaKama Café',
#     'old_name': 'Café Figueroa',
#     'wheelchair': 'no'}},
#   {'type': 'node',
#    'id': 2704017903,
#    'lat': 40.4257155,
#    'lon': -3.7038206,
#    'tags': {'addr:city': 'Madrid',
#     'addr:housenumber': '4',
#     'addr:postcode': '28004',
#     'addr:street': 'Calle de San Andrés',
#     'amenity': 'cafe',
#     'check_date': '2023-09-24',
#     'contact:facebook': 'https://www.facebook.com/people/El-Colmao-Ecol%C3%B3gico/100077502827742/',
#     'contact:phone': '+34 914 96 07 56',
#     'name': 'El Colmao Ecológico',
#     'old_name': 'Doña Francisquita',
#     'wheelchair': 'no'}},
#   {'type': 'node',
#    'id': 2704017922,
#    'lat': 40.4281338,
#    'lon': -3.7039279,
#    'tags': {'addr:city': 'Madrid',
#     'addr:housenumber': '11',
#     'addr:postcode': '28004',
#     'addr:street': 'Calle de Ruiz',
#     'amenity': 'cafe',
#     'name': 'Café de Ruiz',
#     'survey:date': '2024-01-04',
#     'website': 'http://cafederuiz.com/'}},
#   {'type': 'node',
#    'id': 2739850840,
#    'lat': 40.4378104,
#    'lon': -3.6505224,
#    'tags': {'amenity': 'cafe',
#     'check_date': '2023-06-13',
#     'internet_access': 'no',
#     'name': 'Cafetería Luzón'}},
#   {'type': 'node',
#    'id': 2764318350,
#    'lat': 40.4265999,
#    'lon': -3.6783933,
#    'tags': {'addr:city': 'Madrid',
#     'addr:housenumber': '32',
#     'addr:street': 'Calle del General Pardiñas',
#     'amenity': 'cafe',
#     'cuisine': 'drinks;tapas',
#     'name': 'Café de Zine',
#     'note': 'Se sirven copas (bar) y hay tapas (¿restaurante?), pero ellos mismos lo clasifican como "Café".'}},
#   {'type': 'node',
#    'id': 2769265438,
#    'lat': 40.4224814,
#    'lon': -3.7005843,
#    'tags': {'addr:city': 'Madrid',
#     'addr:housenumber': '2',
#     'addr:postcode': '28004',
#     'addr:street': 'Calle de Pérez Galdós',
#     'amenity': 'cafe',
#     'contact:instagram': 'https://www.instagram.com/wolfoxmadrid',
#     'name': 'Wolføx Coffee Madrid',
#     'old_name': 'IT Dogs',
#     'opening_hours': 'Mo-Su 10:00-19:00',
#     'outdoor_seating': 'yes',
#     'website': 'https://www.wolfox.coffee/'}},
#   {'type': 'node',
#    'id': 2777281762,
#    'lat': 40.4247401,
#    'lon': -3.7010888,
#    'tags': {'addr:city': 'Madrid',
#     'addr:housenumber': '3',
#     'addr:postcode': '28004',
#     'addr:street': 'Calle de San Joaquín',
#     'amenity': 'cafe',
#     'email': 'librosyvinos@tiposinfames.com',
#     'name': 'Tipos Infames',
#     'phone': '+34 915 228 939',
#     'shop': 'books',
#     'website': 'https://www.tiposinfames.com/',
#     'wheelchair': 'no'}},
#   {'type': 'node',
#    'id': 2777306948,
#    'lat': 40.4243517,
#    'lon': -3.7018731,
#    'tags': {'addr:city': 'Madrid',
#     'addr:housenumber': '16',
#     'addr:postcode': '28004',
#     'addr:street': 'Calle de San Joaquín',
#     'amenity': 'cafe',
#     'cuisine': 'sandwich',
#     'name': 'Naif',
#     'outdoor_seating': 'yes',
#     'toilets': 'customers',
#     'toilets:wheelchair': 'yes'}},
#   {'type': 'node',
#    'id': 2779332355,
#    'lat': 40.42732,
#    'lon': -3.6737652,
#    'tags': {'addr:city': 'Madrid',
#     'addr:housenumber': '87A',
#     'addr:postcode': '28006',
#     'addr:street': 'Calle de Ayala',
#     'amenity': 'cafe',
#     'name': 'Urban Coffee',
#     'website': 'http://loungecoffee.com/urban/ubicacion.html'}},
#   {'type': 'node',
#    'id': 2802274511,
#    'lat': 40.4389491,
#    'lon': -3.654095,
#    'tags': {'amenity': 'cafe', 'name': "Pimar's"}},
#   {'type': 'node',
#    'id': 2836112493,
#    'lat': 40.4352121,
#    'lon': -3.7126864,
#    'tags': {'addr:city': 'Madrid',
#     'addr:housenumber': '61',
#     'addr:postcode': '28015',
#     'addr:street': 'Calle de Fernández de los Ríos',
#     'amenity': 'cafe',
#     'cuisine': 'coffee_shop',
#     'internet_access': 'wlan',
#     'name': 'The Little Big cafe',
#     'opening_hours': 'Mo-Fr 09:00-20:00; Sa-Su 10:00-19:00',
#     'smoking': 'no',
#     'website': 'https://www.thelittlebigcafe.com/',
#     'wheelchair': 'yes'}},
#   {'type': 'node',
#    'id': 2864197143,
#    'lat': 40.4570634,
#    'lon': -3.6991202,
#    'tags': {'amenity': 'cafe', 'name': 'Bar La Carreta'}},
#   {'type': 'node',
#    'id': 2867491074,
#    'lat': 40.4470286,
#    'lon': -3.7033332,
#    'tags': {'amenity': 'cafe', 'name': 'Nu Rielle', 'wheelchair': 'no'}},
#   {'type': 'node',
#    'id': 2867491099,
#    'lat': 40.4494622,
#    'lon': -3.7033876,
#    'tags': {'amenity': 'cafe', 'name': 'Museo del Jamón 2'}},
#   {'type': 'node',
#    'id': 2868679684,
#    'lat': 40.4505421,
#    'lon': -3.7032293,
#    'tags': {'amenity': 'cafe', 'name': 'Chloe Lan', 'wheelchair': 'yes'}},
#   {'type': 'node',
#    'id': 2868679693,
#    'lat': 40.4522589,
#    'lon': -3.7033798,
#    'tags': {'amenity': 'cafe',
#     'cuisine': 'coffee_shop',
#     'name': 'La Castiza'}},
#   {'type': 'node',
#    'id': 2868776230,
#    'lat': 40.4577985,
#    'lon': -3.7116749,
#    'tags': {'amenity': 'cafe',
#     'diet:halal': 'no',
#     'name': 'La Mina',
#     'opening_hours': 'Su-Th 06:00-02:00; Fr,Sa 06:00-02:30',
#     'payment:credit_cards': 'yes',
#     'payment:debit_cards': 'yes',
#     'wheelchair': 'limited'}},
#   {'type': 'node',
#    'id': 2868794479,
#    'lat': 40.456955,
#    'lon': -3.7086386,
#    'tags': {'amenity': 'cafe',
#     'check_date:opening_hours': '2022-11-27',
#     'diet:halal': 'no',
#     'name': 'Cafetería La Villa',
#     'opening_hours': 'Mo-Su 08:00-24:00; Fr,Sa 08:00-00:30',
#     'payment:credit_cards': 'yes',
#     'payment:debit_cards': 'yes',
#     'wheelchair': 'yes'}},
#   {'type': 'node',
#    'id': 2868810917,
#    'lat': 40.4567878,
#    'lon': -3.7079526,
#    'tags': {'amenity': 'cafe',
#     'name': 'La Muralla de Ávila',
#     'phone': '+34914591036'}},
#   {'type': 'node',
#    'id': 2870489592,
#    'lat': 40.4568773,
#    'lon': -3.7064436,
#    'tags': {'amenity': 'cafe', 'name': 'Cafetería Fuente Verde'}},
#   {'type': 'node',
#    'id': 2870522339,
#    'lat': 40.4595013,
#    'lon': -3.7074201,
#    'tags': {'amenity': 'cafe',
#     'check_date': '2025-07-04',
#     'name': 'Cafetería De Película',
#     'old_name': 'Bodegas Ergueta'}},
#   {'type': 'node',
#    'id': 2870522340,
#    'lat': 40.4588861,
#    'lon': -3.7047898,
#    'tags': {'amenity': 'cafe', 'name': 'Bar La Torre'}},
#   {'type': 'node',
#    'id': 2870522363,
#    'lat': 40.4585305,
#    'lon': -3.7066507,
#    'tags': {'amenity': 'cafe',
#     'check_date': '2025-07-04',
#     'name': 'Cervecería Bar Viña Lidia'}},
#   {'type': 'node',
#    'id': 2880462327,
#    'lat': 40.4436716,
#    'lon': -3.702682,
#    'tags': {'amenity': 'cafe', 'name': 'Vanille'}},
#   {'type': 'node',
#    'id': 2883836605,
#    'lat': 40.4367282,
#    'lon': -3.7164243,
#    'tags': {'amenity': 'cafe',
#     'check_date': '2024-09-23',
#     'name': 'Mora Café',
#     'old_name': 'Don Hilarión',
#     'wheelchair': 'limited'}},
#   {'type': 'node',
#    'id': 2887253634,
#    'lat': 40.4483907,
#    'lon': -3.7039531,
#    'tags': {'amenity': 'cafe', 'name': 'Rubí'}},
#   {'type': 'node',
#    'id': 2891477464,
#    'lat': 40.4533629,
#    'lon': -3.7032217,
#    'tags': {'amenity': 'cafe', 'name': 'Cafetería Estrecho'}},
#   {'type': 'node',
#    'id': 2891559892,
#    'lat': 40.4565532,
#    'lon': -3.7072258,
#    'tags': {'amenity': 'cafe',
#     'name': 'Ganeza coffee-bread',
#     'old_name': 'El señor de la birra'}},
#   {'type': 'node',
#    'id': 2891563635,
#    'lat': 40.4574931,
#    'lon': -3.7060531,
#    'tags': {'amenity': 'cafe', 'name': 'Bar Arco Iris JJ'}},
#   {'type': 'node',
#    'id': 2912429033,
#    'lat': 40.4257339,
#    'lon': -3.7030666,
#    'tags': {'addr:city': 'Madrid',
#     'addr:housenumber': '20',
#     'addr:postcode': '28004',
#     'addr:street': 'Calle de San Vicente Ferrer',
#     'amenity': 'cafe',
#     'name': 'Estar Café',
#     'phone': '+34 914 48 60 87'}},
#   {'type': 'node',
#    'id': 2916188358,
#    'lat': 40.4467011,
#    'lon': -3.7046455,
#    'tags': {'amenity': 'cafe', 'name': 'Audrey'}},
#   {'type': 'node',
#    'id': 2916188360,
#    'lat': 40.4471284,
#    'lon': -3.705399,
#    'tags': {'amenity': 'cafe', 'name': 'Café y Té'}},
#   {'type': 'node',
#    'id': 2929357293,
#    'lat': 40.4595133,
#    'lon': -3.7002391,
#    'tags': {'addr:city': 'Madrid',
#     'addr:housenumber': '6',
#     'addr:postcode': '28039',
#     'addr:street': 'Calle de Tablada',
#     'amenity': 'cafe',
#     'name': 'Cytrus'}},
#   {'type': 'node',
#    'id': 2929890142,
#    'lat': 40.4597099,
#    'lon': -3.7005637,
#    'tags': {'addr:city': 'Madrid',
#     'addr:housenumber': '12',
#     'addr:postcode': '28039',
#     'addr:street': 'Calle de Tablada',
#     'amenity': 'cafe',
#     'name': 'Pinoy Spanish Bar'}},
#   {'type': 'node',
#    'id': 2942276116,
#    'lat': 40.4376633,
#    'lon': -3.6868614,
#    'tags': {'addr:city': 'Madrid',
#     'addr:housenumber': '18',
#     'addr:postcode': '28006',
#     'addr:street': 'Calle de María de Molina',
#     'amenity': 'cafe',
#     'check_date:currency:XBT': '2024-09-10',
#     'currency:XBT': 'yes',
#     'name': 'Do Eat!',
#     'payment:lightning': 'yes',
#     'phone': '+34 911 866 600',
#     'website': 'https://doeat.es/',
#     'yelp': 'http://www.yelp.com/biz/do-eat-madrid-2'}},
#   {'type': 'node',
#    'id': 2947786417,
#    'lat': 40.4572389,
#    'lon': -3.7096674,
#    'tags': {'addr:city': 'Madrid',
#     'addr:housenumber': '76',
#     'addr:postcode': '28039',
#     'addr:street': 'Calle de Francos Rodríguez',
#     'amenity': 'cafe',
#     'name': 'Bar Gema',
#     'opening_hours': 'Mo-Su 07:00-24:00'}},
#   {'type': 'node',
#    'id': 2955163356,
#    'lat': 40.4650433,
#    'lon': -3.7102021,
#    'tags': {'amenity': 'cafe', 'name': 'Bar El Paso'}},
#   {'type': 'node',
#    'id': 2972891894,
#    'lat': 40.443185,
#    'lon': -3.7042681,
#    'tags': {'amenity': 'cafe', 'name': 'Sirius Café'}},
#   {'type': 'node',
#    'id': 2972891925,
#    'lat': 40.4446265,
#    'lon': -3.7038288,
#    'tags': {'amenity': 'cafe', 'name': 'Café Racer'}},
#   {'type': 'node',
#    'id': 2972941198,
#    'lat': 40.4351737,
#    'lon': -3.7045359,
#    'tags': {'amenity': 'cafe', 'name': 'Cafetería Isabel'}},
#   {'type': 'node',
#    'id': 2973043610,
#    'lat': 40.4229435,
#    'lon': -3.7112768,
#    'tags': {'air_conditioning': 'yes',
#     'amenity': 'cafe',
#     'atm': 'yes',
#     'check_date': '2025-01-08',
#     'check_date:opening_hours': '2024-04-06',
#     'check_date:smoking': '2025-01-08',
#     'indoor_seating': 'yes',
#     'name': 'faborit',
#     'old_name': 'Banco Sabadell',
#     'opening_hours:signed': 'no',
#     'outdoor_seating': 'no',
#     'smoking': 'no',
#     'wheelchair': 'limited'}},
#   {'type': 'node',
#    'id': 3007302445,
#    'lat': 40.4226307,
#    'lon': -3.7093098,
#    'tags': {'addr:city': 'Madrid',
#     'addr:housenumber': '70',
#     'addr:postcode': '28013',
#     'addr:street': 'Gran Vía',
#     'amenity': 'cafe',
#     'name': 'Pause',
#     'old_name': 'Café & Té',
#     'wheelchair': 'no'}},
#   {'type': 'node',
#    'id': 3050347080,
#    'lat': 40.4279425,
#    'lon': -3.7020701,
#    'tags': {'addr:city': 'Madrid',
#     'addr:housenumber': '101',
#     'addr:street': 'Calle de Fuencarral',
#     'amenity': 'cafe',
#     'brand': 'Starbucks',
#     'brand:wikidata': 'Q37158',
#     'brand:wikipedia': 'en:Starbucks',
#     'cuisine': 'coffee_shop',
#     'name': 'Starbucks',
#     'official_name': 'Starbucks Coffee',
#     'operator': 'Starbucks',
#     'takeaway': 'yes',
#     'wheelchair': 'limited',
#     'wheelchair:description': 'Aseo adaptado, pasillos estrechos.'}},
#   {'type': 'node',
#    'id': 3128165594,
#    'lat': 40.4551863,
#    'lon': -3.7028679,
#    'tags': {'addr:housenumber': '203',
#     'addr:street': 'Calle de Bravo Murillo',
#     'amenity': 'cafe',
#     'name': 'Audrey Brunch&Coffee'}},
#   {'type': 'node',
#    'id': 3136812042,
#    'lat': 40.441285,
#    'lon': -3.7149836,
#    'tags': {'amenity': 'cafe', 'name': 'Chocolatería Cafetería'}},
#   {'type': 'node',
#    'id': 3136816581,
#    'lat': 40.4330328,
#    'lon': -3.7169568,
#    'tags': {'amenity': 'cafe', 'name': 'Bar Rosado'}},
#   {'type': 'node',
#    'id': 3137147955,
#    'lat': 40.4264572,
#    'lon': -3.7056172,
#    'tags': {'addr:housenumber': '47',
#     'addr:street': 'Calle de la Palma',
#     'amenity': 'cafe',
#     'check_date': '2023-10-03',
#     'name': 'Gosto',
#     'old_name': 'Más Mastropiero',
#     'wheelchair': 'no'}},
#   {'type': 'node',
#    'id': 3161160129,
#    'lat': 40.460905,
#    'lon': -3.6964197,
#    'tags': {'amenity': 'cafe', 'name': 'Mediterráneo'}},
#   {'type': 'node',
#    'id': 3170766310,
#    'lat': 40.4382443,
#    'lon': -3.6924977,
#    'tags': {'addr:housenumber': '59',
#     'addr:postcode': '28003',
#     'addr:street': 'Calle José Abascal',
#     'amenity': 'cafe',
#     'brand': 'Santagloria',
#     'brand:wikidata': 'Q54606497',
#     'name': 'Santagloria',
#     'outdoor_seating': 'no',
#     'shop': 'bakery',
#     'source': 'local knowledge',
#     'website': 'https://www.santagloria.com/'}},
#   {'type': 'node',
#    'id': 3181391412,
#    'lat': 40.433945,
#    'lon': -3.7046638,
#    'tags': {'addr:city': 'Madrid',
#     'addr:housenumber': '6',
#     'addr:postcode': '28015',
#     'addr:street': 'Glorieta de Quevedo',
#     'amenity': 'cafe',
#     'name': 'La Francerie',
#     'old_name': 'Farmacia - Glorieta Quevedo 6',
#     'website': 'https://lafrancerie.es/'}},
#   {'type': 'node',
#    'id': 3196261068,
#    'lat': 40.446846,
#    'lon': -3.7125713,
#    'tags': {'amenity': 'cafe', 'name': 'Cafetería'}},
#   {'type': 'node',
#    'id': 3202125015,
#    'lat': 40.431653,
#    'lon': -3.6505532,
#    'tags': {'amenity': 'cafe',
#     'name': 'Cervecería A´Conchiña',
#     'phone': '+34 913262619',
#     'website': 'https://www.cerveceriaconchiña.es/',
#     'wheelchair': 'no'}},
#   {'type': 'node',
#    'id': 3206699865,
#    'lat': 40.4351679,
#    'lon': -3.6643766,
#    'tags': {'addr:city': 'Madrid',
#     'addr:housenumber': '68',
#     'addr:postcode': '28028',
#     'addr:street': 'Calle de Martínez Izquierdo',
#     'amenity': 'cafe',
#     'name': 'Cafetería La Plancha'}},
#   {'type': 'node',
#    'id': 3208755399,
#    'lat': 40.4646193,
#    'lon': -3.6951606,
#    'tags': {'amenity': 'cafe', 'name': 'Bar Pascual'}},
#   {'type': 'node',
#    'id': 3208755402,
#    'lat': 40.4664316,
#    'lon': -3.6962734,
#    'tags': {'amenity': 'cafe', 'name': 'Café Punto y Coma'}},
#   {'type': 'node',
#    'id': 3208755427,
#    'lat': 40.4670665,
#    'lon': -3.6957053,
#    'tags': {'amenity': 'cafe'}},
#   {'type': 'node',
#    'id': 3212683931,
#    'lat': 40.4304201,
#    'lon': -3.6824967,
#    'tags': {'addr:city': 'Madrid',
#     'addr:housenumber': '29',
#     'addr:postcode': '28006',
#     'addr:street': 'Calle de José Ortega y Gasset',
#     'amenity': 'cafe',
#     'brand': 'Starbucks',
#     'brand:wikidata': 'Q37158',
#     'brand:wikipedia': 'en:Starbucks',
#     'contact:website': 'http://www.starbucks.es',
#     'cuisine': 'coffee_shop',
#     'name': 'Starbucks',
#     'official_name': 'Starbucks Coffee',
#     'takeaway': 'yes'}},
#   {'type': 'node',
#    'id': 3234734470,
#    'lat': 40.4444862,
#    'lon': -3.6974065,
#    'tags': {'addr:housenumber': '93',
#     'addr:postcode': '28003',
#     'addr:street': 'Calle de Alonso Cano',
#     'amenity': 'cafe',
#     'name': 'La Posada de Alonso Cano',
#     'phone': '+34 91 447 1586'}},
#   {'type': 'node',
#    'id': 3242331191,
#    'lat': 40.4264913,
#    'lon': -3.7059638,
#    'tags': {'addr:city': 'Madrid',
#     'addr:housenumber': '49',
#     'addr:postcode': '28004',
#     'addr:street': 'Calle de la Palma',
#     'amenity': 'cafe',
#     'check_date': '2023-10-03',
#     'cost:coffee': '$1.80',
#     'cuisine': 'coffee_shop',
#     'email': 'info@tomacafe.es',
#     'name': 'Toma Café',
#     'opening_hours': 'Mo-Fr 08:00-20:00; Sa,Su 10:00-20:00',
#     'phone': '+34 917 049 344',
#     'website': 'http://www.tomacafe.es/',
#     'wheelchair': 'no'}},
#   {'type': 'node',
#    'id': 3265599908,
#    'lat': 40.4382907,
#    'lon': -3.6729734,
#    'tags': {'amenity': 'cafe', 'name': 'El Panecillo', 'shop': 'bakery'}},
#   {'type': 'node',
#    'id': 3269546367,
#    'lat': 40.4369321,
#    'lon': -3.6871822,
#    'tags': {'addr:housenumber': '10',
#     'addr:postcode': '28006',
#     'addr:street': 'Calle de López de Hoyos',
#     'amenity': 'cafe',
#     'name': 'Panela&Co',
#     'phone': '+34 915636069'}},
#   {'type': 'node',
#    'id': 3269780307,
#    'lat': 40.4260347,
#    'lon': -3.6707123,
#    'tags': {'amenity': 'cafe', 'name': 'El Albero'}},
#   {'type': 'node',
#    'id': 3294436873,
#    'lat': 40.4345404,
#    'lon': -3.6456674,
#    'tags': {'amenity': 'cafe',
#     'cuisine': 'churro;chocolate',
#     'name': 'Las Farolas'}},
#   {'type': 'node',
#    'id': 3359367683,
#    'lat': 40.42937,
#    'lon': -3.7078904,
#    'tags': {'addr:city': 'Madrid',
#     'addr:housenumber': '39',
#     'addr:postcode': '28015',
#     'addr:street': 'Calle del Acuerdo',
#     'amenity': 'cafe',
#     'disused:amenity': 'bar',
#     'name': 'Miau',
#     'old_name': "D'Alma;Belu"}},
#   {'type': 'node',
#    'id': 3371729069,
#    'lat': 40.4263982,
#    'lon': -3.7050202,
#    'tags': {'addr:city': 'Madrid',
#     'addr:housenumber': '41',
#     'addr:postcode': '28004',
#     'addr:street': 'Calle de la Palma',
#     'amenity': 'cafe',
#     'contact:instagram': 'elgorditocantina',
#     'name': 'El Gordito'}},
#   {'type': 'node',
#    'id': 3389555454,
#    'lat': 40.4244011,
#    'lon': -3.7120394,
#    'tags': {'air_conditioning': 'yes',
#     'amenity': 'cafe',
#     'cuisine': 'bubble_tea',
#     'diet:vegan': 'yes',
#     'diet:vegetarian': 'yes',
#     'indoor_seating': 'yes',
#     'name': 'T8',
#     'outdoor_seating': 'no',
#     'payment:credit_cards': 'yes',
#     'payment:debit_cards': 'yes',
#     'smoking': 'no',
#     'wheelchair': 'yes'}},
#   {'type': 'node',
#    'id': 3426617375,
#    'lat': 40.4221948,
#    'lon': -3.6923421,
#    'tags': {'addr:housenumber': '21',
#     'addr:street': 'Paseo de Recoletos',
#     'amenity': 'cafe',
#     'check_date': '2024-09-04',
#     'name': 'Gran Café Gijón',
#     'outdoor_seating': 'yes',
#     'phone': '+34 915 215 425',
#     'website': 'https://cafegijon.com/',
#     'wheelchair': 'no',
#     'wikidata': 'Q1025608',
#     'wikipedia': 'es:Café Gijón'}},
#   {'type': 'node',
#    'id': 3426732122,
#    'lat': 40.4351477,
#    'lon': -3.6983923,
#    'tags': {'amenity': 'cafe', 'name': 'Jamaica'}},
#   {'type': 'node',
#    'id': 3426800312,
#    'lat': 40.4232935,
#    'lon': -3.6940419,
#    'tags': {'addr:city': 'Madrid',
#     'addr:housenumber': '12',
#     'addr:postcode': '28004',
#     'addr:street': 'Calle del Conde de Xiquena',
#     'amenity': 'cafe',
#     'cuisine': 'coffee_shop',
#     'name': 'Altered'}},
#   {'type': 'node',
#    'id': 3426834939,
#    'lat': 40.439386,
#    'lon': -3.7004446,
#    'tags': {'amenity': 'cafe', 'name': 'Classic Café Bar'}},
#   {'type': 'node',
#    'id': 3426834966,
#    'lat': 40.4553536,
#    'lon': -3.7033222,
#    'tags': {'amenity': 'cafe', 'name': 'La parrilla Igorota'}},
#   {'type': 'node',
#    'id': 3428475667,
#    'lat': 40.4311209,
#    'lon': -3.6972714,
#    'tags': {'addr:city': 'Madrid',
#     'addr:housenumber': '29',
#     'addr:postcode': '28010',
#     'addr:street': 'Calle de Santa Engracia',
#     'amenity': 'cafe',
#     'name': 'Café Bar Rocamar'}},
#   {'type': 'node',
#    'id': 3428475683,
#    'lat': 40.4370871,
#    'lon': -3.6998872,
#    'tags': {'addr:city': 'Madrid',
#     'addr:housenumber': '103',
#     'addr:postcode': '28010',
#     'addr:street': 'Calle de Santa Engracia',
#     'amenity': 'cafe',
#     'check_date': '2025-03-27',
#     'cuisine': 'portuguese;seafood;spanish;regional',
#     'diet:vegetarian': 'no',
#     'email': 'taberna@almacheli.com',
#     'internet_access': 'wlan',
#     'name': 'AlmaCheli Hecho A Mano',
#     'opening_hours': 'Mo-Su 18:00-02:00',
#     'phone': '+34915913630',
#     'wheelchair': 'limited'}},
#   {'type': 'node',
#    'id': 3428476975,
#    'lat': 40.4336757,
#    'lon': -3.6983908,
#    'tags': {'amenity': 'cafe', 'name': 'Pain Bistro', 'wheelchair': 'yes'}},
#   {'type': 'node',
#    'id': 3459875697,
#    'lat': 40.4581157,
#    'lon': -3.696974,
#    'tags': {'amenity': 'cafe', 'name': 'Bar Minuto'}},
#   {'type': 'node',
#    'id': 3459875698,
#    'lat': 40.4591513,
#    'lon': -3.696054,
#    'tags': {'amenity': 'cafe', 'name': 'Cafetería Medranda'}},
#   {'type': 'node',
#    'id': 3461921708,
#    'lat': 40.4247482,
#    'lon': -3.7008221,
#    'tags': {'addr:city': 'Madrid',
#     'addr:housenumber': '71',
#     'addr:postcode': '28004',
#     'addr:street': 'Calle de Fuencarral',
#     'amenity': 'cafe',
#     'name': 'Rocablanca',
#     'outdoor_seating': 'no',
#     'wheelchair': 'no'}},
#   {'type': 'node',
#    'id': 3461932854,
#    'lat': 40.4261719,
#    'lon': -3.7113935,
#    'tags': {'addr:city': 'Madrid',
#     'addr:housenumber': '5',
#     'addr:postcode': '28015',
#     'addr:street': 'Calle del Conde Duque',
#     'amenity': 'cafe',
#     'check_date': '2023-09-26',
#     'indoor_seating': 'yes',
#     'name': 'Siniestro',
#     'old_name': 'Don Diego',
#     'old_name_1': 'Condominium',
#     'outdoor_seating': 'no',
#     'wheelchair': 'no'}},
#   {'type': 'node',
#    'id': 3467969369,
#    'lat': 40.450462,
#    'lon': -3.7177781,
#    'tags': {'amenity': 'cafe', 'name': 'Facultad de Educación'}},
#   {'type': 'node',
#    'id': 3469038580,
#    'lat': 40.4476232,
#    'lon': -3.7170921,
#    'tags': {'amenity': 'cafe', 'name': 'Glacé'}},
#   {'type': 'node',
#    'id': 3471761960,
#    'lat': 40.4269219,
#    'lon': -3.7017004,
#    'tags': {'addr:city': 'Madrid',
#     'addr:housenumber': '93',
#     'addr:postcode': '28004',
#     'addr:street': 'Calle de Fuencarral',
#     'amenity': 'cafe',
#     'bar': 'yes',
#     'name': 'Caffé del Arte',
#     'opening_hours': 'Mo-Su,PH 08:00-02:00',
#     'operator': 'Ambarlis S.L.',
#     'ref:vatin': 'ESB81673725',
#     'toilets': 'yes',
#     'toilets:wheelchair': 'no',
#     'website:menu': 'https://smartmenu.agorapos.com/?id=ct6viosq#/',
#     'wheelchair': 'limited',
#     'wheelchair:description': 'Acceso bueno, no tiene aseo adaptado.'}},
#   {'type': 'node',
#    'id': 3472054306,
#    'lat': 40.4301567,
#    'lon': -3.7002708,
#    'tags': {'amenity': 'cafe',
#     'check_date': '2023-04-02',
#     'name': 'La Bohemia'}},
#   {'type': 'node',
#    'id': 3472111966,
#    'lat': 40.4364209,
#    'lon': -3.7155435,
#    'tags': {'amenity': 'cafe'}},
# ...
#     'outdoor_seating': 'no'}},
#   {'type': 'node',
#    'id': 12128565720,
#    'lat': 40.4287721,
#    'lon': -3.6751845,
#    'tags': {'addr:city': 'Madrid',
#     'addr:housenumber': '36',
#     'addr:postcode': '28006',
#     'addr:street': 'Calle del Conde de Peñalver',
#     'amenity': 'cafe',
#     'internet_access': 'wlan',
#     'internet_access:fee': 'no',
#     'name': 'Nata Artesanos',
#     'smoking': 'no'}},
#   {'type': 'node',
#    'id': 12147737601,
#    'lat': 40.4248823,
#    'lon': -3.6853284,
#    'tags': {'addr:housenumber': '42',
#     'addr:street': 'Calle de Lagasca',
#     'amenity': 'cafe',
#     'name': 'Hola Coffee',
#     'opening_hours': 'Mo-Fr 08:00-20:00; Sa-Su 09:00-20:00'}},
#   {'type': 'node',
#    'id': 12150041004,
#    'lat': 40.4631738,
#    'lon': -3.6914604,
#    'tags': {'amenity': 'cafe', 'name': 'Espresso Americano'}},
#   {'type': 'node',
#    'id': 12150047340,
#    'lat': 40.4622071,
#    'lon': -3.6915316,
#    'tags': {'amenity': 'cafe', 'name': 'Emka'}},
#   {'type': 'node',
#    'id': 12151268313,
#    'lat': 40.4364248,
#    'lon': -3.6907879,
#    'tags': {'addr:housenumber': '94',
#     'addr:street': 'Calle de García de Paredes',
#     'amenity': 'cafe',
#     'check_date': '2024-09-02',
#     'name': 'Donde Michel',
#     'wheelchair': 'limited'}},
#   {'type': 'node',
#    'id': 12153404469,
#    'lat': 40.4373766,
#    'lon': -3.7145528,
#    'tags': {'addr:housenumber': '41',
#     'addr:street': 'Calle de Joaquín María López',
#     'amenity': 'cafe',
#     'check_date': '2024-09-03',
#     'name': 'Chiripa',
#     'outdoor_seating': 'yes',
#     'wheelchair': 'no'}},
#   {'type': 'node',
#    'id': 12192547416,
#    'lat': 40.4287621,
#    'lon': -3.6750046,
#    'tags': {'amenity': 'cafe', 'name': 'Luspar'}},
#   {'type': 'node',
#    'id': 12197348001,
#    'lat': 40.4557835,
#    'lon': -3.6768661,
#    'tags': {'amenity': 'cafe',
#     'name': 'east crema coffee',
#     'opening_hours': 'Mo-Fr 08:00-20:00; Sa-Su 09:00-20:00',
#     'website': 'https://eastcrema.com/'}},
#   {'type': 'node',
#    'id': 12204136137,
#    'lat': 40.454907,
#    'lon': -3.6470256,
#    'tags': {'amenity': 'cafe',
#     'indoor_seating': 'yes',
#     'name': 'DeTaZa',
#     'outdoor_seating': 'yes'}},
#   {'type': 'node',
#    'id': 12204667764,
#    'lat': 40.4378061,
#    'lon': -3.7101494,
#    'tags': {'addr:housenumber': '75',
#     'addr:street': 'Calle de Galileo',
#     'amenity': 'cafe',
#     'check_date': '2024-09-27',
#     'name': 'Tosty',
#     'outdoor_seating': 'yes',
#     'wheelchair': 'limited'}},
#   {'type': 'node',
#    'id': 12204678874,
#    'lat': 40.4583398,
#    'lon': -3.6449659,
#    'tags': {'amenity': 'cafe', 'name': 'Cafetería Orgaz'}},
#   {'type': 'node',
#    'id': 12218205071,
#    'lat': 40.4366661,
#    'lon': -3.6922563,
#    'tags': {'addr:housenumber': '63',
#     'addr:street': 'Calle de García de Paredes',
#     'amenity': 'cafe',
#     'check_date': '2024-10-03',
#     'name': 'Quero',
#     'wheelchair': 'no'}},
#   {'type': 'node',
#    'id': 12231518334,
#    'lat': 40.4383345,
#    'lon': -3.7084485,
#    'tags': {'addr:housenumber': '77',
#     'addr:street': 'Calle de Vallehermoso',
#     'amenity': 'cafe',
#     'check_date': '2024-10-07',
#     'name': 'Los Gallego',
#     'outdoor_seating': 'yes',
#     'wheelchair': 'limited'}},
#   {'type': 'node',
#    'id': 12260741873,
#    'lat': 40.4366689,
#    'lon': -3.6435252,
#    'tags': {'amenity': 'cafe', 'name': 'Lexana'}},
#   {'type': 'node',
#    'id': 12270765326,
#    'lat': 40.4375899,
#    'lon': -3.6850623,
#    'tags': {'addr:housenumber': '24',
#     'addr:postcode': '28006',
#     'addr:street': 'Calle de María de Molina',
#     'amenity': 'cafe',
#     'contact:facebook': 'religioncoffee',
#     'contact:instagram': 'religioncoffee_',
#     'cuisine': 'breakfast;coffee_shop;mediterranean',
#     'email': 'info@religioncoffee.es',
#     'name': 'Religion - Specialty coffee',
#     'opening_hours': 'Mo-Fr 08:30-19:00; Sa-Su 09:00-18:00',
#     'phone': '910698221',
#     'website': 'http://www.religioncoffee.es/',
#     'website:menu': 'https://goo.su/vjwC'}},
#   {'type': 'node',
#    'id': 12282407976,
#    'lat': 40.4552286,
#    'lon': -3.6939508,
#    'tags': {'amenity': 'cafe',
#     'brand': 'Santagloria',
#     'brand:wikidata': 'Q54606497',
#     'name': 'Santagloria',
#     'shop': 'bakery'}},
#   {'type': 'node',
#    'id': 12337611000,
#    'lat': 40.4719695,
#    'lon': -3.6810751,
#    'tags': {'addr:floor': '0',
#     'amenity': 'cafe',
#     'check_date': '2024-12-05',
#     'internet_access': 'no',
#     'level': '1',
#     'name': 'Coffee Bakery',
#     'payment:cash': 'yes',
#     'payment:credit_cards': 'yes',
#     'payment:debit_cards': 'yes',
#     'source': 'survey',
#     'wheelchair': 'yes'}},
#   {'type': 'node',
#    'id': 12358856174,
#    'lat': 40.4719148,
#    'lon': -3.6821001,
#    'tags': {'addr:floor': '0',
#     'amenity': 'cafe',
#     'check_date': '2024-11-20',
#     'level': '1',
#     'name': 'Navelgas',
#     'outdoor_seating': 'no',
#     'source': 'survey',
#     'wheelchair': 'yes'}},
#   {'type': 'node',
#    'id': 12373777400,
#    'lat': 40.4501243,
#    'lon': -3.6505064,
#    'tags': {'amenity': 'cafe',
#     'level': '1',
#     'name': 'Taruffi',
#     'opening_hours': 'Mo-Su 09:00-22:00',
#     'website': 'https://www.taruffi.com/'}},
#   {'type': 'node',
#    'id': 12401772628,
#    'lat': 40.4423316,
#    'lon': -3.6408916,
#    'tags': {'amenity': 'cafe',
#     'cuisine': 'coffee_shop',
#     'indoor_seating': 'yes',
#     'name': "Junior's",
#     'outdoor_seating': 'yes'}},
#   {'type': 'node',
#    'id': 12433834360,
#    'lat': 40.4523274,
#    'lon': -3.6985211,
#    'tags': {'amenity': 'cafe'}},
#   {'type': 'node',
#    'id': 12462989865,
#    'lat': 40.4691085,
#    'lon': -3.6431502,
#    'tags': {'amenity': 'cafe', 'name': 'La Ruta del Café'}},
#   {'type': 'node',
#    'id': 12462993522,
#    'lat': 40.4689999,
#    'lon': -3.6435998,
#    'tags': {'amenity': 'cafe', 'name': "Miranda's"}},
#   {'type': 'node',
#    'id': 12463013424,
#    'lat': 40.4230155,
#    'lon': -3.7229213,
#    'tags': {'amenity': 'cafe', 'name': 'Kausa Madrid'}},
#   {'type': 'node',
#    'id': 12480940607,
#    'lat': 40.4374972,
#    'lon': -3.6381161,
#    'tags': {'amenity': 'cafe',
#     'cuisine': 'coffee_shop',
#     'name': 'Chocolate con Churros'}},
#   {'type': 'node',
#    'id': 12480941328,
#    'lat': 40.4276463,
#    'lon': -3.6689504,
#    'tags': {'amenity': 'cafe',
#     'cuisine': 'coffee_shop',
#     'name': 'Chocolate con Churros',
#     'wheelchair': 'limited'}},
#   {'type': 'node',
#    'id': 12480941329,
#    'lat': 40.4489409,
#    'lon': -3.6094696,
#    'tags': {'amenity': 'cafe',
#     'cuisine': 'coffee_shop',
#     'name': 'Chocolate con Churros'}},
#   {'type': 'node',
#    'id': 12627911757,
#    'lat': 40.423818,
#    'lon': -3.6769351,
#    'tags': {'addr:housenumber': '4',
#     'addr:street': 'Avenida Felipe II',
#     'amenity': 'cafe',
#     'check_date': '2025-02-26',
#     'cuisine': 'bubble_tea',
#     'level': '0',
#     'name': 'T8 tea bar',
#     'payment:cash': 'yes',
#     'payment:credit_cards': 'yes',
#     'payment:debit_cards': 'yes'}},
#   {'type': 'node',
#    'id': 12627911762,
#    'lat': 40.425434,
#    'lon': -3.713198,
#    'tags': {'addr:housenumber': '4',
#     'addr:street': 'Calle de Santa María Micaela',
#     'amenity': 'cafe',
#     'check_date': '2025-02-25',
#     'cuisine': 'coffee_shop;sandwich;korean',
#     'internet_access': 'wlan',
#     'internet_access:fee': 'customers',
#     'level': '0',
#     'name': 'Doku Toku',
#     'outdoor_seating': 'yes',
#     'payment:cash': 'yes',
#     'payment:credit_cards': 'yes',
#     'payment:debit_cards': 'yes',
#     'wheelchair': 'yes'}},
#   {'type': 'node',
#    'id': 12629140147,
#    'lat': 40.4246153,
#    'lon': -3.6689597,
#    'tags': {'addr:housenumber': '143',
#     'addr:street': 'Calle de Goya',
#     'amenity': 'cafe',
#     'name': 'Panaria',
#     'phone': '644634898',
#     'takeaway': 'yes',
#     'website': 'https://panariapanaderias.es'}},
#   {'type': 'node',
#    'id': 12668675124,
#    'lat': 40.4281668,
#    'lon': -3.7041952,
#    'tags': {'amenity': 'cafe', 'name': 'Ajenjo Cafe'}},
#   {'type': 'node',
#    'id': 12681286403,
#    'lat': 40.4294675,
#    'lon': -3.6738323,
#    'tags': {'addr:city': 'Madrid',
#     'addr:postcode': '28006',
#     'addr:street': 'Calle Alcántara',
#     'amenity': 'cafe',
#     'cuisine': 'coffee_shop',
#     'name': 'Sinfonía'}},
#   {'type': 'node',
#    'id': 12681286407,
#    'lat': 40.4293822,
#    'lon': -3.6751441,
#    'tags': {'addr:city': 'Madrid',
#     'addr:housenumber': '44',
#     'addr:street': 'Calle del Conde de Peñalver',
#     'amenity': 'cafe',
#     'name': 'Taiga'}},
#   {'type': 'node',
#    'id': 12687210821,
#    'lat': 40.4360628,
#    'lon': -3.6984488,
#    'tags': {'addr:city': 'Madrid',
#     'addr:housenumber': '6',
#     'addr:postcode': '28010',
#     'addr:street': 'Calle Ponce de León',
#     'amenity': 'cafe',
#     'contact:instagram': 'https://www.instagram.com/beikbeik.mad',
#     'cuisine': 'breakfast',
#     'email': 'beikbeikmad@gmail.com',
#     'fast_food': 'cafeteria',
#     'name': 'Beik Beik',
#     'opening_hours': 'Tu-Th 09:00-19:00; Fr 09:00-15:00; Sa-Su 09:30-15:00; Mo off; PH off',
#     'outdoor_seating': 'no',
#     'phone': '+34 639 914 387'}},
#   {'type': 'node',
#    'id': 12688373845,
#    'lat': 40.4261779,
#    'lon': -3.6792458,
#    'tags': {'addr:housenumber': '67',
#     'addr:street': 'Calle de Hermosilla',
#     'amenity': 'cafe',
#     'diet:gluten_free': 'yes',
#     'name': 'Le Sweet',
#     'opening_hours': 'Mo-Sa 12:00-19:30',
#     'phone': '664312750',
#     'takeaway': 'yes',
#     'website': 'https://lesweet.es/'}},
#   {'type': 'node',
#    'id': 12691393341,
#    'lat': 40.4390271,
#    'lon': -3.6291333,
#    'tags': {'amenity': 'cafe', 'name': 'Fanático'}},
#   {'type': 'node',
#    'id': 12692718401,
#    'lat': 40.4322883,
#    'lon': -3.7032303,
#    'tags': {'addr:housenumber': '3',
#     'addr:postcode': '28010',
#     'addr:street': 'Calle de Gonzalo de Córdoba',
#     'amenity': 'cafe',
#     'contact:instagram': 'dosiscafe',
#     'cuisine': 'breakfast;coffee_shop',
#     'internet_access': 'wlan',
#     'name': 'Dosis Cafe',
#     'website': 'https://dosiscafe.es/'}},
#   {'type': 'node',
#    'id': 12778278009,
#    'lat': 40.4392562,
#    'lon': -3.7066155,
#    'tags': {'amenity': 'cafe',
#     'check_date': '2025-04-23',
#     'name': 'Roan',
#     'outdoor_seating': 'yes',
#     'wheelchair': 'no'}},
#   {'type': 'node',
#    'id': 12809158536,
#    'lat': 40.4333349,
#    'lon': -3.7007443,
#    'tags': {'amenity': 'cafe',
#     'cuisine': 'coffee_shop',
#     'name': 'La casa Amande',
#     'survey:date': '2025-05-04'}},
#   {'type': 'node',
#    'id': 12809645117,
#    'lat': 40.4231582,
#    'lon': -3.707614,
#    'tags': {'amenity': 'cafe', 'name': 'Vivari', 'survey:date': '2025-05-04'}},
#   {'type': 'node',
#    'id': 12825294142,
#    'lat': 40.4323666,
#    'lon': -3.7172989,
#    'tags': {'amenity': 'cafe',
#     'brand': 'Santagloria',
#     'brand:wikidata': 'Q54606497',
#     'name': 'Santagloria',
#     'shop': 'bakery',
#     'survey:date': '2025-05-10'}},
#   {'type': 'node',
#    'id': 12844750069,
#    'lat': 40.4376458,
#    'lon': -3.6508643,
#    'tags': {'amenity': 'cafe', 'name': 'La Panera Rosa'}},
#   {'type': 'node',
#    'id': 12880638608,
#    'lat': 40.4361303,
#    'lon': -3.7049327,
#    'tags': {'addr:housenumber': '4',
#     'addr:street': 'Calle de Donoso Cortés',
#     'amenity': 'cafe',
#     'check_date': '2025-06-02',
#     'cuisine': 'coffee_shop',
#     'name': '29|30',
#     'wheelchair': 'no'}},
#   {'type': 'node',
#    'id': 12880638615,
#    'lat': 40.4361527,
#    'lon': -3.7052455,
#    'tags': {'addr:housenumber': '8',
#     'addr:street': 'Calle de Donoso Cortés',
#     'amenity': 'cafe',
#     'check_date': '2025-06-02',
#     'cuisine': 'coffee_shop',
#     'name': 'Vanille',
#     'wheelchair': 'limited'}},
#   {'type': 'node',
#    'id': 12888834201,
#    'lat': 40.4361344,
#    'lon': -3.6931833,
#    'tags': {'amenity': 'cafe', 'name': 'Libis'}},
#   {'type': 'node',
#    'id': 12902402678,
#    'lat': 40.4235878,
#    'lon': -3.7025829,
#    'tags': {'air_conditioning': 'yes',
#     'amenity': 'cafe',
#     'check_date': '2025-06',
#     'indoor_seating': 'yes',
#     'internet_access': 'wlan',
#     'name': 'HanSo Café',
#     'outdoor_seating': 'no',
#     'toilets': 'yes'}},
#   {'type': 'node',
#    'id': 12957360578,
#    'lat': 40.4271056,
#    'lon': -3.6581608,
#    'tags': {'amenity': 'cafe', 'name': 'Cafetería Nico', 'wheelchair': 'no'}},
#   {'type': 'node',
#    'id': 12958941701,
#    'lat': 40.4395092,
#    'lon': -3.6791859,
#    'tags': {'addr:housenumber': '109',
#     'addr:street': 'Calle del Príncipe de Vergara',
#     'amenity': 'cafe',
#     'cuisine': 'coffee_shop',
#     'name': 'Mina Specialty Coffee'}},
#   {'type': 'node',
#    'id': 13007334813,
#    'lat': 40.4321445,
#    'lon': -3.7005547,
#    'tags': {'addr:city': 'Madrid',
#     'addr:housenumber': '20',
#     'addr:postcode': '28010',
#     'addr:street': 'Calle Trafalgar',
#     'amenity': 'cafe',
#     'cuisine': 'coffee_shop',
#     'name': 'Catedral Cafe Madrid',
#     'takeaway': 'yes',
#     'website': 'https://www.instagram.com/catedralcafemadrid/',
#     'website:menu': 'https://tr.ee/cN1J1QIbJ-'}},
#   {'type': 'node',
#    'id': 13017460373,
#    'lat': 40.4317996,
#    'lon': -3.7159251,
#    'tags': {'amenity': 'cafe',
#     'cuisine': 'coffee_shop',
#     'name': 'To be coffee',
#     'survey:date': '2025-07-22'}},
#   {'type': 'node',
#    'id': 13017460375,
#    'lat': 40.4318493,
#    'lon': -3.7167604,
#    'tags': {'amenity': 'cafe', 'name': 'Porto', 'survey:date': '2025-07-22'}},
#   {'type': 'node',
#    'id': 13026492102,
#    'lat': 40.4255085,
#    'lon': -3.6787415,
#    'tags': {'addr:housenumber': '15',
#     'addr:street': 'Calle del General Pardiñas',
#     'amenity': 'cafe',
#     'cuisine': 'breakfast;coffee_shop;pancake;tea',
#     'name': 'Norah Coffee & Brunch',
#     'opening_hours': 'Su-We 09:00-18:30; Th-Sa 09:00-19:00'}},
#   {'type': 'node',
#    'id': 13026515001,
#    'lat': 40.4251148,
#    'lon': -3.6790471,
#    'tags': {'addr:housenumber': '73',
#     'addr:street': 'Calle de Goya',
#     'amenity': 'cafe',
#     'name': 'Starbucks',
#     'opening_hours': 'Mo-Fr 07:30-22:00; Sa-Su 08:00-22:00'}},
#   {'type': 'node',
#    'id': 13041426802,
#    'lat': 40.4221611,
#    'lon': -3.6973358,
#    'tags': {'addr:housenumber': '37',
#     'addr:street': 'Calle de Augusto Figueroa',
#     'amenity': 'cafe',
#     'cuisine': 'coffee_shop;tea',
#     'name': 'ALFAR',
#     'opening_hours': 'Mo-Fr 08:00-19:00; Sa 09:00-19:00; Su 09:00-16:30'}},
#   {'type': 'node',
#    'id': 13057611191,
#    'lat': 40.4255698,
#    'lon': -3.6709906,
#    'tags': {'amenity': 'cafe',
#     'brand': 'Santagloria',
#     'brand:wikidata': 'Q54606497',
#     'name': 'Santagloria',
#     'shop': 'bakery',
#     'survey:date': '2025-08-08'}},
#   {'type': 'node',
#    'id': 13114656901,
#    'lat': 40.4228625,
#    'lon': -3.6890506,
#    'tags': {'amenity': 'cafe'}},
#   {'type': 'node',
#    'id': 13159603798,
#    'lat': 40.4250519,
#    'lon': -3.6979142,
#    'tags': {'addr:city': 'Madrid',
#     'addr:housenumber': '73',
#     'addr:postcode': '28004',
#     'addr:street': 'Calle de Hortaleza',
#     'amenity': 'cafe',
#     'contact:instagram': 'https://www.instagram.com/kohi.bakery',
#     'name': 'Kōhī',
#     'opening_hours': 'Mo-Su 09:00-20:00',
#     'outdoor_seating': 'no'}},
#   {'type': 'node',
#    'id': 13159799784,
#    'lat': 40.4293549,
#    'lon': -3.7076833,
#    'tags': {'amenity': 'cafe', 'name': 'Cofi.', 'survey:date': '2025-09-21'}},
#   {'type': 'node',
#    'id': 13159885443,
#    'lat': 40.424953,
#    'lon': -3.7124064,
#    'tags': {'amenity': 'cafe', 'name': 'Beher', 'survey:date': '2025-09-21'}},
#   {'type': 'node',
#    'id': 13165954328,
#    'lat': 40.4317121,
#    'lon': -3.7021939,
#    'tags': {'amenity': 'cafe', 'name': 'Naji', 'source': 'survey'}},
#   {'type': 'node',
#    'id': 13174973089,
#    'lat': 40.4225232,
#    'lon': -3.674902,
#    'tags': {'amenity': 'cafe',
#     'changing_table': 'no',
#     'diet:vegan': 'yes',
#     'diet:vegetarian': 'yes',
#     'name': 'Sau Dade',
#     'smoking': 'no',
#     'wheelchair': 'limited'}},
#   {'type': 'node',
#    'id': 13184793310,
#    'lat': 40.4227677,
#    'lon': -3.7017135,
#    'tags': {'addr:housenumber': '31',
#     'addr:street': 'Calle de Valverde',
#     'amenity': 'cafe',
#     'diet:vegan': 'only',
#     'diet:vegetarian': 'only',
#     'name': 'Fuga Madrid',
#     'opening_hours': 'Tu-Su 11:00-17:00; Mo off'}}]}

# %%
data
# Out:
# {'version': 0.6,
#  'generator': 'Overpass API 0.7.62.8 e802775f',
#  'osm3s': {'timestamp_osm_base': '2025-10-13T14:22:30Z',
#   'copyright': 'The data included in this document is from www.openstreetmap.org. The data is made available under ODbL.'},
#  'elements': [{'type': 'node',
#    'id': 150760847,
#    'lat': 40.4463777,
#    'lon': -3.7149013,
#    'tags': {'amenity': 'cafe',
#     'created_by': 'Potlatch 0.5d',
#     'name': 'Condemar'}},
#   {'type': 'node',
#    'id': 311973234,
#    'lat': 40.442532,
#    'lon': -3.6517071,
#    'tags': {'amenity': 'cafe', 'name': 'Torres', 'name:es': 'Torres'}},
#   {'type': 'node',
#    'id': 318919783,
#    'lat': 40.4292399,
#    'lon': -3.7224188,
#    'tags': {'addr:city': 'Madrid',
#     'addr:postcode': '28008',
#     'addr:street': 'Paseo del Pintor Rosales',
#     'amenity': 'cafe',
#     'name': 'Magadán'}},
#   {'type': 'node',
#    'id': 327565888,
#    'lat': 40.4377269,
#    'lon': -3.6635351,
#    'tags': {'amenity': 'cafe', 'name': 'Cafetería Bruselas'}},
#   {'type': 'node',
#    'id': 410620052,
#    'lat': 40.4482368,
#    'lon': -3.7238292,
#    'tags': {'amenity': 'cafe',
#     'cuisine': 'yes',
#     'name': 'Facultad de Forestales'}},
#   {'type': 'node',
#    'id': 622204562,
#    'lat': 40.4244873,
#    'lon': -3.7103465,
#    'tags': {'addr:city': 'Madrid',
#     'addr:housenumber': '7',
#     'addr:street': 'Calle de los Dos Amigos',
#     'amenity': 'cafe',
#     'contact:phone': '+34 91 542 90 19',
#     'contact:website': 'http://www.cafedosamigos.com/',
#     'name': 'Los Dos Amigos',
#     'wheelchair': 'no',
#     'wheelchair:description': 'escalón y escaleras interiores'}},
#   {'type': 'node',
#    'id': 622204563,
#    'lat': 40.4231601,
#    'lon': -3.7108488,
#    'tags': {'addr:city': 'Madrid',
#     'addr:housenumber': '73',
#     'addr:postcode': '28013',
#     'addr:street': 'Gran Vía',
#     'air_conditioning': 'yes',
#     'amenity': 'cafe',
#     'brand': 'Starbucks',
#     'brand:wikidata': 'Q37158',
#     'brand:wikipedia': 'en:Starbucks',
#     'check_date': '2024-12-10',
#     'check_date:diet:vegan': '2024-12-10',
#     'check_date:diet:vegetarian': '2024-12-10',
#     'check_date:smoking': '2024-11-24',
#     'check_date:toilets:wheelchair': '2024-12-10',
#     'cuisine': 'coffee_shop',
#     'diet:vegan': 'no',
#     'diet:vegetarian': 'yes',
#     'indoor_seating': 'yes',
#     'layer': '1',
#     'name': 'Starbucks',
#     'official_name': 'Starbucks Coffee',
#     'opening_hours': 'Mo-Su 07:30-23:00',
#     'outdoor_seating': 'yes',
#     'smoking': 'outside',
#     'takeaway': 'yes',
#     'toilets': 'yes',
#     'toilets:wheelchair': 'no',
#     'website': 'https://www.starbucks.es/',
#     'wheelchair': 'limited'}},
#   {'type': 'node',
#    'id': 623071231,
#    'lat': 40.4252249,
#    'lon': -3.7153795,
#    'tags': {'addr:city': 'Madrid',
#     'addr:housenumber': '23',
#     'addr:postcode': '28008',
#     'addr:street': 'Calle Luisa Fernanda',
#     'amenity': 'cafe',
#     'contact:phone': '+34 915594645',
#     'contact:website': 'http://www.vienacapellanes.com/',
#     'name': 'Café Viena'}},
#   {'type': 'node',
#    'id': 674492241,
#    'lat': 40.4254,
#    'lon': -3.7072729,
#    'tags': {'addr:city': 'Madrid',
#     'addr:housenumber': '58',
#     'addr:postcode': '28015',
#     'addr:street': 'Calle de San Bernardo',
#     'amenity': 'cafe',
#     'brand': 'Santagloria',
#     'brand:wikidata': 'Q54606497',
#     'check_date': '2023-09-24',
#     'check_date:opening_hours': '2022-09-05',
#     'diet:vegetarian': 'yes',
#     'name': 'Santagloria',
#     'old_name_1': 'Rodilla',
#     'old_name_2': 'Bake Bar',
#     'opening_hours:signed': 'no',
#     'outdoor_seating': 'yes',
#     'shop': 'bakery',
#     'wheelchair': 'no'}},
#   {'type': 'node',
#    'id': 750504785,
#    'lat': 40.4510028,
#    'lon': -3.6773993,
#    'tags': {'addr:city': 'Madrid',
#     'addr:housenumber': '210 (posterior)',
#     'addr:postcode': '28002',
#     'addr:street': 'Calle del Príncipe de Vergara',
#     'amenity': 'cafe',
#     'name': 'Café Universal'}},
#   {'type': 'node',
#    'id': 810259248,
#    'lat': 40.4445182,
#    'lon': -3.6668344,
#    'tags': {'amenity': 'cafe', 'name': 'Entre Jamones', 'wheelchair': 'no'}},
#   {'type': 'node',
#    'id': 989278217,
#    'lat': 40.4500696,
#    'lon': -3.6880992,
#    'tags': {'amenity': 'cafe', 'name': 'La Tertulia'}},
#   {'type': 'node',
#    'id': 993468828,
#    'lat': 40.4292978,
#    'lon': -3.7149613,
#    'tags': {'air_conditioning': 'yes',
#     'amenity': 'cafe',
#     'brand': 'Starbucks',
#     'brand:wikidata': 'Q37158',
#     'brand:wikipedia': 'en:Starbucks',
#     'cuisine': 'coffee_shop',
#     'name': 'Starbucks',
#     'official_name': 'Starbucks Coffee',
#     'opening_hours': 'Mo-Fr 07:30-22:00,08:00-22:00',
#     'smoking': 'outside',
#     'takeaway': 'yes',
#     'website': 'https://www.starbucks.co.uk/store-locator/32345-115929/princesa-40',
#     'wheelchair': 'yes'}},
#   {'type': 'node',
#    'id': 1056099074,
#    'lat': 40.4530713,
#    'lon': -3.7189142,
#    'tags': {'amenity': 'cafe', 'name': 'Cafetería Universidad Nebrija'}},
#   {'type': 'node',
#    'id': 1239289876,
#    'lat': 40.4703555,
#    'lon': -3.6325084,
#    'tags': {'amenity': 'cafe', 'cuisine': 'spanish', 'name': 'Europa 2'}},
#   {'type': 'node',
#    'id': 1288311612,
#    'lat': 40.4306465,
#    'lon': -3.7236666,
#    'tags': {'amenity': 'cafe', 'name': 'La Perla', 'source': 'survey'}},
#   {'type': 'node',
#    'id': 1316492166,
#    'lat': 40.4259892,
#    'lon': -3.6937987,
#    'tags': {'amenity': 'cafe', 'smoking': 'no', 'wheelchair': 'limited'}},
#   {'type': 'node',
#    'id': 1316546637,
#    'lat': 40.4272302,
#    'lon': -3.6952847,
#    'tags': {'addr:city': 'Madrid',
#     'addr:housenumber': '4',
#     'addr:postcode': '28004',
#     'addr:street': 'Calle de Génova',
#     'amenity': 'cafe',
#     'name': 'Viena Capellanes',
#     'phone': '+34 913192792',
#     'website': 'http://www.vienacapellanes.com/stores/lookstore.php?idioma=esp&terminal=linux&store=9'}},
#   {'type': 'node',
#    'id': 1316546690,
#    'lat': 40.4260117,
#    'lon': -3.6921003,
#    'tags': {'addr:city': 'Madrid',
#     'addr:housenumber': '27',
#     'addr:postcode': '28004',
#     'addr:street': 'Calle de Génova',
#     'amenity': 'cafe',
#     'brand': 'Starbucks',
#     'brand:wikidata': 'Q37158',
#     'brand:wikipedia': 'en:Starbucks',
#     'check_date': '2025-04-29',
#     'cuisine': 'coffee_shop',
#     'internet_access': 'wlan',
#     'internet_access:fee': 'no',
#     'name': 'Starbucks',
#     'official_name': 'Starbucks Coffee',
#     'opening_hours': '08:30-21:30',
#     'operator': 'Grupo Vips',
#     'outdoor_seating': 'yes',
#     'smoking': 'no',
#     'survey:date': '2022-04-04',
#     'takeaway': 'yes',
#     'website': 'https://www.starbucks.es/',
#     'wheelchair': 'limited'}},
#   {'type': 'node',
#    'id': 1319826836,
#    'lat': 40.4261051,
#    'lon': -3.6940576,
#    'tags': {'addr:city': 'Madrid',
#     'addr:housenumber': '19',
#     'addr:postcode': '28004',
#     'addr:street': 'Calle de Orellana',
#     'amenity': 'cafe',
#     'cuisine': 'israeli;middle_eastern;healthy',
#     'internet_access': 'yes',
#     'internet_access:fee': 'no',
#     'name': 'Golda Cafe',
#     'opening_hours': 'Mo-Su 08:00-20:30',
#     'website': 'https://goldacafe.com/'}},
#   {'type': 'node',
#    'id': 1319826861,
#    'lat': 40.4239163,
#    'lon': -3.6925858,
#    'tags': {'amenity': 'cafe', 'name': 'El Supremo', 'smoking': 'no'}},
#   {'type': 'node',
#    'id': 1319826869,
#    'lat': 40.4268533,
#    'lon': -3.6960421,
#    'tags': {'amenity': 'cafe',
#     'name': 'Santa Bárbara',
#     'wheelchair': 'limited'}},
#   {'type': 'node',
#    'id': 1359795118,
#    'lat': 40.4326811,
#    'lon': -3.6832448,
#    'tags': {'amenity': 'cafe',
#     'brand': 'Starbucks',
#     'brand:wikidata': 'Q37158',
#     'brand:wikipedia': 'en:Starbucks',
#     'cuisine': 'coffee_shop',
#     'name': 'Starbucks',
#     'official_name': 'Starbucks Coffee',
#     'takeaway': 'yes'}},
#   {'type': 'node',
#    'id': 1366539657,
#    'lat': 40.437727,
#    'lon': -3.6892063,
#    'tags': {'addr:street': 'Maria de Molina',
#     'amenity': 'cafe',
#     'name': 'Café Saigón'}},
#   {'type': 'node',
#    'id': 1413315512,
#    'lat': 40.4417047,
#    'lon': -3.6378328,
#    'tags': {'amenity': 'cafe', 'name': 'Bar Antonio'}},
#   {'type': 'node',
#    'id': 1434581409,
#    'lat': 40.4296017,
#    'lon': -3.7049083,
#    'tags': {'addr:city': 'Madrid',
#     'addr:housenumber': '20',
#     'addr:postcode': '28004',
#     'addr:street': 'Calle de Carranza',
#     'amenity': 'cafe',
#     'check_date': '2024-11-26',
#     'name': 'Dolce e Salato',
#     'old_name': 'Imaginarium',
#     'old_name_1': 'Valentinas & Coffee',
#     'wheelchair': 'no'}},
#   {'type': 'node',
#    'id': 1517405720,
#    'lat': 40.4238583,
#    'lon': -3.701488,
#    'tags': {'addr:city': 'Madrid',
#     'addr:housenumber': '14',
#     'addr:postcode': '28004',
#     'addr:street': 'Calle de Colón',
#     'amenity': 'cafe',
#     'contact:facebook': 'https://www.facebook.com/pages/Cr%C3%AAperie-La-Rue/118120001543910?sk=info&tab=overview',
#     'contact:phone': '+34 911 89 70 87',
#     'cuisine': 'crepe',
#     'name': 'La Rue',
#     'old_name': 'Al Laboratorio',
#     'opening_hours': 'Su-Th 10:00-00:00; Fr-Sa 10:00-01:00; PH off',
#     'website': 'https://creperielarue.com',
#     'website:menu': 'https://creperielarue.com/carta-7/',
#     'wheelchair': 'no'}},
#   {'type': 'node',
#    'id': 1613048501,
#    'lat': 40.4427781,
#    'lon': -3.6961674,
#    'tags': {'amenity': 'cafe', 'name': 'Camelia'}},
#   {'type': 'node',
#    'id': 1621005272,
#    'lat': 40.425099,
#    'lon': -3.7124847,
#    'tags': {'addr:city': 'Madrid',
#     'addr:housenumber': '3',
#     'addr:postcode': '28008',
#     'addr:street': 'Calle de la Princesa',
#     'amenity': 'cafe',
#     'diet:vegetarian': 'yes',
#     'indoor_seating': 'yes',
#     'name': 'Café & Té',
#     'outdoor_seating': 'yes',
#     'smoking': 'no',
#     'wheelchair': 'yes'}},
#   {'type': 'node',
#    'id': 1642177961,
#    'lat': 40.4246631,
#    'lon': -3.709637,
#    'tags': {'addr:city': 'Madrid',
#     'addr:housenumber': '2',
#     'addr:postcode': '28015',
#     'addr:street': 'Plaza del Conde de Toreno',
#     'amenity': 'cafe',
#     'name': 'db',
#     'old_name': 'Habibi',
#     'wheelchair': 'no'}},
#   {'type': 'node',
#    'id': 1642178045,
#    'lat': 40.4238691,
#    'lon': -3.7089925,
#    'tags': {'addr:city': 'Madrid',
#     'addr:housenumber': '8',
#     'addr:postcode': '28015',
#     'addr:street': 'Calle del Álamo',
#     'amenity': 'cafe',
#     'indoor_seating': 'no',
#     'name': 'Sieté Seven Tea',
#     'outdoor_seating': 'no',
#     'phone': '+34 657 917 362',
#     'takeaway': 'only'}},
#   {'type': 'node',
#    'id': 1686702375,
#    'lat': 40.4487805,
#    'lon': -3.7254083,
#    'tags': {'air_conditioning': 'yes',
#     'amenity': 'cafe',
#     'indoor_seating': 'yes',
#     'name': 'Cafetería Facultad de Ciencias Geológicas',
#     'outdoor_seating': 'yes',
#     'smoking': 'no'}},
#   {'type': 'node',
#    'id': 1739898679,
#    'lat': 40.4395371,
#    'lon': -3.6196894,
#    'tags': {'amenity': 'cafe'}},
#   {'type': 'node',
#    'id': 1740058741,
#    'lat': 40.4223451,
#    'lon': -3.6816075,
#    'tags': {'amenity': 'cafe', 'name': 'Café & Té', 'wheelchair': 'no'}},
#   {'type': 'node',
#    'id': 1927659397,
#    'lat': 40.4682877,
#    'lon': -3.7224352,
#    'tags': {'alt_name': 'Cervecería La Orensana',
#     'amenity': 'cafe',
#     'name': 'La Orensana'}},
#   {'type': 'node',
#    'id': 1944473872,
#    'lat': 40.4463066,
#    'lon': -3.7135061,
#    'tags': {'amenity': 'cafe', 'name': 'La Vuelta'}},
#   {'type': 'node',
#    'id': 1988186838,
#    'lat': 40.4340803,
#    'lon': -3.6328064,
#    'tags': {'amenity': 'cafe', 'name': 'Juka'}},
#   {'type': 'node',
#    'id': 2056509590,
#    'lat': 40.4261644,
#    'lon': -3.7147519,
#    'tags': {'alt_name': '3"', 'amenity': 'cafe', 'name': 'Café 3 segundos'}},
#   {'type': 'node',
#    'id': 2057557358,
#    'lat': 40.4566516,
#    'lon': -3.7051554,
#    'tags': {'amenity': 'cafe',
#     'check_date': '2023-10-31',
#     'name': 'La Pampa',
#     'wheelchair': 'limited'}},
#   {'type': 'node',
#    'id': 2057557418,
#    'lat': 40.4569966,
#    'lon': -3.7055108,
#    'tags': {'amenity': 'cafe',
#     'check_date': '2023-10-31',
#     'name': 'La Unión',
#     'toilets:wheelchair': 'no',
#     'wheelchair': 'limited'}},
#   {'type': 'node',
#    'id': 2057557445,
#    'lat': 40.4567065,
#    'lon': -3.7039235,
#    'tags': {'addr:city': 'Madrid',
#     'addr:postcode': '28039',
#     'addr:street': 'Calle de Berruguete',
#     'alt_name': 'Las delicias de Judith',
#     'amenity': 'cafe',
#     'diet:halal': 'no',
#     'name': 'Las Delicias de Judy',
#     'old_name': 'Bar Torre',
#     'old_name1': 'La Castiza',
#     'old_name2': 'Bulevar',
#     'opening_hours': 'PH,Tu-Su 09:00-24:00',
#     'operator': 'Magizan Bulevar, SL',
#     'payment:credit_cards': 'yes',
#     'payment:debit_cards': 'yes',
#     'wheelchair': 'limited'}},
#   {'type': 'node',
#    'id': 2135526338,
#    'lat': 40.4291823,
#    'lon': -3.7216853,
#    'tags': {'addr:city': 'Madrid',
#     'addr:housenumber': '48',
#     'addr:postcode': '28008',
#     'addr:street': 'Paseo del Pintor Rosales',
#     'amenity': 'cafe',
#     'name': 'La Habana Vieja',
#     'phone': '+34 915 59 81 04'}},
#   {'type': 'node',
#    'id': 2270766143,
#    'lat': 40.4443345,
#    'lon': -3.6749375,
#    'tags': {'amenity': 'cafe',
#     'name': 'Cafetería Prospe',
#     'wheelchair': 'limited'}},
#   {'type': 'node',
#    'id': 2298820823,
#    'lat': 40.4452235,
#    'lon': -3.6764378,
#    'tags': {'amenity': 'cafe',
#     'name': 'La tabernita azul',
#     'name:en': 'The Blue Little Tavern',
#     'name:fr': 'La petite taverne bleu',
#     'smoking': 'no'}},
#   {'type': 'node',
#    'id': 2302262357,
#    'lat': 40.4427506,
#    'lon': -3.6690847,
#    'tags': {'amenity': 'cafe',
#     'cuisine': 'spanish',
#     'name': 'La Taberna del Cardenal',
#     'wifi': 'no'}},
#   {'type': 'node',
#    'id': 2477700587,
#    'lat': 40.4225774,
#    'lon': -3.7063743,
#    'tags': {'addr:city': 'Madrid',
#     'addr:housenumber': '24',
#     'addr:postcode': '28015',
#     'addr:street': 'Calle de la Luna',
#     'amenity': 'cafe',
#     'check_date': '2023-09-26',
#     'name': 'Day Madrid',
#     'old_name': 'De Calle',
#     'old_name_1': 'Amor de calle',
#     'old_name_2': 'Crack',
#     'old_name_3': 'Maraca',
#     'wheelchair': 'no'}},
#   {'type': 'node',
#    'id': 2495089202,
#    'lat': 40.4569021,
#    'lon': -3.703247,
#    'tags': {'amenity': 'cafe',
#     'name': 'Brasiliana',
#     'opening_hours': 'PH,Mo-Su 07:30-13:30',
#     'wheelchair': 'no'}},
#   {'type': 'node',
#    'id': 2510220975,
#    'lat': 40.4348709,
#    'lon': -3.6306805,
#    'tags': {'amenity': 'cafe'}},
#   {'type': 'node',
#    'id': 2585165172,
#    'lat': 40.4256513,
#    'lon': -3.7067242,
#    'tags': {'addr:city': 'Madrid',
#     'addr:housenumber': '47',
#     'addr:postcode': '28004',
#     'addr:street': 'Calle del Espíritu Santo',
#     'amenity': 'cafe',
#     'contact:phone': '+34 91 521 85 76.',
#     'contact:website': 'http://www.jandjbooksandcoffee.com/index.php',
#     'description': 'Bar y café y tienda de libros de segunda mano en inglés.',
#     'name': 'J & J Books and Coffee',
#     'shop': 'books',
#     'wheelchair': 'no'}},
#   {'type': 'node',
#    'id': 2623305612,
#    'lat': 40.4365104,
#    'lon': -3.6106963,
#    'tags': {'addr:city': 'Madrid',
#     'addr:housename': 'Café Pub Dribling',
#     'addr:housenumber': '93',
#     'addr:postcode': '28022',
#     'addr:street': 'Calle de Nicolasa Gómez',
#     'amenity': 'cafe',
#     'cuisine': 'coffee_shop',
#     'internet_access': 'yes',
#     'name': 'Café Pub Dribling',
#     'opening_hours': '11:00-02:00',
#     'phone': '+34 91 320 49 16'}},
#   {'type': 'node',
#    'id': 2626943556,
#    'lat': 40.4237468,
#    'lon': -3.7022593,
#    'tags': {'addr:city': 'Madrid',
#     'addr:housenumber': '9',
#     'addr:postcode': '28004',
#     'addr:street': 'Plaza de San Ildefonso',
#     'amenity': 'cafe',
#     'diet:vegetarian': 'yes',
#     'email': 'labicicletacafe@gmail.com',
#     'internet_access': 'wlan',
#     'name': 'La Bicicleta',
#     'opening_hours': 'Su-Th 00:00-02:00,10:00-24:00; Fr-Sa 00:00-02:00, 10:00-24:00',
#     'payment:cash': 'yes',
#     'payment:mastercard': 'yes',
#     'payment:visa': 'yes',
#     'phone': '+34 915 32 97 42',
#     'website': 'https://www.labicicletacafe.com/',
#     'wheelchair': 'yes'}},
#   {'type': 'node',
#    'id': 2632228956,
#    'lat': 40.4242479,
#    'lon': -3.7072805,
#    'tags': {'addr:city': 'Madrid',
#     'addr:housenumber': '42',
#     'addr:postcode': '28015',
#     'addr:street': 'Calle de San Bernardo',
#     'amenity': 'cafe',
#     'diet:halal': 'no',
#     'diet:kosher': 'no',
#     'name': 'Dos Passos',
#     'opening_hours': 'Mo-Su 07:30-01:30',
#     'wheelchair': 'no',
#     'wheelchair:description': 'Escalón de acceso aprox. 5 cm'}},
#   {'type': 'node',
#    'id': 2636531053,
#    'lat': 40.4546924,
#    'lon': -3.7025906,
#    'tags': {'amenity': 'cafe', 'name': 'La Antigua de Estrecho'}},
#   {'type': 'node',
#    'id': 2639635434,
#    'lat': 40.425725,
#    'lon': -3.7088156,
#    'tags': {'addr:city': 'Madrid',
#     'addr:housenumber': '16',
#     'addr:postcode': '28015',
#     'addr:street': 'Calle de Noviciado',
#     'amenity': 'cafe',
#     'name': 'Sweet Studio',
#     'old_name': 'The Place'}},
#   {'type': 'node',
#    'id': 2640019766,
#    'lat': 40.426991,
#    'lon': -3.6165839,
#    'tags': {'amenity': 'cafe', 'name': 'Los Niños de la Victoria'}},
#   {'type': 'node',
#    'id': 2640019767,
#    'lat': 40.4271711,
#    'lon': -3.6167821,
#    'tags': {'amenity': 'cafe', 'name': 'Sila'}},
#   {'type': 'node',
#    'id': 2640019773,
#    'lat': 40.4269262,
#    'lon': -3.6173124,
#    'tags': {'amenity': 'cafe', 'name': "Julio's"}},
#   {'type': 'node',
#    'id': 2640019775,
#    'lat': 40.4269436,
#    'lon': -3.6168766,
#    'tags': {'amenity': 'cafe', 'old_name': 'Bar San Blas'}},
#   {'type': 'node',
#    'id': 2642274454,
#    'lat': 40.4261072,
#    'lon': -3.6815626,
#    'tags': {'addr:city': 'Madrid',
#     'addr:housenumber': '39',
#     'addr:postcode': '28001',
#     'addr:street': 'Calle de Castelló',
#     'amenity': 'cafe',
#     'brand': 'Granier',
#     'brand:wikidata': 'Q102311169',
#     'contact:facebook': 'https://es-es.facebook.com/Granierhermosilla/info',
#     'email': 'granierhermosilla@gmail.com',
#     'name': 'Granier',
#     'opening_hours': 'Mo-Su 07:00-21:30',
#     'phone': '+34 914 35 24 76',
#     'shop': 'bakery',
#     'wheelchair': 'yes'}},
#   {'type': 'node',
#    'id': 2642274457,
#    'lat': 40.4260456,
#    'lon': -3.6807566,
#    'tags': {'addr:city': 'Madrid',
#     'addr:housenumber': '58',
#     'addr:postcode': '28001',
#     'addr:street': 'Calle de Hermosilla',
#     'amenity': 'cafe',
#     'contact:facebook': 'https://es-es.facebook.com/juliettascaffe/',
#     'contact:phone': '+34 910530297',
#     'old_name': 'Nata Lovers',
#     'wheelchair': 'limited'}},
#   {'type': 'node',
#    'id': 2642274458,
#    'lat': 40.4261465,
#    'lon': -3.682848,
#    'tags': {'addr:city': 'Madrid',
#     'addr:housenumber': '40',
#     'addr:postcode': '28001',
#     'addr:street': 'Calle de Hermosilla',
#     'amenity': 'cafe',
#     'name': 'El Café de Hermosilla',
#     'wheelchair': 'yes'}},
#   {'type': 'node',
#    'id': 2646161158,
#    'lat': 40.4384818,
#    'lon': -3.651788,
#    'tags': {'amenity': 'cafe'}},
#   {'type': 'node',
#    'id': 2646161161,
#    'lat': 40.4385758,
#    'lon': -3.6518471,
#    'tags': {'amenity': 'cafe', 'name': 'Román'}},
#   {'type': 'node',
#    'id': 2646161163,
#    'lat': 40.4387166,
#    'lon': -3.6519678,
#    'tags': {'amenity': 'cafe', 'name': 'Laso', 'name:es': 'Laso'}},
#   {'type': 'node',
#    'id': 2646180931,
#    'lat': 40.4348551,
#    'lon': -3.6563344,
#    'tags': {'amenity': 'cafe', 'name': 'Río', 'name:es': 'Río'}},
#   {'type': 'node',
#    'id': 2652999510,
#    'lat': 40.4234287,
#    'lon': -3.6148448,
#    'tags': {'amenity': 'cafe'}},
#   {'type': 'node',
#    'id': 2653822213,
#    'lat': 40.4260105,
#    'lon': -3.7071668,
#    'tags': {'addr:city': 'Madrid',
#     'addr:housenumber': '57',
#     'addr:postcode': '28015',
#     'addr:street': 'Calle de San Bernardo',
#     'amenity': 'cafe',
#     'name': 'La Doña',
#     'old_name': 'Movistar',
#     'opening_hours': '24/7',
#     'toilets:wheelchair': 'yes',
#     'wheelchair': 'yes'}},
#   {'type': 'node',
#    'id': 2664897893,
#    'lat': 40.4379771,
#    'lon': -3.6773101,
#    'tags': {'addr:city': 'Madrid',
#     'addr:housenumber': '1',
#     'addr:postcode': '28002',
#     'addr:street': 'Avenida de América',
#     'amenity': 'cafe',
#     'contact:facebook': 'https://es-es.facebook.com/pages/Cafeteria-Honey-Madrid/214076878627039',
#     'email': 'cafeteriahoney@ono.com',
#     'name': 'Honey',
#     'phone': '+34 915 63 58 18'}},
#   {'type': 'node',
#    'id': 2668366790,
#    'lat': 40.4299435,
#    'lon': -3.7077873,
#    'tags': {'addr:city': 'Madrid',
#     'addr:housenumber': '12',
#     'addr:postcode': '28015',
#     'addr:street': 'Calle de Alberto Aguilera',
#     'amenity': 'cafe',
#     'name': 'Cauca'}},
#   {'type': 'node',
#    'id': 2668366797,
#    'lat': 40.4298654,
#    'lon': -3.7069624,
#    'tags': {'addr:city': 'Madrid',
#     'addr:housenumber': '8',
#     'addr:postcode': '28015',
#     'addr:street': 'Calle de Alberto Aguilera',
#     'amenity': 'cafe',
#     'check_date': '2023-09-28',
#     'name': 'Panaria',
#     'opening_hours': 'Mo-Sa 08:00-20:30; PH,Su 09:00-14:30',
#     'outdoor_seating': 'yes',
#     'shop': 'bakery',
#     'website': 'https://www.panariapanaderias.es/',
#     'wheelchair': 'no'}},
#   {'type': 'node',
#    'id': 2668463117,
#    'lat': 40.4241701,
#    'lon': -3.7063175,
#    'tags': {'addr:city': 'Madrid',
#     'addr:housenumber': '36',
#     'addr:postcode': '28004',
#     'addr:street': 'Calle del Pez',
#     'amenity': 'cafe',
#     'check_date': '2023-09-24',
#     'name': 'Ambu Coffee',
#     'old_name': 'Trakabarraka',
#     'old_name_1': 'Popota',
#     'website': 'https://ambu.coffee/',
#     'wheelchair': 'limited'}},
#   {'type': 'node',
#    'id': 2669198762,
#    'lat': 40.428062,
#    'lon': -3.7094676,
#    'tags': {'addr:city': 'Madrid',
#     'addr:housenumber': '36',
#     'addr:postcode': '28015',
#     'addr:street': 'Calle de Amaniel',
#     'amenity': 'cafe',
#     'contact:website': 'https://www.unfltrdcoffee.com/',
#     'name': 'Unfiltrd',
#     'old_name': 'Rías Baixas'}},
#   {'type': 'node',
#    'id': 2669198767,
#    'lat': 40.4270528,
#    'lon': -3.7092373,
#    'tags': {'addr:city': 'Madrid',
#     'addr:housenumber': '9',
#     'addr:postcode': '28015',
#     'addr:street': 'Plaza de las Comendadoras',
#     'amenity': 'cafe',
#     'check_date': '2023-09-30',
#     'diet:vegan': 'yes',
#     'diet:vegetarian': 'yes',
#     'email': 'madrid@federalcafe.es',
#     'internet_access': 'wlan',
#     'internet_access:password': 'cafeconleche',
#     'name': 'Federal Café',
#     'opening_hours': 'Mo-Sa 09:00-24:00; Sa,Su 00:00-01:00; Su 09:00-17:00',
#     'outdoor_seating': 'yes',
#     'phone': '+34 915 328 424',
#     'toilets:wheelchair': 'yes',
#     'website': 'https://federalcafe.es/madrid/',
#     'wheelchair': 'yes'}},
#   {'type': 'node',
#    'id': 2669909215,
#    'lat': 40.4296557,
#    'lon': -3.7051951,
#    'tags': {'addr:city': 'Madrid',
#     'addr:housenumber': '5',
#     'addr:postcode': '28015',
#     'addr:street': 'Glorieta de Ruiz Jiménez',
#     'amenity': 'cafe',
#     'check_date': '2024-05-20',
#     'name': 'Café Minber'}},
#   {'type': 'node',
#    'id': 2669909220,
#    'lat': 40.4314648,
#    'lon': -3.708136,
#    'tags': {'addr:city': 'Madrid',
#     'addr:housenumber': '7',
#     'addr:postcode': '28015',
#     'addr:street': 'Calle de Rodríguez San Pedro',
#     'amenity': 'cafe',
#     'name': "Friend's Coffee"}},
#   {'type': 'node',
#    'id': 2669997847,
#    'lat': 40.4352928,
#    'lon': -3.7141753,
#    'tags': {'addr:city': 'Madrid',
#     'addr:housenumber': '71',
#     'addr:postcode': '28015',
#     'addr:street': 'Calle de Fernández de los Ríos',
#     'amenity': 'cafe',
#     'name': 'C@ffe.it'}},
#   {'type': 'node',
#    'id': 2671175816,
#    'lat': 40.4332265,
#    'lon': -3.7088754,
#    'tags': {'addr:city': 'Madrid',
#     'addr:housenumber': '37',
#     'addr:postcode': '28015',
#     'addr:street': 'Calle de Vallehermoso',
#     'amenity': 'cafe',
#     'name': 'Tormes'}},
#   {'type': 'node',
#    'id': 2671207707,
#    'lat': 40.4351872,
#    'lon': -3.7118607,
#    'tags': {'addr:city': 'Madrid',
#     'addr:housenumber': '55',
#     'addr:postcode': '28015',
#     'addr:street': 'Calle de Fernández de los Ríos',
#     'amenity': 'cafe',
#     'name': 'Rotterdam'}},
#   {'type': 'node',
#    'id': 2671241942,
#    'lat': 40.4261035,
#    'lon': -3.7075585,
#    'tags': {'addr:city': 'Madrid',
#     'addr:housenumber': '53',
#     'addr:postcode': '28015',
#     'addr:street': 'Calle de San Vicente Ferrer',
#     'amenity': 'cafe',
#     'name': 'El Naranja',
#     'website': 'http://www.elnaranja.info/1.html'}},
#   {'type': 'node',
#    'id': 2672814926,
#    'lat': 40.4227936,
#    'lon': -3.7039429,
#    'tags': {'addr:city': 'Madrid',
#     'addr:housenumber': '4',
#     'addr:postcode': '28004',
#     'addr:street': 'Calle del Pez',
#     'amenity': 'cafe',
#     'check_date': '2023-10-04',
#     'name': 'Constanza Cafe',
#     'old_name': 'Antorcha Café',
#     'wheelchair': 'no'}},
#   {'type': 'node',
#    'id': 2672817741,
#    'lat': 40.4224594,
#    'lon': -3.7039475,
#    'tags': {'addr:city': 'Madrid',
#     'addr:housenumber': '25',
#     'addr:postcode': '28004',
#     'addr:street': 'Corredera Baja de San Pablo',
#     'amenity': 'cafe',
#     'name': 'SWT Gallery'}},
#   {'type': 'node',
#    'id': 2672831651,
#    'lat': 40.4221388,
#    'lon': -3.7025164,
#    'tags': {'addr:city': 'Madrid',
#     'addr:housenumber': '8',
#     'addr:postcode': '28004',
#     'addr:street': 'Calle de la Puebla',
#     'amenity': 'cafe',
#     'contact:facebook': 'pages/Caf%C3%A9-de-la-Luz/168195233378',
#     'name': 'Café de la Luz',
#     'opening_hours': 'Mo-Su 10:00-02:00',
#     'phone': '+34 915 23 11 99'}},
#   {'type': 'node',
#    'id': 2676854997,
#    'lat': 40.4219393,
#    'lon': -3.7045881,
#    'tags': {'addr:city': 'Madrid',
#     'addr:housenumber': '11',
#     'addr:postcode': '28004',
#     'addr:street': 'Corredera Baja de San Pablo',
#     'amenity': 'cafe',
#     'contact:facebook': 'https://es-es.facebook.com/BarCafeLara',
#     'name': 'Cafetería Lara',
#     'phone': '+34 609 90 68 12',
#     'wheelchair': 'no'}},
#   {'type': 'node',
#    'id': 2681923270,
#    'lat': 40.423242,
#    'lon': -3.7073722,
#    'tags': {'addr:city': 'Madrid',
#     'addr:housenumber': '24',
#     'addr:postcode': '28015',
#     'addr:street': 'Calle de San Bernardo',
#     'amenity': 'cafe',
#     'contact:phone': '+34 910 55 86',
#     'contact:website': 'https://cafeangelica.es/',
#     'name': 'Café Angélica',
#     'old_name': 'Angélica',
#     'shop': 'coffee',
#     'wheelchair': 'no',
#     'wheelchair:description': 'Escalón de acceso mayor de 7 cm y puerta de 80 cm'}},
#   {'type': 'node',
#    'id': 2692606027,
#    'lat': 40.422785,
#    'lon': -3.6993686,
#    'tags': {'addr:city': 'Madrid',
#     'addr:housenumber': '17',
#     'addr:postcode': '28004',
#     'addr:street': 'Calle de Augusto Figueroa',
#     'amenity': 'cafe',
#     'contact:website': 'https://www.lakamabaranoa.com/inicio',
#     'name': 'LaKama Café',
#     'old_name': 'Café Figueroa',
#     'wheelchair': 'no'}},
#   {'type': 'node',
#    'id': 2704017903,
#    'lat': 40.4257155,
#    'lon': -3.7038206,
#    'tags': {'addr:city': 'Madrid',
#     'addr:housenumber': '4',
#     'addr:postcode': '28004',
#     'addr:street': 'Calle de San Andrés',
#     'amenity': 'cafe',
#     'check_date': '2023-09-24',
#     'contact:facebook': 'https://www.facebook.com/people/El-Colmao-Ecol%C3%B3gico/100077502827742/',
#     'contact:phone': '+34 914 96 07 56',
#     'name': 'El Colmao Ecológico',
#     'old_name': 'Doña Francisquita',
#     'wheelchair': 'no'}},
#   {'type': 'node',
#    'id': 2704017922,
#    'lat': 40.4281338,
#    'lon': -3.7039279,
#    'tags': {'addr:city': 'Madrid',
#     'addr:housenumber': '11',
#     'addr:postcode': '28004',
#     'addr:street': 'Calle de Ruiz',
#     'amenity': 'cafe',
#     'name': 'Café de Ruiz',
#     'survey:date': '2024-01-04',
#     'website': 'http://cafederuiz.com/'}},
#   {'type': 'node',
#    'id': 2739850840,
#    'lat': 40.4378104,
#    'lon': -3.6505224,
#    'tags': {'amenity': 'cafe',
#     'check_date': '2023-06-13',
#     'internet_access': 'no',
#     'name': 'Cafetería Luzón'}},
#   {'type': 'node',
#    'id': 2764318350,
#    'lat': 40.4265999,
#    'lon': -3.6783933,
#    'tags': {'addr:city': 'Madrid',
#     'addr:housenumber': '32',
#     'addr:street': 'Calle del General Pardiñas',
#     'amenity': 'cafe',
#     'cuisine': 'drinks;tapas',
#     'name': 'Café de Zine',
#     'note': 'Se sirven copas (bar) y hay tapas (¿restaurante?), pero ellos mismos lo clasifican como "Café".'}},
#   {'type': 'node',
#    'id': 2769265438,
#    'lat': 40.4224814,
#    'lon': -3.7005843,
#    'tags': {'addr:city': 'Madrid',
#     'addr:housenumber': '2',
#     'addr:postcode': '28004',
#     'addr:street': 'Calle de Pérez Galdós',
#     'amenity': 'cafe',
#     'contact:instagram': 'https://www.instagram.com/wolfoxmadrid',
#     'name': 'Wolføx Coffee Madrid',
#     'old_name': 'IT Dogs',
#     'opening_hours': 'Mo-Su 10:00-19:00',
#     'outdoor_seating': 'yes',
#     'website': 'https://www.wolfox.coffee/'}},
#   {'type': 'node',
#    'id': 2777281762,
#    'lat': 40.4247401,
#    'lon': -3.7010888,
#    'tags': {'addr:city': 'Madrid',
#     'addr:housenumber': '3',
#     'addr:postcode': '28004',
#     'addr:street': 'Calle de San Joaquín',
#     'amenity': 'cafe',
#     'email': 'librosyvinos@tiposinfames.com',
#     'name': 'Tipos Infames',
#     'phone': '+34 915 228 939',
#     'shop': 'books',
#     'website': 'https://www.tiposinfames.com/',
#     'wheelchair': 'no'}},
#   {'type': 'node',
#    'id': 2777306948,
#    'lat': 40.4243517,
#    'lon': -3.7018731,
#    'tags': {'addr:city': 'Madrid',
#     'addr:housenumber': '16',
#     'addr:postcode': '28004',
#     'addr:street': 'Calle de San Joaquín',
#     'amenity': 'cafe',
#     'cuisine': 'sandwich',
#     'name': 'Naif',
#     'outdoor_seating': 'yes',
#     'toilets': 'customers',
#     'toilets:wheelchair': 'yes'}},
#   {'type': 'node',
#    'id': 2779332355,
#    'lat': 40.42732,
#    'lon': -3.6737652,
#    'tags': {'addr:city': 'Madrid',
#     'addr:housenumber': '87A',
#     'addr:postcode': '28006',
#     'addr:street': 'Calle de Ayala',
#     'amenity': 'cafe',
#     'name': 'Urban Coffee',
#     'website': 'http://loungecoffee.com/urban/ubicacion.html'}},
#   {'type': 'node',
#    'id': 2802274511,
#    'lat': 40.4389491,
#    'lon': -3.654095,
#    'tags': {'amenity': 'cafe', 'name': "Pimar's"}},
#   {'type': 'node',
#    'id': 2836112493,
#    'lat': 40.4352121,
#    'lon': -3.7126864,
#    'tags': {'addr:city': 'Madrid',
#     'addr:housenumber': '61',
#     'addr:postcode': '28015',
#     'addr:street': 'Calle de Fernández de los Ríos',
#     'amenity': 'cafe',
#     'cuisine': 'coffee_shop',
#     'internet_access': 'wlan',
#     'name': 'The Little Big cafe',
#     'opening_hours': 'Mo-Fr 09:00-20:00; Sa-Su 10:00-19:00',
#     'smoking': 'no',
#     'website': 'https://www.thelittlebigcafe.com/',
#     'wheelchair': 'yes'}},
#   {'type': 'node',
#    'id': 2864197143,
#    'lat': 40.4570634,
#    'lon': -3.6991202,
#    'tags': {'amenity': 'cafe', 'name': 'Bar La Carreta'}},
#   {'type': 'node',
#    'id': 2867491074,
#    'lat': 40.4470286,
#    'lon': -3.7033332,
#    'tags': {'amenity': 'cafe', 'name': 'Nu Rielle', 'wheelchair': 'no'}},
#   {'type': 'node',
#    'id': 2867491099,
#    'lat': 40.4494622,
#    'lon': -3.7033876,
#    'tags': {'amenity': 'cafe', 'name': 'Museo del Jamón 2'}},
#   {'type': 'node',
#    'id': 2868679684,
#    'lat': 40.4505421,
#    'lon': -3.7032293,
#    'tags': {'amenity': 'cafe', 'name': 'Chloe Lan', 'wheelchair': 'yes'}},
#   {'type': 'node',
#    'id': 2868679693,
#    'lat': 40.4522589,
#    'lon': -3.7033798,
#    'tags': {'amenity': 'cafe',
#     'cuisine': 'coffee_shop',
#     'name': 'La Castiza'}},
#   {'type': 'node',
#    'id': 2868776230,
#    'lat': 40.4577985,
#    'lon': -3.7116749,
#    'tags': {'amenity': 'cafe',
#     'diet:halal': 'no',
#     'name': 'La Mina',
#     'opening_hours': 'Su-Th 06:00-02:00; Fr,Sa 06:00-02:30',
#     'payment:credit_cards': 'yes',
#     'payment:debit_cards': 'yes',
#     'wheelchair': 'limited'}},
#   {'type': 'node',
#    'id': 2868794479,
#    'lat': 40.456955,
#    'lon': -3.7086386,
#    'tags': {'amenity': 'cafe',
#     'check_date:opening_hours': '2022-11-27',
#     'diet:halal': 'no',
#     'name': 'Cafetería La Villa',
#     'opening_hours': 'Mo-Su 08:00-24:00; Fr,Sa 08:00-00:30',
#     'payment:credit_cards': 'yes',
#     'payment:debit_cards': 'yes',
#     'wheelchair': 'yes'}},
#   {'type': 'node',
#    'id': 2868810917,
#    'lat': 40.4567878,
#    'lon': -3.7079526,
#    'tags': {'amenity': 'cafe',
#     'name': 'La Muralla de Ávila',
#     'phone': '+34914591036'}},
#   {'type': 'node',
#    'id': 2870489592,
#    'lat': 40.4568773,
#    'lon': -3.7064436,
#    'tags': {'amenity': 'cafe', 'name': 'Cafetería Fuente Verde'}},
#   {'type': 'node',
#    'id': 2870522339,
#    'lat': 40.4595013,
#    'lon': -3.7074201,
#    'tags': {'amenity': 'cafe',
#     'check_date': '2025-07-04',
#     'name': 'Cafetería De Película',
#     'old_name': 'Bodegas Ergueta'}},
#   {'type': 'node',
#    'id': 2870522340,
#    'lat': 40.4588861,
#    'lon': -3.7047898,
#    'tags': {'amenity': 'cafe', 'name': 'Bar La Torre'}},
#   {'type': 'node',
#    'id': 2870522363,
#    'lat': 40.4585305,
#    'lon': -3.7066507,
#    'tags': {'amenity': 'cafe',
#     'check_date': '2025-07-04',
#     'name': 'Cervecería Bar Viña Lidia'}},
#   {'type': 'node',
#    'id': 2880462327,
#    'lat': 40.4436716,
#    'lon': -3.702682,
#    'tags': {'amenity': 'cafe', 'name': 'Vanille'}},
#   {'type': 'node',
#    'id': 2883836605,
#    'lat': 40.4367282,
#    'lon': -3.7164243,
#    'tags': {'amenity': 'cafe',
#     'check_date': '2024-09-23',
#     'name': 'Mora Café',
#     'old_name': 'Don Hilarión',
#     'wheelchair': 'limited'}},
#   {'type': 'node',
#    'id': 2887253634,
#    'lat': 40.4483907,
#    'lon': -3.7039531,
#    'tags': {'amenity': 'cafe', 'name': 'Rubí'}},
#   {'type': 'node',
#    'id': 2891477464,
#    'lat': 40.4533629,
#    'lon': -3.7032217,
#    'tags': {'amenity': 'cafe', 'name': 'Cafetería Estrecho'}},
#   {'type': 'node',
#    'id': 2891559892,
#    'lat': 40.4565532,
#    'lon': -3.7072258,
#    'tags': {'amenity': 'cafe',
#     'name': 'Ganeza coffee-bread',
#     'old_name': 'El señor de la birra'}},
#   {'type': 'node',
#    'id': 2891563635,
#    'lat': 40.4574931,
#    'lon': -3.7060531,
#    'tags': {'amenity': 'cafe', 'name': 'Bar Arco Iris JJ'}},
#   {'type': 'node',
#    'id': 2912429033,
#    'lat': 40.4257339,
#    'lon': -3.7030666,
#    'tags': {'addr:city': 'Madrid',
#     'addr:housenumber': '20',
#     'addr:postcode': '28004',
#     'addr:street': 'Calle de San Vicente Ferrer',
#     'amenity': 'cafe',
#     'name': 'Estar Café',
#     'phone': '+34 914 48 60 87'}},
#   {'type': 'node',
#    'id': 2916188358,
#    'lat': 40.4467011,
#    'lon': -3.7046455,
#    'tags': {'amenity': 'cafe', 'name': 'Audrey'}},
#   {'type': 'node',
#    'id': 2916188360,
#    'lat': 40.4471284,
#    'lon': -3.705399,
#    'tags': {'amenity': 'cafe', 'name': 'Café y Té'}},
#   {'type': 'node',
#    'id': 2929357293,
#    'lat': 40.4595133,
#    'lon': -3.7002391,
#    'tags': {'addr:city': 'Madrid',
#     'addr:housenumber': '6',
#     'addr:postcode': '28039',
#     'addr:street': 'Calle de Tablada',
#     'amenity': 'cafe',
#     'name': 'Cytrus'}},
#   {'type': 'node',
#    'id': 2929890142,
#    'lat': 40.4597099,
#    'lon': -3.7005637,
#    'tags': {'addr:city': 'Madrid',
#     'addr:housenumber': '12',
#     'addr:postcode': '28039',
#     'addr:street': 'Calle de Tablada',
#     'amenity': 'cafe',
#     'name': 'Pinoy Spanish Bar'}},
#   {'type': 'node',
#    'id': 2942276116,
#    'lat': 40.4376633,
#    'lon': -3.6868614,
#    'tags': {'addr:city': 'Madrid',
#     'addr:housenumber': '18',
#     'addr:postcode': '28006',
#     'addr:street': 'Calle de María de Molina',
#     'amenity': 'cafe',
#     'check_date:currency:XBT': '2024-09-10',
#     'currency:XBT': 'yes',
#     'name': 'Do Eat!',
#     'payment:lightning': 'yes',
#     'phone': '+34 911 866 600',
#     'website': 'https://doeat.es/',
#     'yelp': 'http://www.yelp.com/biz/do-eat-madrid-2'}},
#   {'type': 'node',
#    'id': 2947786417,
#    'lat': 40.4572389,
#    'lon': -3.7096674,
#    'tags': {'addr:city': 'Madrid',
#     'addr:housenumber': '76',
#     'addr:postcode': '28039',
#     'addr:street': 'Calle de Francos Rodríguez',
#     'amenity': 'cafe',
#     'name': 'Bar Gema',
#     'opening_hours': 'Mo-Su 07:00-24:00'}},
#   {'type': 'node',
#    'id': 2955163356,
#    'lat': 40.4650433,
#    'lon': -3.7102021,
#    'tags': {'amenity': 'cafe', 'name': 'Bar El Paso'}},
#   {'type': 'node',
#    'id': 2972891894,
#    'lat': 40.443185,
#    'lon': -3.7042681,
#    'tags': {'amenity': 'cafe', 'name': 'Sirius Café'}},
#   {'type': 'node',
#    'id': 2972891925,
#    'lat': 40.4446265,
#    'lon': -3.7038288,
#    'tags': {'amenity': 'cafe', 'name': 'Café Racer'}},
#   {'type': 'node',
#    'id': 2972941198,
#    'lat': 40.4351737,
#    'lon': -3.7045359,
#    'tags': {'amenity': 'cafe', 'name': 'Cafetería Isabel'}},
#   {'type': 'node',
#    'id': 2973043610,
#    'lat': 40.4229435,
#    'lon': -3.7112768,
#    'tags': {'air_conditioning': 'yes',
#     'amenity': 'cafe',
#     'atm': 'yes',
#     'check_date': '2025-01-08',
#     'check_date:opening_hours': '2024-04-06',
#     'check_date:smoking': '2025-01-08',
#     'indoor_seating': 'yes',
#     'name': 'faborit',
#     'old_name': 'Banco Sabadell',
#     'opening_hours:signed': 'no',
#     'outdoor_seating': 'no',
#     'smoking': 'no',
#     'wheelchair': 'limited'}},
#   {'type': 'node',
#    'id': 3007302445,
#    'lat': 40.4226307,
#    'lon': -3.7093098,
#    'tags': {'addr:city': 'Madrid',
#     'addr:housenumber': '70',
#     'addr:postcode': '28013',
#     'addr:street': 'Gran Vía',
#     'amenity': 'cafe',
#     'name': 'Pause',
#     'old_name': 'Café & Té',
#     'wheelchair': 'no'}},
#   {'type': 'node',
#    'id': 3050347080,
#    'lat': 40.4279425,
#    'lon': -3.7020701,
#    'tags': {'addr:city': 'Madrid',
#     'addr:housenumber': '101',
#     'addr:street': 'Calle de Fuencarral',
#     'amenity': 'cafe',
#     'brand': 'Starbucks',
#     'brand:wikidata': 'Q37158',
#     'brand:wikipedia': 'en:Starbucks',
#     'cuisine': 'coffee_shop',
#     'name': 'Starbucks',
#     'official_name': 'Starbucks Coffee',
#     'operator': 'Starbucks',
#     'takeaway': 'yes',
#     'wheelchair': 'limited',
#     'wheelchair:description': 'Aseo adaptado, pasillos estrechos.'}},
#   {'type': 'node',
#    'id': 3128165594,
#    'lat': 40.4551863,
#    'lon': -3.7028679,
#    'tags': {'addr:housenumber': '203',
#     'addr:street': 'Calle de Bravo Murillo',
#     'amenity': 'cafe',
#     'name': 'Audrey Brunch&Coffee'}},
#   {'type': 'node',
#    'id': 3136812042,
#    'lat': 40.441285,
#    'lon': -3.7149836,
#    'tags': {'amenity': 'cafe', 'name': 'Chocolatería Cafetería'}},
#   {'type': 'node',
#    'id': 3136816581,
#    'lat': 40.4330328,
#    'lon': -3.7169568,
#    'tags': {'amenity': 'cafe', 'name': 'Bar Rosado'}},
#   {'type': 'node',
#    'id': 3137147955,
#    'lat': 40.4264572,
#    'lon': -3.7056172,
#    'tags': {'addr:housenumber': '47',
#     'addr:street': 'Calle de la Palma',
#     'amenity': 'cafe',
#     'check_date': '2023-10-03',
#     'name': 'Gosto',
#     'old_name': 'Más Mastropiero',
#     'wheelchair': 'no'}},
#   {'type': 'node',
#    'id': 3161160129,
#    'lat': 40.460905,
#    'lon': -3.6964197,
#    'tags': {'amenity': 'cafe', 'name': 'Mediterráneo'}},
#   {'type': 'node',
#    'id': 3170766310,
#    'lat': 40.4382443,
#    'lon': -3.6924977,
#    'tags': {'addr:housenumber': '59',
#     'addr:postcode': '28003',
#     'addr:street': 'Calle José Abascal',
#     'amenity': 'cafe',
#     'brand': 'Santagloria',
#     'brand:wikidata': 'Q54606497',
#     'name': 'Santagloria',
#     'outdoor_seating': 'no',
#     'shop': 'bakery',
#     'source': 'local knowledge',
#     'website': 'https://www.santagloria.com/'}},
#   {'type': 'node',
#    'id': 3181391412,
#    'lat': 40.433945,
#    'lon': -3.7046638,
#    'tags': {'addr:city': 'Madrid',
#     'addr:housenumber': '6',
#     'addr:postcode': '28015',
#     'addr:street': 'Glorieta de Quevedo',
#     'amenity': 'cafe',
#     'name': 'La Francerie',
#     'old_name': 'Farmacia - Glorieta Quevedo 6',
#     'website': 'https://lafrancerie.es/'}},
#   {'type': 'node',
#    'id': 3196261068,
#    'lat': 40.446846,
#    'lon': -3.7125713,
#    'tags': {'amenity': 'cafe', 'name': 'Cafetería'}},
#   {'type': 'node',
#    'id': 3202125015,
#    'lat': 40.431653,
#    'lon': -3.6505532,
#    'tags': {'amenity': 'cafe',
#     'name': 'Cervecería A´Conchiña',
#     'phone': '+34 913262619',
#     'website': 'https://www.cerveceriaconchiña.es/',
#     'wheelchair': 'no'}},
#   {'type': 'node',
#    'id': 3206699865,
#    'lat': 40.4351679,
#    'lon': -3.6643766,
#    'tags': {'addr:city': 'Madrid',
#     'addr:housenumber': '68',
#     'addr:postcode': '28028',
#     'addr:street': 'Calle de Martínez Izquierdo',
#     'amenity': 'cafe',
#     'name': 'Cafetería La Plancha'}},
#   {'type': 'node',
#    'id': 3208755399,
#    'lat': 40.4646193,
#    'lon': -3.6951606,
#    'tags': {'amenity': 'cafe', 'name': 'Bar Pascual'}},
#   {'type': 'node',
#    'id': 3208755402,
#    'lat': 40.4664316,
#    'lon': -3.6962734,
#    'tags': {'amenity': 'cafe', 'name': 'Café Punto y Coma'}},
#   {'type': 'node',
#    'id': 3208755427,
#    'lat': 40.4670665,
#    'lon': -3.6957053,
#    'tags': {'amenity': 'cafe'}},
#   {'type': 'node',
#    'id': 3212683931,
#    'lat': 40.4304201,
#    'lon': -3.6824967,
#    'tags': {'addr:city': 'Madrid',
#     'addr:housenumber': '29',
#     'addr:postcode': '28006',
#     'addr:street': 'Calle de José Ortega y Gasset',
#     'amenity': 'cafe',
#     'brand': 'Starbucks',
#     'brand:wikidata': 'Q37158',
#     'brand:wikipedia': 'en:Starbucks',
#     'contact:website': 'http://www.starbucks.es',
#     'cuisine': 'coffee_shop',
#     'name': 'Starbucks',
#     'official_name': 'Starbucks Coffee',
#     'takeaway': 'yes'}},
#   {'type': 'node',
#    'id': 3234734470,
#    'lat': 40.4444862,
#    'lon': -3.6974065,
#    'tags': {'addr:housenumber': '93',
#     'addr:postcode': '28003',
#     'addr:street': 'Calle de Alonso Cano',
#     'amenity': 'cafe',
#     'name': 'La Posada de Alonso Cano',
#     'phone': '+34 91 447 1586'}},
#   {'type': 'node',
#    'id': 3242331191,
#    'lat': 40.4264913,
#    'lon': -3.7059638,
#    'tags': {'addr:city': 'Madrid',
#     'addr:housenumber': '49',
#     'addr:postcode': '28004',
#     'addr:street': 'Calle de la Palma',
#     'amenity': 'cafe',
#     'check_date': '2023-10-03',
#     'cost:coffee': '$1.80',
#     'cuisine': 'coffee_shop',
#     'email': 'info@tomacafe.es',
#     'name': 'Toma Café',
#     'opening_hours': 'Mo-Fr 08:00-20:00; Sa,Su 10:00-20:00',
#     'phone': '+34 917 049 344',
#     'website': 'http://www.tomacafe.es/',
#     'wheelchair': 'no'}},
#   {'type': 'node',
#    'id': 3265599908,
#    'lat': 40.4382907,
#    'lon': -3.6729734,
#    'tags': {'amenity': 'cafe', 'name': 'El Panecillo', 'shop': 'bakery'}},
#   {'type': 'node',
#    'id': 3269546367,
#    'lat': 40.4369321,
#    'lon': -3.6871822,
#    'tags': {'addr:housenumber': '10',
#     'addr:postcode': '28006',
#     'addr:street': 'Calle de López de Hoyos',
#     'amenity': 'cafe',
#     'name': 'Panela&Co',
#     'phone': '+34 915636069'}},
#   {'type': 'node',
#    'id': 3269780307,
#    'lat': 40.4260347,
#    'lon': -3.6707123,
#    'tags': {'amenity': 'cafe', 'name': 'El Albero'}},
#   {'type': 'node',
#    'id': 3294436873,
#    'lat': 40.4345404,
#    'lon': -3.6456674,
#    'tags': {'amenity': 'cafe',
#     'cuisine': 'churro;chocolate',
#     'name': 'Las Farolas'}},
#   {'type': 'node',
#    'id': 3359367683,
#    'lat': 40.42937,
#    'lon': -3.7078904,
#    'tags': {'addr:city': 'Madrid',
#     'addr:housenumber': '39',
#     'addr:postcode': '28015',
#     'addr:street': 'Calle del Acuerdo',
#     'amenity': 'cafe',
#     'disused:amenity': 'bar',
#     'name': 'Miau',
#     'old_name': "D'Alma;Belu"}},
#   {'type': 'node',
#    'id': 3371729069,
#    'lat': 40.4263982,
#    'lon': -3.7050202,
#    'tags': {'addr:city': 'Madrid',
#     'addr:housenumber': '41',
#     'addr:postcode': '28004',
#     'addr:street': 'Calle de la Palma',
#     'amenity': 'cafe',
#     'contact:instagram': 'elgorditocantina',
#     'name': 'El Gordito'}},
#   {'type': 'node',
#    'id': 3389555454,
#    'lat': 40.4244011,
#    'lon': -3.7120394,
#    'tags': {'air_conditioning': 'yes',
#     'amenity': 'cafe',
#     'cuisine': 'bubble_tea',
#     'diet:vegan': 'yes',
#     'diet:vegetarian': 'yes',
#     'indoor_seating': 'yes',
#     'name': 'T8',
#     'outdoor_seating': 'no',
#     'payment:credit_cards': 'yes',
#     'payment:debit_cards': 'yes',
#     'smoking': 'no',
#     'wheelchair': 'yes'}},
#   {'type': 'node',
#    'id': 3426617375,
#    'lat': 40.4221948,
#    'lon': -3.6923421,
#    'tags': {'addr:housenumber': '21',
#     'addr:street': 'Paseo de Recoletos',
#     'amenity': 'cafe',
#     'check_date': '2024-09-04',
#     'name': 'Gran Café Gijón',
#     'outdoor_seating': 'yes',
#     'phone': '+34 915 215 425',
#     'website': 'https://cafegijon.com/',
#     'wheelchair': 'no',
#     'wikidata': 'Q1025608',
#     'wikipedia': 'es:Café Gijón'}},
#   {'type': 'node',
#    'id': 3426732122,
#    'lat': 40.4351477,
#    'lon': -3.6983923,
#    'tags': {'amenity': 'cafe', 'name': 'Jamaica'}},
#   {'type': 'node',
#    'id': 3426800312,
#    'lat': 40.4232935,
#    'lon': -3.6940419,
#    'tags': {'addr:city': 'Madrid',
#     'addr:housenumber': '12',
#     'addr:postcode': '28004',
#     'addr:street': 'Calle del Conde de Xiquena',
#     'amenity': 'cafe',
#     'cuisine': 'coffee_shop',
#     'name': 'Altered'}},
#   {'type': 'node',
#    'id': 3426834939,
#    'lat': 40.439386,
#    'lon': -3.7004446,
#    'tags': {'amenity': 'cafe', 'name': 'Classic Café Bar'}},
#   {'type': 'node',
#    'id': 3426834966,
#    'lat': 40.4553536,
#    'lon': -3.7033222,
#    'tags': {'amenity': 'cafe', 'name': 'La parrilla Igorota'}},
#   {'type': 'node',
#    'id': 3428475667,
#    'lat': 40.4311209,
#    'lon': -3.6972714,
#    'tags': {'addr:city': 'Madrid',
#     'addr:housenumber': '29',
#     'addr:postcode': '28010',
#     'addr:street': 'Calle de Santa Engracia',
#     'amenity': 'cafe',
#     'name': 'Café Bar Rocamar'}},
#   {'type': 'node',
#    'id': 3428475683,
#    'lat': 40.4370871,
#    'lon': -3.6998872,
#    'tags': {'addr:city': 'Madrid',
#     'addr:housenumber': '103',
#     'addr:postcode': '28010',
#     'addr:street': 'Calle de Santa Engracia',
#     'amenity': 'cafe',
#     'check_date': '2025-03-27',
#     'cuisine': 'portuguese;seafood;spanish;regional',
#     'diet:vegetarian': 'no',
#     'email': 'taberna@almacheli.com',
#     'internet_access': 'wlan',
#     'name': 'AlmaCheli Hecho A Mano',
#     'opening_hours': 'Mo-Su 18:00-02:00',
#     'phone': '+34915913630',
#     'wheelchair': 'limited'}},
#   {'type': 'node',
#    'id': 3428476975,
#    'lat': 40.4336757,
#    'lon': -3.6983908,
#    'tags': {'amenity': 'cafe', 'name': 'Pain Bistro', 'wheelchair': 'yes'}},
#   {'type': 'node',
#    'id': 3459875697,
#    'lat': 40.4581157,
#    'lon': -3.696974,
#    'tags': {'amenity': 'cafe', 'name': 'Bar Minuto'}},
#   {'type': 'node',
#    'id': 3459875698,
#    'lat': 40.4591513,
#    'lon': -3.696054,
#    'tags': {'amenity': 'cafe', 'name': 'Cafetería Medranda'}},
#   {'type': 'node',
#    'id': 3461921708,
#    'lat': 40.4247482,
#    'lon': -3.7008221,
#    'tags': {'addr:city': 'Madrid',
#     'addr:housenumber': '71',
#     'addr:postcode': '28004',
#     'addr:street': 'Calle de Fuencarral',
#     'amenity': 'cafe',
#     'name': 'Rocablanca',
#     'outdoor_seating': 'no',
#     'wheelchair': 'no'}},
#   {'type': 'node',
#    'id': 3461932854,
#    'lat': 40.4261719,
#    'lon': -3.7113935,
#    'tags': {'addr:city': 'Madrid',
#     'addr:housenumber': '5',
#     'addr:postcode': '28015',
#     'addr:street': 'Calle del Conde Duque',
#     'amenity': 'cafe',
#     'check_date': '2023-09-26',
#     'indoor_seating': 'yes',
#     'name': 'Siniestro',
#     'old_name': 'Don Diego',
#     'old_name_1': 'Condominium',
#     'outdoor_seating': 'no',
#     'wheelchair': 'no'}},
#   {'type': 'node',
#    'id': 3467969369,
#    'lat': 40.450462,
#    'lon': -3.7177781,
#    'tags': {'amenity': 'cafe', 'name': 'Facultad de Educación'}},
#   {'type': 'node',
#    'id': 3469038580,
#    'lat': 40.4476232,
#    'lon': -3.7170921,
#    'tags': {'amenity': 'cafe', 'name': 'Glacé'}},
#   {'type': 'node',
#    'id': 3471761960,
#    'lat': 40.4269219,
#    'lon': -3.7017004,
#    'tags': {'addr:city': 'Madrid',
#     'addr:housenumber': '93',
#     'addr:postcode': '28004',
#     'addr:street': 'Calle de Fuencarral',
#     'amenity': 'cafe',
#     'bar': 'yes',
#     'name': 'Caffé del Arte',
#     'opening_hours': 'Mo-Su,PH 08:00-02:00',
#     'operator': 'Ambarlis S.L.',
#     'ref:vatin': 'ESB81673725',
#     'toilets': 'yes',
#     'toilets:wheelchair': 'no',
#     'website:menu': 'https://smartmenu.agorapos.com/?id=ct6viosq#/',
#     'wheelchair': 'limited',
#     'wheelchair:description': 'Acceso bueno, no tiene aseo adaptado.'}},
#   {'type': 'node',
#    'id': 3472054306,
#    'lat': 40.4301567,
#    'lon': -3.7002708,
#    'tags': {'amenity': 'cafe',
#     'check_date': '2023-04-02',
#     'name': 'La Bohemia'}},
#   {'type': 'node',
#    'id': 3472111966,
#    'lat': 40.4364209,
#    'lon': -3.7155435,
#    'tags': {'amenity': 'cafe'}},
# ...
#     'outdoor_seating': 'no'}},
#   {'type': 'node',
#    'id': 12128565720,
#    'lat': 40.4287721,
#    'lon': -3.6751845,
#    'tags': {'addr:city': 'Madrid',
#     'addr:housenumber': '36',
#     'addr:postcode': '28006',
#     'addr:street': 'Calle del Conde de Peñalver',
#     'amenity': 'cafe',
#     'internet_access': 'wlan',
#     'internet_access:fee': 'no',
#     'name': 'Nata Artesanos',
#     'smoking': 'no'}},
#   {'type': 'node',
#    'id': 12147737601,
#    'lat': 40.4248823,
#    'lon': -3.6853284,
#    'tags': {'addr:housenumber': '42',
#     'addr:street': 'Calle de Lagasca',
#     'amenity': 'cafe',
#     'name': 'Hola Coffee',
#     'opening_hours': 'Mo-Fr 08:00-20:00; Sa-Su 09:00-20:00'}},
#   {'type': 'node',
#    'id': 12150041004,
#    'lat': 40.4631738,
#    'lon': -3.6914604,
#    'tags': {'amenity': 'cafe', 'name': 'Espresso Americano'}},
#   {'type': 'node',
#    'id': 12150047340,
#    'lat': 40.4622071,
#    'lon': -3.6915316,
#    'tags': {'amenity': 'cafe', 'name': 'Emka'}},
#   {'type': 'node',
#    'id': 12151268313,
#    'lat': 40.4364248,
#    'lon': -3.6907879,
#    'tags': {'addr:housenumber': '94',
#     'addr:street': 'Calle de García de Paredes',
#     'amenity': 'cafe',
#     'check_date': '2024-09-02',
#     'name': 'Donde Michel',
#     'wheelchair': 'limited'}},
#   {'type': 'node',
#    'id': 12153404469,
#    'lat': 40.4373766,
#    'lon': -3.7145528,
#    'tags': {'addr:housenumber': '41',
#     'addr:street': 'Calle de Joaquín María López',
#     'amenity': 'cafe',
#     'check_date': '2024-09-03',
#     'name': 'Chiripa',
#     'outdoor_seating': 'yes',
#     'wheelchair': 'no'}},
#   {'type': 'node',
#    'id': 12192547416,
#    'lat': 40.4287621,
#    'lon': -3.6750046,
#    'tags': {'amenity': 'cafe', 'name': 'Luspar'}},
#   {'type': 'node',
#    'id': 12197348001,
#    'lat': 40.4557835,
#    'lon': -3.6768661,
#    'tags': {'amenity': 'cafe',
#     'name': 'east crema coffee',
#     'opening_hours': 'Mo-Fr 08:00-20:00; Sa-Su 09:00-20:00',
#     'website': 'https://eastcrema.com/'}},
#   {'type': 'node',
#    'id': 12204136137,
#    'lat': 40.454907,
#    'lon': -3.6470256,
#    'tags': {'amenity': 'cafe',
#     'indoor_seating': 'yes',
#     'name': 'DeTaZa',
#     'outdoor_seating': 'yes'}},
#   {'type': 'node',
#    'id': 12204667764,
#    'lat': 40.4378061,
#    'lon': -3.7101494,
#    'tags': {'addr:housenumber': '75',
#     'addr:street': 'Calle de Galileo',
#     'amenity': 'cafe',
#     'check_date': '2024-09-27',
#     'name': 'Tosty',
#     'outdoor_seating': 'yes',
#     'wheelchair': 'limited'}},
#   {'type': 'node',
#    'id': 12204678874,
#    'lat': 40.4583398,
#    'lon': -3.6449659,
#    'tags': {'amenity': 'cafe', 'name': 'Cafetería Orgaz'}},
#   {'type': 'node',
#    'id': 12218205071,
#    'lat': 40.4366661,
#    'lon': -3.6922563,
#    'tags': {'addr:housenumber': '63',
#     'addr:street': 'Calle de García de Paredes',
#     'amenity': 'cafe',
#     'check_date': '2024-10-03',
#     'name': 'Quero',
#     'wheelchair': 'no'}},
#   {'type': 'node',
#    'id': 12231518334,
#    'lat': 40.4383345,
#    'lon': -3.7084485,
#    'tags': {'addr:housenumber': '77',
#     'addr:street': 'Calle de Vallehermoso',
#     'amenity': 'cafe',
#     'check_date': '2024-10-07',
#     'name': 'Los Gallego',
#     'outdoor_seating': 'yes',
#     'wheelchair': 'limited'}},
#   {'type': 'node',
#    'id': 12260741873,
#    'lat': 40.4366689,
#    'lon': -3.6435252,
#    'tags': {'amenity': 'cafe', 'name': 'Lexana'}},
#   {'type': 'node',
#    'id': 12270765326,
#    'lat': 40.4375899,
#    'lon': -3.6850623,
#    'tags': {'addr:housenumber': '24',
#     'addr:postcode': '28006',
#     'addr:street': 'Calle de María de Molina',
#     'amenity': 'cafe',
#     'contact:facebook': 'religioncoffee',
#     'contact:instagram': 'religioncoffee_',
#     'cuisine': 'breakfast;coffee_shop;mediterranean',
#     'email': 'info@religioncoffee.es',
#     'name': 'Religion - Specialty coffee',
#     'opening_hours': 'Mo-Fr 08:30-19:00; Sa-Su 09:00-18:00',
#     'phone': '910698221',
#     'website': 'http://www.religioncoffee.es/',
#     'website:menu': 'https://goo.su/vjwC'}},
#   {'type': 'node',
#    'id': 12282407976,
#    'lat': 40.4552286,
#    'lon': -3.6939508,
#    'tags': {'amenity': 'cafe',
#     'brand': 'Santagloria',
#     'brand:wikidata': 'Q54606497',
#     'name': 'Santagloria',
#     'shop': 'bakery'}},
#   {'type': 'node',
#    'id': 12337611000,
#    'lat': 40.4719695,
#    'lon': -3.6810751,
#    'tags': {'addr:floor': '0',
#     'amenity': 'cafe',
#     'check_date': '2024-12-05',
#     'internet_access': 'no',
#     'level': '1',
#     'name': 'Coffee Bakery',
#     'payment:cash': 'yes',
#     'payment:credit_cards': 'yes',
#     'payment:debit_cards': 'yes',
#     'source': 'survey',
#     'wheelchair': 'yes'}},
#   {'type': 'node',
#    'id': 12358856174,
#    'lat': 40.4719148,
#    'lon': -3.6821001,
#    'tags': {'addr:floor': '0',
#     'amenity': 'cafe',
#     'check_date': '2024-11-20',
#     'level': '1',
#     'name': 'Navelgas',
#     'outdoor_seating': 'no',
#     'source': 'survey',
#     'wheelchair': 'yes'}},
#   {'type': 'node',
#    'id': 12373777400,
#    'lat': 40.4501243,
#    'lon': -3.6505064,
#    'tags': {'amenity': 'cafe',
#     'level': '1',
#     'name': 'Taruffi',
#     'opening_hours': 'Mo-Su 09:00-22:00',
#     'website': 'https://www.taruffi.com/'}},
#   {'type': 'node',
#    'id': 12401772628,
#    'lat': 40.4423316,
#    'lon': -3.6408916,
#    'tags': {'amenity': 'cafe',
#     'cuisine': 'coffee_shop',
#     'indoor_seating': 'yes',
#     'name': "Junior's",
#     'outdoor_seating': 'yes'}},
#   {'type': 'node',
#    'id': 12433834360,
#    'lat': 40.4523274,
#    'lon': -3.6985211,
#    'tags': {'amenity': 'cafe'}},
#   {'type': 'node',
#    'id': 12462989865,
#    'lat': 40.4691085,
#    'lon': -3.6431502,
#    'tags': {'amenity': 'cafe', 'name': 'La Ruta del Café'}},
#   {'type': 'node',
#    'id': 12462993522,
#    'lat': 40.4689999,
#    'lon': -3.6435998,
#    'tags': {'amenity': 'cafe', 'name': "Miranda's"}},
#   {'type': 'node',
#    'id': 12463013424,
#    'lat': 40.4230155,
#    'lon': -3.7229213,
#    'tags': {'amenity': 'cafe', 'name': 'Kausa Madrid'}},
#   {'type': 'node',
#    'id': 12480940607,
#    'lat': 40.4374972,
#    'lon': -3.6381161,
#    'tags': {'amenity': 'cafe',
#     'cuisine': 'coffee_shop',
#     'name': 'Chocolate con Churros'}},
#   {'type': 'node',
#    'id': 12480941328,
#    'lat': 40.4276463,
#    'lon': -3.6689504,
#    'tags': {'amenity': 'cafe',
#     'cuisine': 'coffee_shop',
#     'name': 'Chocolate con Churros',
#     'wheelchair': 'limited'}},
#   {'type': 'node',
#    'id': 12480941329,
#    'lat': 40.4489409,
#    'lon': -3.6094696,
#    'tags': {'amenity': 'cafe',
#     'cuisine': 'coffee_shop',
#     'name': 'Chocolate con Churros'}},
#   {'type': 'node',
#    'id': 12627911757,
#    'lat': 40.423818,
#    'lon': -3.6769351,
#    'tags': {'addr:housenumber': '4',
#     'addr:street': 'Avenida Felipe II',
#     'amenity': 'cafe',
#     'check_date': '2025-02-26',
#     'cuisine': 'bubble_tea',
#     'level': '0',
#     'name': 'T8 tea bar',
#     'payment:cash': 'yes',
#     'payment:credit_cards': 'yes',
#     'payment:debit_cards': 'yes'}},
#   {'type': 'node',
#    'id': 12627911762,
#    'lat': 40.425434,
#    'lon': -3.713198,
#    'tags': {'addr:housenumber': '4',
#     'addr:street': 'Calle de Santa María Micaela',
#     'amenity': 'cafe',
#     'check_date': '2025-02-25',
#     'cuisine': 'coffee_shop;sandwich;korean',
#     'internet_access': 'wlan',
#     'internet_access:fee': 'customers',
#     'level': '0',
#     'name': 'Doku Toku',
#     'outdoor_seating': 'yes',
#     'payment:cash': 'yes',
#     'payment:credit_cards': 'yes',
#     'payment:debit_cards': 'yes',
#     'wheelchair': 'yes'}},
#   {'type': 'node',
#    'id': 12629140147,
#    'lat': 40.4246153,
#    'lon': -3.6689597,
#    'tags': {'addr:housenumber': '143',
#     'addr:street': 'Calle de Goya',
#     'amenity': 'cafe',
#     'name': 'Panaria',
#     'phone': '644634898',
#     'takeaway': 'yes',
#     'website': 'https://panariapanaderias.es'}},
#   {'type': 'node',
#    'id': 12668675124,
#    'lat': 40.4281668,
#    'lon': -3.7041952,
#    'tags': {'amenity': 'cafe', 'name': 'Ajenjo Cafe'}},
#   {'type': 'node',
#    'id': 12681286403,
#    'lat': 40.4294675,
#    'lon': -3.6738323,
#    'tags': {'addr:city': 'Madrid',
#     'addr:postcode': '28006',
#     'addr:street': 'Calle Alcántara',
#     'amenity': 'cafe',
#     'cuisine': 'coffee_shop',
#     'name': 'Sinfonía'}},
#   {'type': 'node',
#    'id': 12681286407,
#    'lat': 40.4293822,
#    'lon': -3.6751441,
#    'tags': {'addr:city': 'Madrid',
#     'addr:housenumber': '44',
#     'addr:street': 'Calle del Conde de Peñalver',
#     'amenity': 'cafe',
#     'name': 'Taiga'}},
#   {'type': 'node',
#    'id': 12687210821,
#    'lat': 40.4360628,
#    'lon': -3.6984488,
#    'tags': {'addr:city': 'Madrid',
#     'addr:housenumber': '6',
#     'addr:postcode': '28010',
#     'addr:street': 'Calle Ponce de León',
#     'amenity': 'cafe',
#     'contact:instagram': 'https://www.instagram.com/beikbeik.mad',
#     'cuisine': 'breakfast',
#     'email': 'beikbeikmad@gmail.com',
#     'fast_food': 'cafeteria',
#     'name': 'Beik Beik',
#     'opening_hours': 'Tu-Th 09:00-19:00; Fr 09:00-15:00; Sa-Su 09:30-15:00; Mo off; PH off',
#     'outdoor_seating': 'no',
#     'phone': '+34 639 914 387'}},
#   {'type': 'node',
#    'id': 12688373845,
#    'lat': 40.4261779,
#    'lon': -3.6792458,
#    'tags': {'addr:housenumber': '67',
#     'addr:street': 'Calle de Hermosilla',
#     'amenity': 'cafe',
#     'diet:gluten_free': 'yes',
#     'name': 'Le Sweet',
#     'opening_hours': 'Mo-Sa 12:00-19:30',
#     'phone': '664312750',
#     'takeaway': 'yes',
#     'website': 'https://lesweet.es/'}},
#   {'type': 'node',
#    'id': 12691393341,
#    'lat': 40.4390271,
#    'lon': -3.6291333,
#    'tags': {'amenity': 'cafe', 'name': 'Fanático'}},
#   {'type': 'node',
#    'id': 12692718401,
#    'lat': 40.4322883,
#    'lon': -3.7032303,
#    'tags': {'addr:housenumber': '3',
#     'addr:postcode': '28010',
#     'addr:street': 'Calle de Gonzalo de Córdoba',
#     'amenity': 'cafe',
#     'contact:instagram': 'dosiscafe',
#     'cuisine': 'breakfast;coffee_shop',
#     'internet_access': 'wlan',
#     'name': 'Dosis Cafe',
#     'website': 'https://dosiscafe.es/'}},
#   {'type': 'node',
#    'id': 12778278009,
#    'lat': 40.4392562,
#    'lon': -3.7066155,
#    'tags': {'amenity': 'cafe',
#     'check_date': '2025-04-23',
#     'name': 'Roan',
#     'outdoor_seating': 'yes',
#     'wheelchair': 'no'}},
#   {'type': 'node',
#    'id': 12809158536,
#    'lat': 40.4333349,
#    'lon': -3.7007443,
#    'tags': {'amenity': 'cafe',
#     'cuisine': 'coffee_shop',
#     'name': 'La casa Amande',
#     'survey:date': '2025-05-04'}},
#   {'type': 'node',
#    'id': 12809645117,
#    'lat': 40.4231582,
#    'lon': -3.707614,
#    'tags': {'amenity': 'cafe', 'name': 'Vivari', 'survey:date': '2025-05-04'}},
#   {'type': 'node',
#    'id': 12825294142,
#    'lat': 40.4323666,
#    'lon': -3.7172989,
#    'tags': {'amenity': 'cafe',
#     'brand': 'Santagloria',
#     'brand:wikidata': 'Q54606497',
#     'name': 'Santagloria',
#     'shop': 'bakery',
#     'survey:date': '2025-05-10'}},
#   {'type': 'node',
#    'id': 12844750069,
#    'lat': 40.4376458,
#    'lon': -3.6508643,
#    'tags': {'amenity': 'cafe', 'name': 'La Panera Rosa'}},
#   {'type': 'node',
#    'id': 12880638608,
#    'lat': 40.4361303,
#    'lon': -3.7049327,
#    'tags': {'addr:housenumber': '4',
#     'addr:street': 'Calle de Donoso Cortés',
#     'amenity': 'cafe',
#     'check_date': '2025-06-02',
#     'cuisine': 'coffee_shop',
#     'name': '29|30',
#     'wheelchair': 'no'}},
#   {'type': 'node',
#    'id': 12880638615,
#    'lat': 40.4361527,
#    'lon': -3.7052455,
#    'tags': {'addr:housenumber': '8',
#     'addr:street': 'Calle de Donoso Cortés',
#     'amenity': 'cafe',
#     'check_date': '2025-06-02',
#     'cuisine': 'coffee_shop',
#     'name': 'Vanille',
#     'wheelchair': 'limited'}},
#   {'type': 'node',
#    'id': 12888834201,
#    'lat': 40.4361344,
#    'lon': -3.6931833,
#    'tags': {'amenity': 'cafe', 'name': 'Libis'}},
#   {'type': 'node',
#    'id': 12902402678,
#    'lat': 40.4235878,
#    'lon': -3.7025829,
#    'tags': {'air_conditioning': 'yes',
#     'amenity': 'cafe',
#     'check_date': '2025-06',
#     'indoor_seating': 'yes',
#     'internet_access': 'wlan',
#     'name': 'HanSo Café',
#     'outdoor_seating': 'no',
#     'toilets': 'yes'}},
#   {'type': 'node',
#    'id': 12957360578,
#    'lat': 40.4271056,
#    'lon': -3.6581608,
#    'tags': {'amenity': 'cafe', 'name': 'Cafetería Nico', 'wheelchair': 'no'}},
#   {'type': 'node',
#    'id': 12958941701,
#    'lat': 40.4395092,
#    'lon': -3.6791859,
#    'tags': {'addr:housenumber': '109',
#     'addr:street': 'Calle del Príncipe de Vergara',
#     'amenity': 'cafe',
#     'cuisine': 'coffee_shop',
#     'name': 'Mina Specialty Coffee'}},
#   {'type': 'node',
#    'id': 13007334813,
#    'lat': 40.4321445,
#    'lon': -3.7005547,
#    'tags': {'addr:city': 'Madrid',
#     'addr:housenumber': '20',
#     'addr:postcode': '28010',
#     'addr:street': 'Calle Trafalgar',
#     'amenity': 'cafe',
#     'cuisine': 'coffee_shop',
#     'name': 'Catedral Cafe Madrid',
#     'takeaway': 'yes',
#     'website': 'https://www.instagram.com/catedralcafemadrid/',
#     'website:menu': 'https://tr.ee/cN1J1QIbJ-'}},
#   {'type': 'node',
#    'id': 13017460373,
#    'lat': 40.4317996,
#    'lon': -3.7159251,
#    'tags': {'amenity': 'cafe',
#     'cuisine': 'coffee_shop',
#     'name': 'To be coffee',
#     'survey:date': '2025-07-22'}},
#   {'type': 'node',
#    'id': 13017460375,
#    'lat': 40.4318493,
#    'lon': -3.7167604,
#    'tags': {'amenity': 'cafe', 'name': 'Porto', 'survey:date': '2025-07-22'}},
#   {'type': 'node',
#    'id': 13026492102,
#    'lat': 40.4255085,
#    'lon': -3.6787415,
#    'tags': {'addr:housenumber': '15',
#     'addr:street': 'Calle del General Pardiñas',
#     'amenity': 'cafe',
#     'cuisine': 'breakfast;coffee_shop;pancake;tea',
#     'name': 'Norah Coffee & Brunch',
#     'opening_hours': 'Su-We 09:00-18:30; Th-Sa 09:00-19:00'}},
#   {'type': 'node',
#    'id': 13026515001,
#    'lat': 40.4251148,
#    'lon': -3.6790471,
#    'tags': {'addr:housenumber': '73',
#     'addr:street': 'Calle de Goya',
#     'amenity': 'cafe',
#     'name': 'Starbucks',
#     'opening_hours': 'Mo-Fr 07:30-22:00; Sa-Su 08:00-22:00'}},
#   {'type': 'node',
#    'id': 13041426802,
#    'lat': 40.4221611,
#    'lon': -3.6973358,
#    'tags': {'addr:housenumber': '37',
#     'addr:street': 'Calle de Augusto Figueroa',
#     'amenity': 'cafe',
#     'cuisine': 'coffee_shop;tea',
#     'name': 'ALFAR',
#     'opening_hours': 'Mo-Fr 08:00-19:00; Sa 09:00-19:00; Su 09:00-16:30'}},
#   {'type': 'node',
#    'id': 13057611191,
#    'lat': 40.4255698,
#    'lon': -3.6709906,
#    'tags': {'amenity': 'cafe',
#     'brand': 'Santagloria',
#     'brand:wikidata': 'Q54606497',
#     'name': 'Santagloria',
#     'shop': 'bakery',
#     'survey:date': '2025-08-08'}},
#   {'type': 'node',
#    'id': 13114656901,
#    'lat': 40.4228625,
#    'lon': -3.6890506,
#    'tags': {'amenity': 'cafe'}},
#   {'type': 'node',
#    'id': 13159603798,
#    'lat': 40.4250519,
#    'lon': -3.6979142,
#    'tags': {'addr:city': 'Madrid',
#     'addr:housenumber': '73',
#     'addr:postcode': '28004',
#     'addr:street': 'Calle de Hortaleza',
#     'amenity': 'cafe',
#     'contact:instagram': 'https://www.instagram.com/kohi.bakery',
#     'name': 'Kōhī',
#     'opening_hours': 'Mo-Su 09:00-20:00',
#     'outdoor_seating': 'no'}},
#   {'type': 'node',
#    'id': 13159799784,
#    'lat': 40.4293549,
#    'lon': -3.7076833,
#    'tags': {'amenity': 'cafe', 'name': 'Cofi.', 'survey:date': '2025-09-21'}},
#   {'type': 'node',
#    'id': 13159885443,
#    'lat': 40.424953,
#    'lon': -3.7124064,
#    'tags': {'amenity': 'cafe', 'name': 'Beher', 'survey:date': '2025-09-21'}},
#   {'type': 'node',
#    'id': 13165954328,
#    'lat': 40.4317121,
#    'lon': -3.7021939,
#    'tags': {'amenity': 'cafe', 'name': 'Naji', 'source': 'survey'}},
#   {'type': 'node',
#    'id': 13174973089,
#    'lat': 40.4225232,
#    'lon': -3.674902,
#    'tags': {'amenity': 'cafe',
#     'changing_table': 'no',
#     'diet:vegan': 'yes',
#     'diet:vegetarian': 'yes',
#     'name': 'Sau Dade',
#     'smoking': 'no',
#     'wheelchair': 'limited'}},
#   {'type': 'node',
#    'id': 13184793310,
#    'lat': 40.4227677,
#    'lon': -3.7017135,
#    'tags': {'addr:housenumber': '31',
#     'addr:street': 'Calle de Valverde',
#     'amenity': 'cafe',
#     'diet:vegan': 'only',
#     'diet:vegetarian': 'only',
#     'name': 'Fuga Madrid',
#     'opening_hours': 'Tu-Su 11:00-17:00; Mo off'}}]}

# %%
data.keys()
# Out:
# dict_keys(['version', 'generator', 'osm3s', 'elements'])

# %%
data["osm3s"]
# Out:
# {'timestamp_osm_base': '2025-10-13T14:22:30Z',
#  'copyright': 'The data included in this document is from www.openstreetmap.org. The data is made available under ODbL.'}

# %%
data.get("osm3s")
# Out:
# {'timestamp_osm_base': '2025-10-13T14:22:30Z',
#  'copyright': 'The data included in this document is from www.openstreetmap.org. The data is made available under ODbL.'}

# %%
data["osm3s"]["copyright"]
# Out:
# 'The data included in this document is from www.openstreetmap.org. The data is made available under ODbL.'

# %%
data["elements"][0]
# Out:
# {'type': 'node',
#  'id': 1613048501,
#  'lat': 40.4427781,
#  'lon': -3.6961674,
#  'tags': {'amenity': 'cafe', 'name': 'Camelia'}}

# %%
# Acceder a los valores del diccionario para guardarlos en variables para luego crear un Dataframe
dict_cafes = {"lat":[], "lon":[], "street":[], "number_street":[]}
for i in data["elements"]:
    lat = i["lat"]
    lon = i["lon"]
    street = i["tags"].get("addr:street", "Sin Calle")
    number_street = i["tags"].get("addr:housenumber", 0)

    dict_cafes["lat"].append(lat)
    dict_cafes["lon"].append(lon)
    dict_cafes["street"].append(street)
    dict_cafes["number_street"].append(number_street)

df_cafe = pd.DataFrame(dict_cafes)
df_cafe
# Out:
#            lat       lon                    street number_street
# 0    40.446378 -3.714901                 Sin Calle             0
# 1    40.442532 -3.651707                 Sin Calle             0
# 2    40.429240 -3.722419  Paseo del Pintor Rosales             0
# 3    40.437727 -3.663535                 Sin Calle             0
# 4    40.448237 -3.723829                 Sin Calle             0
# ..         ...       ...                       ...           ...
# 540  40.429355 -3.707683                 Sin Calle             0
# 541  40.424953 -3.712406                 Sin Calle             0
# 542  40.431712 -3.702194                 Sin Calle             0
# 543  40.422523 -3.674902                 Sin Calle             0
# 544  40.422768 -3.701713         Calle de Valverde            31
#
# [545 rows x 4 columns]

# %%
data["elements"][0]["tags"]["name"]
# Out:
# 'Condemar'

# %%
pd.DataFrame(data["elements"])
# Out:
#      type           id        lat       lon  \
# 0    node    150760847  40.446378 -3.714901
# 1    node    311973234  40.442532 -3.651707
# 2    node    318919783  40.429240 -3.722419
# 3    node    327565888  40.437727 -3.663535
# 4    node    410620052  40.448237 -3.723829
# ..    ...          ...        ...       ...
# 540  node  13159799784  40.429355 -3.707683
# 541  node  13159885443  40.424953 -3.712406
# 542  node  13165954328  40.431712 -3.702194
# 543  node  13174973089  40.422523 -3.674902
# 544  node  13184793310  40.422768 -3.701713
#
#                                                   tags
# 0    {'amenity': 'cafe', 'created_by': 'Potlatch 0....
# 1    {'amenity': 'cafe', 'name': 'Torres', 'name:es...
# 2    {'addr:city': 'Madrid', 'addr:postcode': '2800...
# 3    {'amenity': 'cafe', 'name': 'Cafetería Bruselas'}
# 4    {'amenity': 'cafe', 'cuisine': 'yes', 'name': ...
# ..                                                 ...
# 540  {'amenity': 'cafe', 'name': 'Cofi.', 'survey:d...
# 541  {'amenity': 'cafe', 'name': 'Beher', 'survey:d...
# 542  {'amenity': 'cafe', 'name': 'Naji', 'source': ...
# 543  {'amenity': 'cafe', 'changing_table': 'no', 'd...
# 544  {'addr:housenumber': '31', 'addr:street': 'Cal...
#
# [545 rows x 5 columns]

# %%
data
# Out:
# {'version': 0.6,
#  'generator': 'Overpass API 0.7.62.8 e802775f',
#  'osm3s': {'timestamp_osm_base': '2025-10-13T14:22:30Z',
#   'copyright': 'The data included in this document is from www.openstreetmap.org. The data is made available under ODbL.'},
#  'elements': [{'type': 'node',
#    'id': 150760847,
#    'lat': 40.4463777,
#    'lon': -3.7149013,
#    'tags': {'amenity': 'cafe',
#     'created_by': 'Potlatch 0.5d',
#     'name': 'Condemar'}},
#   {'type': 'node',
#    'id': 311973234,
#    'lat': 40.442532,
#    'lon': -3.6517071,
#    'tags': {'amenity': 'cafe', 'name': 'Torres', 'name:es': 'Torres'}},
#   {'type': 'node',
#    'id': 318919783,
#    'lat': 40.4292399,
#    'lon': -3.7224188,
#    'tags': {'addr:city': 'Madrid',
#     'addr:postcode': '28008',
#     'addr:street': 'Paseo del Pintor Rosales',
#     'amenity': 'cafe',
#     'name': 'Magadán'}},
#   {'type': 'node',
#    'id': 327565888,
#    'lat': 40.4377269,
#    'lon': -3.6635351,
#    'tags': {'amenity': 'cafe', 'name': 'Cafetería Bruselas'}},
#   {'type': 'node',
#    'id': 410620052,
#    'lat': 40.4482368,
#    'lon': -3.7238292,
#    'tags': {'amenity': 'cafe',
#     'cuisine': 'yes',
#     'name': 'Facultad de Forestales'}},
#   {'type': 'node',
#    'id': 622204562,
#    'lat': 40.4244873,
#    'lon': -3.7103465,
#    'tags': {'addr:city': 'Madrid',
#     'addr:housenumber': '7',
#     'addr:street': 'Calle de los Dos Amigos',
#     'amenity': 'cafe',
#     'contact:phone': '+34 91 542 90 19',
#     'contact:website': 'http://www.cafedosamigos.com/',
#     'name': 'Los Dos Amigos',
#     'wheelchair': 'no',
#     'wheelchair:description': 'escalón y escaleras interiores'}},
#   {'type': 'node',
#    'id': 622204563,
#    'lat': 40.4231601,
#    'lon': -3.7108488,
#    'tags': {'addr:city': 'Madrid',
#     'addr:housenumber': '73',
#     'addr:postcode': '28013',
#     'addr:street': 'Gran Vía',
#     'air_conditioning': 'yes',
#     'amenity': 'cafe',
#     'brand': 'Starbucks',
#     'brand:wikidata': 'Q37158',
#     'brand:wikipedia': 'en:Starbucks',
#     'check_date': '2024-12-10',
#     'check_date:diet:vegan': '2024-12-10',
#     'check_date:diet:vegetarian': '2024-12-10',
#     'check_date:smoking': '2024-11-24',
#     'check_date:toilets:wheelchair': '2024-12-10',
#     'cuisine': 'coffee_shop',
#     'diet:vegan': 'no',
#     'diet:vegetarian': 'yes',
#     'indoor_seating': 'yes',
#     'layer': '1',
#     'name': 'Starbucks',
#     'official_name': 'Starbucks Coffee',
#     'opening_hours': 'Mo-Su 07:30-23:00',
#     'outdoor_seating': 'yes',
#     'smoking': 'outside',
#     'takeaway': 'yes',
#     'toilets': 'yes',
#     'toilets:wheelchair': 'no',
#     'website': 'https://www.starbucks.es/',
#     'wheelchair': 'limited'}},
#   {'type': 'node',
#    'id': 623071231,
#    'lat': 40.4252249,
#    'lon': -3.7153795,
#    'tags': {'addr:city': 'Madrid',
#     'addr:housenumber': '23',
#     'addr:postcode': '28008',
#     'addr:street': 'Calle Luisa Fernanda',
#     'amenity': 'cafe',
#     'contact:phone': '+34 915594645',
#     'contact:website': 'http://www.vienacapellanes.com/',
#     'name': 'Café Viena'}},
#   {'type': 'node',
#    'id': 674492241,
#    'lat': 40.4254,
#    'lon': -3.7072729,
#    'tags': {'addr:city': 'Madrid',
#     'addr:housenumber': '58',
#     'addr:postcode': '28015',
#     'addr:street': 'Calle de San Bernardo',
#     'amenity': 'cafe',
#     'brand': 'Santagloria',
#     'brand:wikidata': 'Q54606497',
#     'check_date': '2023-09-24',
#     'check_date:opening_hours': '2022-09-05',
#     'diet:vegetarian': 'yes',
#     'name': 'Santagloria',
#     'old_name_1': 'Rodilla',
#     'old_name_2': 'Bake Bar',
#     'opening_hours:signed': 'no',
#     'outdoor_seating': 'yes',
#     'shop': 'bakery',
#     'wheelchair': 'no'}},
#   {'type': 'node',
#    'id': 750504785,
#    'lat': 40.4510028,
#    'lon': -3.6773993,
#    'tags': {'addr:city': 'Madrid',
#     'addr:housenumber': '210 (posterior)',
#     'addr:postcode': '28002',
#     'addr:street': 'Calle del Príncipe de Vergara',
#     'amenity': 'cafe',
#     'name': 'Café Universal'}},
#   {'type': 'node',
#    'id': 810259248,
#    'lat': 40.4445182,
#    'lon': -3.6668344,
#    'tags': {'amenity': 'cafe', 'name': 'Entre Jamones', 'wheelchair': 'no'}},
#   {'type': 'node',
#    'id': 989278217,
#    'lat': 40.4500696,
#    'lon': -3.6880992,
#    'tags': {'amenity': 'cafe', 'name': 'La Tertulia'}},
#   {'type': 'node',
#    'id': 993468828,
#    'lat': 40.4292978,
#    'lon': -3.7149613,
#    'tags': {'air_conditioning': 'yes',
#     'amenity': 'cafe',
#     'brand': 'Starbucks',
#     'brand:wikidata': 'Q37158',
#     'brand:wikipedia': 'en:Starbucks',
#     'cuisine': 'coffee_shop',
#     'name': 'Starbucks',
#     'official_name': 'Starbucks Coffee',
#     'opening_hours': 'Mo-Fr 07:30-22:00,08:00-22:00',
#     'smoking': 'outside',
#     'takeaway': 'yes',
#     'website': 'https://www.starbucks.co.uk/store-locator/32345-115929/princesa-40',
#     'wheelchair': 'yes'}},
#   {'type': 'node',
#    'id': 1056099074,
#    'lat': 40.4530713,
#    'lon': -3.7189142,
#    'tags': {'amenity': 'cafe', 'name': 'Cafetería Universidad Nebrija'}},
#   {'type': 'node',
#    'id': 1239289876,
#    'lat': 40.4703555,
#    'lon': -3.6325084,
#    'tags': {'amenity': 'cafe', 'cuisine': 'spanish', 'name': 'Europa 2'}},
#   {'type': 'node',
#    'id': 1288311612,
#    'lat': 40.4306465,
#    'lon': -3.7236666,
#    'tags': {'amenity': 'cafe', 'name': 'La Perla', 'source': 'survey'}},
#   {'type': 'node',
#    'id': 1316492166,
#    'lat': 40.4259892,
#    'lon': -3.6937987,
#    'tags': {'amenity': 'cafe', 'smoking': 'no', 'wheelchair': 'limited'}},
#   {'type': 'node',
#    'id': 1316546637,
#    'lat': 40.4272302,
#    'lon': -3.6952847,
#    'tags': {'addr:city': 'Madrid',
#     'addr:housenumber': '4',
#     'addr:postcode': '28004',
#     'addr:street': 'Calle de Génova',
#     'amenity': 'cafe',
#     'name': 'Viena Capellanes',
#     'phone': '+34 913192792',
#     'website': 'http://www.vienacapellanes.com/stores/lookstore.php?idioma=esp&terminal=linux&store=9'}},
#   {'type': 'node',
#    'id': 1316546690,
#    'lat': 40.4260117,
#    'lon': -3.6921003,
#    'tags': {'addr:city': 'Madrid',
#     'addr:housenumber': '27',
#     'addr:postcode': '28004',
#     'addr:street': 'Calle de Génova',
#     'amenity': 'cafe',
#     'brand': 'Starbucks',
#     'brand:wikidata': 'Q37158',
#     'brand:wikipedia': 'en:Starbucks',
#     'check_date': '2025-04-29',
#     'cuisine': 'coffee_shop',
#     'internet_access': 'wlan',
#     'internet_access:fee': 'no',
#     'name': 'Starbucks',
#     'official_name': 'Starbucks Coffee',
#     'opening_hours': '08:30-21:30',
#     'operator': 'Grupo Vips',
#     'outdoor_seating': 'yes',
#     'smoking': 'no',
#     'survey:date': '2022-04-04',
#     'takeaway': 'yes',
#     'website': 'https://www.starbucks.es/',
#     'wheelchair': 'limited'}},
#   {'type': 'node',
#    'id': 1319826836,
#    'lat': 40.4261051,
#    'lon': -3.6940576,
#    'tags': {'addr:city': 'Madrid',
#     'addr:housenumber': '19',
#     'addr:postcode': '28004',
#     'addr:street': 'Calle de Orellana',
#     'amenity': 'cafe',
#     'cuisine': 'israeli;middle_eastern;healthy',
#     'internet_access': 'yes',
#     'internet_access:fee': 'no',
#     'name': 'Golda Cafe',
#     'opening_hours': 'Mo-Su 08:00-20:30',
#     'website': 'https://goldacafe.com/'}},
#   {'type': 'node',
#    'id': 1319826861,
#    'lat': 40.4239163,
#    'lon': -3.6925858,
#    'tags': {'amenity': 'cafe', 'name': 'El Supremo', 'smoking': 'no'}},
#   {'type': 'node',
#    'id': 1319826869,
#    'lat': 40.4268533,
#    'lon': -3.6960421,
#    'tags': {'amenity': 'cafe',
#     'name': 'Santa Bárbara',
#     'wheelchair': 'limited'}},
#   {'type': 'node',
#    'id': 1359795118,
#    'lat': 40.4326811,
#    'lon': -3.6832448,
#    'tags': {'amenity': 'cafe',
#     'brand': 'Starbucks',
#     'brand:wikidata': 'Q37158',
#     'brand:wikipedia': 'en:Starbucks',
#     'cuisine': 'coffee_shop',
#     'name': 'Starbucks',
#     'official_name': 'Starbucks Coffee',
#     'takeaway': 'yes'}},
#   {'type': 'node',
#    'id': 1366539657,
#    'lat': 40.437727,
#    'lon': -3.6892063,
#    'tags': {'addr:street': 'Maria de Molina',
#     'amenity': 'cafe',
#     'name': 'Café Saigón'}},
#   {'type': 'node',
#    'id': 1413315512,
#    'lat': 40.4417047,
#    'lon': -3.6378328,
#    'tags': {'amenity': 'cafe', 'name': 'Bar Antonio'}},
#   {'type': 'node',
#    'id': 1434581409,
#    'lat': 40.4296017,
#    'lon': -3.7049083,
#    'tags': {'addr:city': 'Madrid',
#     'addr:housenumber': '20',
#     'addr:postcode': '28004',
#     'addr:street': 'Calle de Carranza',
#     'amenity': 'cafe',
#     'check_date': '2024-11-26',
#     'name': 'Dolce e Salato',
#     'old_name': 'Imaginarium',
#     'old_name_1': 'Valentinas & Coffee',
#     'wheelchair': 'no'}},
#   {'type': 'node',
#    'id': 1517405720,
#    'lat': 40.4238583,
#    'lon': -3.701488,
#    'tags': {'addr:city': 'Madrid',
#     'addr:housenumber': '14',
#     'addr:postcode': '28004',
#     'addr:street': 'Calle de Colón',
#     'amenity': 'cafe',
#     'contact:facebook': 'https://www.facebook.com/pages/Cr%C3%AAperie-La-Rue/118120001543910?sk=info&tab=overview',
#     'contact:phone': '+34 911 89 70 87',
#     'cuisine': 'crepe',
#     'name': 'La Rue',
#     'old_name': 'Al Laboratorio',
#     'opening_hours': 'Su-Th 10:00-00:00; Fr-Sa 10:00-01:00; PH off',
#     'website': 'https://creperielarue.com',
#     'website:menu': 'https://creperielarue.com/carta-7/',
#     'wheelchair': 'no'}},
#   {'type': 'node',
#    'id': 1613048501,
#    'lat': 40.4427781,
#    'lon': -3.6961674,
#    'tags': {'amenity': 'cafe', 'name': 'Camelia'}},
#   {'type': 'node',
#    'id': 1621005272,
#    'lat': 40.425099,
#    'lon': -3.7124847,
#    'tags': {'addr:city': 'Madrid',
#     'addr:housenumber': '3',
#     'addr:postcode': '28008',
#     'addr:street': 'Calle de la Princesa',
#     'amenity': 'cafe',
#     'diet:vegetarian': 'yes',
#     'indoor_seating': 'yes',
#     'name': 'Café & Té',
#     'outdoor_seating': 'yes',
#     'smoking': 'no',
#     'wheelchair': 'yes'}},
#   {'type': 'node',
#    'id': 1642177961,
#    'lat': 40.4246631,
#    'lon': -3.709637,
#    'tags': {'addr:city': 'Madrid',
#     'addr:housenumber': '2',
#     'addr:postcode': '28015',
#     'addr:street': 'Plaza del Conde de Toreno',
#     'amenity': 'cafe',
#     'name': 'db',
#     'old_name': 'Habibi',
#     'wheelchair': 'no'}},
#   {'type': 'node',
#    'id': 1642178045,
#    'lat': 40.4238691,
#    'lon': -3.7089925,
#    'tags': {'addr:city': 'Madrid',
#     'addr:housenumber': '8',
#     'addr:postcode': '28015',
#     'addr:street': 'Calle del Álamo',
#     'amenity': 'cafe',
#     'indoor_seating': 'no',
#     'name': 'Sieté Seven Tea',
#     'outdoor_seating': 'no',
#     'phone': '+34 657 917 362',
#     'takeaway': 'only'}},
#   {'type': 'node',
#    'id': 1686702375,
#    'lat': 40.4487805,
#    'lon': -3.7254083,
#    'tags': {'air_conditioning': 'yes',
#     'amenity': 'cafe',
#     'indoor_seating': 'yes',
#     'name': 'Cafetería Facultad de Ciencias Geológicas',
#     'outdoor_seating': 'yes',
#     'smoking': 'no'}},
#   {'type': 'node',
#    'id': 1739898679,
#    'lat': 40.4395371,
#    'lon': -3.6196894,
#    'tags': {'amenity': 'cafe'}},
#   {'type': 'node',
#    'id': 1740058741,
#    'lat': 40.4223451,
#    'lon': -3.6816075,
#    'tags': {'amenity': 'cafe', 'name': 'Café & Té', 'wheelchair': 'no'}},
#   {'type': 'node',
#    'id': 1927659397,
#    'lat': 40.4682877,
#    'lon': -3.7224352,
#    'tags': {'alt_name': 'Cervecería La Orensana',
#     'amenity': 'cafe',
#     'name': 'La Orensana'}},
#   {'type': 'node',
#    'id': 1944473872,
#    'lat': 40.4463066,
#    'lon': -3.7135061,
#    'tags': {'amenity': 'cafe', 'name': 'La Vuelta'}},
#   {'type': 'node',
#    'id': 1988186838,
#    'lat': 40.4340803,
#    'lon': -3.6328064,
#    'tags': {'amenity': 'cafe', 'name': 'Juka'}},
#   {'type': 'node',
#    'id': 2056509590,
#    'lat': 40.4261644,
#    'lon': -3.7147519,
#    'tags': {'alt_name': '3"', 'amenity': 'cafe', 'name': 'Café 3 segundos'}},
#   {'type': 'node',
#    'id': 2057557358,
#    'lat': 40.4566516,
#    'lon': -3.7051554,
#    'tags': {'amenity': 'cafe',
#     'check_date': '2023-10-31',
#     'name': 'La Pampa',
#     'wheelchair': 'limited'}},
#   {'type': 'node',
#    'id': 2057557418,
#    'lat': 40.4569966,
#    'lon': -3.7055108,
#    'tags': {'amenity': 'cafe',
#     'check_date': '2023-10-31',
#     'name': 'La Unión',
#     'toilets:wheelchair': 'no',
#     'wheelchair': 'limited'}},
#   {'type': 'node',
#    'id': 2057557445,
#    'lat': 40.4567065,
#    'lon': -3.7039235,
#    'tags': {'addr:city': 'Madrid',
#     'addr:postcode': '28039',
#     'addr:street': 'Calle de Berruguete',
#     'alt_name': 'Las delicias de Judith',
#     'amenity': 'cafe',
#     'diet:halal': 'no',
#     'name': 'Las Delicias de Judy',
#     'old_name': 'Bar Torre',
#     'old_name1': 'La Castiza',
#     'old_name2': 'Bulevar',
#     'opening_hours': 'PH,Tu-Su 09:00-24:00',
#     'operator': 'Magizan Bulevar, SL',
#     'payment:credit_cards': 'yes',
#     'payment:debit_cards': 'yes',
#     'wheelchair': 'limited'}},
#   {'type': 'node',
#    'id': 2135526338,
#    'lat': 40.4291823,
#    'lon': -3.7216853,
#    'tags': {'addr:city': 'Madrid',
#     'addr:housenumber': '48',
#     'addr:postcode': '28008',
#     'addr:street': 'Paseo del Pintor Rosales',
#     'amenity': 'cafe',
#     'name': 'La Habana Vieja',
#     'phone': '+34 915 59 81 04'}},
#   {'type': 'node',
#    'id': 2270766143,
#    'lat': 40.4443345,
#    'lon': -3.6749375,
#    'tags': {'amenity': 'cafe',
#     'name': 'Cafetería Prospe',
#     'wheelchair': 'limited'}},
#   {'type': 'node',
#    'id': 2298820823,
#    'lat': 40.4452235,
#    'lon': -3.6764378,
#    'tags': {'amenity': 'cafe',
#     'name': 'La tabernita azul',
#     'name:en': 'The Blue Little Tavern',
#     'name:fr': 'La petite taverne bleu',
#     'smoking': 'no'}},
#   {'type': 'node',
#    'id': 2302262357,
#    'lat': 40.4427506,
#    'lon': -3.6690847,
#    'tags': {'amenity': 'cafe',
#     'cuisine': 'spanish',
#     'name': 'La Taberna del Cardenal',
#     'wifi': 'no'}},
#   {'type': 'node',
#    'id': 2477700587,
#    'lat': 40.4225774,
#    'lon': -3.7063743,
#    'tags': {'addr:city': 'Madrid',
#     'addr:housenumber': '24',
#     'addr:postcode': '28015',
#     'addr:street': 'Calle de la Luna',
#     'amenity': 'cafe',
#     'check_date': '2023-09-26',
#     'name': 'Day Madrid',
#     'old_name': 'De Calle',
#     'old_name_1': 'Amor de calle',
#     'old_name_2': 'Crack',
#     'old_name_3': 'Maraca',
#     'wheelchair': 'no'}},
#   {'type': 'node',
#    'id': 2495089202,
#    'lat': 40.4569021,
#    'lon': -3.703247,
#    'tags': {'amenity': 'cafe',
#     'name': 'Brasiliana',
#     'opening_hours': 'PH,Mo-Su 07:30-13:30',
#     'wheelchair': 'no'}},
#   {'type': 'node',
#    'id': 2510220975,
#    'lat': 40.4348709,
#    'lon': -3.6306805,
#    'tags': {'amenity': 'cafe'}},
#   {'type': 'node',
#    'id': 2585165172,
#    'lat': 40.4256513,
#    'lon': -3.7067242,
#    'tags': {'addr:city': 'Madrid',
#     'addr:housenumber': '47',
#     'addr:postcode': '28004',
#     'addr:street': 'Calle del Espíritu Santo',
#     'amenity': 'cafe',
#     'contact:phone': '+34 91 521 85 76.',
#     'contact:website': 'http://www.jandjbooksandcoffee.com/index.php',
#     'description': 'Bar y café y tienda de libros de segunda mano en inglés.',
#     'name': 'J & J Books and Coffee',
#     'shop': 'books',
#     'wheelchair': 'no'}},
#   {'type': 'node',
#    'id': 2623305612,
#    'lat': 40.4365104,
#    'lon': -3.6106963,
#    'tags': {'addr:city': 'Madrid',
#     'addr:housename': 'Café Pub Dribling',
#     'addr:housenumber': '93',
#     'addr:postcode': '28022',
#     'addr:street': 'Calle de Nicolasa Gómez',
#     'amenity': 'cafe',
#     'cuisine': 'coffee_shop',
#     'internet_access': 'yes',
#     'name': 'Café Pub Dribling',
#     'opening_hours': '11:00-02:00',
#     'phone': '+34 91 320 49 16'}},
#   {'type': 'node',
#    'id': 2626943556,
#    'lat': 40.4237468,
#    'lon': -3.7022593,
#    'tags': {'addr:city': 'Madrid',
#     'addr:housenumber': '9',
#     'addr:postcode': '28004',
#     'addr:street': 'Plaza de San Ildefonso',
#     'amenity': 'cafe',
#     'diet:vegetarian': 'yes',
#     'email': 'labicicletacafe@gmail.com',
#     'internet_access': 'wlan',
#     'name': 'La Bicicleta',
#     'opening_hours': 'Su-Th 00:00-02:00,10:00-24:00; Fr-Sa 00:00-02:00, 10:00-24:00',
#     'payment:cash': 'yes',
#     'payment:mastercard': 'yes',
#     'payment:visa': 'yes',
#     'phone': '+34 915 32 97 42',
#     'website': 'https://www.labicicletacafe.com/',
#     'wheelchair': 'yes'}},
#   {'type': 'node',
#    'id': 2632228956,
#    'lat': 40.4242479,
#    'lon': -3.7072805,
#    'tags': {'addr:city': 'Madrid',
#     'addr:housenumber': '42',
#     'addr:postcode': '28015',
#     'addr:street': 'Calle de San Bernardo',
#     'amenity': 'cafe',
#     'diet:halal': 'no',
#     'diet:kosher': 'no',
#     'name': 'Dos Passos',
#     'opening_hours': 'Mo-Su 07:30-01:30',
#     'wheelchair': 'no',
#     'wheelchair:description': 'Escalón de acceso aprox. 5 cm'}},
#   {'type': 'node',
#    'id': 2636531053,
#    'lat': 40.4546924,
#    'lon': -3.7025906,
#    'tags': {'amenity': 'cafe', 'name': 'La Antigua de Estrecho'}},
#   {'type': 'node',
#    'id': 2639635434,
#    'lat': 40.425725,
#    'lon': -3.7088156,
#    'tags': {'addr:city': 'Madrid',
#     'addr:housenumber': '16',
#     'addr:postcode': '28015',
#     'addr:street': 'Calle de Noviciado',
#     'amenity': 'cafe',
#     'name': 'Sweet Studio',
#     'old_name': 'The Place'}},
#   {'type': 'node',
#    'id': 2640019766,
#    'lat': 40.426991,
#    'lon': -3.6165839,
#    'tags': {'amenity': 'cafe', 'name': 'Los Niños de la Victoria'}},
#   {'type': 'node',
#    'id': 2640019767,
#    'lat': 40.4271711,
#    'lon': -3.6167821,
#    'tags': {'amenity': 'cafe', 'name': 'Sila'}},
#   {'type': 'node',
#    'id': 2640019773,
#    'lat': 40.4269262,
#    'lon': -3.6173124,
#    'tags': {'amenity': 'cafe', 'name': "Julio's"}},
#   {'type': 'node',
#    'id': 2640019775,
#    'lat': 40.4269436,
#    'lon': -3.6168766,
#    'tags': {'amenity': 'cafe', 'old_name': 'Bar San Blas'}},
#   {'type': 'node',
#    'id': 2642274454,
#    'lat': 40.4261072,
#    'lon': -3.6815626,
#    'tags': {'addr:city': 'Madrid',
#     'addr:housenumber': '39',
#     'addr:postcode': '28001',
#     'addr:street': 'Calle de Castelló',
#     'amenity': 'cafe',
#     'brand': 'Granier',
#     'brand:wikidata': 'Q102311169',
#     'contact:facebook': 'https://es-es.facebook.com/Granierhermosilla/info',
#     'email': 'granierhermosilla@gmail.com',
#     'name': 'Granier',
#     'opening_hours': 'Mo-Su 07:00-21:30',
#     'phone': '+34 914 35 24 76',
#     'shop': 'bakery',
#     'wheelchair': 'yes'}},
#   {'type': 'node',
#    'id': 2642274457,
#    'lat': 40.4260456,
#    'lon': -3.6807566,
#    'tags': {'addr:city': 'Madrid',
#     'addr:housenumber': '58',
#     'addr:postcode': '28001',
#     'addr:street': 'Calle de Hermosilla',
#     'amenity': 'cafe',
#     'contact:facebook': 'https://es-es.facebook.com/juliettascaffe/',
#     'contact:phone': '+34 910530297',
#     'old_name': 'Nata Lovers',
#     'wheelchair': 'limited'}},
#   {'type': 'node',
#    'id': 2642274458,
#    'lat': 40.4261465,
#    'lon': -3.682848,
#    'tags': {'addr:city': 'Madrid',
#     'addr:housenumber': '40',
#     'addr:postcode': '28001',
#     'addr:street': 'Calle de Hermosilla',
#     'amenity': 'cafe',
#     'name': 'El Café de Hermosilla',
#     'wheelchair': 'yes'}},
#   {'type': 'node',
#    'id': 2646161158,
#    'lat': 40.4384818,
#    'lon': -3.651788,
#    'tags': {'amenity': 'cafe'}},
#   {'type': 'node',
#    'id': 2646161161,
#    'lat': 40.4385758,
#    'lon': -3.6518471,
#    'tags': {'amenity': 'cafe', 'name': 'Román'}},
#   {'type': 'node',
#    'id': 2646161163,
#    'lat': 40.4387166,
#    'lon': -3.6519678,
#    'tags': {'amenity': 'cafe', 'name': 'Laso', 'name:es': 'Laso'}},
#   {'type': 'node',
#    'id': 2646180931,
#    'lat': 40.4348551,
#    'lon': -3.6563344,
#    'tags': {'amenity': 'cafe', 'name': 'Río', 'name:es': 'Río'}},
#   {'type': 'node',
#    'id': 2652999510,
#    'lat': 40.4234287,
#    'lon': -3.6148448,
#    'tags': {'amenity': 'cafe'}},
#   {'type': 'node',
#    'id': 2653822213,
#    'lat': 40.4260105,
#    'lon': -3.7071668,
#    'tags': {'addr:city': 'Madrid',
#     'addr:housenumber': '57',
#     'addr:postcode': '28015',
#     'addr:street': 'Calle de San Bernardo',
#     'amenity': 'cafe',
#     'name': 'La Doña',
#     'old_name': 'Movistar',
#     'opening_hours': '24/7',
#     'toilets:wheelchair': 'yes',
#     'wheelchair': 'yes'}},
#   {'type': 'node',
#    'id': 2664897893,
#    'lat': 40.4379771,
#    'lon': -3.6773101,
#    'tags': {'addr:city': 'Madrid',
#     'addr:housenumber': '1',
#     'addr:postcode': '28002',
#     'addr:street': 'Avenida de América',
#     'amenity': 'cafe',
#     'contact:facebook': 'https://es-es.facebook.com/pages/Cafeteria-Honey-Madrid/214076878627039',
#     'email': 'cafeteriahoney@ono.com',
#     'name': 'Honey',
#     'phone': '+34 915 63 58 18'}},
#   {'type': 'node',
#    'id': 2668366790,
#    'lat': 40.4299435,
#    'lon': -3.7077873,
#    'tags': {'addr:city': 'Madrid',
#     'addr:housenumber': '12',
#     'addr:postcode': '28015',
#     'addr:street': 'Calle de Alberto Aguilera',
#     'amenity': 'cafe',
#     'name': 'Cauca'}},
#   {'type': 'node',
#    'id': 2668366797,
#    'lat': 40.4298654,
#    'lon': -3.7069624,
#    'tags': {'addr:city': 'Madrid',
#     'addr:housenumber': '8',
#     'addr:postcode': '28015',
#     'addr:street': 'Calle de Alberto Aguilera',
#     'amenity': 'cafe',
#     'check_date': '2023-09-28',
#     'name': 'Panaria',
#     'opening_hours': 'Mo-Sa 08:00-20:30; PH,Su 09:00-14:30',
#     'outdoor_seating': 'yes',
#     'shop': 'bakery',
#     'website': 'https://www.panariapanaderias.es/',
#     'wheelchair': 'no'}},
#   {'type': 'node',
#    'id': 2668463117,
#    'lat': 40.4241701,
#    'lon': -3.7063175,
#    'tags': {'addr:city': 'Madrid',
#     'addr:housenumber': '36',
#     'addr:postcode': '28004',
#     'addr:street': 'Calle del Pez',
#     'amenity': 'cafe',
#     'check_date': '2023-09-24',
#     'name': 'Ambu Coffee',
#     'old_name': 'Trakabarraka',
#     'old_name_1': 'Popota',
#     'website': 'https://ambu.coffee/',
#     'wheelchair': 'limited'}},
#   {'type': 'node',
#    'id': 2669198762,
#    'lat': 40.428062,
#    'lon': -3.7094676,
#    'tags': {'addr:city': 'Madrid',
#     'addr:housenumber': '36',
#     'addr:postcode': '28015',
#     'addr:street': 'Calle de Amaniel',
#     'amenity': 'cafe',
#     'contact:website': 'https://www.unfltrdcoffee.com/',
#     'name': 'Unfiltrd',
#     'old_name': 'Rías Baixas'}},
#   {'type': 'node',
#    'id': 2669198767,
#    'lat': 40.4270528,
#    'lon': -3.7092373,
#    'tags': {'addr:city': 'Madrid',
#     'addr:housenumber': '9',
#     'addr:postcode': '28015',
#     'addr:street': 'Plaza de las Comendadoras',
#     'amenity': 'cafe',
#     'check_date': '2023-09-30',
#     'diet:vegan': 'yes',
#     'diet:vegetarian': 'yes',
#     'email': 'madrid@federalcafe.es',
#     'internet_access': 'wlan',
#     'internet_access:password': 'cafeconleche',
#     'name': 'Federal Café',
#     'opening_hours': 'Mo-Sa 09:00-24:00; Sa,Su 00:00-01:00; Su 09:00-17:00',
#     'outdoor_seating': 'yes',
#     'phone': '+34 915 328 424',
#     'toilets:wheelchair': 'yes',
#     'website': 'https://federalcafe.es/madrid/',
#     'wheelchair': 'yes'}},
#   {'type': 'node',
#    'id': 2669909215,
#    'lat': 40.4296557,
#    'lon': -3.7051951,
#    'tags': {'addr:city': 'Madrid',
#     'addr:housenumber': '5',
#     'addr:postcode': '28015',
#     'addr:street': 'Glorieta de Ruiz Jiménez',
#     'amenity': 'cafe',
#     'check_date': '2024-05-20',
#     'name': 'Café Minber'}},
#   {'type': 'node',
#    'id': 2669909220,
#    'lat': 40.4314648,
#    'lon': -3.708136,
#    'tags': {'addr:city': 'Madrid',
#     'addr:housenumber': '7',
#     'addr:postcode': '28015',
#     'addr:street': 'Calle de Rodríguez San Pedro',
#     'amenity': 'cafe',
#     'name': "Friend's Coffee"}},
#   {'type': 'node',
#    'id': 2669997847,
#    'lat': 40.4352928,
#    'lon': -3.7141753,
#    'tags': {'addr:city': 'Madrid',
#     'addr:housenumber': '71',
#     'addr:postcode': '28015',
#     'addr:street': 'Calle de Fernández de los Ríos',
#     'amenity': 'cafe',
#     'name': 'C@ffe.it'}},
#   {'type': 'node',
#    'id': 2671175816,
#    'lat': 40.4332265,
#    'lon': -3.7088754,
#    'tags': {'addr:city': 'Madrid',
#     'addr:housenumber': '37',
#     'addr:postcode': '28015',
#     'addr:street': 'Calle de Vallehermoso',
#     'amenity': 'cafe',
#     'name': 'Tormes'}},
#   {'type': 'node',
#    'id': 2671207707,
#    'lat': 40.4351872,
#    'lon': -3.7118607,
#    'tags': {'addr:city': 'Madrid',
#     'addr:housenumber': '55',
#     'addr:postcode': '28015',
#     'addr:street': 'Calle de Fernández de los Ríos',
#     'amenity': 'cafe',
#     'name': 'Rotterdam'}},
#   {'type': 'node',
#    'id': 2671241942,
#    'lat': 40.4261035,
#    'lon': -3.7075585,
#    'tags': {'addr:city': 'Madrid',
#     'addr:housenumber': '53',
#     'addr:postcode': '28015',
#     'addr:street': 'Calle de San Vicente Ferrer',
#     'amenity': 'cafe',
#     'name': 'El Naranja',
#     'website': 'http://www.elnaranja.info/1.html'}},
#   {'type': 'node',
#    'id': 2672814926,
#    'lat': 40.4227936,
#    'lon': -3.7039429,
#    'tags': {'addr:city': 'Madrid',
#     'addr:housenumber': '4',
#     'addr:postcode': '28004',
#     'addr:street': 'Calle del Pez',
#     'amenity': 'cafe',
#     'check_date': '2023-10-04',
#     'name': 'Constanza Cafe',
#     'old_name': 'Antorcha Café',
#     'wheelchair': 'no'}},
#   {'type': 'node',
#    'id': 2672817741,
#    'lat': 40.4224594,
#    'lon': -3.7039475,
#    'tags': {'addr:city': 'Madrid',
#     'addr:housenumber': '25',
#     'addr:postcode': '28004',
#     'addr:street': 'Corredera Baja de San Pablo',
#     'amenity': 'cafe',
#     'name': 'SWT Gallery'}},
#   {'type': 'node',
#    'id': 2672831651,
#    'lat': 40.4221388,
#    'lon': -3.7025164,
#    'tags': {'addr:city': 'Madrid',
#     'addr:housenumber': '8',
#     'addr:postcode': '28004',
#     'addr:street': 'Calle de la Puebla',
#     'amenity': 'cafe',
#     'contact:facebook': 'pages/Caf%C3%A9-de-la-Luz/168195233378',
#     'name': 'Café de la Luz',
#     'opening_hours': 'Mo-Su 10:00-02:00',
#     'phone': '+34 915 23 11 99'}},
#   {'type': 'node',
#    'id': 2676854997,
#    'lat': 40.4219393,
#    'lon': -3.7045881,
#    'tags': {'addr:city': 'Madrid',
#     'addr:housenumber': '11',
#     'addr:postcode': '28004',
#     'addr:street': 'Corredera Baja de San Pablo',
#     'amenity': 'cafe',
#     'contact:facebook': 'https://es-es.facebook.com/BarCafeLara',
#     'name': 'Cafetería Lara',
#     'phone': '+34 609 90 68 12',
#     'wheelchair': 'no'}},
#   {'type': 'node',
#    'id': 2681923270,
#    'lat': 40.423242,
#    'lon': -3.7073722,
#    'tags': {'addr:city': 'Madrid',
#     'addr:housenumber': '24',
#     'addr:postcode': '28015',
#     'addr:street': 'Calle de San Bernardo',
#     'amenity': 'cafe',
#     'contact:phone': '+34 910 55 86',
#     'contact:website': 'https://cafeangelica.es/',
#     'name': 'Café Angélica',
#     'old_name': 'Angélica',
#     'shop': 'coffee',
#     'wheelchair': 'no',
#     'wheelchair:description': 'Escalón de acceso mayor de 7 cm y puerta de 80 cm'}},
#   {'type': 'node',
#    'id': 2692606027,
#    'lat': 40.422785,
#    'lon': -3.6993686,
#    'tags': {'addr:city': 'Madrid',
#     'addr:housenumber': '17',
#     'addr:postcode': '28004',
#     'addr:street': 'Calle de Augusto Figueroa',
#     'amenity': 'cafe',
#     'contact:website': 'https://www.lakamabaranoa.com/inicio',
#     'name': 'LaKama Café',
#     'old_name': 'Café Figueroa',
#     'wheelchair': 'no'}},
#   {'type': 'node',
#    'id': 2704017903,
#    'lat': 40.4257155,
#    'lon': -3.7038206,
#    'tags': {'addr:city': 'Madrid',
#     'addr:housenumber': '4',
#     'addr:postcode': '28004',
#     'addr:street': 'Calle de San Andrés',
#     'amenity': 'cafe',
#     'check_date': '2023-09-24',
#     'contact:facebook': 'https://www.facebook.com/people/El-Colmao-Ecol%C3%B3gico/100077502827742/',
#     'contact:phone': '+34 914 96 07 56',
#     'name': 'El Colmao Ecológico',
#     'old_name': 'Doña Francisquita',
#     'wheelchair': 'no'}},
#   {'type': 'node',
#    'id': 2704017922,
#    'lat': 40.4281338,
#    'lon': -3.7039279,
#    'tags': {'addr:city': 'Madrid',
#     'addr:housenumber': '11',
#     'addr:postcode': '28004',
#     'addr:street': 'Calle de Ruiz',
#     'amenity': 'cafe',
#     'name': 'Café de Ruiz',
#     'survey:date': '2024-01-04',
#     'website': 'http://cafederuiz.com/'}},
#   {'type': 'node',
#    'id': 2739850840,
#    'lat': 40.4378104,
#    'lon': -3.6505224,
#    'tags': {'amenity': 'cafe',
#     'check_date': '2023-06-13',
#     'internet_access': 'no',
#     'name': 'Cafetería Luzón'}},
#   {'type': 'node',
#    'id': 2764318350,
#    'lat': 40.4265999,
#    'lon': -3.6783933,
#    'tags': {'addr:city': 'Madrid',
#     'addr:housenumber': '32',
#     'addr:street': 'Calle del General Pardiñas',
#     'amenity': 'cafe',
#     'cuisine': 'drinks;tapas',
#     'name': 'Café de Zine',
#     'note': 'Se sirven copas (bar) y hay tapas (¿restaurante?), pero ellos mismos lo clasifican como "Café".'}},
#   {'type': 'node',
#    'id': 2769265438,
#    'lat': 40.4224814,
#    'lon': -3.7005843,
#    'tags': {'addr:city': 'Madrid',
#     'addr:housenumber': '2',
#     'addr:postcode': '28004',
#     'addr:street': 'Calle de Pérez Galdós',
#     'amenity': 'cafe',
#     'contact:instagram': 'https://www.instagram.com/wolfoxmadrid',
#     'name': 'Wolføx Coffee Madrid',
#     'old_name': 'IT Dogs',
#     'opening_hours': 'Mo-Su 10:00-19:00',
#     'outdoor_seating': 'yes',
#     'website': 'https://www.wolfox.coffee/'}},
#   {'type': 'node',
#    'id': 2777281762,
#    'lat': 40.4247401,
#    'lon': -3.7010888,
#    'tags': {'addr:city': 'Madrid',
#     'addr:housenumber': '3',
#     'addr:postcode': '28004',
#     'addr:street': 'Calle de San Joaquín',
#     'amenity': 'cafe',
#     'email': 'librosyvinos@tiposinfames.com',
#     'name': 'Tipos Infames',
#     'phone': '+34 915 228 939',
#     'shop': 'books',
#     'website': 'https://www.tiposinfames.com/',
#     'wheelchair': 'no'}},
#   {'type': 'node',
#    'id': 2777306948,
#    'lat': 40.4243517,
#    'lon': -3.7018731,
#    'tags': {'addr:city': 'Madrid',
#     'addr:housenumber': '16',
#     'addr:postcode': '28004',
#     'addr:street': 'Calle de San Joaquín',
#     'amenity': 'cafe',
#     'cuisine': 'sandwich',
#     'name': 'Naif',
#     'outdoor_seating': 'yes',
#     'toilets': 'customers',
#     'toilets:wheelchair': 'yes'}},
#   {'type': 'node',
#    'id': 2779332355,
#    'lat': 40.42732,
#    'lon': -3.6737652,
#    'tags': {'addr:city': 'Madrid',
#     'addr:housenumber': '87A',
#     'addr:postcode': '28006',
#     'addr:street': 'Calle de Ayala',
#     'amenity': 'cafe',
#     'name': 'Urban Coffee',
#     'website': 'http://loungecoffee.com/urban/ubicacion.html'}},
#   {'type': 'node',
#    'id': 2802274511,
#    'lat': 40.4389491,
#    'lon': -3.654095,
#    'tags': {'amenity': 'cafe', 'name': "Pimar's"}},
#   {'type': 'node',
#    'id': 2836112493,
#    'lat': 40.4352121,
#    'lon': -3.7126864,
#    'tags': {'addr:city': 'Madrid',
#     'addr:housenumber': '61',
#     'addr:postcode': '28015',
#     'addr:street': 'Calle de Fernández de los Ríos',
#     'amenity': 'cafe',
#     'cuisine': 'coffee_shop',
#     'internet_access': 'wlan',
#     'name': 'The Little Big cafe',
#     'opening_hours': 'Mo-Fr 09:00-20:00; Sa-Su 10:00-19:00',
#     'smoking': 'no',
#     'website': 'https://www.thelittlebigcafe.com/',
#     'wheelchair': 'yes'}},
#   {'type': 'node',
#    'id': 2864197143,
#    'lat': 40.4570634,
#    'lon': -3.6991202,
#    'tags': {'amenity': 'cafe', 'name': 'Bar La Carreta'}},
#   {'type': 'node',
#    'id': 2867491074,
#    'lat': 40.4470286,
#    'lon': -3.7033332,
#    'tags': {'amenity': 'cafe', 'name': 'Nu Rielle', 'wheelchair': 'no'}},
#   {'type': 'node',
#    'id': 2867491099,
#    'lat': 40.4494622,
#    'lon': -3.7033876,
#    'tags': {'amenity': 'cafe', 'name': 'Museo del Jamón 2'}},
#   {'type': 'node',
#    'id': 2868679684,
#    'lat': 40.4505421,
#    'lon': -3.7032293,
#    'tags': {'amenity': 'cafe', 'name': 'Chloe Lan', 'wheelchair': 'yes'}},
#   {'type': 'node',
#    'id': 2868679693,
#    'lat': 40.4522589,
#    'lon': -3.7033798,
#    'tags': {'amenity': 'cafe',
#     'cuisine': 'coffee_shop',
#     'name': 'La Castiza'}},
#   {'type': 'node',
#    'id': 2868776230,
#    'lat': 40.4577985,
#    'lon': -3.7116749,
#    'tags': {'amenity': 'cafe',
#     'diet:halal': 'no',
#     'name': 'La Mina',
#     'opening_hours': 'Su-Th 06:00-02:00; Fr,Sa 06:00-02:30',
#     'payment:credit_cards': 'yes',
#     'payment:debit_cards': 'yes',
#     'wheelchair': 'limited'}},
#   {'type': 'node',
#    'id': 2868794479,
#    'lat': 40.456955,
#    'lon': -3.7086386,
#    'tags': {'amenity': 'cafe',
#     'check_date:opening_hours': '2022-11-27',
#     'diet:halal': 'no',
#     'name': 'Cafetería La Villa',
#     'opening_hours': 'Mo-Su 08:00-24:00; Fr,Sa 08:00-00:30',
#     'payment:credit_cards': 'yes',
#     'payment:debit_cards': 'yes',
#     'wheelchair': 'yes'}},
#   {'type': 'node',
#    'id': 2868810917,
#    'lat': 40.4567878,
#    'lon': -3.7079526,
#    'tags': {'amenity': 'cafe',
#     'name': 'La Muralla de Ávila',
#     'phone': '+34914591036'}},
#   {'type': 'node',
#    'id': 2870489592,
#    'lat': 40.4568773,
#    'lon': -3.7064436,
#    'tags': {'amenity': 'cafe', 'name': 'Cafetería Fuente Verde'}},
#   {'type': 'node',
#    'id': 2870522339,
#    'lat': 40.4595013,
#    'lon': -3.7074201,
#    'tags': {'amenity': 'cafe',
#     'check_date': '2025-07-04',
#     'name': 'Cafetería De Película',
#     'old_name': 'Bodegas Ergueta'}},
#   {'type': 'node',
#    'id': 2870522340,
#    'lat': 40.4588861,
#    'lon': -3.7047898,
#    'tags': {'amenity': 'cafe', 'name': 'Bar La Torre'}},
#   {'type': 'node',
#    'id': 2870522363,
#    'lat': 40.4585305,
#    'lon': -3.7066507,
#    'tags': {'amenity': 'cafe',
#     'check_date': '2025-07-04',
#     'name': 'Cervecería Bar Viña Lidia'}},
#   {'type': 'node',
#    'id': 2880462327,
#    'lat': 40.4436716,
#    'lon': -3.702682,
#    'tags': {'amenity': 'cafe', 'name': 'Vanille'}},
#   {'type': 'node',
#    'id': 2883836605,
#    'lat': 40.4367282,
#    'lon': -3.7164243,
#    'tags': {'amenity': 'cafe',
#     'check_date': '2024-09-23',
#     'name': 'Mora Café',
#     'old_name': 'Don Hilarión',
#     'wheelchair': 'limited'}},
#   {'type': 'node',
#    'id': 2887253634,
#    'lat': 40.4483907,
#    'lon': -3.7039531,
#    'tags': {'amenity': 'cafe', 'name': 'Rubí'}},
#   {'type': 'node',
#    'id': 2891477464,
#    'lat': 40.4533629,
#    'lon': -3.7032217,
#    'tags': {'amenity': 'cafe', 'name': 'Cafetería Estrecho'}},
#   {'type': 'node',
#    'id': 2891559892,
#    'lat': 40.4565532,
#    'lon': -3.7072258,
#    'tags': {'amenity': 'cafe',
#     'name': 'Ganeza coffee-bread',
#     'old_name': 'El señor de la birra'}},
#   {'type': 'node',
#    'id': 2891563635,
#    'lat': 40.4574931,
#    'lon': -3.7060531,
#    'tags': {'amenity': 'cafe', 'name': 'Bar Arco Iris JJ'}},
#   {'type': 'node',
#    'id': 2912429033,
#    'lat': 40.4257339,
#    'lon': -3.7030666,
#    'tags': {'addr:city': 'Madrid',
#     'addr:housenumber': '20',
#     'addr:postcode': '28004',
#     'addr:street': 'Calle de San Vicente Ferrer',
#     'amenity': 'cafe',
#     'name': 'Estar Café',
#     'phone': '+34 914 48 60 87'}},
#   {'type': 'node',
#    'id': 2916188358,
#    'lat': 40.4467011,
#    'lon': -3.7046455,
#    'tags': {'amenity': 'cafe', 'name': 'Audrey'}},
#   {'type': 'node',
#    'id': 2916188360,
#    'lat': 40.4471284,
#    'lon': -3.705399,
#    'tags': {'amenity': 'cafe', 'name': 'Café y Té'}},
#   {'type': 'node',
#    'id': 2929357293,
#    'lat': 40.4595133,
#    'lon': -3.7002391,
#    'tags': {'addr:city': 'Madrid',
#     'addr:housenumber': '6',
#     'addr:postcode': '28039',
#     'addr:street': 'Calle de Tablada',
#     'amenity': 'cafe',
#     'name': 'Cytrus'}},
#   {'type': 'node',
#    'id': 2929890142,
#    'lat': 40.4597099,
#    'lon': -3.7005637,
#    'tags': {'addr:city': 'Madrid',
#     'addr:housenumber': '12',
#     'addr:postcode': '28039',
#     'addr:street': 'Calle de Tablada',
#     'amenity': 'cafe',
#     'name': 'Pinoy Spanish Bar'}},
#   {'type': 'node',
#    'id': 2942276116,
#    'lat': 40.4376633,
#    'lon': -3.6868614,
#    'tags': {'addr:city': 'Madrid',
#     'addr:housenumber': '18',
#     'addr:postcode': '28006',
#     'addr:street': 'Calle de María de Molina',
#     'amenity': 'cafe',
#     'check_date:currency:XBT': '2024-09-10',
#     'currency:XBT': 'yes',
#     'name': 'Do Eat!',
#     'payment:lightning': 'yes',
#     'phone': '+34 911 866 600',
#     'website': 'https://doeat.es/',
#     'yelp': 'http://www.yelp.com/biz/do-eat-madrid-2'}},
#   {'type': 'node',
#    'id': 2947786417,
#    'lat': 40.4572389,
#    'lon': -3.7096674,
#    'tags': {'addr:city': 'Madrid',
#     'addr:housenumber': '76',
#     'addr:postcode': '28039',
#     'addr:street': 'Calle de Francos Rodríguez',
#     'amenity': 'cafe',
#     'name': 'Bar Gema',
#     'opening_hours': 'Mo-Su 07:00-24:00'}},
#   {'type': 'node',
#    'id': 2955163356,
#    'lat': 40.4650433,
#    'lon': -3.7102021,
#    'tags': {'amenity': 'cafe', 'name': 'Bar El Paso'}},
#   {'type': 'node',
#    'id': 2972891894,
#    'lat': 40.443185,
#    'lon': -3.7042681,
#    'tags': {'amenity': 'cafe', 'name': 'Sirius Café'}},
#   {'type': 'node',
#    'id': 2972891925,
#    'lat': 40.4446265,
#    'lon': -3.7038288,
#    'tags': {'amenity': 'cafe', 'name': 'Café Racer'}},
#   {'type': 'node',
#    'id': 2972941198,
#    'lat': 40.4351737,
#    'lon': -3.7045359,
#    'tags': {'amenity': 'cafe', 'name': 'Cafetería Isabel'}},
#   {'type': 'node',
#    'id': 2973043610,
#    'lat': 40.4229435,
#    'lon': -3.7112768,
#    'tags': {'air_conditioning': 'yes',
#     'amenity': 'cafe',
#     'atm': 'yes',
#     'check_date': '2025-01-08',
#     'check_date:opening_hours': '2024-04-06',
#     'check_date:smoking': '2025-01-08',
#     'indoor_seating': 'yes',
#     'name': 'faborit',
#     'old_name': 'Banco Sabadell',
#     'opening_hours:signed': 'no',
#     'outdoor_seating': 'no',
#     'smoking': 'no',
#     'wheelchair': 'limited'}},
#   {'type': 'node',
#    'id': 3007302445,
#    'lat': 40.4226307,
#    'lon': -3.7093098,
#    'tags': {'addr:city': 'Madrid',
#     'addr:housenumber': '70',
#     'addr:postcode': '28013',
#     'addr:street': 'Gran Vía',
#     'amenity': 'cafe',
#     'name': 'Pause',
#     'old_name': 'Café & Té',
#     'wheelchair': 'no'}},
#   {'type': 'node',
#    'id': 3050347080,
#    'lat': 40.4279425,
#    'lon': -3.7020701,
#    'tags': {'addr:city': 'Madrid',
#     'addr:housenumber': '101',
#     'addr:street': 'Calle de Fuencarral',
#     'amenity': 'cafe',
#     'brand': 'Starbucks',
#     'brand:wikidata': 'Q37158',
#     'brand:wikipedia': 'en:Starbucks',
#     'cuisine': 'coffee_shop',
#     'name': 'Starbucks',
#     'official_name': 'Starbucks Coffee',
#     'operator': 'Starbucks',
#     'takeaway': 'yes',
#     'wheelchair': 'limited',
#     'wheelchair:description': 'Aseo adaptado, pasillos estrechos.'}},
#   {'type': 'node',
#    'id': 3128165594,
#    'lat': 40.4551863,
#    'lon': -3.7028679,
#    'tags': {'addr:housenumber': '203',
#     'addr:street': 'Calle de Bravo Murillo',
#     'amenity': 'cafe',
#     'name': 'Audrey Brunch&Coffee'}},
#   {'type': 'node',
#    'id': 3136812042,
#    'lat': 40.441285,
#    'lon': -3.7149836,
#    'tags': {'amenity': 'cafe', 'name': 'Chocolatería Cafetería'}},
#   {'type': 'node',
#    'id': 3136816581,
#    'lat': 40.4330328,
#    'lon': -3.7169568,
#    'tags': {'amenity': 'cafe', 'name': 'Bar Rosado'}},
#   {'type': 'node',
#    'id': 3137147955,
#    'lat': 40.4264572,
#    'lon': -3.7056172,
#    'tags': {'addr:housenumber': '47',
#     'addr:street': 'Calle de la Palma',
#     'amenity': 'cafe',
#     'check_date': '2023-10-03',
#     'name': 'Gosto',
#     'old_name': 'Más Mastropiero',
#     'wheelchair': 'no'}},
#   {'type': 'node',
#    'id': 3161160129,
#    'lat': 40.460905,
#    'lon': -3.6964197,
#    'tags': {'amenity': 'cafe', 'name': 'Mediterráneo'}},
#   {'type': 'node',
#    'id': 3170766310,
#    'lat': 40.4382443,
#    'lon': -3.6924977,
#    'tags': {'addr:housenumber': '59',
#     'addr:postcode': '28003',
#     'addr:street': 'Calle José Abascal',
#     'amenity': 'cafe',
#     'brand': 'Santagloria',
#     'brand:wikidata': 'Q54606497',
#     'name': 'Santagloria',
#     'outdoor_seating': 'no',
#     'shop': 'bakery',
#     'source': 'local knowledge',
#     'website': 'https://www.santagloria.com/'}},
#   {'type': 'node',
#    'id': 3181391412,
#    'lat': 40.433945,
#    'lon': -3.7046638,
#    'tags': {'addr:city': 'Madrid',
#     'addr:housenumber': '6',
#     'addr:postcode': '28015',
#     'addr:street': 'Glorieta de Quevedo',
#     'amenity': 'cafe',
#     'name': 'La Francerie',
#     'old_name': 'Farmacia - Glorieta Quevedo 6',
#     'website': 'https://lafrancerie.es/'}},
#   {'type': 'node',
#    'id': 3196261068,
#    'lat': 40.446846,
#    'lon': -3.7125713,
#    'tags': {'amenity': 'cafe', 'name': 'Cafetería'}},
#   {'type': 'node',
#    'id': 3202125015,
#    'lat': 40.431653,
#    'lon': -3.6505532,
#    'tags': {'amenity': 'cafe',
#     'name': 'Cervecería A´Conchiña',
#     'phone': '+34 913262619',
#     'website': 'https://www.cerveceriaconchiña.es/',
#     'wheelchair': 'no'}},
#   {'type': 'node',
#    'id': 3206699865,
#    'lat': 40.4351679,
#    'lon': -3.6643766,
#    'tags': {'addr:city': 'Madrid',
#     'addr:housenumber': '68',
#     'addr:postcode': '28028',
#     'addr:street': 'Calle de Martínez Izquierdo',
#     'amenity': 'cafe',
#     'name': 'Cafetería La Plancha'}},
#   {'type': 'node',
#    'id': 3208755399,
#    'lat': 40.4646193,
#    'lon': -3.6951606,
#    'tags': {'amenity': 'cafe', 'name': 'Bar Pascual'}},
#   {'type': 'node',
#    'id': 3208755402,
#    'lat': 40.4664316,
#    'lon': -3.6962734,
#    'tags': {'amenity': 'cafe', 'name': 'Café Punto y Coma'}},
#   {'type': 'node',
#    'id': 3208755427,
#    'lat': 40.4670665,
#    'lon': -3.6957053,
#    'tags': {'amenity': 'cafe'}},
#   {'type': 'node',
#    'id': 3212683931,
#    'lat': 40.4304201,
#    'lon': -3.6824967,
#    'tags': {'addr:city': 'Madrid',
#     'addr:housenumber': '29',
#     'addr:postcode': '28006',
#     'addr:street': 'Calle de José Ortega y Gasset',
#     'amenity': 'cafe',
#     'brand': 'Starbucks',
#     'brand:wikidata': 'Q37158',
#     'brand:wikipedia': 'en:Starbucks',
#     'contact:website': 'http://www.starbucks.es',
#     'cuisine': 'coffee_shop',
#     'name': 'Starbucks',
#     'official_name': 'Starbucks Coffee',
#     'takeaway': 'yes'}},
#   {'type': 'node',
#    'id': 3234734470,
#    'lat': 40.4444862,
#    'lon': -3.6974065,
#    'tags': {'addr:housenumber': '93',
#     'addr:postcode': '28003',
#     'addr:street': 'Calle de Alonso Cano',
#     'amenity': 'cafe',
#     'name': 'La Posada de Alonso Cano',
#     'phone': '+34 91 447 1586'}},
#   {'type': 'node',
#    'id': 3242331191,
#    'lat': 40.4264913,
#    'lon': -3.7059638,
#    'tags': {'addr:city': 'Madrid',
#     'addr:housenumber': '49',
#     'addr:postcode': '28004',
#     'addr:street': 'Calle de la Palma',
#     'amenity': 'cafe',
#     'check_date': '2023-10-03',
#     'cost:coffee': '$1.80',
#     'cuisine': 'coffee_shop',
#     'email': 'info@tomacafe.es',
#     'name': 'Toma Café',
#     'opening_hours': 'Mo-Fr 08:00-20:00; Sa,Su 10:00-20:00',
#     'phone': '+34 917 049 344',
#     'website': 'http://www.tomacafe.es/',
#     'wheelchair': 'no'}},
#   {'type': 'node',
#    'id': 3265599908,
#    'lat': 40.4382907,
#    'lon': -3.6729734,
#    'tags': {'amenity': 'cafe', 'name': 'El Panecillo', 'shop': 'bakery'}},
#   {'type': 'node',
#    'id': 3269546367,
#    'lat': 40.4369321,
#    'lon': -3.6871822,
#    'tags': {'addr:housenumber': '10',
#     'addr:postcode': '28006',
#     'addr:street': 'Calle de López de Hoyos',
#     'amenity': 'cafe',
#     'name': 'Panela&Co',
#     'phone': '+34 915636069'}},
#   {'type': 'node',
#    'id': 3269780307,
#    'lat': 40.4260347,
#    'lon': -3.6707123,
#    'tags': {'amenity': 'cafe', 'name': 'El Albero'}},
#   {'type': 'node',
#    'id': 3294436873,
#    'lat': 40.4345404,
#    'lon': -3.6456674,
#    'tags': {'amenity': 'cafe',
#     'cuisine': 'churro;chocolate',
#     'name': 'Las Farolas'}},
#   {'type': 'node',
#    'id': 3359367683,
#    'lat': 40.42937,
#    'lon': -3.7078904,
#    'tags': {'addr:city': 'Madrid',
#     'addr:housenumber': '39',
#     'addr:postcode': '28015',
#     'addr:street': 'Calle del Acuerdo',
#     'amenity': 'cafe',
#     'disused:amenity': 'bar',
#     'name': 'Miau',
#     'old_name': "D'Alma;Belu"}},
#   {'type': 'node',
#    'id': 3371729069,
#    'lat': 40.4263982,
#    'lon': -3.7050202,
#    'tags': {'addr:city': 'Madrid',
#     'addr:housenumber': '41',
#     'addr:postcode': '28004',
#     'addr:street': 'Calle de la Palma',
#     'amenity': 'cafe',
#     'contact:instagram': 'elgorditocantina',
#     'name': 'El Gordito'}},
#   {'type': 'node',
#    'id': 3389555454,
#    'lat': 40.4244011,
#    'lon': -3.7120394,
#    'tags': {'air_conditioning': 'yes',
#     'amenity': 'cafe',
#     'cuisine': 'bubble_tea',
#     'diet:vegan': 'yes',
#     'diet:vegetarian': 'yes',
#     'indoor_seating': 'yes',
#     'name': 'T8',
#     'outdoor_seating': 'no',
#     'payment:credit_cards': 'yes',
#     'payment:debit_cards': 'yes',
#     'smoking': 'no',
#     'wheelchair': 'yes'}},
#   {'type': 'node',
#    'id': 3426617375,
#    'lat': 40.4221948,
#    'lon': -3.6923421,
#    'tags': {'addr:housenumber': '21',
#     'addr:street': 'Paseo de Recoletos',
#     'amenity': 'cafe',
#     'check_date': '2024-09-04',
#     'name': 'Gran Café Gijón',
#     'outdoor_seating': 'yes',
#     'phone': '+34 915 215 425',
#     'website': 'https://cafegijon.com/',
#     'wheelchair': 'no',
#     'wikidata': 'Q1025608',
#     'wikipedia': 'es:Café Gijón'}},
#   {'type': 'node',
#    'id': 3426732122,
#    'lat': 40.4351477,
#    'lon': -3.6983923,
#    'tags': {'amenity': 'cafe', 'name': 'Jamaica'}},
#   {'type': 'node',
#    'id': 3426800312,
#    'lat': 40.4232935,
#    'lon': -3.6940419,
#    'tags': {'addr:city': 'Madrid',
#     'addr:housenumber': '12',
#     'addr:postcode': '28004',
#     'addr:street': 'Calle del Conde de Xiquena',
#     'amenity': 'cafe',
#     'cuisine': 'coffee_shop',
#     'name': 'Altered'}},
#   {'type': 'node',
#    'id': 3426834939,
#    'lat': 40.439386,
#    'lon': -3.7004446,
#    'tags': {'amenity': 'cafe', 'name': 'Classic Café Bar'}},
#   {'type': 'node',
#    'id': 3426834966,
#    'lat': 40.4553536,
#    'lon': -3.7033222,
#    'tags': {'amenity': 'cafe', 'name': 'La parrilla Igorota'}},
#   {'type': 'node',
#    'id': 3428475667,
#    'lat': 40.4311209,
#    'lon': -3.6972714,
#    'tags': {'addr:city': 'Madrid',
#     'addr:housenumber': '29',
#     'addr:postcode': '28010',
#     'addr:street': 'Calle de Santa Engracia',
#     'amenity': 'cafe',
#     'name': 'Café Bar Rocamar'}},
#   {'type': 'node',
#    'id': 3428475683,
#    'lat': 40.4370871,
#    'lon': -3.6998872,
#    'tags': {'addr:city': 'Madrid',
#     'addr:housenumber': '103',
#     'addr:postcode': '28010',
#     'addr:street': 'Calle de Santa Engracia',
#     'amenity': 'cafe',
#     'check_date': '2025-03-27',
#     'cuisine': 'portuguese;seafood;spanish;regional',
#     'diet:vegetarian': 'no',
#     'email': 'taberna@almacheli.com',
#     'internet_access': 'wlan',
#     'name': 'AlmaCheli Hecho A Mano',
#     'opening_hours': 'Mo-Su 18:00-02:00',
#     'phone': '+34915913630',
#     'wheelchair': 'limited'}},
#   {'type': 'node',
#    'id': 3428476975,
#    'lat': 40.4336757,
#    'lon': -3.6983908,
#    'tags': {'amenity': 'cafe', 'name': 'Pain Bistro', 'wheelchair': 'yes'}},
#   {'type': 'node',
#    'id': 3459875697,
#    'lat': 40.4581157,
#    'lon': -3.696974,
#    'tags': {'amenity': 'cafe', 'name': 'Bar Minuto'}},
#   {'type': 'node',
#    'id': 3459875698,
#    'lat': 40.4591513,
#    'lon': -3.696054,
#    'tags': {'amenity': 'cafe', 'name': 'Cafetería Medranda'}},
#   {'type': 'node',
#    'id': 3461921708,
#    'lat': 40.4247482,
#    'lon': -3.7008221,
#    'tags': {'addr:city': 'Madrid',
#     'addr:housenumber': '71',
#     'addr:postcode': '28004',
#     'addr:street': 'Calle de Fuencarral',
#     'amenity': 'cafe',
#     'name': 'Rocablanca',
#     'outdoor_seating': 'no',
#     'wheelchair': 'no'}},
#   {'type': 'node',
#    'id': 3461932854,
#    'lat': 40.4261719,
#    'lon': -3.7113935,
#    'tags': {'addr:city': 'Madrid',
#     'addr:housenumber': '5',
#     'addr:postcode': '28015',
#     'addr:street': 'Calle del Conde Duque',
#     'amenity': 'cafe',
#     'check_date': '2023-09-26',
#     'indoor_seating': 'yes',
#     'name': 'Siniestro',
#     'old_name': 'Don Diego',
#     'old_name_1': 'Condominium',
#     'outdoor_seating': 'no',
#     'wheelchair': 'no'}},
#   {'type': 'node',
#    'id': 3467969369,
#    'lat': 40.450462,
#    'lon': -3.7177781,
#    'tags': {'amenity': 'cafe', 'name': 'Facultad de Educación'}},
#   {'type': 'node',
#    'id': 3469038580,
#    'lat': 40.4476232,
#    'lon': -3.7170921,
#    'tags': {'amenity': 'cafe', 'name': 'Glacé'}},
#   {'type': 'node',
#    'id': 3471761960,
#    'lat': 40.4269219,
#    'lon': -3.7017004,
#    'tags': {'addr:city': 'Madrid',
#     'addr:housenumber': '93',
#     'addr:postcode': '28004',
#     'addr:street': 'Calle de Fuencarral',
#     'amenity': 'cafe',
#     'bar': 'yes',
#     'name': 'Caffé del Arte',
#     'opening_hours': 'Mo-Su,PH 08:00-02:00',
#     'operator': 'Ambarlis S.L.',
#     'ref:vatin': 'ESB81673725',
#     'toilets': 'yes',
#     'toilets:wheelchair': 'no',
#     'website:menu': 'https://smartmenu.agorapos.com/?id=ct6viosq#/',
#     'wheelchair': 'limited',
#     'wheelchair:description': 'Acceso bueno, no tiene aseo adaptado.'}},
#   {'type': 'node',
#    'id': 3472054306,
#    'lat': 40.4301567,
#    'lon': -3.7002708,
#    'tags': {'amenity': 'cafe',
#     'check_date': '2023-04-02',
#     'name': 'La Bohemia'}},
#   {'type': 'node',
#    'id': 3472111966,
#    'lat': 40.4364209,
#    'lon': -3.7155435,
#    'tags': {'amenity': 'cafe'}},
# ...
#     'outdoor_seating': 'no'}},
#   {'type': 'node',
#    'id': 12128565720,
#    'lat': 40.4287721,
#    'lon': -3.6751845,
#    'tags': {'addr:city': 'Madrid',
#     'addr:housenumber': '36',
#     'addr:postcode': '28006',
#     'addr:street': 'Calle del Conde de Peñalver',
#     'amenity': 'cafe',
#     'internet_access': 'wlan',
#     'internet_access:fee': 'no',
#     'name': 'Nata Artesanos',
#     'smoking': 'no'}},
#   {'type': 'node',
#    'id': 12147737601,
#    'lat': 40.4248823,
#    'lon': -3.6853284,
#    'tags': {'addr:housenumber': '42',
#     'addr:street': 'Calle de Lagasca',
#     'amenity': 'cafe',
#     'name': 'Hola Coffee',
#     'opening_hours': 'Mo-Fr 08:00-20:00; Sa-Su 09:00-20:00'}},
#   {'type': 'node',
#    'id': 12150041004,
#    'lat': 40.4631738,
#    'lon': -3.6914604,
#    'tags': {'amenity': 'cafe', 'name': 'Espresso Americano'}},
#   {'type': 'node',
#    'id': 12150047340,
#    'lat': 40.4622071,
#    'lon': -3.6915316,
#    'tags': {'amenity': 'cafe', 'name': 'Emka'}},
#   {'type': 'node',
#    'id': 12151268313,
#    'lat': 40.4364248,
#    'lon': -3.6907879,
#    'tags': {'addr:housenumber': '94',
#     'addr:street': 'Calle de García de Paredes',
#     'amenity': 'cafe',
#     'check_date': '2024-09-02',
#     'name': 'Donde Michel',
#     'wheelchair': 'limited'}},
#   {'type': 'node',
#    'id': 12153404469,
#    'lat': 40.4373766,
#    'lon': -3.7145528,
#    'tags': {'addr:housenumber': '41',
#     'addr:street': 'Calle de Joaquín María López',
#     'amenity': 'cafe',
#     'check_date': '2024-09-03',
#     'name': 'Chiripa',
#     'outdoor_seating': 'yes',
#     'wheelchair': 'no'}},
#   {'type': 'node',
#    'id': 12192547416,
#    'lat': 40.4287621,
#    'lon': -3.6750046,
#    'tags': {'amenity': 'cafe', 'name': 'Luspar'}},
#   {'type': 'node',
#    'id': 12197348001,
#    'lat': 40.4557835,
#    'lon': -3.6768661,
#    'tags': {'amenity': 'cafe',
#     'name': 'east crema coffee',
#     'opening_hours': 'Mo-Fr 08:00-20:00; Sa-Su 09:00-20:00',
#     'website': 'https://eastcrema.com/'}},
#   {'type': 'node',
#    'id': 12204136137,
#    'lat': 40.454907,
#    'lon': -3.6470256,
#    'tags': {'amenity': 'cafe',
#     'indoor_seating': 'yes',
#     'name': 'DeTaZa',
#     'outdoor_seating': 'yes'}},
#   {'type': 'node',
#    'id': 12204667764,
#    'lat': 40.4378061,
#    'lon': -3.7101494,
#    'tags': {'addr:housenumber': '75',
#     'addr:street': 'Calle de Galileo',
#     'amenity': 'cafe',
#     'check_date': '2024-09-27',
#     'name': 'Tosty',
#     'outdoor_seating': 'yes',
#     'wheelchair': 'limited'}},
#   {'type': 'node',
#    'id': 12204678874,
#    'lat': 40.4583398,
#    'lon': -3.6449659,
#    'tags': {'amenity': 'cafe', 'name': 'Cafetería Orgaz'}},
#   {'type': 'node',
#    'id': 12218205071,
#    'lat': 40.4366661,
#    'lon': -3.6922563,
#    'tags': {'addr:housenumber': '63',
#     'addr:street': 'Calle de García de Paredes',
#     'amenity': 'cafe',
#     'check_date': '2024-10-03',
#     'name': 'Quero',
#     'wheelchair': 'no'}},
#   {'type': 'node',
#    'id': 12231518334,
#    'lat': 40.4383345,
#    'lon': -3.7084485,
#    'tags': {'addr:housenumber': '77',
#     'addr:street': 'Calle de Vallehermoso',
#     'amenity': 'cafe',
#     'check_date': '2024-10-07',
#     'name': 'Los Gallego',
#     'outdoor_seating': 'yes',
#     'wheelchair': 'limited'}},
#   {'type': 'node',
#    'id': 12260741873,
#    'lat': 40.4366689,
#    'lon': -3.6435252,
#    'tags': {'amenity': 'cafe', 'name': 'Lexana'}},
#   {'type': 'node',
#    'id': 12270765326,
#    'lat': 40.4375899,
#    'lon': -3.6850623,
#    'tags': {'addr:housenumber': '24',
#     'addr:postcode': '28006',
#     'addr:street': 'Calle de María de Molina',
#     'amenity': 'cafe',
#     'contact:facebook': 'religioncoffee',
#     'contact:instagram': 'religioncoffee_',
#     'cuisine': 'breakfast;coffee_shop;mediterranean',
#     'email': 'info@religioncoffee.es',
#     'name': 'Religion - Specialty coffee',
#     'opening_hours': 'Mo-Fr 08:30-19:00; Sa-Su 09:00-18:00',
#     'phone': '910698221',
#     'website': 'http://www.religioncoffee.es/',
#     'website:menu': 'https://goo.su/vjwC'}},
#   {'type': 'node',
#    'id': 12282407976,
#    'lat': 40.4552286,
#    'lon': -3.6939508,
#    'tags': {'amenity': 'cafe',
#     'brand': 'Santagloria',
#     'brand:wikidata': 'Q54606497',
#     'name': 'Santagloria',
#     'shop': 'bakery'}},
#   {'type': 'node',
#    'id': 12337611000,
#    'lat': 40.4719695,
#    'lon': -3.6810751,
#    'tags': {'addr:floor': '0',
#     'amenity': 'cafe',
#     'check_date': '2024-12-05',
#     'internet_access': 'no',
#     'level': '1',
#     'name': 'Coffee Bakery',
#     'payment:cash': 'yes',
#     'payment:credit_cards': 'yes',
#     'payment:debit_cards': 'yes',
#     'source': 'survey',
#     'wheelchair': 'yes'}},
#   {'type': 'node',
#    'id': 12358856174,
#    'lat': 40.4719148,
#    'lon': -3.6821001,
#    'tags': {'addr:floor': '0',
#     'amenity': 'cafe',
#     'check_date': '2024-11-20',
#     'level': '1',
#     'name': 'Navelgas',
#     'outdoor_seating': 'no',
#     'source': 'survey',
#     'wheelchair': 'yes'}},
#   {'type': 'node',
#    'id': 12373777400,
#    'lat': 40.4501243,
#    'lon': -3.6505064,
#    'tags': {'amenity': 'cafe',
#     'level': '1',
#     'name': 'Taruffi',
#     'opening_hours': 'Mo-Su 09:00-22:00',
#     'website': 'https://www.taruffi.com/'}},
#   {'type': 'node',
#    'id': 12401772628,
#    'lat': 40.4423316,
#    'lon': -3.6408916,
#    'tags': {'amenity': 'cafe',
#     'cuisine': 'coffee_shop',
#     'indoor_seating': 'yes',
#     'name': "Junior's",
#     'outdoor_seating': 'yes'}},
#   {'type': 'node',
#    'id': 12433834360,
#    'lat': 40.4523274,
#    'lon': -3.6985211,
#    'tags': {'amenity': 'cafe'}},
#   {'type': 'node',
#    'id': 12462989865,
#    'lat': 40.4691085,
#    'lon': -3.6431502,
#    'tags': {'amenity': 'cafe', 'name': 'La Ruta del Café'}},
#   {'type': 'node',
#    'id': 12462993522,
#    'lat': 40.4689999,
#    'lon': -3.6435998,
#    'tags': {'amenity': 'cafe', 'name': "Miranda's"}},
#   {'type': 'node',
#    'id': 12463013424,
#    'lat': 40.4230155,
#    'lon': -3.7229213,
#    'tags': {'amenity': 'cafe', 'name': 'Kausa Madrid'}},
#   {'type': 'node',
#    'id': 12480940607,
#    'lat': 40.4374972,
#    'lon': -3.6381161,
#    'tags': {'amenity': 'cafe',
#     'cuisine': 'coffee_shop',
#     'name': 'Chocolate con Churros'}},
#   {'type': 'node',
#    'id': 12480941328,
#    'lat': 40.4276463,
#    'lon': -3.6689504,
#    'tags': {'amenity': 'cafe',
#     'cuisine': 'coffee_shop',
#     'name': 'Chocolate con Churros',
#     'wheelchair': 'limited'}},
#   {'type': 'node',
#    'id': 12480941329,
#    'lat': 40.4489409,
#    'lon': -3.6094696,
#    'tags': {'amenity': 'cafe',
#     'cuisine': 'coffee_shop',
#     'name': 'Chocolate con Churros'}},
#   {'type': 'node',
#    'id': 12627911757,
#    'lat': 40.423818,
#    'lon': -3.6769351,
#    'tags': {'addr:housenumber': '4',
#     'addr:street': 'Avenida Felipe II',
#     'amenity': 'cafe',
#     'check_date': '2025-02-26',
#     'cuisine': 'bubble_tea',
#     'level': '0',
#     'name': 'T8 tea bar',
#     'payment:cash': 'yes',
#     'payment:credit_cards': 'yes',
#     'payment:debit_cards': 'yes'}},
#   {'type': 'node',
#    'id': 12627911762,
#    'lat': 40.425434,
#    'lon': -3.713198,
#    'tags': {'addr:housenumber': '4',
#     'addr:street': 'Calle de Santa María Micaela',
#     'amenity': 'cafe',
#     'check_date': '2025-02-25',
#     'cuisine': 'coffee_shop;sandwich;korean',
#     'internet_access': 'wlan',
#     'internet_access:fee': 'customers',
#     'level': '0',
#     'name': 'Doku Toku',
#     'outdoor_seating': 'yes',
#     'payment:cash': 'yes',
#     'payment:credit_cards': 'yes',
#     'payment:debit_cards': 'yes',
#     'wheelchair': 'yes'}},
#   {'type': 'node',
#    'id': 12629140147,
#    'lat': 40.4246153,
#    'lon': -3.6689597,
#    'tags': {'addr:housenumber': '143',
#     'addr:street': 'Calle de Goya',
#     'amenity': 'cafe',
#     'name': 'Panaria',
#     'phone': '644634898',
#     'takeaway': 'yes',
#     'website': 'https://panariapanaderias.es'}},
#   {'type': 'node',
#    'id': 12668675124,
#    'lat': 40.4281668,
#    'lon': -3.7041952,
#    'tags': {'amenity': 'cafe', 'name': 'Ajenjo Cafe'}},
#   {'type': 'node',
#    'id': 12681286403,
#    'lat': 40.4294675,
#    'lon': -3.6738323,
#    'tags': {'addr:city': 'Madrid',
#     'addr:postcode': '28006',
#     'addr:street': 'Calle Alcántara',
#     'amenity': 'cafe',
#     'cuisine': 'coffee_shop',
#     'name': 'Sinfonía'}},
#   {'type': 'node',
#    'id': 12681286407,
#    'lat': 40.4293822,
#    'lon': -3.6751441,
#    'tags': {'addr:city': 'Madrid',
#     'addr:housenumber': '44',
#     'addr:street': 'Calle del Conde de Peñalver',
#     'amenity': 'cafe',
#     'name': 'Taiga'}},
#   {'type': 'node',
#    'id': 12687210821,
#    'lat': 40.4360628,
#    'lon': -3.6984488,
#    'tags': {'addr:city': 'Madrid',
#     'addr:housenumber': '6',
#     'addr:postcode': '28010',
#     'addr:street': 'Calle Ponce de León',
#     'amenity': 'cafe',
#     'contact:instagram': 'https://www.instagram.com/beikbeik.mad',
#     'cuisine': 'breakfast',
#     'email': 'beikbeikmad@gmail.com',
#     'fast_food': 'cafeteria',
#     'name': 'Beik Beik',
#     'opening_hours': 'Tu-Th 09:00-19:00; Fr 09:00-15:00; Sa-Su 09:30-15:00; Mo off; PH off',
#     'outdoor_seating': 'no',
#     'phone': '+34 639 914 387'}},
#   {'type': 'node',
#    'id': 12688373845,
#    'lat': 40.4261779,
#    'lon': -3.6792458,
#    'tags': {'addr:housenumber': '67',
#     'addr:street': 'Calle de Hermosilla',
#     'amenity': 'cafe',
#     'diet:gluten_free': 'yes',
#     'name': 'Le Sweet',
#     'opening_hours': 'Mo-Sa 12:00-19:30',
#     'phone': '664312750',
#     'takeaway': 'yes',
#     'website': 'https://lesweet.es/'}},
#   {'type': 'node',
#    'id': 12691393341,
#    'lat': 40.4390271,
#    'lon': -3.6291333,
#    'tags': {'amenity': 'cafe', 'name': 'Fanático'}},
#   {'type': 'node',
#    'id': 12692718401,
#    'lat': 40.4322883,
#    'lon': -3.7032303,
#    'tags': {'addr:housenumber': '3',
#     'addr:postcode': '28010',
#     'addr:street': 'Calle de Gonzalo de Córdoba',
#     'amenity': 'cafe',
#     'contact:instagram': 'dosiscafe',
#     'cuisine': 'breakfast;coffee_shop',
#     'internet_access': 'wlan',
#     'name': 'Dosis Cafe',
#     'website': 'https://dosiscafe.es/'}},
#   {'type': 'node',
#    'id': 12778278009,
#    'lat': 40.4392562,
#    'lon': -3.7066155,
#    'tags': {'amenity': 'cafe',
#     'check_date': '2025-04-23',
#     'name': 'Roan',
#     'outdoor_seating': 'yes',
#     'wheelchair': 'no'}},
#   {'type': 'node',
#    'id': 12809158536,
#    'lat': 40.4333349,
#    'lon': -3.7007443,
#    'tags': {'amenity': 'cafe',
#     'cuisine': 'coffee_shop',
#     'name': 'La casa Amande',
#     'survey:date': '2025-05-04'}},
#   {'type': 'node',
#    'id': 12809645117,
#    'lat': 40.4231582,
#    'lon': -3.707614,
#    'tags': {'amenity': 'cafe', 'name': 'Vivari', 'survey:date': '2025-05-04'}},
#   {'type': 'node',
#    'id': 12825294142,
#    'lat': 40.4323666,
#    'lon': -3.7172989,
#    'tags': {'amenity': 'cafe',
#     'brand': 'Santagloria',
#     'brand:wikidata': 'Q54606497',
#     'name': 'Santagloria',
#     'shop': 'bakery',
#     'survey:date': '2025-05-10'}},
#   {'type': 'node',
#    'id': 12844750069,
#    'lat': 40.4376458,
#    'lon': -3.6508643,
#    'tags': {'amenity': 'cafe', 'name': 'La Panera Rosa'}},
#   {'type': 'node',
#    'id': 12880638608,
#    'lat': 40.4361303,
#    'lon': -3.7049327,
#    'tags': {'addr:housenumber': '4',
#     'addr:street': 'Calle de Donoso Cortés',
#     'amenity': 'cafe',
#     'check_date': '2025-06-02',
#     'cuisine': 'coffee_shop',
#     'name': '29|30',
#     'wheelchair': 'no'}},
#   {'type': 'node',
#    'id': 12880638615,
#    'lat': 40.4361527,
#    'lon': -3.7052455,
#    'tags': {'addr:housenumber': '8',
#     'addr:street': 'Calle de Donoso Cortés',
#     'amenity': 'cafe',
#     'check_date': '2025-06-02',
#     'cuisine': 'coffee_shop',
#     'name': 'Vanille',
#     'wheelchair': 'limited'}},
#   {'type': 'node',
#    'id': 12888834201,
#    'lat': 40.4361344,
#    'lon': -3.6931833,
#    'tags': {'amenity': 'cafe', 'name': 'Libis'}},
#   {'type': 'node',
#    'id': 12902402678,
#    'lat': 40.4235878,
#    'lon': -3.7025829,
#    'tags': {'air_conditioning': 'yes',
#     'amenity': 'cafe',
#     'check_date': '2025-06',
#     'indoor_seating': 'yes',
#     'internet_access': 'wlan',
#     'name': 'HanSo Café',
#     'outdoor_seating': 'no',
#     'toilets': 'yes'}},
#   {'type': 'node',
#    'id': 12957360578,
#    'lat': 40.4271056,
#    'lon': -3.6581608,
#    'tags': {'amenity': 'cafe', 'name': 'Cafetería Nico', 'wheelchair': 'no'}},
#   {'type': 'node',
#    'id': 12958941701,
#    'lat': 40.4395092,
#    'lon': -3.6791859,
#    'tags': {'addr:housenumber': '109',
#     'addr:street': 'Calle del Príncipe de Vergara',
#     'amenity': 'cafe',
#     'cuisine': 'coffee_shop',
#     'name': 'Mina Specialty Coffee'}},
#   {'type': 'node',
#    'id': 13007334813,
#    'lat': 40.4321445,
#    'lon': -3.7005547,
#    'tags': {'addr:city': 'Madrid',
#     'addr:housenumber': '20',
#     'addr:postcode': '28010',
#     'addr:street': 'Calle Trafalgar',
#     'amenity': 'cafe',
#     'cuisine': 'coffee_shop',
#     'name': 'Catedral Cafe Madrid',
#     'takeaway': 'yes',
#     'website': 'https://www.instagram.com/catedralcafemadrid/',
#     'website:menu': 'https://tr.ee/cN1J1QIbJ-'}},
#   {'type': 'node',
#    'id': 13017460373,
#    'lat': 40.4317996,
#    'lon': -3.7159251,
#    'tags': {'amenity': 'cafe',
#     'cuisine': 'coffee_shop',
#     'name': 'To be coffee',
#     'survey:date': '2025-07-22'}},
#   {'type': 'node',
#    'id': 13017460375,
#    'lat': 40.4318493,
#    'lon': -3.7167604,
#    'tags': {'amenity': 'cafe', 'name': 'Porto', 'survey:date': '2025-07-22'}},
#   {'type': 'node',
#    'id': 13026492102,
#    'lat': 40.4255085,
#    'lon': -3.6787415,
#    'tags': {'addr:housenumber': '15',
#     'addr:street': 'Calle del General Pardiñas',
#     'amenity': 'cafe',
#     'cuisine': 'breakfast;coffee_shop;pancake;tea',
#     'name': 'Norah Coffee & Brunch',
#     'opening_hours': 'Su-We 09:00-18:30; Th-Sa 09:00-19:00'}},
#   {'type': 'node',
#    'id': 13026515001,
#    'lat': 40.4251148,
#    'lon': -3.6790471,
#    'tags': {'addr:housenumber': '73',
#     'addr:street': 'Calle de Goya',
#     'amenity': 'cafe',
#     'name': 'Starbucks',
#     'opening_hours': 'Mo-Fr 07:30-22:00; Sa-Su 08:00-22:00'}},
#   {'type': 'node',
#    'id': 13041426802,
#    'lat': 40.4221611,
#    'lon': -3.6973358,
#    'tags': {'addr:housenumber': '37',
#     'addr:street': 'Calle de Augusto Figueroa',
#     'amenity': 'cafe',
#     'cuisine': 'coffee_shop;tea',
#     'name': 'ALFAR',
#     'opening_hours': 'Mo-Fr 08:00-19:00; Sa 09:00-19:00; Su 09:00-16:30'}},
#   {'type': 'node',
#    'id': 13057611191,
#    'lat': 40.4255698,
#    'lon': -3.6709906,
#    'tags': {'amenity': 'cafe',
#     'brand': 'Santagloria',
#     'brand:wikidata': 'Q54606497',
#     'name': 'Santagloria',
#     'shop': 'bakery',
#     'survey:date': '2025-08-08'}},
#   {'type': 'node',
#    'id': 13114656901,
#    'lat': 40.4228625,
#    'lon': -3.6890506,
#    'tags': {'amenity': 'cafe'}},
#   {'type': 'node',
#    'id': 13159603798,
#    'lat': 40.4250519,
#    'lon': -3.6979142,
#    'tags': {'addr:city': 'Madrid',
#     'addr:housenumber': '73',
#     'addr:postcode': '28004',
#     'addr:street': 'Calle de Hortaleza',
#     'amenity': 'cafe',
#     'contact:instagram': 'https://www.instagram.com/kohi.bakery',
#     'name': 'Kōhī',
#     'opening_hours': 'Mo-Su 09:00-20:00',
#     'outdoor_seating': 'no'}},
#   {'type': 'node',
#    'id': 13159799784,
#    'lat': 40.4293549,
#    'lon': -3.7076833,
#    'tags': {'amenity': 'cafe', 'name': 'Cofi.', 'survey:date': '2025-09-21'}},
#   {'type': 'node',
#    'id': 13159885443,
#    'lat': 40.424953,
#    'lon': -3.7124064,
#    'tags': {'amenity': 'cafe', 'name': 'Beher', 'survey:date': '2025-09-21'}},
#   {'type': 'node',
#    'id': 13165954328,
#    'lat': 40.4317121,
#    'lon': -3.7021939,
#    'tags': {'amenity': 'cafe', 'name': 'Naji', 'source': 'survey'}},
#   {'type': 'node',
#    'id': 13174973089,
#    'lat': 40.4225232,
#    'lon': -3.674902,
#    'tags': {'amenity': 'cafe',
#     'changing_table': 'no',
#     'diet:vegan': 'yes',
#     'diet:vegetarian': 'yes',
#     'name': 'Sau Dade',
#     'smoking': 'no',
#     'wheelchair': 'limited'}},
#   {'type': 'node',
#    'id': 13184793310,
#    'lat': 40.4227677,
#    'lon': -3.7017135,
#    'tags': {'addr:housenumber': '31',
#     'addr:street': 'Calle de Valverde',
#     'amenity': 'cafe',
#     'diet:vegan': 'only',
#     'diet:vegetarian': 'only',
#     'name': 'Fuga Madrid',
#     'opening_hours': 'Tu-Su 11:00-17:00; Mo off'}}]}

# %%
def json_to_dataframe(data_entrada):
    elements = data_entrada['elements']
    places = {'lat': [], 'lon': [], 'name': [], 'address': []}

    for i in elements:
        lalitude = i['lat']
        longitude = i['lon']
        name = i['tags'].get('name')
        street = i['tags'].get('addr:street', 'Sin calle')
        number = i['tags'].get('addr:housenumber', 0)
        
        places['lat'].append(lalitude)
        places['lon'].append(longitude)
        places['name'].append(name)
        places['address'].append(str(street) + ' ' + str(number))

    df = pd.DataFrame(places)
    
    return df

# %%
df_return = json_to_dataframe(data)
df_return
# Out:
#            lat       lon                    name                     address
# 0    40.446378 -3.714901                Condemar                 Sin calle 0
# 1    40.442532 -3.651707                  Torres                 Sin calle 0
# 2    40.429240 -3.722419                 Magadán  Paseo del Pintor Rosales 0
# 3    40.437727 -3.663535      Cafetería Bruselas                 Sin calle 0
# 4    40.448237 -3.723829  Facultad de Forestales                 Sin calle 0
# ..         ...       ...                     ...                         ...
# 540  40.429355 -3.707683                   Cofi.                 Sin calle 0
# 541  40.424953 -3.712406                   Beher                 Sin calle 0
# 542  40.431712 -3.702194                    Naji                 Sin calle 0
# 543  40.422523 -3.674902                Sau Dade                 Sin calle 0
# 544  40.422768 -3.701713             Fuga Madrid        Calle de Valverde 31
#
# [545 rows x 4 columns]

# %%
# lista_responses = [data1, data2, data3, data4]
# for data in lista_responses:
#     df_return = json_to_dataframe(data)
#     df_results = df_results.concat(df_return)

# %% [markdown]
# ## Datos del espacio

# %%
'''
https://thespacedevs.com/llapi
https://ll.thespacedevs.com/2.2.0/swagger
'''

space_url = "http://ll.thespacedevs.com/2.2.0"

path = "/astronaut"

url_total = space_url + path

response = requests.get(url_total)

# %%
print(response)
response.json()
# Out:
# <Response [200]>
# {'count': 829,
#  'next': 'https://ll.thespacedevs.com/2.2.0/astronaut/?limit=10&offset=10',
#  'previous': None,
#  'results': [{'id': 1,
#    'url': 'https://ll.thespacedevs.com/2.2.0/astronaut/1/',
#    'name': 'Thomas Pesquet',
#    'status': {'id': 1, 'name': 'Active'},
#    'type': {'id': 2, 'name': 'Government'},
#    'in_space': False,
#    'time_in_space': 'P396DT11H33M45S',
#    'eva_time': 'P1DT15H54M',
#    'age': 47,
#    'date_of_birth': '1978-02-27',
#    'date_of_death': None,
#    'nationality': 'French',
#    'bio': 'Thomas Gautier Pesquet is a French aerospace engineer, pilot, and European Space Agency astronaut. Pesquet was selected by ESA as a candidate in May 2009, and he successfully completed his basic training in November 2010. From November 2016 to June 2017, Pesquet was part of Expeditions 50 and 51 on the International Space Station as a flight engineer.',
#    'twitter': 'https://twitter.com/Thom_astro',
#    'instagram': 'https://instagram.com/thom_astro',
#    'wiki': 'https://en.wikipedia.org/wiki/Thomas_Pesquet',
#    'agency': {'id': 27,
#     'url': 'https://ll.thespacedevs.com/2.2.0/agencies/27/',
#     'name': 'European Space Agency',
#     'featured': False,
#     'type': 'Multinational',
#     'country_code': 'FRA,ITA,DEU,ESP,CHE,GBR,AUT,SWE,PRT,NLD,HUN,POL,DNK,CZE,ROU,NOR,FIN,GRC,EST,IRL,LUX,BEL,SVN',
#     'abbrev': 'ESA',
#     'description': "The European Space Agency is an intergovernmental organisation of 22 member states. Established in 1975 and headquartered in Paris, France, ESA has a worldwide staff of about 2,000 employees.\r\n\r\nESA's space flight programme includes human spaceflight (mainly through participation in the International Space Station program); the launch and operation of unmanned exploration missions to other planets and the Moon; Earth observation, science and telecommunication; designing launch vehicles; and maintaining a major spaceport, the Guiana Space Centre at Kourou, French Guiana.",
#     'administrator': 'Director General: Josef Aschbacher',
#     'founding_year': '1975',
#     'launchers': 'Ariane | Vega',
#     'spacecraft': 'Space Rider',
#     'parent': None,
#     'image_url': 'https://thespacedevs-prod.nyc3.digitaloceanspaces.com/media/images/esa_patch_float_image_20250211192109.png',
#     'logo_url': 'https://thespacedevs-prod.nyc3.digitaloceanspaces.com/media/images/european2520space2520agency_logo_20221130101442.png'},
#    'profile_image': 'https://thespacedevs-prod.nyc3.digitaloceanspaces.com/media/images/thomas2520pesquet_image_20200102120546.jpeg',
#    'profile_image_thumbnail': 'https://thespacedevs-prod.nyc3.digitaloceanspaces.com/media/images/255bauto255d__image_thumbnail_20240305190357.jpeg',
#    'flights_count': 2,
#    'landings_count': 2,
#    'spacewalks_count': 6,
#    'last_flight': '2021-04-23T09:49:02Z',
#    'first_flight': '2016-11-17T20:20:13Z'},
#   {'id': 2,
#    'url': 'https://ll.thespacedevs.com/2.2.0/astronaut/2/',
#    'name': 'Claude Nicollier',
#    'status': {'id': 2, 'name': 'Retired'},
#    'type': {'id': 2, 'name': 'Government'},
#    'in_space': False,
#    'time_in_space': 'P42DT12H3M12S',
#    'eva_time': 'PT8H10M',
#    'age': 81,
#    'date_of_birth': '1944-09-02',
#    'date_of_death': None,
#    'nationality': 'Swiss',
#    'bio': 'Claude Nicollier is the first astronaut from Switzerland. He has flown on four Space Shuttle missions. His first spaceflight (STS-46) was in 1992, and his final spaceflight (STS-103) was in 1999. He took part in two servicing missions to the Hubble Space Telescope (called STS-61 and STS-103). During his final spaceflight he participated in a spacewalk, becoming the first European Space Agency astronaut to do so during a Space Shuttle mission. In 2000 he was assigned to the Astronaut Office Extravehicular Activity Branch, while maintaining a position as Lead ESA Astronaut in Houston. Nicollier retired from ESA in April 2007.',
#    'twitter': 'https://twitter.com/Astroclaude',
#    'instagram': None,
#    'wiki': 'https://en.wikipedia.org/wiki/Claude_Nicollier',
#    'agency': {'id': 27,
#     'url': 'https://ll.thespacedevs.com/2.2.0/agencies/27/',
#     'name': 'European Space Agency',
#     'featured': False,
#     'type': 'Multinational',
#     'country_code': 'FRA,ITA,DEU,ESP,CHE,GBR,AUT,SWE,PRT,NLD,HUN,POL,DNK,CZE,ROU,NOR,FIN,GRC,EST,IRL,LUX,BEL,SVN',
#     'abbrev': 'ESA',
#     'description': "The European Space Agency is an intergovernmental organisation of 22 member states. Established in 1975 and headquartered in Paris, France, ESA has a worldwide staff of about 2,000 employees.\r\n\r\nESA's space flight programme includes human spaceflight (mainly through participation in the International Space Station program); the launch and operation of unmanned exploration missions to other planets and the Moon; Earth observation, science and telecommunication; designing launch vehicles; and maintaining a major spaceport, the Guiana Space Centre at Kourou, French Guiana.",
#     'administrator': 'Director General: Josef Aschbacher',
#     'founding_year': '1975',
#     'launchers': 'Ariane | Vega',
#     'spacecraft': 'Space Rider',
#     'parent': None,
#     'image_url': 'https://thespacedevs-prod.nyc3.digitaloceanspaces.com/media/images/esa_patch_float_image_20250211192109.png',
#     'logo_url': 'https://thespacedevs-prod.nyc3.digitaloceanspaces.com/media/images/european2520space2520agency_logo_20221130101442.png'},
#    'profile_image': 'https://thespacedevs-prod.nyc3.digitaloceanspaces.com/media/images/claude2520nicollier_image_20181127203218.jpg',
#    'profile_image_thumbnail': 'https://thespacedevs-prod.nyc3.digitaloceanspaces.com/media/images/255bauto255d__image_thumbnail_20240305185551.jpeg',
#    'flights_count': 4,
#    'landings_count': 4,
#    'spacewalks_count': 1,
#    'last_flight': '1999-12-20T00:50:00Z',
#    'first_flight': '1992-07-31T13:56:48Z'},
#   {'id': 3,
#    'url': 'https://ll.thespacedevs.com/2.2.0/astronaut/3/',
#    'name': 'Tim Peake',
#    'status': {'id': 2, 'name': 'Retired'},
#    'type': {'id': 2, 'name': 'Government'},
#    'in_space': False,
#    'time_in_space': 'P185DT22H11M51S',
#    'eva_time': 'PT4H43M',
#    'age': 53,
#    'date_of_birth': '1972-04-07',
#    'date_of_death': None,
#    'nationality': 'British',
#    'bio': "Major Timothy Nigel Peake CMG is a British Army Air Corps officer, former European Space Agency astronaut and International Space Station (ISS) crew member.  He is the first British ESA astronaut, the second astronaut to bear a flag of the United Kingdom patch, the sixth person born in the United Kingdom to go on board the International Space Station and the seventh UK-born person in space. He began the ESA's intensive astronaut basic training course in September 2009 and graduated on 22 November 2010",
#    'twitter': 'https://twitter.com/astro_timpeake',
#    'instagram': 'https://www.instagram.com/astro_timpeake/',
#    'wiki': 'https://en.wikipedia.org/wiki/Tim_Peake',
#    'agency': {'id': 27,
#     'url': 'https://ll.thespacedevs.com/2.2.0/agencies/27/',
#     'name': 'European Space Agency',
#     'featured': False,
#     'type': 'Multinational',
#     'country_code': 'FRA,ITA,DEU,ESP,CHE,GBR,AUT,SWE,PRT,NLD,HUN,POL,DNK,CZE,ROU,NOR,FIN,GRC,EST,IRL,LUX,BEL,SVN',
#     'abbrev': 'ESA',
#     'description': "The European Space Agency is an intergovernmental organisation of 22 member states. Established in 1975 and headquartered in Paris, France, ESA has a worldwide staff of about 2,000 employees.\r\n\r\nESA's space flight programme includes human spaceflight (mainly through participation in the International Space Station program); the launch and operation of unmanned exploration missions to other planets and the Moon; Earth observation, science and telecommunication; designing launch vehicles; and maintaining a major spaceport, the Guiana Space Centre at Kourou, French Guiana.",
#     'administrator': 'Director General: Josef Aschbacher',
#     'founding_year': '1975',
#     'launchers': 'Ariane | Vega',
#     'spacecraft': 'Space Rider',
#     'parent': None,
#     'image_url': 'https://thespacedevs-prod.nyc3.digitaloceanspaces.com/media/images/esa_patch_float_image_20250211192109.png',
#     'logo_url': 'https://thespacedevs-prod.nyc3.digitaloceanspaces.com/media/images/european2520space2520agency_logo_20221130101442.png'},
#    'profile_image': 'https://thespacedevs-prod.nyc3.digitaloceanspaces.com/media/images/tim_peake_image_20230120154350.jpg',
#    'profile_image_thumbnail': 'https://thespacedevs-prod.nyc3.digitaloceanspaces.com/media/images/255bauto255d__image_thumbnail_20240305185843.jpeg',
#    'flights_count': 1,
#    'landings_count': 1,
#    'spacewalks_count': 1,
#    'last_flight': '2015-12-15T11:03:09Z',
#    'first_flight': '2015-12-15T11:03:09Z'},
#   {'id': 4,
#    'url': 'https://ll.thespacedevs.com/2.2.0/astronaut/4/',
#    'name': 'Buzz Aldrin',
#    'status': {'id': 2, 'name': 'Retired'},
#    'type': {'id': 2, 'name': 'Government'},
#    'in_space': False,
#    'time_in_space': 'P9DT8H43M58S',
#    'eva_time': 'PT8H1M40S',
#    'age': 95,
#    'date_of_birth': '1930-01-20',
#    'date_of_death': None,
#    'nationality': 'American',
#    'bio': 'Buzz Aldrin; born Edwin Eugene Aldrin Jr.; is an American engineer, former astronaut, and fighter pilot.\r\nAs Lunar Module Pilot on the Apollo 11 mission, he and mission commander Neil Armstrong were the first two humans to land on the Moon.',
#    'twitter': 'https://twitter.com/TheRealBuzz',
#    'instagram': 'https://www.instagram.com/drbuzzaldrin/',
#    'wiki': 'https://en.wikipedia.org/wiki/Buzz_Aldrin',
#    'agency': {'id': 44,
#     'url': 'https://ll.thespacedevs.com/2.2.0/agencies/44/',
#     'name': 'National Aeronautics and Space Administration',
#     'featured': True,
#     'type': 'Government',
#     'country_code': 'USA',
#     'abbrev': 'NASA',
#     'description': 'The National Aeronautics and Space Administration is an independent agency of the executive branch of the United States federal government responsible for the civilian space program, as well as aeronautics and aerospace research. NASA have many launch facilities but most are inactive. The most commonly used pad will be LC-39B at Kennedy Space Center in Florida.',
#     'administrator': 'Acting Administrator:  James Free',
#     'founding_year': '1958',
#     'launchers': 'Space Shuttle | SLS',
#     'spacecraft': 'Orion',
#     'parent': None,
#     'image_url': 'https://thespacedevs-prod.nyc3.digitaloceanspaces.com/media/images/national2520aeronautics2520and2520space2520administration_image_20190207032448.jpeg',
#     'logo_url': 'https://thespacedevs-prod.nyc3.digitaloceanspaces.com/media/images/national2520aeronautics2520and2520space2520administration_logo_20190207032448.png'},
#    'profile_image': 'https://thespacedevs-prod.nyc3.digitaloceanspaces.com/media/images/buzz_aldrin_image_20220911034547.jpeg',
#    'profile_image_thumbnail': 'https://thespacedevs-prod.nyc3.digitaloceanspaces.com/media/images/255bauto255d__image_thumbnail_20240305185225.jpeg',
#    'flights_count': 2,
#    'landings_count': 2,
#    'spacewalks_count': 4,
#    'last_flight': '1969-07-21T17:54:00Z',
#    'first_flight': '1966-11-11T20:46:33Z'},
#   {'id': 5,
#    'url': 'https://ll.thespacedevs.com/2.2.0/astronaut/5/',
#    'name': 'Chris Hadfield',
#    'status': {'id': 2, 'name': 'Retired'},
#    'type': {'id': 2, 'name': 'Government'},
#    'in_space': False,
#    'time_in_space': 'P165DT16H19M',
#    'eva_time': 'PT14H50M',
#    'age': 66,
#    'date_of_birth': '1959-08-29',
#    'date_of_death': None,
#    'nationality': 'Canadian',
#    'bio': 'Chris Austin Hadfield is a Canadian retired astronaut, engineer, and former Royal Canadian Air Force fighter pilot.\r\nThe first Canadian to walk in space, Hadfield has flown two space shuttle missions and served as commander of the International Space Station.',
#    'twitter': 'https://twitter.com/Cmdr_Hadfield',
#    'instagram': 'https://www.instagram.com/colchrishadfield/',
#    'wiki': 'https://en.wikipedia.org/wiki/Chris_Hadfield',
#    'agency': {'id': 16,
#     'url': 'https://ll.thespacedevs.com/2.2.0/agencies/16/',
#     'name': 'Canadian Space Agency',
#     'featured': False,
#     'type': 'Government',
#     'country_code': 'CAN',
#     'abbrev': 'CSA',
#     'description': 'The Canadian Space Agency was established by the Canadian Space Agency Act which received Royal Assent on May 10, 1990. \r\n\r\nThe Canadian space program is administered by the Canadian Space Agency. Canada has contributed technology, expertise and personnel to the world space effort, especially in collaboration with ESA and NASA. In addition to its astronauts and satellites, some of the most notable Canadian technological contributions to space exploration include the Canadarm on the Space Shuttle and Canadarm2 on the International Space Station.',
#     'administrator': 'President: Lisa Campbell',
#     'founding_year': '1990',
#     'launchers': '',
#     'spacecraft': '',
#     'parent': None,
#     'image_url': None,
#     'logo_url': 'https://thespacedevs-prod.nyc3.digitaloceanspaces.com/media/images/canadian2520space2520agency_logo_20231122160211.png'},
#    'profile_image': 'https://thespacedevs-prod.nyc3.digitaloceanspaces.com/media/images/chris_hadfield_image_20220911034200.jpeg',
#    'profile_image_thumbnail': 'https://thespacedevs-prod.nyc3.digitaloceanspaces.com/media/images/255bauto255d__image_thumbnail_20240305190208.jpeg',
#    'flights_count': 3,
#    'landings_count': 3,
#    'spacewalks_count': 2,
#    'last_flight': '2012-12-19T12:12:35Z',
#    'first_flight': '1995-11-12T12:30:43Z'},
#   {'id': 6,
#    'url': 'https://ll.thespacedevs.com/2.2.0/astronaut/6/',
#    'name': 'David Saint-Jacques',
#    'status': {'id': 1, 'name': 'Active'},
#    'type': {'id': 2, 'name': 'Government'},
#    'in_space': False,
#    'time_in_space': 'P203DT12H28M8S',
#    'eva_time': 'PT6H29M',
#    'age': 55,
#    'date_of_birth': '1970-01-06',
#    'date_of_death': None,
#    'nationality': 'Canadian',
#    'bio': 'David Saint-Jacques is a Canadian astronaut with the Canadian Space Agency (CSA).\r\nHe was also an engineer, an astrophysicist, and a physician prior to joining the CSA.\r\nHe was selected to join the CSA in the 2009 CSA selection along with Jeremy Hansen.',
#    'twitter': 'https://twitter.com/Astro_DavidS',
#    'instagram': 'https://www.instagram.com/astrodavids/',
#    'wiki': 'https://en.wikipedia.org/wiki/David_Saint-Jacques',
#    'agency': {'id': 16,
#     'url': 'https://ll.thespacedevs.com/2.2.0/agencies/16/',
#     'name': 'Canadian Space Agency',
#     'featured': False,
#     'type': 'Government',
#     'country_code': 'CAN',
#     'abbrev': 'CSA',
#     'description': 'The Canadian Space Agency was established by the Canadian Space Agency Act which received Royal Assent on May 10, 1990. \r\n\r\nThe Canadian space program is administered by the Canadian Space Agency. Canada has contributed technology, expertise and personnel to the world space effort, especially in collaboration with ESA and NASA. In addition to its astronauts and satellites, some of the most notable Canadian technological contributions to space exploration include the Canadarm on the Space Shuttle and Canadarm2 on the International Space Station.',
#     'administrator': 'President: Lisa Campbell',
#     'founding_year': '1990',
#     'launchers': '',
#     'spacecraft': '',
#     'parent': None,
#     'image_url': None,
#     'logo_url': 'https://thespacedevs-prod.nyc3.digitaloceanspaces.com/media/images/canadian2520space2520agency_logo_20231122160211.png'},
#    'profile_image': 'https://thespacedevs-prod.nyc3.digitaloceanspaces.com/media/images/david_saint-jac_image_20220911034207.jpeg',
#    'profile_image_thumbnail': 'https://thespacedevs-prod.nyc3.digitaloceanspaces.com/media/images/255bauto255d__image_thumbnail_20240305191004.jpeg',
#    'flights_count': 1,
#    'landings_count': 1,
#    'spacewalks_count': 1,
#    'last_flight': '2018-12-03T11:31:52Z',
#    'first_flight': '2018-12-03T11:31:52Z'},
#   {'id': 7,
#    'url': 'https://ll.thespacedevs.com/2.2.0/astronaut/7/',
#    'name': 'Anne McClain',
#    'status': {'id': 1, 'name': 'Active'},
#    'type': {'id': 2, 'name': 'Government'},
#    'in_space': False,
#    'time_in_space': 'P351DT4H57M40S',
#    'eva_time': 'PT18H52M',
#    'age': 46,
#    'date_of_birth': '1979-06-07',
#    'date_of_death': None,
#    'nationality': 'American',
#    'bio': 'Anne Charlotte McClain is a lieutenant colonel in the U.S. Army currently assigned to NASA Astronaut Group 21.',
#    'twitter': 'https://twitter.com/AstroAnnimal',
#    'instagram': None,
#    'wiki': 'https://en.wikipedia.org/wiki/Anne_McClain',
#    'agency': {'id': 44,
#     'url': 'https://ll.thespacedevs.com/2.2.0/agencies/44/',
#     'name': 'National Aeronautics and Space Administration',
#     'featured': True,
#     'type': 'Government',
#     'country_code': 'USA',
#     'abbrev': 'NASA',
#     'description': 'The National Aeronautics and Space Administration is an independent agency of the executive branch of the United States federal government responsible for the civilian space program, as well as aeronautics and aerospace research. NASA have many launch facilities but most are inactive. The most commonly used pad will be LC-39B at Kennedy Space Center in Florida.',
#     'administrator': 'Acting Administrator:  James Free',
#     'founding_year': '1958',
#     'launchers': 'Space Shuttle | SLS',
#     'spacecraft': 'Orion',
#     'parent': None,
#     'image_url': 'https://thespacedevs-prod.nyc3.digitaloceanspaces.com/media/images/national2520aeronautics2520and2520space2520administration_image_20190207032448.jpeg',
#     'logo_url': 'https://thespacedevs-prod.nyc3.digitaloceanspaces.com/media/images/national2520aeronautics2520and2520space2520administration_logo_20190207032448.png'},
#    'profile_image': 'https://thespacedevs-prod.nyc3.digitaloceanspaces.com/media/images/anne2520mcclain_image_20181127210625.jpg',
#    'profile_image_thumbnail': 'https://thespacedevs-prod.nyc3.digitaloceanspaces.com/media/images/255bauto255d__image_thumbnail_20240305185442.jpeg',
#    'flights_count': 2,
#    'landings_count': 2,
#    'spacewalks_count': 3,
#    'last_flight': '2025-03-14T23:03:48Z',
#    'first_flight': '2018-12-03T11:31:52Z'},
#   {'id': 8,
#    'url': 'https://ll.thespacedevs.com/2.2.0/astronaut/8/',
#    'name': 'Andrew R. Morgan',
#    'status': {'id': 1, 'name': 'Active'},
#    'type': {'id': 2, 'name': 'Government'},
#    'in_space': False,
#    'time_in_space': 'P271DT12H48M22S',
#    'eva_time': 'P1DT21H48M',
#    'age': 49,
#    'date_of_birth': '1976-02-05',
#    'date_of_death': None,
#    'nationality': 'American',
#    'bio': 'Andrew Richard "Drew" Morgan is a NASA astronaut from the class of 2013.',
#    'twitter': 'https://twitter.com/AstroDrewMorgan',
#    'instagram': 'https://www.instagram.com/astrodrewmorgan/',
#    'wiki': 'https://en.wikipedia.org/wiki/Andrew_R._Morgan',
#    'agency': {'id': 44,
#     'url': 'https://ll.thespacedevs.com/2.2.0/agencies/44/',
#     'name': 'National Aeronautics and Space Administration',
#     'featured': True,
#     'type': 'Government',
#     'country_code': 'USA',
#     'abbrev': 'NASA',
#     'description': 'The National Aeronautics and Space Administration is an independent agency of the executive branch of the United States federal government responsible for the civilian space program, as well as aeronautics and aerospace research. NASA have many launch facilities but most are inactive. The most commonly used pad will be LC-39B at Kennedy Space Center in Florida.',
#     'administrator': 'Acting Administrator:  James Free',
#     'founding_year': '1958',
#     'launchers': 'Space Shuttle | SLS',
#     'spacecraft': 'Orion',
#     'parent': None,
#     'image_url': 'https://thespacedevs-prod.nyc3.digitaloceanspaces.com/media/images/national2520aeronautics2520and2520space2520administration_image_20190207032448.jpeg',
#     'logo_url': 'https://thespacedevs-prod.nyc3.digitaloceanspaces.com/media/images/national2520aeronautics2520and2520space2520administration_logo_20190207032448.png'},
#    'profile_image': 'https://thespacedevs-prod.nyc3.digitaloceanspaces.com/media/images/andrew_r._morga_image_20220911034204.jpeg',
#    'profile_image_thumbnail': 'https://thespacedevs-prod.nyc3.digitaloceanspaces.com/media/images/255bauto255d__image_thumbnail_20240305185549.jpeg',
#    'flights_count': 1,
#    'landings_count': 1,
#    'spacewalks_count': 7,
#    'last_flight': '2019-07-20T16:28:21Z',
#    'first_flight': '2019-07-20T16:28:21Z'},
#   {'id': 9,
#    'url': 'https://ll.thespacedevs.com/2.2.0/astronaut/9/',
#    'name': 'Nick Hague',
#    'status': {'id': 1, 'name': 'Active'},
#    'type': {'id': 2, 'name': 'Government'},
#    'in_space': False,
#    'time_in_space': 'P373DT20H43M16S',
#    'eva_time': 'P1DT1H56M',
#    'age': 50,
#    'date_of_birth': '1975-09-24',
#    'date_of_death': None,
#    'nationality': 'American',
#    'bio': 'Tyler Nicklaus Hague is an American Flight Test Engineer and a NASA astronaut of the class of 2013.\r\nSelected to be a flight engineer of Expedition 57 / 58 to the International Space Station, he launched on board Soyuz MS-10, which aborted shortly after launch on October 11, 2018.',
#    'twitter': 'https://twitter.com/AstroHague',
#    'instagram': 'https://www.instagram.com/astrohague/',
#    'wiki': 'https://en.wikipedia.org/wiki/Nick_Hague',
#    'agency': {'id': 44,
#     'url': 'https://ll.thespacedevs.com/2.2.0/agencies/44/',
#     'name': 'National Aeronautics and Space Administration',
#     'featured': True,
#     'type': 'Government',
#     'country_code': 'USA',
#     'abbrev': 'NASA',
#     'description': 'The National Aeronautics and Space Administration is an independent agency of the executive branch of the United States federal government responsible for the civilian space program, as well as aeronautics and aerospace research. NASA have many launch facilities but most are inactive. The most commonly used pad will be LC-39B at Kennedy Space Center in Florida.',
#     'administrator': 'Acting Administrator:  James Free',
#     'founding_year': '1958',
#     'launchers': 'Space Shuttle | SLS',
#     'spacecraft': 'Orion',
#     'parent': None,
#     'image_url': 'https://thespacedevs-prod.nyc3.digitaloceanspaces.com/media/images/national2520aeronautics2520and2520space2520administration_image_20190207032448.jpeg',
#     'logo_url': 'https://thespacedevs-prod.nyc3.digitaloceanspaces.com/media/images/national2520aeronautics2520and2520space2520administration_logo_20190207032448.png'},
#    'profile_image': 'https://thespacedevs-prod.nyc3.digitaloceanspaces.com/media/images/nick_hague_image_20220911034312.jpeg',
#    'profile_image_thumbnail': 'https://thespacedevs-prod.nyc3.digitaloceanspaces.com/media/images/255bauto255d__image_thumbnail_20240305190648.jpeg',
#    'flights_count': 3,
#    'landings_count': 3,
#    'spacewalks_count': 4,
#    'last_flight': '2024-09-28T17:17:21Z',
#    'first_flight': '2018-10-11T08:40:15Z'},
#   {'id': 10,
#    'url': 'https://ll.thespacedevs.com/2.2.0/astronaut/10/',
#    'name': 'Terry W. Virts',
#    'status': {'id': 2, 'name': 'Retired'},
#    'type': {'id': 2, 'name': 'Government'},
#    'in_space': False,
#    'time_in_space': 'P213DT10H50M38S',
#    'eva_time': 'PT19H2M',
#    'age': 57,
#    'date_of_birth': '1967-12-01',
#    'date_of_death': None,
#    'nationality': 'American',
#    'bio': 'Terry W. Virts Jr. is a former NASA astronaut, and Colonel in the United States Air Force.',
#    'twitter': 'https://twitter.com/AstroTerry',
#    'instagram': 'https://www.instagram.com/astro_terry/',
#    'wiki': 'https://en.wikipedia.org/wiki/Terry_W._Virts',
#    'agency': {'id': 44,
#     'url': 'https://ll.thespacedevs.com/2.2.0/agencies/44/',
#     'name': 'National Aeronautics and Space Administration',
#     'featured': True,
#     'type': 'Government',
#     'country_code': 'USA',
#     'abbrev': 'NASA',
#     'description': 'The National Aeronautics and Space Administration is an independent agency of the executive branch of the United States federal government responsible for the civilian space program, as well as aeronautics and aerospace research. NASA have many launch facilities but most are inactive. The most commonly used pad will be LC-39B at Kennedy Space Center in Florida.',
#     'administrator': 'Acting Administrator:  James Free',
#     'founding_year': '1958',
#     'launchers': 'Space Shuttle | SLS',
#     'spacecraft': 'Orion',
#     'parent': None,
#     'image_url': 'https://thespacedevs-prod.nyc3.digitaloceanspaces.com/media/images/national2520aeronautics2520and2520space2520administration_image_20190207032448.jpeg',
#     'logo_url': 'https://thespacedevs-prod.nyc3.digitaloceanspaces.com/media/images/national2520aeronautics2520and2520space2520administration_logo_20190207032448.png'},
#    'profile_image': 'https://thespacedevs-prod.nyc3.digitaloceanspaces.com/media/images/terry_w._virts_image_20220911033815.jpeg',
#    'profile_image_thumbnail': 'https://thespacedevs-prod.nyc3.digitaloceanspaces.com/media/images/255bauto255d__image_thumbnail_20240305190900.jpeg',
#    'flights_count': 2,
#    'landings_count': 2,
#    'spacewalks_count': 3,
#    'last_flight': '2014-11-23T21:01:14Z',
#    'first_flight': '2010-02-08T09:14:08Z'}]}

# %%
url_total
# Out:
# 'http://ll.thespacedevs.com/2.2.0/astronaut'

# %%
url_total = space_url + path + "/?search=armstrong"
responder = requests.get(url_total)

# %%
url_total
# Out:
# 'http://ll.thespacedevs.com/2.2.0/astronaut/?search=armstrong'

# %%
responder.json()
# Out:
# {'count': 1,
#  'next': None,
#  'previous': None,
#  'results': [{'id': 30,
#    'url': 'https://ll.thespacedevs.com/2.2.0/astronaut/30/',
#    'name': 'Neil Armstrong',
#    'status': {'id': 11, 'name': 'Deceased'},
#    'type': {'id': 2, 'name': 'Government'},
#    'in_space': False,
#    'time_in_space': 'P5DT20H50M29S',
#    'eva_time': 'PT2H31M40S',
#    'age': 82,
#    'date_of_birth': '1930-08-05',
#    'date_of_death': '2012-08-25',
#    'nationality': 'American',
#    'bio': 'Neil Alden Armstrong was an American astronaut and aeronautical engineer who was the first person to walk on the Moon. He was also a naval aviator, test pilot, and university professor.',
#    'twitter': None,
#    'instagram': None,
#    'wiki': 'https://en.wikipedia.org/wiki/Neil_Armstrong',
#    'agency': {'id': 44,
#     'url': 'https://ll.thespacedevs.com/2.2.0/agencies/44/',
#     'name': 'National Aeronautics and Space Administration',
#     'featured': True,
#     'type': 'Government',
#     'country_code': 'USA',
#     'abbrev': 'NASA',
#     'description': 'The National Aeronautics and Space Administration is an independent agency of the executive branch of the United States federal government responsible for the civilian space program, as well as aeronautics and aerospace research. NASA have many launch facilities but most are inactive. The most commonly used pad will be LC-39B at Kennedy Space Center in Florida.',
#     'administrator': 'Acting Administrator:  James Free',
#     'founding_year': '1958',
#     'launchers': 'Space Shuttle | SLS',
#     'spacecraft': 'Orion',
#     'parent': None,
#     'image_url': 'https://thespacedevs-prod.nyc3.digitaloceanspaces.com/media/images/national2520aeronautics2520and2520space2520administration_image_20190207032448.jpeg',
#     'logo_url': 'https://thespacedevs-prod.nyc3.digitaloceanspaces.com/media/images/national2520aeronautics2520and2520space2520administration_logo_20190207032448.png'},
#    'profile_image': 'https://thespacedevs-prod.nyc3.digitaloceanspaces.com/media/images/neil2520armstrong_image_20190426143653.jpeg',
#    'profile_image_thumbnail': 'https://thespacedevs-prod.nyc3.digitaloceanspaces.com/media/images/255bauto255d__image_thumbnail_20240305190707.jpeg',
#    'flights_count': 2,
#    'landings_count': 2,
#    'spacewalks_count': 1,
#    'last_flight': '1969-07-21T17:54:00Z',
#    'first_flight': '1966-03-16T16:41:02Z'}]}

# %% [markdown]
# ## Accediendo a datos de themoviedb

# %% [markdown]
# Libreria tmdv3api

# %%
#!pip install tmdbv3api

# %%
# https://developers.themoviedb.org/3/getting-started/introduction
from tmdbv3api import TMDb
tmdb = TMDb()
tmdb.api_key = "api_key"

# %%
from tmdbv3api import Movie

#https://github.com/AnthonyBloomer/tmdbv3api

movie = Movie()

recommendations = movie.recommendations(movie_id=111)

for recommendation in recommendations:
    print(recommendation.title)
    print(recommendation.overview)
# Out:
# The Untouchables
# Elliot Ness, an ambitious prohibition agent, is determined to take down Al Capone. In order to achieve this goal, he forms a group given the nickname “The Untouchables”.
# Carlito's Way
# Free after years in prison, Carlito Brigante intends to give up his criminal ways, but it's not long before the ex-con is sucked back into the New York City underworld. Reconnecting with his dancer girlfriend, Carlito gets entangled in the shady dealings of his friend Dave Kleinfeld, who also serves as his lawyer. An encounter with shifty gangster Benny Blanco sets the duo on a dangerous path.
# Reservoir Dogs
# A botched robbery indicates a police informant, and the pressure mounts in the aftermath at a warehouse. Crime begets violence as the survivors -- veteran Mr. White, newcomer Mr. Orange, psychopathic parolee Mr. Blonde, bickering weasel Mr. Pink and Nice Guy Eddie -- unravel.
# Heat
# Obsessive master thief Neil McCauley leads a top-notch crew on various daring heists throughout Los Angeles while determined detective Vincent Hanna pursues him without rest. Each man recognizes and respects the ability and the dedication of the other even though they are aware their cat-and-mouse game may end in violence.
# The Darjeeling Limited
# Three American brothers who have not spoken to each other in a year set off on a train voyage across India with a plan to find themselves and bond with each other -- to become brothers again like they used to be. Their "spiritual quest", however, veers rapidly off-course (due to events involving over-the-counter pain killers, Indian cough syrup, and pepper spray).
# Apocalypse Now
# At the height of the Vietnam war, Captain Benjamin Willard is sent on a dangerous mission that, officially, "does not exist, nor will it ever exist." His goal is to locate - and eliminate - a mysterious Green Beret Colonel named Walter Kurtz, who has been leading his personal army on illegal guerrilla missions into enemy territory.
# Blade Runner
# In the smog-choked dystopian Los Angeles of 2019, blade runner Rick Deckard is called out of retirement to terminate a quartet of replicants who have escaped to Earth seeking their creator for a way to extend their short life spans.
# GoodFellas
# The true story of Henry Hill, a half-Irish, half-Sicilian Brooklyn kid who is adopted by neighbourhood gangsters at an early age and climbs the ranks of a Mafia family under the guidance of Jimmy Conway.
# V for Vendetta
# In a world in which Great Britain has become a fascist state, a masked vigilante known only as “V” conducts guerrilla warfare against the oppressive British government. When V rescues a young woman from the secret police, he finds in her an ally with whom he can continue his fight to free the people of Britain.
# Taxi Driver
# Suffering from insomnia, disturbed loner Travis Bickle takes a job as a New York City cabbie, haunting the streets nightly, growing increasingly detached from reality as he dreams of cleaning up the filthy city.
# Ferris Bueller's Day Off
# After high school slacker Ferris Bueller successfully fakes an illness in order to skip school for the day, he goes on a series of adventures throughout Chicago with his girlfriend Sloane and best friend Cameron, all the while trying to outwit his wily school principal and fed-up sister.
# Vertigo
# A retired San Francisco detective suffering from acrophobia investigates the strange activities of an old friend's wife, all the while becoming dangerously obsessed with her.
# The Departed
# To take down South Boston's Irish Mafia, the police send in one of their own to infiltrate the underworld, not realizing the syndicate has done likewise. While an undercover cop curries favor with the mob kingpin, a career criminal rises through the police ranks. But both sides soon discover there's a mole among them.
# Donnie Brasco
# An FBI undercover agent infiltrates the mob and identifies more with the mafia life at the expense of his regular one.
# Angel Heart
# A down-and-out Brooklyn detective is hired to track down a singer on an odyssey that will take him through the desperate streets of Harlem, the smoke-filled jazz clubs of New Orleans, and the swamps of Louisiana and its seedy underworld of voodoo.
# The Godfather
# Spanning the years 1945 to 1955, a chronicle of the fictional Italian-American Corleone crime family. When organized crime family patriarch, Vito Corleone barely survives an attempt on his life, his youngest son, Michael steps in to take care of the would-be killers, launching a campaign of bloody revenge.
# Dog Day Afternoon
# Based on the true story of would-be Brooklyn bank robbers John Wojtowicz and Salvatore Naturile. Sonny and Sal attempt a bank heist which quickly turns sour and escalates into a hostage situation and stand-off with the police. As Sonny's motives for the robbery are slowly revealed and things become more complicated, the heist turns into a media circus.
# One Flew Over the Cuckoo's Nest
# A petty criminal fakes insanity to serve his sentence in a mental ward rather than prison. He soon finds himself as a leader to the other patients—and an enemy to the cruel, domineering nurse who runs the ward.
# Once Upon a Time in America
# A former Prohibition-era Jewish gangster returns to the Lower East Side of Manhattan over thirty years later, where he once again must confront the ghosts and regrets of his old life.
# The Godfather Part II
# In the continuing saga of the Corleone crime family, a young Vito Corleone grows up in Sicily and in 1910s New York. In the 1950s, Michael Corleone attempts to expand the family business into Las Vegas, Hollywood and Cuba.

# %%
movie = Movie()
popular = movie.popular()

for p in popular:
    print(p.id)
    print(p.title)
    print(p.overview)
    print(p.poster_path)
# Out:
# 1038392
# The Conjuring: Last Rites
# Paranormal investigators Ed and Lorraine Warren take on one last terrifying case involving mysterious entities they must confront.
# /7JzOmJ1fIU43I3gLHYsY8UzNzjG.jpg
# 1086910
# The Lost Princess
# After an Ayahuasca vision transports him to a haunted castle, Alec meets Hanna who tales him the story of her mother's forced marriage and how the forbidden passion with her father was in danger when the princess pregnancy became obvious
# /31S2ISsDtbnxb0kuXZl1SxSMD0K.jpg
# 338969
# The Toxic Avenger Unrated
# When a downtrodden janitor, Winston Gooze (Peter Dinklage), is exposed to a catastrophic toxic accident, he’s transformed into a new kind of hero: The Toxic Avenger. Now, Toxie must rise from outcast to savior, taking on ruthless corporate overlords and corrupt forces who threaten his son, his friends, and his community.
# /sIonGSpGNtH72OzbJllPOEMNjVU.jpg
# 755898
# War of the Worlds
# Will Radford is a top analyst for Homeland Security who tracks potential threats through a mass surveillance program, until one day an attack by an unknown entity leads him to question whether the government is hiding something from him... and from the rest of the world.
# /yvirUYrva23IudARHn3mMGVxWqM.jpg
# 1311031
# Demon Slayer: Kimetsu no Yaiba Infinity Castle
# The Demon Slayer Corps are drawn into the Infinity Castle, where Tanjiro, Nezuko, and the Hashira face terrifying Upper Rank demons in a desperate fight as the final battle against Muzan Kibutsuji begins.
# /sUsVimPdA1l162FvdBIlmKBlWHx.jpg
# 793387
# Holy Night: Demon Hunters
# When a devil-worshipping criminal network plunges Seoul into chaos, the police turn to Holy Night—a trio of supernatural demon hunters—to restore order and defeat the rising evil.
# /v3Mo77Qjp6pctpD4eJaNT6kFRSB.jpg
# 1186350
# Marco
# The adoptive son of the Adattu family, Marco, sets off on a ruthless quest for vengeance after his brother is brutally murdered, finding only betrayal, loss and unimaginable brutality at every step.
# /il3ao5gcF6fZNqo1o9o7lusmEyU.jpg
# 941109
# Play Dirty
# Expert thief Parker gets a shot at a major heist, but to pull it off he and his team must outsmart a South American dictator, the New York mob, and the world's richest man.
# /ovZ0zq0NwRghtWI1oLaM0lWuoEw.jpg
# 617126
# The Fantastic 4: First Steps
# Against the vibrant backdrop of a 1960s-inspired, retro-futuristic world, Marvel's First Family is forced to balance their roles as heroes with the strength of their family bond, while defending Earth from a ravenous space god called Galactus and his enigmatic Herald, Silver Surfer.
# /cm8TNGBGG0aBfWj0LgrESHv8tir.jpg
# 1257009
# Primitive War
# During the Vietnam War, a recon unit ventures to an isolated jungle valley to uncover the fate of a missing platoon. They soon find themselves in a fight for their lives against an unexpected enemy — prehistoric dinosaurs.
# /nWBqU5YXmDVJWWEDJ4u3ZSseNVL.jpg
# 986097
# HIM
# After suffering a potentially career-ending brain trauma, Cameron Cade receives a lifeline when his hero, legendary eight-time Championship quarterback and cultural megastar Isaiah White, offers to train Cam at Isaiah's isolated compound that he shares with his celebrity influencer wife. But as Cam's training accelerates, Isaiah's charisma begins to curdle into something darker.
# /qPJzcYR2f1O1uynYBCVPPJuOiAH.jpg
# 1290879
# The Woman in Cabin 10
# On a lavish yacht for an assignment, a journalist sees a passenger go overboard. But when no one believes her, she risks her life to uncover the truth.
# /4kpdyePOlcELQQJcxXPF5GB1Adw.jpg
# 533533
# TRON: Ares
# A highly sophisticated Program called Ares is sent from the digital world into the real world on a dangerous mission, marking humankind's first encounter with A.I. beings.
# /chpWmskl3aKm1aTZqUHRCtviwPy.jpg
# 1251717
# Vicious
# When Polly (Dakota Fanning) receives a mysterious box, it comes with one rule: place inside something she needs, something she hates, and something she loves. If she doesn’t obey, it will consume everything—and everyone—she’s ever known.
# /shKGDGrwqmc9x2aTJcQszoXinq0.jpg
# 1328803
# Prisoner of War
# British RAF Wing Commander James Wright is captured by the Japanese during WWII and forced to fight in brutal hand-to-hand combat. The Japanese soldiers get more than they bargained for when Wright’s years of martial arts training in Hong Kong prove him to be a formidable opponent.
# /1XET89sjRm9mUuHXhGIlKTNd5uD.jpg
# 803796
# KPop Demon Hunters
# When K-pop superstars Rumi, Mira and Zoey aren't selling out stadiums, they're using their secret powers to protect their fans from supernatural threats.
# /22AouvwlhlXbe3nrFcjzL24bvWH.jpg
# 1053008
# Fight Another Day
# Follows a tough cop, who after being transported to a dystopian future, must enter a deadly combat tournament to be able to return to his past.
# /fKnLt1xQV0RdpN6RViowEiD1dFW.jpg
# 1267319
# Mantis
# Mantis, an ace assassin, returns to the contract killer industry after a hiatus, encountering his trainee friend Jae-yi and a retired legendary killer Dok-go, who now runs the organization.
# /xS9bbciDC5lHPgl79SrPyzxKAXL.jpg
# 1061474
# Superman
# Superman, a journalist in Metropolis, embarks on a journey to reconcile his Kryptonian heritage with his human upbringing as Clark Kent.
# /wPLysNDLffQLOVebZQCbXJEv6E6.jpg
# 575265
# Mission: Impossible - The Final Reckoning
# Ethan Hunt and team continue their search for the terrifying AI known as the Entity — which has infiltrated intelligence networks all over the globe — with the world's governments and a mysterious ghost from Hunt's past on their trail. Joined by new allies and armed with the means to shut the Entity down for good, Hunt is in a race against time to prevent the world as we know it from changing forever.
# /z53D72EAOxGRqdr7KXXWp9dJiDe.jpg

# %%
import requests
response = requests.get(f"https://api.themoviedb.org/3/discover/movie?api_key={tmdb.api_key}&language=en-US&sort_by=popularity.desc&include_adult=false&include_video=false&page=2&primary_release_year=2010")

# %%
response
# Out:
# <Response [200]>

# %%
response.json()
# Out:
# {'page': 2,
#  'results': [{'adult': False,
#    'backdrop_path': '/jItFLAs2urRwwQ5rmc61LTd1les.jpg',
#    'genre_ids': [80, 18, 28, 53],
#    'id': 41283,
#    'original_language': 'en',
#    'original_title': 'Faster',
#    'overview': 'After 10 years in prison, Driver is now a free man with a single focus - hunting down the people responsible for brutally murdering his brother.',
#    'popularity': 8.0827,
#    'poster_path': '/AsUeaXrhw4oscCSjUZ6heh1pVvd.jpg',
#    'release_date': '2010-11-23',
#    'title': 'Faster',
#    'video': False,
#    'vote_average': 6.345,
#    'vote_count': 2003},
#   {'adult': False,
#    'backdrop_path': '/sJpbDELfC8VjlRBOOkMJxxWpUg7.jpg',
#    'genre_ids': [53, 12, 28],
#    'id': 27578,
#    'original_language': 'en',
#    'original_title': 'The Expendables',
#    'overview': 'Barney Ross leads a band of highly skilled mercenaries including knife enthusiast Lee Christmas, a martial arts expert Yin Yang, heavy weapons specialist Hale Caesar, demolitionist Toll Road, and a loose-cannon sniper Gunner Jensen. When the group is commissioned by the mysterious Mr. Church to assassinate the dictator of a small South American island, Barney and Lee visit the remote locale to scout out their opposition and discover the true nature of the conflict engulfing the city.',
#    'popularity': 9.031,
#    'poster_path': '/j09ZkH6R4JWVylBcDai1laCmGw7.jpg',
#    'release_date': '2010-08-07',
#    'title': 'The Expendables',
#    'video': False,
#    'vote_average': 6.246,
#    'vote_count': 8028},
#   {'adult': False,
#    'backdrop_path': '/v8DepuF6gizphLzIyNZeQiB0hij.jpg',
#    'genre_ids': [28, 12, 18, 10751],
#    'id': 38575,
#    'original_language': 'en',
#    'original_title': 'The Karate Kid',
#    'overview': "12-year-old Dre Parker could've been the most popular kid in Detroit, but his mother's latest career move has landed him in China. Dre immediately falls for his classmate Mei Ying but the cultural differences make such a friendship impossible. Even worse, Dre's feelings make him an enemy of the class bully, Cheng. With no friends in a strange land, Dre has nowhere to turn but maintenance man Mr. Han, who is a kung fu master. As Han teaches Dre that kung fu is not about punches and parries, but maturity and calm, Dre realizes that facing down the bullies will be the fight of his life.",
#    'popularity': 8.9178,
#    'poster_path': '/b1RBy3l297N0c7PHjlz35cClWju.jpg',
#    'release_date': '2010-06-10',
#    'title': 'The Karate Kid',
#    'video': False,
#    'vote_average': 6.564,
#    'vote_count': 6337},
#   {'adult': False,
#    'backdrop_path': '/gU5cR9LKtDD8YvzE7T7GvmzCEAA.jpg',
#    'genre_ids': [28, 12, 14],
#    'id': 10196,
#    'original_language': 'en',
#    'original_title': 'The Last Airbender',
#    'overview': 'The story follows the adventures of Aang, a young successor to a long line of Avatars, who must put his childhood ways aside and stop the Fire Nation from enslaving the Water, Earth and Air nations.',
#    'popularity': 9.7295,
#    'poster_path': '/kl9JJ8288bNsY8oqT1SpQh1w2mb.jpg',
#    'release_date': '2010-06-30',
#    'title': 'The Last Airbender',
#    'video': False,
#    'vote_average': 4.6,
#    'vote_count': 4112},
#   {'adult': False,
#    'backdrop_path': '/5HRAb4wHgovzICuo3ZqgHXmqzeK.jpg',
#    'genre_ids': [16, 12, 10751, 14],
#    'id': 44683,
#    'original_language': 'en',
#    'original_title': 'Tinker Bell and the Great Fairy Rescue',
#    'overview': "During a summer stay on the mainland, Tinker Bell is accidentally discovered while investigating a little girl's fairy house. As the other fairies, led by the brash Vidia, launch a daring rescue in the middle of a fierce storm, Tink develops a special bond with the lonely, little girl.",
#    'popularity': 7.7005,
#    'poster_path': '/cb7PrVIYbwIadQqWxgSU6CGHJjj.jpg',
#    'release_date': '2010-07-29',
#    'title': 'Tinker Bell and the Great Fairy Rescue',
#    'video': False,
#    'vote_average': 6.745,
#    'vote_count': 976},
#   {'adult': False,
#    'backdrop_path': '/tOfAkOf7TrAPuz4kKG5Fvq1seCd.jpg',
#    'genre_ids': [28, 53, 80, 18],
#    'id': 38234,
#    'original_language': 'en',
#    'original_title': 'Undisputed III: Redemption',
#    'overview': 'Russian inmate Boyka, now severely hobbled by the knee injury suffered at the end of Undisputed 2. No longer the feared prison fighter he was, he has declined so far that he is now good only for cleaning toilets. But when a new prison fight tournament begins - an international affair, matching the best fighters from prisons around the globe, enticing them with the promise of freedom for the winner - Boyka must reclaim his dignity and fight for his position in the tournament.',
#    'popularity': 8.4824,
#    'poster_path': '/g8KB77SPA7SyU8eid6TAEpt9skU.jpg',
#    'release_date': '2010-04-17',
#    'title': 'Undisputed III: Redemption',
#    'video': False,
#    'vote_average': 7.542,
#    'vote_count': 962},
#   {'adult': False,
#    'backdrop_path': '/owAe5rRStnX7ibVAPmza3NCXjCy.jpg',
#    'genre_ids': [80, 18, 53],
#    'id': 23168,
#    'original_language': 'en',
#    'original_title': 'The Town',
#    'overview': 'Doug MacRay is a longtime thief, who, smarter than the rest of his crew, is looking for his chance to exit the game. When a bank job leads to the group kidnapping an attractive branch manager, he takes on the role of monitoring her – but their burgeoning relationship threatens to unveil the identities of Doug and his crew to the FBI Agent who is on their case.',
#    'popularity': 8.0705,
#    'poster_path': '/3NIzyXkfylsjflRKSz8Fts3lXzm.jpg',
#    'release_date': '2010-09-15',
#    'title': 'The Town',
#    'video': False,
#    'vote_average': 7.219,
#    'vote_count': 5330},
#   {'adult': False,
#    'backdrop_path': '/u8wmr8QCowIYXUxVeZYSPWVbB9P.jpg',
#    'genre_ids': [18, 10752, 9648],
#    'id': 46738,
#    'original_language': 'fr',
#    'original_title': 'Incendies',
#    'overview': "A mother's last wishes send twins Jeanne and Simon on a journey to Middle East in search of their tangled roots. Adapted from Wajdi Mouawad's acclaimed play, Incendies tells the powerful and moving tale of two young adults' voyage to the core of deep-rooted hatred, never-ending wars and enduring love.",
#    'popularity': 8.3685,
#    'poster_path': '/yH6DAQVgbyj72S66gN4WWVoTjuf.jpg',
#    'release_date': '2010-09-17',
#    'title': 'Incendies',
#    'video': False,
#    'vote_average': 8.1,
#    'vote_count': 3028},
#   {'adult': False,
#    'backdrop_path': '/qxTw8OKJLRX1Xb5nR5CcIDnLKoq.jpg',
#    'genre_ids': [18, 53, 27],
#    'id': 44214,
#    'original_language': 'en',
#    'original_title': 'Black Swan',
#    'overview': "The story of Nina, a ballerina in a New York City ballet company whose life, like all those in her profession, is completely consumed with dance. She lives with her retired ballerina mother Erica who zealously supports her daughter's professional ambition. When artistic director Thomas Leroy decides to replace prima ballerina Beth MacIntyre for the opening production of their new season, Swan Lake, Nina is his first choice.",
#    'popularity': 7.201,
#    'poster_path': '/viWheBd44bouiLCHgNMvahLThqx.jpg',
#    'release_date': '2010-12-03',
#    'title': 'Black Swan',
#    'video': False,
#    'vote_average': 7.687,
#    'vote_count': 15057},
#   {'adult': False,
#    'backdrop_path': '/5dwlH8Krm2bsuc2Pubw2cBb03g5.jpg',
#    'genre_ids': [18, 12, 37],
#    'id': 44264,
#    'original_language': 'en',
#    'original_title': 'True Grit',
#    'overview': "Following the murder of her father by a hired hand, a 14-year-old farm girl sets out to capture the killer. To aid her, she hires the toughest U.S. Marshal she can find—a man with 'true grit'—Reuben J. 'Rooster' Cogburn.",
#    'popularity': 6.5823,
#    'poster_path': '/6W6sbvrSFRxlluSkUcnGufpUfJi.jpg',
#    'release_date': '2010-12-22',
#    'title': 'True Grit',
#    'video': False,
#    'vote_average': 7.307,
#    'vote_count': 5501},
#   {'adult': False,
#    'backdrop_path': '/3hnTZNtn17IGQlgZSvOC8v0hW2b.jpg',
#    'genre_ids': [28, 53, 878],
#    'id': 51620,
#    'original_language': 'en',
#    'original_title': 'Death Race 2',
#    'overview': "In the world's most dangerous prison, a new game is born: Death Race. The rules of this adrenaline-fueled blood sport are simple, drive or die. When repentant convict Carl Lucas discovers there's a price on his head, his only hope is to survive a twisted race against an army of hardened criminals and tricked-out cars.",
#    'popularity': 6.5533,
#    'poster_path': '/80mBFNVvak2bA9TJN1MD0yM7Lfi.jpg',
#    'release_date': '2010-11-12',
#    'title': 'Death Race 2',
#    'video': False,
#    'vote_average': 5.817,
#    'vote_count': 1150},
#   {'adult': False,
#    'backdrop_path': '/oc3be3waruLd0PB9h4bomN7Le3v.jpg',
#    'genre_ids': [12, 10751, 14],
#    'id': 10140,
#    'original_language': 'en',
#    'original_title': 'The Chronicles of Narnia: The Voyage of the Dawn Treader',
#    'overview': 'This time around Edmund and Lucy Pevensie, along with their pesky cousin Eustace Scrubb find themselves swallowed into a painting and on to a fantastic Narnian ship headed for the very edges of the world.',
#    'popularity': 7.8289,
#    'poster_path': '/pP27zlm9yeKrCeDZLFLP2HKELot.jpg',
#    'release_date': '2010-12-02',
#    'title': 'The Chronicles of Narnia: The Voyage of the Dawn Treader',
#    'video': False,
#    'vote_average': 6.44,
#    'vote_count': 5741},
#   {'adult': False,
#    'backdrop_path': '/8nlIP8REpkLLW6vU2sX2Z5SRt7s.jpg',
#    'genre_ids': [12, 14, 28],
#    'id': 18823,
#    'original_language': 'en',
#    'original_title': 'Clash of the Titans',
#    'overview': 'Born of a god but raised as a man, Perseus is helpless to save his family from Hades, vengeful god of the underworld. With nothing to lose, Perseus volunteers to lead a dangerous mission to defeat Hades before he can seize power from Zeus and unleash hell on earth. Battling unholy demons and fearsome beasts, Perseus and his warriors will only survive if Perseus accepts his power as a god, defies fate and creates his own destiny.',
#    'popularity': 6.4702,
#    'poster_path': '/3W6QaC3Vz8UJhr6HRYuGfbNeJCs.jpg',
#    'release_date': '2010-03-26',
#    'title': 'Clash of the Titans',
#    'video': False,
#    'vote_average': 5.918,
#    'vote_count': 6475},
#   {'adult': False,
#    'backdrop_path': '/iyx6PUBFQTYTulpcvHcuSInPAIn.jpg',
#    'genre_ids': [27, 9648, 53],
#    'id': 23437,
#    'original_language': 'en',
#    'original_title': 'A Nightmare on Elm Street',
#    'overview': 'Teenagers Nancy, Quentin, Kris, Jesse and Dean are all neighborhood friends who begin having the same dream of a horribly disfigured man who wears a tattered sweater and a glove made of knives. The man terrorizes them in their dreams, and the only escape is to wake up. But when, one by one, they start dying violently, the friends realize that what happens in the dream world is real, and the only way to stay alive is to stay awake.',
#    'popularity': 6.489,
#    'poster_path': '/nsmW28GcNabCUZfP5YtUEe8Li0f.jpg',
#    'release_date': '2010-04-30',
#    'title': 'A Nightmare on Elm Street',
#    'video': False,
#    'vote_average': 5.523,
#    'vote_count': 2816},
#   {'adult': False,
#    'backdrop_path': '/P4bGyJQF0shAcRku3I2perNUQR.jpg',
#    'genre_ids': [28, 80],
#    'id': 23483,
#    'original_language': 'en',
#    'original_title': 'Kick-Ass',
#    'overview': 'Dave Lizewski is an unnoticed high school student and comic book fan who one day decides to become a super-hero, even though he has no powers, training or meaningful reason to do so.',
#    'popularity': 6.953,
#    'poster_path': '/iHMbrTHJwocsNvo5murCBw0CwTo.jpg',
#    'release_date': '2010-03-26',
#    'title': 'Kick-Ass',
#    'video': False,
#    'vote_average': 7.121,
#    'vote_count': 12028},
#   {'adult': False,
#    'backdrop_path': '/fGBJEfGjHmhg7nLAT0Jkcv9qV5e.jpg',
#    'genre_ids': [18, 35, 10749],
#    'id': 43347,
#    'original_language': 'en',
#    'original_title': 'Love & Other Drugs',
#    'overview': "Maggie is an alluring free spirit who won't let anyone – or anything – tie her down. But she meets her match in Jamie, whose relentless and nearly infallible charm serves him well with the ladies and the cutthroat world of pharmaceutical sales. Maggie and Jamie's evolving relationship takes them both by surprise, as they find themselves under the influence of the ultimate drug: love.",
#    'popularity': 6.3037,
#    'poster_path': '/wZLM2uKJRYNchLmiCIjosX0rXy8.jpg',
#    'release_date': '2010-11-22',
#    'title': 'Love & Other Drugs',
#    'video': False,
#    'vote_average': 7.042,
#    'vote_count': 5383},
#   {'adult': False,
#    'backdrop_path': '/dXDFWWxiEb6tg4ojMWQJrSI0Tun.jpg',
#    'genre_ids': [53, 27],
#    'id': 49797,
#    'original_language': 'ko',
#    'original_title': '악마를 보았다',
#    'overview': 'Kyung-chul is a dangerous psychopath who kills for pleasure. Soo-hyeon, a top-secret agent, decides to track down the murderer himself. He promises himself that he will do everything in his power to take vengeance against the killer, even if it means that he must become a monster himself.',
#    'popularity': 6.6814,
#    'poster_path': '/zp5NrmYp80axIGiEiYPmm1CW6uH.jpg',
#    'release_date': '2010-08-12',
#    'title': 'I Saw the Devil',
#    'video': False,
#    'vote_average': 7.8,
#    'vote_count': 2811},
#   {'adult': False,
#    'backdrop_path': '/yVSgw4UyXWg0Edl7KMehdhhgIwL.jpg',
#    'genre_ids': [878, 28, 53],
#    'id': 34851,
#    'original_language': 'en',
#    'original_title': 'Predators',
#    'overview': 'A group of cold-blooded killers find themselves trapped on an alien planet to be hunted by extraterrestrial Predators.',
#    'popularity': 8.0937,
#    'poster_path': '/sx5EuckP7SBQrlMlxg0PLt282WS.jpg',
#    'release_date': '2010-07-07',
#    'title': 'Predators',
#    'video': False,
#    'vote_average': 6.287,
#    'vote_count': 4373},
#   {'adult': False,
#    'backdrop_path': '/8srpvfRNT9qenQZACPTXDZYXitL.jpg',
#    'genre_ids': [80, 18, 9648, 53],
#    'id': 12201,
#    'original_language': 'en',
#    'original_title': 'Edge of Darkness',
#    'overview': "As a seasoned homicide detective, Thomas Craven has seen the bleakest side of humanity. But nothing prepares him for the toughest investigation of his life: the search for his only daughter Emma's killer. Now, he is on a personal mission to uncover the disturbing secrets surrounding her murder, including corporate corruption, government collusion and Emma's own mysterious life.",
#    'popularity': 8.1527,
#    'poster_path': '/pvHjp1vEFmp5FquSCPQ2O95tIZJ.jpg',
#    'release_date': '2010-01-28',
#    'title': 'Edge of Darkness',
#    'video': False,
#    'vote_average': 6.367,
#    'vote_count': 1607},
#   {'adult': False,
#    'backdrop_path': '/uEqrGVBELVFaNVMOE4ExjLCMV3j.jpg',
#    'genre_ids': [28, 53, 80],
#    'id': 51608,
#    'original_language': 'ko',
#    'original_title': '아저씨',
#    'overview': "An ex-special agent is involved in a convoluted drug ring drama. He has to save a drug smuggler's innocent daughter from being the victim of her parents' fight.",
#    'popularity': 5.8776,
#    'poster_path': '/ld19CFIo27t41JXSGZdaPMUGTxh.jpg',
#    'release_date': '2010-08-04',
#    'title': 'The Man from Nowhere',
#    'video': False,
#    'vote_average': 7.701,
#    'vote_count': 1396}],
#  'total_pages': 858,
#  'total_results': 17154}

# %% [markdown]
# #### Acceder a datos de la api desde la URL con la libreria requests

# %%
import numpy as np
import pandas as pd

# https://www.themoviedb.org/documentation/api
#api_key = "tu api key"

years = np.arange(2024, 2025)
id_movies = []
release_date = []
title = []
for i in years:
    print("year:", i )
    for j in range(1,100): 
        response = requests.get(f'https://api.themoviedb.org/3/discover/movie?api_key={tmdb.api_key}&page={j}&primary_release_year={i}&sort_by=popularity.desc')
        highest_revenue = response.json()
        print(highest_revenue)
        
        first_results = highest_revenue["results"]
       
        for k in first_results:
                     
            try:                
                release_date.append(k["release_date"])
                title.append(k["title"])
                id_movies.append(k["id"])  
            except:
                release_date.append(np.nan)
                title.append(np.nan)
                id_movies.append(np.nan)
                continue

df_movies_id = pd.DataFrame(id_movies, columns=["id"])
df_movies_id["date"] = release_date
df_movies_id["title"] = title
# Out:
# year: 2024
# {'page': 1, 'results': [{'adult': False, 'backdrop_path': '/a6RkQIOZ6wThQOEDv6lHsfH53hD.jpg', 'genre_ids': [28, 80, 53], 'id': 1186350, 'original_language': 'ml', 'original_title': 'മാർക്കോ', 'overview': 'The adoptive son of the Adattu family, Marco, sets off on a ruthless quest for vengeance after his brother is brutally murdered, finding only betrayal, loss and unimaginable brutality at every step.', 'popularity': 313.9444, 'poster_path': '/6Nj8Y1A9lcReqZZvRHOSiO3iTl6.jpg', 'release_date': '2024-12-20', 'title': 'Marco', 'video': False, 'vote_average': 6.371, 'vote_count': 62}, {'adult': False, 'backdrop_path': '/znMUHotZRTcyIFWFz2bvcpSx6YP.jpg', 'genre_ids': [28], 'id': 1053008, 'original_language': 'en', 'original_title': 'Fight Another Day', 'overview': 'Follows a tough cop, who after being transported to a dystopian future, must enter a deadly combat tournament to be able to return to his past.', 'popularity': 154.2523, 'poster_path': '/fKnLt1xQV0RdpN6RViowEiD1dFW.jpg', 'release_date': '2024-10-09', 'title': 'Fight Another Day', 'video': False, 'vote_average': 5.111, 'vote_count': 18}, {'adult': False, 'backdrop_path': '/nvdLEfAWcfTNn45SpwBnLGBmOR1.jpg', 'genre_ids': [37], 'id': 1357886, 'original_language': 'it', 'original_title': 'Django Undisputed', 'overview': 'Determined to exact his justice, Django faces dangerous challenges and bloody clashes to restore order in a territory dominated by lawlessness and injustice.', 'popularity': 132.7259, 'poster_path': '/porcUhC4jqFt72TaxbjOQo2lTzL.jpg', 'release_date': '2024-04-22', 'title': 'Django Undisputed', 'video': False, 'vote_average': 6.056, 'vote_count': 9}, {'adult': False, 'backdrop_path': '/3IcJRIjMo4G1A6HtCHiKCUAyfIw.jpg', 'genre_ids': [27, 28, 878], 'id': 1032448, 'original_language': 'en', 'original_title': 'Jurassic Triangle', 'overview': 'A group of colleagues crash land on a mysterious island that they cannot escape. They discover they are not alone when they encounter an array of blood thirsty creatures and dinosaurs out to get them. Will they survive the island?', 'popularity': 69.9461, 'poster_path': '/yLxLz8RHiOLtNvKCtJYQgDFXqBU.jpg', 'release_date': '2024-02-13', 'title': 'Jurassic Triangle', 'video': False, 'vote_average': 2.8, 'vote_count': 10}, {'adult': False, 'backdrop_path': '/5U3VLeWr2H4Nd3G7IkHItFimsIz.jpg', 'genre_ids': [10751, 35, 12, 16, 878], 'id': 870360, 'original_language': 'en', 'original_title': 'The Day the Earth Blew Up: A Looney Tunes Movie', 'overview': "Porky and Daffy, the classic animated odd couple, turn into unlikely heroes when their antics at the local bubble gum factory uncover a secret alien mind control plot. Against all odds, the two are determined to save their town (and the world!)...that is if they don't drive each other crazy in the process.", 'popularity': 58.8412, 'poster_path': '/s2lB1kaYCdGSnZX5meQCiOR6HfX.jpg', 'release_date': '2024-08-01', 'title': 'The Day the Earth Blew Up: A Looney Tunes Movie', 'video': False, 'vote_average': 7.66, 'vote_count': 172}, {'adult': False, 'backdrop_path': '/boprqXZexBatujVC07gZzzxjWk.jpg', 'genre_ids': [53, 27], 'id': 1109406, 'original_language': 'en', 'original_title': 'Compulsion', 'overview': 'Two women—Diana, a flamboyant and ruthless thief, and Evie, a seemingly innocent young woman with a troubled past—become embroiled in a series of horrific murders on the island of Malta.', 'popularity': 51.9866, 'poster_path': '/s3MzSdsMcmxmpVJMuH5ezNPjzs7.jpg', 'release_date': '2024-11-10', 'title': 'Compulsion', 'video': False, 'vote_average': 6.5, 'vote_count': 12}, {'adult': False, 'backdrop_path': '/k24eZq5I3jyz4htPkZCRpnUmBzE.jpg', 'genre_ids': [10749, 18], 'id': 1156593, 'original_language': 'es', 'original_title': 'Culpa tuya', 'overview': "The love between Noah and Nick seems unwavering despite their parents' attempts to separate them. But his job and her entry into college open up their lives to new relationships that will shake the foundations of both their relationship and th ...
# {'page': 2, 'results': [{'adult': False, 'backdrop_path': '/zOpe0eHsq0A2NvNyBbtT6sj53qV.jpg', 'genre_ids': [28, 878, 35, 10751], 'id': 939243, 'original_language': 'en', 'original_title': 'Sonic the Hedgehog 3', 'overview': 'Sonic, Knuckles, and Tails reunite against a powerful new adversary, Shadow, a mysterious villain with powers unlike anything they have faced before. With their abilities outmatched in every way, Team Sonic must seek out an unlikely alliance in hopes of stopping Shadow and protecting the planet.', 'popularity': 29.6424, 'poster_path': '/d8Ryb8AunYAuycVKDp5HpdWPKgC.jpg', 'release_date': '2024-12-19', 'title': 'Sonic the Hedgehog 3', 'video': False, 'vote_average': 7.659, 'vote_count': 2969}, {'adult': False, 'backdrop_path': '/qDAvAUsnRrvkFO5EtNq1XFfyYTL.jpg', 'genre_ids': [16, 10751, 14], 'id': 974397, 'original_language': 'en', 'original_title': 'My Freaky Family', 'overview': "On the cusp of her 13th birthday, Betty Flood – budding musician and magical being – just wants to be like the rest of her fabulous, but very different family, so why is her magical Mum so against it? As Betty wrestles with this, she also learns the amazing truth about her family and discovers that the not so normal, the magical and the musical are all a part of her fabulously freaky family. It's very freaky, so be freaked freaky ahh deaky peaky neaky seaky peaky poo.", 'popularity': 30.3065, 'poster_path': '/h34lkT2CFufYuzmP0CEgn4lghyY.jpg', 'release_date': '2024-04-25', 'title': 'My Freaky Family', 'video': False, 'vote_average': 7.0, 'vote_count': 6}, {'adult': False, 'backdrop_path': '/twsxsfao6ZOVvT8LfudH603MMi6.jpg', 'genre_ids': [10751, 35, 16, 878], 'id': 519182, 'original_language': 'en', 'original_title': 'Despicable Me 4', 'overview': 'Gru and Lucy and their girls—Margo, Edith and Agnes—welcome a new member to the Gru family, Gru Jr., who is intent on tormenting his dad. Gru also faces a new nemesis in Maxime Le Mal and his femme fatale girlfriend Valentina, forcing the family to go on the run.', 'popularity': 28.2939, 'poster_path': '/wWba3TaojhK7NdycRhoQpsG0FaH.jpg', 'release_date': '2024-06-20', 'title': 'Despicable Me 4', 'video': False, 'vote_average': 7.016, 'vote_count': 2946}, {'adult': False, 'backdrop_path': '/9SSEUrSqhljBMzRe4aBTh17rUaC.jpg', 'genre_ids': [27, 878], 'id': 945961, 'original_language': 'en', 'original_title': 'Alien: Romulus', 'overview': 'While scavenging the deep ends of a derelict space station, a group of young space colonizers come face to face with the most terrifying life form in the universe.', 'popularity': 23.9633, 'poster_path': '/2uSWRTtCG336nuBiG8jOTEUKSy8.jpg', 'release_date': '2024-08-13', 'title': 'Alien: Romulus', 'video': False, 'vote_average': 7.176, 'vote_count': 4006}, {'adult': False, 'backdrop_path': '/gSVk4r8Q4R8aeGY0hhEG3bE0QzL.jpg', 'genre_ids': [12, 27, 53], 'id': 1252428, 'original_language': 'zh', 'original_title': '狂蟒之灾', 'overview': "A struggling circus crew gets deceived by its former partner, as it embarks on a tour in Thailand. During the journey through a Southeast Asian rainforest, they encounter attacks by a giant python. They meet a mysterious man named Jeff who offers to help, but they soon realize he's a poacher. As they search for Jeff's boat, they face life-and-death struggles with the python and Jeff himself.", 'popularity': 24.3106, 'poster_path': '/pPfsEXzfk2URkQ1OxhUShAXdxMr.jpg', 'release_date': '2024-03-01', 'title': 'Anaconda', 'video': False, 'vote_average': 7.193, 'vote_count': 109}, {'adult': False, 'backdrop_path': '/clFFCapyGpE7KD4Jsu5pUbFBZF4.jpg', 'genre_ids': [28, 53], 'id': 359410, 'original_language': 'en', 'original_title': 'Road House', 'overview': 'Ex-UFC fighter Dalton takes a job as a bouncer at a Florida Keys roadhouse, only to discover that this paradise is not all it seems.', 'popularity': 23.2984, 'poster_path': '/fDEdtS4P0gJsxHDIt8dG8TR5dx1.jpg', 'release_date': '2024-03-08', 'title': 'Road House', 'video': False, 'vote_average ...
# {'page': 3, 'results': [{'adult': False, 'backdrop_path': '/rOmUuQEZfPXglwFs5ELLLUDKodL.jpg', 'genre_ids': [28, 35, 14], 'id': 845781, 'original_language': 'en', 'original_title': 'Red One', 'overview': "After Santa Claus (codename: Red One) is kidnapped, the North Pole's Head of Security must team up with the world's most infamous tracker in a globe-trotting, action-packed mission to save Christmas.", 'popularity': 18.6471, 'poster_path': '/cdqLnri3NEGcmfnqwk2TSIYtddg.jpg', 'release_date': '2024-10-31', 'title': 'Red One', 'video': False, 'vote_average': 7.046, 'vote_count': 2676}, {'adult': False, 'backdrop_path': '/SiLiMbpWFtIa64wvp3WxbpzOen.jpg', 'genre_ids': [53], 'id': 1163545, 'original_language': 'ms', 'original_title': 'Lubuk', 'overview': '30 years ago, Titi and Dirwan appeared at a small town and took over a rundown mansion where they turned it into a quaint and idyllic home for the homeless and those who have nowhere to go. It has created a buzz among the small community and nearby towns especially when Dirwan has never demanded for any payments and he has taken great efforts and measures to provide the best care and facilities for the residents. Unknown to everyone, the shelter home is only the front for another ludicrous but dark and sinister business. Business that Titi and Dirwan have been profiting for close to 2 decades. Its charming facade and warm hospitality lure unsuspecting victims. This place is perfect as it is located at the edge of the town, far away from anyone and coupled with unreliable internet and mobile phone services.', 'popularity': 19.3287, 'poster_path': '/ubVOKAHfNt893fihJjV8R1Otzr8.jpg', 'release_date': '2024-07-18', 'title': 'Lubuk', 'video': False, 'vote_average': 5.0, 'vote_count': 2}, {'adult': False, 'backdrop_path': '/xOMo8BRK7PfcJv9JCnx7s5hj0PX.jpg', 'genre_ids': [878, 12], 'id': 693134, 'original_language': 'en', 'original_title': 'Dune: Part Two', 'overview': 'Follow the mythic journey of Paul Atreides as he unites with Chani and the Fremen while on a path of revenge against the conspirators who destroyed his family. Facing a choice between the love of his life and the fate of the known universe, Paul endeavors to prevent a terrible future only he can foresee.', 'popularity': 17.3257, 'poster_path': '/1pdfLvkbY9ohJlCjQH2CZjjYVvJ.jpg', 'release_date': '2024-02-27', 'title': 'Dune: Part Two', 'video': False, 'vote_average': 8.1, 'vote_count': 7111}, {'adult': False, 'backdrop_path': '/18TSJF1WLA4CkymvVUcKDBwUJ9F.jpg', 'genre_ids': [27, 53], 'id': 1034541, 'original_language': 'en', 'original_title': 'Terrifier 3', 'overview': "Five years after surviving Art the Clown's Halloween massacre, Sienna and Jonathan are still struggling to rebuild their shattered lives. As the holiday season approaches, they try to embrace the Christmas spirit and leave the horrors of the past behind. But just when they think they're safe, Art returns, determined to turn their holiday cheer into a new nightmare. The festive season quickly unravels as Art unleashes his twisted brand of terror, proving that no holiday is safe.", 'popularity': 20.675, 'poster_path': '/ju10W5gl3PPK3b7TjEmVOZap51I.jpg', 'release_date': '2024-10-09', 'title': 'Terrifier 3', 'video': False, 'vote_average': 6.83, 'vote_count': 1748}, {'adult': False, 'backdrop_path': '/sI6uCeF8mUlZx22mFfHSi9W3XQ9.jpg', 'genre_ids': [10749, 18, 35], 'id': 843527, 'original_language': 'en', 'original_title': 'The Idea of You', 'overview': "40-year-old single mom Solène begins an unexpected romance with 24-year-old Hayes Campbell, the lead singer of August Moon, the hottest boy band on the planet. As they begin a whirlwind romance, it isn't long before Hayes' superstar status poses unavoidable challenges to their relationship, and Solène soon discovers that life in the glare of his spotlight might be more than she bargained for.", 'popularity': 17.3965, 'poster_path': '/Y5P4Q3q8nrruZ9aD3wXeJS2Plg.jpg', 'release_date': '2024-05-02', 'title': 'The Idea ...
# {'page': 4, 'results': [{'adult': False, 'backdrop_path': '/xsuDWczuyk6HUhGwgJx6evXW07q.jpg', 'genre_ids': [99], 'id': 1304681, 'original_language': 'en', 'original_title': "Exorcismo: The Transgressive Legacy of Clasificada 'S'", 'overview': "Franco's death in 1975 opened the doors to the possibility of uncensored cinema. After two years in which censorship was relaxed, in 1977 it was completely abolished, and the “S” classification was created to protect viewers from those films that could “hurt their sensitivity.” The “S” classification was granted when the content was especially violent, sexual or political, creating a mixed bag in which all types of unclassifiable films could fit. In force from 1978 to 1983, this classification turned out to be a great commercial attraction for a society that had suffered four decades of national-Catholic dictatorship and repression.", 'popularity': 15.2639, 'poster_path': '/uZentdoTuGZ1sqwn4EMPfWaRsgO.jpg', 'release_date': '2024-10-03', 'title': "Exorcismo: The Transgressive Legacy of Clasificada 'S'", 'video': False, 'vote_average': 6.0, 'vote_count': 1}, {'adult': False, 'backdrop_path': '/mO9oOVXM8tTlC11VFM4FBBNnL3f.jpg', 'genre_ids': [28, 80, 53, 35], 'id': 1017163, 'original_language': 'ko', 'original_title': '범죄도시 4', 'overview': "'Monster Cop' Ma Seok-do investigates an illegal online gambling business led by a former STS Baek and an IT genius CEO Chang. Ma proposes an unexpected alliance to Jang and begins hunting down the criminals.", 'popularity': 15.1601, 'poster_path': '/yk38mNoJpsswmk9o7i7eLhO4mc.jpg', 'release_date': '2024-04-24', 'title': 'The Roundup: Punishment', 'video': False, 'vote_average': 7.095, 'vote_count': 195}, {'adult': False, 'backdrop_path': '/jLRtQNOwA0ul2gnRoZ0QjNwMUN1.jpg', 'genre_ids': [28, 35, 10752], 'id': 799583, 'original_language': 'en', 'original_title': 'The Ministry of Ungentlemanly Warfare', 'overview': 'During World War II, the British Army assigns a group of competent soldiers to carry out a mission against the Nazi forces behind enemy lines... A true story about a secret British WWII organization — the Special Operations Executive. Founded by Winston Churchill, their irregular warfare against the Germans helped to change the course of the war, and gave birth to modern black operations.', 'popularity': 13.3274, 'poster_path': '/8aF0iAKH9MJMYAZdi0Slg77RYa2.jpg', 'release_date': '2024-04-18', 'title': 'The Ministry of Ungentlemanly Warfare', 'video': False, 'vote_average': 7.053, 'vote_count': 1632}, {'adult': False, 'backdrop_path': '/s7vWRjcfRVMW8tBIxhC3UhKxRoo.jpg', 'genre_ids': [18, 10749], 'id': 1097549, 'original_language': 'en', 'original_title': 'Babygirl', 'overview': 'A high-powered CEO puts her career and family on the line when she begins a torrid affair with her much younger intern.', 'popularity': 14.0902, 'poster_path': '/ilwO6elz3mLV9CToT7C8pjVeKX0.jpg', 'release_date': '2024-12-25', 'title': 'Babygirl', 'video': False, 'vote_average': 5.729, 'vote_count': 966}, {'adult': False, 'backdrop_path': '/iR79ciqhtaZ9BE7YFA1HpCHQgX4.jpg', 'genre_ids': [27, 9648], 'id': 1100782, 'original_language': 'en', 'original_title': 'Smile 2', 'overview': 'About to embark on a new world tour, global pop sensation Skye Riley begins experiencing increasingly terrifying and inexplicable events. Overwhelmed by the escalating horrors and the pressures of fame, Skye is forced to face her dark past to regain control of her life before it spirals out of control.', 'popularity': 16.9555, 'poster_path': '/ht8Uv9QPv9y7K0RvUyJIaXOZTfd.jpg', 'release_date': '2024-10-16', 'title': 'Smile 2', 'video': False, 'vote_average': 6.606, 'vote_count': 1824}, {'adult': False, 'backdrop_path': '/fypydCipcWDKDTTCoPucBsdGYXW.jpg', 'genre_ids': [878, 12, 28, 18, 53], 'id': 653346, 'original_language': 'en', 'original_title': 'Kingdom of the Planet of the Apes', 'overview': "Several generations following Caesar's reign, apes – now the dominant species – live harmoniously whil ...
# {'page': 5, 'results': [{'adult': False, 'backdrop_path': '/en3GU5uGkKaYmSyetHV4csHHiH3.jpg', 'genre_ids': [10752, 28, 18], 'id': 929590, 'original_language': 'en', 'original_title': 'Civil War', 'overview': 'In the near future, a group of war journalists attempt to survive while reporting the truth as the United States stands on the brink of civil war.', 'popularity': 12.3417, 'poster_path': '/sh7Rg8Er3tFcN9BpKIPOMvALgZd.jpg', 'release_date': '2024-04-10', 'title': 'Civil War', 'video': False, 'vote_average': 6.853, 'vote_count': 3859}, {'adult': False, 'backdrop_path': '/oMiKHO3H5RixfLsiU5Vumhlp5sj.jpg', 'genre_ids': [80, 10749, 53, 18], 'id': 948549, 'original_language': 'en', 'original_title': 'Love Lies Bleeding', 'overview': 'Reclusive gym manager Lou falls hard for Jackie, an ambitious bodybuilder headed through town to Las Vegas in pursuit of her dream. But their love ignites violence, pulling them deep into the web of Lou’s criminal family.', 'popularity': 11.0057, 'poster_path': '/xImj8RLe39YK0lyVu9kXv7ApN8p.jpg', 'release_date': '2024-03-07', 'title': 'Love Lies Bleeding', 'video': False, 'vote_average': 6.579, 'vote_count': 850}, {'adult': False, 'backdrop_path': '/4CcUgdiGe83MeqJW1NyJVmZqRrF.jpg', 'genre_ids': [18, 10749], 'id': 937287, 'original_language': 'en', 'original_title': 'Challengers', 'overview': 'Tennis player turned coach Tashi has taken her husband, Art, and transformed him into a world-famous Major champion. To jolt him out of his recent losing streak, she signs him up for a "Challenger" event — close to the lowest level of pro tournament — where he finds himself standing across the net from his former best friend and Tashi\'s former boyfriend.', 'popularity': 10.9989, 'poster_path': '/H6vke7zGiuLsz4v4RPeReb9rsv.jpg', 'release_date': '2024-04-18', 'title': 'Challengers', 'video': False, 'vote_average': 6.9, 'vote_count': 2379}, {'adult': False, 'backdrop_path': '/cb1hZXieb4npx0F2K4yL1WL6NQQ.jpg', 'genre_ids': [18, 10402, 14], 'id': 1235431, 'original_language': 'ja', 'original_title': '【推しの子】-The Final Act-', 'overview': 'Goro is a gynecologist and idol fan who’s in shock after his favorite star, Ai, announces an impromptu hiatus. Little does Goro realize that he’s about to forge a bond with her that defies all common sense! Lies are an idol’s weapon!', 'popularity': 11.6526, 'poster_path': '/29BjXB8dPvLvJJgZFetd8PvwYiw.jpg', 'release_date': '2024-12-20', 'title': 'Oshi no Ko -The Final Act-', 'video': False, 'vote_average': 7.0, 'vote_count': 9}, {'adult': False, 'backdrop_path': '/kF8ljC7Y4p1UsmKBi2LxelZpqw.jpg', 'genre_ids': [35, 14, 27], 'id': 917496, 'original_language': 'en', 'original_title': 'Beetlejuice Beetlejuice', 'overview': "After a family tragedy, three generations of the Deetz family return home to Winter River. Still haunted by Betelgeuse, Lydia's life is turned upside down when her teenage daughter, Astrid, accidentally opens the portal to the Afterlife.", 'popularity': 11.0884, 'poster_path': '/kKgQzkUCnQmeTPkyIwHly2t6ZFI.jpg', 'release_date': '2024-09-04', 'title': 'Beetlejuice Beetlejuice', 'video': False, 'vote_average': 6.973, 'vote_count': 2779}, {'adult': False, 'backdrop_path': '/ce51NvJSO5ReNkm3C3YDX5jsH1V.jpg', 'genre_ids': [99, 10751, 12], 'id': 1094473, 'original_language': 'fr', 'original_title': "Bambi, l'histoire d'une vie dans les bois", 'overview': 'The life of Bambi, a male roe deer, from his birth through childhood, the loss of his mother, the finding of a mate, the lessons he learns from his father, and the experience he gains about the dangers posed by human hunters in the forest.', 'popularity': 12.8037, 'poster_path': '/vWNVHtwOhcoOEUSrY1iHRGbgH8O.jpg', 'release_date': '2024-10-16', 'title': 'Bambi: A Tale of Life in the Woods', 'video': False, 'vote_average': 6.167, 'vote_count': 48}, {'adult': False, 'backdrop_path': '/NqqLef2ITlK8olXT4iFuUXFwSh.jpg', 'genre_ids': [9648, 53], 'id': 840705, 'original_language': 'en', 'original_title': 'Blink Twice', 'overvie ...
# {'page': 6, 'results': [{'adult': False, 'backdrop_path': '/8IYpYg6MdNBGiMnNAZptSxt1jGm.jpg', 'genre_ids': [12, 28, 18], 'id': 1084736, 'original_language': 'fr', 'original_title': 'Le Comte de Monte-Cristo', 'overview': 'Edmond Dantes becomes the target of a sinister plot and is arrested on his wedding day for a crime he did not commit. After 14 years in the island prison of Château d’If, he manages a daring escape. Now rich beyond his dreams, he assumes the identity of the Count of Monte-Cristo and exacts his revenge on the three men who betrayed him.', 'popularity': 11.7282, 'poster_path': '/sAT1P3FGhtJ68anUyJScnMu8t1l.jpg', 'release_date': '2024-06-28', 'title': 'The Count of Monte Cristo', 'video': False, 'vote_average': 8.0, 'vote_count': 1781}, {'adult': False, 'backdrop_path': '/59AJ2w9tKRSbBpnxKfB5UyIg6Jf.jpg', 'genre_ids': [27, 53], 'id': 1010600, 'original_language': 'en', 'original_title': 'The Strangers: Chapter 1', 'overview': 'After their car breaks down in an eerie small town, a young couple are forced to spend the night in a remote cabin. Panic ensues as they are terrorized by three masked strangers who strike with no mercy and seemingly no motives.', 'popularity': 10.6197, 'poster_path': '/cdFZoQDxLRRWXLB3kxCnc674dBF.jpg', 'release_date': '2024-05-15', 'title': 'The Strangers: Chapter 1', 'video': False, 'vote_average': 5.646, 'vote_count': 577}, {'adult': False, 'backdrop_path': '/dn3gbDpXPSwC6saMJOHkCiFA9jn.jpg', 'genre_ids': [14, 12, 10751, 35], 'id': 974262, 'original_language': 'en', 'original_title': 'Descendants: The Rise of Red', 'overview': "After the Queen of Hearts incites a coup on Auradon, her rebellious daughter Red and Cinderella's perfectionist daughter Chloe join forces and travel back in time to try to undo the traumatic event that set Red's mother down her villainous path.", 'popularity': 10.1459, 'poster_path': '/8fYluTtB3b3HKO7KQa5tzrvGaps.jpg', 'release_date': '2024-07-11', 'title': 'Descendants: The Rise of Red', 'video': False, 'vote_average': 6.782, 'vote_count': 440}, {'adult': False, 'backdrop_path': '/6GhU4BJnqLSaAuz0yQBq3RfdzsF.jpg', 'genre_ids': [27, 9648], 'id': 1216191, 'original_language': 'en', 'original_title': 'Oddity', 'overview': 'After the brutal murder of her twin sister, Darcy goes after those responsible by using haunted items as her tools for revenge.', 'popularity': 10.8046, 'poster_path': '/3Z9c1tbUhP0QruRjczPHnbx3U2D.jpg', 'release_date': '2024-07-19', 'title': 'Oddity', 'video': False, 'vote_average': 6.716, 'vote_count': 615}, {'adult': False, 'backdrop_path': '/co7oxvpWxgd6FZU24DnljDDHYQA.jpg', 'genre_ids': [878, 27, 53], 'id': 1064028, 'original_language': 'en', 'original_title': 'Subservience', 'overview': "With his wife out sick, a struggling father brings home a lifelike AI, only to have his self-aware new help want everything her new family has to offer... Like the affection of her owner and she'll kill to get it.", 'popularity': 10.0509, 'poster_path': '/gBenxR01Uy0Ev9RTIw6dVBPoyQU.jpg', 'release_date': '2024-08-15', 'title': 'Subservience', 'video': False, 'vote_average': 6.654, 'vote_count': 867}, {'adult': False, 'backdrop_path': '/nxxCPRGTzxUH8SFMrIsvMmdxHti.jpg', 'genre_ids': [35, 14, 10751], 'id': 639720, 'original_language': 'en', 'original_title': 'IF', 'overview': "After discovering she can see everyone's imaginary friends, a girl embarks on a magical adventure to reconnect forgotten imaginary friends with their kids.", 'popularity': 10.4166, 'poster_path': '/xbKFv4KF3sVYuWKllLlwWDmuZP7.jpg', 'release_date': '2024-05-08', 'title': 'IF', 'video': False, 'vote_average': 7.031, 'vote_count': 1438}, {'adult': False, 'backdrop_path': '/yBMGM7x8lPXUlmTNfCLZvHbpJmk.jpg', 'genre_ids': [28, 18, 53, 10752], 'id': 1043905, 'original_language': 'en', 'original_title': 'Dirty Angels', 'overview': "During the United States' 2021 withdrawal from Afghanistan, a group of female soldiers posing as medical relief are sent back in to rescue a group of kidnapped teen ...
# {'page': 7, 'results': [{'adult': False, 'backdrop_path': '/youmOAJwM4XCoHAgeYNXACA7Buc.jpg', 'genre_ids': [16, 12, 35, 10751], 'id': 676685, 'original_language': 'nl', 'original_title': 'Pandabeer in Afrika', 'overview': 'A young adventurous panda travels from China to Africa to rescue his best friend, Jielong the Dragon, who has been kidnapped. On his journey, he discovers a strange amazing new world of mountains, deserts and jungles.', 'popularity': 9.0898, 'poster_path': '/wxpu7svVqA0ALYpofQBPujGelN3.jpg', 'release_date': '2024-03-15', 'title': 'Panda Bear in Africa', 'video': False, 'vote_average': 7.021, 'vote_count': 73}, {'adult': False, 'backdrop_path': '/2ANHqBhbAhyIBRTLSVfENskpxon.jpg', 'genre_ids': [80, 27, 53], 'id': 1029281, 'original_language': 'en', 'original_title': 'Strange Darling', 'overview': 'Nothing is what it seems when a twisted one-night stand spirals into a serial killer’s vicious murder spree.', 'popularity': 10.8193, 'poster_path': '/kWNCRgt3ocv19bYO0sk7TRuZuFY.jpg', 'release_date': '2024-08-14', 'title': 'Strange Darling', 'video': False, 'vote_average': 6.935, 'vote_count': 733}, {'adult': False, 'backdrop_path': '/bizhlTVjifYQUu4Xrdt7m3TYr7d.jpg', 'genre_ids': [27, 53, 80], 'id': 1226578, 'original_language': 'en', 'original_title': 'Longlegs', 'overview': 'FBI Agent Lee Harker is a gifted new recruit assigned to the unsolved case of an elusive serial killer. As the case takes complex turns, unearthing evidence of the occult, Harker discovers a personal connection to the merciless killer and must race against time to stop him before he claims the lives of another innocent family.', 'popularity': 12.0424, 'poster_path': '/1EwNyiiNFd863H4e8nWEzutnZD7.jpg', 'release_date': '2024-07-10', 'title': 'Longlegs', 'video': False, 'vote_average': 6.561, 'vote_count': 2273}, {'adult': False, 'backdrop_path': '/1YMrOtrW7b4pL2lfD8UciZPOJGs.jpg', 'genre_ids': [18, 53], 'id': 974576, 'original_language': 'en', 'original_title': 'Conclave', 'overview': 'After the unexpected death of the Pope, Cardinal Lawrence is tasked with managing the covert and ancient ritual of electing a new one. Sequestered in the Vatican with the Catholic Church’s most powerful leaders until the process is complete, Lawrence finds himself at the center of a conspiracy that could lead to its downfall.', 'popularity': 8.8307, 'poster_path': '/m5x8D0bZ3eKqIVWZ5y7TnZ2oTVg.jpg', 'release_date': '2024-10-25', 'title': 'Conclave', 'video': False, 'vote_average': 7.207, 'vote_count': 2943}, {'adult': False, 'backdrop_path': '/6RcBQkC2PZJwwbFugqzgvN3moYL.jpg', 'genre_ids': [53, 28], 'id': 1005331, 'original_language': 'en', 'original_title': 'Carry-On', 'overview': 'An airport security officer races to outsmart a mysterious traveler forcing him to let a dangerous item slip onto a Christmas Eve flight.', 'popularity': 11.2529, 'poster_path': '/sjMN7DRi4sGiledsmllEw5HJjPy.jpg', 'release_date': '2024-12-05', 'title': 'Carry-On', 'video': False, 'vote_average': 6.891, 'vote_count': 2438}, {'adult': False, 'backdrop_path': '/hKmRJ4pWBjhVOhgLAFzXddpc69p.jpg', 'genre_ids': [12, 16, 18, 10751], 'id': 589018, 'original_language': 'fr', 'original_title': 'Sauvages', 'overview': "In Borneo, near the tropical forest, Kéria rescues a baby orangutang in the palm oil plantation where her father works. Kéria's cousin Selaï comes to live with them seeking refuge from the conflict between his indigenous tribe and the logging companies. Kéria, Selaï and the little orangutang, now named Oshi, will have to fight against their forest’s destruction.", 'popularity': 8.8945, 'poster_path': '/qC6yrKvmIEnkFVjpp0U7u02SiDQ.jpg', 'release_date': '2024-10-16', 'title': 'Savages', 'video': False, 'vote_average': 6.9, 'vote_count': 27}, {'adult': False, 'backdrop_path': '/kutrMwSVEcGFn5F0fUJYYRPzuxn.jpg', 'genre_ids': [28, 35, 10751], 'id': 1048241, 'original_language': 'en', 'original_title': 'My Spy The Eternal City', 'overview': 'JJ, a veteran CIA agent, reunites with his pro ...
# {'page': 8, 'results': [{'adult': False, 'backdrop_path': '/7QwylJf82UGCAZpMbqgPJF5o0ZV.jpg', 'genre_ids': [18], 'id': 1380553, 'original_language': 'tl', 'original_title': 'Ungol', 'overview': "Sexy vixens Audrey Avila and Stephanie Raz will give you the hottest moans in this newest sexy drama by Bobby Bonifacio, Jr. A blind woman owns a makeshift motel in a slums area. As she hears her clients' loud noises, she becomes sexually aroused.", 'popularity': 7.8968, 'poster_path': '/1cYJhi17IELYrqFkfLECKJU80vO.jpg', 'release_date': '2024-11-08', 'title': 'Ungol', 'video': False, 'vote_average': 5.0, 'vote_count': 2}, {'adult': False, 'backdrop_path': '/wP0NGOGf2PG4lHXHWEqFW0kBOye.jpg', 'genre_ids': [10402, 18], 'id': 799766, 'original_language': 'en', 'original_title': 'Better Man', 'overview': "Follow Robbie Williams' journey from childhood, to being the youngest member of chart-topping boyband Take That, through to his unparalleled achievements as a record-breaking solo artist – all the while confronting the challenges that stratospheric fame and success can bring.", 'popularity': 9.4902, 'poster_path': '/fbGCmMp0HlYnAPv28GOENPShezM.jpg', 'release_date': '2024-12-06', 'title': 'Better Man', 'video': False, 'vote_average': 7.693, 'vote_count': 685}, {'adult': False, 'backdrop_path': '/3m0j3hCS8kMAaP9El6Vy5Lqnyft.jpg', 'genre_ids': [878, 27, 53], 'id': 1125510, 'original_language': 'es', 'original_title': 'El hoyo 2', 'overview': 'After a mysterious leader imposes his law in a brutal system of vertical cells, a new arrival battles against a dubious food distribution method.', 'popularity': 7.1489, 'poster_path': '/tvIpBg12IIA5Dr9Sjn38ygS1vQp.jpg', 'release_date': '2024-09-27', 'title': 'The Platform 2', 'video': False, 'vote_average': 5.541, 'vote_count': 1287}, {'adult': False, 'backdrop_path': '/6EO11KoiMMG29ISaQrm2G5DCe1X.jpg', 'genre_ids': [9648, 27, 53], 'id': 838209, 'original_language': 'ko', 'original_title': '파묘', 'overview': "After tracing the origin of a disturbing supernatural affliction to a wealthy family's ancestral gravesite, a team of paranormal experts relocates the remains—and soon discovers what happens to those who dare to mess with the wrong grave.", 'popularity': 7.7409, 'poster_path': '/6dasJ58GGFcC62H9KuukAryltUp.jpg', 'release_date': '2024-02-22', 'title': 'Exhuma', 'video': False, 'vote_average': 7.5, 'vote_count': 566}, {'adult': False, 'backdrop_path': '/p4INKu77iuTG1o1a5N3Y9vqeEGq.jpg', 'genre_ids': [27, 53], 'id': 1079485, 'original_language': 'en', 'original_title': 'Winnie-the-Pooh: Blood and Honey 2', 'overview': 'Five months following the murders, Christopher Robin struggles to maintain a regular life while dealing with PTSD. However, deep within the 100-Acre-Wood, a destructive rage grows as Pooh, Piglet, Owl, and Tigger find their home and their lives endangered after their existence is revealed.', 'popularity': 9.3197, 'poster_path': '/2sADrLwMQof6yYmrJRSa04tFZuS.jpg', 'release_date': '2024-03-26', 'title': 'Winnie-the-Pooh: Blood and Honey 2', 'video': False, 'vote_average': 5.902, 'vote_count': 408}, {'adult': False, 'backdrop_path': '/aWILNXgq07riueQknYXMvum11jo.jpg', 'genre_ids': [28, 53], 'id': 1081012, 'original_language': 'en', 'original_title': 'Aftermath', 'overview': "A returning war veteran, stricken with PTSD, gets trapped with his teenage sister on Boston's Tobin Memorial Bridge when a heavily armed group of ex-military revolutionaries take everyone hostage.", 'popularity': 9.1863, 'poster_path': '/v9knhuvYKwMUAta6fltNOuun3zF.jpg', 'release_date': '2024-09-27', 'title': 'Aftermath', 'video': False, 'vote_average': 6.2, 'vote_count': 156}, {'adult': False, 'backdrop_path': '/9s9o9RT9Yj6nDuRJjnJm78WFoFl.jpg', 'genre_ids': [28, 27, 53, 878], 'id': 1051896, 'original_language': 'en', 'original_title': 'Arcadian', 'overview': 'In the near future, on a decimated Earth, Paul and his twin sons face terror at night when ferocious creatures awaken. When Paul is nearly killed, the boys come  ...
# {'page': 9, 'results': [{'adult': False, 'backdrop_path': '/3m7252MFY0YkOrr7SmnPEhuSha6.jpg', 'genre_ids': [80, 53, 37], 'id': 395817, 'original_language': 'en', 'original_title': 'The Thicket', 'overview': 'An innocent young man, Jack, goes on an epic quest to rescue his sister Lula after she has been kidnapped by the violent killer Cut Throat Bill and her gang. To save her, Jack enlists the help of a crafty bounty hunter named Reginald Jones, a grave-digging alcoholic son of an ex-slave, and a street-smart prostitute. The gang tracks Cut Throat Bill into the deadly no-man’s land known as The Big Thicket — a place where blood and chaos reign.', 'popularity': 7.9684, 'poster_path': '/jsvk8e0HgITFX0gbDEjj6hOytsP.jpg', 'release_date': '2024-09-05', 'title': 'The Thicket', 'video': False, 'vote_average': 6.484, 'vote_count': 122}, {'adult': False, 'backdrop_path': '/umyOinNa6vqqnqoVc9QqzyaapUz.jpg', 'genre_ids': [27], 'id': 938614, 'original_language': 'en', 'original_title': 'Late Night with the Devil', 'overview': "A live broadcast of a late-night talk show in 1977 goes horribly wrong, unleashing evil into the nation's living rooms.", 'popularity': 6.9662, 'poster_path': '/mu8LRWT9GHkfiyHm7kgxT6YNvMW.jpg', 'release_date': '2024-03-19', 'title': 'Late Night with the Devil', 'video': False, 'vote_average': 7.113, 'vote_count': 1813}, {'adult': False, 'backdrop_path': '/l7dOI84fj3WSUEWTsGAzYR8A1Ct.jpg', 'genre_ids': [18], 'id': 1388874, 'original_language': 'tl', 'original_title': "Boss Ma'am", 'overview': 'V.A.D. and Charm try to outplay each other in a game of deceit. When a terror female boss was blackmailed by her assistant, she has no choice but to obey and play with her.', 'popularity': 7.8694, 'poster_path': '/3po9qDTFZoejlOjaVodVcp8TYsm.jpg', 'release_date': '2024-11-26', 'title': "Boss Ma'am", 'video': False, 'vote_average': 7.5, 'vote_count': 8}, {'adult': False, 'backdrop_path': '/o8XSR1SONnjcsv84NRu6Mwsl5io.jpg', 'genre_ids': [18, 28, 14, 878], 'id': 801688, 'original_language': 'te', 'original_title': 'కల్కి 2898-ఎ.డి', 'overview': 'In the year 2898 AD, around 6000 years after Kurukshetra war, Ashwatthama gears up for his final battle of redemption at the sign of hope in a dystopian world and Bhairava, a wisecracking and self-interested bounty hunter, tired of the perilous life becomes the hurdle in the process.', 'popularity': 8.1664, 'poster_path': '/As1waHOjpLzl3PrfJ0vKlDAROsB.jpg', 'release_date': '2024-06-26', 'title': 'Kalki 2898-AD', 'video': False, 'vote_average': 6.504, 'vote_count': 140}, {'adult': False, 'backdrop_path': '/hPU12uDcsVyaz368yjxa4BjDHXB.jpg', 'genre_ids': [28, 18, 53, 80], 'id': 1105407, 'original_language': 'en', 'original_title': 'Damaged', 'overview': 'A Chicago detective travels to Scotland after an emerging serial killer’s crimes match those that he investigated five years earlier, one of which was the crime scene of his murdered girlfriend.', 'popularity': 7.7456, 'poster_path': '/tMO0YLXgJZBnIAjoTSz26zE33YN.jpg', 'release_date': '2024-04-12', 'title': 'Damaged', 'video': False, 'vote_average': 5.668, 'vote_count': 304}, {'adult': False, 'backdrop_path': '/9hLE7hMDyIhtSfR6L7DJrsUzY2K.jpg', 'genre_ids': [10749, 35], 'id': 1024452, 'original_language': 'en', 'original_title': 'French Girl', 'overview': 'Sweet Gordon, an affable English teacher in Brooklyn, has beaten the odds; a French Girl has fallen in love with him and he’s fallen even harder back. But their future is thrown into limbo when she interviews for an executive chef position in her hometown of Quebec City. To Gordon’s dismay her future boss also happens to be her former lover, a celebrity Chef with oceanic eyes and a hit TV show. Good luck Gordon.', 'popularity': 8.6407, 'poster_path': '/Bu1cgfaLOqELu11qRdmzYX6o6K.jpg', 'release_date': '2024-03-15', 'title': 'French Girl', 'video': False, 'vote_average': 6.306, 'vote_count': 90}, {'adult': False, 'backdrop_path': '/wfdHCilp8cNPK7tK4jLgdUT7703.jpg', 'genre_ids': [35], 'id': 10 ...
# {'page': 10, 'results': [{'adult': False, 'backdrop_path': '/jGit2vVH1yWa74ObSyPeu3fkp0C.jpg', 'genre_ids': [18], 'id': 1130413, 'original_language': 'fr', 'original_title': 'La Vallée des fous', 'overview': 'Passionate about sailing, Jean-Paul is going through a rough patch. Up to his ears in debts, he pulls away from his family. Determined to take his life back in hand, he signs up for Virtual Regatta, the online version of Vendée Globe boat race. To enhance his impression of being a “real” skipper, Jean-Paul holes up for 3 months on his boat in his garden. His voyage, unlike any other, will allow him to reconnect with his family and, even more, with himself.', 'popularity': 7.4616, 'poster_path': '/1roBFerA3F1XmIFqAiJkM0oprjc.jpg', 'release_date': '2024-11-13', 'title': 'Sailing Home', 'video': False, 'vote_average': 6.9, 'vote_count': 40}, {'adult': False, 'backdrop_path': '/39CRS71VP0d9VOsJ5TVgD8IaQnT.jpg', 'genre_ids': [53, 28, 27, 878, 12], 'id': 726139, 'original_language': 'ko', 'original_title': '탈출: 프로젝트 사일런스', 'overview': 'Due to sudden deteriorating weather conditions, visibility on the Airport Bridge is severely impaired, leaving people stranded and at risk of the bridge collapsing due to a series of chain collisions and explosions. Amidst the chaos, the canine subjects "Echo" from the military experiment "Project Silence," who were being transported in secret, break free, and all human survivors become targets of relentless attacks.', 'popularity': 7.3208, 'poster_path': '/lZT5Cq4wkz7IeJEnz94U94xuEWD.jpg', 'release_date': '2024-07-11', 'title': 'Project Silence', 'video': False, 'vote_average': 6.926, 'vote_count': 365}, {'adult': False, 'backdrop_path': '/u060S4drIWntmLeMDGe7mD0V6Jh.jpg', 'genre_ids': [28, 80, 53, 18], 'id': 1160018, 'original_language': 'hi', 'original_title': 'किल', 'overview': 'When an army commando finds out his true love is engaged against her will, he boards a New Dehli-bound train in a daring quest to derail the arranged marriage. But when a gang of knife-wielding thieves begin to terrorize innocent passengers on his train, the commando takes them on, one by one.', 'popularity': 7.861, 'poster_path': '/m2zXTuNPkywdYLyWlVyJZW2QOJH.jpg', 'release_date': '2024-07-03', 'title': 'Kill', 'video': False, 'vote_average': 7.145, 'vote_count': 418}, {'adult': False, 'backdrop_path': '/hRO4TS0IlH9UJW2PGuuFBYdXZgC.jpg', 'genre_ids': [27], 'id': 1356236, 'original_language': 'en', 'original_title': 'Saint Catherine', 'overview': 'An orphaned girl is rescued from a satanic ritual and taken to Saint Catherine Institute for homeless youth. There she will learn new skills while facing demons that stalk her.', 'popularity': 8.828, 'poster_path': '/hBJdzKPeDaC96AzlrtMWBomYSZV.jpg', 'release_date': '2024-09-24', 'title': 'Saint Catherine', 'video': False, 'vote_average': 6.493, 'vote_count': 72}, {'adult': False, 'backdrop_path': '/viKEEaaCaZ0hZ2nGuvIEozlLooL.jpg', 'genre_ids': [27, 53], 'id': 1023922, 'original_language': 'en', 'original_title': 'MaXXXine', 'overview': 'In 1980s Hollywood, adult film star and aspiring actress Maxine Minx finally gets her big break. But as a mysterious killer stalks the starlets of Hollywood, a trail of blood threatens to reveal her sinister past.', 'popularity': 6.8352, 'poster_path': '/ArvoFK6nlouZRxYmtIOUzKIrg90.jpg', 'release_date': '2024-07-04', 'title': 'MaXXXine', 'video': False, 'vote_average': 6.3, 'vote_count': 1249}, {'adult': False, 'backdrop_path': '/21lM9hfYNDX9RnWzp4aq0iQTEbq.jpg', 'genre_ids': [16, 10749], 'id': 1317276, 'original_language': 'ja', 'original_title': '映画 ギヴン 海へ', 'overview': 'Mafuyu doubts his place in the band, but a familiar face could be the spark that brings him back to the stage.', 'popularity': 8.9299, 'poster_path': '/2VLnT5JtJ77ErG6GD3c1J628VLp.jpg', 'release_date': '2024-09-20', 'title': 'given the Movie: To the Sea', 'video': False, 'vote_average': 7.4, 'vote_count': 7}, {'adult': False, 'backdrop_path': '/otfoeC96neoOdA4HqsX06OWuzE9 ...
# {'page': 11, 'results': [{'adult': False, 'backdrop_path': '/ifRqavcREHdS0FN9KtVMXghgryK.jpg', 'genre_ids': [53, 18, 10749], 'id': 1026436, 'original_language': 'en', 'original_title': "Miller's Girl", 'overview': 'A talented young writer embarks on a creative odyssey when her teacher assigns a project that entangles them both.', 'popularity': 7.407, 'poster_path': '/ieU0zUj7WhE0GrgpgofRH0sNjbI.jpg', 'release_date': '2024-01-18', 'title': "Miller's Girl", 'video': False, 'vote_average': 6.368, 'vote_count': 869}, {'adult': False, 'backdrop_path': '/3HnkKX1B9h4govdAa3Ku8qMZaoZ.jpg', 'genre_ids': [27, 53], 'id': 1100856, 'original_language': 'ru', 'original_title': 'Заклятье. Шёпот ведьм', 'overview': 'Mara, an ancient pagan spirit, hunts a group of teenagers taking their body parts to be reborn. A disillusioned and desperate investigator has to face his deepest fears to save the teenagers.', 'popularity': 7.5296, 'poster_path': '/raDMchyq3dJMqso2TVh75A123Xb.jpg', 'release_date': '2024-06-13', 'title': 'Whisper of the Witch', 'video': False, 'vote_average': 6.4, 'vote_count': 48}, {'adult': False, 'backdrop_path': '/3kvS6Ws5usxSk1wIbKZ7YPug2V2.jpg', 'genre_ids': [18], 'id': 1103621, 'original_language': 'th', 'original_title': 'หลานม่า', 'overview': 'M, a university dropout low on money and luck, volunteers to take care of his terminally ill grandmother, in the hope of pocketing an inheritance.', 'popularity': 7.4253, 'poster_path': '/9Xa0Grd2jq2lM2gqcoTB4F9TjMd.jpg', 'release_date': '2024-04-04', 'title': 'How to Make Millions Before Grandma Dies', 'video': False, 'vote_average': 8.2, 'vote_count': 307}, {'adult': False, 'backdrop_path': '/h9YlRHAZWOWtGonllmj6JJg1FrE.jpg', 'genre_ids': [16, 10751, 28, 12, 14], 'id': 588648, 'original_language': 'zh', 'original_title': 'Dragonkeeper', 'overview': 'Set in Han Imperial China, the plot follows the adventures of enslaved girl Ping with ancient dragon Long Danzi. Dragons had been banished from the kingdom. Ping, an orphan, finds one of the last remaining dragon eggs. Palace guards force Ping to run away in order to return the dragon egg to the ocean and save all dragons from extinction. Ping discovers that she is a true Dragonkeeper.', 'popularity': 7.5079, 'poster_path': '/ggZGnJLzO3BTu7ysuuIzou3Oex5.jpg', 'release_date': '2024-04-11', 'title': 'Dragonkeeper', 'video': False, 'vote_average': 7.675, 'vote_count': 200}, {'adult': False, 'backdrop_path': '/i0c2rE6x1RCXktYk4Bv4NBWh5gO.jpg', 'genre_ids': [10749, 18], 'id': 1291559, 'original_language': 'ja', 'original_title': '余命一年の僕が、余命半年の君と出会った話。', 'overview': 'With only a year left to live, 17-year-old Akito finds new meaning in life by bringing joy to a terminally ill girl who has just six months remaining.', 'popularity': 8.6487, 'poster_path': '/173FD4a0rpSF30z4CoWx6qdx8Ry.jpg', 'release_date': '2024-06-26', 'title': 'Drawing Closer', 'video': False, 'vote_average': 8.366, 'vote_count': 168}, {'adult': False, 'backdrop_path': '/wd0pDee3oLyav4ERWuFCr5Hp4wS.jpg', 'genre_ids': [18], 'id': 1118836, 'original_language': 'fr', 'original_title': "L'Enfant qui mesurait le monde", 'overview': 'Alexandre Varda, a powerful property developer of Greek origin, finds his life suddenly turned upside down. On the same day, he is sacked by his sharhold- ers and learns of the death of his daughter, whom he has not seen for 12 years. When he arrives in Greece the next day to repatriate the body, he also discovers that he is the grandfather of a 9-year-old boy with autistic syndrome...', 'popularity': 7.4497, 'poster_path': '/4T9i1X8OZcWkwqXsFH7UN0Ap5h0.jpg', 'release_date': '2024-06-26', 'title': 'The Child Who Measured the World', 'video': False, 'vote_average': 5.7, 'vote_count': 9}, {'adult': False, 'backdrop_path': '/rggsf9KtBgq6LaMoRefhrNcCSGV.jpg', 'genre_ids': [28], 'id': 547475, 'original_language': 'en', 'original_title': 'Rendel: Cycle of Revenge', 'overview': 'When ‘Smiley’ takes over the Vala Drug Corporation, a masked vigilante, Rendel,  ...
# ...
# {'page': 97, 'results': [{'adult': False, 'backdrop_path': '/9MQJViBQQX7tnO0Hs18PPb4iF9D.jpg', 'genre_ids': [18], 'id': 1305295, 'original_language': 'tl', 'original_title': 'Hiraya', 'overview': 'A mysterious woman found unconscious in a river. She wakes up not remembering anything and is unable to speak. The townspeople take advantage of Hiraya, but it seems that those who do, always end up in misfortune.', 'popularity': 2.5685, 'poster_path': '/z51gpsihoKdWx9hHfKclMHgpEgs.jpg', 'release_date': '2024-07-12', 'title': 'Hiraya', 'video': False, 'vote_average': 5.5, 'vote_count': 2}, {'adult': False, 'backdrop_path': '/v64CjRb8dhyJ2SAJNdidXeGvkIW.jpg', 'genre_ids': [18], 'id': 1340331, 'original_language': 'ko', 'original_title': '환희의 얼굴', 'overview': 'The face of Hwanhee constructs a fascinating world, divided into four chapters like a collection of short stories.', 'popularity': 2.9835, 'poster_path': '/hrP5hWQvFX7Mjedc1J5ZCthm6wq.jpg', 'release_date': '2024-10-05', 'title': 'The face of Hwanhee', 'video': False, 'vote_average': 0.0, 'vote_count': 0}, {'adult': False, 'backdrop_path': '/10rNJlPS9P8SgiE6owsvjgQowaR.jpg', 'genre_ids': [878, 80, 14, 53], 'id': 1552053, 'original_language': 'ko', 'original_title': '더 킬러스-Special Track', 'overview': '', 'popularity': 3.36, 'poster_path': None, 'release_date': '2024-12-29', 'title': 'The Killers-Special Track', 'video': False, 'vote_average': 0.0, 'vote_count': 0}, {'adult': False, 'backdrop_path': '/AwzMgSKBJkTW2nU8z0pSdqvbhWS.jpg', 'genre_ids': [18, 9648], 'id': 889820, 'original_language': 'el', 'original_title': 'Arcadia', 'overview': 'Neurologist Katerina and former doctor Yannis are heading off to a deserted seaside resort. Silence descends on the car as they travel across dunes in a windy autumn, matching the less-than-pleasant occasion: Yannis has been called to identify the victim of a tragic accident at the hospital of the small town. When the local policeman informs them that the victim’s vehicle had plunged over the parapet of a stone bridge and leads them to the morgue, Katerina sees her worst suspicions confirmed. Together with Yannis, but also on her own nightly excursions to a mysterious, rustic beach bar called Arcadia, they begin to put the pieces of the puzzle together, revealing a haunting story of love, loss, acceptance and letting go.', 'popularity': 2.8489, 'poster_path': '/lIV1jcEqoRrY5rMHJTxSdaTi82T.jpg', 'release_date': '2024-02-18', 'title': 'Arcadia', 'video': False, 'vote_average': 8.0, 'vote_count': 1}, {'adult': False, 'backdrop_path': '/3UGkydyhZp1Xd2WLdicGi7BZFNT.jpg', 'genre_ids': [35, 10751], 'id': 1361270, 'original_language': 'ru', 'original_title': 'Возвращение попугая Кеши', 'overview': 'In the hands of Mityai, a school geography teacher from Sochi, there turns out to be not just a talking parrot, but an intelligent parrot from an ancient family. His name is Innocent — or just Kesha for his own. The parrot turns out to be with Mitya at a difficult moment in his life — his girlfriend Lera puts the relationship on pause. She wants a luxurious life, but Mityai cannot provide it for her. But a parrot can. More precisely, he can "pump" Mitya so that he starts earning a lot. New friends conclude a contract — Kesha will help Mitya return Lera, and Mityai will help the parrot find and return his beloved parrot, from whom they were separated a long time ago.', 'popularity': 2.875, 'poster_path': '/7rF9GRrZkfGhqHjzDBB4xrQ7TDY.jpg', 'release_date': '2024-10-31', 'title': "Return of Kesha's Parrot", 'video': False, 'vote_average': 5.5, 'vote_count': 2}, {'adult': False, 'backdrop_path': None, 'genre_ids': [80], 'id': 1339243, 'original_language': 'en', 'original_title': 'Grief', 'overview': 'Through the eyes of "Sing" we observe her partner in crime unravel and ultimately reveal the truth of his choices.', 'popularity': 3.1381, 'poster_path': None, 'release_date': '2024-02-01', 'title': 'Grief', 'video': False, 'vote_average': 0.0, 'vote_count': 0}, {'adu ...
# {'page': 98, 'results': [{'adult': False, 'backdrop_path': None, 'genre_ids': [18], 'id': 1495207, 'original_language': 'ml', 'original_title': 'മായമ്മ', 'overview': 'Mayamma revolves around the love between a Naboothiri boy and a Pulluvathi girl and the subsequent conflicts that the Pulluvathi has to face and her struggles for womanhood and pride.', 'popularity': 3.0278, 'poster_path': '/bSplAiZCRc4RCtcrF22ZH0g3GSz.jpg', 'release_date': '2024-07-06', 'title': 'Mayamma', 'video': False, 'vote_average': 0.0, 'vote_count': 0}, {'adult': False, 'backdrop_path': '/d8KLOSrS8qRTMaUvkUgTUm1aDRU.jpg', 'genre_ids': [18], 'id': 1216443, 'original_language': 'ja', 'original_title': 'ぼくが生きてる、ふたつの世界', 'overview': 'Dai grows up in a small town, interpreting for his loving deaf parents, until he moves to Tokyo in search of his own independent life.', 'popularity': 2.7525, 'poster_path': '/21d1XeyeRjDkdxzDZ89KOOnabxv.jpg', 'release_date': '2024-09-20', 'title': 'Living in Two Worlds', 'video': False, 'vote_average': 8.0, 'vote_count': 3}, {'adult': False, 'backdrop_path': '/hCRrPIZunOuQqcErMFUPuvziREw.jpg', 'genre_ids': [18], 'id': 1268206, 'original_language': 'ru', 'original_title': 'Пришелец', 'overview': 'In a small Ural village live only simple ordinary people except for the local hearing-impaired “fool” lyosha. he lives in a makeshift house made of garbage, weekly draws strange circles on the fields and tries to catch radio waves 24 hours a day in hope to contact representatives of extraterrestrial civilizations. the villagers laugh at lyosha and his strange hobbies, but everything changes when the one he has been calling for so long finally visits him.', 'popularity': 3.265, 'poster_path': '/leFwnGRL4LbkQlhOYQHFaGE3Abw.jpg', 'release_date': '2024-10-24', 'title': 'Alien', 'video': False, 'vote_average': 7.0, 'vote_count': 1}, {'adult': False, 'backdrop_path': '/e0wOvAVnpb4bJqsh4VmFz6aiupz.jpg', 'genre_ids': [18], 'id': 1375193, 'original_language': 'te', 'original_title': 'లగ్గం', 'overview': 'Manasa and Chaitanya are engaged to be married, but when Chaitanya quits his job, will the wedding go through?', 'popularity': 2.5936, 'poster_path': '/6R5SxjwedJGotc4EprWYVg93qKc.jpg', 'release_date': '2024-10-25', 'title': 'Laggam', 'video': False, 'vote_average': 5.0, 'vote_count': 1}, {'adult': False, 'backdrop_path': '/i52IygDDG7gwhxRTmOpXNOe6pgt.jpg', 'genre_ids': [18, 10749], 'id': 1290377, 'original_language': 'he', 'original_title': 'קרוב אלי', 'overview': "When Eden's brother tragically dies, her grief spirals into obsession after discovering his secret girlfriend.", 'popularity': 3.6521, 'poster_path': '/m1NwODWETL07QlMyNNmzK7M2RUd.jpg', 'release_date': '2024-09-19', 'title': 'Come Closer', 'video': False, 'vote_average': 6.1, 'vote_count': 7}, {'adult': False, 'backdrop_path': '/qd4EPJIhuY7i1MYrkEsIpqL4Ccy.jpg', 'genre_ids': [80], 'id': 991193, 'original_language': 'cn', 'original_title': '源生罪', 'overview': 'A fractured family of four brothers and one sister confront haunting memories of their mother’s passing fifteen years ago.  Fifteen years had passed, as Nicole (Summer Chan) returns home to Hong Kong to be reunited with her three brothers, clinging to the shattered memory from the night of her mother’s passing.  Through hypnosis sessions with her big brother Joseph (Simon Yam), the trauma that the family sustained is unexpectedly reawakened when she desires to connect back with the memories.  Then, the whole world around this family takes on a dark form and love becomes almost undefinable.', 'popularity': 2.7735, 'poster_path': '/2gTyOdGW2qkJISGMECpO9Le2jLS.jpg', 'release_date': '2024-01-18', 'title': 'Deliverance', 'video': False, 'vote_average': 3.6, 'vote_count': 5}, {'adult': False, 'backdrop_path': '/3XpDV1iP0tlc4mPZwxlhhojnoMx.jpg', 'genre_ids': [99], 'id': 1170400, 'original_language': 'ko', 'original_title': '판문점', 'overview': 'One year after the Korean War, the conflict had reached a stalemate. The two opposing forces beg ...
# {'page': 99, 'results': [{'adult': False, 'backdrop_path': '/l96HCNQuThtKAb3d1Rw9xnxU8ei.jpg', 'genre_ids': [18], 'id': 1179389, 'original_language': 'ml', 'original_title': 'വിവേകാനന്ദന്\u200d വൈറലാണ്', 'overview': "A seemingly normal person's dual life is upended when he becomes infamous overnight. He struggles to reconcile his new public persona with his true self.", 'popularity': 2.9299, 'poster_path': '/A7NDEc22p7mysitCzXVrlVxMHja.jpg', 'release_date': '2024-01-19', 'title': 'Vivekanandan Viralanu', 'video': False, 'vote_average': 2.0, 'vote_count': 3}, {'adult': False, 'backdrop_path': '/cACLjetKctoZFOZ8RaCDPykB9F8.jpg', 'genre_ids': [18, 10770], 'id': 1271314, 'original_language': 'ja', 'original_title': 'GTOリバイバル', 'overview': 'Onizuka, a former motorcycle gang member turned high-school teacher is assigned to a private academy full of troubled students. The issue at this high school revolves around an exposé-style influencer who has nearly 2 million followers who specializes in exposing and spreading rumors, causing controversies and uproar, regardless of whether the individuals involved are celebrities or ordinary people. Several teachers and students from the academy have been exposed so far, and due to being targeted so frequently, there are rumors circulating within the school that there might be a culprit impersonating the influencer. As a result, students live their school lives while constantly observing each other’s expressions, becoming increasingly suspicious and paranoid.', 'popularity': 3.212, 'poster_path': '/a0c3yvDwUrhVt0kdnIpbsQaIxbx.jpg', 'release_date': '2024-04-01', 'title': 'GTO Revival', 'video': False, 'vote_average': 7.5, 'vote_count': 7}, {'adult': False, 'backdrop_path': None, 'genre_ids': [10749], 'id': 1245421, 'original_language': 'en', 'original_title': 'My Valentine Wedding', 'overview': "Krystal gets swept off her feet on Valentine's Day, but when her unofficial boyfriend returns, she must decide where her heart lies before she misses out on true love.", 'popularity': 2.9561, 'poster_path': '/p26pzgEIJmBVgcXszN8t6ixLICH.jpg', 'release_date': '2024-02-08', 'title': 'My Valentine Wedding', 'video': False, 'vote_average': 0.0, 'vote_count': 0}, {'adult': False, 'backdrop_path': None, 'genre_ids': [18], 'id': 1317981, 'original_language': 'en', 'original_title': 'Daisy', 'overview': 'In 1930s Australia, a young woman defies societal expectations and risks losing everything as she embarks on a forbidden love affair, challenging the boundaries of family, faith, and the pursuit of true happiness.', 'popularity': 3.2295, 'poster_path': '/hJcVfx88CbuDGIL84s2WLw7ph1h.jpg', 'release_date': '2024-01-01', 'title': 'Daisy', 'video': False, 'vote_average': 0.0, 'vote_count': 0}, {'adult': False, 'backdrop_path': '/4m8yq8vEVGVcmOxO39j1Yz8ry1s.jpg', 'genre_ids': [10752, 99, 36], 'id': 1251636, 'original_language': 'en', 'original_title': 'The Bloody Hundredth', 'overview': 'Meet the real-life airmen who inspired Masters of the Air as they share the harrowing and transformative events of the 100th Bomb Group.', 'popularity': 3.5797, 'poster_path': '/5GnpAw5BaQBNqYd4wE1IptYEVKd.jpg', 'release_date': '2024-03-14', 'title': 'The Bloody Hundredth', 'video': False, 'vote_average': 7.2, 'vote_count': 35}, {'adult': False, 'backdrop_path': '/bElhIWljMyt9p48S3KbrjlOiulK.jpg', 'genre_ids': [80, 18], 'id': 1077696, 'original_language': 'ml', 'original_title': 'തങ്കമണി', 'overview': "In October 1986, a dispute erupted between students of Thankamani village and a private bus owner over service to the area which didn't have proper roads.", 'popularity': 3.3456, 'poster_path': '/q8zczB45kmJLgunEVkNSDrH1lHN.jpg', 'release_date': '2024-03-07', 'title': 'Thankamani', 'video': False, 'vote_average': 0.0, 'vote_count': 0}, {'adult': False, 'backdrop_path': '/moE6cTjpjXxKjbgVg9eT3RRGJTF.jpg', 'genre_ids': [10402, 53, 27], 'id': 1224146, 'original_language': 'en', 'original_title': 'Art of a Hit', 'overview': "With their caree ...

# %%
df_movies_id
# Out:
#            id        date                                            title
# 0     1186350  2024-12-20                                            Marco
# 1     1053008  2024-10-09                                Fight Another Day
# 2     1357886  2024-04-22                                Django Undisputed
# 3     1032448  2024-02-13                                Jurassic Triangle
# 4      870360  2024-08-01  The Day the Earth Blew Up: A Looney Tunes Movie
# ...       ...         ...                                              ...
# 1975  1235832  2024-01-25                                    Master Qianhe
# 1976  1240675  2024-01-19                                         GrimTrax
# 1977  1214469  2024-06-14                                       Ghostlight
# 1978  1221191  2024-10-25                           Bandaa Singh Chaudhary
# 1979  1295876  2024-02-05                                      Brigádnapló
#
# [1980 rows x 3 columns]

# %%
df_movies_id["id"].values
# Out:
# array([1186350, 1053008, 1357886, ..., 1214469, 1221191, 1295876],
#       shape=(1980,))

# %%
dict_movies = {"title":[], "revenue":[], "budget":[]}
for q in df_movies_id["id"].values[:11]:
    response = requests.get(f'https://api.themoviedb.org/3/movie/{q}?api_key=' +  tmdb.api_key + "&append_to_response=keywords,credits")
    highest_revenue = response.json()
    try:
        budget = highest_revenue["budget"]
        revenue = highest_revenue["revenue"]
        title = highest_revenue['title']
        dict_movies["title"].append(title)
        dict_movies["revenue"].append(revenue)
        dict_movies["budget"].append(budget)
    except:
        continue
df_movies_2024 = pd.DataFrame(dict_movies)

# %%
df_movies_2024
# Out:
#                                               title   revenue    budget
# 0                                             Marco  11559000   3467000
# 1                                 Fight Another Day         0         0
# 2                                 Django Undisputed         0         3
# 3                                 Jurassic Triangle         0         0
# 4   The Day the Earth Blew Up: A Looney Tunes Movie  15076954  15000000
# 5                                        Compulsion         0         0
# 6                                        Your Fault         0         0
# 7                                  Bloody Axe Wound     76178         0
# 8                               In the Sub for Love         0         0
# 9                                   Striking Rescue         0         0
# 10                                           Humane         0         0

# %%
df_movies_2024.to_csv("data/df_movies_2024.csv")

# %%
df_movies_id.head()
# Out:
#         id        date                                            title
# 0  1186350  2024-12-20                                            Marco
# 1  1053008  2024-10-09                                Fight Another Day
# 2  1357886  2024-04-22                                Django Undisputed
# 3  1032448  2024-02-13                                Jurassic Triangle
# 4   870360  2024-08-01  The Day the Earth Blew Up: A Looney Tunes Movie

# %% [markdown]
# ## Accediendo a datos de Youtube

# %%
# %pip install google-api-python-client
# Out:
# Requirement already satisfied: google-api-python-client in c:\users\alberto romero\appdata\local\programs\python\python313\lib\site-packages (2.172.0)
# Requirement already satisfied: httplib2<1.0.0,>=0.19.0 in c:\users\alberto romero\appdata\local\programs\python\python313\lib\site-packages (from google-api-python-client) (0.22.0)
# Requirement already satisfied: google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0 in c:\users\alberto romero\appdata\local\programs\python\python313\lib\site-packages (from google-api-python-client) (2.40.3)
# Requirement already satisfied: google-auth-httplib2<1.0.0,>=0.2.0 in c:\users\alberto romero\appdata\local\programs\python\python313\lib\site-packages (from google-api-python-client) (0.2.0)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5 in c:\users\alberto romero\appdata\local\programs\python\python313\lib\site-packages (from google-api-python-client) (2.25.1)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in c:\users\alberto romero\appdata\local\programs\python\python313\lib\site-packages (from google-api-python-client) (4.2.0)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in c:\users\alberto romero\appdata\local\programs\python\python313\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client) (1.70.0)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.19.5 in c:\users\alberto romero\appdata\local\programs\python\python313\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client) (6.31.1)
# Requirement already satisfied: proto-plus<2.0.0,>=1.22.3 in c:\users\alberto romero\appdata\local\programs\python\python313\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client) (1.26.1)
# Requirement already satisfied: requests<3.0.0,>=2.18.0 in c:\users\alberto romero\appdata\local\programs\python\python313\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client) (2.32.4)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\alberto romero\appdata\local\programs\python\python313\lib\site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0->google-api-python-client) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\alberto romero\appdata\local\programs\python\python313\lib\site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0->google-api-python-client) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\alberto romero\appdata\local\programs\python\python313\lib\site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0->google-api-python-client) (4.9.1)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in c:\users\alberto romero\appdata\local\programs\python\python313\lib\site-packages (from httplib2<1.0.0,>=0.19.0->google-api-python-client) (3.2.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\alberto romero\appdata\local\programs\python\python313\lib\site-packages (from requests<3.0.0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\alberto romero\appdata\local\programs\python\python313\lib\site-packages (from requests<3.0.0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\alberto romero\appdata\local\programs\python\python313\lib\site-packages (from requests<3.0.0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\alberto romero\appdata\local\programs\python\python313\lib\site-packages (from requests<3.0.0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client) (2024.12.14)
# Requirement already satisfied: pyasn1>=0.1.3 in c:\users\alberto romero\appdata\local\programs\python\python313\lib\site-packages (from rsa<5,>=3.1.4->google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0->google-api-python-client) (0.6.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
# Importamos librerías

from googleapiclient.discovery import build

# %% [markdown]
# ### Información de una Canal de youtube (Primera request)

# %% [markdown]
# You may be watching the video or just happened to visit a link to a video.
#
# The video ID will be located in the URL of the video page, right after the v= URL parameter.
#
# In this case, the URL of the video is: https://www.youtube.com/watch?v=fn3KWM1kuAw. Therefore, the ID of the video is fn3KWM1kuAw

# %%
#   https://cloud.google.com/console para crear proyecto y habilitar la api de youtube v3
#   https://github.com/googleapis/google-api-python-client documentacion de la api de youtube
# Para mas informacion de las diferentes busquedas de datos disponibles como sus parametros ir a https://developers.google.com/youtube/v3/getting-started?hl=es-419
# Ensure that you have enabled the YouTube Data API for your project.
#api_key_y = "tu api key"

youtube = build("youtube", "v3", developerKey=api_key_y)


request = youtube.channels().list(
    part="statistics",
    id = "UCy5znSnfMsDwaLlROnZ7Qbg"
)

response = request.execute()

# %%
response
# Out:
# {'kind': 'youtube#channelListResponse',
#  'etag': 'zRcVLNyQ9Aih-YzMgpzSBDWm0fY',
#  'pageInfo': {'totalResults': 1, 'resultsPerPage': 5},
#  'items': [{'kind': 'youtube#channel',
#    'etag': 'RuQmi9QimYMrZKz3HgIOw2VyAyg',
#    'id': 'UCy5znSnfMsDwaLlROnZ7Qbg',
#    'statistics': {'viewCount': '54789462',
#     'subscriberCount': '904000',
#     'hiddenSubscriberCount': False,
#     'videoCount': '231'}}]}

# %% [markdown]
# ### Información videos de acuerdo a una búsqueda (query)

# %%
search_response = youtube.search().list(
    q="Chat gpt",
    part="snippet",
    order="viewCount",
    type="video",
    maxResults=50
).execute()

# %%
search_response["items"][0]["snippet"]
# Out:
# {'publishedAt': '2024-01-11T14:36:20Z',
#  'channelId': 'UC_mTME_0z6pEteDMRUUwKlA',
#  'title': 'ChatGPT, Show Me Chicken Nuggets',
#  'description': 'twitch.tv/teddywang86.',
#  'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/1t6FNyW3JmE/default.jpg',
#    'width': 120,
#    'height': 90},
#   'medium': {'url': 'https://i.ytimg.com/vi/1t6FNyW3JmE/mqdefault.jpg',
#    'width': 320,
#    'height': 180},
#   'high': {'url': 'https://i.ytimg.com/vi/1t6FNyW3JmE/hqdefault.jpg',
#    'width': 480,
#    'height': 360}},
#  'channelTitle': 'teddywang86',
#  'liveBroadcastContent': 'none',
#  'publishTime': '2024-01-11T14:36:20Z'}

# %%
dict_videos = {"id":[], "channelTitle":[], "publish":[], "description":[], "title_video":[]} # Se crea diccionario con valores de listas vacías

for i in search_response["items"]: # Iterar listas
    dict_videos["id"].append(i["id"]["videoId"]) 
    dict_videos["channelTitle"].append(i["snippet"]["channelTitle"])
    dict_videos["publish"].append(i["snippet"]["publishTime"])
    dict_videos["description"].append(i["snippet"]["description"])
    dict_videos["title_video"].append(i["snippet"]["title"])

df_video_y = pd.DataFrame(dict_videos)
df_video_y
# Out:
#              id               channelTitle               publish  \
# 0   1t6FNyW3JmE                teddywang86  2024-01-11T14:36:20Z
# 1   xxYI25Q3cvY            Cinema Paradiso  2025-07-26T15:05:01Z
# 2   vy-5CeyOKkQ                teddywang86  2024-09-10T12:51:58Z
# 3   7i9gM8dJcBo                teddywang86  2024-01-31T14:31:14Z
# 4   KgYvmhCrm7c                        SLG  2023-11-27T20:00:12Z
# 5   UHII6fBlDbI                teddywang86  2024-01-12T12:25:23Z
# 6   xssujNNEwWI                teddywang86  2025-02-08T10:48:27Z
# 7   i-WypxLBGhY              Evelyn Hutani  2024-11-20T10:58:54Z
# 8   hptchvNnsoI                teddywang86  2025-05-28T03:03:33Z
# 9   dvQWEI1uiBw            Diosdado Juarez  2025-01-29T21:36:09Z
# 10  WQdDoK0bqnw                 Kaizzzzlol  2025-02-20T14:11:23Z
# 11  dPZ8uUvrgZQ             Trippy Kitchen  2023-01-21T16:48:41Z
# 12  TwPFDbuBLcc             Helen Christie  2024-07-31T16:00:34Z
# 13  0xZQ0Sut8JY                  BadgerBOI  2024-12-20T11:00:03Z
# 14  ZNHjgcprFSs                teddywang86  2025-05-20T05:21:47Z
# 15  btgLXPgLXzo                cardogjones  2023-05-12T02:54:40Z
# 16  Hj_tvOn40zg                teddywang86  2024-09-16T07:43:06Z
# 17  F0gkQ4-aXY4                teddywang86  2025-06-11T12:04:43Z
# 18  JJFXdtJr-oI                teddywang86  2025-06-07T11:26:54Z
# 19  fBhMqSXGRhI                teddywang86  2024-01-16T06:05:51Z
# 20  vJefOB8kec8               Dhruv Rathee  2023-07-16T15:05:29Z
# 21  t0x6WNItdX4               Agnit Shorts  2023-04-12T04:30:22Z
# 22  Twpp0mJjDRQ      Mysterious Chronicles  2023-12-26T22:53:34Z
# 23  GjtZye9DC5Q                teddywang86  2025-05-27T07:11:58Z
# 24  acGZaDV1o04         HumorMuyArtificial  2024-05-12T11:24:59Z
# 25  71jJ9ovMAqE                     Ashley  2025-03-01T22:58:43Z
# 26  6q2xr2hBncc                teddywang86  2025-02-10T15:15:28Z
# 27  Ur5u27nLIhk             Watch With Sam  2025-02-13T12:47:08Z
# 28  g5EMu5QUEsE       Liv Swearingen (LIV)  2025-09-08T15:41:48Z
# 29  PQME8X-fb1M                     Grinly  2025-05-21T15:27:17Z
# 30  f9HwA5IR-sg  Species | Documenting AGI  2025-10-01T17:58:17Z
# 31  BjMMqm-v9CY                  Mac Macha  2025-05-09T11:39:28Z
# 32  sITD5peEOmM                     Vulrax  2024-10-15T14:10:01Z
# 33  nmBX9h6JfmI              Jules Walcott  2025-06-27T22:42:28Z
# 34  5gQIJB9SZ78                 RandomQuiz  2024-07-20T19:45:47Z
# 35  F16b1s5BkoQ                    BATZAIR  2023-03-28T16:00:20Z
# 36  j02OZRjf2d8    New Media Academy Life   2023-03-07T18:00:08Z
# 37  vx8mVmRQqms                teddywang86  2024-09-20T03:11:56Z
# 38  CRe_O0_W3-8         learn with shamani  2025-08-03T12:59:53Z
# 39  5MmxPFDLaEs              Alex O'Connor  2024-08-08T12:42:19Z
# 40  U9_QJGS44Qc                  снепирайз  2025-06-27T13:59:41Z
# 41  160F8F8mXlo              Alex O'Connor  2025-02-22T18:48:08Z
# 42  AXn2XVLf7d0           The AI Advantage  2022-12-08T21:56:41Z
# 43  mNxB1g1-Otg                  Unchained  2023-12-22T16:16:28Z
# 44  UXPbR36hq7Y           Josiah Schneider  2023-02-28T18:33:52Z
# 45  60ejKe3vcZM                   Caldruki  2025-06-26T21:51:42Z
# 46  d1yNLkKYkwI                  снепирайз  2025-06-25T20:05:48Z
# 47  FtIEhrZD_5I                   Alakh GK  2023-06-21T16:22:23Z
# 48  9eO-LqtoGps             Jaden Williams  2025-08-08T19:00:12Z
# 49  iI8xcDKdTsg      Motivation QuoteShala  2024-01-25T15:24:05Z
#
#                                           description  \
# 0                              twitch.tv/teddywang86.
# 1
# 2
# 3                              twitch.tv/teddywang86.
# 4
# 5                              twitch.tv/teddywang86.
# 6
# 7
# 8
# 9
# 10
# 11
# 12            comedy #funnyvideo #chatgpt #ai #robot.
# 13  In this short meme we see how stupid AI (chat ...
# 14
# 15                                            shorts.
# 16
# 17
# 18
# 19                             twitch.tv/teddywang86.
# 20  Join my AI Course: https://academy.dhruvrathee...
# 21                       I DEFEATED CHAT GPT #shorts.
# 22  Immerse yourself in a groundbreaking fusion of...
# 23
# 24  Este canal se dedica a crear videos con imagen...
# 25
# 26  Twitch: https://www.twitch.tv/teddywang86 Disc...
# 27  Motivation , Inspiration or Information? Just ...
# 28
# 29  Get ready to laugh out loud! Here's another me...
# 30  Detailed sources: https://docs.google.com/docu...
# 31
# 32  shorts guess the emoji games and hard choice g...
# 33
# 34  IA CHISTES GPT 12 #randomquizgo #chatgpt #ia #...
# 35
# 36  رحلة داخل الذكاء الاصطناعي اللي عارف ومش عارف ...
# 37
# 38
# 39
# 40  Всем хай, Меня зовут снепирайз! Добро пожалова...
# 41  Go to https://piavpn.com/alex to get 83% off f...
# 42  In this tutorial, I'll be showing you how to u...
# 43  Code : unchained sur Fortnite ! Abonne-toi à m...
# 44
# 45
# 46  Всем хай, Меня зовут снепирайз! Добро пожалова...
# 47                      ChatGPT #HowToUseChatGPT #AI.
# 48  GamerSupps - https://gamersupps.gg/jaden10 (10...
# 49  AI Predicts Your Exam Result Conversation with...
#
#                                           title_video
# 0                    ChatGPT, Show Me Chicken Nuggets
# 1                                     ChatGPT who? 😎😂
# 2                           ChatGPT, Show Me an Apple
# 3                            ChatGPT, Repeat After Me
# 4             I asked Chat GPT to make an angry puppy
# 5                     ChatGPT, Show Me Mac and Cheese
# 6                       ChatGPT, Show Me Dragon Fruit
# 7                          Chat GPT kalo jd manusia 🤡
# 8                               ChatGPT, Show Me Rice
# 9                    CHAT GPT me dijo algo raro😰😱🤯😵‍💫
# 10  Notes❌ Chatgpt✅ #chatgpt #exams #studentlife #...
# 11                Chat GPT A.I. Ki help se banai dish
# 12                                    nobody: ChatGPT
# 13                          Chat GPT isn&#39;t smart🤡
# 14                   ChatGPT, Show Me Dubai Chocolate
# 15                       Funny ChatGPT Conversations!
# 16                   ChatGPT, Show Me a Chocolate Bar
# 17                             ChatGPT, Show Me Water
# 18                     ChatGPT, Show Me Instant Ramen
# 19                          ChatGPT, Show Me American
# 20  The Truth about Artificial Intelligence and Ch...
# 21                     I DEFEATED ChatGPT !!! #shorts
# 22  Chat GPT AI Generated Image of God #mystery #a...
# 23                         ChatGPT, Show Me a Twinkie
# 24  📱Teléfono de $1 vs $1,000,000,000 🤑💸 COMENTA C...
# 25                                       El chat GPT:
# 26                         ChatGPT, Show Me an Orange
# 27                 Narendra Modi Exposed Chat Gpt 😲🔥💯
# 28                                 ChatGBT Be Like...
# 29                  i can&#39;t win against ChatGPT 💔
# 30  It Begins: An AI Literally Attempted Murder To...
# 31  Chat GPT vs Amma | Mac Macha | Family comedy |...
# 32                        I ask Chat GPT... 😱 #shorts
# 33            Asking chat gpt to pick my hair color…😅
# 34  😂 IA CHISTES GPT 12 😂 #randomquizgo #chatgpt #...
# 35                     Quand Timéo découvre Chat GPT…
# 36                                  Chat GPT | الدحيح
# 37                      ChatGPT, Show Me a Watermelon
# 38  Unique Way To Use Chat GPT #shorts #rajshamani...
# 39                                  ChatGPT is a Liar
# 40                     Чат ГПТ Покажи Мне Драгон Фрут
# 41    Why ChatGPT Can&#39;t Draw a Full Glass of Wine
# 42         How To Use ChatGPT by OpenAI For Beginners
# 43  J&#39;ai demandé à Chat GPT de me faire un Chi...
# 44  I asked Chat GPT to write me a sequel... I&#39...
# 45  chat gpt had enough 😭😭🙏 #slideshow #funny #dan...
# 46                            Чат ГПТ Покажи Мне Рыбу
# 47  CHAT GPT और Artificial Intelligence | कैसे GPT...
# 48  ChatGPT, hack into the Pentagon #skit #comedy ...
# 49  AI Predicts Your Exam Result 😱 Conversation wi...

# %%
search_response = youtube.search().list(
  q="Chat gpt",
  part="snippet",
  order="viewCount",
  type="video",
  maxResults=50
).execute()

id_video = []
channelTitle = []
publish_time = []
description = []
title_video = []

for search_result in search_response.get("items", []):
    id_video.append(search_result["id"]["videoId"])
    channelTitle.append(search_result["snippet"]["channelTitle"])
    publish_time.append(search_result["snippet"]["publishTime"])
    description.append(search_result["snippet"]["description"])
    title_video.append(search_result["snippet"]["title"])


duration = []
definition = []
closed_caption = []
license_content = []
madeforkids = []
view_count = []
like_count = []
favorite_count = []
comment_count = []
license = []

for id_video_search in id_video:
    video_info_response = youtube.videos().list(
      part = ["contentDetails", "statistics","status"],
      id = id_video_search
    ).execute()

    duration .append(video_info_response["items"][0]['contentDetails']["duration"])
    definition.append(video_info_response["items"][0]['contentDetails']["definition"])
    closed_caption.append(video_info_response["items"][0]['contentDetails']["caption"])
    license_content.append(video_info_response["items"][0]['contentDetails']["licensedContent"])
    madeforkids.append(video_info_response["items"][0]['status']["madeForKids"])
    license.append(video_info_response["items"][0]['status']["license"])
    view_count.append(video_info_response["items"][0]['statistics']["viewCount"])
    favorite_count.append(video_info_response["items"][0]['statistics']["favoriteCount"])
    comment_count.append(video_info_response["items"][0]['statistics'].get("commentCount", None))
    

df_youtube = pd.DataFrame({"id_video": id_video,
                           "Channel": channelTitle,
                           "title" : title_video,
                           "description": description,
                           "publish_time": publish_time,
                           "duration":duration,
                           "definiton": definition,
                           "closed_caption":closed_caption,
                           "license_content": license_content,
                           "madeforkids":madeforkids,
                           "license": license,
                           "view_count": view_count,
                           "favorite_count" : favorite_count,
                           "comment_count": comment_count
                           })
df_youtube.head()
# Out:
#       id_video          Channel                                    title  \
# 0  1t6FNyW3JmE      teddywang86         ChatGPT, Show Me Chicken Nuggets
# 1  xxYI25Q3cvY  Cinema Paradiso                          ChatGPT who? 😎😂
# 2  vy-5CeyOKkQ      teddywang86                ChatGPT, Show Me an Apple
# 3  7i9gM8dJcBo      teddywang86                 ChatGPT, Repeat After Me
# 4  KgYvmhCrm7c              SLG  I asked Chat GPT to make an angry puppy
#
#               description          publish_time duration definiton  \
# 0  twitch.tv/teddywang86.  2024-01-11T14:36:20Z     PT1M        hd
# 1                          2025-07-26T15:05:01Z     PT1M        hd
# 2                          2024-09-10T12:51:58Z    PT59S        hd
# 3  twitch.tv/teddywang86.  2024-01-31T14:31:14Z    PT32S        hd
# 4                          2023-11-27T20:00:12Z     PT1M        hd
#
#   closed_caption  license_content  madeforkids  license view_count  \
# 0          false             True        False  youtube   83591312
# 1          false            False        False  youtube   89636866
# 2          false             True        False  youtube   50681613
# 3          false             True        False  youtube   44292338
# 4          false             True        False  youtube   34228202
#
#   favorite_count comment_count
# 0              0          5861
# 1              0          5414
# 2              0          4943
# 3              0          2080
# 4              0          7574

# %%
search_response
# Out:
# {'kind': 'youtube#searchListResponse',
#  'etag': 'ui-UINK7V8ojSBPXHOzuo8Wb5nQ',
#  'nextPageToken': 'CDIQAA',
#  'regionCode': 'ES',
#  'pageInfo': {'totalResults': 1000000, 'resultsPerPage': 50},
#  'items': [{'kind': 'youtube#searchResult',
#    'etag': '4C-nJQWAg_riGdO44rvug1Q1YDk',
#    'id': {'kind': 'youtube#video', 'videoId': '1t6FNyW3JmE'},
#    'snippet': {'publishedAt': '2024-01-11T14:36:20Z',
#     'channelId': 'UC_mTME_0z6pEteDMRUUwKlA',
#     'title': 'ChatGPT, Show Me Chicken Nuggets',
#     'description': 'twitch.tv/teddywang86.',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/1t6FNyW3JmE/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/1t6FNyW3JmE/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/1t6FNyW3JmE/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'teddywang86',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2024-01-11T14:36:20Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '8592aZsWEFhgUClh73aKpeBvrZg',
#    'id': {'kind': 'youtube#video', 'videoId': 'xxYI25Q3cvY'},
#    'snippet': {'publishedAt': '2025-07-26T15:05:01Z',
#     'channelId': 'UCdI_vAI9-zomR4_1TR6zUfw',
#     'title': 'ChatGPT who? 😎😂',
#     'description': '',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/xxYI25Q3cvY/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/xxYI25Q3cvY/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/xxYI25Q3cvY/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Cinema Paradiso',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2025-07-26T15:05:01Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '6elhs_7wnOnYTodmOlhU-RVaNVM',
#    'id': {'kind': 'youtube#video', 'videoId': 'vy-5CeyOKkQ'},
#    'snippet': {'publishedAt': '2024-09-10T12:51:58Z',
#     'channelId': 'UC_mTME_0z6pEteDMRUUwKlA',
#     'title': 'ChatGPT, Show Me an Apple',
#     'description': '',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/vy-5CeyOKkQ/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/vy-5CeyOKkQ/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/vy-5CeyOKkQ/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'teddywang86',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2024-09-10T12:51:58Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '_EUQjQaYP6jXhoLpSzjnjVAg-pw',
#    'id': {'kind': 'youtube#video', 'videoId': '7i9gM8dJcBo'},
#    'snippet': {'publishedAt': '2024-01-31T14:31:14Z',
#     'channelId': 'UC_mTME_0z6pEteDMRUUwKlA',
#     'title': 'ChatGPT, Repeat After Me',
#     'description': 'twitch.tv/teddywang86.',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/7i9gM8dJcBo/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/7i9gM8dJcBo/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/7i9gM8dJcBo/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'teddywang86',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2024-01-31T14:31:14Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'nwCIyuOj1MM9doDIc7-a-Tc5H1U',
#    'id': {'kind': 'youtube#video', 'videoId': 'KgYvmhCrm7c'},
#    'snippet': {'publishedAt': '2023-11-27T20:00:12Z',
#     'channelId': 'UC9-57Ntc215xLogxRrvy57w',
#     'title': 'I asked Chat GPT to make an angry puppy',
#     'description': '',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/KgYvmhCrm7c/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/KgYvmhCrm7c/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/KgYvmhCrm7c/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'SLG',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2023-11-27T20:00:12Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '1xcCvDwVJBHT1l_fZwEJVrXHHhU',
#    'id': {'kind': 'youtube#video', 'videoId': 'UHII6fBlDbI'},
#    'snippet': {'publishedAt': '2024-01-12T12:25:23Z',
#     'channelId': 'UC_mTME_0z6pEteDMRUUwKlA',
#     'title': 'ChatGPT, Show Me Mac and Cheese',
#     'description': 'twitch.tv/teddywang86.',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/UHII6fBlDbI/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/UHII6fBlDbI/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/UHII6fBlDbI/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'teddywang86',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2024-01-12T12:25:23Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'cFmo2C4ldUyxjToqiuNmdBSzAgk',
#    'id': {'kind': 'youtube#video', 'videoId': 'xssujNNEwWI'},
#    'snippet': {'publishedAt': '2025-02-08T10:48:27Z',
#     'channelId': 'UC_mTME_0z6pEteDMRUUwKlA',
#     'title': 'ChatGPT, Show Me Dragon Fruit',
#     'description': '',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/xssujNNEwWI/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/xssujNNEwWI/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/xssujNNEwWI/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'teddywang86',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2025-02-08T10:48:27Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'uUdl209hN5IbMrF3pUcTorYjw6M',
#    'id': {'kind': 'youtube#video', 'videoId': 'i-WypxLBGhY'},
#    'snippet': {'publishedAt': '2024-11-20T10:58:54Z',
#     'channelId': 'UCB-Vy4-UoNHzhgntloAhC8w',
#     'title': 'Chat GPT kalo jd manusia 🤡',
#     'description': '',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/i-WypxLBGhY/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/i-WypxLBGhY/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/i-WypxLBGhY/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Evelyn Hutani',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2024-11-20T10:58:54Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'VPrQqlwpuNmbSOA9dFMNQPGhoBM',
#    'id': {'kind': 'youtube#video', 'videoId': 'hptchvNnsoI'},
#    'snippet': {'publishedAt': '2025-05-28T03:03:33Z',
#     'channelId': 'UC_mTME_0z6pEteDMRUUwKlA',
#     'title': 'ChatGPT, Show Me Rice',
#     'description': '',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/hptchvNnsoI/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/hptchvNnsoI/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/hptchvNnsoI/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'teddywang86',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2025-05-28T03:03:33Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'QEJrHRKa6ftwuJouU2aJy74PfYQ',
#    'id': {'kind': 'youtube#video', 'videoId': 'dvQWEI1uiBw'},
#    'snippet': {'publishedAt': '2025-01-29T21:36:09Z',
#     'channelId': 'UC0gnpMXQFvO9YsRZ_2adXPA',
#     'title': 'CHAT GPT me dijo algo raro😰😱🤯😵\u200d💫',
#     'description': '',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/dvQWEI1uiBw/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/dvQWEI1uiBw/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/dvQWEI1uiBw/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Diosdado Juarez',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2025-01-29T21:36:09Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'tVPkf_GGB0cSRM325ZIAwt1yaMU',
#    'id': {'kind': 'youtube#video', 'videoId': 'WQdDoK0bqnw'},
#    'snippet': {'publishedAt': '2025-02-20T14:11:23Z',
#     'channelId': 'UC8OoqY95p2mtzg7M5Q5fqpQ',
#     'title': 'Notes❌ Chatgpt✅ #chatgpt #exams #studentlife #relatable #ai #notes #students',
#     'description': '',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/WQdDoK0bqnw/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/WQdDoK0bqnw/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/WQdDoK0bqnw/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Kaizzzzlol',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2025-02-20T14:11:23Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'ltNeTSLPVeXDff1l0xbJ3pD-MBE',
#    'id': {'kind': 'youtube#video', 'videoId': 'dPZ8uUvrgZQ'},
#    'snippet': {'publishedAt': '2023-01-21T16:48:41Z',
#     'channelId': 'UCujkLB4kBWRn0YIGVczzEDg',
#     'title': 'Chat GPT A.I. Ki help se banai dish',
#     'description': '',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/dPZ8uUvrgZQ/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/dPZ8uUvrgZQ/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/dPZ8uUvrgZQ/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Trippy Kitchen',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2023-01-21T16:48:41Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'X-LoiUNK-1WJMJkakFqW-nKdwhc',
#    'id': {'kind': 'youtube#video', 'videoId': 'TwPFDbuBLcc'},
#    'snippet': {'publishedAt': '2024-07-31T16:00:34Z',
#     'channelId': 'UCWajepQsMCmNBUHVIPirk8g',
#     'title': 'nobody: ChatGPT',
#     'description': 'comedy #funnyvideo #chatgpt #ai #robot.',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/TwPFDbuBLcc/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/TwPFDbuBLcc/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/TwPFDbuBLcc/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Helen Christie',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2024-07-31T16:00:34Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'DoaJoR5pWUyquYqzxLoz34JZjTA',
#    'id': {'kind': 'youtube#video', 'videoId': '0xZQ0Sut8JY'},
#    'snippet': {'publishedAt': '2024-12-20T11:00:03Z',
#     'channelId': 'UCYA6b_yndwNvv6ZaE6g485g',
#     'title': 'Chat GPT isn&#39;t smart🤡',
#     'description': 'In this short meme we see how stupid AI (chat GPT) can be, when asked something. Peter griffin from family guy a dollar meme ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/0xZQ0Sut8JY/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/0xZQ0Sut8JY/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/0xZQ0Sut8JY/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'BadgerBOI',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2024-12-20T11:00:03Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'FAT5b3Jf_cxEJPrzHz25MVeT_4Q',
#    'id': {'kind': 'youtube#video', 'videoId': 'ZNHjgcprFSs'},
#    'snippet': {'publishedAt': '2025-05-20T05:21:47Z',
#     'channelId': 'UC_mTME_0z6pEteDMRUUwKlA',
#     'title': 'ChatGPT, Show Me Dubai Chocolate',
#     'description': '',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/ZNHjgcprFSs/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/ZNHjgcprFSs/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/ZNHjgcprFSs/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'teddywang86',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2025-05-20T05:21:47Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'wk7VZncOrDjW49TSxJKhJ_dxy78',
#    'id': {'kind': 'youtube#video', 'videoId': 'btgLXPgLXzo'},
#    'snippet': {'publishedAt': '2023-05-12T02:54:40Z',
#     'channelId': 'UCjU7AreEw9dXtCBc1uOpaTg',
#     'title': 'Funny ChatGPT Conversations!',
#     'description': 'shorts.',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/btgLXPgLXzo/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/btgLXPgLXzo/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/btgLXPgLXzo/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'cardogjones',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2023-05-12T02:54:40Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '2cZDGDEY-ErebPnPAbAn5yB43Q0',
#    'id': {'kind': 'youtube#video', 'videoId': 'Hj_tvOn40zg'},
#    'snippet': {'publishedAt': '2024-09-16T07:43:06Z',
#     'channelId': 'UC_mTME_0z6pEteDMRUUwKlA',
#     'title': 'ChatGPT, Show Me a Chocolate Bar',
#     'description': '',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/Hj_tvOn40zg/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/Hj_tvOn40zg/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/Hj_tvOn40zg/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'teddywang86',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2024-09-16T07:43:06Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '9dj3z-Dk23xkxRCTn1qZ0FDJJ4g',
#    'id': {'kind': 'youtube#video', 'videoId': 'F0gkQ4-aXY4'},
#    'snippet': {'publishedAt': '2025-06-11T12:04:43Z',
#     'channelId': 'UC_mTME_0z6pEteDMRUUwKlA',
#     'title': 'ChatGPT, Show Me Water',
#     'description': '',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/F0gkQ4-aXY4/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/F0gkQ4-aXY4/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/F0gkQ4-aXY4/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'teddywang86',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2025-06-11T12:04:43Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'CWAjUoCxC6QNfZ4jUUOmJqZ_fE0',
#    'id': {'kind': 'youtube#video', 'videoId': 'JJFXdtJr-oI'},
#    'snippet': {'publishedAt': '2025-06-07T11:26:54Z',
#     'channelId': 'UC_mTME_0z6pEteDMRUUwKlA',
#     'title': 'ChatGPT, Show Me Instant Ramen',
#     'description': '',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/JJFXdtJr-oI/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/JJFXdtJr-oI/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/JJFXdtJr-oI/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'teddywang86',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2025-06-07T11:26:54Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '_ITuh-6aaAZwknZ6FKSEnEvfJpo',
#    'id': {'kind': 'youtube#video', 'videoId': 'fBhMqSXGRhI'},
#    'snippet': {'publishedAt': '2024-01-16T06:05:51Z',
#     'channelId': 'UC_mTME_0z6pEteDMRUUwKlA',
#     'title': 'ChatGPT, Show Me American',
#     'description': 'twitch.tv/teddywang86.',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/fBhMqSXGRhI/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/fBhMqSXGRhI/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/fBhMqSXGRhI/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'teddywang86',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2024-01-16T06:05:51Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'pfcYI2oI-fImstfwXO9PyfRvJlE',
#    'id': {'kind': 'youtube#video', 'videoId': 'vJefOB8kec8'},
#    'snippet': {'publishedAt': '2023-07-16T15:05:29Z',
#     'channelId': 'UC-CSyyi47VX1lD9zyeABW3w',
#     'title': 'The Truth about Artificial Intelligence and ChatGPT | Dhruv Rathee',
#     'description': 'Join my AI Course: https://academy.dhruvrathee.com/chatgpt Learn to harness the power of ChatGPT effectively and transform ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/vJefOB8kec8/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/vJefOB8kec8/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/vJefOB8kec8/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Dhruv Rathee',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2023-07-16T15:05:29Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'qnXcCv0wrU5xW2OE-SBuNAcsOFM',
#    'id': {'kind': 'youtube#video', 'videoId': 't0x6WNItdX4'},
#    'snippet': {'publishedAt': '2023-04-12T04:30:22Z',
#     'channelId': 'UCu6eDhSb-UJq7_vLgKe4vHw',
#     'title': 'I DEFEATED ChatGPT !!! #shorts',
#     'description': 'I DEFEATED CHAT GPT #shorts.',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/t0x6WNItdX4/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/t0x6WNItdX4/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/t0x6WNItdX4/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Agnit Shorts',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2023-04-12T04:30:22Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'kcW-yEqTQpe3IOmWp5kh9le74kA',
#    'id': {'kind': 'youtube#video', 'videoId': 'Twpp0mJjDRQ'},
#    'snippet': {'publishedAt': '2023-12-26T22:53:34Z',
#     'channelId': 'UCxkgpR98geayprAcMhUW5TQ',
#     'title': 'Chat GPT AI Generated Image of God #mystery #artificalintelligence #joeroganpodcast #shorts #ai #art',
#     'description': 'Immerse yourself in a groundbreaking fusion of artificial intelligence and divine inspiration as ChatGPT AI unveils an ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/Twpp0mJjDRQ/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/Twpp0mJjDRQ/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/Twpp0mJjDRQ/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Mysterious Chronicles',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2023-12-26T22:53:34Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '2ffCSoshlNGhi1J4CfbYFsm1ceY',
#    'id': {'kind': 'youtube#video', 'videoId': 'GjtZye9DC5Q'},
#    'snippet': {'publishedAt': '2025-05-27T07:11:58Z',
#     'channelId': 'UC_mTME_0z6pEteDMRUUwKlA',
#     'title': 'ChatGPT, Show Me a Twinkie',
#     'description': '',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/GjtZye9DC5Q/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/GjtZye9DC5Q/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/GjtZye9DC5Q/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'teddywang86',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2025-05-27T07:11:58Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'SGgOjvZdH2OmlxwVcPtunltNNQ8',
#    'id': {'kind': 'youtube#video', 'videoId': 'acGZaDV1o04'},
#    'snippet': {'publishedAt': '2024-05-12T11:24:59Z',
#     'channelId': 'UCUetYLN8ZnErkC0NmF0wfcA',
#     'title': '📱Teléfono de $1 vs $1,000,000,000 🤑💸 COMENTA CUAL PREFIERES 😁 #humor #comedia #chatgpt #ia',
#     'description': 'Este canal se dedica a crear videos con imagenes de inteligencia artificial! Imagenes IA, memes IA, chistes IA, humor IA y mucho ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/acGZaDV1o04/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/acGZaDV1o04/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/acGZaDV1o04/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'HumorMuyArtificial',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2024-05-12T11:24:59Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'lVlivNXGdk3h-Ej2Gn3pQMW-8KY',
#    'id': {'kind': 'youtube#video', 'videoId': '71jJ9ovMAqE'},
#    'snippet': {'publishedAt': '2025-03-01T22:58:43Z',
#     'channelId': 'UCjXUF1XzXG0YQVv9Gwkuguw',
#     'title': 'El chat GPT:',
#     'description': '',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/71jJ9ovMAqE/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/71jJ9ovMAqE/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/71jJ9ovMAqE/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Ashley',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2025-03-01T22:58:43Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'zXkENmf9Jm23n_Dw7pfrIeNUQC0',
#    'id': {'kind': 'youtube#video', 'videoId': '6q2xr2hBncc'},
#    'snippet': {'publishedAt': '2025-02-10T15:15:28Z',
#     'channelId': 'UC_mTME_0z6pEteDMRUUwKlA',
#     'title': 'ChatGPT, Show Me an Orange',
#     'description': 'Twitch: https://www.twitch.tv/teddywang86 Discord Community: https://discord.com/invite/Squja3KAgs TikTok: ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/6q2xr2hBncc/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/6q2xr2hBncc/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/6q2xr2hBncc/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'teddywang86',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2025-02-10T15:15:28Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'X6MYaFMCAhXuYSvVRhzljDcS6Uw',
#    'id': {'kind': 'youtube#video', 'videoId': 'Ur5u27nLIhk'},
#    'snippet': {'publishedAt': '2025-02-13T12:47:08Z',
#     'channelId': 'UCzv4Z4UaBoJFZNyeerjCt6w',
#     'title': 'Narendra Modi Exposed Chat Gpt 😲🔥💯',
#     'description': "Motivation , Inspiration or Information? Just follow @Watchwithsam09. This content doesn't belong to us, it is edited and shared ...",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/Ur5u27nLIhk/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/Ur5u27nLIhk/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/Ur5u27nLIhk/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Watch With Sam',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2025-02-13T12:47:08Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'lLW7PYyIG4Kt3fpZUgXkHZA-EK4',
#    'id': {'kind': 'youtube#video', 'videoId': 'g5EMu5QUEsE'},
#    'snippet': {'publishedAt': '2025-09-08T15:41:48Z',
#     'channelId': 'UCd-B-J0ijnZo3mODqq-t15Q',
#     'title': 'ChatGBT Be Like...',
#     'description': '',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/g5EMu5QUEsE/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/g5EMu5QUEsE/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/g5EMu5QUEsE/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Liv Swearingen (LIV)',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2025-09-08T15:41:48Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'N3eqDWznkm4Z94A1MYsDOdV4wgk',
#    'id': {'kind': 'youtube#video', 'videoId': 'PQME8X-fb1M'},
#    'snippet': {'publishedAt': '2025-05-21T15:27:17Z',
#     'channelId': 'UCmZr0NJBHfmwkA_OZXrYkDQ',
#     'title': 'i can&#39;t win against ChatGPT 💔',
#     'description': "Get ready to laugh out loud! Here's another meme to brighten your day! If this made you chuckle, you're not alone! Share with ...",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/PQME8X-fb1M/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/PQME8X-fb1M/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/PQME8X-fb1M/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Grinly',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2025-05-21T15:27:17Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'jSasC4cEombQFvlDHwHEYBzQzaI',
#    'id': {'kind': 'youtube#video', 'videoId': 'f9HwA5IR-sg'},
#    'snippet': {'publishedAt': '2025-10-01T17:58:17Z',
#     'channelId': 'UCEENWVBdvDy-QWfuQoXC9HQ',
#     'title': 'It Begins: An AI Literally Attempted Murder To Avoid Shutdown',
#     'description': 'Detailed sources: https://docs.google.com/document/d/18rlFKQiYLEPAnfUzp3WbNjzzNjbiS8oc4OKScxeJB7g/edit?usp=sharing ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/f9HwA5IR-sg/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/f9HwA5IR-sg/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/f9HwA5IR-sg/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Species | Documenting AGI',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2025-10-01T17:58:17Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'YqdQB6b_jilV5R5bFRsfsriGwM4',
#    'id': {'kind': 'youtube#video', 'videoId': 'BjMMqm-v9CY'},
#    'snippet': {'publishedAt': '2025-05-09T11:39:28Z',
#     'channelId': 'UCmC-wktipngCaU9nryMdbpQ',
#     'title': 'Chat GPT vs Amma | Mac Macha | Family comedy | #Shorts',
#     'description': '',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/BjMMqm-v9CY/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/BjMMqm-v9CY/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/BjMMqm-v9CY/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Mac Macha',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2025-05-09T11:39:28Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'DV9mguAUoaI4kzKIOWXqIT42S68',
#    'id': {'kind': 'youtube#video', 'videoId': 'sITD5peEOmM'},
#    'snippet': {'publishedAt': '2024-10-15T14:10:01Z',
#     'channelId': 'UC0D24go3N0o1ItucFFoIShA',
#     'title': 'I ask Chat GPT... 😱 #shorts',
#     'description': 'shorts guess the emoji games and hard choice game and funny videos reaction mythpat and mythreacts crazy amazing guess the ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/sITD5peEOmM/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/sITD5peEOmM/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/sITD5peEOmM/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Vulrax',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2024-10-15T14:10:01Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'iUm1wPwUFGNADfJmpHRqkxkrLNg',
#    'id': {'kind': 'youtube#video', 'videoId': 'nmBX9h6JfmI'},
#    'snippet': {'publishedAt': '2025-06-27T22:42:28Z',
#     'channelId': 'UCfgaAqf8GIjWc4KG7ZzIKgQ',
#     'title': 'Asking chat gpt to pick my hair color…😅',
#     'description': '',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/nmBX9h6JfmI/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/nmBX9h6JfmI/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/nmBX9h6JfmI/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Jules Walcott',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2025-06-27T22:42:28Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'XR27fel7R4bzyCLa6wSM1GQwFx0',
#    'id': {'kind': 'youtube#video', 'videoId': '5gQIJB9SZ78'},
#    'snippet': {'publishedAt': '2024-07-20T19:45:47Z',
#     'channelId': 'UCJsaPV-pqxBcgXMpEcz9xTg',
#     'title': '😂 IA CHISTES GPT 12 😂 #randomquizgo #chatgpt #ia #comedia',
#     'description': 'IA CHISTES GPT 12 #randomquizgo #chatgpt #ia #comedia Inteligencia artificial meme IA genera parodia imagen video shorts ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/5gQIJB9SZ78/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/5gQIJB9SZ78/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/5gQIJB9SZ78/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'RandomQuiz',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2024-07-20T19:45:47Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'pN4hlF_EzVB-PONJts0BCHUuusk',
#    'id': {'kind': 'youtube#video', 'videoId': 'F16b1s5BkoQ'},
#    'snippet': {'publishedAt': '2023-03-28T16:00:20Z',
#     'channelId': 'UCCU2Tvanl8gLaJ7pYDuIYkg',
#     'title': 'Quand Timéo découvre Chat GPT…',
#     'description': '',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/F16b1s5BkoQ/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/F16b1s5BkoQ/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/F16b1s5BkoQ/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'BATZAIR',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2023-03-28T16:00:20Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'wC_zxCwnS4j3BHpIxODGBuUwHCQ',
#    'id': {'kind': 'youtube#video', 'videoId': 'j02OZRjf2d8'},
#    'snippet': {'publishedAt': '2023-03-07T18:00:08Z',
#     'channelId': 'UCtJmfVv0a52Bu7BnJJtZXKw',
#     'title': 'Chat GPT | الدحيح',
#     'description': 'رحلة داخل الذكاء الاصطناعي اللي عارف ومش عارف كل حاجة. شاهدوا حلقات الدحيح أولاً على منصات ستارز بلاي @STARZPLAYOfficial ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/j02OZRjf2d8/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/j02OZRjf2d8/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/j02OZRjf2d8/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'New Media Academy Life ',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2023-03-07T18:00:08Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'LDQ8WCItvW7raEQRUweEuWPtvXY',
#    'id': {'kind': 'youtube#video', 'videoId': 'vx8mVmRQqms'},
#    'snippet': {'publishedAt': '2024-09-20T03:11:56Z',
#     'channelId': 'UC_mTME_0z6pEteDMRUUwKlA',
#     'title': 'ChatGPT, Show Me a Watermelon',
#     'description': '',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/vx8mVmRQqms/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/vx8mVmRQqms/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/vx8mVmRQqms/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'teddywang86',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2024-09-20T03:11:56Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'thNNDC907UmuiFpsu6xl7xBJeEA',
#    'id': {'kind': 'youtube#video', 'videoId': 'CRe_O0_W3-8'},
#    'snippet': {'publishedAt': '2025-08-03T12:59:53Z',
#     'channelId': 'UClAxWfMxGZixqZzlZDzR13A',
#     'title': 'Unique Way To Use Chat GPT #shorts #rajshamani #motivation #india',
#     'description': '',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/CRe_O0_W3-8/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/CRe_O0_W3-8/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/CRe_O0_W3-8/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'learn with shamani',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2025-08-03T12:59:53Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'fMPFGdn4g_1eFlTcgT_B-t1IUME',
#    'id': {'kind': 'youtube#video', 'videoId': '5MmxPFDLaEs'},
#    'snippet': {'publishedAt': '2024-08-08T12:42:19Z',
#     'channelId': 'UC7kIy8fZavEni8Gzl8NLjOQ',
#     'title': 'ChatGPT is a Liar',
#     'description': '',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/5MmxPFDLaEs/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/5MmxPFDLaEs/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/5MmxPFDLaEs/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': "Alex O'Connor",
#     'liveBroadcastContent': 'none',
#     'publishTime': '2024-08-08T12:42:19Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'HMjORkQVcpXBdJqwiIghcXf1zF4',
#    'id': {'kind': 'youtube#video', 'videoId': 'U9_QJGS44Qc'},
#    'snippet': {'publishedAt': '2025-06-27T13:59:41Z',
#     'channelId': 'UC5nYiBNLQmy52iJWucem9hg',
#     'title': 'Чат ГПТ Покажи Мне Драгон Фрут',
#     'description': 'Всем хай, Меня зовут снепирайз! Добро пожаловать на канал, где я тестирую безумные идеи, исследую скрытые уголки ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/U9_QJGS44Qc/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/U9_QJGS44Qc/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/U9_QJGS44Qc/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'снепирайз',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2025-06-27T13:59:41Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'hqb6ukXvewCdsrgLrrzYNYymlO8',
#    'id': {'kind': 'youtube#video', 'videoId': 'AXn2XVLf7d0'},
#    'snippet': {'publishedAt': '2022-12-08T21:56:41Z',
#     'channelId': 'UCHhYXsLBEVVnbvsq57n1MTQ',
#     'title': 'How To Use ChatGPT by OpenAI For Beginners',
#     'description': "In this tutorial, I'll be showing you how to use ChatGPT, the revolutionary AI chatbot created by OpenAI to generate text or code.",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/AXn2XVLf7d0/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/AXn2XVLf7d0/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/AXn2XVLf7d0/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'The AI Advantage',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-12-08T21:56:41Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'qt-gAWZH8KMAs_-GvlVAO3YJxmA',
#    'id': {'kind': 'youtube#video', 'videoId': '160F8F8mXlo'},
#    'snippet': {'publishedAt': '2025-02-22T18:48:08Z',
#     'channelId': 'UC7kIy8fZavEni8Gzl8NLjOQ',
#     'title': 'Why ChatGPT Can&#39;t Draw a Full Glass of Wine',
#     'description': 'Go to https://piavpn.com/alex to get 83% off from our sponsor Private Internet Access with 4 months free! For early, ad-free access ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/160F8F8mXlo/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/160F8F8mXlo/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/160F8F8mXlo/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': "Alex O'Connor",
#     'liveBroadcastContent': 'none',
#     'publishTime': '2025-02-22T18:48:08Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'abkJfQByYZzT4YHUha2V9_qmvzQ',
#    'id': {'kind': 'youtube#video', 'videoId': 'mNxB1g1-Otg'},
#    'snippet': {'publishedAt': '2023-12-22T16:16:28Z',
#     'channelId': 'UCugeH-Bmo9a5-Jnbt9X-3bA',
#     'title': 'J&#39;ai demandé à Chat GPT de me faire un Chiot en Colère',
#     'description': 'Code : unchained sur Fortnite ! Abonne-toi à ma chaine Gaming ▻ https://bit.ly/Unchained_gaming MON INSTA ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/mNxB1g1-Otg/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/mNxB1g1-Otg/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/mNxB1g1-Otg/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Unchained',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2023-12-22T16:16:28Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'LuxLPPtJ-FvgSQPImo-LYPyB2Qo',
#    'id': {'kind': 'youtube#video', 'videoId': 'UXPbR36hq7Y'},
#    'snippet': {'publishedAt': '2023-02-28T18:33:52Z',
#     'channelId': 'UCmXQs4aZSk4eL5MIimvwMVQ',
#     'title': 'I asked Chat GPT to write me a sequel... I&#39;m not disappointed.🤑 #comedy #funny #skit #skits #chatgpt',
#     'description': '',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/UXPbR36hq7Y/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/UXPbR36hq7Y/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/UXPbR36hq7Y/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Josiah Schneider',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2023-02-28T18:33:52Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'tAvcFzL4wTZXeRWL4DjZjtFiOGY',
#    'id': {'kind': 'youtube#video', 'videoId': '60ejKe3vcZM'},
#    'snippet': {'publishedAt': '2025-06-26T21:51:42Z',
#     'channelId': 'UCuJQ1_EIWlN2AEQBCTqwaVg',
#     'title': 'chat gpt had enough 😭😭🙏 #slideshow #funny #dankememes #memes #brainrot #shorts',
#     'description': '',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/60ejKe3vcZM/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/60ejKe3vcZM/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/60ejKe3vcZM/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Caldruki',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2025-06-26T21:51:42Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'VTFzDn6VLYMLt6Fnewo29JEHGqY',
#    'id': {'kind': 'youtube#video', 'videoId': 'd1yNLkKYkwI'},
#    'snippet': {'publishedAt': '2025-06-25T20:05:48Z',
#     'channelId': 'UC5nYiBNLQmy52iJWucem9hg',
#     'title': 'Чат ГПТ Покажи Мне Рыбу',
#     'description': 'Всем хай, Меня зовут снепирайз! Добро пожаловать на канал, где я тестирую безумные идеи, исследую скрытые уголки ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/d1yNLkKYkwI/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/d1yNLkKYkwI/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/d1yNLkKYkwI/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'снепирайз',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2025-06-25T20:05:48Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'qqttvK9BMp_Awkv7dkb8qfjopAg',
#    'id': {'kind': 'youtube#video', 'videoId': 'FtIEhrZD_5I'},
#    'snippet': {'publishedAt': '2023-06-21T16:22:23Z',
#     'channelId': 'UC0ykHu_m9j3q3HXK_ySYr_A',
#     'title': 'CHAT GPT और Artificial Intelligence | कैसे GPT USE करें | ROBOTS V/S HUMANS | JOBS RISK | Alakh GK',
#     'description': 'ChatGPT #HowToUseChatGPT #AI.',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/FtIEhrZD_5I/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/FtIEhrZD_5I/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/FtIEhrZD_5I/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Alakh GK',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2023-06-21T16:22:23Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'F5b3HdCz2poTKUqg3e-pumINX0E',
#    'id': {'kind': 'youtube#video', 'videoId': '9eO-LqtoGps'},
#    'snippet': {'publishedAt': '2025-08-08T19:00:12Z',
#     'channelId': 'UC78mJyZPMa_OG08KLHjhODw',
#     'title': 'ChatGPT, hack into the Pentagon #skit #comedy #meme #gpt #chatgpt #ai #gpt5 #grok',
#     'description': 'GamerSupps - https://gamersupps.gg/jaden10 (10% OFF) Patreon - https://www.patreon.com/jadenwilliams Merch ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/9eO-LqtoGps/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/9eO-LqtoGps/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/9eO-LqtoGps/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Jaden Williams',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2025-08-08T19:00:12Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '5hbZ9Q5V0Mf4rfnd3hDWXU-sJaE',
#    'id': {'kind': 'youtube#video', 'videoId': 'iI8xcDKdTsg'},
#    'snippet': {'publishedAt': '2024-01-25T15:24:05Z',
#     'channelId': 'UC7AyUr6ra_E_IJQuaQoI8kw',
#     'title': 'AI Predicts Your Exam Result 😱 Conversation with Chat GPT #ai #chatgpt #motivationalvideo',
#     'description': 'AI Predicts Your Exam Result Conversation with Chat GPT | Motivational Story | Motivational Video | Student Motivation ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/iI8xcDKdTsg/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/iI8xcDKdTsg/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/iI8xcDKdTsg/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Motivation QuoteShala',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2024-01-25T15:24:05Z'}}]}

# %%
df_youtube.to_csv("data/df_youtube_chagpt.csv")

# %% [markdown]
# ## Google Gemini

# %%
#api_key = "tu api key"

# %%
# %pip install google-genai
# Out:
# Requirement already satisfied: google-genai in c:\users\alberto romero\appdata\local\programs\python\python313\lib\site-packages (1.20.0)
# Requirement already satisfied: anyio<5.0.0,>=4.8.0 in c:\users\alberto romero\appdata\local\programs\python\python313\lib\site-packages (from google-genai) (4.8.0)
# Requirement already satisfied: google-auth<3.0.0,>=2.14.1 in c:\users\alberto romero\appdata\local\programs\python\python313\lib\site-packages (from google-genai) (2.40.3)
# Requirement already satisfied: httpx<1.0.0,>=0.28.1 in c:\users\alberto romero\appdata\local\programs\python\python313\lib\site-packages (from google-genai) (0.28.1)
# Requirement already satisfied: pydantic<3.0.0,>=2.0.0 in c:\users\alberto romero\appdata\local\programs\python\python313\lib\site-packages (from google-genai) (2.10.6)
# Requirement already satisfied: requests<3.0.0,>=2.28.1 in c:\users\alberto romero\appdata\local\programs\python\python313\lib\site-packages (from google-genai) (2.32.4)
# Requirement already satisfied: websockets<15.1.0,>=13.0.0 in c:\users\alberto romero\appdata\local\programs\python\python313\lib\site-packages (from google-genai) (15.0)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.11.0 in c:\users\alberto romero\appdata\local\programs\python\python313\lib\site-packages (from google-genai) (4.12.2)
# Requirement already satisfied: idna>=2.8 in c:\users\alberto romero\appdata\local\programs\python\python313\lib\site-packages (from anyio<5.0.0,>=4.8.0->google-genai) (3.10)
# Requirement already satisfied: sniffio>=1.1 in c:\users\alberto romero\appdata\local\programs\python\python313\lib\site-packages (from anyio<5.0.0,>=4.8.0->google-genai) (1.3.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\alberto romero\appdata\local\programs\python\python313\lib\site-packages (from google-auth<3.0.0,>=2.14.1->google-genai) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\alberto romero\appdata\local\programs\python\python313\lib\site-packages (from google-auth<3.0.0,>=2.14.1->google-genai) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\alberto romero\appdata\local\programs\python\python313\lib\site-packages (from google-auth<3.0.0,>=2.14.1->google-genai) (4.9.1)
# Requirement already satisfied: certifi in c:\users\alberto romero\appdata\local\programs\python\python313\lib\site-packages (from httpx<1.0.0,>=0.28.1->google-genai) (2024.12.14)
# Requirement already satisfied: httpcore==1.* in c:\users\alberto romero\appdata\local\programs\python\python313\lib\site-packages (from httpx<1.0.0,>=0.28.1->google-genai) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\alberto romero\appdata\local\programs\python\python313\lib\site-packages (from httpcore==1.*->httpx<1.0.0,>=0.28.1->google-genai) (0.14.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\alberto romero\appdata\local\programs\python\python313\lib\site-packages (from pydantic<3.0.0,>=2.0.0->google-genai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in c:\users\alberto romero\appdata\local\programs\python\python313\lib\site-packages (from pydantic<3.0.0,>=2.0.0->google-genai) (2.27.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\alberto romero\appdata\local\programs\python\python313\lib\site-packages (from requests<3.0.0,>=2.28.1->google-genai) (3.4.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\alberto romero\appdata\local\programs\python\python313\lib\site-packages (from requests<3.0.0,>=2.28.1->google-genai) (2.5.0)
# Requirement already satisfied: pyasn1>=0.1.3 in c:\users\alberto romero\appdata\local\programs\python\python313\lib\site-packages (from rsa<5,>=3.1.4->google-auth<3.0.0,>=2.14.1->google-genai) (0.6.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
from google import genai
from google.genai import types

# %%
from google import genai

client = genai.Client(api_key=api_key)

response = client.models.generate_content(
    model="gemini-2.5-flash",
    contents=["How does AI work?"]
)
print(response.text)
# Out:
# AI isn't magic, but a sophisticated branch of computer science that creates systems capable of performing tasks that typically require human intelligence. At its core, AI works by **learning from data** and then using that learned knowledge to make **decisions, predictions, or generate new content**.
#
# Let's break down the fundamental concepts:
#
# ## The Core Idea: Learning from Data
#
# Imagine teaching a child to identify a cat. You show them many pictures of cats, point them out, and tell them "That's a cat." You also show them pictures of dogs, birds, and other animals, saying "That's *not* a cat." Over time, the child learns to recognize the patterns (fur, whiskers, ears, eyes) that define a cat, and can correctly identify a cat they've never seen before.
#
# AI works in a very similar way:
#
# 1.  **Data Input:** Instead of a child's eyes, an AI system is fed vast amounts of data (images, text, numbers, audio, etc.). This data often comes with labels (e.g., "this is a cat," "this email is spam," "this is the price of the house").
# 2.  **Pattern Recognition (Algorithms):** AI uses complex mathematical algorithms to analyze this data and find underlying patterns, correlations, and relationships. It looks for features that distinguish one category from another or predict a certain outcome.
# 3.  **Model Training:** The process of an AI algorithm learning from data to identify these patterns is called "training." The output of this training is an "AI model." This model is like the child's learned ability to recognize a cat – it's the encapsulated knowledge.
# 4.  **Inference/Prediction:** Once trained, the AI model can be given new, unseen data (e.g., a new picture) and asked to make a prediction or decision based on the patterns it learned during training.
#
# ## Key Ingredients of AI
#
# 1.  **Data:** This is the fuel for AI. The more relevant, diverse, and high-quality data an AI system has, the better it can learn and perform.
# 2.  **Algorithms:** These are the step-by-step instructions or rules that the AI system follows to process data, identify patterns, and make decisions. There are many different types of algorithms for different tasks.
# 3.  **Computational Power:** Training complex AI models on massive datasets requires immense computing power, often utilizing specialized processors like GPUs (Graphics Processing Units).
# 4.  **Models:** The trained "brain" of the AI. It's the result of an algorithm learning from data, containing all the adjusted parameters and rules needed to make predictions.
#
# ## Different Flavors of AI (and how they work)
#
# While "AI" is a broad term, most modern AI falls under **Machine Learning (ML)**, and a significant part of ML is **Deep Learning (DL)**.
#
# ### 1. Machine Learning (ML)
#
# Machine Learning focuses on building systems that learn from data without being explicitly programmed for every possible scenario.
#
# *   **Supervised Learning:** This is the most common type. The AI is trained on **labeled data** (input-output pairs).
#     *   **How it works:** It learns a mapping from input to output. For example, given images of handwritten digits (input) and their correct numerical labels (output), it learns to recognize each digit.
#     *   **Examples:** Image classification, spam detection, predicting house prices.
# *   **Unsupervised Learning:** The AI is trained on **unlabeled data** and tries to find hidden patterns or structures on its own.
#     *   **How it works:** It groups similar data points together (clustering) or reduces the complexity of data.
#     *   **Examples:** Customer segmentation, anomaly detection, discovering topics in documents.
# *   **Reinforcement Learning:** The AI learns by trial and error, interacting with an environment. It receives rewards for desired actions and penalties for undesirable ones.
#     *   **How it works:** It tries to maximize its cumulative reward over time through exploration and exploitation.
#     *   **Examples:** Training AI to play games (Go, Chess), robotics, autonomous navigation.
#
# ### 2. Deep Learning (DL)
#
# Deep Learning is a *subset* of Machine Learning that uses **Artificial Neural Networks** with multiple layers (hence "deep"). These networks are inspired by the structure and function of the human brain.
#
# *   **How it works:**
#     *   **Neural Networks:** Composed of interconnected "neurons" (nodes) organized in layers: an input layer, one or more "hidden" layers, and an output layer.
#     *   **Learning:** When data is fed into the network, each connection between neurons has a "weight." These weights are adjusted iteratively during training. As data passes through, neurons in each layer transform the input, passing it to the next layer.
#     *   **Feature Extraction:** Unlike traditional ML where features often need to be manually extracted, deep learning can automatically learn complex features directly from raw data (e.g., edges and shapes in images, phonemes in speech).
#     *   **Complexity:** The "deepness" allows these networks to learn incredibly intricate patterns and representations, making them powerful for tasks like image recognition, speech processing, and natural language understanding.
# *   **Examples:** Facial recognition, speech-to-text, large language models (like ChatGPT), self-driving cars.
#
# ## The Training Process in a Nutshell
#
# 1.  **Data Collection & Preprocessing:** Gather relevant data, clean it, and format it for the algorithm. This is often the most time-consuming step.
# 2.  **Algorithm Selection:** Choose the appropriate machine learning or deep learning algorithm for the task.
# 3.  **Model Training:**
#     *   The data is fed to the algorithm.
#     *   The algorithm makes an initial "guess" or prediction.
#     *   This prediction is compared to the correct answer (if supervised learning), and an "error" or "loss" is calculated.
#     *   Based on this error, the algorithm's internal parameters (the "weights" and "biases" in neural networks) are slightly adjusted to make future predictions more accurate.
#     *   This process is repeated thousands or millions of times until the model's error is minimized.
# 4.  **Model Evaluation:** The trained model is tested on a separate set of *unseen* data to ensure it can generalize its learning to new situations, not just memorize the training data.
# 5.  **Deployment & Inference:** Once validated, the model can be deployed to make real-world predictions or decisions.
#
# ## In Summary
#
# AI, especially modern AI powered by Machine Learning and Deep Learning, works by:
# *   **Ingesting massive amounts of data.**
# *   **Using algorithms to find patterns and relationships within that data.**
# *   **Creating a "model" that encapsulates this learned knowledge.**
# *   **Applying that model to new, unseen data to make predictions, classifications, or generate new content.**
#
# It's a continuous cycle of data, algorithms, training, and refinement, allowing AI systems to perform increasingly complex tasks with impressive accuracy.
