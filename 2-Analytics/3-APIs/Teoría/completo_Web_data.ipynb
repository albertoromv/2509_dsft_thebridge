# %% [markdown]
# # Descargas de diferentes fuentes de la web

# %%
#!python.exe -m pip install --upgrade pip
# Out:
# Requirement already satisfied: pip in c:\users\alberto romero\appdata\local\programs\python\python313\lib\site-packages (25.1.1)

# %%
#%pip install numpy
# Out:
# Requirement already satisfied: numpy in c:\users\alberto romero\appdata\local\programs\python\python313\lib\site-packages (2.3.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
#%pip install pandas
# Out:
# Requirement already satisfied: pandas in c:\users\alberto romero\appdata\local\programs\python\python313\lib\site-packages (2.2.3)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\alberto romero\appdata\local\programs\python\python313\lib\site-packages (from pandas) (2.3.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\alberto romero\appdata\roaming\python\python313\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\alberto romero\appdata\local\programs\python\python313\lib\site-packages (from pandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\alberto romero\appdata\local\programs\python\python313\lib\site-packages (from pandas) (2024.2)
# Requirement already satisfied: six>=1.5 in c:\users\alberto romero\appdata\roaming\python\python313\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
#%pip install requests
# Out:
# Requirement already satisfied: requests in c:\users\alberto romero\appdata\local\programs\python\python313\lib\site-packages (2.20.0)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\users\alberto romero\appdata\local\programs\python\python313\lib\site-packages (from requests) (3.0.4)
# Requirement already satisfied: idna<2.8,>=2.5 in c:\users\alberto romero\appdata\local\programs\python\python313\lib\site-packages (from requests) (2.7)
# Collecting urllib3<1.25,>=1.21.1 (from requests)
#   Using cached urllib3-1.24.3-py2.py3-none-any.whl.metadata (36 kB)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\alberto romero\appdata\local\programs\python\python313\lib\site-packages (from requests) (2024.12.14)
# Using cached urllib3-1.24.3-py2.py3-none-any.whl (118 kB)
# Installing collected packages: urllib3
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 2.4.0
#     Uninstalling urllib3-2.4.0:
#       Successfully uninstalled urllib3-2.4.0
# Successfully installed urllib3-1.24.3
# Note: you may need to restart the kernel to use updated packages.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# selenium 4.31.0 requires urllib3[socks]<3,>=1.26, but you have urllib3 1.24.3 which is incompatible.

# %%
# Importamos librerias
import requests
import zipfile
import pandas as pd
import numpy as np
import json

# %% [markdown]
# ## Primera petición

# %%
url = "https://m.media-amazon.com/images/M/MV5BZGUzYTI3M2EtZmM0Yy00NGUyLWI4ODEtN2Q3ZGJlYzhhZjU3XkEyXkFqcGdeQXVyNTM0OTY1OQ@@._V1_.jpg"
image = requests.get(url)

# %%
image
# Out:
# <Response [200]>

# %%
with open("../data/thelast.png", "wb") as f:
    f.write(image.content)

# %% [markdown]
# ## Bajar datos de inflación mediante url

# %%
df_inflaction = pd.read_csv("https://datahub.io/core/inflation/r/inflation-gdp.csv")
df_inflaction.head()
# Out:
#   Country Country Code  Year  Inflation
# 0   Aruba          ABW  1985   4.032258
# 1   Aruba          ABW  1986   1.073966
# 2   Aruba          ABW  1987   3.643045
# 3   Aruba          ABW  1988   3.121868
# 4   Aruba          ABW  1989   3.991628

# %%
df_inflaction["Country"] == "Spain"
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 11177    False
# 11178    False
# 11179    False
# 11180    False
# 11181    False
# Name: Country, Length: 11182, dtype: bool

# %%
df_inflaction[df_inflaction["Country"] == "Spain"]
# Out:
#      Country Country Code  Year  Inflation
# 2904   Spain          ESP  1960   1.177771
# 2905   Spain          ESP  1961   0.809253
# 2906   Spain          ESP  1962   5.706477
# 2907   Spain          ESP  1963   8.743698
# 2908   Spain          ESP  1964   6.979247
# ...      ...          ...   ...        ...
# 2964   Spain          ESP  2020  -0.322753
# 2965   Spain          ESP  2021   3.093135
# 2966   Spain          ESP  2022   8.390576
# 2967   Spain          ESP  2023   3.532361
# 2968   Spain          ESP  2024   2.774178
#
# [65 rows x 4 columns]

# %%
df_inflaction.to_csv("../data/inflaction.csv") # Crear carpeta "data" en la ubicación del notebook

# %% [markdown]
# ## Bajar datos de Bicimad

# %%
url = "https://opendata.emtmadrid.es/getattachment/c3383795-121b-4ebf-98b4-c7b05e902eaf/202106_movements.aspx"
r = requests.get(url)

# %%
r
# Out:
# <Response [200]>

# %%
# Guardamos el zip
filename = "../data/bicis.zip"
with open(filename, "wb") as f:
    f.write(r.content)

# %%
# Extraemos lo que hay dentro
with zipfile.ZipFile(filename, "r") as zip_ref:
    zip_ref.extractall("data/")

# %%
# Leemos los datos
datos_bicis = pd.read_json("data/202106_movements.json", lines=True, encoding="latin-1", nrows=10000)

# %%
# Vemos qué pinta tienen
datos_bicis.head()
# Out:
#                                     _id  \
# 0  {'$oid': '60bbf3f21b91311d90d568ad'}
# 1  {'$oid': '60bbf3f21b91311d90d568b2'}
# 2  {'$oid': '60bbf3f21b91311d90d568b3'}
# 3  {'$oid': '60bbf3f21b91311d90d568b4'}
# 4  {'$oid': '60bbf3f21b91311d90d568b5'}
#
#                                        user_day_code  idplug_base  user_type  \
# 0  b67ea824acf706087d5818ebc6f90821a5abaab17a0868...           15          1
# 1  364b1b99f1f9a1748f7abf1134c8d6a46197b583649308...            7          1
# 2  5cc17031cba02835dda4b6c153b56572beaade54d8ab91...           14          1
# 3  6e855acaaa17d6d14236598c0f1172c783e16950e39c01...            8          1
# 4  e93417502d55208995a61f4177956ab9289aba39044ce3...            1          1
#
#    idunplug_base  travel_time  idunplug_station  ageRange  idplug_station  \
# 0             13          319                38         0              54
# 1              1          386               185         0             126
# 2             10          465                15         0              91
# 3             22          613                84         0             236
# 4              4          751               131         5              94
#
#         unplug_hourTime zip_code
# 0  2021-06-01T00:00:00Z
# 1  2021-06-01T00:00:00Z
# 2  2021-06-01T00:00:00Z
# 3  2021-06-01T00:00:00Z
# 4  2021-06-01T00:00:00Z    28006

# %%
# Informacion dataframe
datos_bicis.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   _id               10000 non-null  object
#  1   user_day_code     10000 non-null  object
#  2   idplug_base       10000 non-null  int64
#  3   user_type         10000 non-null  int64
#  4   idunplug_base     10000 non-null  int64
#  5   travel_time       10000 non-null  int64
#  6   idunplug_station  10000 non-null  int64
#  7   ageRange          10000 non-null  int64
#  8   idplug_station    10000 non-null  int64
#  9   unplug_hourTime   10000 non-null  object
#  10  zip_code          10000 non-null  object
# dtypes: int64(7), object(4)
# memory usage: 859.5+ KB

# %%
# Valores unicos de la columna zip_code
datos_bicis["zip_code"].unique()
# Out:
# array(['', '28006', '28004', '28045', '28028', '28009', '28007', '28005',
#        '28010', '28034', '28012', '28001', '28008', '28015', '28002',
#        '28105', 'CODIGO_POSTAL_NOT_DEF', '28013', '39724', '28100',
#        '28800', '28027', '28020', '28011', '28014', '28850', '15002',
#        '28003', '45007', '28046', '28039', '28043', '28038', '28934',
#        '28016', '28945', '28221', '28033', '28030', '28029', '28048',
#        '28054', '28035', '35572', '28049', '28004 ', '28019', '28040',
#        '28941', '28523', '28380', '28933', '28026', '45600', '28938',
#        '28220', '28935', '28760', '28863', '28018', '28250', '28053',
#        '28017', '28024', '28823', '28021', '28922', '28210', '28022',
#        '28036', '28047', '28430', '28041', '46009', '28770', '28031',
#        '28200', '46026', '20540', '28232', '28042', '28071', '18006',
#        '28400', '62973', '2', '28521', '28822', '28411', '28229', '48520',
#        '29039', '28260', '28055', '28942', '28815', '28037', '28702',
#        '28707', '28701', '28290', '28691', '28460', '28936', '28915',
#        '28025', '28750', '28905', '28223', '75014', '28891', '28903',
#        '23009', '28023', '28660', '28006 ', '28924', '28911', '28032',
#        '28801', '10318', '28803', '29740', '28051', '28342', '28912',
#        '28064', '28299', '33206', '28791', '28028 ', '09006', '28917',
#        '19160', '28923', '28350', '29045', '23012', '28670', '28044',
#        '28909', '28450', '28906', '28231'], dtype=object)

# %% [markdown]
# # Acceso a archivos de la pagina de datos.gob.es
# Uno de los mayores catálogos de información pública descargable en España

# %% [markdown]
# <table align="left">
#  <tr><td width="80"><img src="./img/ejercicio.png" style="width:auto;height:auto"></td>
#      <td style="text-align:left">
#          <h3>Ejercicio datos.gob.es</h3>
#
# Descarga con pandas un dataset de la página https://datos.gob.es/es/catalogo acerca del empleo y guárdalo en un csv en la carpeta data.
#
#  </td></tr>
# </table>

# %%
# ubicar en la pagina web la direccion del enlace del archivo a descargar, para ello ubicarse sobre el posible enlace (boton) y dar clic derecho
url = "https://dadesobertes.gva.es/dataset/f706e6d9-fd44-4d45-988f-9b79010bc219/resource/9ae4e50e-09b0-401d-91e9-640905275749/download/datos-erte-solicitados-por-covid-19-2020-11-30.csv"
datos_empleo = pd.read_csv(url, sep=";")
datos_empleo.head()
# Out:
#   AUTORIDAD_LABORAL       SECTOR  NUM_EXPEDIENTES  NUM_TRABAJADORES_AFECTADOS  \
# 0              D.G.  AGRICULTURA                3                          64
# 1              D.G.  CONSTRUCIÓN               32                        1431
# 2              D.G.    INDUSTRIA              223                       56791
# 3              D.G.    SERVICIOS              664                       38105
# 4       DT VALENCIA  AGRICULTURA               68                         264
#
#    HOMBRES  MUJERES  PERS_GENERO_SIN_DETERMINAR
# 0       50       14                           0
# 1     1189      242                           0
# 2    42703    10146                        3942
# 3    18003    18170                        1932
# 4      200       64                           0

# %%
url = "https://datos.madrid.es/egob/catalogo/212086-0-oficinas-empleo.csv"
datos_empleo = pd.read_csv(url, sep=";", encoding='latin-1')
datos_empleo.head()
# Out:
#         PK                                NOMBRE  \
# 0  5949409   Agencia de Proximidad de Arganzuela
# 1  5666151      Agencia de Proximidad de Barajas
# 2  4514901  Agencia de Proximidad de Carabanchel
# 3  5520471       Agencia de Proximidad de Latina
# 4  5520488  Agencia de Proximidad de MercaMadrid
#
#                            DESCRIPCION-ENTIDAD  \
# 0  Agencia de Colocación Autorizada 1300000002
# 1  Agencia de Colocación Autorizada 1300000002
# 2  Agencia de Colocación Autorizada 1300000002
# 3  Agencia de Colocación Autorizada 1300000002
# 4  Agencia de Colocación Autorizada 1300000002
#
#                                              HORARIO  \
# 0             De lunes a viernes de 8:30 a 14 horas.
# 1             De lunes a viernes de 8:30 a 14 horas.
# 2             De lunes a viernes de 8:30 a 14 horas.
# 3             De lunes a viernes de 8:30 a 14 horas.
# 4  De atención a Empresas: de lunes a viernes de ...
#
#                                         EQUIPAMIENTO  \
# 0  Para las personas desempleadas:   Orientación ...
# 1  Para las personas desempleadas:   Orientación ...
# 2  Para las personas desempleadas:   Orientación ...
# 3  Para las personas desempleadas:   Orientación ...
# 4  Para las personas desempleadas:  Bolsa de Empl...
#
#                                           TRANSPORTE  DESCRIPCION  \
# 0  Metro: Puerta de Toledo  Cercanias: Pirámides ...          NaN
# 1         Metro: Alameda de Osuna Bus: 114, 115, 151          NaN
# 2       Metro: Carabanchel Alto Bus: 34, 35, 47, 139          NaN
# 3            METRO/RENFE: Laguna BUS: 25,31,55 y 119          NaN
# 4  Autobuses: T-32 desde la Paza de Legazpi (24 h...          NaN
#
#   ACCESIBILIDAD                                        CONTENT-URL  \
# 0           1,6  http://www.madrid.es/sites/v/index.jsp?vgnextc...
# 1           1,6  http://www.madrid.es/sites/v/index.jsp?vgnextc...
# 2           1,6  http://www.madrid.es/sites/v/index.jsp?vgnextc...
# 3           1,6  http://www.madrid.es/sites/v/index.jsp?vgnextc...
# 4             1  http://www.madrid.es/sites/v/index.jsp?vgnextc...
#
#                                           NOMBRE-VIA  ... COD-DISTRITO  \
# 0                                           PONTONES  ...          2.0
# 1                                          CANTABRIA  ...         21.0
# 2                                   CARABANCHEL ALTO  ...         11.0
# 3                                           ALHAMBRA  ...         10.0
# 4  Zona Comercial Local 1E/1F Mercamadrid. Salida...  ...          NaN
#
#             DISTRITO  COORDENADA-X  COORDENADA-Y    LATITUD  LONGITUD  \
# 0         ARGANZUELA        439268       4472945  40.404908 -3.715722
# 1            BARAJAS        450175       4478385  40.454636 -3.587632
# 2        CARABANCHEL        436104       4469258  40.371456 -3.752637
# 3             LATINA        436899       4472004  40.396255 -3.743547
# 4  VILLA DE VALLECAS        443827       4467859  40.359398 -3.661553
#
#       TELEFONO FAX                      EMAIL  \
# 0  913 643 460 NaN   aparganzuelaae@madrid.es
# 1  917 412 190 NaN      apbarajasae@madrid.es
# 2  915 133 085 NaN  apcarabanchelae@madrid.es
# 3  915 088 758 NaN       aplatinaae@madrid.es
# 4  915 880 332 NaN    aemercamadrid@madrid.es
#
#                                              TIPO
# 0  /contenido/entidadesYorganismos/OficinasEmpleo
# 1  /contenido/entidadesYorganismos/OficinasEmpleo
# 2  /contenido/entidadesYorganismos/OficinasEmpleo
# 3  /contenido/entidadesYorganismos/OficinasEmpleo
# 4  /contenido/entidadesYorganismos/OficinasEmpleo
#
# [5 rows x 32 columns]

# %%
url = "https://dadesobertes.gva.es/dataset/e9b02404-1755-4965-8f5b-917b43dc0368/resource/8a61dfcf-fb24-46e7-9b62-30ad193ec77c/download/contratos_por_municipio-sector-grupo_ocupacion-genero-edad-2018.csv"
datos_empleo = pd.read_csv(url, sep=";")

# %%
datos_empleo.to_csv("data/datos_empleo.csv")

# %% [markdown]
# # OpenStreetMap

# %%
# Amenities
# https://wiki.openstreetmap.org/wiki/Key:amenity
overpass_url = "http://overpass-api.de/api/interpreter"

overpass_query = """
[out:json];
node["amenity"="cafe"]
  (40.2702, -3.4102 ,40.2802, -3.4104); 
out;
"""

response = requests.get(overpass_url, 
                        params={'data': overpass_query})
print(response)
data = response.json()
# Out:
# <Response [200]>

# %%
data
# Out:
# {'version': 0.6,
#  'generator': 'Overpass API 0.7.62.8 e802775f',
#  'osm3s': {'timestamp_osm_base': '2025-10-08T14:14:51Z',
#   'copyright': 'The data included in this document is from www.openstreetmap.org. The data is made available under ODbL.'},
#  'elements': [{'type': 'node',
#    'id': 422157543,
#    'lat': 40.2770334,
#    'lon': -76.8241383,
#    'tags': {'addr:city': 'Union Square',
#     'addr:housenumber': '3901',
#     'addr:postcode': '17109',
#     'addr:state': 'PA',
#     'addr:street': 'Union Deposit Road',
#     'amenity': 'cafe',
#     'branch': 'Union Deposit Road',
#     'brand': 'Starbucks',
#     'brand:wikidata': 'Q37158',
#     'cuisine': 'coffee_shop',
#     'name': 'Starbucks',
#     'official_name': 'Starbucks Coffee',
#     'phone': '+1 717-564-3291',
#     'ref': '7350',
#     'takeaway': 'yes',
#     'website': 'https://www.starbucks.com/store-locator/store/7350/union-deposit-road-3901-union-deposit-road-harrisburg-pa-171095922-us'}},
#   {'type': 'node',
#    'id': 911490084,
#    'lat': 40.2774342,
#    'lon': 69.6300307,
#    'tags': {'amenity': 'cafe', 'name': 'Дустмухаммад'}},
#   {'type': 'node',
#    'id': 1235854116,
#    'lat': 40.273188,
#    'lon': -7.4964387,
#    'tags': {'amenity': 'cafe'}},
#   {'type': 'node',
#    'id': 1286907639,
#    'lat': 40.2795473,
#    'lon': 65.1374874,
#    'tags': {'amenity': 'cafe'}},
#   {'type': 'node',
#    'id': 1377477523,
#    'lat': 40.2706393,
#    'lon': 22.5083508,
#    'tags': {'addr:city': 'Κατερίνη',
#     'addr:housenumber': '10-12',
#     'addr:postcode': '601 32',
#     'addr:street': 'Γεωργάκη Ολυμπίου',
#     'amenity': 'cafe',
#     'name': 'Kartell',
#     'operator': 'BAG Τουριστικές Εκμεταλλεύσεις Χώρων Αναψυχής ΕΠE',
#     'outdoor_seating': 'yes'}},
#   {'type': 'node',
#    'id': 1377477542,
#    'lat': 40.2706607,
#    'lon': 22.5085488,
#    'tags': {'addr:city': 'Κατερίνη',
#     'addr:housenumber': '1',
#     'addr:postcode': '601 32',
#     'addr:street': 'Γεωργάκη Ολυμπίου',
#     'amenity': 'cafe',
#     'name': 'Boga',
#     'operator': 'Γ Μερίκος και Σία ΟΕ',
#     'outdoor_seating': 'yes'}},
#   {'type': 'node',
#    'id': 1377477561,
#    'lat': 40.270581,
#    'lon': 22.5088444,
#    'tags': {'addr:city': 'Κατερίνη',
#     'addr:housenumber': '4',
#     'addr:postcode': '601 32',
#     'addr:street': 'Σολωμού',
#     'amenity': 'cafe',
#     'name': "Oliver's Pub",
#     'operator': 'Ιορδανίδης Χρήστος και Σία ΟΕ',
#     'outdoor_seating': 'yes'}},
#   {'type': 'node',
#    'id': 1573449365,
#    'lat': 40.2757399,
#    'lon': -76.8951718,
#    'tags': {'addr:city': 'Harrisburg',
#     'addr:housenumber': '1836',
#     'addr:postcode': '17102',
#     'addr:state': 'PA',
#     'addr:street': 'Green Street',
#     'amenity': 'cafe',
#     'check_date': '2023-10-30',
#     'contact:instagram': 'https://www.instagram.com/littleampscoffee',
#     'cuisine': 'coffee_shop',
#     'internet_access': 'wlan',
#     'name': 'Little Amps',
#     'opening_hours': 'Mo-Fr 07:00-14:00; Sa-Su 08:00-14:00',
#     'phone': '+1 717-695-4882',
#     'website': 'https://littleampscoffee.com'}},
#   {'type': 'node',
#    'id': 1731434694,
#    'lat': 40.2731956,
#    'lon': 22.5073581,
#    'tags': {'addr:city': 'Κατερίνη',
#     'addr:housenumber': '14',
#     'addr:postcode': '601 33',
#     'addr:street': 'Δημητρίου Δημάδη',
#     'amenity': 'cafe',
#     'name': 'Bistro 49'}},
#   {'type': 'node',
#    'id': 1731445028,
#    'lat': 40.2706471,
#    'lon': 22.5074875,
#    'tags': {'addr:city': 'Κατερίνη',
#     'addr:housenumber': '5',
#     'addr:postcode': '601 32',
#     'addr:street': 'Αγίας Λαύρας',
#     'amenity': 'cafe',
#     'name': 'Ludo'}},
#   {'type': 'node',
#    'id': 1731448607,
#    'lat': 40.27107,
#    'lon': 22.5094911,
#    'tags': {'addr:city': 'Κατερίνη',
#     'addr:housenumber': '2',
#     'addr:postcode': '601 34',
#     'addr:street': 'Παναγή Τσαλδάρη',
#     'amenity': 'cafe',
#     'brand': 'Mikel',
#     'brand:wikidata': 'Q16952021',
#     'brand:wikipedia': 'el:Mikel',
#     'cuisine': 'coffee_shop',
#     'name': 'Mikel',
#     'takeaway': 'yes'}},
#   {'type': 'node',
#    'id': 1732839843,
#    'lat': 40.271436,
#    'lon': 22.5015902,
#    'tags': {'addr:city': 'Κατερίνη',
#     'addr:housenumber': '3',
#     'addr:postcode': '601 31',
#     'addr:street': 'Μητροπόλεως',
#     'amenity': 'cafe',
#     'name': 'Barrio Gastrobar',
#     'operator': 'Τσιούχα Αικατερίνη-Ραφαέλα',
#     'outdoor_seating': 'yes'}},
#   {'type': 'node',
#    'id': 1732839854,
#    'lat': 40.2713278,
#    'lon': 22.5015593,
#    'tags': {'addr:city': 'Κατερίνη',
#     'addr:housenumber': '5',
#     'addr:postcode': '601 31',
#     'addr:street': 'Μητροπόλεως',
#     'amenity': 'cafe',
#     'name': 'Park Cafe',
#     'operator': 'Δημάκη Άννα'}},
#   {'type': 'node',
#    'id': 1732856635,
#    'lat': 40.2721393,
#    'lon': 22.505212,
#    'tags': {'addr:city': 'Κατερίνη',
#     'addr:housenumber': '3',
#     'addr:postcode': '601 33',
#     'addr:street': 'Κρέσνας',
#     'amenity': 'cafe',
#     'name': 'Art Caffe'}},
#   {'type': 'node',
#    'id': 1747338120,
#    'lat': 40.2712439,
#    'lon': 22.5084498,
#    'tags': {'addr:city': 'Κατερίνη',
#     'addr:housenumber': '11',
#     'addr:postcode': '601 33',
#     'addr:street': 'Πλατεία Ελευθερίας',
#     'amenity': 'cafe',
#     'name': 'Dolce'}},
#   {'type': 'node',
#    'id': 1747338293,
#    'lat': 40.2714585,
#    'lon': 22.5074243,
#    'tags': {'amenity': 'cafe'}},
#   {'type': 'node',
#    'id': 1747338830,
#    'lat': 40.2715401,
#    'lon': 22.5057948,
#    'tags': {'addr:city': 'Κατερίνη',
#     'addr:housenumber': '2',
#     'addr:postcode': '601 33',
#     'addr:street': 'Τσιμισκή',
#     'amenity': 'cafe',
#     'name': 'Boutique 26'}},
#   {'type': 'node',
#    'id': 1764134996,
#    'lat': 40.2735615,
#    'lon': 22.5151671,
#    'tags': {'addr:city': 'Κατερίνη',
#     'addr:housenumber': '54',
#     'addr:postcode': '601 34',
#     'addr:street': 'Περγάμου',
#     'amenity': 'cafe',
#     'name': 'Ζαχαροπλαστείο-Καφέ Μάρκος'}},
#   {'type': 'node',
#    'id': 1855367761,
#    'lat': 40.2771946,
#    'lon': -3.792095,
#    'tags': {'addr:housenumber': '19',
#     'addr:postcode': '28944',
#     'addr:street': 'Calle de Las Eras',
#     'amenity': 'cafe',
#     'cuisine': 'coffee_shop',
#     'name': 'Éboli',
#     'website': 'http://www.pasteleriaeboli.es/'}},
#   {'type': 'node',
#    'id': 1855773850,
#    'lat': 40.2755992,
#    'lon': -3.7905512,
#    'tags': {'addr:housenumber': '41',
#     'addr:postcode': '28944',
#     'addr:street': 'Calle de Fuentevaqueros',
#     'amenity': 'cafe',
#     'name': 'Cafetería Oliva III'}},
#   {'type': 'node',
#    'id': 1864364952,
#    'lat': 40.2792621,
#    'lon': -3.7942241,
#    'tags': {'amenity': 'cafe', 'name': "Cafetería D'Madrid"}},
#   {'type': 'node',
#    'id': 1866310985,
#    'lat': 40.2788553,
#    'lon': 22.5040232,
#    'tags': {'addr:city': 'Κατερίνη',
#     'addr:housenumber': '11',
#     'addr:postcode': '601 33',
#     'addr:street': 'Σωκράτους',
#     'amenity': 'cafe',
#     'cuisine': 'ice_cream',
#     'name': 'Ζαχαροπλαστείο Μπούσια',
#     'operator': 'Μπούσιας Σωτήριος'}},
#   {'type': 'node',
#    'id': 1868902735,
#    'lat': 40.278985,
#    'lon': -3.7999481,
#    'tags': {'amenity': 'cafe', 'name': 'Cafetería Convair'}},
#   {'type': 'node',
#    'id': 1870611613,
#    'lat': 40.2779068,
#    'lon': -3.7972131,
#    'tags': {'amenity': 'cafe',
#     'cuisine': 'churro',
#     'name': 'Churrería Don Churro'}},
#   {'type': 'node',
#    'id': 1870611616,
#    'lat': 40.2780858,
#    'lon': -3.796854,
#    'tags': {'amenity': 'cafe', 'name': 'El Rincón de Laura'}},
#   {'type': 'node',
#    'id': 1870611619,
#    'lat': 40.277852,
#    'lon': -3.797323,
#    'tags': {'amenity': 'cafe', 'name': 'Hermanos Suero'}},
#   {'type': 'node',
#    'id': 1873347440,
#    'lat': 40.2762915,
#    'lon': -3.7979066,
#    'tags': {'amenity': 'cafe', 'name': 'Café Alhambra'}},
#   {'type': 'node',
#    'id': 1887981280,
#    'lat': 40.279904,
#    'lon': -3.7970503,
#    'tags': {'addr:city': 'Fuenlabrada',
#     'addr:country': 'ES',
#     'addr:housenumber': '10',
#     'addr:street': 'Calle de Extremadura',
#     'amenity': 'cafe',
#     'name': 'Alessandra'}},
#   {'type': 'node',
#    'id': 2012644501,
#    'lat': 40.2750049,
#    'lon': -74.8034144,
#    'tags': {'addr:street': 'Scotch Road',
#     'amenity': 'cafe',
#     'name': 'Bagel Shop'}},
#   {'type': 'node',
#    'id': 2025480819,
#    'lat': 40.2707562,
#    'lon': -7.8956124,
#    'tags': {'amenity': 'cafe', 'name': 'Café da Glória'}},
#   {'type': 'node',
#    'id': 2295502483,
#    'lat': 40.2734528,
#    'lon': -8.6827809,
#    'tags': {'amenity': 'cafe'}},
#   {'type': 'node',
#    'id': 2295502484,
#    'lat': 40.2738785,
#    'lon': -8.6837894,
#    'tags': {'amenity': 'cafe'}},
#   {'type': 'node',
#    'id': 2447353883,
#    'lat': 40.2721484,
#    'lon': -5.8613621,
#    'tags': {'amenity': 'cafe', 'name': 'Bar Nacar'}},
#   {'type': 'node',
#    'id': 2911078228,
#    'lat': 40.2774365,
#    'lon': 18.0462217,
#    'tags': {'amenity': 'cafe'}},
#   {'type': 'node',
#    'id': 3177151661,
#    'lat': 40.2719679,
#    'lon': 18.2605032,
#    'tags': {'addr:city': 'Castri di Lecce',
#     'addr:postcode': '73020',
#     'addr:street': 'Via Indipendenza',
#     'amenity': 'cafe',
#     'name': 'Bar Torsello',
#     'wheelchair': 'limited',
#     'wheelchair:description': 'Luogo accessibile. Stanze interne accessibili ma senza servizi igienici per disabili'}},
#   {'type': 'node',
#    'id': 3183720470,
#    'lat': 40.273448,
#    'lon': 18.265301,
#    'tags': {'addr:city': 'Castri di Lecce',
#     'addr:postcode': '73020',
#     'addr:street': 'Piazza Municipio',
#     'amenity': 'cafe',
#     'name': 'Bar Centrale',
#     'wheelchair': 'no',
#     'wheelchair:description': 'Luogo inaccessibile'}},
#   {'type': 'node',
#    'id': 3184934961,
#    'lat': 40.274014,
#    'lon': 18.256733,
#    'tags': {'addr:city': 'Castri di Lecce',
#     'amenity': 'cafe',
#     'name': 'Bar Tonio - Distributore IP',
#     'wheelchair': 'yes',
#     'wheelchair:description': 'Distributore IP con Bar accessibile'}},
#   {'type': 'node',
#    'id': 3184954361,
#    'lat': 40.274621,
#    'lon': 18.261718,
#    'tags': {'addr:city': 'Castri di Lecce',
#     'addr:postcode': '73020',
#     'addr:street': 'Piazza dei Caduti',
#     'amenity': 'cafe',
#     'name': 'Snack Cafe',
#     'wheelchair': 'yes',
#     'wheelchair:description': 'Bar accessibile'}},
#   {'type': 'node',
#    'id': 3190546947,
#    'lat': 40.271191,
#    'lon': -76.8433895,
#    'tags': {'amenity': 'cafe', 'name': 'Souled Out Cafe'}},
#   {'type': 'node',
#    'id': 3498386418,
#    'lat': 40.2709812,
#    'lon': 69.6921406,
#    'tags': {'addr:street': 'Қасри Арбоб',
#     'amenity': 'cafe',
#     'name': 'Чойхонаи миллӣ'}},
#   {'type': 'node',
#    'id': 3499694052,
#    'lat': 40.2775538,
#    'lon': -7.4987514,
#    'tags': {'amenity': 'cafe'}},
#   {'type': 'node',
#    'id': 3499694054,
#    'lat': 40.276979,
#    'lon': -7.4988193,
#    'tags': {'amenity': 'cafe'}},
#   {'type': 'node',
#    'id': 3499694057,
#    'lat': 40.2757313,
#    'lon': -7.4994707,
#    'tags': {'amenity': 'cafe'}},
#   {'type': 'node',
#    'id': 3499694060,
#    'lat': 40.2764365,
#    'lon': -7.4997005,
#    'tags': {'amenity': 'cafe', 'name': 'Primor'}},
#   {'type': 'node',
#    'id': 3573990064,
#    'lat': 40.2795527,
#    'lon': 69.62773,
#    'tags': {'amenity': 'cafe', 'name': 'Орзуи Ширин'}},
#   {'type': 'node',
#    'id': 3735999726,
#    'lat': 40.2738532,
#    'lon': 18.2587275,
#    'tags': {'addr:street': 'Via Giacomo Brodolini',
#     'amenity': 'cafe',
#     'name': 'Salento Caffè',
#     'wheelchair': 'yes'}},
#   {'type': 'node',
#    'id': 3753298267,
#    'lat': 40.2747961,
#    'lon': -81.8691777,
#    'tags': {'addr:city': 'Coshocton',
#     'addr:housenumber': '131',
#     'addr:postcode': '43812-1130',
#     'addr:state': 'OH',
#     'addr:street': 'Chestnut Street',
#     'amenity': 'cafe',
#     'brand': 'Tim Hortons',
#     'brand:wikidata': 'Q175106',
#     'cuisine': 'coffee_shop',
#     'delivery': 'yes',
#     'drive_through': 'yes',
#     'indoor_seating': 'no',
#     'internet_access': 'wlan',
#     'name': 'Tim Hortons',
#     'opening_hours': 'Mo-We 06:00-20:00; Fr-Sa 06:00-20:00; Su 06:00-16:00',
#     'phone': '+1 740-295-0529',
#     'takeaway': 'yes'}},
#   {'type': 'node',
#    'id': 4013613462,
#    'lat': 40.2734921,
#    'lon': -111.6784318,
#    'tags': {'addr:city': 'Orem',
#     'addr:housenumber': '725',
#     'addr:postcode': '84097',
#     'addr:state': 'UT',
#     'addr:street': 'East University Parkway',
#     'amenity': 'cafe',
#     'branch': 'Orem - University Mall',
#     'brand': 'Starbucks',
#     'brand:wikidata': 'Q37158',
#     'cuisine': 'coffee_shop',
#     'name': 'Starbucks',
#     'official_name': 'Starbucks Coffee',
#     'phone': '+1 801-225-7104',
#     'ref': '1012284',
#     'takeaway': 'yes',
#     'website': 'https://www.starbucks.com/store-locator/store/1012284/orem-university-mall-725-east-university-parkway-orem-ut-840977771-us'}},
#   {'type': 'node',
#    'id': 4104682075,
#    'lat': 40.2718613,
#    'lon': 22.5039306,
#    'tags': {'addr:city': 'Κατερίνη',
#     'addr:housenumber': '1',
#     'addr:postcode': '601 33',
#     'addr:street': 'Σαρανταπόρου',
#     'amenity': 'cafe',
#     'name': 'Πόδας'}},
#   {'type': 'node',
#    'id': 4120107990,
#    'lat': 40.2726756,
#    'lon': 44.6335877,
#    'tags': {'amenity': 'cafe', 'name': 'Ureni'}},
#   {'type': 'node',
#    'id': 4235737592,
#    'lat': 40.2724549,
#    'lon': -7.498471,
#    'tags': {'addr:city': 'Covilhã',
#     'addr:housenumber': '1',
#     'addr:postcode': '6200-505',
#     'addr:street': 'Rua Centro de Artes',
#     'addr:unit': 'Rés de Chão Esquerdo',
#     'amenity': 'cafe',
#     'cuisine': 'tea;breakfast;coffee_shop',
#     'name': 'Pérola Doce',
#     'opening_hours': 'Mo-Fr 07:30-21:00; Sa-Su 08:00-20:00',
#     'outdoor_seating': 'no',
#     'phone': '+351275332406'}},
#   {'type': 'node',
#    'id': 4285946496,
#    'lat': 40.2737056,
#    'lon': 18.4285268,
#    'tags': {'addr:postcode': '73026',
#     'addr:street': 'Via Giacomo Matteotti',
#     'amenity': 'cafe',
#     'cuisine': 'ice_cream',
#     'name': 'Dentoni',
#     'phone': '+39 0832 841485',
#     'shop': 'pastry'}},
#   {'type': 'node',
#    'id': 4396721462,
#    'lat': 40.273404,
#    'lon': -8.5207666,
#    'tags': {'amenity': 'cafe', 'name': 'Flor de Ançã'}},
#   {'type': 'node',
#    'id': 4402590493,
#    'lat': 40.2714018,
#    'lon': 22.5072329,
#    'tags': {'amenity': 'cafe'}},
#   {'type': 'node',
#    'id': 4463502198,
#    'lat': 40.2764041,
#    'lon': 22.5146083,
#    'tags': {'addr:city': 'Κατερίνη',
#     'addr:housenumber': '82',
#     'addr:postcode': '601 34',
#     'addr:street': 'Θεσσαλονίκης',
#     'amenity': 'cafe',
#     'cuisine': 'sausage;hot_dog;sandwich;coffee_shop;greek',
#     'name': 'Μπουγάτσα ΛΙΧΟΥΔΙΕΣ',
#     'name:el': 'Μπουγάτσα ΛΙΧΟΥΔΙΕΣ',
#     'name:en': 'Bougatsa LICHOUDIES',
#     'opening_hours': 'Mo-Sa 06:00-16:00',
#     'operator': 'Κατερίνα',
#     'phone': '+302351079996'}},
#   {'type': 'node',
#    'id': 4503675491,
#    'lat': 40.2720129,
#    'lon': 69.6046094,
#    'tags': {'amenity': 'cafe',
#     'name': 'Шашлычная "Катикча"',
#     'name:ru': 'Шашлычная "Катикча"'}},
#   {'type': 'node',
#    'id': 4643884032,
#    'lat': 40.2738029,
#    'lon': -5.8583816,
#    'tags': {'amenity': 'cafe'}},
#   {'type': 'node',
#    'id': 4648488294,
#    'lat': 40.2704302,
#    'lon': 44.6277393,
#    'tags': {'amenity': 'cafe',
#     'name': 'Աբովյան Բուրգեր',
#     'name:en': '"Abovyan Burger"',
#     'name:ru': '"Abovyan Burger"',
#     'phone': '+374 98 09 50 60;374 222 6 50 60'}},
#   {'type': 'node',
#    'id': 4690473690,
#    'lat': 40.2709395,
#    'lon': 22.5083914,
#    'tags': {'amenity': 'cafe', 'name': 'Florian', 'operator': 'Ντούφα Ελένη'}},
#   {'type': 'node',
#    'id': 4711840959,
#    'lat': 40.2718562,
#    'lon': 22.508945,
#    'tags': {'addr:city': 'Κατερίνη',
#     'addr:housenumber': '2',
#     'addr:postcode': '601 34',
#     'addr:street': 'Εθνικής Αντιστάσεως',
#     'amenity': 'cafe',
#     'name': 'Cafe Καφέ',
#     'operator': 'Κασιτερόπουλος Γ. Κασιτεροπούλου Δ. ΟΕ'}},
#   {'type': 'node',
#    'id': 4711840961,
#    'lat': 40.2716152,
#    'lon': 22.5091064,
#    'tags': {'amenity': 'cafe',
#     'brand': 'Coffee Island',
#     'brand:wikidata': 'Q60867333',
#     'brand:wikipedia': 'en:Coffee Island',
#     'cuisine': 'coffee_shop',
#     'name': 'Coffee Island',
#     'takeaway': 'yes'}},
#   {'type': 'node',
#    'id': 4711935670,
#    'lat': 40.2713142,
#    'lon': 22.5084514,
#    'tags': {'addr:city': 'Κατερίνη',
#     'addr:housenumber': '9',
#     'addr:postcode': '601 33',
#     'addr:street': 'Πλατεία Ελευθερίας',
#     'amenity': 'cafe',
#     'name': 'Αρχοντικό'}},
#   {'type': 'node',
#    'id': 4711935673,
#    'lat': 40.2715765,
#    'lon': 22.5084551,
#    'tags': {'addr:city': 'Κατερίνη',
#     'addr:housenumber': '1',
#     'addr:postcode': '601 33',
#     'addr:street': '16ης Οκτωβρίου',
#     'amenity': 'cafe',
#     'name': 'Better Cafe.bar'}},
#   {'type': 'node',
#    'id': 4712033657,
#    'lat': 40.2709233,
#    'lon': 22.5091822,
#    'tags': {'addr:city': 'Κατερίνη',
#     'addr:housenumber': '1',
#     'addr:postcode': '601 32',
#     'addr:street': 'Πλατεία Ελευθερίας',
#     'amenity': 'cafe',
#     'name': 'Piazza'}},
#   {'type': 'node',
#    'id': 4719810291,
#    'lat': 40.2726479,
#    'lon': 44.6343859,
#    'tags': {'addr:street': 'Հատիս փողոց',
#     'amenity': 'cafe',
#     'name': 'Տարոն',
#     'name:hy': 'Տարոն'}},
#   {'type': 'node',
#    'id': 4737875344,
#    'lat': 40.2718525,
#    'lon': 22.4986403,
#    'tags': {'addr:city': 'Κατερίνη',
#     'addr:housenumber': '1',
#     'addr:postcode': '601 33',
#     'addr:street': 'Φιλελλήνων',
#     'amenity': 'cafe',
#     'name': 'Bruno'}},
#   {'type': 'node',
#    'id': 4737875345,
#    'lat': 40.2743704,
#    'lon': 22.5136211,
#    'tags': {'addr:city': 'Κατερίνη',
#     'addr:housenumber': '58',
#     'addr:postcode': '601 34',
#     'addr:street': 'Θεσσαλονίκης',
#     'amenity': 'cafe',
#     'name': 'Bruno',
#     'operator': 'Χείρας Αλέξανδρος'}},
#   {'type': 'node',
#    'id': 4773808698,
#    'lat': 40.2710094,
#    'lon': 22.5096468,
#    'tags': {'addr:city': 'Κατερίνη',
#     'addr:housenumber': '3',
#     'addr:postcode': '601 34',
#     'addr:street': 'Ειρήνης',
#     'amenity': 'cafe',
#     'name': 'Μπουγάτσα Καφέ Μιχάλης',
#     'operator': 'Μπουμπουλέντρας Μιχαήλ'}},
#   {'type': 'node',
#    'id': 4780012360,
#    'lat': 40.274065,
#    'lon': 22.5142513,
#    'tags': {'addr:city': 'Κατερίνη',
#     'addr:housenumber': '10',
#     'addr:postcode': '601 34',
#     'addr:street': 'Νικολάου Δίκα',
#     'amenity': 'cafe',
#     'delivery': 'yes',
#     'name': 'Illy Street Cafe',
#     'opening_hours': 'Mo-Su 06:00-23:30',
#     'outdoor_seating': 'yes',
#     'payment:cash': 'yes',
#     'payment:contactless': 'yes',
#     'phone': '2351028777',
#     'takeaway': 'yes',
#     'toilets': 'yes',
#     'website': 'https://www.street-cafe.gr/'}},
#   {'type': 'node',
#    'id': 4794890688,
#    'lat': 40.2757471,
#    'lon': 69.6411885,
#    'tags': {'addr:city': 'Худжанд',
#     'addr:postcode': '735700',
#     'addr:street': 'кучаи Гагарина',
#     'amenity': 'cafe',
#     'name': 'Фарзона',
#     'name:uz': 'Farzoda oilaviy oshxonasi',
#     'old_name': 'МУБАРО'}},
#   {'type': 'node',
#    'id': 4798382229,
#    'lat': 40.2717716,
#    'lon': 22.5058754,
#    'tags': {'addr:city': 'Κατερίνη',
#     'addr:housenumber': '5',
#     'addr:postcode': '601 33',
#     'addr:street': 'Τσιμισκή',
#     'amenity': 'cafe',
#     'name': 'Louis Lauren Chocolates',
#     'operator': 'Πέλλας Νικόλαος'}},
#   {'type': 'node',
#    'id': 4807728125,
#    'lat': 40.2793716,
#    'lon': 69.615344,
#    'tags': {'amenity': 'cafe', 'name': 'Аюбҷон', 'name:ru': 'Аюбҷон'}},
#   {'type': 'node',
#    'id': 4818950434,
#    'lat': 40.2711956,
#    'lon': 22.5015299,
#    'tags': {'addr:city': 'Κατερίνη',
#     'addr:housenumber': '9',
#     'addr:postcode': '601 31',
#     'addr:street': 'Μητροπόλεως',
#     'amenity': 'cafe',
#     'name': 'Mystique',
#     'operator': 'Γιαννούλης Γεώργιος'}},
#   {'type': 'node',
#    'id': 4818950435,
#    'lat': 40.271601,
#    'lon': 22.5016403,
#    'tags': {'addr:city': 'Κατερίνη',
#     'addr:housenumber': '1',
#     'addr:postcode': '601 31',
#     'addr:street': 'Μητροπόλεως',
#     'amenity': 'cafe',
#     'brand': 'Mikel',
#     'brand:wikidata': 'Q16952021',
#     'cuisine': 'coffee_shop',
#     'disused:amenity': 'cafe',
#     'name': 'Mikel',
#     'takeaway': 'yes'}},
#   {'type': 'node',
#    'id': 4861932021,
#    'lat': 40.2753305,
#    'lon': 69.6374245,
#    'tags': {'amenity': 'cafe',
#     'description': 'Cafe with pastry and good coffee'}},
#   {'type': 'node',
#    'id': 4890072547,
#    'lat': 40.2735125,
#    'lon': 22.5123989,
#    'tags': {'addr:city': 'Κατερίνη',
#     'addr:housenumber': '13',
#     'addr:postcode': '601 34',
#     'addr:street': 'Δημητρίου Βακάλη',
#     'amenity': 'cafe',
#     'name': 'Καφέ Κομπολόι',
#     'operator': 'Μέριμνα Παιδιού Κατερίνης'}},
#   {'type': 'node',
#    'id': 4939666307,
#    'lat': 40.2790954,
#    'lon': 22.5038466,
#    'tags': {'addr:city': 'Κατερίνη',
#     'addr:housenumber': '13',
#     'addr:postcode': '601 33',
#     'addr:street': 'Σωκράτους',
#     'amenity': 'cafe',
#     'name': 'Τσαχούρ'}},
#   {'type': 'node',
#    'id': 5003885849,
#    'lat': 40.2786147,
#    'lon': -86.394378,
#    'tags': {'amenity': 'cafe'}},
#   {'type': 'node',
#    'id': 5105947936,
#    'lat': 40.2787173,
#    'lon': 19.5036692,
#    'tags': {'amenity': 'cafe'}},
#   {'type': 'node',
#    'id': 5158965007,
#    'lat': 40.2713581,
#    'lon': 22.5066931,
#    'tags': {'addr:city': 'Κατερίνη',
#     'addr:housenumber': '26',
#     'addr:postcode': '601 33',
#     'addr:street': 'Μεγάλου Αλεξάνδρου',
#     'amenity': 'cafe',
#     'name': 'Freud',
#     'operator': 'Ι. Κωνσταντινίδης και Σία ΟΕ',
#     'outdoor_seating': 'yes'}},
#   {'type': 'node',
#    'id': 5218907716,
#    'lat': 40.271376,
#    'lon': 22.5056621,
#    'tags': {'addr:city': 'Κατερίνη',
#     'addr:housenumber': '39',
#     'addr:postcode': '601 32',
#     'addr:street': 'Μεγάλου Αλεξάνδρου',
#     'amenity': 'cafe',
#     'name': 'Transistor',
#     'operator': 'Γκιάτας Νικόλαος'}},
#   {'type': 'node',
#    'id': 5244558941,
#    'lat': 40.2702429,
#    'lon': 22.5085043,
#    'tags': {'addr:city': 'Κατερίνη',
#     'addr:housenumber': '18',
#     'addr:postcode': '601 32',
#     'addr:street': 'Αγίας Λαύρας',
#     'amenity': 'cafe',
#     'name': 'Μπουγάτσα Ζέλιος',
#     'operator': 'Μπουκλής Θεμιστοκλής'}},
#   {'type': 'node',
#    'id': 5255483021,
#    'lat': 40.270809,
#    'lon': 22.5080431,
#    'tags': {'addr:city': 'Κατερίνη',
#     'addr:housenumber': '3',
#     'addr:postcode': '601 32',
#     'addr:street': 'Α΄ Πάροδος Γεωργάκη Ολυμπίου',
#     'amenity': 'cafe',
#     'name': 'Το Αδιέξοδο',
#     'operator': 'Βαϊτσοπούλου Ελένη'}},
#   {'type': 'node',
#    'id': 5255483024,
#    'lat': 40.2707179,
#    'lon': 22.5083622,
#    'tags': {'addr:city': 'Κατερίνη',
#     'addr:housenumber': '10',
#     'addr:postcode': '601 32',
#     'addr:street': 'Γεωργάκη Ολυμπίου',
#     'amenity': 'cafe',
#     'name': 'Celso',
#     'operator': 'Ντούλας Νικόλαος'}},
#   {'type': 'node',
#    'id': 5272843624,
#    'lat': 40.2702571,
#    'lon': 22.5081492,
#    'tags': {'addr:city': 'Κατερίνη',
#     'addr:housenumber': '14',
#     'addr:postcode': '601 32',
#     'addr:street': 'Αγίας Λαύρας',
#     'amenity': 'cafe',
#     'name': 'Geppetto Bistro',
#     'outdoor_seating': 'yes'}},
#   {'type': 'node',
#    'id': 5272843626,
#    'lat': 40.2708038,
#    'lon': 22.5085421,
#    'tags': {'addr:city': 'Κατερίνη',
#     'addr:housenumber': '1',
#     'addr:postcode': '601 32',
#     'addr:street': 'Γεωργάκη Ολυμπίου',
#     'amenity': 'cafe'}},
#   {'type': 'node',
#    'id': 5368746442,
#    'lat': 40.2714219,
#    'lon': 22.5099449,
#    'tags': {'amenity': 'cafe', 'name': 'BAKA'}},
#   {'type': 'node',
#    'id': 5472423986,
#    'lat': 40.2710274,
#    'lon': 140.5693469,
#    'tags': {'amenity': 'cafe', 'name': 'コーヒーハウス 茶色の小びん'}},
#   {'type': 'node',
#    'id': 5472436527,
#    'lat': 40.2743029,
#    'lon': 140.5594577,
#    'tags': {'amenity': 'cafe', 'name': '加賀コーヒー店'}},
#   {'type': 'node',
#    'id': 5472436531,
#    'lat': 40.2708877,
#    'lon': 140.5700158,
#    'tags': {'amenity': 'cafe', 'name': 'ワラビカフェ'}},
#   {'type': 'node',
#    'id': 5537672722,
#    'lat': 40.2749846,
#    'lon': 44.6315673,
#    'tags': {'addr:city': 'Աբովյան',
#     'addr:country': 'AM',
#     'addr:housenumber': '1/10',
#     'addr:street': 'Ռուսաստանի փողոց',
#     'amenity': 'cafe',
#     'name': 'ՄԱԿՈւ',
#     'name:en': 'MAKU',
#     'phone': '091698866'}},
#   {'type': 'node',
#    'id': 5543026585,
#    'lat': 40.2722031,
#    'lon': 22.5127314,
#    'tags': {'addr:city': 'Κατερίνη',
#     'addr:housenumber': '31',
#     'addr:postcode': '601 34',
#     'addr:street': 'Δημητρίου Νίκα',
#     'amenity': 'cafe',
#     'name': 'Amanthis'}},
#   {'type': 'node',
#    'id': 5802415978,
#    'lat': 40.2787399,
#    'lon': 22.5042258,
#    'tags': {'addr:street': 'Σωκράτους',
#     'amenity': 'cafe',
#     'name': 'Mojo Cafe',
#     'source': 'Kaart Ground Survey 2018'}},
#   {'type': 'node',
#    'id': 5828638291,
#    'lat': 40.2732237,
#    'lon': 69.6391711,
#    'tags': {'amenity': 'cafe',
#     'cuisine': 'oriental;regional;breakfast;cake;tea;coffee_shop;local;donut',
#     'name': "Магазин сладостей ' Печелка",
#     'name:en': "Cafe 'Pechelka'",
#     'name:ru': "Кафе 'Печелка'"}},
#   {'type': 'node',
#    'id': 5898376610,
#    'lat': 40.278023,
#    'lon': -78.8464266,
#    'tags': {'amenity': 'cafe',
#     'brand': 'Starbucks',
#     'brand:wikidata': 'Q37158',
#     'contact:website': 'https://www.starbucks.com/store-locator/store/8091/johnstown-109-town-centre-drive-110-johnstown-pa-159042824-u',
#     'cuisine': 'coffee_shop',
#     'name': 'Starbucks',
#     'official_name': 'Starbucks Coffee',
#     'takeaway': 'yes'}},
#   {'type': 'node',
#    'id': 5927074286,
#    'lat': 40.2751124,
#    'lon': 63.2816475,
#    'tags': {'amenity': 'cafe', 'name': 'Minutka'}},
#   {'type': 'node',
#    'id': 5944091386,
#    'lat': 40.2723563,
#    'lon': 18.3369389,
#    'tags': {'addr:city': 'Melendugno',
#     'addr:postcode': '73026',
#     'addr:street': 'Via IV Novembre',
#     'amenity': 'cafe',
#     'name': 'Gelateria Bar Roma'}},
#   {'type': 'node',
#    'id': 5944102185,
#    'lat': 40.2711804,
#    'lon': 18.3351535,
#    'tags': {'amenity': 'cafe', 'name': 'Historic Café'}},
#   {'type': 'node',
#    'id': 5948743007,
#    'lat': 40.2725384,
#    'lon': -79.886975,
#    'tags': {'addr:city': 'Elizabeth',
#     'addr:housenumber': '111',
#     'addr:postcode': '15037',
#     'addr:street': 'South 2nd Avenue',
#     'amenity': 'cafe',
#     'name': "Top o' the Morning",
#     'shop': 'bakery',
#     'website': 'https://top-o-the-mornin-donut-and-coffee-shop.business.site/'}},
#   {'type': 'node',
#    'id': 5949091185,
#    'lat': 40.2752388,
#    'lon': 9.5975121,
#    'tags': {'amenity': 'cafe',
#     'name': 'Chiosco Monte Longu',
#     'opening_hours': 'Mo off'}},
#   {'type': 'node',
#    'id': 6382140710,
#    'lat': 40.2729679,
#    'lon': -7.72705,
#    'tags': {'amenity': 'cafe',
#     'cuisine': 'coffee_shop',
#     'name': 'Café Mira Rio',
#     'outdoor_seating': 'yes'}},
#   {'type': 'node',
#    'id': 6657114733,
#    'lat': 40.2727169,
#    'lon': 18.0484787,
#    'tags': {'amenity': 'cafe',
#     'contact:mobile': '+39 333 9419971',
#     'contact:phone': '+39 0832 1693423',
#     'name': 'Caffè 900'}},
#   {'type': 'node',
#    'id': 6899256636,
#    'lat': 40.2763777,
#    'lon': -4.3060659,
#    'tags': {'amenity': 'cafe',
#     'bar': 'yes',
#     'name': 'Bar la Pinta',
#     'outdoor_seating': 'yes'}},
#   {'type': 'node',
#    'id': 6899266885,
#    'lat': 40.2782588,
#    'lon': -4.3083733,
#    'tags': {'amenity': 'cafe', 'name': 'Peña Madridista Pradeña'}},
#   {'type': 'node',
#    'id': 7250455616,
#    'lat': 40.2707904,
#    'lon': 22.5082094,
#    'tags': {'addr:city': 'Κατερίνη',
#     'addr:housenumber': '1',
#     'addr:postcode': '601 32',
#     'addr:street': 'Α΄ Πάροδος Γεωργάκη Ολυμπίου',
#     'amenity': 'cafe',
#     'name': 'Μπάρμπα Σπύρος'}},
#   {'type': 'node',
#    'id': 7433146584,
#    'lat': 40.2783384,
#    'lon': -3.9167434,
#    'tags': {'addr:housenumber': '21',
#     'addr:postcode': '28939',
#     'addr:street': 'Calle de Marbella',
#     'amenity': 'cafe',
#     'name': 'Cafeteria Olimpia'}},
#   {'type': 'node',
#    'id': 7834155466,
#    'lat': 40.2768067,
#    'lon': -4.3056751,
#    'tags': {'amenity': 'cafe', 'name': 'El Dorado'}},
#   {'type': 'node',
#    'id': 7956061569,
#    'lat': 40.2763007,
#    'lon': 48.3488238,
#    'tags': {'amenity': 'cafe', 'name': 'İsmayıllı kafe'}},
#   {'type': 'node',
#    'id': 8019360689,
#    'lat': 40.2796392,
#    'lon': -80.084462,
#    'tags': {'addr:city': 'McMurray',
#     'addr:housenumber': '465',
#     'addr:postcode': '15317',
#     'addr:state': 'PA',
#     'addr:street': 'Valley Brook Road',
#     'amenity': 'cafe',
#     'branch': 'McMurray, Valley Brook Road',
#     'brand': 'Starbucks',
#     'brand:wikidata': 'Q37158',
#     'cuisine': 'coffee_shop',
#     'name': 'Starbucks',
#     'official_name': 'Starbucks Coffee',
#     'phone': '+1 724-941-9219',
#     'takeaway': 'yes',
#     'website': 'https://www.starbucks.com/store-locator/store/18279/mc-murray-valley-brook-rd-465-valleybrook-rd-mc-murray-pa-153173449-us'}},
#   {'type': 'node',
#    'id': 8862913018,
#    'lat': 40.2708698,
#    'lon': 70.4427874,
#    'tags': {'amenity': 'cafe', 'name': 'место встречи'}},
#   {'type': 'node',
#    'id': 8954379613,
#    'lat': 40.2729328,
#    'lon': 18.2625249,
#    'tags': {'amenity': 'cafe',
#     'name': 'Bar Nuovo',
#     'outdoor_seating': 'no',
#     'wheelchair': 'no'}},
#   {'type': 'node',
#    'id': 9041493120,
#    'lat': 40.2751635,
#    'lon': -8.6099732,
#    'tags': {'amenity': 'cafe'}},
#   {'type': 'node',
#    'id': 9356171545,
#    'lat': 40.2762935,
#    'lon': 18.1623034,
#    'tags': {'amenity': 'cafe',
#     'name': 'Apulia Caffè',
#     'phone': '+39 0832 1785255'}},
#   {'type': 'node',
#    'id': 9549207617,
#    'lat': 40.2774447,
#    'lon': 69.6315135,
#    'tags': {'amenity': 'cafe',
#     'cuisine': 'kebab;local',
#     'diet:vegetarian': 'yes'}},
#   {'type': 'node',
#    'id': 9842087559,
#    'lat': 40.2724185,
#    'lon': -3.6956741,
#    'tags': {'amenity': 'cafe',
#     'cuisine': 'coffee_shop',
#     'name': 'Coffy Right'}},
#   {'type': 'node',
#    'id': 9923932186,
#    'lat': 40.2715157,
#    'lon': 22.4989213,
#    'tags': {'amenity': 'cafe',
#     'name': 'Ekavi Lounge Bar',
#     'name:el': 'Εκάβη Lounge Bar',
#     'opening_hours': 'Mo-Su 10:00-01:00'}},
#   {'type': 'node',
#    'id': 9938374118,
#    'lat': 40.273185,
#    'lon': -8.5223553,
#    'tags': {'amenity': 'cafe', 'name': 'Café Bar Pelourinho'}},
#   {'type': 'node',
#    'id': 9938398697,
#    'lat': 40.273061,
#    'lon': -8.5222001,
#    'tags': {'amenity': 'cafe', 'name': 'Café Central'}},
#   {'type': 'node',
#    'id': 9959362818,
#    'lat': 40.2729622,
#    'lon': 69.6396484,
#    'tags': {'amenity': 'cafe', 'name': 'Кафе Ханиф'}},
#   {'type': 'node',
#    'id': 10016867091,
#    'lat': 40.2759329,
#    'lon': 15.6760707,
#    'tags': {'amenity': 'cafe'}},
#   {'type': 'node',
#    'id': 10092922117,
#    'lat': 40.2756622,
#    'lon': 9.6313496,
#    'tags': {'amenity': 'cafe'}},
#   {'type': 'node',
#    'id': 10121258160,
#    'lat': 40.2779367,
#    'lon': -8.0927078,
#    'tags': {'amenity': 'cafe', 'lottery': 'yes', 'name': 'Rainha Cláudia'}},
#   {'type': 'node',
#    'id': 10211736993,
#    'lat': 40.2739831,
#    'lon': -8.4525864,
#    'tags': {'amenity': 'cafe', 'shop': 'convenience'}},
#   {'type': 'node',
#    'id': 10293882800,
#    'lat': 40.2719616,
#    'lon': -76.8904734,
#    'tags': {'addr:city': 'Harrisburg',
#     'addr:housenumber': '1507',
#     'addr:state': 'PA',
#     'addr:street': 'North 3rd Street',
#     'amenity': 'cafe',
#     'name': 'Raising the Bar Bakery'}},
#   {'type': 'node',
#    'id': 10908386320,
#    'lat': 40.2702766,
#    'lon': -7.8960485,
#    'tags': {'amenity': 'cafe'}},
#   {'type': 'node',
#    'id': 10935274081,
#    'lat': 40.2720613,
#    'lon': -8.1475753,
#    'tags': {'amenity': 'cafe', 'name': 'Caçula'}},
#   {'type': 'node',
#    'id': 10965916065,
#    'lat': 40.2730824,
#    'lon': -4.2410077,
#    'tags': {'amenity': 'cafe', 'name': 'El Rulo'}},
#   {'type': 'node',
#    'id': 10965916067,
#    'lat': 40.2719563,
#    'lon': -4.2335739,
#    'tags': {'amenity': 'cafe', 'name': 'El Arca de las Tapas'}},
#   {'type': 'node',
#    'id': 11576141686,
#    'lat': 40.2741529,
#    'lon': 22.5213822,
#    'tags': {'amenity': 'cafe', 'name': 'Mooven'}},
#   {'type': 'node',
#    'id': 11693645592,
#    'lat': 40.2703562,
#    'lon': 22.5970515,
#    'tags': {'amenity': 'cafe', 'name': 'Cafe Posto Paralia'}},
#   {'type': 'node',
#    'id': 11782985805,
#    'lat': 40.2705477,
#    'lon': 22.5113452,
#    'tags': {'addr:city': 'Κατερίνη',
#     'addr:housenumber': '33',
#     'addr:postcode': '601 34',
#     'addr:street': 'Ειρήνης',
#     'amenity': 'cafe',
#     'name': 'Azur'}},
#   {'type': 'node',
#    'id': 11809287083,
#    'lat': 40.2706318,
#    'lon': -8.2749358,
#    'tags': {'amenity': 'cafe', 'name': 'Café Côta'}},
#   {'type': 'node',
#    'id': 11992087678,
#    'lat': 40.2730919,
#    'lon': -7.4987572,
#    'tags': {'addr:city': 'Covilhã',
#     'addr:housenumber': '1',
#     'addr:postcode': '6200-502',
#     'addr:street': 'Avenida da Anil',
#     'amenity': 'cafe',
#     'name': 'O Carapito',
#     'opening_hours': 'Mo-Fr 07:30-22:00; Sa 08:00-16:00',
#     'outdoor_seating': 'yes',
#     'phone': '+351275331643',
#     'website': 'http://www.carapitosnackbar.pt/'}},
#   {'type': 'node',
#    'id': 12014513898,
#    'lat': 40.2720839,
#    'lon': 28.6009465,
#    'tags': {'amenity': 'cafe',
#     'check_date': '2024-06-27',
#     'name': 'İskender'}},
#   {'type': 'node',
#    'id': 12014513900,
#    'lat': 40.2737071,
#    'lon': 28.600218,
#    'tags': {'amenity': 'cafe',
#     'check_date': '2024-06-27',
#     'name': 'İskender'}},
#   {'type': 'node',
#    'id': 12140581680,
#    'lat': 40.2736602,
#    'lon': 18.4246004,
#    'tags': {'amenity': 'cafe', 'name': 'Sauvage'}},
#   {'type': 'node',
#    'id': 12150438006,
#    'lat': 40.2716837,
#    'lon': 18.0478375,
#    'tags': {'amenity': 'cafe', 'fixme': 'verify', 'name': 'Bar Garden'}},
#   {'type': 'node',
#    'id': 12150438009,
#    'lat': 40.2725687,
#    'lon': 18.0481426,
#    'tags': {'amenity': 'cafe',
#     'contact:facebook': 'https://www.facebook.com/profile.php?id=100063806523014',
#     'name': 'Concept Briganti Lounge Bar'}},
#   {'type': 'node',
#    'id': 12150438012,
#    'lat': 40.2730159,
#    'lon': 18.0474351,
#    'tags': {'amenity': 'cafe',
#     'contact:website': 'https://www.layogurteria.it/',
#     'name': 'La Yogurteria'}},
#   {'type': 'node',
#    'id': 12150438013,
#    'lat': 40.2740449,
#    'lon': 18.0457449,
#    'tags': {'amenity': 'cafe'}},
#   {'type': 'node',
#    'id': 12151379495,
#    'lat': 40.2715424,
#    'lon': 18.0490205,
#    'tags': {'amenity': 'cafe', 'name': 'Ciokko Cafè'}},
#   {'type': 'node',
#    'id': 12151379496,
#    'lat': 40.2721349,
#    'lon': 18.049052,
#    'tags': {'amenity': 'cafe', 'name': 'Central Bar'}},
#   {'type': 'node',
#    'id': 12151379499,
#    'lat': 40.274352,
#    'lon': 18.0451188,
#    'tags': {'amenity': 'cafe', 'name': 'Est Cafè 2'}},
#   {'type': 'node',
#    'id': 12151379500,
#    'lat': 40.2744451,
#    'lon': 18.0449002,
#    'tags': {'amenity': 'cafe', 'name': 'Bar Castello'}},
#   {'type': 'node',
#    'id': 12187479007,
#    'lat': 40.2728566,
#    'lon': -3.724793,
#    'tags': {'air_conditioning': 'yes',
#     'amenity': 'cafe',
#     'bar': 'yes',
#     'indoor': 'yes',
#     'indoor_seating': 'yes',
#     'internet_access': 'no',
#     'level': '0',
#     'name': 'Cafetería Servicios Centrales UPM',
#     'opening_hours': 'Mo-Fr 07:30-15:30; PH closed',
#     'outdoor_seating': 'yes',
#     'smoking': 'no',
#     'toilets': 'yes',
#     'toilets:access': 'customers',
#     'toilets:wheelchair': 'limited',
#     'wheelchair': 'limited'}},
#   {'type': 'node',
#    'id': 12211135802,
#    'lat': 40.2762356,
#    'lon': 22.5968922,
#    'tags': {'amenity': 'cafe',
#     'diet:vegan': 'yes',
#     'diet:vegetarian': 'yes',
#     'indoor_seating': 'no',
#     'name': 'By The Pool - cafe-bar restaurant',
#     'outdoor_seating': 'yes'}},
#   {'type': 'node',
#    'id': 12231733071,
#    'lat': 40.2730003,
#    'lon': -7.4996628,
#    'tags': {'access': 'permissive',
#     'addr:city': 'Covilhã',
#     'addr:housenumber': '3',
#     'addr:postcode': '6200-546',
#     'addr:street': 'Alameda da Europa',
#     'addr:unit': 'Rés de Chão Direito',
#     'amenity': 'cafe',
#     'door': 'sliding',
#     'entrance': 'main',
#     'name': 'Ramalha Alameda'}},
#   {'type': 'node',
#    'id': 12253738552,
#    'lat': 40.2798299,
#    'lon': -8.0185729,
#    'tags': {'amenity': 'cafe', 'name': 'Mota'}},
#   {'type': 'node',
#    'id': 12321074455,
#    'lat': 40.2713589,
#    'lon': -7.5017155,
#    'tags': {'amenity': 'cafe', 'name': 'Padaria da Ramalha'}},
#   {'type': 'node',
#    'id': 12324206616,
#    'lat': 40.2709502,
#    'lon': -7.5026253,
#    'tags': {'amenity': 'cafe', 'name': 'Quiosque Café'}},
#   {'type': 'node',
#    'id': 12361175102,
#    'lat': 40.2751311,
#    'lon': 65.1398198,
#    'tags': {'amenity': 'cafe', 'cuisine': 'local', 'name': 'Mehribon kafe'}},
#   {'type': 'node',
#    'id': 12361175201,
#    'lat': 40.276569,
#    'lon': 65.1359805,
#    'tags': {'amenity': 'cafe', 'name': 'Шашлык сомса'}},
#   {'type': 'node',
#    'id': 12361175301,
#    'lat': 40.2744737,
#    'lon': 65.1528741,
#    'tags': {'amenity': 'cafe'}},
#   {'type': 'node',
#    'id': 12435523605,
#    'lat': 40.2717095,
#    'lon': 22.5031936,
#    'tags': {'addr:city': 'Κατερίνη',
#     'addr:housenumber': '58',
#     'addr:postcode': '601 33',
#     'addr:street': 'Μεγάλου Αλεξάνδρου',
#     'amenity': 'cafe',
#     'name': 'The Coffee Road'}},
#   {'type': 'node',
#    'id': 12469267591,
#    'lat': 40.2765361,
#    'lon': -85.8420435,
#    'tags': {'amenity': 'cafe', 'name': 'Gypsy Soul'}},
#   {'type': 'node',
#    'id': 12479825456,
#    'lat': 40.2747277,
#    'lon': -111.6835606,
#    'tags': {'addr:city': 'Orem',
#     'addr:housenumber': '541',
#     'addr:postcode': '84097',
#     'addr:state': 'UT',
#     'addr:street': 'University Parkway',
#     'addr:unit': 'Suite C',
#     'amenity': 'cafe',
#     'cuisine': 'bubble_tea',
#     'name': 'Boba Luv',
#     'phone': '+1-801-225-4969',
#     'website': 'https://bobaluv.com/utah'}},
#   {'type': 'node',
#    'id': 12542289404,
#    'lat': 40.2774098,
#    'lon': 48.3495265,
#    'tags': {'amenity': 'cafe', 'name': 'Turist Kafe \\ Karrar'}},
#   {'type': 'node',
#    'id': 12826640106,
#    'lat': 40.2779766,
#    'lon': -8.0879235,
#    'tags': {'amenity': 'cafe', 'name': 'Locomotiva'}},
#   {'type': 'node',
#    'id': 12851989264,
#    'lat': 40.2717829,
#    'lon': -8.1507864,
#    'tags': {'amenity': 'cafe', 'name': 'São Martinho'}},
#   {'type': 'node',
#    'id': 13088971774,
#    'lat': 40.2730553,
#    'lon': 22.5054336,
#    'tags': {'addr:city': 'Κατερίνη',
#     'addr:housenumber': '19',
#     'addr:postcode': '601 33',
#     'addr:street': 'Ζαλόγγου',
#     'amenity': 'cafe',
#     'name': 'Umi'}},
#   {'type': 'node',
#    'id': 13111906549,
#    'lat': 40.27051,
#    'lon': 22.5069656,
#    'tags': {'addr:city': 'Κατερίνη',
#     'addr:housenumber': '3',
#     'addr:postcode': '601 32',
#     'addr:street': 'Παρθενίου Βαρδάκα',
#     'amenity': 'cafe',
#     'name': 'City Roasters'}},
#   {'type': 'node',
#    'id': 13141045459,
#    'lat': 40.2746685,
#    'lon': 15.6232042,
#    'tags': {'amenity': 'cafe', 'name': 'Bar Casale'}},
#   {'type': 'node',
#    'id': 13165627996,
#    'lat': 40.2748831,
#    'lon': -8.2671366,
#    'tags': {'amenity': 'cafe', 'name': 'Tricanto'}},
#   {'type': 'node',
#    'id': 13165627997,
#    'lat': 40.2755652,
#    'lon': -8.2670253,
#    'tags': {'amenity': 'cafe', 'name': 'Primavera'}},
#   {'type': 'node',
#    'id': 13165635809,
#    'lat': 40.2774045,
#    'lon': -8.2668919,
#    'tags': {'amenity': 'cafe', 'name': 'Silva'}},
#   {'type': 'node',
#    'id': 13165635810,
#    'lat': 40.2784831,
#    'lon': -8.2668694,
#    'tags': {'amenity': 'cafe', 'name': 'Café Petisqueira Conceição'}},
#   {'type': 'node',
#    'id': 13168354403,
#    'lat': 40.2702192,
#    'lon': 22.512051,
#    'tags': {'amenity': 'cafe'}}]}

# %%
data.keys()
# Out:
# dict_keys(['version', 'generator', 'osm3s', 'elements'])

# %%
data["osm3s"]
# Out:
# {'timestamp_osm_base': '2025-10-08T14:14:51Z',
#  'copyright': 'The data included in this document is from www.openstreetmap.org. The data is made available under ODbL.'}

# %%
data.get("osm3s")
# Out:
# {'timestamp_osm_base': '2025-10-08T14:14:51Z',
#  'copyright': 'The data included in this document is from www.openstreetmap.org. The data is made available under ODbL.'}

# %%
data["osm3s"]["copyright"]
# Out:
# 'The data included in this document is from www.openstreetmap.org. The data is made available under ODbL.'

# %%
data["elements"][0]
# Out:
# {'type': 'node',
#  'id': 422157543,
#  'lat': 40.2770334,
#  'lon': -76.8241383,
#  'tags': {'addr:city': 'Union Square',
#   'addr:housenumber': '3901',
#   'addr:postcode': '17109',
#   'addr:state': 'PA',
#   'addr:street': 'Union Deposit Road',
#   'amenity': 'cafe',
#   'branch': 'Union Deposit Road',
#   'brand': 'Starbucks',
#   'brand:wikidata': 'Q37158',
#   'cuisine': 'coffee_shop',
#   'name': 'Starbucks',
#   'official_name': 'Starbucks Coffee',
#   'phone': '+1 717-564-3291',
#   'ref': '7350',
#   'takeaway': 'yes',
#   'website': 'https://www.starbucks.com/store-locator/store/7350/union-deposit-road-3901-union-deposit-road-harrisburg-pa-171095922-us'}}

# %%
# Acceder a los valores del diccionario para guardarlos en variables para luego crear un Dataframe
dict_cafes = {"lat":[], "lon":[], "street":[], "number_street":[]}
for i in data["elements"]:
    lat = i["lat"]
    lon = i["lon"]
    street = i["tags"].get("addr:street", "Sin Calle")
    number_street = i["tags"].get("addr:housenumber", 0)

    dict_cafes["lat"].append(lat)
    dict_cafes["lon"].append(lon)
    dict_cafes["street"].append(street)
    dict_cafes["number_street"].append(number_street)

df_cafe = pd.DataFrame(dict_cafes)
df_cafe
# Out:
#            lat        lon              street number_street
# 0    40.277033 -76.824138  Union Deposit Road          3901
# 1    40.277434  69.630031           Sin Calle             0
# 2    40.273188  -7.496439           Sin Calle             0
# 3    40.279547  65.137487           Sin Calle             0
# 4    40.270639  22.508351   Γεωργάκη Ολυμπίου         10-12
# ..         ...        ...                 ...           ...
# 162  40.274883  -8.267137           Sin Calle             0
# 163  40.275565  -8.267025           Sin Calle             0
# 164  40.277405  -8.266892           Sin Calle             0
# 165  40.278483  -8.266869           Sin Calle             0
# 166  40.270219  22.512051           Sin Calle             0
#
# [167 rows x 4 columns]

# %%
data["elements"][0]["tags"]["name"]
# Out:
# 'Starbucks'

# %%
pd.DataFrame(data["elements"])
# Out:
#      type           id        lat        lon  \
# 0    node    422157543  40.277033 -76.824138
# 1    node    911490084  40.277434  69.630031
# 2    node   1235854116  40.273188  -7.496439
# 3    node   1286907639  40.279547  65.137487
# 4    node   1377477523  40.270639  22.508351
# ..    ...          ...        ...        ...
# 162  node  13165627996  40.274883  -8.267137
# 163  node  13165627997  40.275565  -8.267025
# 164  node  13165635809  40.277405  -8.266892
# 165  node  13165635810  40.278483  -8.266869
# 166  node  13168354403  40.270219  22.512051
#
#                                                   tags
# 0    {'addr:city': 'Union Square', 'addr:housenumbe...
# 1          {'amenity': 'cafe', 'name': 'Дустмухаммад'}
# 2                                  {'amenity': 'cafe'}
# 3                                  {'amenity': 'cafe'}
# 4    {'addr:city': 'Κατερίνη', 'addr:housenumber': ...
# ..                                                 ...
# 162            {'amenity': 'cafe', 'name': 'Tricanto'}
# 163           {'amenity': 'cafe', 'name': 'Primavera'}
# 164               {'amenity': 'cafe', 'name': 'Silva'}
# 165  {'amenity': 'cafe', 'name': 'Café Petisqueira ...
# 166                                {'amenity': 'cafe'}
#
# [167 rows x 5 columns]

# %%
data
# Out:
# {'version': 0.6,
#  'generator': 'Overpass API 0.7.62.8 e802775f',
#  'osm3s': {'timestamp_osm_base': '2025-10-08T14:14:51Z',
#   'copyright': 'The data included in this document is from www.openstreetmap.org. The data is made available under ODbL.'},
#  'elements': [{'type': 'node',
#    'id': 422157543,
#    'lat': 40.2770334,
#    'lon': -76.8241383,
#    'tags': {'addr:city': 'Union Square',
#     'addr:housenumber': '3901',
#     'addr:postcode': '17109',
#     'addr:state': 'PA',
#     'addr:street': 'Union Deposit Road',
#     'amenity': 'cafe',
#     'branch': 'Union Deposit Road',
#     'brand': 'Starbucks',
#     'brand:wikidata': 'Q37158',
#     'cuisine': 'coffee_shop',
#     'name': 'Starbucks',
#     'official_name': 'Starbucks Coffee',
#     'phone': '+1 717-564-3291',
#     'ref': '7350',
#     'takeaway': 'yes',
#     'website': 'https://www.starbucks.com/store-locator/store/7350/union-deposit-road-3901-union-deposit-road-harrisburg-pa-171095922-us'}},
#   {'type': 'node',
#    'id': 911490084,
#    'lat': 40.2774342,
#    'lon': 69.6300307,
#    'tags': {'amenity': 'cafe', 'name': 'Дустмухаммад'}},
#   {'type': 'node',
#    'id': 1235854116,
#    'lat': 40.273188,
#    'lon': -7.4964387,
#    'tags': {'amenity': 'cafe'}},
#   {'type': 'node',
#    'id': 1286907639,
#    'lat': 40.2795473,
#    'lon': 65.1374874,
#    'tags': {'amenity': 'cafe'}},
#   {'type': 'node',
#    'id': 1377477523,
#    'lat': 40.2706393,
#    'lon': 22.5083508,
#    'tags': {'addr:city': 'Κατερίνη',
#     'addr:housenumber': '10-12',
#     'addr:postcode': '601 32',
#     'addr:street': 'Γεωργάκη Ολυμπίου',
#     'amenity': 'cafe',
#     'name': 'Kartell',
#     'operator': 'BAG Τουριστικές Εκμεταλλεύσεις Χώρων Αναψυχής ΕΠE',
#     'outdoor_seating': 'yes'}},
#   {'type': 'node',
#    'id': 1377477542,
#    'lat': 40.2706607,
#    'lon': 22.5085488,
#    'tags': {'addr:city': 'Κατερίνη',
#     'addr:housenumber': '1',
#     'addr:postcode': '601 32',
#     'addr:street': 'Γεωργάκη Ολυμπίου',
#     'amenity': 'cafe',
#     'name': 'Boga',
#     'operator': 'Γ Μερίκος και Σία ΟΕ',
#     'outdoor_seating': 'yes'}},
#   {'type': 'node',
#    'id': 1377477561,
#    'lat': 40.270581,
#    'lon': 22.5088444,
#    'tags': {'addr:city': 'Κατερίνη',
#     'addr:housenumber': '4',
#     'addr:postcode': '601 32',
#     'addr:street': 'Σολωμού',
#     'amenity': 'cafe',
#     'name': "Oliver's Pub",
#     'operator': 'Ιορδανίδης Χρήστος και Σία ΟΕ',
#     'outdoor_seating': 'yes'}},
#   {'type': 'node',
#    'id': 1573449365,
#    'lat': 40.2757399,
#    'lon': -76.8951718,
#    'tags': {'addr:city': 'Harrisburg',
#     'addr:housenumber': '1836',
#     'addr:postcode': '17102',
#     'addr:state': 'PA',
#     'addr:street': 'Green Street',
#     'amenity': 'cafe',
#     'check_date': '2023-10-30',
#     'contact:instagram': 'https://www.instagram.com/littleampscoffee',
#     'cuisine': 'coffee_shop',
#     'internet_access': 'wlan',
#     'name': 'Little Amps',
#     'opening_hours': 'Mo-Fr 07:00-14:00; Sa-Su 08:00-14:00',
#     'phone': '+1 717-695-4882',
#     'website': 'https://littleampscoffee.com'}},
#   {'type': 'node',
#    'id': 1731434694,
#    'lat': 40.2731956,
#    'lon': 22.5073581,
#    'tags': {'addr:city': 'Κατερίνη',
#     'addr:housenumber': '14',
#     'addr:postcode': '601 33',
#     'addr:street': 'Δημητρίου Δημάδη',
#     'amenity': 'cafe',
#     'name': 'Bistro 49'}},
#   {'type': 'node',
#    'id': 1731445028,
#    'lat': 40.2706471,
#    'lon': 22.5074875,
#    'tags': {'addr:city': 'Κατερίνη',
#     'addr:housenumber': '5',
#     'addr:postcode': '601 32',
#     'addr:street': 'Αγίας Λαύρας',
#     'amenity': 'cafe',
#     'name': 'Ludo'}},
#   {'type': 'node',
#    'id': 1731448607,
#    'lat': 40.27107,
#    'lon': 22.5094911,
#    'tags': {'addr:city': 'Κατερίνη',
#     'addr:housenumber': '2',
#     'addr:postcode': '601 34',
#     'addr:street': 'Παναγή Τσαλδάρη',
#     'amenity': 'cafe',
#     'brand': 'Mikel',
#     'brand:wikidata': 'Q16952021',
#     'brand:wikipedia': 'el:Mikel',
#     'cuisine': 'coffee_shop',
#     'name': 'Mikel',
#     'takeaway': 'yes'}},
#   {'type': 'node',
#    'id': 1732839843,
#    'lat': 40.271436,
#    'lon': 22.5015902,
#    'tags': {'addr:city': 'Κατερίνη',
#     'addr:housenumber': '3',
#     'addr:postcode': '601 31',
#     'addr:street': 'Μητροπόλεως',
#     'amenity': 'cafe',
#     'name': 'Barrio Gastrobar',
#     'operator': 'Τσιούχα Αικατερίνη-Ραφαέλα',
#     'outdoor_seating': 'yes'}},
#   {'type': 'node',
#    'id': 1732839854,
#    'lat': 40.2713278,
#    'lon': 22.5015593,
#    'tags': {'addr:city': 'Κατερίνη',
#     'addr:housenumber': '5',
#     'addr:postcode': '601 31',
#     'addr:street': 'Μητροπόλεως',
#     'amenity': 'cafe',
#     'name': 'Park Cafe',
#     'operator': 'Δημάκη Άννα'}},
#   {'type': 'node',
#    'id': 1732856635,
#    'lat': 40.2721393,
#    'lon': 22.505212,
#    'tags': {'addr:city': 'Κατερίνη',
#     'addr:housenumber': '3',
#     'addr:postcode': '601 33',
#     'addr:street': 'Κρέσνας',
#     'amenity': 'cafe',
#     'name': 'Art Caffe'}},
#   {'type': 'node',
#    'id': 1747338120,
#    'lat': 40.2712439,
#    'lon': 22.5084498,
#    'tags': {'addr:city': 'Κατερίνη',
#     'addr:housenumber': '11',
#     'addr:postcode': '601 33',
#     'addr:street': 'Πλατεία Ελευθερίας',
#     'amenity': 'cafe',
#     'name': 'Dolce'}},
#   {'type': 'node',
#    'id': 1747338293,
#    'lat': 40.2714585,
#    'lon': 22.5074243,
#    'tags': {'amenity': 'cafe'}},
#   {'type': 'node',
#    'id': 1747338830,
#    'lat': 40.2715401,
#    'lon': 22.5057948,
#    'tags': {'addr:city': 'Κατερίνη',
#     'addr:housenumber': '2',
#     'addr:postcode': '601 33',
#     'addr:street': 'Τσιμισκή',
#     'amenity': 'cafe',
#     'name': 'Boutique 26'}},
#   {'type': 'node',
#    'id': 1764134996,
#    'lat': 40.2735615,
#    'lon': 22.5151671,
#    'tags': {'addr:city': 'Κατερίνη',
#     'addr:housenumber': '54',
#     'addr:postcode': '601 34',
#     'addr:street': 'Περγάμου',
#     'amenity': 'cafe',
#     'name': 'Ζαχαροπλαστείο-Καφέ Μάρκος'}},
#   {'type': 'node',
#    'id': 1855367761,
#    'lat': 40.2771946,
#    'lon': -3.792095,
#    'tags': {'addr:housenumber': '19',
#     'addr:postcode': '28944',
#     'addr:street': 'Calle de Las Eras',
#     'amenity': 'cafe',
#     'cuisine': 'coffee_shop',
#     'name': 'Éboli',
#     'website': 'http://www.pasteleriaeboli.es/'}},
#   {'type': 'node',
#    'id': 1855773850,
#    'lat': 40.2755992,
#    'lon': -3.7905512,
#    'tags': {'addr:housenumber': '41',
#     'addr:postcode': '28944',
#     'addr:street': 'Calle de Fuentevaqueros',
#     'amenity': 'cafe',
#     'name': 'Cafetería Oliva III'}},
#   {'type': 'node',
#    'id': 1864364952,
#    'lat': 40.2792621,
#    'lon': -3.7942241,
#    'tags': {'amenity': 'cafe', 'name': "Cafetería D'Madrid"}},
#   {'type': 'node',
#    'id': 1866310985,
#    'lat': 40.2788553,
#    'lon': 22.5040232,
#    'tags': {'addr:city': 'Κατερίνη',
#     'addr:housenumber': '11',
#     'addr:postcode': '601 33',
#     'addr:street': 'Σωκράτους',
#     'amenity': 'cafe',
#     'cuisine': 'ice_cream',
#     'name': 'Ζαχαροπλαστείο Μπούσια',
#     'operator': 'Μπούσιας Σωτήριος'}},
#   {'type': 'node',
#    'id': 1868902735,
#    'lat': 40.278985,
#    'lon': -3.7999481,
#    'tags': {'amenity': 'cafe', 'name': 'Cafetería Convair'}},
#   {'type': 'node',
#    'id': 1870611613,
#    'lat': 40.2779068,
#    'lon': -3.7972131,
#    'tags': {'amenity': 'cafe',
#     'cuisine': 'churro',
#     'name': 'Churrería Don Churro'}},
#   {'type': 'node',
#    'id': 1870611616,
#    'lat': 40.2780858,
#    'lon': -3.796854,
#    'tags': {'amenity': 'cafe', 'name': 'El Rincón de Laura'}},
#   {'type': 'node',
#    'id': 1870611619,
#    'lat': 40.277852,
#    'lon': -3.797323,
#    'tags': {'amenity': 'cafe', 'name': 'Hermanos Suero'}},
#   {'type': 'node',
#    'id': 1873347440,
#    'lat': 40.2762915,
#    'lon': -3.7979066,
#    'tags': {'amenity': 'cafe', 'name': 'Café Alhambra'}},
#   {'type': 'node',
#    'id': 1887981280,
#    'lat': 40.279904,
#    'lon': -3.7970503,
#    'tags': {'addr:city': 'Fuenlabrada',
#     'addr:country': 'ES',
#     'addr:housenumber': '10',
#     'addr:street': 'Calle de Extremadura',
#     'amenity': 'cafe',
#     'name': 'Alessandra'}},
#   {'type': 'node',
#    'id': 2012644501,
#    'lat': 40.2750049,
#    'lon': -74.8034144,
#    'tags': {'addr:street': 'Scotch Road',
#     'amenity': 'cafe',
#     'name': 'Bagel Shop'}},
#   {'type': 'node',
#    'id': 2025480819,
#    'lat': 40.2707562,
#    'lon': -7.8956124,
#    'tags': {'amenity': 'cafe', 'name': 'Café da Glória'}},
#   {'type': 'node',
#    'id': 2295502483,
#    'lat': 40.2734528,
#    'lon': -8.6827809,
#    'tags': {'amenity': 'cafe'}},
#   {'type': 'node',
#    'id': 2295502484,
#    'lat': 40.2738785,
#    'lon': -8.6837894,
#    'tags': {'amenity': 'cafe'}},
#   {'type': 'node',
#    'id': 2447353883,
#    'lat': 40.2721484,
#    'lon': -5.8613621,
#    'tags': {'amenity': 'cafe', 'name': 'Bar Nacar'}},
#   {'type': 'node',
#    'id': 2911078228,
#    'lat': 40.2774365,
#    'lon': 18.0462217,
#    'tags': {'amenity': 'cafe'}},
#   {'type': 'node',
#    'id': 3177151661,
#    'lat': 40.2719679,
#    'lon': 18.2605032,
#    'tags': {'addr:city': 'Castri di Lecce',
#     'addr:postcode': '73020',
#     'addr:street': 'Via Indipendenza',
#     'amenity': 'cafe',
#     'name': 'Bar Torsello',
#     'wheelchair': 'limited',
#     'wheelchair:description': 'Luogo accessibile. Stanze interne accessibili ma senza servizi igienici per disabili'}},
#   {'type': 'node',
#    'id': 3183720470,
#    'lat': 40.273448,
#    'lon': 18.265301,
#    'tags': {'addr:city': 'Castri di Lecce',
#     'addr:postcode': '73020',
#     'addr:street': 'Piazza Municipio',
#     'amenity': 'cafe',
#     'name': 'Bar Centrale',
#     'wheelchair': 'no',
#     'wheelchair:description': 'Luogo inaccessibile'}},
#   {'type': 'node',
#    'id': 3184934961,
#    'lat': 40.274014,
#    'lon': 18.256733,
#    'tags': {'addr:city': 'Castri di Lecce',
#     'amenity': 'cafe',
#     'name': 'Bar Tonio - Distributore IP',
#     'wheelchair': 'yes',
#     'wheelchair:description': 'Distributore IP con Bar accessibile'}},
#   {'type': 'node',
#    'id': 3184954361,
#    'lat': 40.274621,
#    'lon': 18.261718,
#    'tags': {'addr:city': 'Castri di Lecce',
#     'addr:postcode': '73020',
#     'addr:street': 'Piazza dei Caduti',
#     'amenity': 'cafe',
#     'name': 'Snack Cafe',
#     'wheelchair': 'yes',
#     'wheelchair:description': 'Bar accessibile'}},
#   {'type': 'node',
#    'id': 3190546947,
#    'lat': 40.271191,
#    'lon': -76.8433895,
#    'tags': {'amenity': 'cafe', 'name': 'Souled Out Cafe'}},
#   {'type': 'node',
#    'id': 3498386418,
#    'lat': 40.2709812,
#    'lon': 69.6921406,
#    'tags': {'addr:street': 'Қасри Арбоб',
#     'amenity': 'cafe',
#     'name': 'Чойхонаи миллӣ'}},
#   {'type': 'node',
#    'id': 3499694052,
#    'lat': 40.2775538,
#    'lon': -7.4987514,
#    'tags': {'amenity': 'cafe'}},
#   {'type': 'node',
#    'id': 3499694054,
#    'lat': 40.276979,
#    'lon': -7.4988193,
#    'tags': {'amenity': 'cafe'}},
#   {'type': 'node',
#    'id': 3499694057,
#    'lat': 40.2757313,
#    'lon': -7.4994707,
#    'tags': {'amenity': 'cafe'}},
#   {'type': 'node',
#    'id': 3499694060,
#    'lat': 40.2764365,
#    'lon': -7.4997005,
#    'tags': {'amenity': 'cafe', 'name': 'Primor'}},
#   {'type': 'node',
#    'id': 3573990064,
#    'lat': 40.2795527,
#    'lon': 69.62773,
#    'tags': {'amenity': 'cafe', 'name': 'Орзуи Ширин'}},
#   {'type': 'node',
#    'id': 3735999726,
#    'lat': 40.2738532,
#    'lon': 18.2587275,
#    'tags': {'addr:street': 'Via Giacomo Brodolini',
#     'amenity': 'cafe',
#     'name': 'Salento Caffè',
#     'wheelchair': 'yes'}},
#   {'type': 'node',
#    'id': 3753298267,
#    'lat': 40.2747961,
#    'lon': -81.8691777,
#    'tags': {'addr:city': 'Coshocton',
#     'addr:housenumber': '131',
#     'addr:postcode': '43812-1130',
#     'addr:state': 'OH',
#     'addr:street': 'Chestnut Street',
#     'amenity': 'cafe',
#     'brand': 'Tim Hortons',
#     'brand:wikidata': 'Q175106',
#     'cuisine': 'coffee_shop',
#     'delivery': 'yes',
#     'drive_through': 'yes',
#     'indoor_seating': 'no',
#     'internet_access': 'wlan',
#     'name': 'Tim Hortons',
#     'opening_hours': 'Mo-We 06:00-20:00; Fr-Sa 06:00-20:00; Su 06:00-16:00',
#     'phone': '+1 740-295-0529',
#     'takeaway': 'yes'}},
#   {'type': 'node',
#    'id': 4013613462,
#    'lat': 40.2734921,
#    'lon': -111.6784318,
#    'tags': {'addr:city': 'Orem',
#     'addr:housenumber': '725',
#     'addr:postcode': '84097',
#     'addr:state': 'UT',
#     'addr:street': 'East University Parkway',
#     'amenity': 'cafe',
#     'branch': 'Orem - University Mall',
#     'brand': 'Starbucks',
#     'brand:wikidata': 'Q37158',
#     'cuisine': 'coffee_shop',
#     'name': 'Starbucks',
#     'official_name': 'Starbucks Coffee',
#     'phone': '+1 801-225-7104',
#     'ref': '1012284',
#     'takeaway': 'yes',
#     'website': 'https://www.starbucks.com/store-locator/store/1012284/orem-university-mall-725-east-university-parkway-orem-ut-840977771-us'}},
#   {'type': 'node',
#    'id': 4104682075,
#    'lat': 40.2718613,
#    'lon': 22.5039306,
#    'tags': {'addr:city': 'Κατερίνη',
#     'addr:housenumber': '1',
#     'addr:postcode': '601 33',
#     'addr:street': 'Σαρανταπόρου',
#     'amenity': 'cafe',
#     'name': 'Πόδας'}},
#   {'type': 'node',
#    'id': 4120107990,
#    'lat': 40.2726756,
#    'lon': 44.6335877,
#    'tags': {'amenity': 'cafe', 'name': 'Ureni'}},
#   {'type': 'node',
#    'id': 4235737592,
#    'lat': 40.2724549,
#    'lon': -7.498471,
#    'tags': {'addr:city': 'Covilhã',
#     'addr:housenumber': '1',
#     'addr:postcode': '6200-505',
#     'addr:street': 'Rua Centro de Artes',
#     'addr:unit': 'Rés de Chão Esquerdo',
#     'amenity': 'cafe',
#     'cuisine': 'tea;breakfast;coffee_shop',
#     'name': 'Pérola Doce',
#     'opening_hours': 'Mo-Fr 07:30-21:00; Sa-Su 08:00-20:00',
#     'outdoor_seating': 'no',
#     'phone': '+351275332406'}},
#   {'type': 'node',
#    'id': 4285946496,
#    'lat': 40.2737056,
#    'lon': 18.4285268,
#    'tags': {'addr:postcode': '73026',
#     'addr:street': 'Via Giacomo Matteotti',
#     'amenity': 'cafe',
#     'cuisine': 'ice_cream',
#     'name': 'Dentoni',
#     'phone': '+39 0832 841485',
#     'shop': 'pastry'}},
#   {'type': 'node',
#    'id': 4396721462,
#    'lat': 40.273404,
#    'lon': -8.5207666,
#    'tags': {'amenity': 'cafe', 'name': 'Flor de Ançã'}},
#   {'type': 'node',
#    'id': 4402590493,
#    'lat': 40.2714018,
#    'lon': 22.5072329,
#    'tags': {'amenity': 'cafe'}},
#   {'type': 'node',
#    'id': 4463502198,
#    'lat': 40.2764041,
#    'lon': 22.5146083,
#    'tags': {'addr:city': 'Κατερίνη',
#     'addr:housenumber': '82',
#     'addr:postcode': '601 34',
#     'addr:street': 'Θεσσαλονίκης',
#     'amenity': 'cafe',
#     'cuisine': 'sausage;hot_dog;sandwich;coffee_shop;greek',
#     'name': 'Μπουγάτσα ΛΙΧΟΥΔΙΕΣ',
#     'name:el': 'Μπουγάτσα ΛΙΧΟΥΔΙΕΣ',
#     'name:en': 'Bougatsa LICHOUDIES',
#     'opening_hours': 'Mo-Sa 06:00-16:00',
#     'operator': 'Κατερίνα',
#     'phone': '+302351079996'}},
#   {'type': 'node',
#    'id': 4503675491,
#    'lat': 40.2720129,
#    'lon': 69.6046094,
#    'tags': {'amenity': 'cafe',
#     'name': 'Шашлычная "Катикча"',
#     'name:ru': 'Шашлычная "Катикча"'}},
#   {'type': 'node',
#    'id': 4643884032,
#    'lat': 40.2738029,
#    'lon': -5.8583816,
#    'tags': {'amenity': 'cafe'}},
#   {'type': 'node',
#    'id': 4648488294,
#    'lat': 40.2704302,
#    'lon': 44.6277393,
#    'tags': {'amenity': 'cafe',
#     'name': 'Աբովյան Բուրգեր',
#     'name:en': '"Abovyan Burger"',
#     'name:ru': '"Abovyan Burger"',
#     'phone': '+374 98 09 50 60;374 222 6 50 60'}},
#   {'type': 'node',
#    'id': 4690473690,
#    'lat': 40.2709395,
#    'lon': 22.5083914,
#    'tags': {'amenity': 'cafe', 'name': 'Florian', 'operator': 'Ντούφα Ελένη'}},
#   {'type': 'node',
#    'id': 4711840959,
#    'lat': 40.2718562,
#    'lon': 22.508945,
#    'tags': {'addr:city': 'Κατερίνη',
#     'addr:housenumber': '2',
#     'addr:postcode': '601 34',
#     'addr:street': 'Εθνικής Αντιστάσεως',
#     'amenity': 'cafe',
#     'name': 'Cafe Καφέ',
#     'operator': 'Κασιτερόπουλος Γ. Κασιτεροπούλου Δ. ΟΕ'}},
#   {'type': 'node',
#    'id': 4711840961,
#    'lat': 40.2716152,
#    'lon': 22.5091064,
#    'tags': {'amenity': 'cafe',
#     'brand': 'Coffee Island',
#     'brand:wikidata': 'Q60867333',
#     'brand:wikipedia': 'en:Coffee Island',
#     'cuisine': 'coffee_shop',
#     'name': 'Coffee Island',
#     'takeaway': 'yes'}},
#   {'type': 'node',
#    'id': 4711935670,
#    'lat': 40.2713142,
#    'lon': 22.5084514,
#    'tags': {'addr:city': 'Κατερίνη',
#     'addr:housenumber': '9',
#     'addr:postcode': '601 33',
#     'addr:street': 'Πλατεία Ελευθερίας',
#     'amenity': 'cafe',
#     'name': 'Αρχοντικό'}},
#   {'type': 'node',
#    'id': 4711935673,
#    'lat': 40.2715765,
#    'lon': 22.5084551,
#    'tags': {'addr:city': 'Κατερίνη',
#     'addr:housenumber': '1',
#     'addr:postcode': '601 33',
#     'addr:street': '16ης Οκτωβρίου',
#     'amenity': 'cafe',
#     'name': 'Better Cafe.bar'}},
#   {'type': 'node',
#    'id': 4712033657,
#    'lat': 40.2709233,
#    'lon': 22.5091822,
#    'tags': {'addr:city': 'Κατερίνη',
#     'addr:housenumber': '1',
#     'addr:postcode': '601 32',
#     'addr:street': 'Πλατεία Ελευθερίας',
#     'amenity': 'cafe',
#     'name': 'Piazza'}},
#   {'type': 'node',
#    'id': 4719810291,
#    'lat': 40.2726479,
#    'lon': 44.6343859,
#    'tags': {'addr:street': 'Հատիս փողոց',
#     'amenity': 'cafe',
#     'name': 'Տարոն',
#     'name:hy': 'Տարոն'}},
#   {'type': 'node',
#    'id': 4737875344,
#    'lat': 40.2718525,
#    'lon': 22.4986403,
#    'tags': {'addr:city': 'Κατερίνη',
#     'addr:housenumber': '1',
#     'addr:postcode': '601 33',
#     'addr:street': 'Φιλελλήνων',
#     'amenity': 'cafe',
#     'name': 'Bruno'}},
#   {'type': 'node',
#    'id': 4737875345,
#    'lat': 40.2743704,
#    'lon': 22.5136211,
#    'tags': {'addr:city': 'Κατερίνη',
#     'addr:housenumber': '58',
#     'addr:postcode': '601 34',
#     'addr:street': 'Θεσσαλονίκης',
#     'amenity': 'cafe',
#     'name': 'Bruno',
#     'operator': 'Χείρας Αλέξανδρος'}},
#   {'type': 'node',
#    'id': 4773808698,
#    'lat': 40.2710094,
#    'lon': 22.5096468,
#    'tags': {'addr:city': 'Κατερίνη',
#     'addr:housenumber': '3',
#     'addr:postcode': '601 34',
#     'addr:street': 'Ειρήνης',
#     'amenity': 'cafe',
#     'name': 'Μπουγάτσα Καφέ Μιχάλης',
#     'operator': 'Μπουμπουλέντρας Μιχαήλ'}},
#   {'type': 'node',
#    'id': 4780012360,
#    'lat': 40.274065,
#    'lon': 22.5142513,
#    'tags': {'addr:city': 'Κατερίνη',
#     'addr:housenumber': '10',
#     'addr:postcode': '601 34',
#     'addr:street': 'Νικολάου Δίκα',
#     'amenity': 'cafe',
#     'delivery': 'yes',
#     'name': 'Illy Street Cafe',
#     'opening_hours': 'Mo-Su 06:00-23:30',
#     'outdoor_seating': 'yes',
#     'payment:cash': 'yes',
#     'payment:contactless': 'yes',
#     'phone': '2351028777',
#     'takeaway': 'yes',
#     'toilets': 'yes',
#     'website': 'https://www.street-cafe.gr/'}},
#   {'type': 'node',
#    'id': 4794890688,
#    'lat': 40.2757471,
#    'lon': 69.6411885,
#    'tags': {'addr:city': 'Худжанд',
#     'addr:postcode': '735700',
#     'addr:street': 'кучаи Гагарина',
#     'amenity': 'cafe',
#     'name': 'Фарзона',
#     'name:uz': 'Farzoda oilaviy oshxonasi',
#     'old_name': 'МУБАРО'}},
#   {'type': 'node',
#    'id': 4798382229,
#    'lat': 40.2717716,
#    'lon': 22.5058754,
#    'tags': {'addr:city': 'Κατερίνη',
#     'addr:housenumber': '5',
#     'addr:postcode': '601 33',
#     'addr:street': 'Τσιμισκή',
#     'amenity': 'cafe',
#     'name': 'Louis Lauren Chocolates',
#     'operator': 'Πέλλας Νικόλαος'}},
#   {'type': 'node',
#    'id': 4807728125,
#    'lat': 40.2793716,
#    'lon': 69.615344,
#    'tags': {'amenity': 'cafe', 'name': 'Аюбҷон', 'name:ru': 'Аюбҷон'}},
#   {'type': 'node',
#    'id': 4818950434,
#    'lat': 40.2711956,
#    'lon': 22.5015299,
#    'tags': {'addr:city': 'Κατερίνη',
#     'addr:housenumber': '9',
#     'addr:postcode': '601 31',
#     'addr:street': 'Μητροπόλεως',
#     'amenity': 'cafe',
#     'name': 'Mystique',
#     'operator': 'Γιαννούλης Γεώργιος'}},
#   {'type': 'node',
#    'id': 4818950435,
#    'lat': 40.271601,
#    'lon': 22.5016403,
#    'tags': {'addr:city': 'Κατερίνη',
#     'addr:housenumber': '1',
#     'addr:postcode': '601 31',
#     'addr:street': 'Μητροπόλεως',
#     'amenity': 'cafe',
#     'brand': 'Mikel',
#     'brand:wikidata': 'Q16952021',
#     'cuisine': 'coffee_shop',
#     'disused:amenity': 'cafe',
#     'name': 'Mikel',
#     'takeaway': 'yes'}},
#   {'type': 'node',
#    'id': 4861932021,
#    'lat': 40.2753305,
#    'lon': 69.6374245,
#    'tags': {'amenity': 'cafe',
#     'description': 'Cafe with pastry and good coffee'}},
#   {'type': 'node',
#    'id': 4890072547,
#    'lat': 40.2735125,
#    'lon': 22.5123989,
#    'tags': {'addr:city': 'Κατερίνη',
#     'addr:housenumber': '13',
#     'addr:postcode': '601 34',
#     'addr:street': 'Δημητρίου Βακάλη',
#     'amenity': 'cafe',
#     'name': 'Καφέ Κομπολόι',
#     'operator': 'Μέριμνα Παιδιού Κατερίνης'}},
#   {'type': 'node',
#    'id': 4939666307,
#    'lat': 40.2790954,
#    'lon': 22.5038466,
#    'tags': {'addr:city': 'Κατερίνη',
#     'addr:housenumber': '13',
#     'addr:postcode': '601 33',
#     'addr:street': 'Σωκράτους',
#     'amenity': 'cafe',
#     'name': 'Τσαχούρ'}},
#   {'type': 'node',
#    'id': 5003885849,
#    'lat': 40.2786147,
#    'lon': -86.394378,
#    'tags': {'amenity': 'cafe'}},
#   {'type': 'node',
#    'id': 5105947936,
#    'lat': 40.2787173,
#    'lon': 19.5036692,
#    'tags': {'amenity': 'cafe'}},
#   {'type': 'node',
#    'id': 5158965007,
#    'lat': 40.2713581,
#    'lon': 22.5066931,
#    'tags': {'addr:city': 'Κατερίνη',
#     'addr:housenumber': '26',
#     'addr:postcode': '601 33',
#     'addr:street': 'Μεγάλου Αλεξάνδρου',
#     'amenity': 'cafe',
#     'name': 'Freud',
#     'operator': 'Ι. Κωνσταντινίδης και Σία ΟΕ',
#     'outdoor_seating': 'yes'}},
#   {'type': 'node',
#    'id': 5218907716,
#    'lat': 40.271376,
#    'lon': 22.5056621,
#    'tags': {'addr:city': 'Κατερίνη',
#     'addr:housenumber': '39',
#     'addr:postcode': '601 32',
#     'addr:street': 'Μεγάλου Αλεξάνδρου',
#     'amenity': 'cafe',
#     'name': 'Transistor',
#     'operator': 'Γκιάτας Νικόλαος'}},
#   {'type': 'node',
#    'id': 5244558941,
#    'lat': 40.2702429,
#    'lon': 22.5085043,
#    'tags': {'addr:city': 'Κατερίνη',
#     'addr:housenumber': '18',
#     'addr:postcode': '601 32',
#     'addr:street': 'Αγίας Λαύρας',
#     'amenity': 'cafe',
#     'name': 'Μπουγάτσα Ζέλιος',
#     'operator': 'Μπουκλής Θεμιστοκλής'}},
#   {'type': 'node',
#    'id': 5255483021,
#    'lat': 40.270809,
#    'lon': 22.5080431,
#    'tags': {'addr:city': 'Κατερίνη',
#     'addr:housenumber': '3',
#     'addr:postcode': '601 32',
#     'addr:street': 'Α΄ Πάροδος Γεωργάκη Ολυμπίου',
#     'amenity': 'cafe',
#     'name': 'Το Αδιέξοδο',
#     'operator': 'Βαϊτσοπούλου Ελένη'}},
#   {'type': 'node',
#    'id': 5255483024,
#    'lat': 40.2707179,
#    'lon': 22.5083622,
#    'tags': {'addr:city': 'Κατερίνη',
#     'addr:housenumber': '10',
#     'addr:postcode': '601 32',
#     'addr:street': 'Γεωργάκη Ολυμπίου',
#     'amenity': 'cafe',
#     'name': 'Celso',
#     'operator': 'Ντούλας Νικόλαος'}},
#   {'type': 'node',
#    'id': 5272843624,
#    'lat': 40.2702571,
#    'lon': 22.5081492,
#    'tags': {'addr:city': 'Κατερίνη',
#     'addr:housenumber': '14',
#     'addr:postcode': '601 32',
#     'addr:street': 'Αγίας Λαύρας',
#     'amenity': 'cafe',
#     'name': 'Geppetto Bistro',
#     'outdoor_seating': 'yes'}},
#   {'type': 'node',
#    'id': 5272843626,
#    'lat': 40.2708038,
#    'lon': 22.5085421,
#    'tags': {'addr:city': 'Κατερίνη',
#     'addr:housenumber': '1',
#     'addr:postcode': '601 32',
#     'addr:street': 'Γεωργάκη Ολυμπίου',
#     'amenity': 'cafe'}},
#   {'type': 'node',
#    'id': 5368746442,
#    'lat': 40.2714219,
#    'lon': 22.5099449,
#    'tags': {'amenity': 'cafe', 'name': 'BAKA'}},
#   {'type': 'node',
#    'id': 5472423986,
#    'lat': 40.2710274,
#    'lon': 140.5693469,
#    'tags': {'amenity': 'cafe', 'name': 'コーヒーハウス 茶色の小びん'}},
#   {'type': 'node',
#    'id': 5472436527,
#    'lat': 40.2743029,
#    'lon': 140.5594577,
#    'tags': {'amenity': 'cafe', 'name': '加賀コーヒー店'}},
#   {'type': 'node',
#    'id': 5472436531,
#    'lat': 40.2708877,
#    'lon': 140.5700158,
#    'tags': {'amenity': 'cafe', 'name': 'ワラビカフェ'}},
#   {'type': 'node',
#    'id': 5537672722,
#    'lat': 40.2749846,
#    'lon': 44.6315673,
#    'tags': {'addr:city': 'Աբովյան',
#     'addr:country': 'AM',
#     'addr:housenumber': '1/10',
#     'addr:street': 'Ռուսաստանի փողոց',
#     'amenity': 'cafe',
#     'name': 'ՄԱԿՈւ',
#     'name:en': 'MAKU',
#     'phone': '091698866'}},
#   {'type': 'node',
#    'id': 5543026585,
#    'lat': 40.2722031,
#    'lon': 22.5127314,
#    'tags': {'addr:city': 'Κατερίνη',
#     'addr:housenumber': '31',
#     'addr:postcode': '601 34',
#     'addr:street': 'Δημητρίου Νίκα',
#     'amenity': 'cafe',
#     'name': 'Amanthis'}},
#   {'type': 'node',
#    'id': 5802415978,
#    'lat': 40.2787399,
#    'lon': 22.5042258,
#    'tags': {'addr:street': 'Σωκράτους',
#     'amenity': 'cafe',
#     'name': 'Mojo Cafe',
#     'source': 'Kaart Ground Survey 2018'}},
#   {'type': 'node',
#    'id': 5828638291,
#    'lat': 40.2732237,
#    'lon': 69.6391711,
#    'tags': {'amenity': 'cafe',
#     'cuisine': 'oriental;regional;breakfast;cake;tea;coffee_shop;local;donut',
#     'name': "Магазин сладостей ' Печелка",
#     'name:en': "Cafe 'Pechelka'",
#     'name:ru': "Кафе 'Печелка'"}},
#   {'type': 'node',
#    'id': 5898376610,
#    'lat': 40.278023,
#    'lon': -78.8464266,
#    'tags': {'amenity': 'cafe',
#     'brand': 'Starbucks',
#     'brand:wikidata': 'Q37158',
#     'contact:website': 'https://www.starbucks.com/store-locator/store/8091/johnstown-109-town-centre-drive-110-johnstown-pa-159042824-u',
#     'cuisine': 'coffee_shop',
#     'name': 'Starbucks',
#     'official_name': 'Starbucks Coffee',
#     'takeaway': 'yes'}},
#   {'type': 'node',
#    'id': 5927074286,
#    'lat': 40.2751124,
#    'lon': 63.2816475,
#    'tags': {'amenity': 'cafe', 'name': 'Minutka'}},
#   {'type': 'node',
#    'id': 5944091386,
#    'lat': 40.2723563,
#    'lon': 18.3369389,
#    'tags': {'addr:city': 'Melendugno',
#     'addr:postcode': '73026',
#     'addr:street': 'Via IV Novembre',
#     'amenity': 'cafe',
#     'name': 'Gelateria Bar Roma'}},
#   {'type': 'node',
#    'id': 5944102185,
#    'lat': 40.2711804,
#    'lon': 18.3351535,
#    'tags': {'amenity': 'cafe', 'name': 'Historic Café'}},
#   {'type': 'node',
#    'id': 5948743007,
#    'lat': 40.2725384,
#    'lon': -79.886975,
#    'tags': {'addr:city': 'Elizabeth',
#     'addr:housenumber': '111',
#     'addr:postcode': '15037',
#     'addr:street': 'South 2nd Avenue',
#     'amenity': 'cafe',
#     'name': "Top o' the Morning",
#     'shop': 'bakery',
#     'website': 'https://top-o-the-mornin-donut-and-coffee-shop.business.site/'}},
#   {'type': 'node',
#    'id': 5949091185,
#    'lat': 40.2752388,
#    'lon': 9.5975121,
#    'tags': {'amenity': 'cafe',
#     'name': 'Chiosco Monte Longu',
#     'opening_hours': 'Mo off'}},
#   {'type': 'node',
#    'id': 6382140710,
#    'lat': 40.2729679,
#    'lon': -7.72705,
#    'tags': {'amenity': 'cafe',
#     'cuisine': 'coffee_shop',
#     'name': 'Café Mira Rio',
#     'outdoor_seating': 'yes'}},
#   {'type': 'node',
#    'id': 6657114733,
#    'lat': 40.2727169,
#    'lon': 18.0484787,
#    'tags': {'amenity': 'cafe',
#     'contact:mobile': '+39 333 9419971',
#     'contact:phone': '+39 0832 1693423',
#     'name': 'Caffè 900'}},
#   {'type': 'node',
#    'id': 6899256636,
#    'lat': 40.2763777,
#    'lon': -4.3060659,
#    'tags': {'amenity': 'cafe',
#     'bar': 'yes',
#     'name': 'Bar la Pinta',
#     'outdoor_seating': 'yes'}},
#   {'type': 'node',
#    'id': 6899266885,
#    'lat': 40.2782588,
#    'lon': -4.3083733,
#    'tags': {'amenity': 'cafe', 'name': 'Peña Madridista Pradeña'}},
#   {'type': 'node',
#    'id': 7250455616,
#    'lat': 40.2707904,
#    'lon': 22.5082094,
#    'tags': {'addr:city': 'Κατερίνη',
#     'addr:housenumber': '1',
#     'addr:postcode': '601 32',
#     'addr:street': 'Α΄ Πάροδος Γεωργάκη Ολυμπίου',
#     'amenity': 'cafe',
#     'name': 'Μπάρμπα Σπύρος'}},
#   {'type': 'node',
#    'id': 7433146584,
#    'lat': 40.2783384,
#    'lon': -3.9167434,
#    'tags': {'addr:housenumber': '21',
#     'addr:postcode': '28939',
#     'addr:street': 'Calle de Marbella',
#     'amenity': 'cafe',
#     'name': 'Cafeteria Olimpia'}},
#   {'type': 'node',
#    'id': 7834155466,
#    'lat': 40.2768067,
#    'lon': -4.3056751,
#    'tags': {'amenity': 'cafe', 'name': 'El Dorado'}},
#   {'type': 'node',
#    'id': 7956061569,
#    'lat': 40.2763007,
#    'lon': 48.3488238,
#    'tags': {'amenity': 'cafe', 'name': 'İsmayıllı kafe'}},
#   {'type': 'node',
#    'id': 8019360689,
#    'lat': 40.2796392,
#    'lon': -80.084462,
#    'tags': {'addr:city': 'McMurray',
#     'addr:housenumber': '465',
#     'addr:postcode': '15317',
#     'addr:state': 'PA',
#     'addr:street': 'Valley Brook Road',
#     'amenity': 'cafe',
#     'branch': 'McMurray, Valley Brook Road',
#     'brand': 'Starbucks',
#     'brand:wikidata': 'Q37158',
#     'cuisine': 'coffee_shop',
#     'name': 'Starbucks',
#     'official_name': 'Starbucks Coffee',
#     'phone': '+1 724-941-9219',
#     'takeaway': 'yes',
#     'website': 'https://www.starbucks.com/store-locator/store/18279/mc-murray-valley-brook-rd-465-valleybrook-rd-mc-murray-pa-153173449-us'}},
#   {'type': 'node',
#    'id': 8862913018,
#    'lat': 40.2708698,
#    'lon': 70.4427874,
#    'tags': {'amenity': 'cafe', 'name': 'место встречи'}},
#   {'type': 'node',
#    'id': 8954379613,
#    'lat': 40.2729328,
#    'lon': 18.2625249,
#    'tags': {'amenity': 'cafe',
#     'name': 'Bar Nuovo',
#     'outdoor_seating': 'no',
#     'wheelchair': 'no'}},
#   {'type': 'node',
#    'id': 9041493120,
#    'lat': 40.2751635,
#    'lon': -8.6099732,
#    'tags': {'amenity': 'cafe'}},
#   {'type': 'node',
#    'id': 9356171545,
#    'lat': 40.2762935,
#    'lon': 18.1623034,
#    'tags': {'amenity': 'cafe',
#     'name': 'Apulia Caffè',
#     'phone': '+39 0832 1785255'}},
#   {'type': 'node',
#    'id': 9549207617,
#    'lat': 40.2774447,
#    'lon': 69.6315135,
#    'tags': {'amenity': 'cafe',
#     'cuisine': 'kebab;local',
#     'diet:vegetarian': 'yes'}},
#   {'type': 'node',
#    'id': 9842087559,
#    'lat': 40.2724185,
#    'lon': -3.6956741,
#    'tags': {'amenity': 'cafe',
#     'cuisine': 'coffee_shop',
#     'name': 'Coffy Right'}},
#   {'type': 'node',
#    'id': 9923932186,
#    'lat': 40.2715157,
#    'lon': 22.4989213,
#    'tags': {'amenity': 'cafe',
#     'name': 'Ekavi Lounge Bar',
#     'name:el': 'Εκάβη Lounge Bar',
#     'opening_hours': 'Mo-Su 10:00-01:00'}},
#   {'type': 'node',
#    'id': 9938374118,
#    'lat': 40.273185,
#    'lon': -8.5223553,
#    'tags': {'amenity': 'cafe', 'name': 'Café Bar Pelourinho'}},
#   {'type': 'node',
#    'id': 9938398697,
#    'lat': 40.273061,
#    'lon': -8.5222001,
#    'tags': {'amenity': 'cafe', 'name': 'Café Central'}},
#   {'type': 'node',
#    'id': 9959362818,
#    'lat': 40.2729622,
#    'lon': 69.6396484,
#    'tags': {'amenity': 'cafe', 'name': 'Кафе Ханиф'}},
#   {'type': 'node',
#    'id': 10016867091,
#    'lat': 40.2759329,
#    'lon': 15.6760707,
#    'tags': {'amenity': 'cafe'}},
#   {'type': 'node',
#    'id': 10092922117,
#    'lat': 40.2756622,
#    'lon': 9.6313496,
#    'tags': {'amenity': 'cafe'}},
#   {'type': 'node',
#    'id': 10121258160,
#    'lat': 40.2779367,
#    'lon': -8.0927078,
#    'tags': {'amenity': 'cafe', 'lottery': 'yes', 'name': 'Rainha Cláudia'}},
#   {'type': 'node',
#    'id': 10211736993,
#    'lat': 40.2739831,
#    'lon': -8.4525864,
#    'tags': {'amenity': 'cafe', 'shop': 'convenience'}},
#   {'type': 'node',
#    'id': 10293882800,
#    'lat': 40.2719616,
#    'lon': -76.8904734,
#    'tags': {'addr:city': 'Harrisburg',
#     'addr:housenumber': '1507',
#     'addr:state': 'PA',
#     'addr:street': 'North 3rd Street',
#     'amenity': 'cafe',
#     'name': 'Raising the Bar Bakery'}},
#   {'type': 'node',
#    'id': 10908386320,
#    'lat': 40.2702766,
#    'lon': -7.8960485,
#    'tags': {'amenity': 'cafe'}},
#   {'type': 'node',
#    'id': 10935274081,
#    'lat': 40.2720613,
#    'lon': -8.1475753,
#    'tags': {'amenity': 'cafe', 'name': 'Caçula'}},
#   {'type': 'node',
#    'id': 10965916065,
#    'lat': 40.2730824,
#    'lon': -4.2410077,
#    'tags': {'amenity': 'cafe', 'name': 'El Rulo'}},
#   {'type': 'node',
#    'id': 10965916067,
#    'lat': 40.2719563,
#    'lon': -4.2335739,
#    'tags': {'amenity': 'cafe', 'name': 'El Arca de las Tapas'}},
#   {'type': 'node',
#    'id': 11576141686,
#    'lat': 40.2741529,
#    'lon': 22.5213822,
#    'tags': {'amenity': 'cafe', 'name': 'Mooven'}},
#   {'type': 'node',
#    'id': 11693645592,
#    'lat': 40.2703562,
#    'lon': 22.5970515,
#    'tags': {'amenity': 'cafe', 'name': 'Cafe Posto Paralia'}},
#   {'type': 'node',
#    'id': 11782985805,
#    'lat': 40.2705477,
#    'lon': 22.5113452,
#    'tags': {'addr:city': 'Κατερίνη',
#     'addr:housenumber': '33',
#     'addr:postcode': '601 34',
#     'addr:street': 'Ειρήνης',
#     'amenity': 'cafe',
#     'name': 'Azur'}},
#   {'type': 'node',
#    'id': 11809287083,
#    'lat': 40.2706318,
#    'lon': -8.2749358,
#    'tags': {'amenity': 'cafe', 'name': 'Café Côta'}},
#   {'type': 'node',
#    'id': 11992087678,
#    'lat': 40.2730919,
#    'lon': -7.4987572,
#    'tags': {'addr:city': 'Covilhã',
#     'addr:housenumber': '1',
#     'addr:postcode': '6200-502',
#     'addr:street': 'Avenida da Anil',
#     'amenity': 'cafe',
#     'name': 'O Carapito',
#     'opening_hours': 'Mo-Fr 07:30-22:00; Sa 08:00-16:00',
#     'outdoor_seating': 'yes',
#     'phone': '+351275331643',
#     'website': 'http://www.carapitosnackbar.pt/'}},
#   {'type': 'node',
#    'id': 12014513898,
#    'lat': 40.2720839,
#    'lon': 28.6009465,
#    'tags': {'amenity': 'cafe',
#     'check_date': '2024-06-27',
#     'name': 'İskender'}},
#   {'type': 'node',
#    'id': 12014513900,
#    'lat': 40.2737071,
#    'lon': 28.600218,
#    'tags': {'amenity': 'cafe',
#     'check_date': '2024-06-27',
#     'name': 'İskender'}},
#   {'type': 'node',
#    'id': 12140581680,
#    'lat': 40.2736602,
#    'lon': 18.4246004,
#    'tags': {'amenity': 'cafe', 'name': 'Sauvage'}},
#   {'type': 'node',
#    'id': 12150438006,
#    'lat': 40.2716837,
#    'lon': 18.0478375,
#    'tags': {'amenity': 'cafe', 'fixme': 'verify', 'name': 'Bar Garden'}},
#   {'type': 'node',
#    'id': 12150438009,
#    'lat': 40.2725687,
#    'lon': 18.0481426,
#    'tags': {'amenity': 'cafe',
#     'contact:facebook': 'https://www.facebook.com/profile.php?id=100063806523014',
#     'name': 'Concept Briganti Lounge Bar'}},
#   {'type': 'node',
#    'id': 12150438012,
#    'lat': 40.2730159,
#    'lon': 18.0474351,
#    'tags': {'amenity': 'cafe',
#     'contact:website': 'https://www.layogurteria.it/',
#     'name': 'La Yogurteria'}},
#   {'type': 'node',
#    'id': 12150438013,
#    'lat': 40.2740449,
#    'lon': 18.0457449,
#    'tags': {'amenity': 'cafe'}},
#   {'type': 'node',
#    'id': 12151379495,
#    'lat': 40.2715424,
#    'lon': 18.0490205,
#    'tags': {'amenity': 'cafe', 'name': 'Ciokko Cafè'}},
#   {'type': 'node',
#    'id': 12151379496,
#    'lat': 40.2721349,
#    'lon': 18.049052,
#    'tags': {'amenity': 'cafe', 'name': 'Central Bar'}},
#   {'type': 'node',
#    'id': 12151379499,
#    'lat': 40.274352,
#    'lon': 18.0451188,
#    'tags': {'amenity': 'cafe', 'name': 'Est Cafè 2'}},
#   {'type': 'node',
#    'id': 12151379500,
#    'lat': 40.2744451,
#    'lon': 18.0449002,
#    'tags': {'amenity': 'cafe', 'name': 'Bar Castello'}},
#   {'type': 'node',
#    'id': 12187479007,
#    'lat': 40.2728566,
#    'lon': -3.724793,
#    'tags': {'air_conditioning': 'yes',
#     'amenity': 'cafe',
#     'bar': 'yes',
#     'indoor': 'yes',
#     'indoor_seating': 'yes',
#     'internet_access': 'no',
#     'level': '0',
#     'name': 'Cafetería Servicios Centrales UPM',
#     'opening_hours': 'Mo-Fr 07:30-15:30; PH closed',
#     'outdoor_seating': 'yes',
#     'smoking': 'no',
#     'toilets': 'yes',
#     'toilets:access': 'customers',
#     'toilets:wheelchair': 'limited',
#     'wheelchair': 'limited'}},
#   {'type': 'node',
#    'id': 12211135802,
#    'lat': 40.2762356,
#    'lon': 22.5968922,
#    'tags': {'amenity': 'cafe',
#     'diet:vegan': 'yes',
#     'diet:vegetarian': 'yes',
#     'indoor_seating': 'no',
#     'name': 'By The Pool - cafe-bar restaurant',
#     'outdoor_seating': 'yes'}},
#   {'type': 'node',
#    'id': 12231733071,
#    'lat': 40.2730003,
#    'lon': -7.4996628,
#    'tags': {'access': 'permissive',
#     'addr:city': 'Covilhã',
#     'addr:housenumber': '3',
#     'addr:postcode': '6200-546',
#     'addr:street': 'Alameda da Europa',
#     'addr:unit': 'Rés de Chão Direito',
#     'amenity': 'cafe',
#     'door': 'sliding',
#     'entrance': 'main',
#     'name': 'Ramalha Alameda'}},
#   {'type': 'node',
#    'id': 12253738552,
#    'lat': 40.2798299,
#    'lon': -8.0185729,
#    'tags': {'amenity': 'cafe', 'name': 'Mota'}},
#   {'type': 'node',
#    'id': 12321074455,
#    'lat': 40.2713589,
#    'lon': -7.5017155,
#    'tags': {'amenity': 'cafe', 'name': 'Padaria da Ramalha'}},
#   {'type': 'node',
#    'id': 12324206616,
#    'lat': 40.2709502,
#    'lon': -7.5026253,
#    'tags': {'amenity': 'cafe', 'name': 'Quiosque Café'}},
#   {'type': 'node',
#    'id': 12361175102,
#    'lat': 40.2751311,
#    'lon': 65.1398198,
#    'tags': {'amenity': 'cafe', 'cuisine': 'local', 'name': 'Mehribon kafe'}},
#   {'type': 'node',
#    'id': 12361175201,
#    'lat': 40.276569,
#    'lon': 65.1359805,
#    'tags': {'amenity': 'cafe', 'name': 'Шашлык сомса'}},
#   {'type': 'node',
#    'id': 12361175301,
#    'lat': 40.2744737,
#    'lon': 65.1528741,
#    'tags': {'amenity': 'cafe'}},
#   {'type': 'node',
#    'id': 12435523605,
#    'lat': 40.2717095,
#    'lon': 22.5031936,
#    'tags': {'addr:city': 'Κατερίνη',
#     'addr:housenumber': '58',
#     'addr:postcode': '601 33',
#     'addr:street': 'Μεγάλου Αλεξάνδρου',
#     'amenity': 'cafe',
#     'name': 'The Coffee Road'}},
#   {'type': 'node',
#    'id': 12469267591,
#    'lat': 40.2765361,
#    'lon': -85.8420435,
#    'tags': {'amenity': 'cafe', 'name': 'Gypsy Soul'}},
#   {'type': 'node',
#    'id': 12479825456,
#    'lat': 40.2747277,
#    'lon': -111.6835606,
#    'tags': {'addr:city': 'Orem',
#     'addr:housenumber': '541',
#     'addr:postcode': '84097',
#     'addr:state': 'UT',
#     'addr:street': 'University Parkway',
#     'addr:unit': 'Suite C',
#     'amenity': 'cafe',
#     'cuisine': 'bubble_tea',
#     'name': 'Boba Luv',
#     'phone': '+1-801-225-4969',
#     'website': 'https://bobaluv.com/utah'}},
#   {'type': 'node',
#    'id': 12542289404,
#    'lat': 40.2774098,
#    'lon': 48.3495265,
#    'tags': {'amenity': 'cafe', 'name': 'Turist Kafe \\ Karrar'}},
#   {'type': 'node',
#    'id': 12826640106,
#    'lat': 40.2779766,
#    'lon': -8.0879235,
#    'tags': {'amenity': 'cafe', 'name': 'Locomotiva'}},
#   {'type': 'node',
#    'id': 12851989264,
#    'lat': 40.2717829,
#    'lon': -8.1507864,
#    'tags': {'amenity': 'cafe', 'name': 'São Martinho'}},
#   {'type': 'node',
#    'id': 13088971774,
#    'lat': 40.2730553,
#    'lon': 22.5054336,
#    'tags': {'addr:city': 'Κατερίνη',
#     'addr:housenumber': '19',
#     'addr:postcode': '601 33',
#     'addr:street': 'Ζαλόγγου',
#     'amenity': 'cafe',
#     'name': 'Umi'}},
#   {'type': 'node',
#    'id': 13111906549,
#    'lat': 40.27051,
#    'lon': 22.5069656,
#    'tags': {'addr:city': 'Κατερίνη',
#     'addr:housenumber': '3',
#     'addr:postcode': '601 32',
#     'addr:street': 'Παρθενίου Βαρδάκα',
#     'amenity': 'cafe',
#     'name': 'City Roasters'}},
#   {'type': 'node',
#    'id': 13141045459,
#    'lat': 40.2746685,
#    'lon': 15.6232042,
#    'tags': {'amenity': 'cafe', 'name': 'Bar Casale'}},
#   {'type': 'node',
#    'id': 13165627996,
#    'lat': 40.2748831,
#    'lon': -8.2671366,
#    'tags': {'amenity': 'cafe', 'name': 'Tricanto'}},
#   {'type': 'node',
#    'id': 13165627997,
#    'lat': 40.2755652,
#    'lon': -8.2670253,
#    'tags': {'amenity': 'cafe', 'name': 'Primavera'}},
#   {'type': 'node',
#    'id': 13165635809,
#    'lat': 40.2774045,
#    'lon': -8.2668919,
#    'tags': {'amenity': 'cafe', 'name': 'Silva'}},
#   {'type': 'node',
#    'id': 13165635810,
#    'lat': 40.2784831,
#    'lon': -8.2668694,
#    'tags': {'amenity': 'cafe', 'name': 'Café Petisqueira Conceição'}},
#   {'type': 'node',
#    'id': 13168354403,
#    'lat': 40.2702192,
#    'lon': 22.512051,
#    'tags': {'amenity': 'cafe'}}]}

# %%
def json_to_dataframe(data_entrada):
    elements = data_entrada['elements']
    places = {'lat': [], 'lon': [], 'name': [], 'address': []}

    for i in elements:
        lalitude = i['lat']
        longitude = i['lon']
        name = i['tags'].get('name')
        street = i['tags'].get('addr:street', 'Sin calle')
        number = i['tags'].get('addr:housenumber', 0)
        
        places['lat'].append(lalitude)
        places['lon'].append(longitude)
        places['name'].append(name)
        places['address'].append(str(street) + ' ' + str(number))

    df = pd.DataFrame(places)
    
    return df

# %%
df_return = json_to_dataframe(data)
df_return
# Out:
#            lat        lon                        name                  address
# 0    40.277033 -76.824138                   Starbucks  Union Deposit Road 3901
# 1    40.277434  69.630031                Дустмухаммад              Sin calle 0
# 2    40.273188  -7.496439                        None              Sin calle 0
# 3    40.279547  65.137487                        None              Sin calle 0
# 4    40.270639  22.508351                     Kartell  Γεωργάκη Ολυμπίου 10-12
# ..         ...        ...                         ...                      ...
# 162  40.274883  -8.267137                    Tricanto              Sin calle 0
# 163  40.275565  -8.267025                   Primavera              Sin calle 0
# 164  40.277405  -8.266892                       Silva              Sin calle 0
# 165  40.278483  -8.266869  Café Petisqueira Conceição              Sin calle 0
# 166  40.270219  22.512051                        None              Sin calle 0
#
# [167 rows x 4 columns]

# %%
# lista_responses = [data1, data2, data3, data4]
# for data in lista_responses:
#     df_return = json_to_dataframe(data)
#     df_results = df_results.concat(df_return)

# %% [markdown]
# ## Datos del espacio

# %%
'''
https://thespacedevs.com/llapi
https://ll.thespacedevs.com/2.2.0/swagger
'''

space_url = "http://ll.thespacedevs.com/2.2.0"

path = "/astronaut"

url_total = space_url + path

response = requests.get(url_total)

# %%
print(response)
response.json()
# Out:
# <Response [200]>
# {'count': 828,
#  'next': 'https://ll.thespacedevs.com/2.2.0/astronaut/?limit=10&offset=10',
#  'previous': None,
#  'results': [{'id': 1,
#    'url': 'https://ll.thespacedevs.com/2.2.0/astronaut/1/',
#    'name': 'Thomas Pesquet',
#    'status': {'id': 1, 'name': 'Active'},
#    'type': {'id': 2, 'name': 'Government'},
#    'in_space': False,
#    'time_in_space': 'P396DT11H33M45S',
#    'eva_time': 'P1DT15H54M',
#    'age': 47,
#    'date_of_birth': '1978-02-27',
#    'date_of_death': None,
#    'nationality': 'French',
#    'bio': 'Thomas Gautier Pesquet is a French aerospace engineer, pilot, and European Space Agency astronaut. Pesquet was selected by ESA as a candidate in May 2009, and he successfully completed his basic training in November 2010. From November 2016 to June 2017, Pesquet was part of Expeditions 50 and 51 on the International Space Station as a flight engineer.',
#    'twitter': 'https://twitter.com/Thom_astro',
#    'instagram': 'https://instagram.com/thom_astro',
#    'wiki': 'https://en.wikipedia.org/wiki/Thomas_Pesquet',
#    'agency': {'id': 27,
#     'url': 'https://ll.thespacedevs.com/2.2.0/agencies/27/',
#     'name': 'European Space Agency',
#     'featured': False,
#     'type': 'Multinational',
#     'country_code': 'FRA,ITA,DEU,ESP,CHE,GBR,AUT,SWE,PRT,NLD,HUN,POL,DNK,CZE,ROU,NOR,FIN,GRC,EST,IRL,LUX,BEL,SVN',
#     'abbrev': 'ESA',
#     'description': "The European Space Agency is an intergovernmental organisation of 22 member states. Established in 1975 and headquartered in Paris, France, ESA has a worldwide staff of about 2,000 employees.\r\n\r\nESA's space flight programme includes human spaceflight (mainly through participation in the International Space Station program); the launch and operation of unmanned exploration missions to other planets and the Moon; Earth observation, science and telecommunication; designing launch vehicles; and maintaining a major spaceport, the Guiana Space Centre at Kourou, French Guiana.",
#     'administrator': 'Director General: Josef Aschbacher',
#     'founding_year': '1975',
#     'launchers': 'Ariane | Vega',
#     'spacecraft': 'Space Rider',
#     'parent': None,
#     'image_url': 'https://thespacedevs-prod.nyc3.digitaloceanspaces.com/media/images/esa_patch_float_image_20250211192109.png',
#     'logo_url': 'https://thespacedevs-prod.nyc3.digitaloceanspaces.com/media/images/european2520space2520agency_logo_20221130101442.png'},
#    'profile_image': 'https://thespacedevs-prod.nyc3.digitaloceanspaces.com/media/images/thomas2520pesquet_image_20200102120546.jpeg',
#    'profile_image_thumbnail': 'https://thespacedevs-prod.nyc3.digitaloceanspaces.com/media/images/255bauto255d__image_thumbnail_20240305190357.jpeg',
#    'flights_count': 2,
#    'landings_count': 2,
#    'spacewalks_count': 6,
#    'last_flight': '2021-04-23T09:49:02Z',
#    'first_flight': '2016-11-17T20:20:13Z'},
#   {'id': 2,
#    'url': 'https://ll.thespacedevs.com/2.2.0/astronaut/2/',
#    'name': 'Claude Nicollier',
#    'status': {'id': 2, 'name': 'Retired'},
#    'type': {'id': 2, 'name': 'Government'},
#    'in_space': False,
#    'time_in_space': 'P42DT12H3M12S',
#    'eva_time': 'PT8H10M',
#    'age': 81,
#    'date_of_birth': '1944-09-02',
#    'date_of_death': None,
#    'nationality': 'Swiss',
#    'bio': 'Claude Nicollier is the first astronaut from Switzerland. He has flown on four Space Shuttle missions. His first spaceflight (STS-46) was in 1992, and his final spaceflight (STS-103) was in 1999. He took part in two servicing missions to the Hubble Space Telescope (called STS-61 and STS-103). During his final spaceflight he participated in a spacewalk, becoming the first European Space Agency astronaut to do so during a Space Shuttle mission. In 2000 he was assigned to the Astronaut Office Extravehicular Activity Branch, while maintaining a position as Lead ESA Astronaut in Houston. Nicollier retired from ESA in April 2007.',
#    'twitter': 'https://twitter.com/Astroclaude',
#    'instagram': None,
#    'wiki': 'https://en.wikipedia.org/wiki/Claude_Nicollier',
#    'agency': {'id': 27,
#     'url': 'https://ll.thespacedevs.com/2.2.0/agencies/27/',
#     'name': 'European Space Agency',
#     'featured': False,
#     'type': 'Multinational',
#     'country_code': 'FRA,ITA,DEU,ESP,CHE,GBR,AUT,SWE,PRT,NLD,HUN,POL,DNK,CZE,ROU,NOR,FIN,GRC,EST,IRL,LUX,BEL,SVN',
#     'abbrev': 'ESA',
#     'description': "The European Space Agency is an intergovernmental organisation of 22 member states. Established in 1975 and headquartered in Paris, France, ESA has a worldwide staff of about 2,000 employees.\r\n\r\nESA's space flight programme includes human spaceflight (mainly through participation in the International Space Station program); the launch and operation of unmanned exploration missions to other planets and the Moon; Earth observation, science and telecommunication; designing launch vehicles; and maintaining a major spaceport, the Guiana Space Centre at Kourou, French Guiana.",
#     'administrator': 'Director General: Josef Aschbacher',
#     'founding_year': '1975',
#     'launchers': 'Ariane | Vega',
#     'spacecraft': 'Space Rider',
#     'parent': None,
#     'image_url': 'https://thespacedevs-prod.nyc3.digitaloceanspaces.com/media/images/esa_patch_float_image_20250211192109.png',
#     'logo_url': 'https://thespacedevs-prod.nyc3.digitaloceanspaces.com/media/images/european2520space2520agency_logo_20221130101442.png'},
#    'profile_image': 'https://thespacedevs-prod.nyc3.digitaloceanspaces.com/media/images/claude2520nicollier_image_20181127203218.jpg',
#    'profile_image_thumbnail': 'https://thespacedevs-prod.nyc3.digitaloceanspaces.com/media/images/255bauto255d__image_thumbnail_20240305185551.jpeg',
#    'flights_count': 4,
#    'landings_count': 4,
#    'spacewalks_count': 1,
#    'last_flight': '1999-12-20T00:50:00Z',
#    'first_flight': '1992-07-31T13:56:48Z'},
#   {'id': 3,
#    'url': 'https://ll.thespacedevs.com/2.2.0/astronaut/3/',
#    'name': 'Tim Peake',
#    'status': {'id': 2, 'name': 'Retired'},
#    'type': {'id': 2, 'name': 'Government'},
#    'in_space': False,
#    'time_in_space': 'P185DT22H11M51S',
#    'eva_time': 'PT4H43M',
#    'age': 53,
#    'date_of_birth': '1972-04-07',
#    'date_of_death': None,
#    'nationality': 'British',
#    'bio': "Major Timothy Nigel Peake CMG is a British Army Air Corps officer, former European Space Agency astronaut and International Space Station (ISS) crew member.  He is the first British ESA astronaut, the second astronaut to bear a flag of the United Kingdom patch, the sixth person born in the United Kingdom to go on board the International Space Station and the seventh UK-born person in space. He began the ESA's intensive astronaut basic training course in September 2009 and graduated on 22 November 2010",
#    'twitter': 'https://twitter.com/astro_timpeake',
#    'instagram': 'https://www.instagram.com/astro_timpeake/',
#    'wiki': 'https://en.wikipedia.org/wiki/Tim_Peake',
#    'agency': {'id': 27,
#     'url': 'https://ll.thespacedevs.com/2.2.0/agencies/27/',
#     'name': 'European Space Agency',
#     'featured': False,
#     'type': 'Multinational',
#     'country_code': 'FRA,ITA,DEU,ESP,CHE,GBR,AUT,SWE,PRT,NLD,HUN,POL,DNK,CZE,ROU,NOR,FIN,GRC,EST,IRL,LUX,BEL,SVN',
#     'abbrev': 'ESA',
#     'description': "The European Space Agency is an intergovernmental organisation of 22 member states. Established in 1975 and headquartered in Paris, France, ESA has a worldwide staff of about 2,000 employees.\r\n\r\nESA's space flight programme includes human spaceflight (mainly through participation in the International Space Station program); the launch and operation of unmanned exploration missions to other planets and the Moon; Earth observation, science and telecommunication; designing launch vehicles; and maintaining a major spaceport, the Guiana Space Centre at Kourou, French Guiana.",
#     'administrator': 'Director General: Josef Aschbacher',
#     'founding_year': '1975',
#     'launchers': 'Ariane | Vega',
#     'spacecraft': 'Space Rider',
#     'parent': None,
#     'image_url': 'https://thespacedevs-prod.nyc3.digitaloceanspaces.com/media/images/esa_patch_float_image_20250211192109.png',
#     'logo_url': 'https://thespacedevs-prod.nyc3.digitaloceanspaces.com/media/images/european2520space2520agency_logo_20221130101442.png'},
#    'profile_image': 'https://thespacedevs-prod.nyc3.digitaloceanspaces.com/media/images/tim_peake_image_20230120154350.jpg',
#    'profile_image_thumbnail': 'https://thespacedevs-prod.nyc3.digitaloceanspaces.com/media/images/255bauto255d__image_thumbnail_20240305185843.jpeg',
#    'flights_count': 1,
#    'landings_count': 1,
#    'spacewalks_count': 1,
#    'last_flight': '2015-12-15T11:03:09Z',
#    'first_flight': '2015-12-15T11:03:09Z'},
#   {'id': 4,
#    'url': 'https://ll.thespacedevs.com/2.2.0/astronaut/4/',
#    'name': 'Buzz Aldrin',
#    'status': {'id': 2, 'name': 'Retired'},
#    'type': {'id': 2, 'name': 'Government'},
#    'in_space': False,
#    'time_in_space': 'P9DT8H43M58S',
#    'eva_time': 'PT8H1M40S',
#    'age': 95,
#    'date_of_birth': '1930-01-20',
#    'date_of_death': None,
#    'nationality': 'American',
#    'bio': 'Buzz Aldrin; born Edwin Eugene Aldrin Jr.; is an American engineer, former astronaut, and fighter pilot.\r\nAs Lunar Module Pilot on the Apollo 11 mission, he and mission commander Neil Armstrong were the first two humans to land on the Moon.',
#    'twitter': 'https://twitter.com/TheRealBuzz',
#    'instagram': 'https://www.instagram.com/drbuzzaldrin/',
#    'wiki': 'https://en.wikipedia.org/wiki/Buzz_Aldrin',
#    'agency': {'id': 44,
#     'url': 'https://ll.thespacedevs.com/2.2.0/agencies/44/',
#     'name': 'National Aeronautics and Space Administration',
#     'featured': True,
#     'type': 'Government',
#     'country_code': 'USA',
#     'abbrev': 'NASA',
#     'description': 'The National Aeronautics and Space Administration is an independent agency of the executive branch of the United States federal government responsible for the civilian space program, as well as aeronautics and aerospace research. NASA have many launch facilities but most are inactive. The most commonly used pad will be LC-39B at Kennedy Space Center in Florida.',
#     'administrator': 'Acting Administrator:  James Free',
#     'founding_year': '1958',
#     'launchers': 'Space Shuttle | SLS',
#     'spacecraft': 'Orion',
#     'parent': None,
#     'image_url': 'https://thespacedevs-prod.nyc3.digitaloceanspaces.com/media/images/national2520aeronautics2520and2520space2520administration_image_20190207032448.jpeg',
#     'logo_url': 'https://thespacedevs-prod.nyc3.digitaloceanspaces.com/media/images/national2520aeronautics2520and2520space2520administration_logo_20190207032448.png'},
#    'profile_image': 'https://thespacedevs-prod.nyc3.digitaloceanspaces.com/media/images/buzz_aldrin_image_20220911034547.jpeg',
#    'profile_image_thumbnail': 'https://thespacedevs-prod.nyc3.digitaloceanspaces.com/media/images/255bauto255d__image_thumbnail_20240305185225.jpeg',
#    'flights_count': 2,
#    'landings_count': 2,
#    'spacewalks_count': 4,
#    'last_flight': '1969-07-21T17:54:00Z',
#    'first_flight': '1966-11-11T20:46:33Z'},
#   {'id': 5,
#    'url': 'https://ll.thespacedevs.com/2.2.0/astronaut/5/',
#    'name': 'Chris Hadfield',
#    'status': {'id': 2, 'name': 'Retired'},
#    'type': {'id': 2, 'name': 'Government'},
#    'in_space': False,
#    'time_in_space': 'P165DT16H19M',
#    'eva_time': 'PT14H50M',
#    'age': 66,
#    'date_of_birth': '1959-08-29',
#    'date_of_death': None,
#    'nationality': 'Canadian',
#    'bio': 'Chris Austin Hadfield is a Canadian retired astronaut, engineer, and former Royal Canadian Air Force fighter pilot.\r\nThe first Canadian to walk in space, Hadfield has flown two space shuttle missions and served as commander of the International Space Station.',
#    'twitter': 'https://twitter.com/Cmdr_Hadfield',
#    'instagram': 'https://www.instagram.com/colchrishadfield/',
#    'wiki': 'https://en.wikipedia.org/wiki/Chris_Hadfield',
#    'agency': {'id': 16,
#     'url': 'https://ll.thespacedevs.com/2.2.0/agencies/16/',
#     'name': 'Canadian Space Agency',
#     'featured': False,
#     'type': 'Government',
#     'country_code': 'CAN',
#     'abbrev': 'CSA',
#     'description': 'The Canadian Space Agency was established by the Canadian Space Agency Act which received Royal Assent on May 10, 1990. \r\n\r\nThe Canadian space program is administered by the Canadian Space Agency. Canada has contributed technology, expertise and personnel to the world space effort, especially in collaboration with ESA and NASA. In addition to its astronauts and satellites, some of the most notable Canadian technological contributions to space exploration include the Canadarm on the Space Shuttle and Canadarm2 on the International Space Station.',
#     'administrator': 'President: Lisa Campbell',
#     'founding_year': '1990',
#     'launchers': '',
#     'spacecraft': '',
#     'parent': None,
#     'image_url': None,
#     'logo_url': 'https://thespacedevs-prod.nyc3.digitaloceanspaces.com/media/images/canadian2520space2520agency_logo_20231122160211.png'},
#    'profile_image': 'https://thespacedevs-prod.nyc3.digitaloceanspaces.com/media/images/chris_hadfield_image_20220911034200.jpeg',
#    'profile_image_thumbnail': 'https://thespacedevs-prod.nyc3.digitaloceanspaces.com/media/images/255bauto255d__image_thumbnail_20240305190208.jpeg',
#    'flights_count': 3,
#    'landings_count': 3,
#    'spacewalks_count': 2,
#    'last_flight': '2012-12-19T12:12:35Z',
#    'first_flight': '1995-11-12T12:30:43Z'},
#   {'id': 6,
#    'url': 'https://ll.thespacedevs.com/2.2.0/astronaut/6/',
#    'name': 'David Saint-Jacques',
#    'status': {'id': 1, 'name': 'Active'},
#    'type': {'id': 2, 'name': 'Government'},
#    'in_space': False,
#    'time_in_space': 'P203DT12H28M8S',
#    'eva_time': 'PT6H29M',
#    'age': 55,
#    'date_of_birth': '1970-01-06',
#    'date_of_death': None,
#    'nationality': 'Canadian',
#    'bio': 'David Saint-Jacques is a Canadian astronaut with the Canadian Space Agency (CSA).\r\nHe was also an engineer, an astrophysicist, and a physician prior to joining the CSA.\r\nHe was selected to join the CSA in the 2009 CSA selection along with Jeremy Hansen.',
#    'twitter': 'https://twitter.com/Astro_DavidS',
#    'instagram': 'https://www.instagram.com/astrodavids/',
#    'wiki': 'https://en.wikipedia.org/wiki/David_Saint-Jacques',
#    'agency': {'id': 16,
#     'url': 'https://ll.thespacedevs.com/2.2.0/agencies/16/',
#     'name': 'Canadian Space Agency',
#     'featured': False,
#     'type': 'Government',
#     'country_code': 'CAN',
#     'abbrev': 'CSA',
#     'description': 'The Canadian Space Agency was established by the Canadian Space Agency Act which received Royal Assent on May 10, 1990. \r\n\r\nThe Canadian space program is administered by the Canadian Space Agency. Canada has contributed technology, expertise and personnel to the world space effort, especially in collaboration with ESA and NASA. In addition to its astronauts and satellites, some of the most notable Canadian technological contributions to space exploration include the Canadarm on the Space Shuttle and Canadarm2 on the International Space Station.',
#     'administrator': 'President: Lisa Campbell',
#     'founding_year': '1990',
#     'launchers': '',
#     'spacecraft': '',
#     'parent': None,
#     'image_url': None,
#     'logo_url': 'https://thespacedevs-prod.nyc3.digitaloceanspaces.com/media/images/canadian2520space2520agency_logo_20231122160211.png'},
#    'profile_image': 'https://thespacedevs-prod.nyc3.digitaloceanspaces.com/media/images/david_saint-jac_image_20220911034207.jpeg',
#    'profile_image_thumbnail': 'https://thespacedevs-prod.nyc3.digitaloceanspaces.com/media/images/255bauto255d__image_thumbnail_20240305191004.jpeg',
#    'flights_count': 1,
#    'landings_count': 1,
#    'spacewalks_count': 1,
#    'last_flight': '2018-12-03T11:31:52Z',
#    'first_flight': '2018-12-03T11:31:52Z'},
#   {'id': 7,
#    'url': 'https://ll.thespacedevs.com/2.2.0/astronaut/7/',
#    'name': 'Anne McClain',
#    'status': {'id': 1, 'name': 'Active'},
#    'type': {'id': 2, 'name': 'Government'},
#    'in_space': False,
#    'time_in_space': 'P351DT4H57M40S',
#    'eva_time': 'PT18H52M',
#    'age': 46,
#    'date_of_birth': '1979-06-07',
#    'date_of_death': None,
#    'nationality': 'American',
#    'bio': 'Anne Charlotte McClain is a lieutenant colonel in the U.S. Army currently assigned to NASA Astronaut Group 21.',
#    'twitter': 'https://twitter.com/AstroAnnimal',
#    'instagram': None,
#    'wiki': 'https://en.wikipedia.org/wiki/Anne_McClain',
#    'agency': {'id': 44,
#     'url': 'https://ll.thespacedevs.com/2.2.0/agencies/44/',
#     'name': 'National Aeronautics and Space Administration',
#     'featured': True,
#     'type': 'Government',
#     'country_code': 'USA',
#     'abbrev': 'NASA',
#     'description': 'The National Aeronautics and Space Administration is an independent agency of the executive branch of the United States federal government responsible for the civilian space program, as well as aeronautics and aerospace research. NASA have many launch facilities but most are inactive. The most commonly used pad will be LC-39B at Kennedy Space Center in Florida.',
#     'administrator': 'Acting Administrator:  James Free',
#     'founding_year': '1958',
#     'launchers': 'Space Shuttle | SLS',
#     'spacecraft': 'Orion',
#     'parent': None,
#     'image_url': 'https://thespacedevs-prod.nyc3.digitaloceanspaces.com/media/images/national2520aeronautics2520and2520space2520administration_image_20190207032448.jpeg',
#     'logo_url': 'https://thespacedevs-prod.nyc3.digitaloceanspaces.com/media/images/national2520aeronautics2520and2520space2520administration_logo_20190207032448.png'},
#    'profile_image': 'https://thespacedevs-prod.nyc3.digitaloceanspaces.com/media/images/anne2520mcclain_image_20181127210625.jpg',
#    'profile_image_thumbnail': 'https://thespacedevs-prod.nyc3.digitaloceanspaces.com/media/images/255bauto255d__image_thumbnail_20240305185442.jpeg',
#    'flights_count': 2,
#    'landings_count': 2,
#    'spacewalks_count': 3,
#    'last_flight': '2025-03-14T23:03:48Z',
#    'first_flight': '2018-12-03T11:31:52Z'},
#   {'id': 8,
#    'url': 'https://ll.thespacedevs.com/2.2.0/astronaut/8/',
#    'name': 'Andrew R. Morgan',
#    'status': {'id': 1, 'name': 'Active'},
#    'type': {'id': 2, 'name': 'Government'},
#    'in_space': False,
#    'time_in_space': 'P271DT12H48M22S',
#    'eva_time': 'P1DT21H48M',
#    'age': 49,
#    'date_of_birth': '1976-02-05',
#    'date_of_death': None,
#    'nationality': 'American',
#    'bio': 'Andrew Richard "Drew" Morgan is a NASA astronaut from the class of 2013.',
#    'twitter': 'https://twitter.com/AstroDrewMorgan',
#    'instagram': 'https://www.instagram.com/astrodrewmorgan/',
#    'wiki': 'https://en.wikipedia.org/wiki/Andrew_R._Morgan',
#    'agency': {'id': 44,
#     'url': 'https://ll.thespacedevs.com/2.2.0/agencies/44/',
#     'name': 'National Aeronautics and Space Administration',
#     'featured': True,
#     'type': 'Government',
#     'country_code': 'USA',
#     'abbrev': 'NASA',
#     'description': 'The National Aeronautics and Space Administration is an independent agency of the executive branch of the United States federal government responsible for the civilian space program, as well as aeronautics and aerospace research. NASA have many launch facilities but most are inactive. The most commonly used pad will be LC-39B at Kennedy Space Center in Florida.',
#     'administrator': 'Acting Administrator:  James Free',
#     'founding_year': '1958',
#     'launchers': 'Space Shuttle | SLS',
#     'spacecraft': 'Orion',
#     'parent': None,
#     'image_url': 'https://thespacedevs-prod.nyc3.digitaloceanspaces.com/media/images/national2520aeronautics2520and2520space2520administration_image_20190207032448.jpeg',
#     'logo_url': 'https://thespacedevs-prod.nyc3.digitaloceanspaces.com/media/images/national2520aeronautics2520and2520space2520administration_logo_20190207032448.png'},
#    'profile_image': 'https://thespacedevs-prod.nyc3.digitaloceanspaces.com/media/images/andrew_r._morga_image_20220911034204.jpeg',
#    'profile_image_thumbnail': 'https://thespacedevs-prod.nyc3.digitaloceanspaces.com/media/images/255bauto255d__image_thumbnail_20240305185549.jpeg',
#    'flights_count': 1,
#    'landings_count': 1,
#    'spacewalks_count': 7,
#    'last_flight': '2019-07-20T16:28:21Z',
#    'first_flight': '2019-07-20T16:28:21Z'},
#   {'id': 9,
#    'url': 'https://ll.thespacedevs.com/2.2.0/astronaut/9/',
#    'name': 'Nick Hague',
#    'status': {'id': 1, 'name': 'Active'},
#    'type': {'id': 2, 'name': 'Government'},
#    'in_space': False,
#    'time_in_space': 'P373DT20H43M16S',
#    'eva_time': 'P1DT1H56M',
#    'age': 50,
#    'date_of_birth': '1975-09-24',
#    'date_of_death': None,
#    'nationality': 'American',
#    'bio': 'Tyler Nicklaus Hague is an American Flight Test Engineer and a NASA astronaut of the class of 2013.\r\nSelected to be a flight engineer of Expedition 57 / 58 to the International Space Station, he launched on board Soyuz MS-10, which aborted shortly after launch on October 11, 2018.',
#    'twitter': 'https://twitter.com/AstroHague',
#    'instagram': 'https://www.instagram.com/astrohague/',
#    'wiki': 'https://en.wikipedia.org/wiki/Nick_Hague',
#    'agency': {'id': 44,
#     'url': 'https://ll.thespacedevs.com/2.2.0/agencies/44/',
#     'name': 'National Aeronautics and Space Administration',
#     'featured': True,
#     'type': 'Government',
#     'country_code': 'USA',
#     'abbrev': 'NASA',
#     'description': 'The National Aeronautics and Space Administration is an independent agency of the executive branch of the United States federal government responsible for the civilian space program, as well as aeronautics and aerospace research. NASA have many launch facilities but most are inactive. The most commonly used pad will be LC-39B at Kennedy Space Center in Florida.',
#     'administrator': 'Acting Administrator:  James Free',
#     'founding_year': '1958',
#     'launchers': 'Space Shuttle | SLS',
#     'spacecraft': 'Orion',
#     'parent': None,
#     'image_url': 'https://thespacedevs-prod.nyc3.digitaloceanspaces.com/media/images/national2520aeronautics2520and2520space2520administration_image_20190207032448.jpeg',
#     'logo_url': 'https://thespacedevs-prod.nyc3.digitaloceanspaces.com/media/images/national2520aeronautics2520and2520space2520administration_logo_20190207032448.png'},
#    'profile_image': 'https://thespacedevs-prod.nyc3.digitaloceanspaces.com/media/images/nick_hague_image_20220911034312.jpeg',
#    'profile_image_thumbnail': 'https://thespacedevs-prod.nyc3.digitaloceanspaces.com/media/images/255bauto255d__image_thumbnail_20240305190648.jpeg',
#    'flights_count': 3,
#    'landings_count': 3,
#    'spacewalks_count': 4,
#    'last_flight': '2024-09-28T17:17:21Z',
#    'first_flight': '2018-10-11T08:40:15Z'},
#   {'id': 10,
#    'url': 'https://ll.thespacedevs.com/2.2.0/astronaut/10/',
#    'name': 'Terry W. Virts',
#    'status': {'id': 2, 'name': 'Retired'},
#    'type': {'id': 2, 'name': 'Government'},
#    'in_space': False,
#    'time_in_space': 'P213DT10H50M38S',
#    'eva_time': 'PT19H2M',
#    'age': 57,
#    'date_of_birth': '1967-12-01',
#    'date_of_death': None,
#    'nationality': 'American',
#    'bio': 'Terry W. Virts Jr. is a former NASA astronaut, and Colonel in the United States Air Force.',
#    'twitter': 'https://twitter.com/AstroTerry',
#    'instagram': 'https://www.instagram.com/astro_terry/',
#    'wiki': 'https://en.wikipedia.org/wiki/Terry_W._Virts',
#    'agency': {'id': 44,
#     'url': 'https://ll.thespacedevs.com/2.2.0/agencies/44/',
#     'name': 'National Aeronautics and Space Administration',
#     'featured': True,
#     'type': 'Government',
#     'country_code': 'USA',
#     'abbrev': 'NASA',
#     'description': 'The National Aeronautics and Space Administration is an independent agency of the executive branch of the United States federal government responsible for the civilian space program, as well as aeronautics and aerospace research. NASA have many launch facilities but most are inactive. The most commonly used pad will be LC-39B at Kennedy Space Center in Florida.',
#     'administrator': 'Acting Administrator:  James Free',
#     'founding_year': '1958',
#     'launchers': 'Space Shuttle | SLS',
#     'spacecraft': 'Orion',
#     'parent': None,
#     'image_url': 'https://thespacedevs-prod.nyc3.digitaloceanspaces.com/media/images/national2520aeronautics2520and2520space2520administration_image_20190207032448.jpeg',
#     'logo_url': 'https://thespacedevs-prod.nyc3.digitaloceanspaces.com/media/images/national2520aeronautics2520and2520space2520administration_logo_20190207032448.png'},
#    'profile_image': 'https://thespacedevs-prod.nyc3.digitaloceanspaces.com/media/images/terry_w._virts_image_20220911033815.jpeg',
#    'profile_image_thumbnail': 'https://thespacedevs-prod.nyc3.digitaloceanspaces.com/media/images/255bauto255d__image_thumbnail_20240305190900.jpeg',
#    'flights_count': 2,
#    'landings_count': 2,
#    'spacewalks_count': 3,
#    'last_flight': '2014-11-23T21:01:14Z',
#    'first_flight': '2010-02-08T09:14:08Z'}]}

# %%
url_total
# Out:
# 'http://ll.thespacedevs.com/2.2.0/astronaut'

# %%
url_total = space_url + path + "/?search=armstrong"
responder = requests.get(url_total)

# %%
url_total
# Out:
# 'http://ll.thespacedevs.com/2.2.0/astronaut/?search=armstrong'

# %%
responder.json()
# Out:
# {'count': 1,
#  'next': None,
#  'previous': None,
#  'results': [{'id': 30,
#    'url': 'https://ll.thespacedevs.com/2.2.0/astronaut/30/',
#    'name': 'Neil Armstrong',
#    'status': {'id': 11, 'name': 'Deceased'},
#    'type': {'id': 2, 'name': 'Government'},
#    'in_space': False,
#    'time_in_space': 'P5DT20H50M29S',
#    'eva_time': 'PT2H31M40S',
#    'age': 82,
#    'date_of_birth': '1930-08-05',
#    'date_of_death': '2012-08-25',
#    'nationality': 'American',
#    'bio': 'Neil Alden Armstrong was an American astronaut and aeronautical engineer who was the first person to walk on the Moon. He was also a naval aviator, test pilot, and university professor.',
#    'twitter': None,
#    'instagram': None,
#    'wiki': 'https://en.wikipedia.org/wiki/Neil_Armstrong',
#    'agency': {'id': 44,
#     'url': 'https://ll.thespacedevs.com/2.2.0/agencies/44/',
#     'name': 'National Aeronautics and Space Administration',
#     'featured': True,
#     'type': 'Government',
#     'country_code': 'USA',
#     'abbrev': 'NASA',
#     'description': 'The National Aeronautics and Space Administration is an independent agency of the executive branch of the United States federal government responsible for the civilian space program, as well as aeronautics and aerospace research. NASA have many launch facilities but most are inactive. The most commonly used pad will be LC-39B at Kennedy Space Center in Florida.',
#     'administrator': 'Acting Administrator:  James Free',
#     'founding_year': '1958',
#     'launchers': 'Space Shuttle | SLS',
#     'spacecraft': 'Orion',
#     'parent': None,
#     'image_url': 'https://thespacedevs-prod.nyc3.digitaloceanspaces.com/media/images/national2520aeronautics2520and2520space2520administration_image_20190207032448.jpeg',
#     'logo_url': 'https://thespacedevs-prod.nyc3.digitaloceanspaces.com/media/images/national2520aeronautics2520and2520space2520administration_logo_20190207032448.png'},
#    'profile_image': 'https://thespacedevs-prod.nyc3.digitaloceanspaces.com/media/images/neil2520armstrong_image_20190426143653.jpeg',
#    'profile_image_thumbnail': 'https://thespacedevs-prod.nyc3.digitaloceanspaces.com/media/images/255bauto255d__image_thumbnail_20240305190707.jpeg',
#    'flights_count': 2,
#    'landings_count': 2,
#    'spacewalks_count': 1,
#    'last_flight': '1969-07-21T17:54:00Z',
#    'first_flight': '1966-03-16T16:41:02Z'}]}

# %% [markdown]
# ## Accediendo a datos de themoviedb

# %% [markdown]
# Libreria tmdv3api

# %%
#!pip install tmdbv3api

# %%
# https://developers.themoviedb.org/3/getting-started/introduction
from tmdbv3api import TMDb
tmdb = TMDb()
tmdb.api_key = "api_key"

# %%
from tmdbv3api import Movie

#https://github.com/AnthonyBloomer/tmdbv3api

movie = Movie()

recommendations = movie.recommendations(movie_id=111)

for recommendation in recommendations:
    print(recommendation.title)
    print(recommendation.overview)
# Out:
# The Untouchables
# Elliot Ness, an ambitious prohibition agent, is determined to take down Al Capone. In order to achieve this goal, he forms a group given the nickname “The Untouchables”.
# Carlito's Way
# Free after years in prison, Carlito Brigante intends to give up his criminal ways, but it's not long before the ex-con is sucked back into the New York City underworld. Reconnecting with his dancer girlfriend, Carlito gets entangled in the shady dealings of his friend Dave Kleinfeld, who also serves as his lawyer. An encounter with shifty gangster Benny Blanco sets the duo on a dangerous path.
# Reservoir Dogs
# A botched robbery indicates a police informant, and the pressure mounts in the aftermath at a warehouse. Crime begets violence as the survivors -- veteran Mr. White, newcomer Mr. Orange, psychopathic parolee Mr. Blonde, bickering weasel Mr. Pink and Nice Guy Eddie -- unravel.
# Heat
# Obsessive master thief Neil McCauley leads a top-notch crew on various daring heists throughout Los Angeles while determined detective Vincent Hanna pursues him without rest. Each man recognizes and respects the ability and the dedication of the other even though they are aware their cat-and-mouse game may end in violence.
# The Darjeeling Limited
# Three American brothers who have not spoken to each other in a year set off on a train voyage across India with a plan to find themselves and bond with each other -- to become brothers again like they used to be. Their "spiritual quest", however, veers rapidly off-course (due to events involving over-the-counter pain killers, Indian cough syrup, and pepper spray).
# Apocalypse Now
# At the height of the Vietnam war, Captain Benjamin Willard is sent on a dangerous mission that, officially, "does not exist, nor will it ever exist." His goal is to locate - and eliminate - a mysterious Green Beret Colonel named Walter Kurtz, who has been leading his personal army on illegal guerrilla missions into enemy territory.
# Blade Runner
# In the smog-choked dystopian Los Angeles of 2019, blade runner Rick Deckard is called out of retirement to terminate a quartet of replicants who have escaped to Earth seeking their creator for a way to extend their short life spans.
# GoodFellas
# The true story of Henry Hill, a half-Irish, half-Sicilian Brooklyn kid who is adopted by neighbourhood gangsters at an early age and climbs the ranks of a Mafia family under the guidance of Jimmy Conway.
# V for Vendetta
# In a world in which Great Britain has become a fascist state, a masked vigilante known only as “V” conducts guerrilla warfare against the oppressive British government. When V rescues a young woman from the secret police, he finds in her an ally with whom he can continue his fight to free the people of Britain.
# Taxi Driver
# Suffering from insomnia, disturbed loner Travis Bickle takes a job as a New York City cabbie, haunting the streets nightly, growing increasingly detached from reality as he dreams of cleaning up the filthy city.
# Ferris Bueller's Day Off
# After high school slacker Ferris Bueller successfully fakes an illness in order to skip school for the day, he goes on a series of adventures throughout Chicago with his girlfriend Sloane and best friend Cameron, all the while trying to outwit his wily school principal and fed-up sister.
# Vertigo
# A retired San Francisco detective suffering from acrophobia investigates the strange activities of an old friend's wife, all the while becoming dangerously obsessed with her.
# The Departed
# To take down South Boston's Irish Mafia, the police send in one of their own to infiltrate the underworld, not realizing the syndicate has done likewise. While an undercover cop curries favor with the mob kingpin, a career criminal rises through the police ranks. But both sides soon discover there's a mole among them.
# Donnie Brasco
# An FBI undercover agent infiltrates the mob and identifies more with the mafia life at the expense of his regular one.
# Angel Heart
# A down-and-out Brooklyn detective is hired to track down a singer on an odyssey that will take him through the desperate streets of Harlem, the smoke-filled jazz clubs of New Orleans, and the swamps of Louisiana and its seedy underworld of voodoo.
# The Godfather
# Spanning the years 1945 to 1955, a chronicle of the fictional Italian-American Corleone crime family. When organized crime family patriarch, Vito Corleone barely survives an attempt on his life, his youngest son, Michael steps in to take care of the would-be killers, launching a campaign of bloody revenge.
# Dog Day Afternoon
# Based on the true story of would-be Brooklyn bank robbers John Wojtowicz and Salvatore Naturile. Sonny and Sal attempt a bank heist which quickly turns sour and escalates into a hostage situation and stand-off with the police. As Sonny's motives for the robbery are slowly revealed and things become more complicated, the heist turns into a media circus.
# One Flew Over the Cuckoo's Nest
# A petty criminal fakes insanity to serve his sentence in a mental ward rather than prison. He soon finds himself as a leader to the other patients—and an enemy to the cruel, domineering nurse who runs the ward.
# Once Upon a Time in America
# A former Prohibition-era Jewish gangster returns to the Lower East Side of Manhattan over thirty years later, where he once again must confront the ghosts and regrets of his old life.
# The Godfather Part II
# In the continuing saga of the Corleone crime family, a young Vito Corleone grows up in Sicily and in 1910s New York. In the 1950s, Michael Corleone attempts to expand the family business into Las Vegas, Hollywood and Cuba.

# %%
movie = Movie()
popular = movie.popular()

for p in popular:
    print(p.id)
    print(p.title)
    print(p.overview)
    print(p.poster_path)
# Out:
# 1038392
# The Conjuring: Last Rites
# Paranormal investigators Ed and Lorraine Warren take on one last terrifying case involving mysterious entities they must confront.
# /7JzOmJ1fIU43I3gLHYsY8UzNzjG.jpg
# 941109
# Play Dirty
# Expert thief Parker gets a shot at a major heist, but to pull it off he and his team must outsmart a South American dictator, the New York mob, and the world's richest man.
# /ovZ0zq0NwRghtWI1oLaM0lWuoEw.jpg
# 1186350
# Marco
# The adoptive son of the Adattu family, Marco, sets off on a ruthless quest for vengeance after his brother is brutally murdered, finding only betrayal, loss and unimaginable brutality at every step.
# /il3ao5gcF6fZNqo1o9o7lusmEyU.jpg
# 1311031
# Demon Slayer: Kimetsu no Yaiba Infinity Castle
# The Demon Slayer Corps are drawn into the Infinity Castle, where Tanjiro, Nezuko, and the Hashira face terrifying Upper Rank demons in a desperate fight as the final battle against Muzan Kibutsuji begins.
# /sUsVimPdA1l162FvdBIlmKBlWHx.jpg
# 338969
# The Toxic Avenger Unrated
# When a downtrodden janitor, Winston Gooze (Peter Dinklage), is exposed to a catastrophic toxic accident, he’s transformed into a new kind of hero: The Toxic Avenger. Now, Toxie must rise from outcast to savior, taking on ruthless corporate overlords and corrupt forces who threaten his son, his friends, and his community.
# /sIonGSpGNtH72OzbJllPOEMNjVU.jpg
# 1086910
# The Lost Princess
# After an Ayahuasca vision transports him to a haunted castle, Alec meets Hanna who tales him the story of her mother's forced marriage and how the forbidden passion with her father was in danger when the princess pregnancy became obvious
# /31S2ISsDtbnxb0kuXZl1SxSMD0K.jpg
# 1257009
# Primitive War
# During the Vietnam War, a recon unit ventures to an isolated jungle valley to uncover the fate of a missing platoon. They soon find themselves in a fight for their lives against an unexpected enemy — prehistoric dinosaurs.
# /nWBqU5YXmDVJWWEDJ4u3ZSseNVL.jpg
# 755898
# War of the Worlds
# Will Radford is a top analyst for Homeland Security who tracks potential threats through a mass surveillance program, until one day an attack by an unknown entity leads him to question whether the government is hiding something from him... and from the rest of the world.
# /yvirUYrva23IudARHn3mMGVxWqM.jpg
# 793387
# Holy Night: Demon Hunters
# When a devil-worshipping criminal network plunges Seoul into chaos, the police turn to Holy Night—a trio of supernatural demon hunters—to restore order and defeat the rising evil.
# /v3Mo77Qjp6pctpD4eJaNT6kFRSB.jpg
# 617126
# The Fantastic 4: First Steps
# Against the vibrant backdrop of a 1960s-inspired, retro-futuristic world, Marvel's First Family is forced to balance their roles as heroes with the strength of their family bond, while defending Earth from a ravenous space god called Galactus and his enigmatic Herald, Silver Surfer.
# /cm8TNGBGG0aBfWj0LgrESHv8tir.jpg
# 1267319
# Mantis
# Mantis, an ace assassin, returns to the contract killer industry after a hiatus, encountering his trainee friend Jae-yi and a retired legendary killer Dok-go, who now runs the organization.
# /xS9bbciDC5lHPgl79SrPyzxKAXL.jpg
# 1357886
# Django Undisputed
# Determined to exact his justice, Django faces dangerous challenges and bloody clashes to restore order in a territory dominated by lawlessness and injustice.
# /porcUhC4jqFt72TaxbjOQo2lTzL.jpg
# 1053008
# Fight Another Day
# Follows a tough cop, who after being transported to a dystopian future, must enter a deadly combat tournament to be able to return to his past.
# /fKnLt1xQV0RdpN6RViowEiD1dFW.jpg
# 1328803
# Prisoner of War
# British RAF Wing Commander James Wright is captured by the Japanese during WWII and forced to fight in brutal hand-to-hand combat. The Japanese soldiers get more than they bargained for when Wright’s years of martial arts training in Hong Kong prove him to be a formidable opponent.
# /1XET89sjRm9mUuHXhGIlKTNd5uD.jpg
# 1552819
# Assassin
#
# /fLRCNUz3MsnC0MdhaWpw3hp4Eye.jpg
# 1236470
# The Lost Bus
# A determined father risks everything to rescue a dedicated teacher and her students from a raging wildfire.
# /zpygCOYY1DPBkeUsrrznLRN5js5.jpg
# 1054867
# One Battle After Another
# Washed-up revolutionary Bob exists in a state of stoned paranoia, surviving off-grid with his spirited, self-reliant daughter, Willa. When his evil nemesis resurfaces after 16 years and she goes missing, the former radical scrambles to find her, father and daughter both battling the consequences of his past.
# /m1jFoahEbeQXtx4zArT2FKdbNIj.jpg
# 1061474
# Superman
# Superman, a journalist in Metropolis, embarks on a journey to reconcile his Kryptonian heritage with his human upbringing as Clark Kent.
# /wPLysNDLffQLOVebZQCbXJEv6E6.jpg
# 803796
# KPop Demon Hunters
# When K-pop superstars Rumi, Mira and Zoey aren't selling out stadiums, they're using their secret powers to protect their fans from supernatural threats.
# /22AouvwlhlXbe3nrFcjzL24bvWH.jpg
# 1009640
# Valiant One
# With tensions between North and South Korea, a US helicopter crashes on the North side. The survivors must work together to protect a civilian tech specialist and find their way out without the help of US military support.
# /sT8Z14RDCAd6szzxzWFAU4xcMwg.jpg

# %%
import requests
response = requests.get("https://api.themoviedb.org/3/discover/movie?api_key=<<api_key>>&language=en-US&sort_by=popularity.desc&include_adult=false&include_video=false&page=2&primary_release_year=2010")

# %%
response.json()
# Out:
# {'status_code': 7,
#  'status_message': 'Invalid API key: You must be granted a valid key.',
#  'success': False}

# %% [markdown]
# #### Acceder a datos de la api desde la URL con la libreria requests

# %%
import numpy as np
import pandas as pd

# https://www.themoviedb.org/documentation/api
#api_key = "tu api key"

years = np.arange(2024, 2025)
id_movies = []
release_date = []
title = []
for i in years:
    print("year:", i )
    for j in range(1,100): 
        response = requests.get(f'https://api.themoviedb.org/3/discover/movie?api_key={tmdb.api_key}&page={j}&primary_release_year={i}&sort_by=popularity.desc')
        highest_revenue = response.json()
        print(highest_revenue)
        
        first_results = highest_revenue["results"]
       
        for k in first_results:
                     
            try:                
                release_date.append(k["release_date"])
                title.append(k["title"])
                id_movies.append(k["id"])  
            except:
                release_date.append(np.nan)
                title.append(np.nan)
                id_movies.append(np.nan)
                continue

df_movies_id = pd.DataFrame(id_movies, columns=["id"])
df_movies_id["date"] = release_date
df_movies_id["title"] = title
# Out:
# year: 2024
# {'page': 1, 'results': [{'adult': False, 'backdrop_path': '/a6RkQIOZ6wThQOEDv6lHsfH53hD.jpg', 'genre_ids': [28, 80, 53], 'id': 1186350, 'original_language': 'ml', 'original_title': 'മാർക്കോ', 'overview': 'The adoptive son of the Adattu family, Marco, sets off on a ruthless quest for vengeance after his brother is brutally murdered, finding only betrayal, loss and unimaginable brutality at every step.', 'popularity': 390.0089, 'poster_path': '/il3ao5gcF6fZNqo1o9o7lusmEyU.jpg', 'release_date': '2024-12-20', 'title': 'Marco', 'video': False, 'vote_average': 6.431, 'vote_count': 51}, {'adult': False, 'backdrop_path': '/nvdLEfAWcfTNn45SpwBnLGBmOR1.jpg', 'genre_ids': [37], 'id': 1357886, 'original_language': 'it', 'original_title': 'Django Undisputed', 'overview': 'Determined to exact his justice, Django faces dangerous challenges and bloody clashes to restore order in a territory dominated by lawlessness and injustice.', 'popularity': 175.0102, 'poster_path': '/porcUhC4jqFt72TaxbjOQo2lTzL.jpg', 'release_date': '2024-04-22', 'title': 'Django Undisputed', 'video': False, 'vote_average': 5.3, 'vote_count': 5}, {'adult': False, 'backdrop_path': '/znMUHotZRTcyIFWFz2bvcpSx6YP.jpg', 'genre_ids': [28], 'id': 1053008, 'original_language': 'en', 'original_title': 'Fight Another Day', 'overview': 'Follows a tough cop, who after being transported to a dystopian future, must enter a deadly combat tournament to be able to return to his past.', 'popularity': 206.585, 'poster_path': '/fKnLt1xQV0RdpN6RViowEiD1dFW.jpg', 'release_date': '2024-10-09', 'title': 'Fight Another Day', 'video': False, 'vote_average': 5.1, 'vote_count': 16}, {'adult': False, 'backdrop_path': '/3IcJRIjMo4G1A6HtCHiKCUAyfIw.jpg', 'genre_ids': [27, 28, 878], 'id': 1032448, 'original_language': 'en', 'original_title': 'Jurassic Triangle', 'overview': 'A group of colleagues crash land on a mysterious island that they cannot escape. They discover they are not alone when they encounter an array of blood thirsty creatures and dinosaurs out to get them. Will they survive the island?', 'popularity': 118.4929, 'poster_path': '/yLxLz8RHiOLtNvKCtJYQgDFXqBU.jpg', 'release_date': '2024-02-13', 'title': 'Jurassic Triangle', 'video': False, 'vote_average': 3.25, 'vote_count': 8}, {'adult': False, 'backdrop_path': '/boprqXZexBatujVC07gZzzxjWk.jpg', 'genre_ids': [53, 27], 'id': 1109406, 'original_language': 'en', 'original_title': 'Compulsion', 'overview': 'Two women—Diana, a flamboyant and ruthless thief, and Evie, a seemingly innocent young woman with a troubled past—become embroiled in a series of horrific murders on the island of Malta.', 'popularity': 96.9245, 'poster_path': '/s3MzSdsMcmxmpVJMuH5ezNPjzs7.jpg', 'release_date': '2024-11-10', 'title': 'Compulsion', 'video': False, 'vote_average': 7.0, 'vote_count': 7}, {'adult': False, 'backdrop_path': '/bVQe2nzhh4AvI3yDu22hDK6fTfo.jpg', 'genre_ids': [27, 35], 'id': 1396558, 'original_language': 'en', 'original_title': 'Bloody Axe Wound', 'overview': 'Abbie Bladecut is a teenager torn between the macabre traditions of her family’s bloody trade and the tender stirrings of her first crush. In the small town of Clover Falls, Abbie’s father Roger has built an infamous legacy by capturing real-life killings on tape and selling them to eager customers, but as Abbie delves deeper into the grisly family business, she begins to wonder if it’s time to take the family tradition in a new direction.', 'popularity': 92.9274, 'poster_path': '/dS9sU5JGnkmEVZ9ubgnJa6RMLwx.jpg', 'release_date': '2024-12-27', 'title': 'Bloody Axe Wound', 'video': False, 'vote_average': 5.225, 'vote_count': 19}, {'adult': False, 'backdrop_path': '/5U3VLeWr2H4Nd3G7IkHItFimsIz.jpg', 'genre_ids': [10751, 35, 12, 16, 878], 'id': 870360, 'original_language': 'en', 'original_title': 'The Day the Earth Blew Up: A Looney Tunes Movie', 'overview': "Porky and Daffy, the classic animated odd couple, turn into unlikely heroes when their antics at the local bubble gum factory uncover a secr ...
# {'page': 2, 'results': [{'adult': False, 'backdrop_path': None, 'genre_ids': [18], 'id': 814337, 'original_language': 'es', 'original_title': 'La vecina de al lado', 'overview': '', 'popularity': 26.1753, 'poster_path': '/1N1LQ8Lacj2Rx6fnvkB6psm6ZNI.jpg', 'release_date': '2024-06-04', 'title': 'La vecina de al lado', 'video': False, 'vote_average': 0.0, 'vote_count': 0}, {'adult': False, 'backdrop_path': '/qDAvAUsnRrvkFO5EtNq1XFfyYTL.jpg', 'genre_ids': [16, 10751, 14], 'id': 974397, 'original_language': 'en', 'original_title': 'My Freaky Family', 'overview': "On the cusp of her 13th birthday, Betty Flood – budding musician and magical being – just wants to be like the rest of her fabulous, but very different family, so why is her magical Mum so against it? As Betty wrestles with this, she also learns the amazing truth about her family and discovers that the not so normal, the magical and the musical are all a part of her fabulously freaky family. It's very freaky, so be freaked freaky ahh deaky peaky neaky seaky peaky poo.", 'popularity': 26.6815, 'poster_path': '/h34lkT2CFufYuzmP0CEgn4lghyY.jpg', 'release_date': '2024-04-25', 'title': 'My Freaky Family', 'video': False, 'vote_average': 7.0, 'vote_count': 6}, {'adult': False, 'backdrop_path': '/gSVk4r8Q4R8aeGY0hhEG3bE0QzL.jpg', 'genre_ids': [12, 27, 53], 'id': 1252428, 'original_language': 'zh', 'original_title': '狂蟒之灾', 'overview': "A struggling circus crew gets deceived by its former partner, as it embarks on a tour in Thailand. During the journey through a Southeast Asian rainforest, they encounter attacks by a giant python. They meet a mysterious man named Jeff who offers to help, but they soon realize he's a poacher. As they search for Jeff's boat, they face life-and-death struggles with the python and Jeff himself.", 'popularity': 23.0617, 'poster_path': '/pPfsEXzfk2URkQ1OxhUShAXdxMr.jpg', 'release_date': '2024-03-01', 'title': 'Anaconda', 'video': False, 'vote_average': 7.245, 'vote_count': 106}, {'adult': False, 'backdrop_path': '/mrmaTVp7PTBkjj5G62cE9pjrENg.jpg', 'genre_ids': [27, 18], 'id': 1359977, 'original_language': 'en', 'original_title': 'Conjuring the Cult', 'overview': "After discovering his blood-soaked daughter dead in the bathtub, David Bryson attends a self-help group to help save him from his ghostly nightmares. But when a group of mysterious cult-like women offer to help him resurrect his daughter. David's choices will not just decide his fate... but the fate of his dead daughter's SOUL.", 'popularity': 21.3898, 'poster_path': '/t4MiAeYpjL7saYvqvcn9xtOfA4K.jpg', 'release_date': '2024-10-01', 'title': 'Conjuring the Cult', 'video': False, 'vote_average': 5.6, 'vote_count': 39}, {'adult': False, 'backdrop_path': '/xjU9tmtZTThyKtWnoRfoUnBj6z9.jpg', 'genre_ids': [53, 36, 18], 'id': 1171296, 'original_language': 'en', 'original_title': 'Baltimore', 'overview': 'Based on actual events that took place on 26 April 1974, former debutante turned IRA member Rose Dugdale and three comrades carried out an armed raid on Russborough House, Wicklow, in which nineteen masterpieces were stolen in an effort to support the IRA’s armed struggle. The film plays out over the course of the days following the raid, when Rose is in hiding in a remote cottage.', 'popularity': 23.0073, 'poster_path': '/q8SXr3SCtHESHkmO2mFqzqlJ09L.jpg', 'release_date': '2024-03-01', 'title': 'Baltimore', 'video': False, 'vote_average': 5.839, 'vote_count': 28}, {'adult': False, 'backdrop_path': '/uVlUu174iiKhsUGqnOSy46eIIMU.jpg', 'genre_ids': [18, 10749, 14], 'id': 402431, 'original_language': 'en', 'original_title': 'Wicked', 'overview': "In the land of Oz, ostracized and misunderstood green-skinned Elphaba is forced to share a room with the popular aristocrat Glinda at Shiz University, and the two's unlikely friendship is tested as they begin to fulfill their respective destinies as Glinda the Good and the Wicked Witch of the West.", 'popularity': 21.6941, 'poster_path': '/xDGbZ0JJ3mYaGKy4Nzd9Kph ...
# {'page': 3, 'results': [{'adult': False, 'backdrop_path': '/sI6uCeF8mUlZx22mFfHSi9W3XQ9.jpg', 'genre_ids': [10749, 18, 35], 'id': 843527, 'original_language': 'en', 'original_title': 'The Idea of You', 'overview': "40-year-old single mom Solène begins an unexpected romance with 24-year-old Hayes Campbell, the lead singer of August Moon, the hottest boy band on the planet. As they begin a whirlwind romance, it isn't long before Hayes' superstar status poses unavoidable challenges to their relationship, and Solène soon discovers that life in the glare of his spotlight might be more than she bargained for.", 'popularity': 18.692, 'poster_path': '/Y5P4Q3q8nrruZ9aD3wXeJS2Plg.jpg', 'release_date': '2024-05-02', 'title': 'The Idea of You', 'video': False, 'vote_average': 7.346, 'vote_count': 1776}, {'adult': False, 'backdrop_path': '/euYIwmwkmz95mnXvufEmbL6ovhZ.jpg', 'genre_ids': [28, 12, 18], 'id': 558449, 'original_language': 'en', 'original_title': 'Gladiator II', 'overview': 'Years after witnessing the death of the revered hero Maximus at the hands of his uncle, Lucius is forced to enter the Colosseum after his home is conquered by the tyrannical Emperors who now lead Rome with an iron fist. With rage in his heart and the future of the Empire at stake, Lucius must look to his past to find strength and honor to return the glory of Rome to its people.', 'popularity': 18.5693, 'poster_path': '/2cxhvwyEwRlysAmRH4iodkvo0z5.jpg', 'release_date': '2024-11-13', 'title': 'Gladiator II', 'video': False, 'vote_average': 6.663, 'vote_count': 3915}, {'adult': False, 'backdrop_path': '/18TSJF1WLA4CkymvVUcKDBwUJ9F.jpg', 'genre_ids': [27, 53], 'id': 1034541, 'original_language': 'en', 'original_title': 'Terrifier 3', 'overview': "Five years after surviving Art the Clown's Halloween massacre, Sienna and Jonathan are still struggling to rebuild their shattered lives. As the holiday season approaches, they try to embrace the Christmas spirit and leave the horrors of the past behind. But just when they think they're safe, Art returns, determined to turn their holiday cheer into a new nightmare. The festive season quickly unravels as Art unleashes his twisted brand of terror, proving that no holiday is safe.", 'popularity': 17.8742, 'poster_path': '/ju10W5gl3PPK3b7TjEmVOZap51I.jpg', 'release_date': '2024-10-09', 'title': 'Terrifier 3', 'video': False, 'vote_average': 6.835, 'vote_count': 1742}, {'adult': False, 'backdrop_path': '/f0ACHVpV707zqu4etZrXnWNdSgL.jpg', 'genre_ids': [28, 80, 53], 'id': 866398, 'original_language': 'en', 'original_title': 'The Beekeeper', 'overview': "One man's campaign for vengeance takes on national stakes after he is revealed to be a former operative of a powerful and clandestine organization known as Beekeepers.", 'popularity': 18.2945, 'poster_path': '/A7EByudX0eOzlkQ2FIbogzyazm2.jpg', 'release_date': '2024-01-08', 'title': 'The Beekeeper', 'video': False, 'vote_average': 7.28, 'vote_count': 3805}, {'adult': False, 'backdrop_path': '/8Rseq6hAhAItnTrbECEFt35VoSJ.jpg', 'genre_ids': [10749, 18], 'id': 1252309, 'original_language': 'es', 'original_title': 'Pídeme lo que quieras', 'overview': "After his father's death, Eric Zimmerman travels to Spain to oversee his company's branches. In Madrid, he falls for Judith and engage in an intense, erotic relationship full of exploration. However, Eric fears his secret may end their affair.", 'popularity': 17.8582, 'poster_path': '/6MsRwOG96qs5KtPjxVuvMcUPjdU.jpg', 'release_date': '2024-11-29', 'title': 'Tell Me What You Want', 'video': False, 'vote_average': 6.218, 'vote_count': 239}, {'adult': False, 'backdrop_path': '/xOMo8BRK7PfcJv9JCnx7s5hj0PX.jpg', 'genre_ids': [878, 12], 'id': 693134, 'original_language': 'en', 'original_title': 'Dune: Part Two', 'overview': 'Follow the mythic journey of Paul Atreides as he unites with Chani and the Fremen while on a path of revenge against the conspirators who destroyed his family. Facing a choice between the love of his life and the fate of ...
# {'page': 4, 'results': [{'adult': False, 'backdrop_path': '/uGmYqxh8flqkudioyFtD7IJSHxK.jpg', 'genre_ids': [18, 80, 53], 'id': 889737, 'original_language': 'en', 'original_title': 'Joker: Folie à Deux', 'overview': "While struggling with his dual identity, Arthur Fleck not only stumbles upon true love, but also finds the music that's always been inside him.", 'popularity': 12.9434, 'poster_path': '/if8QiqCI7WAGImKcJCfzp6VTyKA.jpg', 'release_date': '2024-10-01', 'title': 'Joker: Folie à Deux', 'video': False, 'vote_average': 5.416, 'vote_count': 2625}, {'adult': False, 'backdrop_path': '/fypydCipcWDKDTTCoPucBsdGYXW.jpg', 'genre_ids': [878, 12, 28, 18, 53], 'id': 653346, 'original_language': 'en', 'original_title': 'Kingdom of the Planet of the Apes', 'overview': "Several generations following Caesar's reign, apes – now the dominant species – live harmoniously while humans have been reduced to living in the shadows. As a new tyrannical ape leader builds his empire, one young ape undertakes a harrowing journey that will cause him to question all he's known about the past and to make choices that will define a future for apes and humans alike.", 'popularity': 13.9948, 'poster_path': '/gKkl37BQuKTanygYQG1pyYgLVgf.jpg', 'release_date': '2024-05-08', 'title': 'Kingdom of the Planet of the Apes', 'video': False, 'vote_average': 7.061, 'vote_count': 3911}, {'adult': False, 'backdrop_path': '/5cCfqeUH2f5Gnu7Lh9xepY9TB6x.jpg', 'genre_ids': [14, 12, 35], 'id': 967847, 'original_language': 'en', 'original_title': 'Ghostbusters: Frozen Empire', 'overview': 'When the discovery of an ancient artifact unleashes an evil force, Ghostbusters new and old must join forces to protect their home and save the world from a second Ice Age.', 'popularity': 12.2744, 'poster_path': '/e1J2oNzSBdou01sUvriVuoYp0pJ.jpg', 'release_date': '2024-03-20', 'title': 'Ghostbusters: Frozen Empire', 'video': False, 'vote_average': 6.47, 'vote_count': 1936}, {'adult': False, 'backdrop_path': '/eFlx3fW8FHXOktGa7Tzy57RajtG.jpg', 'genre_ids': [18, 10749], 'id': 1357459, 'original_language': 'tl', 'original_title': 'Tatsulok: Tatlo Magkasalo', 'overview': 'Story about a happily married couple visited by an old friend, who ends up stirring the pot by becoming sexually involved with both the husband and the wife.', 'popularity': 14.4242, 'poster_path': '/15B2oabjTSiydkqsV05jX2IV1Dq.jpg', 'release_date': '2024-10-11', 'title': 'Triangle', 'video': False, 'vote_average': 6.0, 'vote_count': 13}, {'adult': False, 'backdrop_path': '/5AsIFZ2AJC7JcGpq40aRPuRuaRc.jpg', 'genre_ids': [18], 'id': 1241752, 'original_language': 'tl', 'original_title': 'Rita', 'overview': 'Rita, who finds herself alone when husband Ariel works abroad. They both find solace and sexual satisfaction in other people. When Ariel comes back, they both act like nothing happened. But will this keep their marriage from falling apart?', 'popularity': 13.8272, 'poster_path': '/pXENxAzOBrTSDJGxDcUnlNTNmWr.jpg', 'release_date': '2024-03-22', 'title': 'Rita', 'video': False, 'vote_average': 6.7, 'vote_count': 17}, {'adult': False, 'backdrop_path': '/oMiKHO3H5RixfLsiU5Vumhlp5sj.jpg', 'genre_ids': [80, 10749, 53, 18], 'id': 948549, 'original_language': 'en', 'original_title': 'Love Lies Bleeding', 'overview': 'Reclusive gym manager Lou falls hard for Jackie, an ambitious bodybuilder headed through town to Las Vegas in pursuit of her dream. But their love ignites violence, pulling them deep into the web of Lou’s criminal family.', 'popularity': 12.8487, 'poster_path': '/xImj8RLe39YK0lyVu9kXv7ApN8p.jpg', 'release_date': '2024-03-07', 'title': 'Love Lies Bleeding', 'video': False, 'vote_average': 6.584, 'vote_count': 848}, {'adult': False, 'backdrop_path': '/cyKH7pDFlxIXluqRyNoHHEpxSDX.jpg', 'genre_ids': [80, 28, 53], 'id': 646097, 'original_language': 'en', 'original_title': 'Rebel Ridge', 'overview': "A former Marine confronts corruption in a small town when local law enforcement unjustly seizes the bag of cash he needs to  ...
# {'page': 5, 'results': [{'adult': False, 'backdrop_path': '/ag66gJCiZ06q1GSJuQlhGLi3Udx.jpg', 'genre_ids': [27, 53], 'id': 1138194, 'original_language': 'en', 'original_title': 'Heretic', 'overview': 'Two young missionaries are forced to prove their faith when they knock on the wrong door and are greeted by a diabolical Mr. Reed, becoming ensnared in his deadly game of cat-and-mouse.', 'popularity': 12.2555, 'poster_path': '/fr96XzlzsONrQrGfdLMiwtQjott.jpg', 'release_date': '2024-10-31', 'title': 'Heretic', 'video': False, 'vote_average': 7.0, 'vote_count': 2179}, {'adult': False, 'backdrop_path': '/wcFV4uOdSbC0cSjs7ecAyOU6t59.jpg', 'genre_ids': [16, 10751, 12, 14, 35], 'id': 947478, 'original_language': 'en', 'original_title': 'Diplodocus', 'overview': 'When the world around him is mysteriously erased, a little green dinosaur named Diplodocus must travel through the pages of a comic book and adventure through time to bring color back to his land. Alongside a wizard and two scientists, Diplo’s plans go awry as he learns that there may be a dimension to his world that he never considered.', 'popularity': 11.1704, 'poster_path': '/9mnMMiwv20EL5weJrLZCaF8cM2u.jpg', 'release_date': '2024-10-04', 'title': 'The Green Dinosaur', 'video': False, 'vote_average': 7.2, 'vote_count': 9}, {'adult': False, 'backdrop_path': '/2okfik8YwzSfdETpT5cUClSiGFO.jpg', 'genre_ids': [16, 18], 'id': 1244492, 'original_language': 'ja', 'original_title': 'ルックバック', 'overview': 'Popular, outgoing Fujino is celebrated by her classmates for her funny comics in the class newspaper. One day, her teacher asks her to share the space with Kyomoto, a truant recluse whose beautiful artwork sparks a competitive fervor in Fujino. What starts as jealousy transforms when Fujino realizes their shared passion for drawing.', 'popularity': 11.1332, 'poster_path': '/4f2EcNkp1Mvp9wE5w7HKxcmACWg.jpg', 'release_date': '2024-06-28', 'title': 'Look Back', 'video': False, 'vote_average': 8.06, 'vote_count': 411}, {'adult': False, 'backdrop_path': '/zGLQmrmIB56kMZPnzqReIOBay1B.jpg', 'genre_ids': [28, 35, 53], 'id': 507241, 'original_language': 'en', 'original_title': "The Killer's Game", 'overview': "When top hitman Joe Flood is diagnosed with a terminal illness, he decides to take matters into his own hands – by taking a hit out on himself. But when the very hitmen he hired also target his ex-girlfriend, he must fend off an army of assassin colleagues and win back the love of his life before it's too late.", 'popularity': 10.5526, 'poster_path': '/4bKlTeOUr5AKrLky8mwWvlQqyVd.jpg', 'release_date': '2024-09-12', 'title': "The Killer's Game", 'video': False, 'vote_average': 6.397, 'vote_count': 472}, {'adult': False, 'backdrop_path': '/au3o84ub27qTZiMiEc9UYzN74V3.jpg', 'genre_ids': [28, 878, 53], 'id': 1035048, 'original_language': 'en', 'original_title': 'Elevation', 'overview': "Post-apocalyptic survivors find refuge in the Rocky Mountains to hide from giant, insect-like creatures that can't live above 8,000 feet. However, when one of them needs life-saving supplies, they risk it all to venture into the danger zone.", 'popularity': 11.0999, 'poster_path': '/tnfc0NJ3BzhJrGJhkkEd6MHBdq5.jpg', 'release_date': '2024-11-07', 'title': 'Elevation', 'video': False, 'vote_average': 6.469, 'vote_count': 811}, {'adult': False, 'backdrop_path': '/nra0mwygGORHlD0Rd84DhQ9jkdf.jpg', 'genre_ids': [53, 9648, 80, 27], 'id': 1032823, 'original_language': 'en', 'original_title': 'Trap', 'overview': "A father and teen daughter attend a pop concert, where they realize they're at the center of a dark and sinister event.", 'popularity': 9.5886, 'poster_path': '/jwoaKYVqPgYemFpaANL941EF94R.jpg', 'release_date': '2024-07-31', 'title': 'Trap', 'video': False, 'vote_average': 6.269, 'vote_count': 2464}, {'adult': False, 'backdrop_path': '/zViRwl3ySscZnbXZJ2Q9wq3SeUG.jpg', 'genre_ids': [16, 878, 12, 10751], 'id': 698687, 'original_language': 'en', 'original_title': 'Transformers One', 'overview': 'The untold o ...
# {'page': 6, 'results': [{'adult': False, 'backdrop_path': '/deLWkOLZmBNkm8p16igfapQyqeq.jpg', 'genre_ids': [14, 28, 12], 'id': 763215, 'original_language': 'en', 'original_title': 'Damsel', 'overview': "A young woman's marriage to a charming prince turns into a fierce fight for survival when she's offered up as a sacrifice to a fire-breathing dragon.", 'popularity': 9.699, 'poster_path': '/290Lsuy4GJF3VEVqMbJqHs7xFdv.jpg', 'release_date': '2024-03-07', 'title': 'Damsel', 'video': False, 'vote_average': 7.005, 'vote_count': 2553}, {'adult': False, 'backdrop_path': '/AvbaItPGQGe8Tk266MYo9uWbVs5.jpg', 'genre_ids': [99], 'id': 1373150, 'original_language': 'en', 'original_title': 'The Devil Is Busy', 'overview': 'At an Atlanta abortion clinic besieged by protesters, the director of operations, Tracy, takes necessary risks to safeguard staff and patients.', 'popularity': 9.0457, 'poster_path': '/hiDLqQ0r7uH5Ww9ekpOmzFEUpxz.jpg', 'release_date': '2024-11-13', 'title': 'The Devil Is Busy', 'video': False, 'vote_average': 5.0, 'vote_count': 2}, {'adult': False, 'backdrop_path': '/hmZnqijPaaACjenDkrbWcCmcADI.jpg', 'genre_ids': [18, 36], 'id': 549509, 'original_language': 'en', 'original_title': 'The Brutalist', 'overview': 'When a visionary architect and his wife flee post-war Europe in 1947 to rebuild their legacy and witness the birth of modern United States, their lives are changed forever by a mysterious, wealthy client.', 'popularity': 9.6971, 'poster_path': '/vP7Yd6couiAaw9jgMd5cjMRj3hQ.jpg', 'release_date': '2024-12-20', 'title': 'The Brutalist', 'video': False, 'vote_average': 6.976, 'vote_count': 1331}, {'adult': False, 'backdrop_path': '/bizhlTVjifYQUu4Xrdt7m3TYr7d.jpg', 'genre_ids': [27, 53, 80], 'id': 1226578, 'original_language': 'en', 'original_title': 'Longlegs', 'overview': 'FBI Agent Lee Harker is a gifted new recruit assigned to the unsolved case of an elusive serial killer. As the case takes complex turns, unearthing evidence of the occult, Harker discovers a personal connection to the merciless killer and must race against time to stop him before he claims the lives of another innocent family.', 'popularity': 9.2657, 'poster_path': '/1EwNyiiNFd863H4e8nWEzutnZD7.jpg', 'release_date': '2024-07-10', 'title': 'Longlegs', 'video': False, 'vote_average': 6.6, 'vote_count': 2264}, {'adult': False, 'backdrop_path': '/qPJZ1N2JoLggeKUqw8Clo5Pggr3.jpg', 'genre_ids': [27, 35], 'id': 1229262, 'original_language': 'en', 'original_title': "I Don't Understand You", 'overview': 'Stranded in rural Italy without transportation or language skills, an American couple on the verge of adopting tries to reconnect during a disastrous vacation, as their fears and relationship problems threaten to boil over.', 'popularity': 9.9298, 'poster_path': '/rnPE7UJrM0NvmbL97vy5wY2LIdj.jpg', 'release_date': '2024-03-08', 'title': "I Don't Understand You", 'video': False, 'vote_average': 6.048, 'vote_count': 21}, {'adult': False, 'backdrop_path': '/bx6LoGl8L3hwgOCoD2H8JgIu7uC.jpg', 'genre_ids': [28, 18], 'id': 1235623, 'original_language': 'zh', 'original_title': 'Mu zhong wu ren 2', 'overview': 'The blind swordsman, skilled in martial arts, named Cheng Xiazi (Xie Miao), accidentally saves Zhang Xiaoyu (Yang Enyou), who has suffered from the destruction of his family. Under the persuasion of the orphan Xiaoyu, Cheng reluctantly keeps him by his side and teaches him skills. Xiaoyu also waits for the opportunity to seek revenge.', 'popularity': 9.9359, 'poster_path': '/mkfznkTshGBp88SFQQAGsr3R62z.jpg', 'release_date': '2024-07-21', 'title': 'Eye for an Eye 2', 'video': False, 'vote_average': 6.42, 'vote_count': 56}, {'adult': False, 'backdrop_path': '/zxjFabSJKMAvuu3acNg78nuTuCs.jpg', 'genre_ids': [28, 53, 27], 'id': 1442776, 'original_language': 'zh', 'original_title': 'Kuang Bao Ju Xi', 'overview': 'A young man climbs into the mountains to pick up a meteorite that has fallen there and is killed by something. The "thing" descends to the village and begin ...
# {'page': 7, 'results': [{'adult': False, 'backdrop_path': '/iWzu3dVJGNfQUkLfK9xpTWoi5mh.jpg', 'genre_ids': [10749, 18, 35], 'id': 1139566, 'original_language': 'es', 'original_title': 'A través de mi ventana 3: A través de tu mirada', 'overview': "After the events of the summer, Ares and Raquel they don't see a way forward in their relationship and decide to go separate ways. But when they meet again in the winter in Barcelona, the love and desire they feel for each other is undeniable. Will they be able to find a way to get back together?", 'popularity': 9.947, 'poster_path': '/gwpTgtwVAwmvivBN8rAQABpx9Am.jpg', 'release_date': '2024-02-23', 'title': 'Through My Window 3: Looking at You', 'video': False, 'vote_average': 6.9, 'vote_count': 633}, {'adult': False, 'backdrop_path': '/vtuGtevnaJutCqWAmGfvb1wLByh.jpg', 'genre_ids': [35], 'id': 1008953, 'original_language': 'en', 'original_title': 'Incoming', 'overview': 'Their first week of high school. The biggest party of the year. Mistakes will be made as four teenage boys navigate a night of mayhem and debauchery.', 'popularity': 9.1612, 'poster_path': '/k2ySukuAiAarLns0yttKS3jg85Y.jpg', 'release_date': '2024-08-22', 'title': 'Incoming', 'video': False, 'vote_average': 6.22, 'vote_count': 316}, {'adult': False, 'backdrop_path': '/qOdR46ymkVXuhnpnL2cBdjqjvnA.jpg', 'genre_ids': [27, 53], 'id': 1023922, 'original_language': 'en', 'original_title': 'MaXXXine', 'overview': 'In 1980s Hollywood, adult film star and aspiring actress Maxine Minx finally gets her big break. But as a mysterious killer stalks the starlets of Hollywood, a trail of blood threatens to reveal her sinister past.', 'popularity': 8.8182, 'poster_path': '/ArvoFK6nlouZRxYmtIOUzKIrg90.jpg', 'release_date': '2024-07-04', 'title': 'MaXXXine', 'video': False, 'vote_average': 6.333, 'vote_count': 1242}, {'adult': False, 'backdrop_path': '/l26AsiS7TfqjKswEavel8BqPviT.jpg', 'genre_ids': [35, 18], 'id': 974613, 'original_language': 'en', 'original_title': 'The Fabulous Four', 'overview': 'Three lifelong friends travel to Key West, Florida to be bridesmaids in the surprise wedding of their college girlfriend Marilyn. Once there, sisterhoods are rekindled, the past rises up again in all its glory, and there’s enough sparks, drinks and romance to change all their lives in ways they never expected.', 'popularity': 9.3098, 'poster_path': '/g7kZFm81LBr2wf34MAdKexkZ0NH.jpg', 'release_date': '2024-07-26', 'title': 'The Fabulous Four', 'video': False, 'vote_average': 6.025, 'vote_count': 20}, {'adult': False, 'backdrop_path': '/H5HjE7Xb9N09rbWn1zBfxgI8uz.jpg', 'genre_ids': [28, 35, 10749], 'id': 746036, 'original_language': 'en', 'original_title': 'The Fall Guy', 'overview': 'Fresh off an almost career-ending accident, stuntman Colt Seavers has to track down a missing movie star, solve a conspiracy and try to win back the love of his life while still doing his day job.', 'popularity': 8.8806, 'poster_path': '/e7olqFmzcIX5c23kX4zSmLPJi8c.jpg', 'release_date': '2024-04-24', 'title': 'The Fall Guy', 'video': False, 'vote_average': 6.997, 'vote_count': 3213}, {'adult': False, 'backdrop_path': '/aWILNXgq07riueQknYXMvum11jo.jpg', 'genre_ids': [28, 53], 'id': 1081012, 'original_language': 'en', 'original_title': 'Aftermath', 'overview': "A returning war veteran, stricken with PTSD, gets trapped with his teenage sister on Boston's Tobin Memorial Bridge when a heavily armed group of ex-military revolutionaries take everyone hostage.", 'popularity': 8.824, 'poster_path': '/v9knhuvYKwMUAta6fltNOuun3zF.jpg', 'release_date': '2024-09-27', 'title': 'Aftermath', 'video': False, 'vote_average': 6.255, 'vote_count': 157}, {'adult': False, 'backdrop_path': '/2CtKnSi5SQ3aZc9Af25bsVv6Rcu.jpg', 'genre_ids': [35], 'id': 1109306, 'original_language': 'it', 'original_title': 'Un Mundo a Parte', 'overview': 'Elementary school teacher Michele Cortese is about to start a whole new life. After 40 years of teaching in the metropolitan Roman jungle, he had to mo ...
# {'page': 8, 'results': [{'adult': False, 'backdrop_path': '/cXmPMdFcbb5XAoH4y8uY00cJp0H.jpg', 'genre_ids': [99], 'id': 1324989, 'original_language': 'en', 'original_title': 'Untold: Sign Stealer', 'overview': 'In this sports documentary, Connor Stalions addresses the allegations surrounding the Michigan football sign-stealing scandal for the first time.', 'popularity': 8.7416, 'poster_path': '/f9smYB0Pqfe1QZwjBCbieAAFsDN.jpg', 'release_date': '2024-08-26', 'title': 'Untold: Sign Stealer', 'video': False, 'vote_average': 7.3, 'vote_count': 14}, {'adult': False, 'backdrop_path': '/kutrMwSVEcGFn5F0fUJYYRPzuxn.jpg', 'genre_ids': [28, 35, 10751], 'id': 1048241, 'original_language': 'en', 'original_title': 'My Spy The Eternal City', 'overview': 'JJ, a veteran CIA agent, reunites with his protégé Sophie, in order to prevent a catastrophic nuclear plot targeting the Vatican.', 'popularity': 9.0637, 'poster_path': '/Bf3vCfM94bSJ1saZlyi0UW0e0U.jpg', 'release_date': '2024-07-18', 'title': 'My Spy The Eternal City', 'video': False, 'vote_average': 6.609, 'vote_count': 417}, {'adult': False, 'backdrop_path': '/l7dOI84fj3WSUEWTsGAzYR8A1Ct.jpg', 'genre_ids': [18], 'id': 1388874, 'original_language': 'tl', 'original_title': "Boss Ma'am", 'overview': 'V.A.D. and Charm try to outplay each other in a game of deceit. When a terror female boss was blackmailed by her assistant, she has no choice but to obey and play with her.', 'popularity': 9.5601, 'poster_path': '/3po9qDTFZoejlOjaVodVcp8TYsm.jpg', 'release_date': '2024-11-26', 'title': "Boss Ma'am", 'video': False, 'vote_average': 7.5, 'vote_count': 8}, {'adult': False, 'backdrop_path': '/8aQYGyXKCohzoTjjxWzANPV2VBS.jpg', 'genre_ids': [27, 53], 'id': 1257586, 'original_language': 'en', 'original_title': 'The Hangman', 'overview': 'Troubled father Leon takes son camping in Appalachia. Local cult summons evil Hangman demon. Son goes missing. Leon must confront cult, monster to find him amid rising body count.', 'popularity': 7.5673, 'poster_path': '/rij9Eh4RVXyPet8A1BNU8pDvtmu.jpg', 'release_date': '2024-05-30', 'title': 'The Hangman', 'video': False, 'vote_average': 5.833, 'vote_count': 54}, {'adult': False, 'backdrop_path': '/ie8OSgIHEl6yQiGJ90dsyBWOpQA.jpg', 'genre_ids': [16, 14, 12, 28], 'id': 839033, 'original_language': 'en', 'original_title': 'The Lord of the Rings: The War of the Rohirrim', 'overview': 'A sudden attack by Wulf, a clever and traitorous lord of Rohan seeking vengeance for the death of his father, forces Helm Hammerhand, the King of Rohan, and his people to make a daring last stand in the ancient stronghold of the Hornburg.', 'popularity': 8.9925, 'poster_path': '/hE9SAMyMSUGAPsHUGdyl6irv11v.jpg', 'release_date': '2024-12-05', 'title': 'The Lord of the Rings: The War of the Rohirrim', 'video': False, 'vote_average': 6.58, 'vote_count': 705}, {'adult': False, 'backdrop_path': '/7u6fQagw5BON5Xvg82MuPJ2REGB.jpg', 'genre_ids': [28, 53, 80], 'id': 976734, 'original_language': 'en', 'original_title': 'Canary Black', 'overview': 'Top level CIA agent Avery Graves is blackmailed by terrorists into betraying her own country to save her kidnapped husband. Cut off from her team, she turns to her underworld contacts to survive and help locate the coveted intelligence that the kidnappers want.', 'popularity': 9.1494, 'poster_path': '/hhiR6uUbTYYvKoACkdAIQPS5c6f.jpg', 'release_date': '2024-10-10', 'title': 'Canary Black', 'video': False, 'vote_average': 6.22, 'vote_count': 446}, {'adult': False, 'backdrop_path': '/dVPPCD7wK0bFEB2NK3fw3CBidwd.jpg', 'genre_ids': [28, 53, 12], 'id': 1108354, 'original_language': 'fr', 'original_title': "KALI, L'ange de la Vengeance", 'overview': 'Lisa, aka Kali, who has nothing left to lose when she finds out her husband has been executed in Rio to cover up a corruption scandal. A former Special Forces recruit, she heads to Brazil with fists, blood and explosives, to Know the truth', 'popularity': 8.0462, 'poster_path': '/7GC0TEOQ1ljAhtvcwdthAbb5D3h.jpg', 'rele ...
# {'page': 9, 'results': [{'adult': False, 'backdrop_path': '/diVcZzeebNQuT4wKiflNP76VcsY.jpg', 'genre_ids': [35, 28], 'id': 1094138, 'original_language': 'en', 'original_title': 'Jackpot!', 'overview': "In the near future, a 'Grand Lottery' has been established - the catch: kill the winner before sundown to legally claim their multi-billion dollar jackpot. When Katie Kim mistakenly finds herself with the winning ticket, she reluctantly joins forces with amateur lottery protection agent Noel Cassidy who must get her to sundown in exchange for a piece of her prize.", 'popularity': 8.801, 'poster_path': '/7vv0NTaQGOO7M5ZMerp1vMFJsby.jpg', 'release_date': '2024-08-13', 'title': 'Jackpot!', 'video': False, 'vote_average': 6.401, 'vote_count': 724}, {'adult': False, 'backdrop_path': '/xRr7mnOJ39bZtCRmVefrm3sBxX4.jpg', 'genre_ids': [80, 53, 28], 'id': 1090007, 'original_language': 'en', 'original_title': 'First Shift', 'overview': "NYPD veteran Mike and rookie Angela tackle a high-stakes day on New York's toughest streets, diving headfirst into a vortex of danger and action. Their adrenaline-fueled pursuits and unexpected threats unfold as they navigate perilous encounters. Amidst the chaos, intense challenges forge unbreakable bonds.", 'popularity': 8.6872, 'poster_path': '/ajsGI4JYaciPIe3gPgiJ3Vw5Vre.jpg', 'release_date': '2024-08-30', 'title': 'First Shift', 'video': False, 'vote_average': 5.5, 'vote_count': 32}, {'adult': False, 'backdrop_path': '/hlIq4fEopPo00ENY9OGdjXGRLH1.jpg', 'genre_ids': [53], 'id': 1243186, 'original_language': 'en', 'original_title': 'Demise', 'overview': 'After the ultimate betrayal by her husband, a woman gets a deadly taste for revenge in a tense and explosive tale of desire, obsession and vengeance.', 'popularity': 8.1876, 'poster_path': '/3RFkqeMh0lsoBdlsHNmJ2I0uec8.jpg', 'release_date': '2024-02-27', 'title': 'Demise', 'video': False, 'vote_average': 4.7, 'vote_count': 6}, {'adult': False, 'backdrop_path': '/ifRqavcREHdS0FN9KtVMXghgryK.jpg', 'genre_ids': [53, 18, 10749], 'id': 1026436, 'original_language': 'en', 'original_title': "Miller's Girl", 'overview': 'A talented young writer embarks on a creative odyssey when her teacher assigns a project that entangles them both.', 'popularity': 8.3761, 'poster_path': '/ieU0zUj7WhE0GrgpgofRH0sNjbI.jpg', 'release_date': '2024-01-18', 'title': "Miller's Girl", 'video': False, 'vote_average': 6.4, 'vote_count': 866}, {'adult': False, 'backdrop_path': '/2xnLwNvea2TSH0M0oc9iEq2KEVp.jpg', 'genre_ids': [878, 53, 12, 28], 'id': 1196470, 'original_language': 'fr', 'original_title': 'Survivre', 'overview': 'A couple celebrates their son’s birthday in the middle of the ocean on their boat. A violent storm hits and it brings up hungry creatures from the depths and they fight for their survival.', 'popularity': 7.6208, 'poster_path': '/7fR3KxswtY8OHHZuOUB9td58CRX.jpg', 'release_date': '2024-06-19', 'title': 'Survive', 'video': False, 'vote_average': 5.841, 'vote_count': 311}, {'adult': False, 'backdrop_path': '/hKmRJ4pWBjhVOhgLAFzXddpc69p.jpg', 'genre_ids': [12, 16, 18, 10751], 'id': 589018, 'original_language': 'fr', 'original_title': 'Sauvages', 'overview': "In Borneo, near the tropical forest, Kéria rescues a baby orangutang in the palm oil plantation where her father works. Kéria's cousin Selaï comes to live with them seeking refuge from the conflict between his indigenous tribe and the logging companies. Kéria, Selaï and the little orangutang, now named Oshi, will have to fight against their forest’s destruction.", 'popularity': 8.3538, 'poster_path': '/qC6yrKvmIEnkFVjpp0U7u02SiDQ.jpg', 'release_date': '2024-10-16', 'title': 'Savages', 'video': False, 'vote_average': 6.9, 'vote_count': 27}, {'adult': False, 'backdrop_path': '/hPU12uDcsVyaz368yjxa4BjDHXB.jpg', 'genre_ids': [28, 18, 53, 80], 'id': 1105407, 'original_language': 'en', 'original_title': 'Damaged', 'overview': 'A Chicago detective travels to Scotland after an emerging serial killer’s crimes match those th ...
# {'page': 10, 'results': [{'adult': False, 'backdrop_path': '/uXDwP5qPhuRyPpQ7WkLbE6t2z5W.jpg', 'genre_ids': [80, 35, 28], 'id': 877817, 'original_language': 'en', 'original_title': 'Wolfs', 'overview': "Hired to cover up a high-profile crime, a fixer soon finds his night spiralling out of control when he's forced to work with an unexpected counterpart.", 'popularity': 7.7085, 'poster_path': '/vOX1Zng472PC2KnS0B9nRfM8aaZ.jpg', 'release_date': '2024-09-20', 'title': 'Wolfs', 'video': False, 'vote_average': 6.541, 'vote_count': 1242}, {'adult': False, 'backdrop_path': '/994i0ocQkO6X10vQPA4ptueEFlh.jpg', 'genre_ids': [80, 18, 10749], 'id': 1108566, 'original_language': 'en', 'original_title': 'Killer Heat', 'overview': "An expat PI is hired to investigate a suspicious death in Crete, Greece, where jealousies run deep amongst the victim's powerful family.", 'popularity': 8.0352, 'poster_path': '/WiAEiqelck0NGWplhL5JQR12eg.jpg', 'release_date': '2024-09-25', 'title': 'Killer Heat', 'video': False, 'vote_average': 5.801, 'vote_count': 286}, {'adult': False, 'backdrop_path': '/9s9o9RT9Yj6nDuRJjnJm78WFoFl.jpg', 'genre_ids': [28, 27, 53, 878], 'id': 1051896, 'original_language': 'en', 'original_title': 'Arcadian', 'overview': 'In the near future, on a decimated Earth, Paul and his twin sons face terror at night when ferocious creatures awaken. When Paul is nearly killed, the boys come up with a plan for survival, using everything their father taught them to keep him alive.', 'popularity': 7.8506, 'poster_path': '/h4T8Xeydkw53h9uIbulYsss25UF.jpg', 'release_date': '2024-04-12', 'title': 'Arcadian', 'video': False, 'vote_average': 6.049, 'vote_count': 749}, {'adult': False, 'backdrop_path': '/rtpFIgy1YYw3kx7PCyNhi6xmEFb.jpg', 'genre_ids': [18, 36], 'id': 1102493, 'original_language': 'en', 'original_title': 'Small Things Like These', 'overview': 'In 1985, while working as a coal merchant to support his family, Bill Furlong discovers disturbing secrets kept by the local convent and uncovers truths of his own; forcing him to confront his past and the complicit silence of a small Irish town controlled by the Catholic Church.', 'popularity': 7.541, 'poster_path': '/rdcO38cbWFg002nXg5QYtk7Tz4L.jpg', 'release_date': '2024-11-01', 'title': 'Small Things Like These', 'video': False, 'vote_average': 6.74, 'vote_count': 369}, {'adult': False, 'backdrop_path': '/e906cyPR9attUUJskwlwYUq8LTI.jpg', 'genre_ids': [18, 36], 'id': 1013406, 'original_language': 'en', 'original_title': 'Modi, Three Days on the Wing of Madness', 'overview': 'A 72-hour whirlwind in the life of bohemian artist Amedeo Modigliani, known as Modi to his friends, follows a chaotic series of events through the streets of war torn Paris in 1916. On the run from the police, his desire to end his career and leave the city is dismissed by fellow artists Maurice Utrillo, Chaim Soutine and Modi’s muse, Beatrice Hastings. Modi seeks advice from his art dealer and friend, Leopold Zborowski — however, after a night of hallucinations, the chaos in Modi’s mind reaches a crescendo when faced with an American collector, Maurice Gangnat, who has the power to change his life.', 'popularity': 7.8941, 'poster_path': '/K5hGnee6HSq7YoJZPSY1TbsBMv.jpg', 'release_date': '2024-12-05', 'title': 'Modi, Three Days on the Wing of Madness', 'video': False, 'vote_average': 6.1, 'vote_count': 17}, {'adult': False, 'backdrop_path': '/fquVJ2v5NAW96sRfFAw4vXR5zla.jpg', 'genre_ids': [27], 'id': 814889, 'original_language': 'en', 'original_title': 'Never Let Go', 'overview': 'As an evil takes over the world beyond their front doorstep, the only protection for a mother and her twin sons is their house and their family’s protective bond.', 'popularity': 7.377, 'poster_path': '/iwUoM3y77fov7bKyFMwpGMzRHyn.jpg', 'release_date': '2024-09-18', 'title': 'Never Let Go', 'video': False, 'vote_average': 6.1, 'vote_count': 500}, {'adult': False, 'backdrop_path': '/tpiqEVTLRz2Mq7eLq5DT8jSrp71.jpg', 'genre_ids': [878, 28, 12], 'id ...
# {'page': 11, 'results': [{'adult': False, 'backdrop_path': '/lA6KdSkCTxwzvqzPqxch997RabQ.jpg', 'genre_ids': [28, 53], 'id': 560016, 'original_language': 'en', 'original_title': 'Monkey Man', 'overview': 'Kid is an anonymous young man who ekes out a meager living in an underground fight club where, night after night, wearing a gorilla mask, he is beaten bloody by more popular fighters for cash. After years of suppressed rage, Kid discovers a way to infiltrate the enclave of the city’s sinister elite. As his childhood trauma boils over, his mysteriously scarred hands unleash an explosive campaign of retribution to settle the score with the men who took everything from him.', 'popularity': 8.1095, 'poster_path': '/4lhR4L2vzzjl68P1zJyCH755Oz4.jpg', 'release_date': '2024-04-03', 'title': 'Monkey Man', 'video': False, 'vote_average': 6.895, 'vote_count': 1223}, {'adult': False, 'backdrop_path': '/aX1P75MWK5BzjqPh8fR8HQoX27s.jpg', 'genre_ids': [18, 35], 'id': 1029955, 'original_language': 'en', 'original_title': 'Kinds of Kindness', 'overview': 'A triptych fable following a man without choice who tries to take control of his own life; a policeman who is alarmed that his wife who was missing-at-sea has returned and seems a different person; and a woman determined to find a specific someone with a special ability, who is destined to become a prodigious spiritual leader.', 'popularity': 7.7187, 'poster_path': '/50lPmjIpDs8gKfgK7fPIeKzpllh.jpg', 'release_date': '2024-05-30', 'title': 'Kinds of Kindness', 'video': False, 'vote_average': 6.501, 'vote_count': 1099}, {'adult': False, 'backdrop_path': '/h9YlRHAZWOWtGonllmj6JJg1FrE.jpg', 'genre_ids': [16, 10751, 28, 12, 14], 'id': 588648, 'original_language': 'zh', 'original_title': 'Dragonkeeper', 'overview': 'Set in Han Imperial China, the plot follows the adventures of enslaved girl Ping with ancient dragon Long Danzi. Dragons had been banished from the kingdom. Ping, an orphan, finds one of the last remaining dragon eggs. Palace guards force Ping to run away in order to return the dragon egg to the ocean and save all dragons from extinction. Ping discovers that she is a true Dragonkeeper.', 'popularity': 7.4431, 'poster_path': '/ggZGnJLzO3BTu7ysuuIzou3Oex5.jpg', 'release_date': '2024-04-11', 'title': 'Dragonkeeper', 'video': False, 'vote_average': 7.7, 'vote_count': 199}, {'adult': False, 'backdrop_path': '/s1tEYOzyK7QEtz0QZKmEZXoFhY4.jpg', 'genre_ids': [10402, 99], 'id': 1360818, 'original_language': 'en', 'original_title': 'LOUDER: The Soundtrack of Change', 'overview': 'A celebration of music and rallying cry that takes viewers on a journey across generations, eras, and genres, anchored by a female chorus of musical icons, whose songs, voices, and activism provided inspiration for the past and current fight for equality for all.', 'popularity': 7.8518, 'poster_path': '/uLlxVonZmMzgM2QL6D3YdgLDWgQ.jpg', 'release_date': '2024-10-16', 'title': 'LOUDER: The Soundtrack of Change', 'video': False, 'vote_average': 7.7, 'vote_count': 6}, {'adult': False, 'backdrop_path': '/3m7252MFY0YkOrr7SmnPEhuSha6.jpg', 'genre_ids': [80, 53, 37], 'id': 395817, 'original_language': 'en', 'original_title': 'The Thicket', 'overview': 'An innocent young man, Jack, goes on an epic quest to rescue his sister Lula after she has been kidnapped by the violent killer Cut Throat Bill and her gang. To save her, Jack enlists the help of a crafty bounty hunter named Reginald Jones, a grave-digging alcoholic son of an ex-slave, and a street-smart prostitute. The gang tracks Cut Throat Bill into the deadly no-man’s land known as The Big Thicket — a place where blood and chaos reign.', 'popularity': 7.477, 'poster_path': '/jsvk8e0HgITFX0gbDEjj6hOytsP.jpg', 'release_date': '2024-09-05', 'title': 'The Thicket', 'video': False, 'vote_average': 6.484, 'vote_count': 122}, {'adult': False, 'backdrop_path': '/2afZgLkzFb8I0cC4n4xNWl2g3dN.jpg', 'genre_ids': [18, 10749], 'id': 1404380, 'original_language': 'ml', 'original_title': 'Sap ...
# ...
# {'page': 97, 'results': [{'adult': False, 'backdrop_path': '/hm7TycVCKM8E3VjHcHZwfILFMOI.jpg', 'genre_ids': [99], 'id': 1259517, 'original_language': 'en', 'original_title': 'Sven', 'overview': "Sven gives us a unique insight into the success story that is Svennis' career, with both a focus on his journey to the top of football Europe and the incurable cancer diagnosis that came to the public's attention in early 2024.", 'popularity': 2.5452, 'poster_path': '/xXjLx3ZstCVOzNgOHBStVvJLivP.jpg', 'release_date': '2024-08-23', 'title': 'Sven', 'video': False, 'vote_average': 6.0, 'vote_count': 1}, {'adult': False, 'backdrop_path': None, 'genre_ids': [], 'id': 1297082, 'original_language': 'en', 'original_title': 'Demoneulogy', 'overview': 'Kathy Acker’s Empire of the Senseless is a lecture that critiques cultural desensitization and communication breakdowns, serving as a timeless socio-political parable. Paris-based artist Geoffroy C. Dedenis works with videos, photos, and collages, merging experimental and narrative styles across genres.', 'popularity': 2.7654, 'poster_path': '/1sOxgJBSVEwmZ1LkLZJyuNelnNM.jpg', 'release_date': '2024-04-26', 'title': 'Demoneulogy', 'video': False, 'vote_average': 0.0, 'vote_count': 0}, {'adult': False, 'backdrop_path': '/rp9MmFVHfe8C4XKQEeQ69qLQSeq.jpg', 'genre_ids': [35], 'id': 1273470, 'original_language': 'zh', 'original_title': '窗前明月，咣！', 'overview': 'When gold medal lawyer Hu Gongping was having a secret meeting with his lover She Xiaoman, a body suddenly fell from the sky in the room. Hu Gongping called for help from his assistant Zhu Shiqi, but he didn\'t want to panic and blurt out several lies, causing a series of chaos! With the emergence of various "family members" such as Xiong Dali, Lin Luanfeng, and Shi Shi, the situation continues to escalate. As the matter is about to be exposed, how will this hilarious "accident" end?', 'popularity': 3.4184, 'poster_path': '/6ToNowvMedCuGjm3SZCn6DUWsWl.jpg', 'release_date': '2024-12-28', 'title': 'Out of Order', 'video': False, 'vote_average': 3.5, 'vote_count': 4}, {'adult': False, 'backdrop_path': '/mw6ucZfre773Fb1BSSsvsvV8a9m.jpg', 'genre_ids': [35, 80, 53], 'id': 1051023, 'original_language': 'hi', 'original_title': 'मर्डर मुबारक', 'overview': 'When a gym trainer is murdered at an elite Delhi club, a wily investigator unravels the sordid secrets of its ultrarich members to find the killer.', 'popularity': 3.1888, 'poster_path': '/joU5VihgUvkhyPnhzxfjmWk32rd.jpg', 'release_date': '2024-03-15', 'title': 'Murder Mubarak', 'video': False, 'vote_average': 6.3, 'vote_count': 48}, {'adult': False, 'backdrop_path': '/kZCwaQYYz35a57MIFrXRJIpnoUO.jpg', 'genre_ids': [18, 36, 53], 'id': 1241486, 'original_language': 'zh', 'original_title': '解密', 'overview': "In the 1940s, the world was in turmoil, and it was crucial to decipher the enemy's communication codes in a timely and accurate manner. Rong Jinzhen has shown amazing mathematical talent since her childhood, and because she solved the problems assigned by her math teacher, she was noticed by more people, and even walked into the door of code-breaking by mistake.", 'popularity': 2.9541, 'poster_path': '/zVbQ7CdjNbInS6ZIY0dS6KBZROi.jpg', 'release_date': '2024-07-25', 'title': 'Decoded', 'video': False, 'vote_average': 6.0, 'vote_count': 21}, {'adult': False, 'backdrop_path': None, 'genre_ids': [80, 18], 'id': 1432708, 'original_language': 'en', 'original_title': 'Murder Queens', 'overview': 'Set in 1959, Macon, Georgia restaurant owner and convicted serial killer Anjette Lyles, gives a final prison interview to Atlanta Constitution Reporter, Celestine Sibley. Based on a true story.', 'popularity': 3.3789, 'poster_path': '/nUmazZ5dJzUZj0rMICRzBLOa4Fi.jpg', 'release_date': '2024-08-17', 'title': 'Murder Queens', 'video': False, 'vote_average': 0.0, 'vote_count': 0}, {'adult': False, 'backdrop_path': '/nn2HYaPRiOytno9pxC652ULRzfU.jpg', 'genre_ids': [28, 35, 18], 'id': 1195394, 'original_language': 'ml', 'or ...
# {'page': 98, 'results': [{'adult': False, 'backdrop_path': None, 'genre_ids': [99], 'id': 1398717, 'original_language': 'pt', 'original_title': 'Cidade da Criança: Uma História Afetiva', 'overview': 'Documentary that presents the history of the Brazilian amusement park "Cidade da Criança".', 'popularity': 2.9605, 'poster_path': None, 'release_date': '2024-12-06', 'title': 'Cidade da Criança: Uma História Afetiva', 'video': False, 'vote_average': 0.0, 'vote_count': 0}, {'adult': False, 'backdrop_path': '/vuMXXuW2TItl2Wn3qDIQfy1LlCK.jpg', 'genre_ids': [], 'id': 1315905, 'original_language': 'ko', 'original_title': '탈옥정사', 'overview': 'How do inmates in a correctional facility satisfy their sexual desires? A full-fledged confined-space erotic story depicting the precarious prison life of prison guards and inmates involved in sex penpals begins!', 'popularity': 2.9602, 'poster_path': '/tXQTZ5JUrPS82zEzcxti6zf2y7b.jpg', 'release_date': '2024-06-14', 'title': 'Jailbreak Affair', 'video': False, 'vote_average': 10.0, 'vote_count': 1}, {'adult': False, 'backdrop_path': '/AwzMgSKBJkTW2nU8z0pSdqvbhWS.jpg', 'genre_ids': [18, 9648], 'id': 889820, 'original_language': 'el', 'original_title': 'Arcadia', 'overview': 'Neurologist Katerina and former doctor Yannis are heading off to a deserted seaside resort. Silence descends on the car as they travel across dunes in a windy autumn, matching the less-than-pleasant occasion: Yannis has been called to identify the victim of a tragic accident at the hospital of the small town. When the local policeman informs them that the victim’s vehicle had plunged over the parapet of a stone bridge and leads them to the morgue, Katerina sees her worst suspicions confirmed. Together with Yannis, but also on her own nightly excursions to a mysterious, rustic beach bar called Arcadia, they begin to put the pieces of the puzzle together, revealing a haunting story of love, loss, acceptance and letting go.', 'popularity': 2.9602, 'poster_path': '/lIV1jcEqoRrY5rMHJTxSdaTi82T.jpg', 'release_date': '2024-02-18', 'title': 'Arcadia', 'video': False, 'vote_average': 8.0, 'vote_count': 1}, {'adult': False, 'backdrop_path': '/wLErqPGsc6leCidTqzE6BmJE6TI.jpg', 'genre_ids': [18, 10749, 35, 14], 'id': 1240834, 'original_language': 'ja', 'original_title': '不死身ラヴァーズ', 'overview': 'Rino believes that "the man of her destiny" is Jun who always disappears from her whenever she feels their love for each other. In their lifetime, they meet many times and Rino is 100% focused on him every time. These encounters and separations are repeated in many circumstances. What could be the miraculous result of her persistent love for him?', 'popularity': 2.9597, 'poster_path': '/34e4Y9sVUPgRPJSZ9TSaky9SKeS.jpg', 'release_date': '2024-05-10', 'title': 'Undead Lovers', 'video': False, 'vote_average': 8.0, 'vote_count': 1}, {'adult': False, 'backdrop_path': '/aUPw0KLmc4xnvjYI0S1xnn8Wp2s.jpg', 'genre_ids': [99, 36], 'id': 1245300, 'original_language': 'es', 'original_title': 'Marisol: llámame Pepa', 'overview': 'A portrait of the actress and singer Pepa Flores, an incarnation of the recent history of Spain, who, in just twenty-five years of intense career, went from being Marisol, child prodigy of the Franco dictatorship, to being one of the first communist militants, icon of the Transition; an idol of the masses who became a discreet person after having claimed her right to remain silent.', 'popularity': 2.9596, 'poster_path': '/pFQ1hwx84w1d8k5VMA8NFJVLMmS.jpg', 'release_date': '2024-05-10', 'title': 'Marisol: llámame Pepa', 'video': False, 'vote_average': 6.5, 'vote_count': 2}, {'adult': False, 'backdrop_path': None, 'genre_ids': [80, 35], 'id': 1287853, 'original_language': 'hi', 'original_title': 'Dead Dead Full Dead', 'overview': 'Junior police officers Balraam and Zubeida make a cute couple, but not the most diligent detectives. Called to a posh apartment tower to investigate a reported murder, the seemingly straightforward case quickly bec ...
# {'page': 99, 'results': [{'adult': False, 'backdrop_path': '/aeleqjKBU6MYdt84o51Un1SmrJI.jpg', 'genre_ids': [18, 878], 'id': 1171192, 'original_language': 'ru', 'original_title': 'Контакты', 'overview': 'Life on Earth has changed after the visit of alien ships hovering in various parts of the planet. Their passengers — biopages or "Vitaliki", as they are popularly called — produce a substance called "prak". Its purpose, as well as the purpose of the aliens\' visit, is unknown, but nurse Nina (Irina Salikova) from a quiet provincial town hopes to help her sick father with the help of prak. After contacting Vitalik, Nina learns the truth about extraterrestrial beings, which completely changes her life.', 'popularity': 2.8774, 'poster_path': '/28Dsxn3jqVkPXSE8yB07Feoh9XD.jpg', 'release_date': '2024-07-04', 'title': 'Encounters', 'video': False, 'vote_average': 5.0, 'vote_count': 1}, {'adult': False, 'backdrop_path': None, 'genre_ids': [27, 35], 'id': 1394825, 'original_language': 'en', 'original_title': 'The Moistest', 'overview': 'Aimee, beat down by the extravagant birthday demands of her friend group, decides to throw herself the birthday party to end all birthday parties – and she’s inviting a gruesome guest.', 'popularity': 3.0634, 'poster_path': '/e9PjHH5xh16cVST0BHnv7gXev83.jpg', 'release_date': '2024-10-18', 'title': 'The Moistest', 'video': False, 'vote_average': 0.0, 'vote_count': 0}, {'adult': False, 'backdrop_path': '/zTCZD3GTWszmuQnmMMTib8f0RG9.jpg', 'genre_ids': [28, 80], 'id': 1089737, 'original_language': 'te', 'original_title': 'సైంధ\u200cవ్', 'overview': 'The father of a sick child takes on a criminal gang running a pharmaceutical racket.', 'popularity': 3.3623, 'poster_path': '/x7c6RQCWmrl92rPg3JhzzalF4SQ.jpg', 'release_date': '2024-01-13', 'title': 'Saindhav', 'video': False, 'vote_average': 5.6, 'vote_count': 8}, {'adult': False, 'backdrop_path': '/6ct1rYiv6IwmLrEwSLpm9uIKC20.jpg', 'genre_ids': [35], 'id': 1336926, 'original_language': 'nl', 'original_title': 'Project Herbert', 'overview': 'When his mother decides it is finally time Herbert moves out, the reserved municipal civil servant ends up in his deceased dad’s conked-out old timer. The housing market is overheated, so finding a house is impossible. After several frantic efforts, due to a mistake he is admitted to a students’ dorm. For the first time, Herbert has to learn what it means to share a bathroom, shower, kitchen and living room with lots of people. And the students suddenly have to deal with a forty-something in their chaotic party house. Will these improbable housemates manage to find domestic peace?', 'popularity': 3.4346, 'poster_path': '/sHl4JfIN1PnLXFsoFCxBHGcKBO9.jpg', 'release_date': '2024-09-23', 'title': 'Project Herbert', 'video': False, 'vote_average': 7.0, 'vote_count': 1}, {'adult': False, 'backdrop_path': '/9Nh7CeAgbH4r1rh6yqve7j8Pwcc.jpg', 'genre_ids': [28, 80, 18], 'id': 1327791, 'original_language': 'zh', 'original_title': '热血天使', 'overview': 'To drive out local criminals, resilient leader Guan Xing relies on her strong sense of justice to overcome challenges and protect her community.', 'popularity': 2.8755, 'poster_path': '/OzRkkTqP34z5vJxyqvW01UVVjy.jpg', 'release_date': '2024-08-10', 'title': 'Hot Blooded Angel', 'video': False, 'vote_average': 1.0, 'vote_count': 1}, {'adult': False, 'backdrop_path': '/jLvNVWqyfvaMaYrOwtuVmNaGGXQ.jpg', 'genre_ids': [36, 10402, 18], 'id': 1002155, 'original_language': 'fr', 'original_title': 'Monsieur Aznavour', 'overview': 'From his poor childhood to his rise to fame, from his triumphs to his failures, from Paris to New York, discover the exceptional journey of an artist. Intimate, intense, fragile and indestructible, devoted to his art until the very end, here is one of the most immortal singers of all time: MONSIEUR AZNAVOUR.', 'popularity': 2.8813, 'poster_path': '/23FkaTaAosaTcTgyuJdTf7TvcJu.jpg', 'release_date': '2024-10-23', 'title': 'Monsieur Aznavour', 'video': False, 'vote_average ...

# %%
df_movies_id
# Out:
#            id        date                                 title
# 0     1186350  2024-12-20                                 Marco
# 1     1357886  2024-04-22                     Django Undisputed
# 2     1053008  2024-10-09                     Fight Another Day
# 3     1032448  2024-02-13                     Jurassic Triangle
# 4     1109406  2024-11-10                            Compulsion
# ...       ...         ...                                   ...
# 1975  1189826  2024-06-07                         Little Hearts
# 1976  1301198  2024-06-05                        Tired Melodies
# 1977  1305193  2024-12-06  Standing on the Shoulders of Kitties
# 1978  1162931  2024-11-15                            The Embers
# 1979  1250657  2024-03-01      Scratches from Baiestorf & Souza
#
# [1980 rows x 3 columns]

# %%
df_movies_id["id"].values
# Out:
# array([1186350, 1357886, 1053008, ..., 1305193, 1162931, 1250657],
#       shape=(1980,))

# %%
dict_movies = {"title":[], "revenue":[], "budget":[]}
for q in df_movies_id["id"].values[:11]:
    response = requests.get(f'https://api.themoviedb.org/3/movie/{q}?api_key=' +  tmdb.api_key + "&append_to_response=keywords,credits")
    highest_revenue = response.json()
    try:
        budget = highest_revenue["budget"]
        revenue = highest_revenue["revenue"]
        title = highest_revenue['title']
        dict_movies["title"].append(title)
        dict_movies["revenue"].append(revenue)
        dict_movies["budget"].append(budget)
    except:
        continue
df_movies_2024 = pd.DataFrame(dict_movies)

# %%
df_movies_2024
# Out:
#                                               title   revenue    budget
# 0                                             Marco  11559000   3467000
# 1                                 Django Undisputed         0         3
# 2                                 Fight Another Day         0         0
# 3                                 Jurassic Triangle         0         0
# 4                                        Compulsion         0         0
# 5                                  Bloody Axe Wound     76178         0
# 6   The Day the Earth Blew Up: A Looney Tunes Movie  15076954  15000000
# 7                                 Possession Street         0         0
# 8                                            Humane         0         0
# 9                                        Your Fault         0         0
# 10                                  Striking Rescue         0         0

# %%
df_movies_2024.to_csv("data/df_movies_2024.csv")

# %%
df_movies_id.head()
# Out:
#         id        date              title
# 0  1186350  2024-12-20              Marco
# 1  1357886  2024-04-22  Django Undisputed
# 2  1053008  2024-10-09  Fight Another Day
# 3  1032448  2024-02-13  Jurassic Triangle
# 4  1109406  2024-11-10         Compulsion

# %% [markdown]
# ## Accediendo a datos de Youtube

# %%
# %pip install google-api-python-client
# Out:
# Requirement already satisfied: google-api-python-client in c:\users\alberto romero\appdata\local\programs\python\python313\lib\site-packages (2.172.0)
# Requirement already satisfied: httplib2<1.0.0,>=0.19.0 in c:\users\alberto romero\appdata\local\programs\python\python313\lib\site-packages (from google-api-python-client) (0.22.0)
# Requirement already satisfied: google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0 in c:\users\alberto romero\appdata\local\programs\python\python313\lib\site-packages (from google-api-python-client) (2.40.3)
# Requirement already satisfied: google-auth-httplib2<1.0.0,>=0.2.0 in c:\users\alberto romero\appdata\local\programs\python\python313\lib\site-packages (from google-api-python-client) (0.2.0)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5 in c:\users\alberto romero\appdata\local\programs\python\python313\lib\site-packages (from google-api-python-client) (2.25.1)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in c:\users\alberto romero\appdata\local\programs\python\python313\lib\site-packages (from google-api-python-client) (4.2.0)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in c:\users\alberto romero\appdata\local\programs\python\python313\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client) (1.70.0)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.19.5 in c:\users\alberto romero\appdata\local\programs\python\python313\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client) (6.31.1)
# Requirement already satisfied: proto-plus<2.0.0,>=1.22.3 in c:\users\alberto romero\appdata\local\programs\python\python313\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client) (1.26.1)
# Requirement already satisfied: requests<3.0.0,>=2.18.0 in c:\users\alberto romero\appdata\local\programs\python\python313\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client) (2.32.4)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\alberto romero\appdata\local\programs\python\python313\lib\site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0->google-api-python-client) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\alberto romero\appdata\local\programs\python\python313\lib\site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0->google-api-python-client) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\alberto romero\appdata\local\programs\python\python313\lib\site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0->google-api-python-client) (4.9.1)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in c:\users\alberto romero\appdata\local\programs\python\python313\lib\site-packages (from httplib2<1.0.0,>=0.19.0->google-api-python-client) (3.2.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\alberto romero\appdata\local\programs\python\python313\lib\site-packages (from requests<3.0.0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\alberto romero\appdata\local\programs\python\python313\lib\site-packages (from requests<3.0.0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\alberto romero\appdata\local\programs\python\python313\lib\site-packages (from requests<3.0.0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\alberto romero\appdata\local\programs\python\python313\lib\site-packages (from requests<3.0.0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client) (2024.12.14)
# Requirement already satisfied: pyasn1>=0.1.3 in c:\users\alberto romero\appdata\local\programs\python\python313\lib\site-packages (from rsa<5,>=3.1.4->google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0->google-api-python-client) (0.6.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
# Importamos librerías

from googleapiclient.discovery import build

# %% [markdown]
# ### Información de una Canal de youtube (Primera request)

# %% [markdown]
# You may be watching the video or just happened to visit a link to a video.
#
# The video ID will be located in the URL of the video page, right after the v= URL parameter.
#
# In this case, the URL of the video is: https://www.youtube.com/watch?v=fn3KWM1kuAw. Therefore, the ID of the video is fn3KWM1kuAw

# %%
#   https://cloud.google.com/console para crear proyecto y habilitar la api de youtube v3
#   https://github.com/googleapis/google-api-python-client documentacion de la api de youtube
# Para mas informacion de las diferentes busquedas de datos disponibles como sus parametros ir a https://developers.google.com/youtube/v3/getting-started?hl=es-419
# Ensure that you have enabled the YouTube Data API for your project.
#api_key_y = "tu api key"

youtube = build("youtube", "v3", developerKey=api_key_y)


request = youtube.channels().list(
    part="statistics",
    id = "UCy5znSnfMsDwaLlROnZ7Qbg"
)

response = request.execute()

# %%
response
# Out:
# {'kind': 'youtube#channelListResponse',
#  'etag': 'NoT7qSqagyBnlA2_q8cONK-w7aE',
#  'pageInfo': {'totalResults': 1, 'resultsPerPage': 5},
#  'items': [{'kind': 'youtube#channel',
#    'etag': 'iC8HEQ0U1pPE5_PtEbbOoMLK63Y',
#    'id': 'UCy5znSnfMsDwaLlROnZ7Qbg',
#    'statistics': {'viewCount': '54769637',
#     'subscriberCount': '903000',
#     'hiddenSubscriberCount': False,
#     'videoCount': '231'}}]}

# %% [markdown]
# ### Información videos de acuerdo a una búsqueda (query)

# %%
search_response = youtube.search().list(
    q="Chat gpt",
    part="snippet",
    order="viewCount",
    type="video",
    maxResults=50
).execute()

# %%
search_response["items"][0]["snippet"]
# Out:
# {'publishedAt': '2024-01-11T14:36:20Z',
#  'channelId': 'UC_mTME_0z6pEteDMRUUwKlA',
#  'title': 'ChatGPT, Show Me Chicken Nuggets',
#  'description': 'twitch.tv/teddywang86.',
#  'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/1t6FNyW3JmE/default.jpg',
#    'width': 120,
#    'height': 90},
#   'medium': {'url': 'https://i.ytimg.com/vi/1t6FNyW3JmE/mqdefault.jpg',
#    'width': 320,
#    'height': 180},
#   'high': {'url': 'https://i.ytimg.com/vi/1t6FNyW3JmE/hqdefault.jpg',
#    'width': 480,
#    'height': 360}},
#  'channelTitle': 'teddywang86',
#  'liveBroadcastContent': 'none',
#  'publishTime': '2024-01-11T14:36:20Z'}

# %%
dict_videos = {"id":[], "channelTitle":[], "publish":[], "description":[], "title_video":[]} # Se crea diccionario con valores de listas vacías

for i in search_response["items"]: # Iterar listas
    dict_videos["id"].append(i["id"]["videoId"]) 
    dict_videos["channelTitle"].append(i["snippet"]["channelTitle"])
    dict_videos["publish"].append(i["snippet"]["publishTime"])
    dict_videos["description"].append(i["snippet"]["description"])
    dict_videos["title_video"].append(i["snippet"]["title"])

df_video_y = pd.DataFrame(dict_videos)
df_video_y
# Out:
#              id             channelTitle               publish  \
# 0   1t6FNyW3JmE              teddywang86  2024-01-11T14:36:20Z
# 1   vy-5CeyOKkQ              teddywang86  2024-09-10T12:51:58Z
# 2   7i9gM8dJcBo              teddywang86  2024-01-31T14:31:14Z
# 3   KgYvmhCrm7c                      SLG  2023-11-27T20:00:12Z
# 4   UHII6fBlDbI              teddywang86  2024-01-12T12:25:23Z
# 5   xssujNNEwWI              teddywang86  2025-02-08T10:48:27Z
# 6   i-WypxLBGhY            Evelyn Hutani  2024-11-20T10:58:54Z
# 7   gj0Y_JFWaTA              teddywang86  2023-12-25T13:01:37Z
# 8   kHWyJ-baLnE                     Zdak  2024-12-25T12:52:33Z
# 9   hptchvNnsoI              teddywang86  2025-05-28T03:03:33Z
# 10  dvQWEI1uiBw          Diosdado Juarez  2025-01-29T21:36:09Z
# 11  WQdDoK0bqnw               Kaizzzzlol  2025-02-20T14:11:23Z
# 12  dPZ8uUvrgZQ           Trippy Kitchen  2023-01-21T16:48:41Z
# 13  TwPFDbuBLcc           Helen Christie  2024-07-31T16:00:34Z
# 14  0xZQ0Sut8JY                BadgerBOI  2024-12-20T11:00:03Z
# 15  ZNHjgcprFSs              teddywang86  2025-05-20T05:21:47Z
# 16  btgLXPgLXzo              cardogjones  2023-05-12T02:54:40Z
# 17  Hj_tvOn40zg              teddywang86  2024-09-16T07:43:06Z
# 18  F0gkQ4-aXY4              teddywang86  2025-06-11T12:04:43Z
# 19  rqI3xF9vDd0    The Royal Institution  2023-09-13T16:29:50Z
# 20  fBhMqSXGRhI              teddywang86  2024-01-16T06:05:51Z
# 21  JJFXdtJr-oI              teddywang86  2025-06-07T11:26:54Z
# 22  vJefOB8kec8             Dhruv Rathee  2023-07-16T15:05:29Z
# 23  t0x6WNItdX4             Agnit Shorts  2023-04-12T04:30:22Z
# 24  Twpp0mJjDRQ    Mysterious Chronicles  2023-12-26T22:53:34Z
# 25  GjtZye9DC5Q              teddywang86  2025-05-27T07:11:58Z
# 26  acGZaDV1o04       HumorMuyArtificial  2024-05-12T11:24:59Z
# 27  71jJ9ovMAqE                   Ashley  2025-03-01T22:58:43Z
# 28  6q2xr2hBncc              teddywang86  2025-02-10T15:15:28Z
# 29  Ur5u27nLIhk           Watch With Sam  2025-02-13T12:47:08Z
# 30  g5EMu5QUEsE     Liv Swearingen (LIV)  2025-09-08T15:41:48Z
# 31  PQME8X-fb1M                   Grinly  2025-05-21T15:27:17Z
# 32  BjMMqm-v9CY                Mac Macha  2025-05-09T11:39:28Z
# 33  sITD5peEOmM                   Vulrax  2024-10-15T14:10:01Z
# 34  nmBX9h6JfmI            Jules Walcott  2025-06-27T22:42:28Z
# 35  OHTy96KPZHY              teddywang86  2024-09-24T14:58:03Z
# 36  5gQIJB9SZ78               RandomQuiz  2024-07-20T19:45:47Z
# 37  cDSI29p6KsU           Ayush More 2.0  2024-01-12T04:23:51Z
# 38  FdZ8LKiJBhQ             Nate Gentile  2023-03-07T21:24:03Z
# 39  F16b1s5BkoQ                  BATZAIR  2023-03-28T16:00:20Z
# 40  j02OZRjf2d8  New Media Academy Life   2023-03-07T18:00:08Z
# 41  vx8mVmRQqms              teddywang86  2024-09-20T03:11:56Z
# 42  CRe_O0_W3-8       learn with shamani  2025-08-03T12:59:53Z
# 43  5MmxPFDLaEs            Alex O'Connor  2024-08-08T12:42:19Z
# 44  AXn2XVLf7d0         The AI Advantage  2022-12-08T21:56:41Z
# 45  U9_QJGS44Qc                снепирайз  2025-06-27T13:59:41Z
# 46  mNxB1g1-Otg                Unchained  2023-12-22T16:16:28Z
# 47  60ejKe3vcZM                 Caldruki  2025-06-26T21:51:42Z
# 48  d1yNLkKYkwI                снепирайз  2025-06-25T20:05:48Z
# 49  FtIEhrZD_5I                 Alakh GK  2023-06-21T16:22:23Z
#
#                                           description  \
# 0                              twitch.tv/teddywang86.
# 1
# 2                              twitch.tv/teddywang86.
# 3
# 4                              twitch.tv/teddywang86.
# 5
# 6
# 7
# 8   ChatGPT cooked bro, fr Funny Chat GPT conversa...
# 9
# 10
# 11
# 12
# 13            comedy #funnyvideo #chatgpt #ai #robot.
# 14  In this short meme we see how stupid AI (chat ...
# 15
# 16                                            shorts.
# 17
# 18
# 19  Watch mathematician Kit Yates describe the pro...
# 20                             twitch.tv/teddywang86.
# 21
# 22  Join my AI Course: https://academy.dhruvrathee...
# 23                       I DEFEATED CHAT GPT #shorts.
# 24  Immerse yourself in a groundbreaking fusion of...
# 25
# 26  Este canal se dedica a crear videos con imagen...
# 27
# 28  Twitch: https://www.twitch.tv/teddywang86 Disc...
# 29  Motivation , Inspiration or Information? Just ...
# 30
# 31  Get ready to laugh out loud! Here's another me...
# 32
# 33  shorts guess the emoji games and hard choice g...
# 34
# 35
# 36  IA CHISTES GPT 12 #randomquizgo #chatgpt #ia #...
# 37
# 38  REGISTRATE A LA GTC Y ASISTE A UNA SESIÓN PARA...
# 39
# 40  رحلة داخل الذكاء الاصطناعي اللي عارف ومش عارف ...
# 41
# 42
# 43
# 44  In this tutorial, I'll be showing you how to u...
# 45  Всем хай, Меня зовут снепирайз! Добро пожалова...
# 46  Code : unchained sur Fortnite ! Abonne-toi à m...
# 47
# 48  Всем хай, Меня зовут снепирайз! Добро пожалова...
# 49                      ChatGPT #HowToUseChatGPT #AI.
#
#                                           title_video
# 0                    ChatGPT, Show Me Chicken Nuggets
# 1                           ChatGPT, Show Me an Apple
# 2                            ChatGPT, Repeat After Me
# 3             I asked Chat GPT to make an angry puppy
# 4                     ChatGPT, Show Me Mac and Cheese
# 5                       ChatGPT, Show Me Dragon Fruit
# 6                          Chat GPT kalo jd manusia 🤡
# 7                        ChatGPT, Show Me a Hamburger
# 8                                         #tf2edit ☠️
# 9                               ChatGPT, Show Me Rice
# 10                   CHAT GPT me dijo algo raro😰😱🤯😵‍💫
# 11  Notes❌ Chatgpt✅ #chatgpt #exams #studentlife #...
# 12                Chat GPT A.I. Ki help se banai dish
# 13                                    nobody: ChatGPT
# 14                          Chat GPT isn&#39;t smart🤡
# 15                   ChatGPT, Show Me Dubai Chocolate
# 16                       Funny ChatGPT Conversations!
# 17                   ChatGPT, Show Me a Chocolate Bar
# 18                             ChatGPT, Show Me Water
# 19  How to fool Chat GPT with non-linear thinking ...
# 20                          ChatGPT, Show Me American
# 21                     ChatGPT, Show Me Instant Ramen
# 22  The Truth about Artificial Intelligence and Ch...
# 23                     I DEFEATED ChatGPT !!! #shorts
# 24  Chat GPT AI Generated Image of God #mystery #a...
# 25                         ChatGPT, Show Me a Twinkie
# 26  📱Teléfono de $1 vs $1,000,000,000 🤑💸 COMENTA C...
# 27                                       El chat GPT:
# 28                         ChatGPT, Show Me an Orange
# 29                 Narendra Modi Exposed Chat Gpt 😲🔥💯
# 30                                 ChatGBT Be Like...
# 31                  i can&#39;t win against ChatGPT 💔
# 32  Chat GPT vs Amma | Mac Macha | Family comedy |...
# 33                        I ask Chat GPT... 😱 #shorts
# 34            Asking chat gpt to pick my hair color…😅
# 35                 ChatGPT, Show Me Lays Potato Chips
# 36  😂 IA CHISTES GPT 12 😂 #randomquizgo #chatgpt #...
# 37                  I ask Chat GPT #AyushMore #Shorts
# 38  ¿Cómo funciona ChatGPT? La revolución de la In...
# 39                     Quand Timéo découvre Chat GPT…
# 40                                  Chat GPT | الدحيح
# 41                      ChatGPT, Show Me a Watermelon
# 42  Unique Way To Use Chat GPT #shorts #rajshamani...
# 43                                  ChatGPT is a Liar
# 44         How To Use ChatGPT by OpenAI For Beginners
# 45                     Чат ГПТ Покажи Мне Драгон Фрут
# 46  J&#39;ai demandé à Chat GPT de me faire un Chi...
# 47  chat gpt had enough 😭😭🙏 #slideshow #funny #dan...
# 48                            Чат ГПТ Покажи Мне Рыбу
# 49  CHAT GPT और Artificial Intelligence | कैसे GPT...

# %%
search_response = youtube.search().list(
  q="Chat gpt",
  part="snippet",
  order="viewCount",
  type="video",
  maxResults=50
).execute()

id_video = []
channelTitle = []
publish_time = []
description = []
title_video = []

for search_result in search_response.get("items", []):
    id_video.append(search_result["id"]["videoId"])
    channelTitle.append(search_result["snippet"]["channelTitle"])
    publish_time.append(search_result["snippet"]["publishTime"])
    description.append(search_result["snippet"]["description"])
    title_video.append(search_result["snippet"]["title"])


duration = []
definition = []
closed_caption = []
license_content = []
madeforkids = []
view_count = []
like_count = []
favorite_count = []
comment_count = []
license = []

for id_video_search in id_video:
    video_info_response = youtube.videos().list(
      part = ["contentDetails", "statistics","status"],
      id = id_video_search
    ).execute()

    duration .append(video_info_response["items"][0]['contentDetails']["duration"])
    definition.append(video_info_response["items"][0]['contentDetails']["definition"])
    closed_caption.append(video_info_response["items"][0]['contentDetails']["caption"])
    license_content.append(video_info_response["items"][0]['contentDetails']["licensedContent"])
    madeforkids.append(video_info_response["items"][0]['status']["madeForKids"])
    license.append(video_info_response["items"][0]['status']["license"])
    view_count.append(video_info_response["items"][0]['statistics']["viewCount"])
    favorite_count.append(video_info_response["items"][0]['statistics']["favoriteCount"])
    comment_count.append(video_info_response["items"][0]['statistics'].get("commentCount", None))
    

df_youtube = pd.DataFrame({"id_video": id_video,
                           "Channel": channelTitle,
                           "title" : title_video,
                           "description": description,
                           "publish_time": publish_time,
                           "duration":duration,
                           "definiton": definition,
                           "closed_caption":closed_caption,
                           "license_content": license_content,
                           "madeforkids":madeforkids,
                           "license": license,
                           "view_count": view_count,
                           "favorite_count" : favorite_count,
                           "comment_count": comment_count
                           })
df_youtube.head()
# Out:
#       id_video      Channel                                    title  \
# 0  1t6FNyW3JmE  teddywang86         ChatGPT, Show Me Chicken Nuggets
# 1  vy-5CeyOKkQ  teddywang86                ChatGPT, Show Me an Apple
# 2  7i9gM8dJcBo  teddywang86                 ChatGPT, Repeat After Me
# 3  KgYvmhCrm7c          SLG  I asked Chat GPT to make an angry puppy
# 4  UHII6fBlDbI  teddywang86          ChatGPT, Show Me Mac and Cheese
#
#               description          publish_time duration definiton  \
# 0  twitch.tv/teddywang86.  2024-01-11T14:36:20Z     PT1M        hd
# 1                          2024-09-10T12:51:58Z    PT59S        hd
# 2  twitch.tv/teddywang86.  2024-01-31T14:31:14Z    PT32S        hd
# 3                          2023-11-27T20:00:12Z     PT1M        hd
# 4  twitch.tv/teddywang86.  2024-01-12T12:25:23Z     PT1M        hd
#
#   closed_caption  license_content  madeforkids  license view_count  \
# 0          false             True        False  youtube   83581218
# 1          false             True        False  youtube   50662726
# 2          false             True        False  youtube   44283845
# 3          false             True        False  youtube   34227948
# 4          false             True        False  youtube   33751493
#
#   favorite_count comment_count
# 0              0          5857
# 1              0          4948
# 2              0          2080
# 3              0          7575
# 4              0          1793

# %%
search_response
# Out:
# {'kind': 'youtube#searchListResponse',
#  'etag': 'j4M-7E1wa_t2r4SD2_qTvQ9iuJs',
#  'nextPageToken': 'CDIQAA',
#  'regionCode': 'ES',
#  'pageInfo': {'totalResults': 1000000, 'resultsPerPage': 50},
#  'items': [{'kind': 'youtube#searchResult',
#    'etag': '4C-nJQWAg_riGdO44rvug1Q1YDk',
#    'id': {'kind': 'youtube#video', 'videoId': '1t6FNyW3JmE'},
#    'snippet': {'publishedAt': '2024-01-11T14:36:20Z',
#     'channelId': 'UC_mTME_0z6pEteDMRUUwKlA',
#     'title': 'ChatGPT, Show Me Chicken Nuggets',
#     'description': 'twitch.tv/teddywang86.',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/1t6FNyW3JmE/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/1t6FNyW3JmE/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/1t6FNyW3JmE/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'teddywang86',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2024-01-11T14:36:20Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '6elhs_7wnOnYTodmOlhU-RVaNVM',
#    'id': {'kind': 'youtube#video', 'videoId': 'vy-5CeyOKkQ'},
#    'snippet': {'publishedAt': '2024-09-10T12:51:58Z',
#     'channelId': 'UC_mTME_0z6pEteDMRUUwKlA',
#     'title': 'ChatGPT, Show Me an Apple',
#     'description': '',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/vy-5CeyOKkQ/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/vy-5CeyOKkQ/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/vy-5CeyOKkQ/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'teddywang86',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2024-09-10T12:51:58Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '_EUQjQaYP6jXhoLpSzjnjVAg-pw',
#    'id': {'kind': 'youtube#video', 'videoId': '7i9gM8dJcBo'},
#    'snippet': {'publishedAt': '2024-01-31T14:31:14Z',
#     'channelId': 'UC_mTME_0z6pEteDMRUUwKlA',
#     'title': 'ChatGPT, Repeat After Me',
#     'description': 'twitch.tv/teddywang86.',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/7i9gM8dJcBo/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/7i9gM8dJcBo/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/7i9gM8dJcBo/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'teddywang86',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2024-01-31T14:31:14Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'nwCIyuOj1MM9doDIc7-a-Tc5H1U',
#    'id': {'kind': 'youtube#video', 'videoId': 'KgYvmhCrm7c'},
#    'snippet': {'publishedAt': '2023-11-27T20:00:12Z',
#     'channelId': 'UC9-57Ntc215xLogxRrvy57w',
#     'title': 'I asked Chat GPT to make an angry puppy',
#     'description': '',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/KgYvmhCrm7c/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/KgYvmhCrm7c/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/KgYvmhCrm7c/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'SLG',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2023-11-27T20:00:12Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '1xcCvDwVJBHT1l_fZwEJVrXHHhU',
#    'id': {'kind': 'youtube#video', 'videoId': 'UHII6fBlDbI'},
#    'snippet': {'publishedAt': '2024-01-12T12:25:23Z',
#     'channelId': 'UC_mTME_0z6pEteDMRUUwKlA',
#     'title': 'ChatGPT, Show Me Mac and Cheese',
#     'description': 'twitch.tv/teddywang86.',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/UHII6fBlDbI/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/UHII6fBlDbI/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/UHII6fBlDbI/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'teddywang86',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2024-01-12T12:25:23Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'cFmo2C4ldUyxjToqiuNmdBSzAgk',
#    'id': {'kind': 'youtube#video', 'videoId': 'xssujNNEwWI'},
#    'snippet': {'publishedAt': '2025-02-08T10:48:27Z',
#     'channelId': 'UC_mTME_0z6pEteDMRUUwKlA',
#     'title': 'ChatGPT, Show Me Dragon Fruit',
#     'description': '',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/xssujNNEwWI/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/xssujNNEwWI/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/xssujNNEwWI/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'teddywang86',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2025-02-08T10:48:27Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'uUdl209hN5IbMrF3pUcTorYjw6M',
#    'id': {'kind': 'youtube#video', 'videoId': 'i-WypxLBGhY'},
#    'snippet': {'publishedAt': '2024-11-20T10:58:54Z',
#     'channelId': 'UCB-Vy4-UoNHzhgntloAhC8w',
#     'title': 'Chat GPT kalo jd manusia 🤡',
#     'description': '',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/i-WypxLBGhY/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/i-WypxLBGhY/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/i-WypxLBGhY/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Evelyn Hutani',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2024-11-20T10:58:54Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'luTHS3j5SY11kTTWCVk5mORwrpU',
#    'id': {'kind': 'youtube#video', 'videoId': 'gj0Y_JFWaTA'},
#    'snippet': {'publishedAt': '2023-12-25T13:01:37Z',
#     'channelId': 'UC_mTME_0z6pEteDMRUUwKlA',
#     'title': 'ChatGPT, Show Me a Hamburger',
#     'description': '',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/gj0Y_JFWaTA/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/gj0Y_JFWaTA/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/gj0Y_JFWaTA/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'teddywang86',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2023-12-25T13:01:37Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'btB6fAywjjn-UO95CXV5euWIQNA',
#    'id': {'kind': 'youtube#video', 'videoId': 'kHWyJ-baLnE'},
#    'snippet': {'publishedAt': '2024-12-25T12:52:33Z',
#     'channelId': 'UC_485Ao_SxlCaBlOZORVsVQ',
#     'title': '#tf2edit ☠️',
#     'description': 'ChatGPT cooked bro, fr Funny Chat GPT conversation "Pick a number from 1 to 50" x Mortal Kombat skeleton smoking cigar ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/kHWyJ-baLnE/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/kHWyJ-baLnE/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/kHWyJ-baLnE/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Zdak',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2024-12-25T12:52:33Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'VPrQqlwpuNmbSOA9dFMNQPGhoBM',
#    'id': {'kind': 'youtube#video', 'videoId': 'hptchvNnsoI'},
#    'snippet': {'publishedAt': '2025-05-28T03:03:33Z',
#     'channelId': 'UC_mTME_0z6pEteDMRUUwKlA',
#     'title': 'ChatGPT, Show Me Rice',
#     'description': '',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/hptchvNnsoI/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/hptchvNnsoI/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/hptchvNnsoI/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'teddywang86',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2025-05-28T03:03:33Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'QEJrHRKa6ftwuJouU2aJy74PfYQ',
#    'id': {'kind': 'youtube#video', 'videoId': 'dvQWEI1uiBw'},
#    'snippet': {'publishedAt': '2025-01-29T21:36:09Z',
#     'channelId': 'UC0gnpMXQFvO9YsRZ_2adXPA',
#     'title': 'CHAT GPT me dijo algo raro😰😱🤯😵\u200d💫',
#     'description': '',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/dvQWEI1uiBw/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/dvQWEI1uiBw/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/dvQWEI1uiBw/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Diosdado Juarez',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2025-01-29T21:36:09Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'tVPkf_GGB0cSRM325ZIAwt1yaMU',
#    'id': {'kind': 'youtube#video', 'videoId': 'WQdDoK0bqnw'},
#    'snippet': {'publishedAt': '2025-02-20T14:11:23Z',
#     'channelId': 'UC8OoqY95p2mtzg7M5Q5fqpQ',
#     'title': 'Notes❌ Chatgpt✅ #chatgpt #exams #studentlife #relatable #ai #notes #students',
#     'description': '',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/WQdDoK0bqnw/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/WQdDoK0bqnw/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/WQdDoK0bqnw/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Kaizzzzlol',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2025-02-20T14:11:23Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'ltNeTSLPVeXDff1l0xbJ3pD-MBE',
#    'id': {'kind': 'youtube#video', 'videoId': 'dPZ8uUvrgZQ'},
#    'snippet': {'publishedAt': '2023-01-21T16:48:41Z',
#     'channelId': 'UCujkLB4kBWRn0YIGVczzEDg',
#     'title': 'Chat GPT A.I. Ki help se banai dish',
#     'description': '',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/dPZ8uUvrgZQ/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/dPZ8uUvrgZQ/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/dPZ8uUvrgZQ/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Trippy Kitchen',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2023-01-21T16:48:41Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'X-LoiUNK-1WJMJkakFqW-nKdwhc',
#    'id': {'kind': 'youtube#video', 'videoId': 'TwPFDbuBLcc'},
#    'snippet': {'publishedAt': '2024-07-31T16:00:34Z',
#     'channelId': 'UCWajepQsMCmNBUHVIPirk8g',
#     'title': 'nobody: ChatGPT',
#     'description': 'comedy #funnyvideo #chatgpt #ai #robot.',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/TwPFDbuBLcc/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/TwPFDbuBLcc/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/TwPFDbuBLcc/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Helen Christie',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2024-07-31T16:00:34Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'DoaJoR5pWUyquYqzxLoz34JZjTA',
#    'id': {'kind': 'youtube#video', 'videoId': '0xZQ0Sut8JY'},
#    'snippet': {'publishedAt': '2024-12-20T11:00:03Z',
#     'channelId': 'UCYA6b_yndwNvv6ZaE6g485g',
#     'title': 'Chat GPT isn&#39;t smart🤡',
#     'description': 'In this short meme we see how stupid AI (chat GPT) can be, when asked something. Peter griffin from family guy a dollar meme ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/0xZQ0Sut8JY/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/0xZQ0Sut8JY/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/0xZQ0Sut8JY/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'BadgerBOI',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2024-12-20T11:00:03Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'FAT5b3Jf_cxEJPrzHz25MVeT_4Q',
#    'id': {'kind': 'youtube#video', 'videoId': 'ZNHjgcprFSs'},
#    'snippet': {'publishedAt': '2025-05-20T05:21:47Z',
#     'channelId': 'UC_mTME_0z6pEteDMRUUwKlA',
#     'title': 'ChatGPT, Show Me Dubai Chocolate',
#     'description': '',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/ZNHjgcprFSs/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/ZNHjgcprFSs/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/ZNHjgcprFSs/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'teddywang86',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2025-05-20T05:21:47Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'wk7VZncOrDjW49TSxJKhJ_dxy78',
#    'id': {'kind': 'youtube#video', 'videoId': 'btgLXPgLXzo'},
#    'snippet': {'publishedAt': '2023-05-12T02:54:40Z',
#     'channelId': 'UCjU7AreEw9dXtCBc1uOpaTg',
#     'title': 'Funny ChatGPT Conversations!',
#     'description': 'shorts.',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/btgLXPgLXzo/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/btgLXPgLXzo/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/btgLXPgLXzo/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'cardogjones',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2023-05-12T02:54:40Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '2cZDGDEY-ErebPnPAbAn5yB43Q0',
#    'id': {'kind': 'youtube#video', 'videoId': 'Hj_tvOn40zg'},
#    'snippet': {'publishedAt': '2024-09-16T07:43:06Z',
#     'channelId': 'UC_mTME_0z6pEteDMRUUwKlA',
#     'title': 'ChatGPT, Show Me a Chocolate Bar',
#     'description': '',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/Hj_tvOn40zg/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/Hj_tvOn40zg/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/Hj_tvOn40zg/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'teddywang86',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2024-09-16T07:43:06Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '9dj3z-Dk23xkxRCTn1qZ0FDJJ4g',
#    'id': {'kind': 'youtube#video', 'videoId': 'F0gkQ4-aXY4'},
#    'snippet': {'publishedAt': '2025-06-11T12:04:43Z',
#     'channelId': 'UC_mTME_0z6pEteDMRUUwKlA',
#     'title': 'ChatGPT, Show Me Water',
#     'description': '',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/F0gkQ4-aXY4/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/F0gkQ4-aXY4/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/F0gkQ4-aXY4/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'teddywang86',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2025-06-11T12:04:43Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'OteORDrtXkY8F95vRMrqT1npQPQ',
#    'id': {'kind': 'youtube#video', 'videoId': 'rqI3xF9vDd0'},
#    'snippet': {'publishedAt': '2023-09-13T16:29:50Z',
#     'channelId': 'UCYeF244yNGuFefuFKqxIAXw',
#     'title': 'How to fool Chat GPT with non-linear thinking #chatgpt',
#     'description': 'Watch mathematician Kit Yates describe the problem with linear thinking and Chat GPT. Watch the full video here: ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/rqI3xF9vDd0/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/rqI3xF9vDd0/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/rqI3xF9vDd0/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'The Royal Institution',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2023-09-13T16:29:50Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '_ITuh-6aaAZwknZ6FKSEnEvfJpo',
#    'id': {'kind': 'youtube#video', 'videoId': 'fBhMqSXGRhI'},
#    'snippet': {'publishedAt': '2024-01-16T06:05:51Z',
#     'channelId': 'UC_mTME_0z6pEteDMRUUwKlA',
#     'title': 'ChatGPT, Show Me American',
#     'description': 'twitch.tv/teddywang86.',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/fBhMqSXGRhI/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/fBhMqSXGRhI/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/fBhMqSXGRhI/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'teddywang86',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2024-01-16T06:05:51Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'CWAjUoCxC6QNfZ4jUUOmJqZ_fE0',
#    'id': {'kind': 'youtube#video', 'videoId': 'JJFXdtJr-oI'},
#    'snippet': {'publishedAt': '2025-06-07T11:26:54Z',
#     'channelId': 'UC_mTME_0z6pEteDMRUUwKlA',
#     'title': 'ChatGPT, Show Me Instant Ramen',
#     'description': '',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/JJFXdtJr-oI/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/JJFXdtJr-oI/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/JJFXdtJr-oI/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'teddywang86',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2025-06-07T11:26:54Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'pfcYI2oI-fImstfwXO9PyfRvJlE',
#    'id': {'kind': 'youtube#video', 'videoId': 'vJefOB8kec8'},
#    'snippet': {'publishedAt': '2023-07-16T15:05:29Z',
#     'channelId': 'UC-CSyyi47VX1lD9zyeABW3w',
#     'title': 'The Truth about Artificial Intelligence and ChatGPT | Dhruv Rathee',
#     'description': 'Join my AI Course: https://academy.dhruvrathee.com/chatgpt Learn to harness the power of ChatGPT effectively and transform ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/vJefOB8kec8/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/vJefOB8kec8/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/vJefOB8kec8/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Dhruv Rathee',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2023-07-16T15:05:29Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'qnXcCv0wrU5xW2OE-SBuNAcsOFM',
#    'id': {'kind': 'youtube#video', 'videoId': 't0x6WNItdX4'},
#    'snippet': {'publishedAt': '2023-04-12T04:30:22Z',
#     'channelId': 'UCu6eDhSb-UJq7_vLgKe4vHw',
#     'title': 'I DEFEATED ChatGPT !!! #shorts',
#     'description': 'I DEFEATED CHAT GPT #shorts.',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/t0x6WNItdX4/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/t0x6WNItdX4/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/t0x6WNItdX4/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Agnit Shorts',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2023-04-12T04:30:22Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'kcW-yEqTQpe3IOmWp5kh9le74kA',
#    'id': {'kind': 'youtube#video', 'videoId': 'Twpp0mJjDRQ'},
#    'snippet': {'publishedAt': '2023-12-26T22:53:34Z',
#     'channelId': 'UCxkgpR98geayprAcMhUW5TQ',
#     'title': 'Chat GPT AI Generated Image of God #mystery #artificalintelligence #joeroganpodcast #shorts #ai #art',
#     'description': 'Immerse yourself in a groundbreaking fusion of artificial intelligence and divine inspiration as ChatGPT AI unveils an ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/Twpp0mJjDRQ/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/Twpp0mJjDRQ/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/Twpp0mJjDRQ/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Mysterious Chronicles',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2023-12-26T22:53:34Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '2ffCSoshlNGhi1J4CfbYFsm1ceY',
#    'id': {'kind': 'youtube#video', 'videoId': 'GjtZye9DC5Q'},
#    'snippet': {'publishedAt': '2025-05-27T07:11:58Z',
#     'channelId': 'UC_mTME_0z6pEteDMRUUwKlA',
#     'title': 'ChatGPT, Show Me a Twinkie',
#     'description': '',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/GjtZye9DC5Q/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/GjtZye9DC5Q/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/GjtZye9DC5Q/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'teddywang86',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2025-05-27T07:11:58Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'SGgOjvZdH2OmlxwVcPtunltNNQ8',
#    'id': {'kind': 'youtube#video', 'videoId': 'acGZaDV1o04'},
#    'snippet': {'publishedAt': '2024-05-12T11:24:59Z',
#     'channelId': 'UCUetYLN8ZnErkC0NmF0wfcA',
#     'title': '📱Teléfono de $1 vs $1,000,000,000 🤑💸 COMENTA CUAL PREFIERES 😁 #humor #comedia #chatgpt #ia',
#     'description': 'Este canal se dedica a crear videos con imagenes de inteligencia artificial! Imagenes IA, memes IA, chistes IA, humor IA y mucho ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/acGZaDV1o04/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/acGZaDV1o04/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/acGZaDV1o04/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'HumorMuyArtificial',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2024-05-12T11:24:59Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'EM-kgAdlAXTRf4cBg7rjDjttnBg',
#    'id': {'kind': 'youtube#video', 'videoId': '71jJ9ovMAqE'},
#    'snippet': {'publishedAt': '2025-03-01T22:58:43Z',
#     'channelId': 'UCjXUF1XzXG0YQVv9Gwkuguw',
#     'title': 'El chat GPT:',
#     'description': '',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/71jJ9ovMAqE/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/71jJ9ovMAqE/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/71jJ9ovMAqE/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Ashley',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2025-03-01T22:58:43Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'zXkENmf9Jm23n_Dw7pfrIeNUQC0',
#    'id': {'kind': 'youtube#video', 'videoId': '6q2xr2hBncc'},
#    'snippet': {'publishedAt': '2025-02-10T15:15:28Z',
#     'channelId': 'UC_mTME_0z6pEteDMRUUwKlA',
#     'title': 'ChatGPT, Show Me an Orange',
#     'description': 'Twitch: https://www.twitch.tv/teddywang86 Discord Community: https://discord.com/invite/Squja3KAgs TikTok: ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/6q2xr2hBncc/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/6q2xr2hBncc/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/6q2xr2hBncc/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'teddywang86',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2025-02-10T15:15:28Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'X6MYaFMCAhXuYSvVRhzljDcS6Uw',
#    'id': {'kind': 'youtube#video', 'videoId': 'Ur5u27nLIhk'},
#    'snippet': {'publishedAt': '2025-02-13T12:47:08Z',
#     'channelId': 'UCzv4Z4UaBoJFZNyeerjCt6w',
#     'title': 'Narendra Modi Exposed Chat Gpt 😲🔥💯',
#     'description': "Motivation , Inspiration or Information? Just follow @Watchwithsam09. This content doesn't belong to us, it is edited and shared ...",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/Ur5u27nLIhk/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/Ur5u27nLIhk/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/Ur5u27nLIhk/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Watch With Sam',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2025-02-13T12:47:08Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'lLW7PYyIG4Kt3fpZUgXkHZA-EK4',
#    'id': {'kind': 'youtube#video', 'videoId': 'g5EMu5QUEsE'},
#    'snippet': {'publishedAt': '2025-09-08T15:41:48Z',
#     'channelId': 'UCd-B-J0ijnZo3mODqq-t15Q',
#     'title': 'ChatGBT Be Like...',
#     'description': '',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/g5EMu5QUEsE/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/g5EMu5QUEsE/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/g5EMu5QUEsE/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Liv Swearingen (LIV)',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2025-09-08T15:41:48Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'N3eqDWznkm4Z94A1MYsDOdV4wgk',
#    'id': {'kind': 'youtube#video', 'videoId': 'PQME8X-fb1M'},
#    'snippet': {'publishedAt': '2025-05-21T15:27:17Z',
#     'channelId': 'UCmZr0NJBHfmwkA_OZXrYkDQ',
#     'title': 'i can&#39;t win against ChatGPT 💔',
#     'description': "Get ready to laugh out loud! Here's another meme to brighten your day! If this made you chuckle, you're not alone! Share with ...",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/PQME8X-fb1M/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/PQME8X-fb1M/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/PQME8X-fb1M/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Grinly',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2025-05-21T15:27:17Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'YqdQB6b_jilV5R5bFRsfsriGwM4',
#    'id': {'kind': 'youtube#video', 'videoId': 'BjMMqm-v9CY'},
#    'snippet': {'publishedAt': '2025-05-09T11:39:28Z',
#     'channelId': 'UCmC-wktipngCaU9nryMdbpQ',
#     'title': 'Chat GPT vs Amma | Mac Macha | Family comedy | #Shorts',
#     'description': '',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/BjMMqm-v9CY/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/BjMMqm-v9CY/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/BjMMqm-v9CY/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Mac Macha',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2025-05-09T11:39:28Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'DV9mguAUoaI4kzKIOWXqIT42S68',
#    'id': {'kind': 'youtube#video', 'videoId': 'sITD5peEOmM'},
#    'snippet': {'publishedAt': '2024-10-15T14:10:01Z',
#     'channelId': 'UC0D24go3N0o1ItucFFoIShA',
#     'title': 'I ask Chat GPT... 😱 #shorts',
#     'description': 'shorts guess the emoji games and hard choice game and funny videos reaction mythpat and mythreacts crazy amazing guess the ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/sITD5peEOmM/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/sITD5peEOmM/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/sITD5peEOmM/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Vulrax',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2024-10-15T14:10:01Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'iUm1wPwUFGNADfJmpHRqkxkrLNg',
#    'id': {'kind': 'youtube#video', 'videoId': 'nmBX9h6JfmI'},
#    'snippet': {'publishedAt': '2025-06-27T22:42:28Z',
#     'channelId': 'UCfgaAqf8GIjWc4KG7ZzIKgQ',
#     'title': 'Asking chat gpt to pick my hair color…😅',
#     'description': '',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/nmBX9h6JfmI/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/nmBX9h6JfmI/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/nmBX9h6JfmI/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Jules Walcott',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2025-06-27T22:42:28Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'vOL0uDV3_zFkrECRP2C-tJWC1h8',
#    'id': {'kind': 'youtube#video', 'videoId': 'OHTy96KPZHY'},
#    'snippet': {'publishedAt': '2024-09-24T14:58:03Z',
#     'channelId': 'UC_mTME_0z6pEteDMRUUwKlA',
#     'title': 'ChatGPT, Show Me Lays Potato Chips',
#     'description': '',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/OHTy96KPZHY/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/OHTy96KPZHY/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/OHTy96KPZHY/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'teddywang86',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2024-09-24T14:58:03Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'XR27fel7R4bzyCLa6wSM1GQwFx0',
#    'id': {'kind': 'youtube#video', 'videoId': '5gQIJB9SZ78'},
#    'snippet': {'publishedAt': '2024-07-20T19:45:47Z',
#     'channelId': 'UCJsaPV-pqxBcgXMpEcz9xTg',
#     'title': '😂 IA CHISTES GPT 12 😂 #randomquizgo #chatgpt #ia #comedia',
#     'description': 'IA CHISTES GPT 12 #randomquizgo #chatgpt #ia #comedia Inteligencia artificial meme IA genera parodia imagen video shorts ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/5gQIJB9SZ78/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/5gQIJB9SZ78/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/5gQIJB9SZ78/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'RandomQuiz',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2024-07-20T19:45:47Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'zabDtj364iwBzDwftNMnGnNtTDw',
#    'id': {'kind': 'youtube#video', 'videoId': 'cDSI29p6KsU'},
#    'snippet': {'publishedAt': '2024-01-12T04:23:51Z',
#     'channelId': 'UCtjW0Pf1eEhVNrJXzEsLB1Q',
#     'title': 'I ask Chat GPT #AyushMore #Shorts',
#     'description': '',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/cDSI29p6KsU/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/cDSI29p6KsU/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/cDSI29p6KsU/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Ayush More 2.0',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2024-01-12T04:23:51Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'SFiC7u82aItcaYHyyx_ymHO_zik',
#    'id': {'kind': 'youtube#video', 'videoId': 'FdZ8LKiJBhQ'},
#    'snippet': {'publishedAt': '2023-03-07T21:24:03Z',
#     'channelId': 'UC36xmz34q02JYaZYKrMwXng',
#     'title': '¿Cómo funciona ChatGPT? La revolución de la Inteligencia Artificial',
#     'description': 'REGISTRATE A LA GTC Y ASISTE A UNA SESIÓN PARA GANAR UNA GPU!',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/FdZ8LKiJBhQ/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/FdZ8LKiJBhQ/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/FdZ8LKiJBhQ/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Nate Gentile',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2023-03-07T21:24:03Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'pN4hlF_EzVB-PONJts0BCHUuusk',
#    'id': {'kind': 'youtube#video', 'videoId': 'F16b1s5BkoQ'},
#    'snippet': {'publishedAt': '2023-03-28T16:00:20Z',
#     'channelId': 'UCCU2Tvanl8gLaJ7pYDuIYkg',
#     'title': 'Quand Timéo découvre Chat GPT…',
#     'description': '',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/F16b1s5BkoQ/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/F16b1s5BkoQ/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/F16b1s5BkoQ/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'BATZAIR',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2023-03-28T16:00:20Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'wC_zxCwnS4j3BHpIxODGBuUwHCQ',
#    'id': {'kind': 'youtube#video', 'videoId': 'j02OZRjf2d8'},
#    'snippet': {'publishedAt': '2023-03-07T18:00:08Z',
#     'channelId': 'UCtJmfVv0a52Bu7BnJJtZXKw',
#     'title': 'Chat GPT | الدحيح',
#     'description': 'رحلة داخل الذكاء الاصطناعي اللي عارف ومش عارف كل حاجة. شاهدوا حلقات الدحيح أولاً على منصات ستارز بلاي @STARZPLAYOfficial ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/j02OZRjf2d8/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/j02OZRjf2d8/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/j02OZRjf2d8/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'New Media Academy Life ',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2023-03-07T18:00:08Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'LDQ8WCItvW7raEQRUweEuWPtvXY',
#    'id': {'kind': 'youtube#video', 'videoId': 'vx8mVmRQqms'},
#    'snippet': {'publishedAt': '2024-09-20T03:11:56Z',
#     'channelId': 'UC_mTME_0z6pEteDMRUUwKlA',
#     'title': 'ChatGPT, Show Me a Watermelon',
#     'description': '',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/vx8mVmRQqms/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/vx8mVmRQqms/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/vx8mVmRQqms/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'teddywang86',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2024-09-20T03:11:56Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'thNNDC907UmuiFpsu6xl7xBJeEA',
#    'id': {'kind': 'youtube#video', 'videoId': 'CRe_O0_W3-8'},
#    'snippet': {'publishedAt': '2025-08-03T12:59:53Z',
#     'channelId': 'UClAxWfMxGZixqZzlZDzR13A',
#     'title': 'Unique Way To Use Chat GPT #shorts #rajshamani #motivation #india',
#     'description': '',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/CRe_O0_W3-8/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/CRe_O0_W3-8/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/CRe_O0_W3-8/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'learn with shamani',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2025-08-03T12:59:53Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'fMPFGdn4g_1eFlTcgT_B-t1IUME',
#    'id': {'kind': 'youtube#video', 'videoId': '5MmxPFDLaEs'},
#    'snippet': {'publishedAt': '2024-08-08T12:42:19Z',
#     'channelId': 'UC7kIy8fZavEni8Gzl8NLjOQ',
#     'title': 'ChatGPT is a Liar',
#     'description': '',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/5MmxPFDLaEs/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/5MmxPFDLaEs/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/5MmxPFDLaEs/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': "Alex O'Connor",
#     'liveBroadcastContent': 'none',
#     'publishTime': '2024-08-08T12:42:19Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'hqb6ukXvewCdsrgLrrzYNYymlO8',
#    'id': {'kind': 'youtube#video', 'videoId': 'AXn2XVLf7d0'},
#    'snippet': {'publishedAt': '2022-12-08T21:56:41Z',
#     'channelId': 'UCHhYXsLBEVVnbvsq57n1MTQ',
#     'title': 'How To Use ChatGPT by OpenAI For Beginners',
#     'description': "In this tutorial, I'll be showing you how to use ChatGPT, the revolutionary AI chatbot created by OpenAI to generate text or code.",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/AXn2XVLf7d0/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/AXn2XVLf7d0/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/AXn2XVLf7d0/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'The AI Advantage',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-12-08T21:56:41Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'HMjORkQVcpXBdJqwiIghcXf1zF4',
#    'id': {'kind': 'youtube#video', 'videoId': 'U9_QJGS44Qc'},
#    'snippet': {'publishedAt': '2025-06-27T13:59:41Z',
#     'channelId': 'UC5nYiBNLQmy52iJWucem9hg',
#     'title': 'Чат ГПТ Покажи Мне Драгон Фрут',
#     'description': 'Всем хай, Меня зовут снепирайз! Добро пожаловать на канал, где я тестирую безумные идеи, исследую скрытые уголки ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/U9_QJGS44Qc/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/U9_QJGS44Qc/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/U9_QJGS44Qc/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'снепирайз',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2025-06-27T13:59:41Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'abkJfQByYZzT4YHUha2V9_qmvzQ',
#    'id': {'kind': 'youtube#video', 'videoId': 'mNxB1g1-Otg'},
#    'snippet': {'publishedAt': '2023-12-22T16:16:28Z',
#     'channelId': 'UCugeH-Bmo9a5-Jnbt9X-3bA',
#     'title': 'J&#39;ai demandé à Chat GPT de me faire un Chiot en Colère',
#     'description': 'Code : unchained sur Fortnite ! Abonne-toi à ma chaine Gaming ▻ https://bit.ly/Unchained_gaming MON INSTA ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/mNxB1g1-Otg/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/mNxB1g1-Otg/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/mNxB1g1-Otg/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Unchained',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2023-12-22T16:16:28Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'tAvcFzL4wTZXeRWL4DjZjtFiOGY',
#    'id': {'kind': 'youtube#video', 'videoId': '60ejKe3vcZM'},
#    'snippet': {'publishedAt': '2025-06-26T21:51:42Z',
#     'channelId': 'UCuJQ1_EIWlN2AEQBCTqwaVg',
#     'title': 'chat gpt had enough 😭😭🙏 #slideshow #funny #dankememes #memes #brainrot #shorts',
#     'description': '',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/60ejKe3vcZM/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/60ejKe3vcZM/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/60ejKe3vcZM/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Caldruki',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2025-06-26T21:51:42Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'VTFzDn6VLYMLt6Fnewo29JEHGqY',
#    'id': {'kind': 'youtube#video', 'videoId': 'd1yNLkKYkwI'},
#    'snippet': {'publishedAt': '2025-06-25T20:05:48Z',
#     'channelId': 'UC5nYiBNLQmy52iJWucem9hg',
#     'title': 'Чат ГПТ Покажи Мне Рыбу',
#     'description': 'Всем хай, Меня зовут снепирайз! Добро пожаловать на канал, где я тестирую безумные идеи, исследую скрытые уголки ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/d1yNLkKYkwI/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/d1yNLkKYkwI/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/d1yNLkKYkwI/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'снепирайз',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2025-06-25T20:05:48Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'qqttvK9BMp_Awkv7dkb8qfjopAg',
#    'id': {'kind': 'youtube#video', 'videoId': 'FtIEhrZD_5I'},
#    'snippet': {'publishedAt': '2023-06-21T16:22:23Z',
#     'channelId': 'UC0ykHu_m9j3q3HXK_ySYr_A',
#     'title': 'CHAT GPT और Artificial Intelligence | कैसे GPT USE करें | ROBOTS V/S HUMANS | JOBS RISK | Alakh GK',
#     'description': 'ChatGPT #HowToUseChatGPT #AI.',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/FtIEhrZD_5I/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/FtIEhrZD_5I/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/FtIEhrZD_5I/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Alakh GK',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2023-06-21T16:22:23Z'}}]}

# %%
df_youtube.to_csv("data/df_youtube_chagpt.csv")

# %% [markdown]
# ## Google Gemini

# %%
#api_key = "tu api key"

# %%
# %pip install google-genai
# Out:
# Requirement already satisfied: google-genai in c:\users\alberto romero\appdata\local\programs\python\python313\lib\site-packages (1.20.0)
# Requirement already satisfied: anyio<5.0.0,>=4.8.0 in c:\users\alberto romero\appdata\local\programs\python\python313\lib\site-packages (from google-genai) (4.8.0)
# Requirement already satisfied: google-auth<3.0.0,>=2.14.1 in c:\users\alberto romero\appdata\local\programs\python\python313\lib\site-packages (from google-genai) (2.40.3)
# Requirement already satisfied: httpx<1.0.0,>=0.28.1 in c:\users\alberto romero\appdata\local\programs\python\python313\lib\site-packages (from google-genai) (0.28.1)
# Requirement already satisfied: pydantic<3.0.0,>=2.0.0 in c:\users\alberto romero\appdata\local\programs\python\python313\lib\site-packages (from google-genai) (2.10.6)
# Requirement already satisfied: requests<3.0.0,>=2.28.1 in c:\users\alberto romero\appdata\local\programs\python\python313\lib\site-packages (from google-genai) (2.32.4)
# Requirement already satisfied: websockets<15.1.0,>=13.0.0 in c:\users\alberto romero\appdata\local\programs\python\python313\lib\site-packages (from google-genai) (15.0)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.11.0 in c:\users\alberto romero\appdata\local\programs\python\python313\lib\site-packages (from google-genai) (4.12.2)
# Requirement already satisfied: idna>=2.8 in c:\users\alberto romero\appdata\local\programs\python\python313\lib\site-packages (from anyio<5.0.0,>=4.8.0->google-genai) (3.10)
# Requirement already satisfied: sniffio>=1.1 in c:\users\alberto romero\appdata\local\programs\python\python313\lib\site-packages (from anyio<5.0.0,>=4.8.0->google-genai) (1.3.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\alberto romero\appdata\local\programs\python\python313\lib\site-packages (from google-auth<3.0.0,>=2.14.1->google-genai) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\alberto romero\appdata\local\programs\python\python313\lib\site-packages (from google-auth<3.0.0,>=2.14.1->google-genai) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\alberto romero\appdata\local\programs\python\python313\lib\site-packages (from google-auth<3.0.0,>=2.14.1->google-genai) (4.9.1)
# Requirement already satisfied: certifi in c:\users\alberto romero\appdata\local\programs\python\python313\lib\site-packages (from httpx<1.0.0,>=0.28.1->google-genai) (2024.12.14)
# Requirement already satisfied: httpcore==1.* in c:\users\alberto romero\appdata\local\programs\python\python313\lib\site-packages (from httpx<1.0.0,>=0.28.1->google-genai) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\alberto romero\appdata\local\programs\python\python313\lib\site-packages (from httpcore==1.*->httpx<1.0.0,>=0.28.1->google-genai) (0.14.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\alberto romero\appdata\local\programs\python\python313\lib\site-packages (from pydantic<3.0.0,>=2.0.0->google-genai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in c:\users\alberto romero\appdata\local\programs\python\python313\lib\site-packages (from pydantic<3.0.0,>=2.0.0->google-genai) (2.27.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\alberto romero\appdata\local\programs\python\python313\lib\site-packages (from requests<3.0.0,>=2.28.1->google-genai) (3.4.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\alberto romero\appdata\local\programs\python\python313\lib\site-packages (from requests<3.0.0,>=2.28.1->google-genai) (2.5.0)
# Requirement already satisfied: pyasn1>=0.1.3 in c:\users\alberto romero\appdata\local\programs\python\python313\lib\site-packages (from rsa<5,>=3.1.4->google-auth<3.0.0,>=2.14.1->google-genai) (0.6.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
from google import genai
from google.genai import types

# %%
from google import genai

client = genai.Client(api_key=api_key)

response = client.models.generate_content(
    model="gemini-2.5-flash",
    contents=["How does AI work?"]
)
print(response.text)
# Out:
# AI, or Artificial Intelligence, works by enabling machines to simulate and perform tasks that typically require human intelligence. It's not a single technology but a broad field encompassing many techniques and approaches.
#
# At its core, AI operates on a few fundamental principles:
#
# 1.  **Data as Fuel:** AI systems are trained on vast amounts of data. This data can be text, images, audio, video, numerical records, etc. The quality and quantity of this data significantly impact the AI's performance.
#
# 2.  **Algorithms as Rules/Learning Mechanisms:** These are the sets of instructions or mathematical models that the AI uses to process data, identify patterns, make decisions, or generate outputs. Different types of AI use different algorithms.
#
# 3.  **Learning and Pattern Recognition:** Instead of being explicitly programmed for every possible scenario, AI systems (especially those using Machine Learning) learn from the data. They identify patterns, correlations, and rules within the data.
#
# Let's break down the main ways this happens:
#
# ---
#
# ### The Fundamental Pillars of How AI Works:
#
# 1.  **Input (Data Collection):**
#     *   AI systems receive various forms of input, just like humans receive information through their senses.
#     *   **Examples:** Sensor data from a self-driving car, text from an email, pixels from an image, speech from a voice command, financial transactions.
#
# 2.  **Processing (Algorithms & Models):**
#     *   This is where the "thinking" happens. The input data is fed into an algorithm, which is a set of rules or mathematical operations.
#     *   **Machine Learning (ML):** This is the most common approach. Instead of explicit programming for every outcome, ML algorithms learn from the data itself.
#         *   **Training:** During training, the algorithm is exposed to data and adjusts its internal parameters (like weights in a neural network) to minimize errors or achieve a desired outcome. It essentially builds a "model" based on the patterns it finds.
#         *   **Inference:** Once trained, the model can be given new, unseen data (input) and will use what it learned to make predictions, classifications, or generate new content (output).
#
# 3.  **Output (Prediction/Action):**
#     *   Based on its processing, the AI system generates an output.
#     *   **Examples:** Identifying an object in an image, translating text, recommending a product, predicting stock prices, generating a creative story, controlling a robot arm.
#
# 4.  **Feedback & Refinement (Continuous Learning):**
#     *   Many AI systems, especially in areas like reinforcement learning, receive feedback on their outputs. If an output is incorrect or suboptimal, the system can adjust its internal parameters to improve future performance. This creates an iterative learning loop.
#
# ---
#
# ### Key AI Approaches (Types of "Brains"):
#
# The "algorithms" mentioned above come in many forms. Here are the most prominent:
#
# 1.  **Machine Learning (ML):**
#     *   **Core Idea:** Teach computers to learn from data without being explicitly programmed.
#     *   **How it works:** Algorithms identify patterns and relationships in large datasets. Once trained, they can make predictions or decisions on new data.
#     *   **Types:**
#         *   **Supervised Learning:** Trained on labeled data (input-output pairs). E.g., given pictures of cats and dogs *labeled* as such, it learns to distinguish them.
#             *   *Examples:* Image classification, spam detection, price prediction.
#         *   **Unsupervised Learning:** Trained on unlabeled data, finding hidden patterns or structures. E.g., grouping customers into segments without prior labels.
#             *   *Examples:* Customer segmentation, anomaly detection, data compression.
#         *   **Reinforcement Learning:** Learns through trial and error, by interacting with an environment and receiving rewards or penalties.
#             *   *Examples:* Game playing (AlphaGo), robotics, autonomous driving.
#
# 2.  **Deep Learning (DL):**
#     *   **Core Idea:** A *subset* of Machine Learning that uses Artificial Neural Networks with multiple layers (hence "deep").
#     *   **How it works:** Inspired by the structure of the human brain, these networks consist of interconnected "neurons" arranged in layers. Each neuron processes information and passes it to the next layer. The "depth" allows them to learn incredibly complex patterns and representations from data.
#     *   **Key Concept:** **Neural Networks** learn by adjusting the "weights" (strength of connections) between neurons through a process called **backpropagation**, minimizing the error in their predictions.
#     *   **Applications:** Facial recognition, natural language processing, speech recognition, medical image analysis, content generation (like ChatGPT).
#
# 3.  **Natural Language Processing (NLP):**
#     *   **Core Idea:** Enables computers to understand, interpret, and generate human language.
#     *   **How it works:** Uses ML and DL techniques to analyze syntax, semantics, and context of text or speech.
#     *   **Applications:** Virtual assistants (Siri, Alexa), machine translation (Google Translate), sentiment analysis, chatbots, text summarization.
#
# 4.  **Computer Vision (CV):**
#     *   **Core Idea:** Enables computers to "see" and interpret visual information from images and videos.
#     *   **How it works:** Uses DL (especially Convolutional Neural Networks) to identify objects, faces, scenes, and even actions within visual data.
#     *   **Applications:** Facial recognition, self-driving cars (object detection), medical imaging, quality control in manufacturing.
#
# 5.  **Robotics:**
#     *   **Core Idea:** Integrating AI into physical robots to enable them to perceive, reason, and act in the real world.
#     *   **How it works:** Combines AI (for decision-making, path planning, object recognition) with mechanical engineering and sensor technology.
#     *   **Applications:** Industrial automation, surgical robots, autonomous drones, humanoid robots.
#
# ---
#
# ### In Simple Terms:
#
# Imagine you want to teach a computer to recognize a cat.
#
# *   **Traditional Programming:** You'd have to write specific rules for every feature: "if it has pointy ears AND whiskers AND fur AND says 'meow', then it's a cat." This is impossible for all variations.
# *   **AI (Machine Learning):** You show the computer thousands of pictures, some with cats, some without, *labeled* correctly. The AI algorithm then *learns* on its own what patterns (shapes, colors, textures) are associated with "cat." After training, when you show it a new picture, it applies what it learned to predict if it's a cat or not.
# *   **AI (Deep Learning):** It's like the ML example, but with a more complex "brain" (the neural network) that can understand even more subtle and intricate features, allowing for even higher accuracy in recognizing cats in various poses, lighting, and environments.
#
# So, AI fundamentally works by learning from data, identifying patterns, and then applying that learned knowledge to new situations to make intelligent decisions or predictions.
