# %% [markdown]
# # WEB SCRAPING WITH BEAUTIFUL SOUP

# %% [markdown]
# Web scraping is the process of extracting data from websites, and Python provides powerful libraries
# like Beautiful Soup 4 that make it easier to scrape and parse HTML and XML content.

# %% [markdown]
# Imports

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd

# %% [markdown]
# We are collecting data of computer peripherals from "MD Computers" site using Beautiful Soup 4

# %% [markdown]
# Enter the item which you wanted to collect information.

# %%
search_item = input("Which item do you want to search? ")

# %% [markdown]
# From the dynamic url of the website we are formatting the search result to the url.

# %%
url = f"https://mdcomputers.in/index.php?submit_search=&route=product%2Fsearch&&search={search_item}"

# %% [markdown]
# Parsing the html content of the page.

# %%
page_ = requests.get(url).text
doc = BeautifulSoup(page_, "html.parser")

# %%
url
# Out:
# 'https://mdcomputers.in/index.php?submit_search=&route=product%2Fsearch&&search=mouse'

# %% [markdown]
# Finding the total number of result pages by filtering the html tags through class name

# %%
#total_pages_x = doc.find(class_="col-sm-6 text-right")
total_pages_x = doc.find(class_="col-md-6 text-md-end mb-2")

# %%
total_pages_x.text.split("(")[1].split(" ")[0]
# Out:
# '8'

# %%
total_pages = int(total_pages_x.text.split("(")[1].split(" ")[0])

# %%
total_pages
# Out:
# 8

# %% [markdown]
# Total page results obtained for the search

# %%
total_pages
# Out:
# 8

# %% [markdown]
# We are going to gather the item's name , its link , its price (old and new) below

# %% [markdown]
# Creating empty lists for the data

# %%
link = []
item_name = []
new_price = []
old_price = []

# %% [markdown]
# Here is the main code which scrape the information from the html code

# %% [markdown]
# From this url , we can search for the products we need , through iterating the pages till the total page results we obtained earlier.

# %%
for page in range(1, total_pages + 1):
    url = f"https://mdcomputers.in/index.php?route=product/search&page={page}&search={search_item}"
    print(url)
    page_ = requests.get(url).text
    doc = BeautifulSoup(page_, "html.parser")
    
    items = doc.find_all(class_ = "product-wrapper") #Finding the main div tag for each product which holds the data. 
    print(items)
    for item in items:
        
        link.append((item.find("h3")).find("a")['href']) #finding the link through href attribute
        item_name.append(((item.find("h3")).find("a")).text) #finding the name in the h3 tag
        old_price.append(((item.find("span",class_ = "del")).find("span",class_ = "amount")).text[1:]) #finding the old price
        new_price.append(((item.find("span",class_ = "ins")).find("span",class_ = "amount")).text[1:])
        #try:
            #In some Products, there is no old price so in order to clear the error , finding the old price in this try block
        #    old_price.append(((item.find("div",class_ = "price")).find("span",class_ = "price-old")).string[1:])    
        #except:
        #    #For the products having no old price , it is declared as null
        #    old_price.append(None)
# Out:
# https://mdcomputers.in/index.php?route=product/search&page=1&search=mouse
# [<div class="product-wrapper"><div class="product-element-top product-quick-shop"><a class="product-image-link" href="https://mdcomputers.in/product/hp-m10-mouse-7ya10pa"><div class="product-labels labels-rectangular"><span class="onsale product-label">-55%</span></div><img alt="HP M10 Black Wired Mouse" class="attachment-large size-large" decoding="async" fetchpriority="low" loading="lazy" src="https://mdcomputers.in/cdn-cgi/image/width=500,height=500,quality=75/image/catalog/mouse/h-p/7ya10pa/7ya10pa-image-main.jpg"/></a><div class="wrapp-buttons"><div class="product-buttons"><div class="product-add-btn product-action-btn product-style-icon product-add-cart-icon"><button class="button product_type_simple add_to_cart_button ajax_add_to_cart add-to-cart-loop" onclick="cart.add('20559');"><span>Add to Cart</span><i class="bi bi-cart-plus"></i></button></div><div class="quick-view product-action-btn product-style-icon product-quick-view-icon"><a class="open-quick-view quick-view-button" href="https://mdcomputers.in/product/hp-m10-mouse-7ya10pa"><span>Quick view</span><i class="bi bi-search"></i></a></div><div class="product-compare-btn product-compare-button product-action-btn product-style-icon product-compare-icon"><button onclick="compare.add('20559');"><span>Product Compare (%s)</span><i class="bi bi-shuffle"></i></button></div><div class="product-wishlist-btn product-action-btn product-style-icon product-wishlist-icon"><button onclick="wishlist.add('20559');"><span>Add to wishlist</span><i class="bi bi-suit-heart"></i></button></div></div></div></div><h3 class="product-entities-title"><a href="https://mdcomputers.in/product/hp-m10-mouse-7ya10pa">HP M10 Black Wired Mouse</a></h3><span class="price"><span class="del"><span class="amount"><span class="">₹599</span></span></span><span class="ins"><span class="amount"> ₹270<span class=""></span></span></span></span></div>, <div class="product-wrapper"><div class="product-element-top product-quick-shop"><a class="product-image-link" href="https://mdcomputers.in/product/ant-esports-mp265-mouse-pad-aepp0094"><div class="product-labels labels-rectangular"><span class="onsale product-label">-65%</span></div><img alt="Ant Esports MP265 Gaming Mouse Pad (Medium)" class="attachment-large size-large" decoding="async" fetchpriority="low" loading="lazy" src="https://mdcomputers.in/cdn-cgi/image/width=500,height=500,quality=75/image/catalog/mouse%20pad/ant-value/aepp0094/aepp0094-image-main.jpg"/></a><div class="wrapp-buttons"><div class="product-buttons"><div class="product-add-btn product-action-btn product-style-icon product-add-cart-icon"><button class="button product_type_simple add_to_cart_button ajax_add_to_cart add-to-cart-loop" onclick="cart.add('21436');"><span>Add to Cart</span><i class="bi bi-cart-plus"></i></button></div><div class="quick-view product-action-btn product-style-icon product-quick-view-icon"><a class="open-quick-view quick-view-button" href="https://mdcomputers.in/product/ant-esports-mp265-mouse-pad-aepp0094"><span>Quick view</span><i class="bi bi-search"></i></a></div><div class="product-compare-btn product-compare-button product-action-btn product-style-icon product-compare-icon"><button onclick="compare.add('21436');"><span>Product Compare (%s)</span><i class="bi bi-shuffle"></i></button></div><div class="product-wishlist-btn product-action-btn product-style-icon product-wishlist-icon"><button onclick="wishlist.add('21436');"><span>Add to wishlist</span><i class="bi bi-suit-heart"></i></button></div></div></div></div><h3 class="product-entities-title"><a href="https://mdcomputers.in/product/ant-esports-mp265-mouse-pad-aepp0094">Ant Esports MP265 Gaming Mouse Pad (Medium)</a></h3><span class="price"><span class="del"><span class="amount"><span class="">₹799</span></span></span><span class="ins"><span class="amount"> ₹280<span class=""></span></span></span></span></div>, <div class="product-wrapper"><div class="product-element-top product-quick-shop"><a class="pr ...
# https://mdcomputers.in/index.php?route=product/search&page=2&search=mouse
# [<div class="product-wrapper"><div class="product-element-top product-quick-shop"><a class="product-image-link" href="https://mdcomputers.in/product/dell-wireless-mouse-d-select-ds320"><div class="product-labels labels-rectangular"><span class="onsale product-label">-44%</span></div><img alt="Dell D SELECT DS320 Wireless Mouse" class="attachment-large size-large" decoding="async" fetchpriority="low" loading="lazy" src="https://mdcomputers.in/cdn-cgi/image/width=500,height=500,quality=75/image/catalog/mouse/dell/ds320/ds320-black-image.webp"/></a><div class="wrapp-buttons"><div class="product-buttons"><div class="product-add-btn product-action-btn product-style-icon product-add-cart-icon"><button class="button product_type_simple add_to_cart_button ajax_add_to_cart add-to-cart-loop" onclick="cart.add('24172');"><span>Add to Cart</span><i class="bi bi-cart-plus"></i></button></div><div class="quick-view product-action-btn product-style-icon product-quick-view-icon"><a class="open-quick-view quick-view-button" href="https://mdcomputers.in/product/dell-wireless-mouse-d-select-ds320"><span>Quick view</span><i class="bi bi-search"></i></a></div><div class="product-compare-btn product-compare-button product-action-btn product-style-icon product-compare-icon"><button onclick="compare.add('24172');"><span>Product Compare (%s)</span><i class="bi bi-shuffle"></i></button></div><div class="product-wishlist-btn product-action-btn product-style-icon product-wishlist-icon"><button onclick="wishlist.add('24172');"><span>Add to wishlist</span><i class="bi bi-suit-heart"></i></button></div></div></div></div><h3 class="product-entities-title"><a href="https://mdcomputers.in/product/dell-wireless-mouse-d-select-ds320">Dell D SELECT DS320 Wireless Mouse</a></h3><span class="price"><span class="del"><span class="amount"><span class="">₹899</span></span></span><span class="ins"><span class="amount"> ₹500<span class=""></span></span></span></span></div>, <div class="product-wrapper"><div class="product-element-top product-quick-shop"><a class="product-image-link" href="https://mdcomputers.in/product/acer-wireless-white-mouse-5w-50611-004"><div class="product-labels labels-rectangular"><span class="onsale product-label">-67%</span></div><img alt="Acer Wireless White and Green Mouse" class="attachment-large size-large" decoding="async" fetchpriority="low" loading="lazy" src="https://mdcomputers.in/cdn-cgi/image/width=500,height=500,quality=75/image/catalog/mouse/acer/5w-50611-004/5w-50611-004-image-main0.jpg"/></a><div class="wrapp-buttons"><div class="product-buttons"><div class="product-add-btn product-action-btn product-style-icon product-add-cart-icon"><button class="button product_type_simple add_to_cart_button ajax_add_to_cart add-to-cart-loop" onclick="cart.add('24941');"><span>Add to Cart</span><i class="bi bi-cart-plus"></i></button></div><div class="quick-view product-action-btn product-style-icon product-quick-view-icon"><a class="open-quick-view quick-view-button" href="https://mdcomputers.in/product/acer-wireless-white-mouse-5w-50611-004"><span>Quick view</span><i class="bi bi-search"></i></a></div><div class="product-compare-btn product-compare-button product-action-btn product-style-icon product-compare-icon"><button onclick="compare.add('24941');"><span>Product Compare (%s)</span><i class="bi bi-shuffle"></i></button></div><div class="product-wishlist-btn product-action-btn product-style-icon product-wishlist-icon"><button onclick="wishlist.add('24941');"><span>Add to wishlist</span><i class="bi bi-suit-heart"></i></button></div></div></div></div><h3 class="product-entities-title"><a href="https://mdcomputers.in/product/acer-wireless-white-mouse-5w-50611-004">Acer Wireless White and Green Mouse</a></h3><span class="price"><span class="del"><span class="amount"><span class="">₹1,499</span></span></span><span class="ins"><span class="amount"> ₹500<span class=""></span></span></span></span></div>, <div class="product-wrapper"><div class="p ...
# https://mdcomputers.in/index.php?route=product/search&page=3&search=mouse
# [<div class="product-wrapper"><div class="product-element-top product-quick-shop"><a class="product-image-link" href="https://mdcomputers.in/product/cosmic-byte-firestorm-rgb-mouse-tcbp03430"><div class="product-labels labels-rectangular"><span class="onsale product-label">-41%</span></div><img alt="Cosmic Byte Firestorm RGB Gaming Mouse" class="attachment-large size-large" decoding="async" fetchpriority="low" loading="lazy" src="https://mdcomputers.in/cdn-cgi/image/width=500,height=500,quality=75/image/catalog/mouse/cosmic-byte/firestorm-rgb-black/firestorm-rgb-black-image.webp"/></a><div class="wrapp-buttons"><div class="product-buttons"><div class="product-add-btn product-action-btn product-style-icon product-add-cart-icon"><button class="button product_type_simple add_to_cart_button ajax_add_to_cart add-to-cart-loop" onclick="cart.add('25305');"><span>Add to Cart</span><i class="bi bi-cart-plus"></i></button></div><div class="quick-view product-action-btn product-style-icon product-quick-view-icon"><a class="open-quick-view quick-view-button" href="https://mdcomputers.in/product/cosmic-byte-firestorm-rgb-mouse-tcbp03430"><span>Quick view</span><i class="bi bi-search"></i></a></div><div class="product-compare-btn product-compare-button product-action-btn product-style-icon product-compare-icon"><button onclick="compare.add('25305');"><span>Product Compare (%s)</span><i class="bi bi-shuffle"></i></button></div><div class="product-wishlist-btn product-action-btn product-style-icon product-wishlist-icon"><button onclick="wishlist.add('25305');"><span>Add to wishlist</span><i class="bi bi-suit-heart"></i></button></div></div></div></div><h3 class="product-entities-title"><a href="https://mdcomputers.in/product/cosmic-byte-firestorm-rgb-mouse-tcbp03430">Cosmic Byte Firestorm RGB Gaming Mouse</a></h3><span class="price"><span class="del"><span class="amount"><span class="">₹1,499</span></span></span><span class="ins"><span class="amount"> ₹890<span class=""></span></span></span></span></div>, <div class="product-wrapper"><div class="product-element-top product-quick-shop"><a class="product-image-link" href="https://mdcomputers.in/product/logitech-mk120-keyboard-mouse-combo"><div class="product-labels labels-rectangular"><span class="onsale product-label">-12%</span></div><img alt="Logitech MK120 Keyboard and Mouse Combo" class="attachment-large size-large" decoding="async" fetchpriority="low" loading="lazy" src="https://mdcomputers.in/cdn-cgi/image/width=500,height=500,quality=75/image/catalog/keyboard/logitech/mk120/mk120-image-main.jpg"/></a><div class="wrapp-buttons"><div class="product-buttons"><div class="product-add-btn product-action-btn product-style-icon product-add-cart-icon"><button class="button product_type_simple add_to_cart_button ajax_add_to_cart add-to-cart-loop" onclick="cart.add('3531');"><span>Add to Cart</span><i class="bi bi-cart-plus"></i></button></div><div class="quick-view product-action-btn product-style-icon product-quick-view-icon"><a class="open-quick-view quick-view-button" href="https://mdcomputers.in/product/logitech-mk120-keyboard-mouse-combo"><span>Quick view</span><i class="bi bi-search"></i></a></div><div class="product-compare-btn product-compare-button product-action-btn product-style-icon product-compare-icon"><button onclick="compare.add('3531');"><span>Product Compare (%s)</span><i class="bi bi-shuffle"></i></button></div><div class="product-wishlist-btn product-action-btn product-style-icon product-wishlist-icon"><button onclick="wishlist.add('3531');"><span>Add to wishlist</span><i class="bi bi-suit-heart"></i></button></div></div></div></div><h3 class="product-entities-title"><a href="https://mdcomputers.in/product/logitech-mk120-keyboard-mouse-combo">Logitech MK120 Keyboard and Mouse Combo</a></h3><span class="price"><span class="del"><span class="amount"><span class="">₹1,045</span></span></span><span class="ins"><span class="amount"> ₹920<span class=""></span></span></span></span><d ...
# https://mdcomputers.in/index.php?route=product/search&page=4&search=mouse
# [<div class="product-wrapper"><div class="product-element-top product-quick-shop"><a class="product-image-link" href="https://mdcomputers.in/product/adata-xpg-infarex-m20-mouse"><div class="product-labels labels-rectangular"><span class="onsale product-label">-71%</span></div><img alt="Adata XPG Infarex M20 RGB" class="attachment-large size-large" decoding="async" fetchpriority="low" loading="lazy" src="https://mdcomputers.in/cdn-cgi/image/width=500,height=500,quality=75/image/catalog/mouse/adata/infarex-m20/infarex-m20-image-main.jpg"/></a><div class="wrapp-buttons"><div class="product-buttons"><div class="product-add-btn product-action-btn product-style-icon product-add-cart-icon"><button class="button product_type_simple add_to_cart_button ajax_add_to_cart add-to-cart-loop" onclick="cart.add('11373');"><span>Add to Cart</span><i class="bi bi-cart-plus"></i></button></div><div class="quick-view product-action-btn product-style-icon product-quick-view-icon"><a class="open-quick-view quick-view-button" href="https://mdcomputers.in/product/adata-xpg-infarex-m20-mouse"><span>Quick view</span><i class="bi bi-search"></i></a></div><div class="product-compare-btn product-compare-button product-action-btn product-style-icon product-compare-icon"><button onclick="compare.add('11373');"><span>Product Compare (%s)</span><i class="bi bi-shuffle"></i></button></div><div class="product-wishlist-btn product-action-btn product-style-icon product-wishlist-icon"><button onclick="wishlist.add('11373');"><span>Add to wishlist</span><i class="bi bi-suit-heart"></i></button></div></div></div></div><h3 class="product-entities-title"><a href="https://mdcomputers.in/product/adata-xpg-infarex-m20-mouse">Adata XPG Infarex M20 RGB</a></h3><span class="price"><span class="del"><span class="amount"><span class="">₹4,499</span></span></span><span class="ins"><span class="amount"> ₹1,300<span class=""></span></span></span></span></div>, <div class="product-wrapper"><div class="product-element-top product-quick-shop"><a class="product-image-link" href="https://mdcomputers.in/product/adata-xpg-mouse-pad-battleground-l-bk-ogcww"><div class="product-labels labels-rectangular"><span class="onsale product-label">-23%</span></div><img alt="Adata XPG Battleground L Gaming Mouse Pad (Large)" class="attachment-large size-large" decoding="async" fetchpriority="low" loading="lazy" src="https://mdcomputers.in/cdn-cgi/image/width=500,height=500,quality=75/image/catalog/mouse%20pad/adata/Battleground-l-bk-ogcww/battleground-l-bk-ogcww-image-main.jpg"/></a><div class="wrapp-buttons"><div class="product-buttons"><div class="product-add-btn product-action-btn product-style-icon product-add-cart-icon"><button class="button product_type_simple add_to_cart_button ajax_add_to_cart add-to-cart-loop" onclick="cart.add('18799');"><span>Add to Cart</span><i class="bi bi-cart-plus"></i></button></div><div class="quick-view product-action-btn product-style-icon product-quick-view-icon"><a class="open-quick-view quick-view-button" href="https://mdcomputers.in/product/adata-xpg-mouse-pad-battleground-l-bk-ogcww"><span>Quick view</span><i class="bi bi-search"></i></a></div><div class="product-compare-btn product-compare-button product-action-btn product-style-icon product-compare-icon"><button onclick="compare.add('18799');"><span>Product Compare (%s)</span><i class="bi bi-shuffle"></i></button></div><div class="product-wishlist-btn product-action-btn product-style-icon product-wishlist-icon"><button onclick="wishlist.add('18799');"><span>Add to wishlist</span><i class="bi bi-suit-heart"></i></button></div></div></div></div><h3 class="product-entities-title"><a href="https://mdcomputers.in/product/adata-xpg-mouse-pad-battleground-l-bk-ogcww">Adata XPG Battleground L Gaming Mouse Pad (Large)</a></h3><span class="price"><span class="del"><span class="amount"><span class="">₹1,699</span></span></span><span class="ins"><span class="amount"> ₹1,300<span class=""></span></span></span></span>< ...
# https://mdcomputers.in/index.php?route=product/search&page=5&search=mouse
# [<div class="product-wrapper"><div class="product-element-top product-quick-shop"><a class="product-image-link" href="https://mdcomputers.in/product/rapoo-vt30-mouse"><div class="product-labels labels-rectangular"><span class="onsale product-label">-36%</span></div><img alt="Rapoo VT30 Gaming Mouse (Black)" class="attachment-large size-large" decoding="async" fetchpriority="low" loading="lazy" src="https://mdcomputers.in/cdn-cgi/image/width=500,height=500,quality=75/image/catalog/mouse/rapoo/vt30/vt30-image-main.jpg"/></a><div class="wrapp-buttons"><div class="product-buttons"><div class="product-add-btn product-action-btn product-style-icon product-add-cart-icon"><button class="button product_type_simple add_to_cart_button ajax_add_to_cart add-to-cart-loop" onclick="cart.add('14505');"><span>Add to Cart</span><i class="bi bi-cart-plus"></i></button></div><div class="quick-view product-action-btn product-style-icon product-quick-view-icon"><a class="open-quick-view quick-view-button" href="https://mdcomputers.in/product/rapoo-vt30-mouse"><span>Quick view</span><i class="bi bi-search"></i></a></div><div class="product-compare-btn product-compare-button product-action-btn product-style-icon product-compare-icon"><button onclick="compare.add('14505');"><span>Product Compare (%s)</span><i class="bi bi-shuffle"></i></button></div><div class="product-wishlist-btn product-action-btn product-style-icon product-wishlist-icon"><button onclick="wishlist.add('14505');"><span>Add to wishlist</span><i class="bi bi-suit-heart"></i></button></div></div></div></div><h3 class="product-entities-title"><a href="https://mdcomputers.in/product/rapoo-vt30-mouse">Rapoo VT30 Gaming Mouse (Black)</a></h3><span class="price"><span class="del"><span class="amount"><span class="">₹2,999</span></span></span><span class="ins"><span class="amount"> ₹1,925<span class=""></span></span></span></span></div>, <div class="product-wrapper"><div class="product-element-top product-quick-shop"><a class="product-image-link" href="https://mdcomputers.in/product/cosmic-byte-atlas-tri-mode-white-wireless-mouse-tcbp03536"><div class="product-labels labels-rectangular"><span class="onsale product-label">-35%</span></div><img alt="Cosmic Byte Atlas Tri-Mode White Wireless Gaming Mouse" class="attachment-large size-large" decoding="async" fetchpriority="low" loading="lazy" src="https://mdcomputers.in/cdn-cgi/image/width=500,height=500,quality=75/image/catalog/mouse/cosmic-byte/tcbp03536/tcbp03536-image.webp"/></a><div class="wrapp-buttons"><div class="product-buttons"><div class="product-add-btn product-action-btn product-style-icon product-add-cart-icon"><button class="button product_type_simple add_to_cart_button ajax_add_to_cart add-to-cart-loop" onclick="cart.add('24591');"><span>Add to Cart</span><i class="bi bi-cart-plus"></i></button></div><div class="quick-view product-action-btn product-style-icon product-quick-view-icon"><a class="open-quick-view quick-view-button" href="https://mdcomputers.in/product/cosmic-byte-atlas-tri-mode-white-wireless-mouse-tcbp03536"><span>Quick view</span><i class="bi bi-search"></i></a></div><div class="product-compare-btn product-compare-button product-action-btn product-style-icon product-compare-icon"><button onclick="compare.add('24591');"><span>Product Compare (%s)</span><i class="bi bi-shuffle"></i></button></div><div class="product-wishlist-btn product-action-btn product-style-icon product-wishlist-icon"><button onclick="wishlist.add('24591');"><span>Add to wishlist</span><i class="bi bi-suit-heart"></i></button></div></div></div></div><h3 class="product-entities-title"><a href="https://mdcomputers.in/product/cosmic-byte-atlas-tri-mode-white-wireless-mouse-tcbp03536">Cosmic Byte Atlas Tri-Mode White Wireless Gaming Mouse</a></h3><span class="price"><span class="del"><span class="amount"><span class="">₹2,999</span></span></span><span class="ins"><span class="amount"> ₹1,940<span class=""></span></span></span></span></div>, <div cla ...
# https://mdcomputers.in/index.php?route=product/search&page=6&search=mouse
# [<div class="product-wrapper"><div class="product-element-top product-quick-shop"><a class="product-image-link" href="https://mdcomputers.in/product/cooler-master-wireless-mouse-mm-311-kkow1"><div class="product-labels labels-rectangular"><span class="onsale product-label">-29%</span></div><img alt="Cooler Master MM311 Wireless Gaming Mouse" class="attachment-large size-large" decoding="async" fetchpriority="low" loading="lazy" src="https://mdcomputers.in/cdn-cgi/image/width=500,height=500,quality=75/image/catalog/mouse/coolermaster/mm-311-kkow1/mm-311-kkow1-image-main.png"/></a><div class="wrapp-buttons"><div class="product-buttons"><div class="product-add-btn product-action-btn product-style-icon product-add-cart-icon"><button class="button product_type_simple add_to_cart_button ajax_add_to_cart add-to-cart-loop" onclick="cart.add('20048');"><span>Add to Cart</span><i class="bi bi-cart-plus"></i></button></div><div class="quick-view product-action-btn product-style-icon product-quick-view-icon"><a class="open-quick-view quick-view-button" href="https://mdcomputers.in/product/cooler-master-wireless-mouse-mm-311-kkow1"><span>Quick view</span><i class="bi bi-search"></i></a></div><div class="product-compare-btn product-compare-button product-action-btn product-style-icon product-compare-icon"><button onclick="compare.add('20048');"><span>Product Compare (%s)</span><i class="bi bi-shuffle"></i></button></div><div class="product-wishlist-btn product-action-btn product-style-icon product-wishlist-icon"><button onclick="wishlist.add('20048');"><span>Add to wishlist</span><i class="bi bi-suit-heart"></i></button></div></div></div></div><h3 class="product-entities-title"><a href="https://mdcomputers.in/product/cooler-master-wireless-mouse-mm-311-kkow1">Cooler Master MM311 Wireless Gaming Mouse</a></h3><span class="price"><span class="del"><span class="amount"><span class="">₹4,499</span></span></span><span class="ins"><span class="amount"> ₹3,200<span class=""></span></span></span></span></div>, <div class="product-wrapper"><div class="product-element-top product-quick-shop"><a class="product-image-link" href="https://mdcomputers.in/product/razer-strider-gaming-mouse-pad-rz02-03810200-r3m1"><div class="product-labels labels-rectangular"><span class="onsale product-label">-27%</span></div><img alt="Razer Strider Gaming Mouse Pad (Large)" class="attachment-large size-large" decoding="async" fetchpriority="low" loading="lazy" src="https://mdcomputers.in/cdn-cgi/image/width=500,height=500,quality=75/image/catalog/mouse%20pad/razer/rz02-03810200-r3m1/rz02_03810200_r3m1_main.jpg"/></a><div class="wrapp-buttons"><div class="product-buttons"><div class="product-add-btn product-action-btn product-style-icon product-add-cart-icon"><button class="button product_type_simple add_to_cart_button ajax_add_to_cart add-to-cart-loop" onclick="cart.add('15973');"><span>Add to Cart</span><i class="bi bi-cart-plus"></i></button></div><div class="quick-view product-action-btn product-style-icon product-quick-view-icon"><a class="open-quick-view quick-view-button" href="https://mdcomputers.in/product/razer-strider-gaming-mouse-pad-rz02-03810200-r3m1"><span>Quick view</span><i class="bi bi-search"></i></a></div><div class="product-compare-btn product-compare-button product-action-btn product-style-icon product-compare-icon"><button onclick="compare.add('15973');"><span>Product Compare (%s)</span><i class="bi bi-shuffle"></i></button></div><div class="product-wishlist-btn product-action-btn product-style-icon product-wishlist-icon"><button onclick="wishlist.add('15973');"><span>Add to wishlist</span><i class="bi bi-suit-heart"></i></button></div></div></div></div><h3 class="product-entities-title"><a href="https://mdcomputers.in/product/razer-strider-gaming-mouse-pad-rz02-03810200-r3m1">Razer Strider Gaming Mouse Pad (Large)</a></h3><span class="price"><span class="del"><span class="amount"><span class="">₹4,399</span></span></span><span class="ins"><span cla ...
# https://mdcomputers.in/index.php?route=product/search&page=7&search=mouse
# [<div class="product-wrapper"><div class="product-element-top product-quick-shop"><a class="product-image-link" href="https://mdcomputers.in/product/razer-deathadder-v3-pro-white-wireless-mouse-rz01-04630200-r3a1"><div class="product-labels labels-rectangular"><span class="onsale product-label">-74%</span></div><img alt="Razer DeathAdder V3 Pro Wireless Gaming Mouse (White)" class="attachment-large size-large" decoding="async" fetchpriority="low" loading="lazy" src="https://mdcomputers.in/cdn-cgi/image/width=500,height=500,quality=75/image/catalog/mouse/razer/rz01-04630200-r3a1/rz01-04630200-r3a1-image-main.jpg"/></a><div class="wrapp-buttons"><div class="product-buttons"><div class="product-add-btn product-action-btn product-style-icon product-add-cart-icon"><button class="button product_type_simple add_to_cart_button ajax_add_to_cart add-to-cart-loop" onclick="cart.add('19063');"><span>Add to Cart</span><i class="bi bi-cart-plus"></i></button></div><div class="quick-view product-action-btn product-style-icon product-quick-view-icon"><a class="open-quick-view quick-view-button" href="https://mdcomputers.in/product/razer-deathadder-v3-pro-white-wireless-mouse-rz01-04630200-r3a1"><span>Quick view</span><i class="bi bi-search"></i></a></div><div class="product-compare-btn product-compare-button product-action-btn product-style-icon product-compare-icon"><button onclick="compare.add('19063');"><span>Product Compare (%s)</span><i class="bi bi-shuffle"></i></button></div><div class="product-wishlist-btn product-action-btn product-style-icon product-wishlist-icon"><button onclick="wishlist.add('19063');"><span>Add to wishlist</span><i class="bi bi-suit-heart"></i></button></div></div></div></div><h3 class="product-entities-title"><a href="https://mdcomputers.in/product/razer-deathadder-v3-pro-white-wireless-mouse-rz01-04630200-r3a1">Razer DeathAdder V3 Pro Wireless Gaming Mouse (White)</a></h3><span class="price"><span class="del"><span class="amount"><span class="">₹29,999</span></span></span><span class="ins"><span class="amount"> ₹7,890<span class=""></span></span></span></span></div>, <div class="product-wrapper"><div class="product-element-top product-quick-shop"><a class="product-image-link" href="https://mdcomputers.in/product/logitech-mx-master-3s-wireless-mouse-910-006561"><div class="product-labels labels-rectangular"><span class="onsale product-label">-41%</span></div><img alt="Logitech MX Master 3S Wireless Mouse (Graphite)" class="attachment-large size-large" decoding="async" fetchpriority="low" loading="lazy" src="https://mdcomputers.in/cdn-cgi/image/width=500,height=500,quality=75/image/catalog/mouse/logitech/910-006561/910-006561-image-main.jpg"/></a><div class="wrapp-buttons"><div class="product-buttons"><div class="product-add-btn product-action-btn product-style-icon product-add-cart-icon"><button class="button product_type_simple add_to_cart_button ajax_add_to_cart add-to-cart-loop" onclick="cart.add('19806');"><span>Add to Cart</span><i class="bi bi-cart-plus"></i></button></div><div class="quick-view product-action-btn product-style-icon product-quick-view-icon"><a class="open-quick-view quick-view-button" href="https://mdcomputers.in/product/logitech-mx-master-3s-wireless-mouse-910-006561"><span>Quick view</span><i class="bi bi-search"></i></a></div><div class="product-compare-btn product-compare-button product-action-btn product-style-icon product-compare-icon"><button onclick="compare.add('19806');"><span>Product Compare (%s)</span><i class="bi bi-shuffle"></i></button></div><div class="product-wishlist-btn product-action-btn product-style-icon product-wishlist-icon"><button onclick="wishlist.add('19806');"><span>Add to wishlist</span><i class="bi bi-suit-heart"></i></button></div></div></div></div><h3 class="product-entities-title"><a href="https://mdcomputers.in/product/logitech-mx-master-3s-wireless-mouse-910-006561">Logitech MX Master 3S Wireless Mouse (Graphite)</a></h3><span class="price"><span class=" ...
# https://mdcomputers.in/index.php?route=product/search&page=8&search=mouse
# [<div class="product-wrapper"><div class="product-element-top product-quick-shop"><a class="product-image-link" href="https://mdcomputers.in/product/razer-wireless-mouse-naga-v2-pro-rz01-04400100-r3a1"><div class="product-labels labels-rectangular"><span class="onsale product-label">-47%</span></div><img alt="Razer Naga V2 Pro Wireless Gaming Mouse (Black)" class="attachment-large size-large" decoding="async" fetchpriority="low" loading="lazy" src="https://mdcomputers.in/cdn-cgi/image/width=500,height=500,quality=75/image/catalog/mouse/razer/rz01-04400100-r3a1/rz01-04400100-r3a1-image-main.jpg"/></a><div class="wrapp-buttons"><div class="product-buttons"><div class="product-add-btn product-action-btn product-style-icon product-add-cart-icon"><button class="button product_type_simple add_to_cart_button ajax_add_to_cart add-to-cart-loop" onclick="cart.add('20636');"><span>Add to Cart</span><i class="bi bi-cart-plus"></i></button></div><div class="quick-view product-action-btn product-style-icon product-quick-view-icon"><a class="open-quick-view quick-view-button" href="https://mdcomputers.in/product/razer-wireless-mouse-naga-v2-pro-rz01-04400100-r3a1"><span>Quick view</span><i class="bi bi-search"></i></a></div><div class="product-compare-btn product-compare-button product-action-btn product-style-icon product-compare-icon"><button onclick="compare.add('20636');"><span>Product Compare (%s)</span><i class="bi bi-shuffle"></i></button></div><div class="product-wishlist-btn product-action-btn product-style-icon product-wishlist-icon"><button onclick="wishlist.add('20636');"><span>Add to wishlist</span><i class="bi bi-suit-heart"></i></button></div></div></div></div><h3 class="product-entities-title"><a href="https://mdcomputers.in/product/razer-wireless-mouse-naga-v2-pro-rz01-04400100-r3a1">Razer Naga V2 Pro Wireless Gaming Mouse (Black)</a></h3><span class="price"><span class="del"><span class="amount"><span class="">₹31,999</span></span></span><span class="ins"><span class="amount"> ₹17,070<span class=""></span></span></span></span></div>]

# %%
len(item_name)
# Out:
# 141

# %%
len(link)
# Out:
# 141

# %%
sorted(item_name)
# Out:
# ['ANT ESPORTS KM550 Keyboard and Mouse Combo',
#  'ANT ESPORTS Thunder 10 RGB Keyboard and Mouse Combo with Brown Switches',
#  'ANT ESPORTS Thunder 30 RGB Keyboard and Mouse Combo',
#  'ASUS ROG Keris II ACE Wireless RGB Moonlight White Gaming Mouse',
#  'AVerMedia Elena Chan Mouse Pad (Large)',
#  'Acer Wireless White and Green Mouse',
#  'Acer ZC.A01SI.2DP Wireless Keyboard and Mouse Combo',
#  'Adata XPG Battleground L Exoskeleton Totem Edition Gaming Mouse Pad (Large)',
#  'Adata XPG Battleground L Gaming Mouse Pad (Large)',
#  'Adata XPG Infarex M20 RGB',
#  'Adata XPG Primer RGB Gaming Mouse (Black)',
#  'Adata XPG Slingshot RGB Gaming Mouse',
#  'Ant Esports AEC410 Type-C To USB Hub',
#  'Ant Esports GM100 Gaming Mouse, Black-White',
#  'Ant Esports KM1600 Gaming Keyboard and Mouse Combo',
#  'Ant Esports KM1650 Pro Gaming Keyboard and Mouse Combo (Black)',
#  'Ant Esports KM500W Gaming Keyboard And Mouse Combo',
#  'Ant Esports KM500W Pro Wireless Gaming Keyboard Mouse Combo',
#  'Ant Esports KM540 Keyboard Mouse Combo',
#  'Ant Esports KM550 Pro Wireless Keyboard and Mouse Combo',
#  'Ant Esports MP 290 Gaming Mouse Pad (Large)',
#  'Ant Esports MP265 Gaming Mouse Pad (Medium)',
#  'Ant Esports MP320C Control Gaming Mouse Pad (Large Extended)',
#  'Ant Esports MP320S Speed Gaming Mouse Pad (Large Extended)',
#  'Ant Esports MP400R RGB XL Gaming Mouse Pad (Extra Large)',
#  'Ant Esports WKM22 Wireless Keyboard and Mouse Combo',
#  'Asus CW101 Keyboard and Mouse Combo',
#  'Asus MW103 Wireless Mouse (Balck)',
#  'Asus ROG Harpe Ace Mini Wireless RGB Gaming Mouse',
#  'Asus ROG Harpe Ace Mini Wireless RGB White Gaming Mouse',
#  'Asus TUF Gaming M4 Wireless Gaming Mouse (Black)',
#  'Cooler Master MM311 Wireless Gaming Mouse',
#  'Cooler Master MP511 Mouse Pad, Large Extended',
#  'Cosmic Byte Atlas Tri-Mode White Wireless Gaming Mouse',
#  'Cosmic Byte Atlas Tri-Mode Wireless Gaming Mouse',
#  'Cosmic Byte Firestorm RGB Gaming Mouse',
#  'Cosmic Byte Raptor Dual Mode RGB Gaming Mouse',
#  'Cybeart Mortal Kombat Gaming Mouse Pad (Large)',
#  'Cybeart Mortal Kombat Gaming Mouse Pad (XXL)',
#  'Dell D SELECT DS111 Mouse',
#  'Dell D SELECT DS320 Wireless Mouse',
#  'Dell KM3322W Keyboard and Mouse Wireless Combo',
#  'Dell MS116 Wired Mouse',
#  'Dell WM118 Wireless Mouse',
#  'EVM EnGrip EWLM-360 Wireless Silver PC Mouse',
#  'EVM M06063 Wired Gaming Mouse (Black)',
#  'EVM NEO 3W042 Wireless Grey Mouse',
#  'Fingers CuteClicks WB4 Wireless White Mouse',
#  'Fingers CuteClicks WB4 Wireless Yellow Mouse',
#  'Fingers Duo-Recharge Keyboard and Mouse Combo',
#  'Fingers Magnifico Duo Keyboard and Mouse Combo (Black)',
#  'Fingers MegaHit Wired Mouse',
#  'Fingers SuperHit Blush Pink Mouse',
#  'Fingers SuperHit Graphite Grey Mouse',
#  'Fingers SuperHit Sea Blue Mouse',
#  'Galax Xanova Deimos Luxe-R RGB Gaming Mouse Pad',
#  'Gamdias Aura GS 2 Gaming Mouse (Black)',
#  'Gamdias Aura GS3 Gaming Mouse (Black)',
#  'Gamdias Aura GS4 Gaming Mouse (Black)',
#  'Gamdias ZEUS E3 RGB Mouse and NYX E1 Mouse Mat Combo',
#  'Glorious Model D RGB Wireless Gaming Mouse (Matte Black)',
#  'Glorious PC Gaming Race Cleaning Kit for Keyboard and Mouse',
#  'HP KM160 Keyboard and Mouse Combo',
#  'HP KM260 Wireless Keyboard and Mouse Combo',
#  'HP M10 Black Wired Mouse',
#  'HP M120 Wireless Mouse',
#  'HP M310 Dual Mode Wireless Mouse',
#  'HP S500 Wireless Mouse (Black)',
#  'HyperX Pulsefire Core RGB Gaming Mouse (Black)',
#  'HyperX Pulsefire Mat Large Gaming Mouse Pad',
#  'Lenovo 120 Wired Mouse (Black)',
#  'Lenovo 130 Wireless Mouse',
#  'Lenovo 160 Wired Keyboard and Mouse Combo',
#  'Lenovo 600 Bluetooth Silent Iron Grey Wireless Mouse',
#  'Lenovo WL310 Bluetooth Silent Wireless Grey Mouse',
#  'Logitech G Pro 2 Lightspeed Wireless Gaming Mouse',
#  'Logitech G Pro Wireless Gaming Mouse',
#  'Logitech G Pro X Superlight 2 DEX Pink Wireless Gaming Mouse',
#  'Logitech G Pro X Superlight 2 DEX White Wireless Gaming Mouse',
#  'Logitech G Pro X Superlight 2 DEX Wireless Gaming Mouse',
#  'Logitech G203 Lightsync RGB Gaming Mouse',
#  'Logitech G203 Lightsync RGB Gaming Mouse (White)',
#  'Logitech G305 Lightspeed Wireless Gaming Mouse (Black)',
#  'Logitech G402 Hyperion Fury Gaming Mouse',
#  'Logitech G502 HERO RGB Gaming Mouse (Black)',
#  'Logitech G502 X Black Gaming Mouse',
#  'Logitech G502 X Lightspeed Wireless Gaming Mouse (Black)',
#  'Logitech G502 X Plus Lightspeed RGB Wireless Gaming Mouse (Black)',
#  'Logitech G502 X Plus Lightspeed RGB Wireless Gaming Mouse (White)',
#  'Logitech G640 Gaming Mouse Pad (Large)',
#  'Logitech G740 Black Gaming Mouse Pad (Large)',
#  'Logitech G840 XL Black Gaming Mouse Pad (Extra Large)',
#  'Logitech G840 XL Pink Gaming Mouse Pad (Extra Large)',
#  'Logitech M171 White Wireless Mouse',
#  'Logitech M171 Wireless Gaming Mouse (Blue-Gray)',
#  'Logitech M185 Grey Wireless Mouse',
#  'Logitech M241 Silent Bluetooth Graphite Wireless Mouse',
#  'Logitech M90 Mouse (Black)',
#  'Logitech MK120 Keyboard and Mouse Combo',
#  'Logitech MK200 Keyboard and Mouse Combo',
#  'Logitech MK220 Wireless Combo',
#  'Logitech MK235 Wireless Keyboard and Mouse Combo',
#  'Logitech MK275 Wireless Keyboard and Mouse Combo',
#  'Logitech MK295 Silent Wireless Keyboard And Mouse Combo',
#  'Logitech MX Master 3S Wireless Mouse (Graphite)',
#  'Logitech PEBBLE 2 Tonal Graphite Keyboard and Mouse Combo',
#  'Rapoo V280 Gaming Mouse (Black)',
#  'Rapoo VT200 Gaming Mouse',
#  'Rapoo VT30 Gaming Mouse (Black)',
#  'Rapoo VT300 Gaming Mouse',
#  'Rapoo VT900 Gaming Mouse',
#  'Razer Basilisk V3 35k Gaming Mouse (Black)',
#  'Razer Basilisk V3 Pro 35k White Gaming Mouse',
#  'Razer Basilisk V3 Pro Wireless Gaming Mouse (Black)',
#  'Razer Basilisk V3 Pro Wireless Gaming Mouse (White)',
#  'Razer Basilisk V3 X HyperSpeed Wireless Gaming Mouse',
#  'Razer Bungee V3 Chroma Mouse Cable Management',
#  'Razer Cobra Pro Wireless Gaming Mouse (Black)',
#  'Razer Cobra Pro Wireless Gaming Mouse (White)',
#  'Razer Cobra RGB Black Gaming Mouse',
#  'Razer DeathAdder V2 X HyperSpeed Wireless Gaming Mouse',
#  'Razer DeathAdder V3 Gaming Mouse (Black)',
#  'Razer DeathAdder V3 HyperSpeed Wireless Gaming Mouse (Black)',
#  'Razer DeathAdder V3 Pro Wireless Gaming Mouse (White)',
#  'Razer Deathadder Essential White Wired Gaming Mouse',
#  'Razer Deathadder Essential Wired Gaming Mouse',
#  'Razer Gigantus V2 Soft Gaming Mouse Pad (Medium)',
#  'Razer Goliathus Mobile Stealth Edition Soft Gaming Mouse Pad',
#  'Razer Mouse Dock Pro (Magnetic Wireless Charging Dock for Razer Basillisk V3 Pro, Chroma RGB Underglow)',
#  'Razer Naga V2 HyperSpeed Wireless Gaming Mouse (Black)',
#  'Razer Naga V2 Pro Wireless Gaming Mouse (Black)',
#  'Razer Orochi V2 Wireless Gaming Mouse (Black)',
#  'Razer Orochi V2 Wireless Gaming Mouse (Quartz)',
#  'Razer Orochi V2 Wireless Gaming Mouse (White)',
#  'Razer Sphex V3 Ultra Thin Gaming Mouse Pad (Large)',
#  'Razer Strider Gaming Mouse Pad (Large)',
#  'Razer Viper V3 HyperSpeed Wireless Gaming Mouse',
#  'Razer Viper V3 Pro Wireless Gaming Mouse (Black)',
#  'Razer Wireless Mouse Charging Dock',
#  'Thermaltake Argent M5 Gaming Mouse (Black)',
#  'Thermaltake Argent MP1 RGB Gaming Mouse Pad (Medium)']

# %% [markdown]
# Converting the lists to Dictionary and then to DataFrame.

# %%
my_dict = {'item_name': item_name , 'link': link , 'new_price': new_price , 'old_price': old_price}

# %%
len(old_price)
# Out:
# 141

# %%
for key in my_dict:
    print(len(my_dict[key]))
# Out:
# 141
# 141
# 141
# 141

# %%
df = pd.DataFrame(my_dict)

# %% [markdown]
# Here is our DataFrame with required data

# %%
df
# Out:
#                                             item_name  \
# 0                            HP M10 Black Wired Mouse
# 1         Ant Esports MP265 Gaming Mouse Pad (Medium)
# 2                           Dell D SELECT DS111 Mouse
# 3                         Fingers MegaHit Wired Mouse
# 4         Ant Esports MP 290 Gaming Mouse Pad (Large)
# ..                                                ...
# 136     Razer Cobra Pro Wireless Gaming Mouse (Black)
# 137     Razer Cobra Pro Wireless Gaming Mouse (White)
# 138  Razer Viper V3 Pro Wireless Gaming Mouse (Black)
# 139      Razer Basilisk V3 Pro 35k White Gaming Mouse
# 140   Razer Naga V2 Pro Wireless Gaming Mouse (Black)
#
#                                                   link new_price old_price
# 0    https://mdcomputers.in/product/hp-m10-mouse-7y...      ₹270       599
# 1    https://mdcomputers.in/product/ant-esports-mp2...      ₹280       799
# 2    https://mdcomputers.in/product/dell-mouse-d-se...      ₹280       499
# 3    https://mdcomputers.in/product/fingers-megahit...      ₹300       425
# 4    https://mdcomputers.in/product/ant-esports-mp-...      ₹315       599
# ..                                                 ...       ...       ...
# 136  https://mdcomputers.in/product/razer-cobra-pro...   ₹11,430    21,299
# 137  https://mdcomputers.in/product/razer-cobra-pro...   ₹11,490    21,999
# 138  https://mdcomputers.in/product/razer-viper-v3-...   ₹12,750    25,999
# 139  https://mdcomputers.in/product/razer-basilisk-...   ₹13,110    24,999
# 140  https://mdcomputers.in/product/razer-wireless-...   ₹17,070    31,999
#
# [141 rows x 4 columns]

# %% [markdown]
# Converting the Dataframe to excel document with file name as the item we searched

# %%
df.to_excel(f'{search_item}_list_mdcomputers.xlsx')

# %% [markdown]
# Finally we scraped the data from website(MD Computers) successfully through BeautifulSoup4.
